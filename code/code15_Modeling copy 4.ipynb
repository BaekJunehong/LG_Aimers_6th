# %% [markdown]
# ## 난임 환자 대상 임신 성공 여부 예측

# %% [markdown]
# ### LGAimers 6th 온라인 해커톤

# %% [markdown]
# Import

# %%
import pandas as pd
import lightgbm as lgb
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### Data Load

# %%
# 데이터 로드
IVF_train = pd.read_csv('../data/IVF_train_dataset.csv')
IVF_test = pd.read_csv('../data/IVF_test_dataset.csv')

DI_train = pd.read_csv('../data/DI_train_dataset.csv')
DI_test = pd.read_csv('../data/DI_test_dataset.csv')

# %%
# ID 열을 제외한 특성과 타겟 변수 분리
IVF_X = IVF_train.drop(['임신_성공_여부', 'ID'], axis=1)
IVF_y = IVF_train['임신_성공_여부']

DI_X = DI_train.drop(['임신_성공_여부', 'ID'], axis=1)
DI_y = DI_train['임신_성공_여부']

# %% [markdown]
# ### 인코딩

# %%
IVF_categorical_columns = [
    "시술_시기_코드",
    "시술_당시_나이",
    "임신_시도_또는_마지막_임신_경과_연수",
    "배란_유도_유형",
    "착상_전_유전_검사_사용_여부",
    "남성_주_불임_원인",
    "남성_부_불임_원인",
    "여성_주_불임_원인",
    "여성_부_불임_원인",
    "부부_주_불임_원인",
    "부부_부_불임_원인",
    "불명확_불임_원인",
    "불임_원인_-_난관_질환",
    "불임_원인_-_남성_요인",
    "불임_원인_-_배란_장애",
    "불임_원인_-_여성_요인",
    "불임_원인_-_자궁경부_문제",
    "불임_원인_-_자궁내막증",
    "불임_원인_-_정자_농도",
    "불임_원인_-_정자_면역학적_요인",
    "불임_원인_-_정자_운동성",
    "불임_원인_-_정자_형태",
    "총_시술_횟수",
    "클리닉_내_총_시술_횟수",
    "IVF_시술_횟수",
    "DI_시술_횟수",
    "총_임신_횟수",
    "IVF_임신_횟수",
    "DI_임신_횟수",
    "총_출산_횟수",
    "IVF_출산_횟수",
    "DI_출산_횟수",
    "난자_출처",
    "정자_출처",
    "난자_기증자_나이",
    "정자_기증자_나이",
    "PGD_시술_여부",
    "PGS_시술_여부",
    "난자_채취_경과일",
    "난자_해동_경과일",
    "난자_혼합_경과일",
    "배아_이식_경과일",
    "배아_해동_경과일",
    "변환된_특정_시술_유형"
]

# %%
DI_categorical_columns = [
    "시술_시기_코드",
    "시술_당시_나이",
    "임신_시도_또는_마지막_임신_경과_연수",
    "총_시술_횟수",
    "클리닉_내_총_시술_횟수",
    "IVF_시술_횟수",
    "DI_시술_횟수",
    "총_임신_횟수",
    "IVF_임신_횟수",
    "DI_임신_횟수",
    "총_출산_횟수",
    "IVF_출산_횟수",
    "DI_출산_횟수",
    "정자_기증자_나이",
    "변환된_특정_시술_유형"
]

# %%
# 모든 범주형 변수를 문자열로 변환
IVF_X[IVF_categorical_columns] = IVF_X[IVF_categorical_columns].astype(str)
DI_X[DI_categorical_columns] = DI_X[DI_categorical_columns].astype(str)
IVF_test[IVF_categorical_columns] = IVF_test[IVF_categorical_columns].astype(str)
DI_test[DI_categorical_columns] = DI_test[DI_categorical_columns].astype(str)

# OrdinalEncoder를 사용하여 범주형 변수 인코딩
IVF_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
DI_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

IVF_X[IVF_categorical_columns] = IVF_encoder.fit_transform(IVF_X[IVF_categorical_columns])
DI_X[DI_categorical_columns] = DI_encoder.fit_transform(DI_X[DI_categorical_columns])
IVF_test[IVF_categorical_columns] = IVF_encoder.transform(IVF_test[IVF_categorical_columns])
DI_test[DI_categorical_columns] = DI_encoder.transform(DI_test[DI_categorical_columns])

# %%
# import category_encoders as ce

# # 모든 범주형 변수를 문자열로 변환
# IVF_X[IVF_categorical_columns] = IVF_X[IVF_categorical_columns].astype(str)
# DI_X[DI_categorical_columns] = DI_X[DI_categorical_columns].astype(str)
# IVF_test[IVF_categorical_columns] = IVF_test[IVF_categorical_columns].astype(str)
# DI_test[DI_categorical_columns] = DI_test[DI_categorical_columns].astype(str)

# # 타겟 인코더를 사용하여 범주형 변수 인코딩
# IVF_target_encoder = ce.TargetEncoder(cols=IVF_categorical_columns)
# DI_target_encoder = ce.TargetEncoder(cols=DI_categorical_columns)

# # 타겟 인코딩을 위해 타겟 변수가 필요합니다. 예시로 IVF_y와 DI_y를 사용합니다.
# IVF_X[IVF_categorical_columns] = IVF_target_encoder.fit_transform(IVF_X[IVF_categorical_columns], IVF_y)
# DI_X[DI_categorical_columns] = DI_target_encoder.fit_transform(DI_X[DI_categorical_columns], DI_y)
# IVF_test[IVF_categorical_columns] = IVF_target_encoder.transform(IVF_test[IVF_categorical_columns])
# DI_test[DI_categorical_columns] = DI_target_encoder.transform(DI_test[DI_categorical_columns])

# %% [markdown]
# ## Modeling

# %%
# 데이터 분할
IVF_X_train, IVF_X_test, IVF_y_train, IVF_y_test = train_test_split(IVF_X, IVF_y, test_size=0.2, random_state=42)
DI_X_train, DI_X_test, DI_y_train, DI_y_test = train_test_split(DI_X, DI_y, test_size=0.2, random_state=42)

# %% [markdown]
# ### DI 데이터

# %%
import optuna
import lightgbm as lgb
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
import optuna
import lightgbm as lgb
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# 목적 함수 정의
def objective(trial):
    param = {
        'objective': 'binary',
        'metric': 'auc',
        'verbose': -1,
        'boosting_type': 'dart',
        'n_estimators': trial.suggest_int('n_estimators', 100, 3000),
        'num_leaves': trial.suggest_int('num_leaves', 10, 2048),
        'max_depth': trial.suggest_int('max_depth', 5, 200),
        'learning_rate': trial.suggest_float('learning_rate', 1e-5, 1e-1, log=True),
        'min_child_samples': trial.suggest_int('min_child_samples', 1, 200),
        'subsample': trial.suggest_float('subsample', 0.1, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.1, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-5, 1e2, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-5, 1e2, log=True),
        'min_split_gain': trial.suggest_float('min_split_gain', 1e-5, 1e1, log=True),
        'random_state': 42,
    }

    model = lgb.LGBMClassifier(**param)
    model.fit(DI_X_train, DI_y_train, eval_set=[(DI_X_test, DI_y_test)])
    
    y_pred_proba = model.predict_proba(DI_X_test)[:, 1]
    auc = roc_auc_score(DI_y_test, y_pred_proba)
    
    return auc

# Optuna 스터디 생성 및 최적화
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=800)

# 최적의 하이퍼파라미터 출력
print("Best trial:")
trial = study.best_trial
print("  Value: {}".format(trial.value))
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))

# 최적의 하이퍼파라미터로 모델 학습
best_params = trial.params
DI_model = lgb.LGBMClassifier(**best_params)
DI_model.fit(DI_X_train, DI_y_train)

# 예측
y_pred = DI_model.predict(DI_X_test)
y_pred_proba = DI_model.predict_proba(DI_X_test)[:, 1]

# 평가
accuracy = accuracy_score(DI_y_test, y_pred)
f1 = f1_score(DI_y_test, y_pred)
auc = roc_auc_score(DI_y_test, y_pred_proba)
cm = confusion_matrix(DI_y_test, y_pred)

# 결과 출력
print()
print("--- Model Performance ---")
print(f"Model Accuracy: {accuracy}")
print(f"Model F1 Score: {f1}")
print(f"Model AUC: {auc}")

# 혼동 행렬 출력
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=DI_model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# [I 2025-02-03 21:27:07,277] A new study created in memory with name: no-name-2023a729-e6ce-4ff3-bcb5-ec38ec7fd9b0
# [I 2025-02-03 21:27:09,247] Trial 0 finished with value: 0.6864897335080822 and parameters: {'n_estimators': 509, 'num_leaves': 1360, 'max_depth': 16, 'learning_rate': 2.9256068602271934e-05, 'min_child_samples': 124, 'subsample': 0.8173856414107938, 'colsample_bytree': 0.5164807291700118, 'reg_alpha': 0.024538836643379504, 'reg_lambda': 9.237486679637602, 'min_split_gain': 0.00026834829765876223}. Best is trial 0 with value: 0.6864897335080822.
# [I 2025-02-03 21:27:30,201] Trial 1 finished with value: 0.6969064001747488 and parameters: {'n_estimators': 2441, 'num_leaves': 1721, 'max_depth': 149, 'learning_rate': 6.97271727949472e-05, 'min_child_samples': 187, 'subsample': 0.1479970129542126, 'colsample_bytree': 0.7440478024935088, 'reg_alpha': 0.0019330867818563382, 'reg_lambda': 0.009875932467543494, 'min_split_gain': 0.00030275524386857636}. Best is trial 1 with value: 0.6969064001747488.
# [I 2025-02-03 21:27:47,855] Trial 2 finished with value: 0.6921308431629531 and parameters: {'n_estimators': 2586, 'num_leaves': 1622, 'max_depth': 152, 'learning_rate': 0.0012864021693129093, 'min_child_samples': 169, 'subsample': 0.125917192134153, 'colsample_bytree': 0.36087921828343983, 'reg_alpha': 0.03976932016114982, 'reg_lambda': 0.5808307437617823, 'min_split_gain': 0.00959810100101398}. Best is trial 1 with value: 0.6969064001747488.
# [I 2025-02-03 21:28:04,394] Trial 3 finished with value: 0.6846657929226736 and parameters: {'n_estimators': 2940, 'num_leaves': 933, 'max_depth': 199, 'learning_rate': 5.892893689924974e-05, 'min_child_samples': 135, 'subsample': 0.274410051996796, 'colsample_bytree': 0.3764096938108812, 'reg_alpha': 0.0010716700556539548, 'reg_lambda': 1.112285863344522, 'min_split_gain': 0.005629674868844096}. Best is trial 1 with value: 0.6969064001747488.
# [I 2025-02-03 21:28:09,454] Trial 4 finished with value: 0.6933731979030143 and parameters: {'n_estimators': 807, 'num_leaves': 1020, 'max_depth': 56, 'learning_rate': 0.005292527250841146, 'min_child_samples': 200, 'subsample': 0.7602578800512201, 'colsample_bytree': 0.7398922198226363, 'reg_alpha': 0.08485905160066809, 'reg_lambda': 0.047319288368446503, 'min_split_gain': 0.003301449521545663}. Best is trial 1 with value: 0.6969064001747488.
# [I 2025-02-03 21:28:15,449] Trial 5 finished with value: 0.6563100698995195 and parameters: {'n_estimators': 2110, 'num_leaves': 917, 'max_depth': 73, 'learning_rate': 0.00030609883662156823, 'min_child_samples': 93, 'subsample': 0.885901824348688, 'colsample_bytree': 0.15399237588694228, 'reg_alpha': 3.528720388813329e-05, 'reg_lambda': 1.8843561133826356, 'min_split_gain': 8.31983703265111}. Best is trial 1 with value: 0.6969064001747488.
# [I 2025-02-03 21:28:31,413] Trial 6 finished with value: 0.64053626037571 and parameters: {'n_estimators': 2629, 'num_leaves': 567, 'max_depth': 83, 'learning_rate': 0.00012379897192028297, 'min_child_samples': 34, 'subsample': 0.9804264407202267, 'colsample_bytree': 0.1299163585143067, 'reg_alpha': 0.015171761933541148, 'reg_lambda': 7.27962630393818e-05, 'min_split_gain': 0.14019215878820124}. Best is trial 1 with value: 0.6969064001747488.
# [I 2025-02-03 21:28:34,842] Trial 7 finished with value: 0.6889089121887286 and parameters: {'n_estimators': 751, 'num_leaves': 1568, 'max_depth': 32, 'learning_rate': 2.812790135265873e-05, 'min_child_samples': 188, 'subsample': 0.8558793856663188, 'colsample_bytree': 0.1829543906031691, 'reg_alpha': 0.004515617852540079, 'reg_lambda': 0.08452758216852509, 'min_split_gain': 0.11612212227471769}. Best is trial 1 with value: 0.6969064001747488.
# [I 2025-02-03 21:28:51,557] Trial 8 finished with value: 0.6872051114023591 and parameters: {'n_estimators': 1155, 'num_leaves': 946, 'max_depth': 198, 'learning_rate': 0.0011155661115332242, 'min_child_samples': 3, 'subsample': 0.35871117692267196, 'colsample_bytree': 0.5936331473706231, 'reg_alpha': 0.0830270015111059, 'reg_lambda': 0.19576233560025105, 'min_split_gain': 0.0009247908895485057}. Best is trial 1 with value: 0.6969064001747488.
# [I 2025-02-03 21:29:04,100] Trial 9 finished with value: 0.7008846657929227 and parameters: {'n_estimators': 2621, 'num_leaves': 1453, 'max_depth': 6, 'learning_rate': 5.126937685588127e-05, 'min_child_samples': 90, 'subsample': 0.7208578962066875, 'colsample_bytree': 0.8437002400171212, 'reg_alpha': 0.05482809479562237, 'reg_lambda': 0.0004341899468669686, 'min_split_gain': 3.205231916759107}. Best is trial 9 with value: 0.7008846657929227.
# [I 2025-02-03 21:29:10,160] Trial 10 finished with value: 0.7024710572302317 and parameters: {'n_estimators': 1772, 'num_leaves': 2011, 'max_depth': 121, 'learning_rate': 0.03679347428042126, 'min_child_samples': 67, 'subsample': 0.5856387915722086, 'colsample_bytree': 0.9929374127048435, 'reg_alpha': 12.489479114524515, 'reg_lambda': 1.7375428741056433e-05, 'min_split_gain': 6.250085714075005}. Best is trial 10 with value: 0.7024710572302317.
# [I 2025-02-03 21:29:17,931] Trial 11 finished with value: 0.666131498470948 and parameters: {'n_estimators': 1803, 'num_leaves': 2042, 'max_depth': 125, 'learning_rate': 0.06630557946785322, 'min_child_samples': 72, 'subsample': 0.5907844741808312, 'colsample_bytree': 0.9384476475633511, 'reg_alpha': 50.46375641860522, 'reg_lambda': 1.5428258372508866e-05, 'min_split_gain': 9.817954677032768}. Best is trial 10 with value: 0.7024710572302317.
# [I 2025-02-03 21:29:24,076] Trial 12 finished with value: 0.7030171472258628 and parameters: {'n_estimators': 1418, 'num_leaves': 1993, 'max_depth': 112, 'learning_rate': 0.07010602431950205, 'min_child_samples': 65, 'subsample': 0.5977958471501695, 'colsample_bytree': 0.9901607095433174, 'reg_alpha': 11.373436441562689, 'reg_lambda': 0.0012563826359959463, 'min_split_gain': 0.3500842589181232}. Best is trial 12 with value: 0.7030171472258628.
# [I 2025-02-03 21:29:29,179] Trial 13 finished with value: 0.6997078418523373 and parameters: {'n_estimators': 1571, 'num_leaves': 2033, 'max_depth': 114, 'learning_rate': 0.09845873543768409, 'min_child_samples': 53, 'subsample': 0.5339607689443467, 'colsample_bytree': 0.9887888462290263, 'reg_alpha': 62.876823375596885, 'reg_lambda': 0.003040630310001926, 'min_split_gain': 0.40424257234903194}. Best is trial 12 with value: 0.7030171472258628.
# [I 2025-02-03 21:29:34,803] Trial 14 finished with value: 0.6990388816076889 and parameters: {'n_estimators': 1331, 'num_leaves': 191, 'max_depth': 144, 'learning_rate': 0.015899498663118544, 'min_child_samples': 27, 'subsample': 0.5725146203511642, 'colsample_bytree': 0.8541231127983108, 'reg_alpha': 4.054818081684102, 'reg_lambda': 0.00039263742446747494, 'min_split_gain': 1.1938930508857414e-05}. Best is trial 12 with value: 0.7030171472258628.
# [I 2025-02-03 21:29:43,051] Trial 15 finished with value: 0.7086282219309743 and parameters: {'n_estimators': 1848, 'num_leaves': 1838, 'max_depth': 101, 'learning_rate': 0.019724192473548865, 'min_child_samples': 62, 'subsample': 0.44196139659866185, 'colsample_bytree': 0.7054016353324377, 'reg_alpha': 1.905626730399162, 'reg_lambda': 1.3835118029406909e-05, 'min_split_gain': 0.9258916732623103}. Best is trial 15 with value: 0.7086282219309743.
# [I 2025-02-03 21:29:53,815] Trial 16 finished with value: 0.6966661205766711 and parameters: {'n_estimators': 2143, 'num_leaves': 1795, 'max_depth': 92, 'learning_rate': 0.008123193280619825, 'min_child_samples': 119, 'subsample': 0.42121152732946265, 'colsample_bytree': 0.662711667132901, 'reg_alpha': 0.6772956836365327, 'reg_lambda': 0.0008098104287233189, 'min_split_gain': 0.656865281123789}. Best is trial 15 with value: 0.7086282219309743.
# [I 2025-02-03 21:29:54,671] Trial 17 finished with value: 0.6946155526430756 and parameters: {'n_estimators': 228, 'num_leaves': 1273, 'max_depth': 54, 'learning_rate': 0.0035795078943378004, 'min_child_samples': 40, 'subsample': 0.4442793312307221, 'colsample_bytree': 0.4907675376099042, 'reg_alpha': 0.9977580398021699, 'reg_lambda': 8.653253804845138e-05, 'min_split_gain': 0.07207469427533672}. Best is trial 15 with value: 0.7086282219309743.
# [I 2025-02-03 21:29:59,974] Trial 18 finished with value: 0.7098268894713848 and parameters: {'n_estimators': 1183, 'num_leaves': 1800, 'max_depth': 177, 'learning_rate': 0.023118207643387824, 'min_child_samples': 13, 'subsample': 0.6785230452652589, 'colsample_bytree': 0.8501826048169706, 'reg_alpha': 0.737878223278432, 'reg_lambda': 0.005122608453206359, 'min_split_gain': 1.2730296558178291}. Best is trial 18 with value: 0.7098268894713848.
# [I 2025-02-03 21:30:04,035] Trial 19 finished with value: 0.7073558322411534 and parameters: {'n_estimators': 1046, 'num_leaves': 1220, 'max_depth': 167, 'learning_rate': 0.019920306692426566, 'min_child_samples': 4, 'subsample': 0.6847938221000935, 'colsample_bytree': 0.8054850018871318, 'reg_alpha': 0.4742156713978601, 'reg_lambda': 58.80314187967861, 'min_split_gain': 1.8179426882110268}. Best is trial 18 with value: 0.7098268894713848.
# [I 2025-02-03 21:30:14,124] Trial 20 finished with value: 0.7007071865443426 and parameters: {'n_estimators': 2081, 'num_leaves': 625, 'max_depth': 176, 'learning_rate': 0.0019181073317874088, 'min_child_samples': 22, 'subsample': 0.2593378071484546, 'colsample_bytree': 0.6459988277585312, 'reg_alpha': 1.708379912933446, 'reg_lambda': 0.013748201521041812, 'min_split_gain': 0.03870351879242043}. Best is trial 18 with value: 0.7098268894713848.
# [I 2025-02-03 21:30:19,031] Trial 21 finished with value: 0.7062964176496286 and parameters: {'n_estimators': 987, 'num_leaves': 1259, 'max_depth': 180, 'learning_rate': 0.019988833420185155, 'min_child_samples': 5, 'subsample': 0.6791134443982552, 'colsample_bytree': 0.8116172990781999, 'reg_alpha': 0.3622679816237621, 'reg_lambda': 46.140630342380945, 'min_split_gain': 1.256801048397141}. Best is trial 18 with value: 0.7098268894713848.
# [I 2025-02-03 21:30:24,731] Trial 22 finished with value: 0.7066131498470949 and parameters: {'n_estimators': 1135, 'num_leaves': 1808, 'max_depth': 170, 'learning_rate': 0.015899445203453762, 'min_child_samples': 16, 'subsample': 0.48346705602457096, 'colsample_bytree': 0.7506083057766104, 'reg_alpha': 0.29942153565092733, 'reg_lambda': 11.849637860216756, 'min_split_gain': 2.0948840387962195}. Best is trial 18 with value: 0.7098268894713848.
# [I 2025-02-03 21:30:37,040] Trial 23 finished with value: 0.6971139143730887 and parameters: {'n_estimators': 1594, 'num_leaves': 1187, 'max_depth': 135, 'learning_rate': 0.0322431772544219, 'min_child_samples': 46, 'subsample': 0.6559808131675579, 'colsample_bytree': 0.9074815883355488, 'reg_alpha': 3.8701346776492453, 'reg_lambda': 84.94776184322293, 'min_split_gain': 0.032617892841827305}. Best is trial 18 with value: 0.7098268894713848.
# [I 2025-02-03 21:30:40,747] Trial 24 finished with value: 0.7008054827435561 and parameters: {'n_estimators': 575, 'num_leaves': 716, 'max_depth': 164, 'learning_rate': 0.007644221006144326, 'min_child_samples': 4, 'subsample': 0.3507318583728971, 'colsample_bytree': 0.6611323795767534, 'reg_alpha': 0.3255783940371309, 'reg_lambda': 0.00557089183441776, 'min_split_gain': 0.8616431617941798}. Best is trial 18 with value: 0.7098268894713848.
# [I 2025-02-03 21:30:49,252] Trial 25 finished with value: 0.6940967671472259 and parameters: {'n_estimators': 1842, 'num_leaves': 1469, 'max_depth': 103, 'learning_rate': 0.00033649535542872684, 'min_child_samples': 54, 'subsample': 0.7695347608157841, 'colsample_bytree': 0.8220979424083779, 'reg_alpha': 12.376167182203865, 'reg_lambda': 7.422534171172204e-05, 'min_split_gain': 0.19121911253321214}. Best is trial 18 with value: 0.7098268894713848.
# [I 2025-02-03 21:30:55,447] Trial 26 finished with value: 0.7047182175622544 and parameters: {'n_estimators': 1272, 'num_leaves': 1845, 'max_depth': 185, 'learning_rate': 0.002779834582076689, 'min_child_samples': 18, 'subsample': 0.6614446045604265, 'colsample_bytree': 0.7037553464426192, 'reg_alpha': 2.1368908490476612, 'reg_lambda': 0.2705127847718292, 'min_split_gain': 2.444040082146437}. Best is trial 18 with value: 0.7098268894713848.
# [I 2025-02-03 21:31:01,130] Trial 27 finished with value: 0.7057366754041066 and parameters: {'n_estimators': 971, 'num_leaves': 1658, 'max_depth': 161, 'learning_rate': 0.031116578896063635, 'min_child_samples': 80, 'subsample': 0.5169026615694028, 'colsample_bytree': 0.7810393094539635, 'reg_alpha': 0.16933296588483232, 'reg_lambda': 7.925881965015205, 'min_split_gain': 1.2430865263963184}. Best is trial 18 with value: 0.7098268894713848.
# [I 2025-02-03 21:31:03,060] Trial 28 finished with value: 0.6891437308868501 and parameters: {'n_estimators': 333, 'num_leaves': 40, 'max_depth': 129, 'learning_rate': 0.009681996131045008, 'min_child_samples': 106, 'subsample': 0.9285262872638784, 'colsample_bytree': 0.5848756416558153, 'reg_alpha': 0.0001159153438072433, 'reg_lambda': 0.03350135511895139, 'min_split_gain': 0.03663792076499817}. Best is trial 18 with value: 0.7098268894713848.
# [I 2025-02-03 21:31:05,373] Trial 29 finished with value: 0.6707350371341196 and parameters: {'n_estimators': 669, 'num_leaves': 1121, 'max_depth': 67, 'learning_rate': 1.0877737532309074e-05, 'min_child_samples': 33, 'subsample': 0.7946868715003638, 'colsample_bytree': 0.5059469671290517, 'reg_alpha': 0.012152369836024092, 'reg_lambda': 4.107667225876208, 'min_split_gain': 3.6112669669552173}. Best is trial 18 with value: 0.7098268894713848.
# [I 2025-02-03 21:31:08,678] Trial 30 finished with value: 0.7084616644823066 and parameters: {'n_estimators': 920, 'num_leaves': 1403, 'max_depth': 99, 'learning_rate': 0.004190931517953103, 'min_child_samples': 153, 'subsample': 0.6894698363373926, 'colsample_bytree': 0.913509053214681, 'reg_alpha': 6.796979857554266, 'reg_lambda': 0.0001798735838353468, 'min_split_gain': 0.32031000012483307}. Best is trial 18 with value: 0.7098268894713848.
# [I 2025-02-03 21:31:12,839] Trial 31 finished with value: 0.7111839231105286 and parameters: {'n_estimators': 1034, 'num_leaves': 1396, 'max_depth': 93, 'learning_rate': 0.012455188568287631, 'min_child_samples': 147, 'subsample': 0.7133664036368923, 'colsample_bytree': 0.8860607757301429, 'reg_alpha': 5.9995483382897605, 'reg_lambda': 0.0001780108959217598, 'min_split_gain': 0.4124222504917696}. Best is trial 31 with value: 0.7111839231105286.
# [I 2025-02-03 21:31:16,414] Trial 32 finished with value: 0.694429882044561 and parameters: {'n_estimators': 870, 'num_leaves': 1474, 'max_depth': 94, 'learning_rate': 0.00397961465268108, 'min_child_samples': 142, 'subsample': 0.7384989683067122, 'colsample_bytree': 0.9107099464314827, 'reg_alpha': 24.29223701275337, 'reg_lambda': 0.00019756999948843606, 'min_split_gain': 0.23225921828009435}. Best is trial 31 with value: 0.7111839231105286.
# [I 2025-02-03 21:31:18,174] Trial 33 finished with value: 0.7036861074705111 and parameters: {'n_estimators': 461, 'num_leaves': 1398, 'max_depth': 100, 'learning_rate': 0.01060694144485964, 'min_child_samples': 155, 'subsample': 0.8367274528131033, 'colsample_bytree': 0.8856280086321703, 'reg_alpha': 2.864777373703109, 'reg_lambda': 1.0808171661292964e-05, 'min_split_gain': 0.4157765620479316}. Best is trial 31 with value: 0.7111839231105286.
# [I 2025-02-03 21:31:23,364] Trial 34 finished with value: 0.7085490388816077 and parameters: {'n_estimators': 1391, 'num_leaves': 1578, 'max_depth': 82, 'learning_rate': 0.0006003687635039059, 'min_child_samples': 167, 'subsample': 0.6317633628857138, 'colsample_bytree': 0.9409315970294784, 'reg_alpha': 7.2651744985728, 'reg_lambda': 3.8397627374055435e-05, 'min_split_gain': 0.013910498584187329}. Best is trial 31 with value: 0.7111839231105286.
# [I 2025-02-03 21:31:29,585] Trial 35 finished with value: 0.690083005679336 and parameters: {'n_estimators': 1434, 'num_leaves': 1583, 'max_depth': 39, 'learning_rate': 0.0006843190305432975, 'min_child_samples': 166, 'subsample': 0.615776087516539, 'colsample_bytree': 0.7459229096077272, 'reg_alpha': 21.350605229673608, 'reg_lambda': 4.7418570624309196e-05, 'min_split_gain': 0.01684418080720979}. Best is trial 31 with value: 0.7111839231105286.
# [I 2025-02-03 21:31:34,208] Trial 36 finished with value: 0.6945991699432068 and parameters: {'n_estimators': 1252, 'num_leaves': 1901, 'max_depth': 86, 'learning_rate': 0.0006020473127884401, 'min_child_samples': 134, 'subsample': 0.48969558386460355, 'colsample_bytree': 0.8618817578302074, 'reg_alpha': 87.17197048657691, 'reg_lambda': 2.984539830470756e-05, 'min_split_gain': 3.273530986111805e-05}. Best is trial 31 with value: 0.7111839231105286.
# [I 2025-02-03 21:31:49,556] Trial 37 finished with value: 0.7059332678025338 and parameters: {'n_estimators': 2294, 'num_leaves': 1716, 'max_depth': 76, 'learning_rate': 0.00018472868941100444, 'min_child_samples': 105, 'subsample': 0.39765274597263295, 'colsample_bytree': 0.9433685758571401, 'reg_alpha': 1.039836760348266, 'reg_lambda': 0.0016842970798901706, 'min_split_gain': 0.002852131516458605}. Best is trial 31 with value: 0.7111839231105286.
# [I 2025-02-03 21:32:01,391] Trial 38 finished with value: 0.6927806902577545 and parameters: {'n_estimators': 1918, 'num_leaves': 1696, 'max_depth': 66, 'learning_rate': 0.0020783037317035416, 'min_child_samples': 179, 'subsample': 0.1965707369402368, 'colsample_bytree': 0.40347253780123, 'reg_alpha': 0.15549184153606405, 'reg_lambda': 0.0001845997616740114, 'min_split_gain': 0.00024587462847899187}. Best is trial 31 with value: 0.7111839231105286.
# [I 2025-02-03 21:32:10,504] Trial 39 finished with value: 0.7013051550895587 and parameters: {'n_estimators': 1637, 'num_leaves': 1576, 'max_depth': 50, 'learning_rate': 0.04859591684678079, 'min_child_samples': 124, 'subsample': 0.63920755152175, 'colsample_bytree': 0.7010499644288538, 'reg_alpha': 6.519436692524406, 'reg_lambda': 3.262118507422164e-05, 'min_split_gain': 0.009683994045420334}. Best is trial 31 with value: 0.7111839231105286.
# [I 2025-02-03 21:32:16,743] Trial 40 finished with value: 0.6858808431629533 and parameters: {'n_estimators': 1470, 'num_leaves': 1881, 'max_depth': 108, 'learning_rate': 0.0013761171249609837, 'min_child_samples': 200, 'subsample': 0.895711519604073, 'colsample_bytree': 0.7808512423745226, 'reg_alpha': 28.60383209702113, 'reg_lambda': 0.012116594406795834, 'min_split_gain': 0.09289472035557282}. Best is trial 31 with value: 0.7111839231105286.
# [I 2025-02-03 21:32:20,373] Trial 41 finished with value: 0.7085626911314985 and parameters: {'n_estimators': 846, 'num_leaves': 1343, 'max_depth': 80, 'learning_rate': 0.00576509605840031, 'min_child_samples': 152, 'subsample': 0.7967717834302486, 'colsample_bytree': 0.94131924808944, 'reg_alpha': 7.17415668036169, 'reg_lambda': 0.0002556104470354835, 'min_split_gain': 0.6951647553069085}. Best is trial 31 with value: 0.7111839231105286.
# [I 2025-02-03 21:32:25,769] Trial 42 finished with value: 0.7051878549584971 and parameters: {'n_estimators': 1138, 'num_leaves': 1315, 'max_depth': 75, 'learning_rate': 0.006208903551411286, 'min_child_samples': 168, 'subsample': 0.801173655910007, 'colsample_bytree': 0.9537173590887018, 'reg_alpha': 1.4061785332318797, 'reg_lambda': 0.0004968763601206982, 'min_split_gain': 0.7349973097487283}. Best is trial 31 with value: 0.7111839231105286.
# [I 2025-02-03 21:32:29,169] Trial 43 finished with value: 0.6925376802096986 and parameters: {'n_estimators': 694, 'num_leaves': 1072, 'max_depth': 83, 'learning_rate': 0.02485379273388599, 'min_child_samples': 157, 'subsample': 0.742914931027641, 'colsample_bytree': 0.8734954663591918, 'reg_alpha': 7.119593681796371, 'reg_lambda': 9.341140716467066e-05, 'min_split_gain': 0.0009365567063469883}. Best is trial 31 with value: 0.7111839231105286.
# [I 2025-02-03 21:32:41,338] Trial 44 finished with value: 0.7060779816513763 and parameters: {'n_estimators': 2923, 'num_leaves': 1528, 'max_depth': 66, 'learning_rate': 0.015262407760897568, 'min_child_samples': 138, 'subsample': 0.7087798870451638, 'colsample_bytree': 0.956183269251365, 'reg_alpha': 3.156491496825248, 'reg_lambda': 1.0347945527857029e-05, 'min_split_gain': 4.88651775125521}. Best is trial 31 with value: 0.7111839231105286.
# [I 2025-02-03 21:32:54,589] Trial 45 finished with value: 0.6797782874617736 and parameters: {'n_estimators': 1697, 'num_leaves': 1756, 'max_depth': 119, 'learning_rate': 0.0007368008678419848, 'min_child_samples': 185, 'subsample': 0.9789805935736472, 'colsample_bytree': 0.25277754776567224, 'reg_alpha': 0.0004142649384484511, 'reg_lambda': 2.6911245994520523e-05, 'min_split_gain': 0.004477359098983897}. Best is trial 31 with value: 0.7111839231105286.
# [I 2025-02-03 21:32:57,720] Trial 46 finished with value: 0.6963084316295326 and parameters: {'n_estimators': 824, 'num_leaves': 1638, 'max_depth': 31, 'learning_rate': 0.00038753662259291495, 'min_child_samples': 146, 'subsample': 0.8741593178478484, 'colsample_bytree': 0.8497336435353585, 'reg_alpha': 15.081572710671992, 'reg_lambda': 0.0002546957855846063, 'min_split_gain': 0.0777968688710005}. Best is trial 31 with value: 0.7111839231105286.
# [I 2025-02-03 21:33:02,945] Trial 47 finished with value: 0.6993337702053299 and parameters: {'n_estimators': 1296, 'num_leaves': 1940, 'max_depth': 144, 'learning_rate': 0.05197395328377244, 'min_child_samples': 118, 'subsample': 0.5516489494118748, 'colsample_bytree': 0.8974468594428269, 'reg_alpha': 38.983325093962456, 'reg_lambda': 0.001878191196353299, 'min_split_gain': 0.6122551590522173}. Best is trial 31 with value: 0.7111839231105286.
# [I 2025-02-03 21:33:07,396] Trial 48 finished with value: 0.7060534076015728 and parameters: {'n_estimators': 1076, 'num_leaves': 1362, 'max_depth': 91, 'learning_rate': 0.00011554063200248112, 'min_child_samples': 176, 'subsample': 0.620891320156558, 'colsample_bytree': 0.9831266741166267, 'reg_alpha': 6.273483957202376, 'reg_lambda': 0.004345299937235468, 'min_split_gain': 0.14236859702729998}. Best is trial 31 with value: 0.7111839231105286.
# [I 2025-02-03 21:33:14,281] Trial 49 finished with value: 0.7051168632590653 and parameters: {'n_estimators': 2003, 'num_leaves': 840, 'max_depth': 109, 'learning_rate': 0.09888609418693979, 'min_child_samples': 131, 'subsample': 0.780639158659855, 'colsample_bytree': 0.7813366874001125, 'reg_alpha': 0.027888683965294737, 'reg_lambda': 0.0007666797108916922, 'min_split_gain': 6.580474689855623}. Best is trial 31 with value: 0.7111839231105286.
# [I 2025-02-03 21:33:21,990] Trial 50 finished with value: 0.7061653560506771 and parameters: {'n_estimators': 1501, 'num_leaves': 1514, 'max_depth': 81, 'learning_rate': 0.011362394619958074, 'min_child_samples': 83, 'subsample': 0.8247608732203034, 'colsample_bytree': 0.693857661251655, 'reg_alpha': 0.7978646655630699, 'reg_lambda': 0.0001182947082066941, 'min_split_gain': 1.3843532087011543}. Best is trial 31 with value: 0.7111839231105286.
# [I 2025-02-03 21:33:25,833] Trial 51 finished with value: 0.7118747269550022 and parameters: {'n_estimators': 890, 'num_leaves': 1388, 'max_depth': 97, 'learning_rate': 0.0031689779660642988, 'min_child_samples': 152, 'subsample': 0.7037952407746622, 'colsample_bytree': 0.9261743932355755, 'reg_alpha': 6.7995808631881305, 'reg_lambda': 3.8462298234467015e-05, 'min_split_gain': 0.33755852486051746}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:33:29,919] Trial 52 finished with value: 0.704660878112713 and parameters: {'n_estimators': 783, 'num_leaves': 1152, 'max_depth': 90, 'learning_rate': 0.004846807099844906, 'min_child_samples': 150, 'subsample': 0.7401407719681855, 'colsample_bytree': 0.941340061594142, 'reg_alpha': 2.309868952474856, 'reg_lambda': 5.339616052618262e-05, 'min_split_gain': 0.4880977282373801}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:33:31,704] Trial 53 finished with value: 0.6904516164263871 and parameters: {'n_estimators': 485, 'num_leaves': 1334, 'max_depth': 117, 'learning_rate': 0.001563466679810143, 'min_child_samples': 161, 'subsample': 0.7155963273097186, 'colsample_bytree': 0.8263098653594663, 'reg_alpha': 10.41164323370094, 'reg_lambda': 2.8234227990556296e-05, 'min_split_gain': 0.23316221478785845}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:33:36,923] Trial 54 finished with value: 0.6977774137177807 and parameters: {'n_estimators': 1378, 'num_leaves': 1747, 'max_depth': 131, 'learning_rate': 0.003109158208812777, 'min_child_samples': 175, 'subsample': 0.5584595358718609, 'colsample_bytree': 0.9735721881766247, 'reg_alpha': 55.811589884354554, 'reg_lambda': 1.9813233026456738e-05, 'min_split_gain': 0.9653216177788251}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:33:42,597] Trial 55 finished with value: 0.7082459589340324 and parameters: {'n_estimators': 1218, 'num_leaves': 1638, 'max_depth': 104, 'learning_rate': 0.007126916000178006, 'min_child_samples': 115, 'subsample': 0.6330580781149708, 'colsample_bytree': 0.9128504535032437, 'reg_alpha': 4.380079632335966, 'reg_lambda': 0.00034759112432424584, 'min_split_gain': 0.020814032389585867}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:33:47,471] Trial 56 finished with value: 0.6964613368283092 and parameters: {'n_estimators': 1038, 'num_leaves': 1958, 'max_depth': 70, 'learning_rate': 0.013697369638761147, 'min_child_samples': 192, 'subsample': 0.5936005656380839, 'colsample_bytree': 0.8802382239125439, 'reg_alpha': 1.6216658305076896, 'reg_lambda': 0.07393635504333125, 'min_split_gain': 0.05862965499668934}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:33:49,857] Trial 57 finished with value: 0.706476627348187 and parameters: {'n_estimators': 599, 'num_leaves': 1442, 'max_depth': 61, 'learning_rate': 0.019663364495732867, 'min_child_samples': 64, 'subsample': 0.47842055098992775, 'colsample_bytree': 0.8388987150531938, 'reg_alpha': 1.90603526292682e-05, 'reg_lambda': 0.000695671015006962, 'min_split_gain': 3.1499975846563233}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:33:59,617] Trial 58 finished with value: 0.6985528615115771 and parameters: {'n_estimators': 1696, 'num_leaves': 1805, 'max_depth': 79, 'learning_rate': 0.0010123788718125087, 'min_child_samples': 96, 'subsample': 0.3355874465674381, 'colsample_bytree': 0.6176850632105475, 'reg_alpha': 0.5744495589740946, 'reg_lambda': 5.22573976456766e-05, 'min_split_gain': 0.12377710540848413}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:34:03,698] Trial 59 finished with value: 0.6898946046308431 and parameters: {'n_estimators': 932, 'num_leaves': 997, 'max_depth': 94, 'learning_rate': 0.0027748525802869604, 'min_child_samples': 129, 'subsample': 0.6880582696183866, 'colsample_bytree': 0.4494312875639645, 'reg_alpha': 0.14834851186509634, 'reg_lambda': 0.00011467619222466334, 'min_split_gain': 2.1698253228866817}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:34:04,184] Trial 60 finished with value: 0.6918004587155964 and parameters: {'n_estimators': 158, 'num_leaves': 418, 'max_depth': 155, 'learning_rate': 0.025946134751590303, 'min_child_samples': 144, 'subsample': 0.29705833457424985, 'colsample_bytree': 0.9998724540005759, 'reg_alpha': 17.858633362147014, 'reg_lambda': 0.0012226339289283053, 'min_split_gain': 0.27046897714940904}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:34:07,459] Trial 61 finished with value: 0.7083579073831368 and parameters: {'n_estimators': 866, 'num_leaves': 1223, 'max_depth': 95, 'learning_rate': 0.0042768332265599365, 'min_child_samples': 164, 'subsample': 0.6921806670856394, 'colsample_bytree': 0.9207101861682379, 'reg_alpha': 7.799236913773479, 'reg_lambda': 0.0001812354115387965, 'min_split_gain': 0.3590955209546126}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:34:12,521] Trial 62 finished with value: 0.7023918741808651 and parameters: {'n_estimators': 1179, 'num_leaves': 1392, 'max_depth': 103, 'learning_rate': 0.006204610848845482, 'min_child_samples': 152, 'subsample': 0.7664628967446975, 'colsample_bytree': 0.7986754656379449, 'reg_alpha': 3.841347226277987, 'reg_lambda': 1.665818508602521e-05, 'min_split_gain': 1.2993041234680751}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:34:17,474] Trial 63 finished with value: 0.6977091524683268 and parameters: {'n_estimators': 931, 'num_leaves': 1535, 'max_depth': 86, 'learning_rate': 0.00228368430712086, 'min_child_samples': 172, 'subsample': 0.6593798912284435, 'colsample_bytree': 0.9333830457937475, 'reg_alpha': 34.70780613952937, 'reg_lambda': 0.00013658175531702243, 'min_split_gain': 0.16877448643799303}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:34:20,501] Trial 64 finished with value: 0.6989242027086066 and parameters: {'n_estimators': 725, 'num_leaves': 1418, 'max_depth': 99, 'learning_rate': 0.009185898516373827, 'min_child_samples': 159, 'subsample': 0.5198509866550729, 'colsample_bytree': 0.8771568816203626, 'reg_alpha': 9.98462586778437, 'reg_lambda': 5.016099028417695e-05, 'min_split_gain': 0.567048081642875}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:34:25,687] Trial 65 finished with value: 0.7104139362166886 and parameters: {'n_estimators': 1113, 'num_leaves': 1275, 'max_depth': 199, 'learning_rate': 0.00481738322352727, 'min_child_samples': 12, 'subsample': 0.7140443446072444, 'colsample_bytree': 0.957446632670501, 'reg_alpha': 4.915158965507932, 'reg_lambda': 0.0003859249300917284, 'min_split_gain': 0.30511464930509263}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:34:34,179] Trial 66 finished with value: 0.708240498034076 and parameters: {'n_estimators': 1374, 'num_leaves': 1283, 'max_depth': 189, 'learning_rate': 0.01360105990115185, 'min_child_samples': 33, 'subsample': 0.8510416361471301, 'colsample_bytree': 0.955711773652347, 'reg_alpha': 1.2763050419128927, 'reg_lambda': 0.00039871642556682074, 'min_split_gain': 0.8718890973740276}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:34:51,145] Trial 67 finished with value: 0.6715923984272607 and parameters: {'n_estimators': 1100, 'num_leaves': 1066, 'max_depth': 190, 'learning_rate': 0.03694204320062107, 'min_child_samples': 23, 'subsample': 0.8087427463221712, 'colsample_bytree': 0.9723107771713183, 'reg_alpha': 0.05796544698297979, 'reg_lambda': 0.02412002366561185, 'min_split_gain': 0.050862570835704}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:34:56,667] Trial 68 finished with value: 0.7011440585408475 and parameters: {'n_estimators': 1547, 'num_leaves': 1229, 'max_depth': 196, 'learning_rate': 0.005358777671752588, 'min_child_samples': 12, 'subsample': 0.7182526333315438, 'colsample_bytree': 0.7619331940367353, 'reg_alpha': 4.739160125682114, 'reg_lambda': 0.0032969414835355947, 'min_split_gain': 3.5055650112035135}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:35:01,910] Trial 69 finished with value: 0.7075196592398427 and parameters: {'n_estimators': 1322, 'num_leaves': 1600, 'max_depth': 177, 'learning_rate': 0.001653606567182221, 'min_child_samples': 39, 'subsample': 0.44081484021682676, 'colsample_bytree': 0.896434836056131, 'reg_alpha': 2.300087251107338, 'reg_lambda': 8.032767886916656e-05, 'min_split_gain': 1.6030818041673704}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:35:03,197] Trial 70 finished with value: 0.6822001965923985 and parameters: {'n_estimators': 390, 'num_leaves': 1484, 'max_depth': 199, 'learning_rate': 0.0005234141218672738, 'min_child_samples': 10, 'subsample': 0.7522688739762273, 'colsample_bytree': 0.5623425194168717, 'reg_alpha': 94.70304542026652, 'reg_lambda': 1.8362155755378956e-05, 'min_split_gain': 0.0016972054283173803}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:35:07,722] Trial 71 finished with value: 0.689018130187855 and parameters: {'n_estimators': 1049, 'num_leaves': 1311, 'max_depth': 86, 'learning_rate': 0.0033856941601886677, 'min_child_samples': 182, 'subsample': 0.6635826779335641, 'colsample_bytree': 0.8510062748119515, 'reg_alpha': 18.70781909770413, 'reg_lambda': 4.3855861795233286e-05, 'min_split_gain': 0.3128779369150583}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:35:11,834] Trial 72 finished with value: 0.7059168851026649 and parameters: {'n_estimators': 959, 'num_leaves': 1156, 'max_depth': 113, 'learning_rate': 0.008495621244869118, 'min_child_samples': 48, 'subsample': 0.6046150880263272, 'colsample_bytree': 0.9170588885031404, 'reg_alpha': 5.2941421895851315, 'reg_lambda': 0.0002675468575457786, 'min_split_gain': 0.39484702302973934}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:35:14,678] Trial 73 finished with value: 0.7050294888597641 and parameters: {'n_estimators': 650, 'num_leaves': 1696, 'max_depth': 73, 'learning_rate': 0.0194179087463486, 'min_child_samples': 136, 'subsample': 0.7035335253930418, 'colsample_bytree': 0.7252388891192338, 'reg_alpha': 11.393547700641632, 'reg_lambda': 0.0006144572540404614, 'min_split_gain': 0.00015898717287984296}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:35:22,805] Trial 74 finished with value: 0.6846739842726082 and parameters: {'n_estimators': 1190, 'num_leaves': 1850, 'max_depth': 123, 'learning_rate': 0.01211035621581528, 'min_child_samples': 193, 'subsample': 0.6435030214445957, 'colsample_bytree': 0.9637876102298368, 'reg_alpha': 0.0036249257820257555, 'reg_lambda': 0.0011308487425401316, 'min_split_gain': 0.18213286575529822}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:35:26,735] Trial 75 finished with value: 0.7104030144167759 and parameters: {'n_estimators': 1024, 'num_leaves': 1356, 'max_depth': 98, 'learning_rate': 0.0009131233776787545, 'min_child_samples': 149, 'subsample': 0.6797681714901465, 'colsample_bytree': 0.9315762240132072, 'reg_alpha': 2.9517725376450983, 'reg_lambda': 0.00015367542955642467, 'min_split_gain': 0.9393318420314504}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:35:30,455] Trial 76 finished with value: 0.7117518567059851 and parameters: {'n_estimators': 802, 'num_leaves': 1371, 'max_depth': 107, 'learning_rate': 0.0008161433660269189, 'min_child_samples': 26, 'subsample': 0.5798511743271666, 'colsample_bytree': 0.9347442757788923, 'reg_alpha': 0.899837246094511, 'reg_lambda': 6.335474393386689e-05, 'min_split_gain': 0.7971043387005864}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:35:35,991] Trial 77 finished with value: 0.7016218872870249 and parameters: {'n_estimators': 783, 'num_leaves': 921, 'max_depth': 138, 'learning_rate': 0.0009876328653377745, 'min_child_samples': 28, 'subsample': 0.7765017085069201, 'colsample_bytree': 0.8322342452495598, 'reg_alpha': 0.48185975727132707, 'reg_lambda': 0.008853151881554527, 'min_split_gain': 0.9918721842211247}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:35:38,342] Trial 78 finished with value: 0.6990661861074705 and parameters: {'n_estimators': 574, 'num_leaves': 1351, 'max_depth': 108, 'learning_rate': 0.00021337989838736177, 'min_child_samples': 58, 'subsample': 0.5680418734321151, 'colsample_bytree': 0.8677203730032567, 'reg_alpha': 0.2595303118178218, 'reg_lambda': 0.9688898092714603, 'min_split_gain': 2.50919402820472}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:35:41,721] Trial 79 finished with value: 0.7019713848842289 and parameters: {'n_estimators': 853, 'num_leaves': 1271, 'max_depth': 15, 'learning_rate': 0.0008510706558763489, 'min_child_samples': 1, 'subsample': 0.38647695599152615, 'colsample_bytree': 0.8932737360000197, 'reg_alpha': 0.01552134774622569, 'reg_lambda': 7.116433007108448e-05, 'min_split_gain': 5.32051786754594}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:35:47,089] Trial 80 finished with value: 0.7063783311489734 and parameters: {'n_estimators': 1007, 'num_leaves': 861, 'max_depth': 171, 'learning_rate': 0.0012762606916344676, 'min_child_samples': 16, 'subsample': 0.6709914118397209, 'colsample_bytree': 0.9961736912941457, 'reg_alpha': 0.9073616448446986, 'reg_lambda': 0.00013641466061461798, 'min_split_gain': 0.6102457205378145}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:35:52,189] Trial 81 finished with value: 0.7080493665356051 and parameters: {'n_estimators': 1127, 'num_leaves': 1476, 'max_depth': 46, 'learning_rate': 0.0004535031647938969, 'min_child_samples': 146, 'subsample': 0.7311921655905702, 'colsample_bytree': 0.9380248254617998, 'reg_alpha': 2.1342039745473094, 'reg_lambda': 3.527275273454778e-05, 'min_split_gain': 0.5054093004148432}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:36:05,342] Trial 82 finished with value: 0.7025283966797728 and parameters: {'n_estimators': 2262, 'num_leaves': 1565, 'max_depth': 96, 'learning_rate': 0.002483954739045464, 'min_child_samples': 9, 'subsample': 0.5817495358492554, 'colsample_bytree': 0.9300196175151253, 'reg_alpha': 2.963991441069033, 'reg_lambda': 0.0002692602962700607, 'min_split_gain': 0.9028657162040807}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:36:10,813] Trial 83 finished with value: 0.6989214722586282 and parameters: {'n_estimators': 1248, 'num_leaves': 1361, 'max_depth': 87, 'learning_rate': 0.00028181681585242403, 'min_child_samples': 75, 'subsample': 0.6182007650471664, 'colsample_bytree': 0.9690979817116254, 'reg_alpha': 1.4359973452009522, 'reg_lambda': 1.2146977843413358e-05, 'min_split_gain': 1.8432660329310018}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:36:20,203] Trial 84 finished with value: 0.7033939493228485 and parameters: {'n_estimators': 1907, 'num_leaves': 1659, 'max_depth': 79, 'learning_rate': 0.001821423951442939, 'min_child_samples': 161, 'subsample': 0.5224616460221795, 'colsample_bytree': 0.8006630291528795, 'reg_alpha': 0.6867230276744668, 'reg_lambda': 1.937908258025596e-05, 'min_split_gain': 0.09623152039637241}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:36:23,203] Trial 85 finished with value: 0.7044124071647008 and parameters: {'n_estimators': 900, 'num_leaves': 1401, 'max_depth': 105, 'learning_rate': 0.000625799974315056, 'min_child_samples': 20, 'subsample': 0.6393139728442638, 'colsample_bytree': 0.8621838903827178, 'reg_alpha': 7.4824163586796315, 'reg_lambda': 6.942613499186431e-05, 'min_split_gain': 0.01399899279511135}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:36:27,472] Trial 86 finished with value: 0.7084534731323723 and parameters: {'n_estimators': 1008, 'num_leaves': 1516, 'max_depth': 115, 'learning_rate': 0.025229662811290885, 'min_child_samples': 27, 'subsample': 0.679769453171461, 'colsample_bytree': 0.8985397700782889, 'reg_alpha': 1.054891066514266, 'reg_lambda': 0.001962317266174122, 'min_split_gain': 1.1712465841333464}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:36:32,298] Trial 87 finished with value: 0.6836746395806028 and parameters: {'n_estimators': 1423, 'num_leaves': 1190, 'max_depth': 59, 'learning_rate': 0.000816505660919169, 'min_child_samples': 168, 'subsample': 0.7884541670639911, 'colsample_bytree': 0.2761753447732397, 'reg_alpha': 3.2262538766230233, 'reg_lambda': 3.0744912283625544e-05, 'min_split_gain': 0.658655614328774}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:36:36,493] Trial 88 finished with value: 0.6948257972913936 and parameters: {'n_estimators': 1076, 'num_leaves': 1782, 'max_depth': 70, 'learning_rate': 0.0011921900958203088, 'min_child_samples': 150, 'subsample': 0.7602473998178944, 'colsample_bytree': 0.9394492832293128, 'reg_alpha': 28.8236813965154, 'reg_lambda': 0.306570977563926, 'min_split_gain': 0.007414010900677364}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:36:40,537] Trial 89 finished with value: 0.6898236129314111 and parameters: {'n_estimators': 816, 'num_leaves': 1999, 'max_depth': 183, 'learning_rate': 0.04659295799655553, 'min_child_samples': 140, 'subsample': 0.7164121538199815, 'colsample_bytree': 0.9780691011451658, 'reg_alpha': 1.8498381071967915, 'reg_lambda': 0.00010639660362724598, 'min_split_gain': 0.2735330332169444}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:36:47,843] Trial 90 finished with value: 0.6826889471384884 and parameters: {'n_estimators': 752, 'num_leaves': 1092, 'max_depth': 82, 'learning_rate': 0.0066035057527419, 'min_child_samples': 39, 'subsample': 0.46840989930512134, 'colsample_bytree': 0.9211939371570267, 'reg_alpha': 0.2198374404353061, 'reg_lambda': 0.0003375550379169357, 'min_split_gain': 0.02533764974209629}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:36:51,325] Trial 91 finished with value: 0.7087783966797728 and parameters: {'n_estimators': 930, 'num_leaves': 1302, 'max_depth': 98, 'learning_rate': 0.004071790919885118, 'min_child_samples': 155, 'subsample': 0.6878063898287469, 'colsample_bytree': 0.9527191192149919, 'reg_alpha': 5.420524357119255, 'reg_lambda': 0.00019915420341361375, 'min_split_gain': 0.402206172302664}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:36:57,113] Trial 92 finished with value: 0.6940012013979904 and parameters: {'n_estimators': 1174, 'num_leaves': 1296, 'max_depth': 98, 'learning_rate': 0.004846129474788579, 'min_child_samples': 156, 'subsample': 0.6992515661017205, 'colsample_bytree': 0.946647596786156, 'reg_alpha': 14.85738715533256, 'reg_lambda': 0.0001737073780693755, 'min_split_gain': 0.44744210181163163}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:37:02,853] Trial 93 finished with value: 0.6995522062035824 and parameters: {'n_estimators': 958, 'num_leaves': 1242, 'max_depth': 91, 'learning_rate': 0.018221110928437072, 'min_child_samples': 162, 'subsample': 0.6552659395471264, 'colsample_bytree': 0.8875853112236495, 'reg_alpha': 5.484760055882103, 'reg_lambda': 0.0005228825351658369, 'min_split_gain': 0.2155340884329745}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:37:07,783] Trial 94 finished with value: 0.702129750982962 and parameters: {'n_estimators': 1268, 'num_leaves': 1442, 'max_depth': 101, 'learning_rate': 0.003726661777535959, 'min_child_samples': 148, 'subsample': 0.10414347606932417, 'colsample_bytree': 0.9982529976134352, 'reg_alpha': 8.430110072569695, 'reg_lambda': 2.4213559990686536e-05, 'min_split_gain': 0.7638275520367734}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:37:10,932] Trial 95 finished with value: 0.7011932066404543 and parameters: {'n_estimators': 692, 'num_leaves': 1170, 'max_depth': 109, 'learning_rate': 0.00988194780365054, 'min_child_samples': 125, 'subsample': 0.6072780948005714, 'colsample_bytree': 0.9607051182772764, 'reg_alpha': 0.4060493799605881, 'reg_lambda': 6.572495429432008e-05, 'min_split_gain': 1.8496252194509424}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:37:14,915] Trial 96 finished with value: 0.7116371778069026 and parameters: {'n_estimators': 880, 'num_leaves': 1365, 'max_depth': 160, 'learning_rate': 0.00041428444367488525, 'min_child_samples': 6, 'subsample': 0.5375035131573387, 'colsample_bytree': 0.9091991197806685, 'reg_alpha': 4.246066511585972, 'reg_lambda': 0.0009287846786153122, 'min_split_gain': 0.13450683679419206}. Best is trial 51 with value: 0.7118747269550022.
# [I 2025-02-03 21:37:18,493] Trial 97 finished with value: 0.7131689602446484 and parameters: {'n_estimators': 880, 'num_leaves': 1367, 'max_depth': 158, 'learning_rate': 0.00038942512212073165, 'min_child_samples': 7, 'subsample': 0.5433562452539323, 'colsample_bytree': 0.9139571818063409, 'reg_alpha': 3.783212410025173, 'reg_lambda': 0.0009407196371390273, 'min_split_gain': 1.2952908418196574}. Best is trial 97 with value: 0.7131689602446484.
# [I 2025-02-03 21:37:20,899] Trial 98 finished with value: 0.7097504368719965 and parameters: {'n_estimators': 612, 'num_leaves': 1361, 'max_depth': 155, 'learning_rate': 0.00025578988490369456, 'min_child_samples': 7, 'subsample': 0.45327004289879874, 'colsample_bytree': 0.8180004836955698, 'reg_alpha': 3.6906689920608837, 'reg_lambda': 0.0010866608165312523, 'min_split_gain': 1.1450597977231698}. Best is trial 97 with value: 0.7131689602446484.
# [I 2025-02-03 21:37:22,884] Trial 99 finished with value: 0.6905362603757099 and parameters: {'n_estimators': 558, 'num_leaves': 1379, 'max_depth': 155, 'learning_rate': 0.00015515622452812983, 'min_child_samples': 8, 'subsample': 0.49885818587727204, 'colsample_bytree': 0.8495161727080635, 'reg_alpha': 3.529793603575785, 'reg_lambda': 0.0008517949368255106, 'min_split_gain': 8.623150015971394}. Best is trial 97 with value: 0.7131689602446484.
# [I 2025-02-03 21:37:25,365] Trial 100 finished with value: 0.6978511358671908 and parameters: {'n_estimators': 635, 'num_leaves': 1110, 'max_depth': 161, 'learning_rate': 0.000281649923760439, 'min_child_samples': 13, 'subsample': 0.5450347882131924, 'colsample_bytree': 0.905584002278003, 'reg_alpha': 4.216694591652011, 'reg_lambda': 0.0020405545915188634, 'min_split_gain': 2.9528696897673874}. Best is trial 97 with value: 0.7131689602446484.
# [I 2025-02-03 21:37:28,715] Trial 101 finished with value: 0.708712865880297 and parameters: {'n_estimators': 755, 'num_leaves': 1317, 'max_depth': 145, 'learning_rate': 0.0003475074083818569, 'min_child_samples': 5, 'subsample': 0.45884166076586413, 'colsample_bytree': 0.8170626844678088, 'reg_alpha': 2.389696338183502, 'reg_lambda': 0.0008850795172575608, 'min_split_gain': 1.2552238242987874}. Best is trial 97 with value: 0.7131689602446484.
# [I 2025-02-03 21:37:31,382] Trial 102 finished with value: 0.6993091961555266 and parameters: {'n_estimators': 728, 'num_leaves': 1312, 'max_depth': 152, 'learning_rate': 9.980436554335047e-05, 'min_child_samples': 6, 'subsample': 0.4264246981635429, 'colsample_bytree': 0.8103230064769028, 'reg_alpha': 2.5145524186426615, 'reg_lambda': 0.00792307851865719, 'min_split_gain': 4.327811258143257}. Best is trial 97 with value: 0.7131689602446484.
# [I 2025-02-03 21:37:35,737] Trial 103 finished with value: 0.6932557885539539 and parameters: {'n_estimators': 886, 'num_leaves': 1425, 'max_depth': 146, 'learning_rate': 0.00038137139605048064, 'min_child_samples': 24, 'subsample': 0.4044281405323083, 'colsample_bytree': 0.8309452315298038, 'reg_alpha': 1.4119327675808777, 'reg_lambda': 0.0028260083792892594, 'min_split_gain': 1.1937081005372152}. Best is trial 97 with value: 0.7131689602446484.
# [I 2025-02-03 21:37:37,935] Trial 104 finished with value: 0.711680865006553 and parameters: {'n_estimators': 390, 'num_leaves': 1260, 'max_depth': 168, 'learning_rate': 0.00022129703891659918, 'min_child_samples': 14, 'subsample': 0.47248811580292316, 'colsample_bytree': 0.876191299531324, 'reg_alpha': 4.956324048400263, 'reg_lambda': 0.0010178084952857185, 'min_split_gain': 0.35394037424984537}. Best is trial 97 with value: 0.7131689602446484.
# [I 2025-02-03 21:37:39,516] Trial 105 finished with value: 0.7012287024901704 and parameters: {'n_estimators': 417, 'num_leaves': 1490, 'max_depth': 164, 'learning_rate': 0.0002483990365994845, 'min_child_samples': 16, 'subsample': 0.4950796220835686, 'colsample_bytree': 0.8740057366150322, 'reg_alpha': 14.68919487236781, 'reg_lambda': 0.001293301522951642, 'min_split_gain': 0.12957819531149317}. Best is trial 97 with value: 0.7131689602446484.
# ...
# [I 2025-02-03 22:16:06,798] Trial 766 finished with value: 0.7103374836173002 and parameters: {'n_estimators': 490, 'num_leaves': 109, 'max_depth': 164, 'learning_rate': 4.871237609518045e-05, 'min_child_samples': 16, 'subsample': 0.709707308823817, 'colsample_bytree': 0.9386919495080368, 'reg_alpha': 3.165939612484216, 'reg_lambda': 0.1263286186242304, 'min_split_gain': 0.003510426903225889}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:07,887] Trial 767 finished with value: 0.7011140235910878 and parameters: {'n_estimators': 571, 'num_leaves': 73, 'max_depth': 39, 'learning_rate': 6.118856084038628e-05, 'min_child_samples': 19, 'subsample': 0.6054275336077821, 'colsample_bytree': 0.9665091091108319, 'reg_alpha': 8.82812769457272, 'reg_lambda': 0.06139813549731817, 'min_split_gain': 0.0053929143062507005}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:12,004] Trial 768 finished with value: 0.7116262560069899 and parameters: {'n_estimators': 2140, 'num_leaves': 115, 'max_depth': 41, 'learning_rate': 2.0596695859954637e-05, 'min_child_samples': 10, 'subsample': 0.10038464864809107, 'colsample_bytree': 0.9190958615512853, 'reg_alpha': 4.3625084525012285, 'reg_lambda': 0.08256232139824998, 'min_split_gain': 0.012262062050459292}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:13,046] Trial 769 finished with value: 0.7024382918304936 and parameters: {'n_estimators': 498, 'num_leaves': 53, 'max_depth': 119, 'learning_rate': 1.392584997451825e-05, 'min_child_samples': 22, 'subsample': 0.7977902374707865, 'colsample_bytree': 0.9480371116122064, 'reg_alpha': 2.5530668421769778, 'reg_lambda': 0.01672178923739087, 'min_split_gain': 0.022596283865026188}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:14,103] Trial 770 finished with value: 0.7043659895150721 and parameters: {'n_estimators': 394, 'num_leaves': 131, 'max_depth': 46, 'learning_rate': 0.02230459292458594, 'min_child_samples': 10, 'subsample': 0.22022918697343488, 'colsample_bytree': 0.9864576922434435, 'reg_alpha': 1.8532022827942884, 'reg_lambda': 0.05084517117850732, 'min_split_gain': 0.002879268684206249}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:15,468] Trial 771 finished with value: 0.7143321319353428 and parameters: {'n_estimators': 584, 'num_leaves': 1481, 'max_depth': 151, 'learning_rate': 2.775644062058745e-05, 'min_child_samples': 4, 'subsample': 0.7114258256189251, 'colsample_bytree': 0.9732982933295703, 'reg_alpha': 3.6715142939689844, 'reg_lambda': 0.12157599777762035, 'min_split_gain': 0.004098702833717325}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:16,452] Trial 772 finished with value: 0.7116999781564002 and parameters: {'n_estimators': 463, 'num_leaves': 38, 'max_depth': 158, 'learning_rate': 4.0068551976574253e-05, 'min_child_samples': 13, 'subsample': 0.5653910364473502, 'colsample_bytree': 0.9548923032926876, 'reg_alpha': 6.045057445535919, 'reg_lambda': 0.033076596445070064, 'min_split_gain': 0.0003254203455533091}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:17,978] Trial 773 finished with value: 0.7141355395369157 and parameters: {'n_estimators': 629, 'num_leaves': 12, 'max_depth': 146, 'learning_rate': 1.650251643540165e-05, 'min_child_samples': 9, 'subsample': 0.17657501301891249, 'colsample_bytree': 0.8905661207968032, 'reg_alpha': 2.9063217308311473, 'reg_lambda': 0.08612750944027063, 'min_split_gain': 0.0322481907349927}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:19,634] Trial 774 finished with value: 0.7081613149847095 and parameters: {'n_estimators': 535, 'num_leaves': 88, 'max_depth': 48, 'learning_rate': 3.493619961638681e-05, 'min_child_samples': 1, 'subsample': 0.12728448778559628, 'colsample_bytree': 0.9982212277838116, 'reg_alpha': 1.5538839841730268, 'reg_lambda': 0.04443324092934745, 'min_split_gain': 0.016295439076063102}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:20,757] Trial 775 finished with value: 0.700961118392311 and parameters: {'n_estimators': 546, 'num_leaves': 603, 'max_depth': 170, 'learning_rate': 2.2895343593273638e-05, 'min_child_samples': 7, 'subsample': 0.16253854053003386, 'colsample_bytree': 0.9339779179331938, 'reg_alpha': 13.53107287711481, 'reg_lambda': 0.0651262833089229, 'min_split_gain': 0.01033728944916931}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:21,531] Trial 776 finished with value: 0.7138543031891658 and parameters: {'n_estimators': 350, 'num_leaves': 130, 'max_depth': 32, 'learning_rate': 1.0027038109547104e-05, 'min_child_samples': 16, 'subsample': 0.5958395246918642, 'colsample_bytree': 0.971157750462854, 'reg_alpha': 4.6769026517537595, 'reg_lambda': 0.10910976048046675, 'min_split_gain': 0.0025485800897170107}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:22,828] Trial 777 finished with value: 0.6559960681520316 and parameters: {'n_estimators': 619, 'num_leaves': 92, 'max_depth': 140, 'learning_rate': 1.7589620720736357e-05, 'min_child_samples': 12, 'subsample': 0.18734217714623586, 'colsample_bytree': 0.2775215947028795, 'reg_alpha': 2.32903670835887, 'reg_lambda': 0.024883744304725886, 'min_split_gain': 0.006127276040904233}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:23,816] Trial 778 finished with value: 0.7130652031454783 and parameters: {'n_estimators': 436, 'num_leaves': 1079, 'max_depth': 161, 'learning_rate': 3.088480421686803e-05, 'min_child_samples': 4, 'subsample': 0.2060564420765691, 'colsample_bytree': 0.9995527596659167, 'reg_alpha': 3.3675497894147024, 'reg_lambda': 0.14819308408940776, 'min_split_gain': 0.004471012840440383}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:25,178] Trial 779 finished with value: 0.7103866317169069 and parameters: {'n_estimators': 679, 'num_leaves': 166, 'max_depth': 152, 'learning_rate': 6.581330688635399e-05, 'min_child_samples': 8, 'subsample': 0.6198879942321094, 'colsample_bytree': 0.9543617491284997, 'reg_alpha': 7.384631405599312, 'reg_lambda': 0.054855692701427816, 'min_split_gain': 0.008620975492544838}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:29,928] Trial 780 finished with value: 0.6938537570991701 and parameters: {'n_estimators': 2181, 'num_leaves': 767, 'max_depth': 114, 'learning_rate': 1.4324439368451012e-05, 'min_child_samples': 20, 'subsample': 0.15441691531901644, 'colsample_bytree': 0.9104014632871501, 'reg_alpha': 1.934677661504264, 'reg_lambda': 0.08932163864739981, 'min_split_gain': 0.01722466992980563}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:30,864] Trial 781 finished with value: 0.7137013979903888 and parameters: {'n_estimators': 496, 'num_leaves': 48, 'max_depth': 136, 'learning_rate': 1.2163792475627365e-05, 'min_child_samples': 12, 'subsample': 0.11776865142832328, 'colsample_bytree': 0.941158935149338, 'reg_alpha': 4.5000096830961684, 'reg_lambda': 0.1271595758938018, 'min_split_gain': 0.0004810418445763518}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:32,211] Trial 782 finished with value: 0.7135539536915684 and parameters: {'n_estimators': 566, 'num_leaves': 130, 'max_depth': 148, 'learning_rate': 5.026783629727976e-05, 'min_child_samples': 1, 'subsample': 0.13447544388314464, 'colsample_bytree': 0.975933431018666, 'reg_alpha': 2.7598039153278564, 'reg_lambda': 0.0491664914096504, 'min_split_gain': 0.013347586767135449}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:33,440] Trial 783 finished with value: 0.7085026212319789 and parameters: {'n_estimators': 608, 'num_leaves': 100, 'max_depth': 109, 'learning_rate': 2.0033809960288333e-05, 'min_child_samples': 5, 'subsample': 0.5886448295016075, 'colsample_bytree': 0.9262799862543172, 'reg_alpha': 6.0382525966241785, 'reg_lambda': 1.748053639719375, 'min_split_gain': 0.00350662567405186}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:34,696] Trial 784 finished with value: 0.7109217999126256 and parameters: {'n_estimators': 509, 'num_leaves': 404, 'max_depth': 156, 'learning_rate': 2.5422120386433683e-05, 'min_child_samples': 9, 'subsample': 0.5726733716521613, 'colsample_bytree': 0.9621201113941726, 'reg_alpha': 1.4991562740372923, 'reg_lambda': 0.031804813624370404, 'min_split_gain': 0.007060809477920371}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:35,965] Trial 785 finished with value: 0.7141191568370467 and parameters: {'n_estimators': 663, 'num_leaves': 72, 'max_depth': 153, 'learning_rate': 0.00018490950582408282, 'min_child_samples': 15, 'subsample': 0.21211106159246404, 'colsample_bytree': 0.982994409440769, 'reg_alpha': 3.6608427105631915, 'reg_lambda': 0.15883344819963172, 'min_split_gain': 0.020241242106478576}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:37,181] Trial 786 finished with value: 0.671562363477501 and parameters: {'n_estimators': 300, 'num_leaves': 149, 'max_depth': 53, 'learning_rate': 4.340376544614027e-05, 'min_child_samples': 5, 'subsample': 0.15285625565267033, 'colsample_bytree': 0.9469764287339607, 'reg_alpha': 0.01141711245818266, 'reg_lambda': 0.07154160169774519, 'min_split_gain': 0.005053679207823389}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:37,947] Trial 787 finished with value: 0.7036779161205767 and parameters: {'n_estimators': 409, 'num_leaves': 11, 'max_depth': 144, 'learning_rate': 1.4843020811560086e-05, 'min_child_samples': 10, 'subsample': 0.17813125514492525, 'colsample_bytree': 0.9600471367242026, 'reg_alpha': 9.620873680182287, 'reg_lambda': 0.01974527388228597, 'min_split_gain': 0.002486819108411071}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:39,329] Trial 788 finished with value: 0.6897225862822193 and parameters: {'n_estimators': 575, 'num_leaves': 172, 'max_depth': 166, 'learning_rate': 7.55060104811504e-05, 'min_child_samples': 1, 'subsample': 0.511560525212773, 'colsample_bytree': 0.5714146898492705, 'reg_alpha': 2.494480931787679, 'reg_lambda': 0.10366494548831127, 'min_split_gain': 0.0110868214620036}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:40,431] Trial 789 finished with value: 0.6989487767584097 and parameters: {'n_estimators': 467, 'num_leaves': 73, 'max_depth': 131, 'learning_rate': 3.179142951823233e-05, 'min_child_samples': 27, 'subsample': 0.10012395481801989, 'colsample_bytree': 0.9298523327272056, 'reg_alpha': 0.9618394680654221, 'reg_lambda': 0.24019997682823746, 'min_split_gain': 0.030677616673944877}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:42,946] Trial 790 finished with value: 0.7035550458715597 and parameters: {'n_estimators': 1508, 'num_leaves': 306, 'max_depth': 159, 'learning_rate': 1.8471609591371172e-05, 'min_child_samples': 153, 'subsample': 0.6092276422275882, 'colsample_bytree': 0.9804486965872475, 'reg_alpha': 4.969730277618442, 'reg_lambda': 0.040634929351615494, 'min_split_gain': 0.006168657866917}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:44,278] Trial 791 finished with value: 0.7057503276539974 and parameters: {'n_estimators': 599, 'num_leaves': 113, 'max_depth': 39, 'learning_rate': 2.7636026341215766e-05, 'min_child_samples': 17, 'subsample': 0.5499484061182326, 'colsample_bytree': 0.9989935626209164, 'reg_alpha': 2.034260851324727, 'reg_lambda': 0.06990757216550314, 'min_split_gain': 0.003906609643343131}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:45,277] Trial 792 finished with value: 0.7049421144604632 and parameters: {'n_estimators': 543, 'num_leaves': 151, 'max_depth': 149, 'learning_rate': 1.1781350266102856e-05, 'min_child_samples': 99, 'subsample': 0.13725984630011953, 'colsample_bytree': 0.850519758583139, 'reg_alpha': 3.4921254597993414, 'reg_lambda': 1.1457320659498589, 'min_split_gain': 0.008409525653815033}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:47,361] Trial 793 finished with value: 0.6837074049803409 and parameters: {'n_estimators': 683, 'num_leaves': 43, 'max_depth': 142, 'learning_rate': 3.7053816091574465e-05, 'min_child_samples': 6, 'subsample': 0.18996658426599358, 'colsample_bytree': 0.9598126066516267, 'reg_alpha': 0.1454897687845646, 'reg_lambda': 0.10608386959430115, 'min_split_gain': 0.0027174160843893946}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:48,484] Trial 794 finished with value: 0.7070636740934906 and parameters: {'n_estimators': 505, 'num_leaves': 1885, 'max_depth': 43, 'learning_rate': 2.1844709411912572e-05, 'min_child_samples': 146, 'subsample': 0.11753140449426205, 'colsample_bytree': 0.9394427603968315, 'reg_alpha': 1.3465359599335207, 'reg_lambda': 0.17792945827684048, 'min_split_gain': 0.013562056908960795}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:52,430] Trial 795 finished with value: 0.7118337702053298 and parameters: {'n_estimators': 2081, 'num_leaves': 355, 'max_depth': 163, 'learning_rate': 0.0033718526458312564, 'min_child_samples': 13, 'subsample': 0.1674277434803275, 'colsample_bytree': 0.9722364164484821, 'reg_alpha': 6.992542787547843, 'reg_lambda': 0.03424819992335276, 'min_split_gain': 0.023576674473819028}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:53,608] Trial 796 finished with value: 0.681722367846221 and parameters: {'n_estimators': 616, 'num_leaves': 10, 'max_depth': 154, 'learning_rate': 1.4573942735853914e-05, 'min_child_samples': 9, 'subsample': 0.3688124237591365, 'colsample_bytree': 0.5431434185453314, 'reg_alpha': 3.0227022723646972, 'reg_lambda': 2.4264877545250165, 'min_split_gain': 0.0006233356401493674}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:56,927] Trial 797 finished with value: 0.7104439711664483 and parameters: {'n_estimators': 1669, 'num_leaves': 1040, 'max_depth': 123, 'learning_rate': 5.439735830773238e-05, 'min_child_samples': 4, 'subsample': 0.2285636731903597, 'colsample_bytree': 0.9093179287289481, 'reg_alpha': 4.785018396129414, 'reg_lambda': 0.06104187823098318, 'min_split_gain': 0.00549754052018947}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:57,878] Trial 798 finished with value: 0.7069571865443424 and parameters: {'n_estimators': 432, 'num_leaves': 85, 'max_depth': 148, 'learning_rate': 1.909567864940679e-05, 'min_child_samples': 22, 'subsample': 0.15120287760489748, 'colsample_bytree': 0.9473195440801618, 'reg_alpha': 1.9681416240689293, 'reg_lambda': 0.14117174860606407, 'min_split_gain': 0.009708626072489877}. Best is trial 568 with value: 0.7174666885102666.
# [I 2025-02-03 22:16:58,892] Trial 799 finished with value: 0.7131744211446046 and parameters: {'n_estimators': 533, 'num_leaves': 806, 'max_depth': 159, 'learning_rate': 2.5703207440264857e-05, 'min_child_samples': 12, 'subsample': 0.6219516159033807, 'colsample_bytree': 0.9997275927499966, 'reg_alpha': 3.848751600680269, 'reg_lambda': 0.2525022607969064, 'min_split_gain': 0.003363383556352644}. Best is trial 568 with value: 0.7174666885102666.
# Best trial:
#   Value: 0.7174666885102666
#   Params:
#     n_estimators: 2203
#     num_leaves: 77
#     max_depth: 14
#     learning_rate: 1.2259823211454586e-05
#     min_child_samples: 7
#     subsample: 0.664356148393677
#     colsample_bytree: 0.9853326215683745
#     reg_alpha: 4.472204940260739
#     reg_lambda: 0.64180733235793
#     min_split_gain: 0.009541597729647336
#
# --- Model Performance ---
# Model Accuracy: 0.8664546899841018
# Model F1 Score: 0.0
# Model AUC: 0.6939575141983398

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# 모델 초기화
DI_model = LGBMClassifier(
    n_estimators=1171,
    num_leaves=1352,
    max_depth=133,
    learning_rate=0.013047268869340142,
    min_child_samples=165,
    subsample=0.24314691590400292,
    colsample_bytree=0.19334614890476431,
    reg_alpha=5.901900488743287,
    reg_lambda=3.858355492244645e-05,
    min_split_gain=0.00045035353026440803,
    random_state=42,
    objective='binary',
    metric='auc',
    verbose=-1,
    boosting_type='gbdt'
)

# 모델 학습
DI_model.fit(DI_X_train, DI_y_train)

# 예측
y_pred = DI_model.predict(DI_X_test)
y_pred_proba = DI_model.predict_proba(DI_X_test)[:, 1]

# 평가
accuracy = accuracy_score(DI_y_test, y_pred)
f1 = f1_score(DI_y_test, y_pred)
auc = roc_auc_score(DI_y_test, y_pred_proba)
cm = confusion_matrix(DI_y_test, y_pred)

# 결과 출력
print()
print("--- Model Performance ---")
print(f"Model Accuracy: {accuracy}")
print(f"Model F1 Score: {f1}")
print(f"Model AUC: {auc}")

# 혼동 행렬 출력
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=DI_model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# --- Model Performance ---
# Model Accuracy: 0.8664546899841018
# Model F1 Score: 0.0
# Model AUC: 0.7120085190039318

# %% [markdown]
# ## 제출

# %%
# 모델 구축
# IVF_model = CatBoostClassifier(
#     iterations=680,
#     depth=10,
#     learning_rate=0.01,
#     random_seed=42,
#     verbose=0
# )

# DI_model = CatBoostClassifier(
#     iterations=500,
#     depth=10,
#     learning_rate=0.01,
#     random_seed=42,
#     verbose=0
# )

# 모델 학습 및 예측
IVF_model.fit(IVF_X, IVF_y)
IVF_pred_proba = IVF_model.predict_proba(IVF_test.drop('ID', axis=1))[:, 1]

DI_model.fit(DI_X, DI_y)
DI_pred_proba = DI_model.predict_proba(DI_test.drop('ID', axis=1))[:, 1]

# %%
# 예측 결과 병합
IVF_test['probability'] = IVF_pred_proba
DI_test['probability'] = DI_pred_proba

# 최종 제출 파일 생성
submission = pd.concat([IVF_test[['ID', 'probability']], DI_test[['ID', 'probability']]], axis=0)
submission = submission.sort_values(by='ID')  

# 제출 파일 저장
submission.to_csv('./code14_submit.csv', index=False, encoding='utf-8')

# %% [markdown]
# .
