# %% [markdown]
# ## 난임 환자 대상 임신 성공 여부 예측

# %% [markdown]
# ### LGAimers 6th 온라인 해커톤

# %% [markdown]
# Import

# %%
import pandas as pd
import lightgbm as lgb
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data Load

# %%
# 데이터 로드
IVF_train = pd.read_csv('../data/IVF_train_dataset_52.csv')
IVF_test = pd.read_csv('../data/IVF_test_dataset_52.csv')

# %%
# ID 열을 제외한 특성과 타겟 변수 분리
IVF_X = IVF_train.drop(['임신_성공_여부', 'ID'], axis=1)
IVF_y = IVF_train['임신_성공_여부']

# %%
print(f"IVF_X shape: {IVF_X.shape}")
print(f"IVF_test shape: {IVF_test.drop('ID', axis=1).shape}")
# Out:
# IVF_X shape: (250052, 84)
# IVF_test shape: (87891, 84)

# %% [markdown]
# ### 인코딩

# %%
IVF_categorical_columns = [
    # 없음
]

# %%
# 모든 범주형 변수를 문자열로 변환
IVF_X[IVF_categorical_columns] = IVF_X[IVF_categorical_columns].astype(str)
IVF_test[IVF_categorical_columns] = IVF_test[IVF_categorical_columns].astype(str)

# OrdinalEncoder를 사용하여 범주형 변수 인코딩
IVF_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

IVF_X[IVF_categorical_columns] = IVF_encoder.fit_transform(IVF_X[IVF_categorical_columns])
IVF_test[IVF_categorical_columns] = IVF_encoder.transform(IVF_test[IVF_categorical_columns])

# %% [markdown]
# ## Modeling

# %%
# 데이터 분할
IVF_X_train, IVF_X_test, IVF_y_train, IVF_y_test = train_test_split(IVF_X, IVF_y, test_size=0.2, random_state=42)

# %% [markdown]
# ### IVF 데이터

# %%
import optuna
import lightgbm as lgb
from sklearn.metrics import roc_auc_score

# 목적 함수 정의
def objective(trial):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 500, 5000),
        'num_leaves': trial.suggest_int('num_leaves', 1000, 5000),
        'learning_rate': trial.suggest_float('learning_rate', 0.00005, 0.5),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 500),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 200.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 200.0),

        'random_state': 42,
        'n_jobs': -1,
        'metric': 'auc',
        'objective': 'binary',
        'boosting_type': 'gbdt',
        'verbose': -1
    }

    model = lgb.LGBMClassifier(**param)
    model.fit(IVF_X_train, IVF_y_train)
    
    y_pred_proba = model.predict_proba(IVF_X_test)[:, 1]
    
    auc = roc_auc_score(IVF_y_test, y_pred_proba)
    return auc

# Optuna 스터디 생성 및 최적화 실행
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=800)

# 최적의 하이퍼파라미터 출력
print("Best trial:")
trial = study.best_trial
print(f"  Value: {trial.value}")
print("  Params: ")
for key, value in trial.params.items():
    print(f"    {key}: {value}")
# Out:
# [I 2025-02-24 19:57:54,088] A new study created in memory with name: no-name-efc10b22-319a-4e35-9d5a-bc47d7f40c6b
# [I 2025-02-24 19:57:56,568] Trial 0 finished with value: 0.7333103674800175 and parameters: {'n_estimators': 962, 'num_leaves': 2766, 'learning_rate': 0.3894742007543145, 'min_child_samples': 478, 'reg_alpha': 12.842600281955828, 'reg_lambda': 85.92430061670689}. Best is trial 0 with value: 0.7333103674800175.
# [I 2025-02-24 19:58:32,495] Trial 1 finished with value: 0.7038962471334061 and parameters: {'n_estimators': 3767, 'num_leaves': 1764, 'learning_rate': 0.12101811356897982, 'min_child_samples': 451, 'reg_alpha': 2.516442883108372, 'reg_lambda': 7.953398680439228}. Best is trial 0 with value: 0.7333103674800175.
# [I 2025-02-24 19:58:35,992] Trial 2 finished with value: 0.7379786152303714 and parameters: {'n_estimators': 2259, 'num_leaves': 3828, 'learning_rate': 0.30770538057371943, 'min_child_samples': 481, 'reg_alpha': 92.45712276119171, 'reg_lambda': 24.68335350429105}. Best is trial 2 with value: 0.7379786152303714.
# [I 2025-02-24 19:58:37,886] Trial 3 finished with value: 0.7382553179604602 and parameters: {'n_estimators': 716, 'num_leaves': 2500, 'learning_rate': 0.2662201576812031, 'min_child_samples': 457, 'reg_alpha': 26.854698682858434, 'reg_lambda': 14.17109566408703}. Best is trial 3 with value: 0.7382553179604602.
# [I 2025-02-24 19:58:42,284] Trial 4 finished with value: 0.7371327937410159 and parameters: {'n_estimators': 3218, 'num_leaves': 2840, 'learning_rate': 0.20553428391222023, 'min_child_samples': 482, 'reg_alpha': 145.19254503665172, 'reg_lambda': 43.02993929448719}. Best is trial 3 with value: 0.7382553179604602.
# [I 2025-02-24 19:58:48,251] Trial 5 finished with value: 0.7371382204720416 and parameters: {'n_estimators': 4776, 'num_leaves': 3534, 'learning_rate': 0.20299623710072526, 'min_child_samples': 200, 'reg_alpha': 144.79411475655368, 'reg_lambda': 160.9211741941576}. Best is trial 3 with value: 0.7382553179604602.
# [I 2025-02-24 19:58:56,256] Trial 6 finished with value: 0.738242683428165 and parameters: {'n_estimators': 4167, 'num_leaves': 3996, 'learning_rate': 0.06853772440217891, 'min_child_samples': 16, 'reg_alpha': 78.77970520110458, 'reg_lambda': 167.13265106683664}. Best is trial 3 with value: 0.7382553179604602.
# [I 2025-02-24 19:59:01,917] Trial 7 finished with value: 0.7391484202875769 and parameters: {'n_estimators': 3426, 'num_leaves': 2656, 'learning_rate': 0.09657483411508248, 'min_child_samples': 451, 'reg_alpha': 38.15625100651052, 'reg_lambda': 55.41710995783291}. Best is trial 7 with value: 0.7391484202875769.
# [I 2025-02-24 19:59:09,271] Trial 8 finished with value: 0.7365823240191307 and parameters: {'n_estimators': 4513, 'num_leaves': 1670, 'learning_rate': 0.04681929073314644, 'min_child_samples': 352, 'reg_alpha': 188.29917882795195, 'reg_lambda': 121.84310484903737}. Best is trial 7 with value: 0.7391484202875769.
# [I 2025-02-24 19:59:15,731] Trial 9 finished with value: 0.7380525588776095 and parameters: {'n_estimators': 4545, 'num_leaves': 3966, 'learning_rate': 0.11256353887900349, 'min_child_samples': 177, 'reg_alpha': 95.41139075403164, 'reg_lambda': 0.772324287146553}. Best is trial 7 with value: 0.7391484202875769.
# [I 2025-02-24 19:59:18,852] Trial 10 finished with value: 0.738705354530238 and parameters: {'n_estimators': 2030, 'num_leaves': 4807, 'learning_rate': 0.47628348810291693, 'min_child_samples': 326, 'reg_alpha': 50.68231350381798, 'reg_lambda': 69.32013053921112}. Best is trial 7 with value: 0.7391484202875769.
# [I 2025-02-24 19:59:22,674] Trial 11 finished with value: 0.7383684545491043 and parameters: {'n_estimators': 2220, 'num_leaves': 4950, 'learning_rate': 0.4694243677822662, 'min_child_samples': 333, 'reg_alpha': 47.8636728872165, 'reg_lambda': 68.45930033759637}. Best is trial 7 with value: 0.7391484202875769.
# [I 2025-02-24 19:59:26,018] Trial 12 finished with value: 0.7380632901912323 and parameters: {'n_estimators': 1730, 'num_leaves': 4920, 'learning_rate': 0.4766672838027508, 'min_child_samples': 350, 'reg_alpha': 56.231546191176534, 'reg_lambda': 116.25249423586953}. Best is trial 7 with value: 0.7391484202875769.
# [I 2025-02-24 19:59:30,963] Trial 13 finished with value: 0.7386212736074597 and parameters: {'n_estimators': 3214, 'num_leaves': 2378, 'learning_rate': 0.3774004815380051, 'min_child_samples': 276, 'reg_alpha': 49.24087875503693, 'reg_lambda': 57.400811770929316}. Best is trial 7 with value: 0.7391484202875769.
# [I 2025-02-24 19:59:34,190] Trial 14 finished with value: 0.7374036041144468 and parameters: {'n_estimators': 1406, 'num_leaves': 1250, 'learning_rate': 0.17130579991617734, 'min_child_samples': 398, 'reg_alpha': 126.06929897016981, 'reg_lambda': 95.80630323416445}. Best is trial 7 with value: 0.7391484202875769.
# [I 2025-02-24 19:59:42,340] Trial 15 finished with value: 0.7385025254991422 and parameters: {'n_estimators': 2775, 'num_leaves': 3400, 'learning_rate': 0.020184170446850724, 'min_child_samples': 269, 'reg_alpha': 73.21752427275109, 'reg_lambda': 48.92363025841148}. Best is trial 7 with value: 0.7391484202875769.
# [I 2025-02-24 19:59:47,551] Trial 16 finished with value: 0.7387468849958392 and parameters: {'n_estimators': 3507, 'num_leaves': 4417, 'learning_rate': 0.36405484092544926, 'min_child_samples': 402, 'reg_alpha': 37.73868747271742, 'reg_lambda': 74.1851772171809}. Best is trial 7 with value: 0.7391484202875769.
# [I 2025-02-24 19:59:52,487] Trial 17 finished with value: 0.7388594807905874 and parameters: {'n_estimators': 3653, 'num_leaves': 4372, 'learning_rate': 0.3227641780192137, 'min_child_samples': 411, 'reg_alpha': 26.19508239021758, 'reg_lambda': 137.1299803787615}. Best is trial 7 with value: 0.7391484202875769.
# [I 2025-02-24 19:59:58,037] Trial 18 finished with value: 0.7380287044379785 and parameters: {'n_estimators': 4035, 'num_leaves': 3175, 'learning_rate': 0.26019028067835226, 'min_child_samples': 93, 'reg_alpha': 21.72024489694214, 'reg_lambda': 198.98510925760155}. Best is trial 7 with value: 0.7391484202875769.
# [I 2025-02-24 20:00:02,103] Trial 19 finished with value: 0.7375116062930904 and parameters: {'n_estimators': 2742, 'num_leaves': 2303, 'learning_rate': 0.2991468629456371, 'min_child_samples': 404, 'reg_alpha': 117.27282726819509, 'reg_lambda': 141.22063902005166}. Best is trial 7 with value: 0.7391484202875769.
# [I 2025-02-24 20:00:06,681] Trial 20 finished with value: 0.7387724829215826 and parameters: {'n_estimators': 2878, 'num_leaves': 4343, 'learning_rate': 0.16665279569641245, 'min_child_samples': 423, 'reg_alpha': 69.1386385648379, 'reg_lambda': 116.25114572562858}. Best is trial 7 with value: 0.7391484202875769.
# [I 2025-02-24 20:00:11,547] Trial 21 finished with value: 0.7390910606384804 and parameters: {'n_estimators': 2749, 'num_leaves': 4304, 'learning_rate': 0.13553069299560716, 'min_child_samples': 427, 'reg_alpha': 30.293216404162877, 'reg_lambda': 115.49523671235045}. Best is trial 7 with value: 0.7391484202875769.
# [I 2025-02-24 20:00:55,146] Trial 22 finished with value: 0.7144973964678484 and parameters: {'n_estimators': 3617, 'num_leaves': 4379, 'learning_rate': 0.10361073338624625, 'min_child_samples': 375, 'reg_alpha': 3.2988648056540484, 'reg_lambda': 142.15009052366014}. Best is trial 7 with value: 0.7391484202875769.
# [I 2025-02-24 20:01:00,525] Trial 23 finished with value: 0.7387404664613365 and parameters: {'n_estimators': 3200, 'num_leaves': 3610, 'learning_rate': 0.16786860074398346, 'min_child_samples': 310, 'reg_alpha': 28.775724345103107, 'reg_lambda': 103.53247239165285}. Best is trial 7 with value: 0.7391484202875769.
# [I 2025-02-24 20:01:08,428] Trial 24 finished with value: 0.7391326401722536 and parameters: {'n_estimators': 4033, 'num_leaves': 3068, 'learning_rate': 0.07817230349963197, 'min_child_samples': 440, 'reg_alpha': 38.8349787880995, 'reg_lambda': 140.08930219225385}. Best is trial 7 with value: 0.7391484202875769.
# [I 2025-02-24 20:01:23,462] Trial 25 finished with value: 0.7389449627662776 and parameters: {'n_estimators': 4191, 'num_leaves': 2033, 'learning_rate': 0.007568082987694097, 'min_child_samples': 442, 'reg_alpha': 61.596277919703226, 'reg_lambda': 34.23096024148309}. Best is trial 7 with value: 0.7391484202875769.
# [I 2025-02-24 20:01:28,815] Trial 26 finished with value: 0.7389247278873363 and parameters: {'n_estimators': 2488, 'num_leaves': 3109, 'learning_rate': 0.07417816283158346, 'min_child_samples': 175, 'reg_alpha': 40.34965153534931, 'reg_lambda': 178.7722406323266}. Best is trial 7 with value: 0.7391484202875769.
# [I 2025-02-24 20:01:34,399] Trial 27 finished with value: 0.7365207465952472 and parameters: {'n_estimators': 3927, 'num_leaves': 2726, 'learning_rate': 0.12619955529568372, 'min_child_samples': 240, 'reg_alpha': 190.6372177237932, 'reg_lambda': 90.8435486388257}. Best is trial 7 with value: 0.7391484202875769.
# [I 2025-02-24 20:01:42,226] Trial 28 finished with value: 0.7384148417197326 and parameters: {'n_estimators': 4929, 'num_leaves': 1034, 'learning_rate': 0.048814138052109254, 'min_child_samples': 497, 'reg_alpha': 82.56635683959331, 'reg_lambda': 127.4288628767917}. Best is trial 7 with value: 0.7391484202875769.
# [I 2025-02-24 20:01:45,361] Trial 29 finished with value: 0.7375047607610907 and parameters: {'n_estimators': 1335, 'num_leaves': 2855, 'learning_rate': 0.22487757409810755, 'min_child_samples': 369, 'reg_alpha': 17.7414550550879, 'reg_lambda': 105.63614616470744}. Best is trial 7 with value: 0.7391484202875769.
# [I 2025-02-24 20:01:53,492] Trial 30 finished with value: 0.7348889793144538 and parameters: {'n_estimators': 3361, 'num_leaves': 3224, 'learning_rate': 0.08353574937313887, 'min_child_samples': 500, 'reg_alpha': 9.827449248605188, 'reg_lambda': 82.3027692743143}. Best is trial 7 with value: 0.7391484202875769.
# [I 2025-02-24 20:02:20,159] Trial 31 finished with value: 0.7335026708662118 and parameters: {'n_estimators': 4470, 'num_leaves': 2094, 'learning_rate': 0.0003697556319717781, 'min_child_samples': 444, 'reg_alpha': 61.980053585796895, 'reg_lambda': 33.53014733902029}. Best is trial 7 with value: 0.7391484202875769.
# [I 2025-02-24 20:02:28,209] Trial 32 finished with value: 0.7391865848853777 and parameters: {'n_estimators': 4210, 'num_leaves': 1913, 'learning_rate': 0.03321830156853821, 'min_child_samples': 443, 'reg_alpha': 41.39793570664902, 'reg_lambda': 29.283097938251487}. Best is trial 32 with value: 0.7391865848853777.
# [I 2025-02-24 20:02:33,807] Trial 33 finished with value: 0.7391671455372255 and parameters: {'n_estimators': 3893, 'num_leaves': 1778, 'learning_rate': 0.12804674950736578, 'min_child_samples': 459, 'reg_alpha': 35.918529504380245, 'reg_lambda': 14.213101981442236}. Best is trial 32 with value: 0.7391865848853777.
# [I 2025-02-24 20:02:40,687] Trial 34 finished with value: 0.739213338523173 and parameters: {'n_estimators': 3857, 'num_leaves': 1672, 'learning_rate': 0.040179006567836434, 'min_child_samples': 476, 'reg_alpha': 39.660355327869, 'reg_lambda': 22.57221248668322}. Best is trial 34 with value: 0.739213338523173.
# [I 2025-02-24 20:03:57,709] Trial 35 finished with value: 0.7080131001746317 and parameters: {'n_estimators': 3856, 'num_leaves': 1603, 'learning_rate': 0.03815223678746782, 'min_child_samples': 460, 'reg_alpha': 0.5019437904034589, 'reg_lambda': 15.767060868020767}. Best is trial 34 with value: 0.739213338523173.
# [I 2025-02-24 20:04:11,634] Trial 36 finished with value: 0.736992075619674 and parameters: {'n_estimators': 4467, 'num_leaves': 1946, 'learning_rate': 0.033324503518630505, 'min_child_samples': 470, 'reg_alpha': 13.878037155560474, 'reg_lambda': 22.176465537336043}. Best is trial 34 with value: 0.739213338523173.
# [I 2025-02-24 20:04:17,923] Trial 37 finished with value: 0.7383604052808845 and parameters: {'n_estimators': 4320, 'num_leaves': 1472, 'learning_rate': 0.14328084845403197, 'min_child_samples': 476, 'reg_alpha': 85.50837955955018, 'reg_lambda': 7.094679751837685}. Best is trial 34 with value: 0.739213338523173.
# [I 2025-02-24 20:04:22,786] Trial 38 finished with value: 0.7376936262432319 and parameters: {'n_estimators': 3055, 'num_leaves': 1833, 'learning_rate': 0.09996757535957801, 'min_child_samples': 464, 'reg_alpha': 108.97383798799288, 'reg_lambda': 33.48053684298952}. Best is trial 34 with value: 0.739213338523173.
# [I 2025-02-24 20:04:30,792] Trial 39 finished with value: 0.7386993870053165 and parameters: {'n_estimators': 4773, 'num_leaves': 1357, 'learning_rate': 0.062124542289555745, 'min_child_samples': 379, 'reg_alpha': 66.97728233928034, 'reg_lambda': 54.43548432538337}. Best is trial 34 with value: 0.739213338523173.
# [I 2025-02-24 20:04:37,230] Trial 40 finished with value: 0.7391980971137383 and parameters: {'n_estimators': 3732, 'num_leaves': 2656, 'learning_rate': 0.19675842168678043, 'min_child_samples': 490, 'reg_alpha': 39.11424920360612, 'reg_lambda': 23.743148850639418}. Best is trial 34 with value: 0.739213338523173.
# [I 2025-02-24 20:04:42,487] Trial 41 finished with value: 0.7389903560454214 and parameters: {'n_estimators': 3751, 'num_leaves': 2610, 'learning_rate': 0.2073955702960624, 'min_child_samples': 479, 'reg_alpha': 39.34219664809893, 'reg_lambda': 23.34362662536418}. Best is trial 34 with value: 0.739213338523173.
# [I 2025-02-24 20:04:47,304] Trial 42 finished with value: 0.7393108077488891 and parameters: {'n_estimators': 3424, 'num_leaves': 2142, 'learning_rate': 0.14578215871874575, 'min_child_samples': 491, 'reg_alpha': 50.74742422246347, 'reg_lambda': 39.9415346498639}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:04:53,007] Trial 43 finished with value: 0.7390362911624648 and parameters: {'n_estimators': 4231, 'num_leaves': 2278, 'learning_rate': 0.18246368198678534, 'min_child_samples': 493, 'reg_alpha': 53.11621347424455, 'reg_lambda': 0.3626612693818778}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:04:58,314] Trial 44 finished with value: 0.7367454422830051 and parameters: {'n_estimators': 3905, 'num_leaves': 2159, 'learning_rate': 0.13917439063705356, 'min_child_samples': 430, 'reg_alpha': 160.00252614972175, 'reg_lambda': 41.09907588952098}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:05:02,954] Trial 45 finished with value: 0.7384999593381455 and parameters: {'n_estimators': 3417, 'num_leaves': 1792, 'learning_rate': 0.23246477676514243, 'min_child_samples': 460, 'reg_alpha': 45.0856930408189, 'reg_lambda': 10.935317292766797}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:05:10,018] Trial 46 finished with value: 0.739072405337077 and parameters: {'n_estimators': 4723, 'num_leaves': 2500, 'learning_rate': 0.1867467878896641, 'min_child_samples': 498, 'reg_alpha': 29.16297120727384, 'reg_lambda': 27.595820489271752}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:05:11,953] Trial 47 finished with value: 0.7387125821675773 and parameters: {'n_estimators': 621, 'num_leaves': 1625, 'learning_rate': 0.1478622441936381, 'min_child_samples': 82, 'reg_alpha': 59.56315364569335, 'reg_lambda': 44.61804103604501}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:05:17,232] Trial 48 finished with value: 0.7384927327448099 and parameters: {'n_estimators': 3650, 'num_leaves': 1066, 'learning_rate': 0.11938106390081965, 'min_child_samples': 477, 'reg_alpha': 74.94255157252803, 'reg_lambda': 12.740931686482613}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:05:21,875] Trial 49 finished with value: 0.7386255404504187 and parameters: {'n_estimators': 2982, 'num_leaves': 1940, 'learning_rate': 0.23985511835458018, 'min_child_samples': 390, 'reg_alpha': 21.40451529645643, 'reg_lambda': 61.16940988956037}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:05:27,513] Trial 50 finished with value: 0.738381570367087 and parameters: {'n_estimators': 4099, 'num_leaves': 2478, 'learning_rate': 0.27480574319787293, 'min_child_samples': 452, 'reg_alpha': 97.61228816057036, 'reg_lambda': 19.412889680014455}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:05:34,028] Trial 51 finished with value: 0.7391132457162588 and parameters: {'n_estimators': 3409, 'num_leaves': 2711, 'learning_rate': 0.061779770731017085, 'min_child_samples': 419, 'reg_alpha': 34.81229201675865, 'reg_lambda': 40.107224432613386}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:05:39,825] Trial 52 finished with value: 0.7392456744485392 and parameters: {'n_estimators': 3753, 'num_leaves': 2890, 'learning_rate': 0.10038776243228759, 'min_child_samples': 450, 'reg_alpha': 49.056932811747586, 'reg_lambda': 52.491451310967285}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:05:44,887] Trial 53 finished with value: 0.7391745871953153 and parameters: {'n_estimators': 3745, 'num_leaves': 2208, 'learning_rate': 0.08692820426775386, 'min_child_samples': 479, 'reg_alpha': 51.246363167306384, 'reg_lambda': 28.672811346436397}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:05:49,997] Trial 54 finished with value: 0.7391583351903375 and parameters: {'n_estimators': 3734, 'num_leaves': 2224, 'learning_rate': 0.09797452271112836, 'min_child_samples': 480, 'reg_alpha': 52.47490459369458, 'reg_lambda': 49.16503245262335}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:06:00,061] Trial 55 finished with value: 0.7392408083474791 and parameters: {'n_estimators': 4330, 'num_leaves': 2912, 'learning_rate': 0.021278703893109582, 'min_child_samples': 438, 'reg_alpha': 50.49258325564637, 'reg_lambda': 63.34089637626572}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:06:08,002] Trial 56 finished with value: 0.7391560039301643 and parameters: {'n_estimators': 4391, 'num_leaves': 2915, 'learning_rate': 0.03523486876910446, 'min_child_samples': 349, 'reg_alpha': 42.33218403362617, 'reg_lambda': 65.43847272388238}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:06:18,367] Trial 57 finished with value: 0.738252015776883 and parameters: {'n_estimators': 3535, 'num_leaves': 2449, 'learning_rate': 0.017140984104165015, 'min_child_samples': 414, 'reg_alpha': 87.72261267373112, 'reg_lambda': 73.81596458607748}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:06:24,691] Trial 58 finished with value: 0.7383619232622063 and parameters: {'n_estimators': 4583, 'num_leaves': 3359, 'learning_rate': 0.44503468052233613, 'min_child_samples': 434, 'reg_alpha': 69.33034522541955, 'reg_lambda': 51.06890570741062}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:06:34,447] Trial 59 finished with value: 0.7390135120466037 and parameters: {'n_estimators': 3247, 'num_leaves': 2951, 'learning_rate': 0.024253222351327555, 'min_child_samples': 309, 'reg_alpha': 47.07252841561143, 'reg_lambda': 80.54610054890563}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:06:48,509] Trial 60 finished with value: 0.7354832157577803 and parameters: {'n_estimators': 5000, 'num_leaves': 2612, 'learning_rate': 0.05469547827310142, 'min_child_samples': 402, 'reg_alpha': 9.870717239667115, 'reg_lambda': 60.00166467259106}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:06:55,084] Trial 61 finished with value: 0.7388905701755832 and parameters: {'n_estimators': 4069, 'num_leaves': 1991, 'learning_rate': 0.08226830291993942, 'min_child_samples': 445, 'reg_alpha': 56.60980643886042, 'reg_lambda': 28.71114865699912}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:07:00,981] Trial 62 finished with value: 0.7389889466404802 and parameters: {'n_estimators': 4218, 'num_leaves': 2256, 'learning_rate': 0.09306938139243959, 'min_child_samples': 483, 'reg_alpha': 64.00950606131819, 'reg_lambda': 37.692779896664824}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:07:07,242] Trial 63 finished with value: 0.7391995086066869 and parameters: {'n_estimators': 3736, 'num_leaves': 2386, 'learning_rate': 0.045662232914999365, 'min_child_samples': 428, 'reg_alpha': 51.00015868909887, 'reg_lambda': 28.574814804331655}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:07:14,489] Trial 64 finished with value: 0.738461154766101 and parameters: {'n_estimators': 3991, 'num_leaves': 2768, 'learning_rate': 0.050995490203387436, 'min_child_samples': 426, 'reg_alpha': 76.99154575025037, 'reg_lambda': 45.626558078941216}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:07:28,960] Trial 65 finished with value: 0.7388274089981474 and parameters: {'n_estimators': 4631, 'num_leaves': 3022, 'learning_rate': 0.016006238705792014, 'min_child_samples': 387, 'reg_alpha': 24.34544734406436, 'reg_lambda': 19.454055087568975}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:07:35,920] Trial 66 finished with value: 0.7391449521074178 and parameters: {'n_estimators': 3566, 'num_leaves': 2358, 'learning_rate': 0.0405401942959586, 'min_child_samples': 449, 'reg_alpha': 45.474884402983, 'reg_lambda': 6.231670038861459}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:07:45,063] Trial 67 finished with value: 0.7389087400152846 and parameters: {'n_estimators': 4319, 'num_leaves': 2537, 'learning_rate': 0.06914176015487611, 'min_child_samples': 365, 'reg_alpha': 56.44189045114458, 'reg_lambda': 32.8835861442446}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:07:50,008] Trial 68 finished with value: 0.7388738139168378 and parameters: {'n_estimators': 3203, 'num_leaves': 3284, 'learning_rate': 0.1596639869244455, 'min_child_samples': 212, 'reg_alpha': 30.750370510274585, 'reg_lambda': 53.07205137218632}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:08:13,229] Trial 69 finished with value: 0.7382946727224334 and parameters: {'n_estimators': 3867, 'num_leaves': 3503, 'learning_rate': 0.0014255968813595143, 'min_child_samples': 414, 'reg_alpha': 47.30703778636866, 'reg_lambda': 39.42920817313959}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:08:17,806] Trial 70 finished with value: 0.7389335758183563 and parameters: {'n_estimators': 2552, 'num_leaves': 1525, 'learning_rate': 0.11900827661089841, 'min_child_samples': 462, 'reg_alpha': 35.581606738630214, 'reg_lambda': 25.548029222476295}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:08:23,589] Trial 71 finished with value: 0.7391526119622724 and parameters: {'n_estimators': 3735, 'num_leaves': 1882, 'learning_rate': 0.10739216933484168, 'min_child_samples': 486, 'reg_alpha': 51.434609019588756, 'reg_lambda': 29.33560210787396}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:08:29,885] Trial 72 finished with value: 0.7387489677831411 and parameters: {'n_estimators': 4125, 'num_leaves': 2092, 'learning_rate': 0.08658157785940887, 'min_child_samples': 468, 'reg_alpha': 70.58645078208093, 'reg_lambda': 45.11805889957344}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:08:40,333] Trial 73 finished with value: 0.7381857956687228 and parameters: {'n_estimators': 3762, 'num_leaves': 2825, 'learning_rate': 0.028457634334229577, 'min_child_samples': 500, 'reg_alpha': 19.134971533358463, 'reg_lambda': 20.85846507125911}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:08:45,382] Trial 74 finished with value: 0.7392248131674017 and parameters: {'n_estimators': 3295, 'num_leaves': 2389, 'learning_rate': 0.070970344366526, 'min_child_samples': 436, 'reg_alpha': 41.80230669610257, 'reg_lambda': 33.611866772152524}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:08:51,219] Trial 75 finished with value: 0.7390007564098839 and parameters: {'n_estimators': 3313, 'num_leaves': 2369, 'learning_rate': 0.051456475980398125, 'min_child_samples': 435, 'reg_alpha': 33.69160799830483, 'reg_lambda': 66.9842985879878}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:08:56,040] Trial 76 finished with value: 0.7390069170754825 and parameters: {'n_estimators': 3508, 'num_leaves': 1728, 'learning_rate': 0.20286457464956778, 'min_child_samples': 399, 'reg_alpha': 41.228000501531675, 'reg_lambda': 4.539216607042896}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:09:01,599] Trial 77 finished with value: 0.7367875239825389 and parameters: {'n_estimators': 3062, 'num_leaves': 2660, 'learning_rate': 0.06561036852902084, 'min_child_samples': 450, 'reg_alpha': 177.22850254099995, 'reg_lambda': 16.107068137321107}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:09:07,781] Trial 78 finished with value: 0.7387976893459535 and parameters: {'n_estimators': 3983, 'num_leaves': 3139, 'learning_rate': 0.1525187098858214, 'min_child_samples': 151, 'reg_alpha': 60.099879222983446, 'reg_lambda': 36.41748392444798}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:09:31,950] Trial 79 finished with value: 0.7376005700209873 and parameters: {'n_estimators': 3619, 'num_leaves': 2119, 'learning_rate': 0.012066694200181624, 'min_child_samples': 430, 'reg_alpha': 15.21326781279383, 'reg_lambda': 56.589859683699856}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:09:38,789] Trial 80 finished with value: 0.7387123410027318 and parameters: {'n_estimators': 4335, 'num_leaves': 1230, 'learning_rate': 0.11352103809576612, 'min_child_samples': 468, 'reg_alpha': 26.524814573303615, 'reg_lambda': 47.53861369956091}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:09:45,386] Trial 81 finished with value: 0.7391490999339596 and parameters: {'n_estimators': 3873, 'num_leaves': 2182, 'learning_rate': 0.0739981127931379, 'min_child_samples': 485, 'reg_alpha': 51.375595880544566, 'reg_lambda': 28.4602442263172}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:09:55,180] Trial 82 finished with value: 0.7392159130361989 and parameters: {'n_estimators': 3112, 'num_leaves': 2433, 'learning_rate': 0.03864529469422057, 'min_child_samples': 442, 'reg_alpha': 42.27481326368008, 'reg_lambda': 34.73496135838844}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:10:03,127] Trial 83 finished with value: 0.7392269972230588 and parameters: {'n_estimators': 3030, 'num_leaves': 2601, 'learning_rate': 0.04937439620743741, 'min_child_samples': 443, 'reg_alpha': 42.606632868725164, 'reg_lambda': 35.62720602772997}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:10:10,696] Trial 84 finished with value: 0.7373864594863397 and parameters: {'n_estimators': 2881, 'num_leaves': 2587, 'learning_rate': 0.0471764220767284, 'min_child_samples': 412, 'reg_alpha': 126.89194532634954, 'reg_lambda': 41.01211584489746}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:10:19,582] Trial 85 finished with value: 0.7387505807687962 and parameters: {'n_estimators': 2979, 'num_leaves': 2861, 'learning_rate': 0.02538588047682462, 'min_child_samples': 451, 'reg_alpha': 64.13149355085477, 'reg_lambda': 61.8844594285119}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:10:26,540] Trial 86 finished with value: 0.7392136151841429 and parameters: {'n_estimators': 3339, 'num_leaves': 2408, 'learning_rate': 0.06119979295240059, 'min_child_samples': 436, 'reg_alpha': 43.91785447709927, 'reg_lambda': 33.783114269608134}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:10:34,929] Trial 87 finished with value: 0.7389846599614516 and parameters: {'n_estimators': 3095, 'num_leaves': 2432, 'learning_rate': 0.05909216496525515, 'min_child_samples': 391, 'reg_alpha': 30.868887711151835, 'reg_lambda': 32.3200398586179}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:10:43,531] Trial 88 finished with value: 0.7387689092970539 and parameters: {'n_estimators': 2569, 'num_leaves': 2318, 'learning_rate': 0.03964307427205625, 'min_child_samples': 18, 'reg_alpha': 44.33732033788348, 'reg_lambda': 36.8736056670152}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:10:51,479] Trial 89 finished with value: 0.7390722790126341 and parameters: {'n_estimators': 3332, 'num_leaves': 2549, 'learning_rate': 0.07061454187703184, 'min_child_samples': 435, 'reg_alpha': 55.04543888478704, 'reg_lambda': 53.210085429584076}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:11:15,210] Trial 90 finished with value: 0.7388108448360752 and parameters: {'n_estimators': 2700, 'num_leaves': 2758, 'learning_rate': 0.013823824515609963, 'min_child_samples': 406, 'reg_alpha': 23.67870612427922, 'reg_lambda': 75.14435285700705}. Best is trial 42 with value: 0.7393108077488891.
# [I 2025-02-24 20:11:25,169] Trial 91 finished with value: 0.7393402277720325 and parameters: {'n_estimators': 3472, 'num_leaves': 2966, 'learning_rate': 0.10507507363494574, 'min_child_samples': 469, 'reg_alpha': 38.49576094577674, 'reg_lambda': 17.371335778049538}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:11:33,480] Trial 92 finished with value: 0.738966616446193 and parameters: {'n_estimators': 3121, 'num_leaves': 3037, 'learning_rate': 0.0958833413235468, 'min_child_samples': 460, 'reg_alpha': 34.211436697446445, 'reg_lambda': 10.596998638827884}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:11:41,044] Trial 93 finished with value: 0.7391539169668476 and parameters: {'n_estimators': 3424, 'num_leaves': 2401, 'learning_rate': 0.13100593864262422, 'min_child_samples': 422, 'reg_alpha': 47.74114795647511, 'reg_lambda': 22.358016365873713}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:11:49,023] Trial 94 finished with value: 0.739260601612872 and parameters: {'n_estimators': 2879, 'num_leaves': 2930, 'learning_rate': 0.07864812940726651, 'min_child_samples': 474, 'reg_alpha': 38.31562695889796, 'reg_lambda': 16.017753894473106}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:11:56,757] Trial 95 finished with value: 0.7392087156749658 and parameters: {'n_estimators': 2958, 'num_leaves': 2956, 'learning_rate': 0.07879467416019979, 'min_child_samples': 457, 'reg_alpha': 38.5168634549991, 'reg_lambda': 18.011412434884882}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:12:03,898] Trial 96 finished with value: 0.7391402979391009 and parameters: {'n_estimators': 3172, 'num_leaves': 3194, 'learning_rate': 0.10840537197010441, 'min_child_samples': 469, 'reg_alpha': 42.65120946012064, 'reg_lambda': 11.880500829397846}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:12:10,073] Trial 97 finished with value: 0.7385534467776664 and parameters: {'n_estimators': 2863, 'num_leaves': 2701, 'learning_rate': 0.34127382572829246, 'min_child_samples': 442, 'reg_alpha': 32.76372018878533, 'reg_lambda': 42.84292856048788}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:12:16,383] Trial 98 finished with value: 0.7390368236043314 and parameters: {'n_estimators': 2350, 'num_leaves': 2800, 'learning_rate': 0.061044614434249245, 'min_child_samples': 474, 'reg_alpha': 57.55194070307386, 'reg_lambda': 2.062689534071831}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:12:26,334] Trial 99 finished with value: 0.7388614435174685 and parameters: {'n_estimators': 3272, 'num_leaves': 2909, 'learning_rate': 0.08839876224709302, 'min_child_samples': 492, 'reg_alpha': 25.596919197515554, 'reg_lambda': 32.889903423100534}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:12:39,832] Trial 100 finished with value: 0.7391358619675488 and parameters: {'n_estimators': 3436, 'num_leaves': 3287, 'learning_rate': 0.030554404837605548, 'min_child_samples': 440, 'reg_alpha': 38.295626467218426, 'reg_lambda': 24.15612813221818}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:12:47,526] Trial 101 finished with value: 0.7391582015578689 and parameters: {'n_estimators': 2962, 'num_leaves': 2964, 'learning_rate': 0.08090034064956773, 'min_child_samples': 459, 'reg_alpha': 38.12458466020512, 'reg_lambda': 8.198595642625248}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:12:54,938] Trial 102 finished with value: 0.7391242557788589 and parameters: {'n_estimators': 2826, 'num_leaves': 2881, 'learning_rate': 0.07322696697627334, 'min_child_samples': 458, 'reg_alpha': 44.50711297041094, 'reg_lambda': 17.85871718078438}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:13:02,244] Trial 103 finished with value: 0.7389901670807588 and parameters: {'n_estimators': 2698, 'num_leaves': 3102, 'learning_rate': 0.10532183195772457, 'min_child_samples': 473, 'reg_alpha': 28.017305133727582, 'reg_lambda': 15.02822711794735}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:13:10,900] Trial 104 finished with value: 0.7393115500354915 and parameters: {'n_estimators': 2943, 'num_leaves': 3022, 'learning_rate': 0.047015349910912524, 'min_child_samples': 422, 'reg_alpha': 41.718221438243035, 'reg_lambda': 36.62724492973682}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:13:20,022] Trial 105 finished with value: 0.7390392112407022 and parameters: {'n_estimators': 3160, 'num_leaves': 3816, 'learning_rate': 0.057433189011021346, 'min_child_samples': 418, 'reg_alpha': 48.798017628113385, 'reg_lambda': 48.031878095003044}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:13:29,667] Trial 106 finished with value: 0.7389072115939262 and parameters: {'n_estimators': 3290, 'num_leaves': 2495, 'learning_rate': 0.03586306489454725, 'min_child_samples': 489, 'reg_alpha': 64.304398484111, 'reg_lambda': 36.991372094708}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:13:42,016] Trial 107 finished with value: 0.7390441890501539 and parameters: {'n_estimators': 3510, 'num_leaves': 3076, 'learning_rate': 0.021793616550461522, 'min_child_samples': 442, 'reg_alpha': 54.27869114190122, 'reg_lambda': 44.44771842739355}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:14:19,318] Trial 108 finished with value: 0.7385701341321704 and parameters: {'n_estimators': 2647, 'num_leaves': 2049, 'learning_rate': 0.005438954875707509, 'min_child_samples': 451, 'reg_alpha': 18.97204345404194, 'reg_lambda': 31.63333064777106}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:14:49,116] Trial 109 finished with value: 0.7306158556293609 and parameters: {'n_estimators': 3625, 'num_leaves': 2646, 'learning_rate': 0.04194397413074413, 'min_child_samples': 381, 'reg_alpha': 6.634944367210217, 'reg_lambda': 51.04451194177587}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:14:52,844] Trial 110 finished with value: 0.7391583769504838 and parameters: {'n_estimators': 1060, 'num_leaves': 2753, 'learning_rate': 0.09367162522420118, 'min_child_samples': 423, 'reg_alpha': 42.97681915399024, 'reg_lambda': 24.49654194044132}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:15:00,292] Trial 111 finished with value: 0.7389973268578602 and parameters: {'n_estimators': 2954, 'num_leaves': 2991, 'learning_rate': 0.0728555510433222, 'min_child_samples': 469, 'reg_alpha': 38.615938683724785, 'reg_lambda': 19.471098735669994}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:15:09,276] Trial 112 finished with value: 0.7391065181566727 and parameters: {'n_estimators': 3032, 'num_leaves': 3418, 'learning_rate': 0.05337118981363728, 'min_child_samples': 289, 'reg_alpha': 35.72981021302605, 'reg_lambda': 35.68762305430913}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:15:15,480] Trial 113 finished with value: 0.7391151186588251 and parameters: {'n_estimators': 2418, 'num_leaves': 3211, 'learning_rate': 0.12402016560788545, 'min_child_samples': 452, 'reg_alpha': 30.856659425998487, 'reg_lambda': 25.656440147911823}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:15:22,245] Trial 114 finished with value: 0.7391538835587305 and parameters: {'n_estimators': 2817, 'num_leaves': 2815, 'learning_rate': 0.08240477262890507, 'min_child_samples': 481, 'reg_alpha': 47.74681692095247, 'reg_lambda': 91.29897663335687}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:15:30,737] Trial 115 finished with value: 0.7391165134477151 and parameters: {'n_estimators': 3364, 'num_leaves': 2983, 'learning_rate': 0.06524929121238036, 'min_child_samples': 406, 'reg_alpha': 40.96243649078485, 'reg_lambda': 39.759370990869925}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:15:34,931] Trial 116 finished with value: 0.7383996827865871 and parameters: {'n_estimators': 1887, 'num_leaves': 2577, 'learning_rate': 0.4274742069281371, 'min_child_samples': 433, 'reg_alpha': 45.75435042450711, 'reg_lambda': 16.98538558411992}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:15:43,262] Trial 117 finished with value: 0.7391902075780785 and parameters: {'n_estimators': 3235, 'num_leaves': 2281, 'learning_rate': 0.04734470335560352, 'min_child_samples': 491, 'reg_alpha': 54.01790853581039, 'reg_lambda': 58.61004841354588}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:15:50,273] Trial 118 finished with value: 0.7388820657217676 and parameters: {'n_estimators': 3444, 'num_leaves': 3301, 'learning_rate': 0.09895009914753061, 'min_child_samples': 467, 'reg_alpha': 60.23976290673631, 'reg_lambda': 30.77230438114418}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:16:02,147] Trial 119 finished with value: 0.7391875276206828 and parameters: {'n_estimators': 2899, 'num_leaves': 2915, 'learning_rate': 0.02699042692702272, 'min_child_samples': 447, 'reg_alpha': 35.72677744038606, 'reg_lambda': 9.225640115647607}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:16:09,652] Trial 120 finished with value: 0.7392307890443526 and parameters: {'n_estimators': 3069, 'num_leaves': 2694, 'learning_rate': 0.0630335810480097, 'min_child_samples': 499, 'reg_alpha': 50.26065168494419, 'reg_lambda': 165.52726331396656}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:16:19,206] Trial 121 finished with value: 0.7389749319353461 and parameters: {'n_estimators': 3127, 'num_leaves': 2707, 'learning_rate': 0.07898521341737723, 'min_child_samples': 498, 'reg_alpha': 49.639641582710055, 'reg_lambda': 171.44335833718438}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:16:29,422] Trial 122 finished with value: 0.7392918496864244 and parameters: {'n_estimators': 3023, 'num_leaves': 2840, 'learning_rate': 0.060448464052244924, 'min_child_samples': 479, 'reg_alpha': 43.38071513905305, 'reg_lambda': 127.57467435422825}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:16:38,307] Trial 123 finished with value: 0.7392975979705771 and parameters: {'n_estimators': 3074, 'num_leaves': 2533, 'learning_rate': 0.05949237675093995, 'min_child_samples': 480, 'reg_alpha': 42.59443836268225, 'reg_lambda': 189.28965165453852}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:16:46,657] Trial 124 finished with value: 0.7392395544990832 and parameters: {'n_estimators': 3045, 'num_leaves': 2500, 'learning_rate': 0.062124130035848026, 'min_child_samples': 486, 'reg_alpha': 43.18629708465717, 'reg_lambda': 188.78266140874615}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:16:55,803] Trial 125 finished with value: 0.73802649428223 and parameters: {'n_estimators': 2751, 'num_leaves': 2526, 'learning_rate': 0.050460981109766406, 'min_child_samples': 485, 'reg_alpha': 103.73299015700223, 'reg_lambda': 194.11325009725033}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:17:03,594] Trial 126 finished with value: 0.7390573894324329 and parameters: {'n_estimators': 3015, 'num_leaves': 2648, 'learning_rate': 0.11495192663183706, 'min_child_samples': 500, 'reg_alpha': 58.82608105081633, 'reg_lambda': 188.2060434253218}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:17:11,985] Trial 127 finished with value: 0.7391584207986375 and parameters: {'n_estimators': 3077, 'num_leaves': 2844, 'learning_rate': 0.06861493641573582, 'min_child_samples': 477, 'reg_alpha': 51.32828248412257, 'reg_lambda': 151.05776357130492}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:17:20,242] Trial 128 finished with value: 0.7390255556728274 and parameters: {'n_estimators': 3160, 'num_leaves': 2476, 'learning_rate': 0.09063717422905447, 'min_child_samples': 464, 'reg_alpha': 32.525324940307975, 'reg_lambda': 179.84641248365563}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:17:35,466] Trial 129 finished with value: 0.738391536426027 and parameters: {'n_estimators': 3238, 'num_leaves': 4546, 'learning_rate': 0.018454875264664185, 'min_child_samples': 246, 'reg_alpha': 72.50311694173026, 'reg_lambda': 159.76136313312668}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:17:44,622] Trial 130 finished with value: 0.7387126364557677 and parameters: {'n_estimators': 2638, 'num_leaves': 2744, 'learning_rate': 0.03634769813632006, 'min_child_samples': 490, 'reg_alpha': 67.97765621129284, 'reg_lambda': 111.95721039268992}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:17:54,506] Trial 131 finished with value: 0.7391921911850329 and parameters: {'n_estimators': 3343, 'num_leaves': 2336, 'learning_rate': 0.061538317682811094, 'min_child_samples': 478, 'reg_alpha': 42.96101436315347, 'reg_lambda': 134.7952769943609}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:18:03,806] Trial 132 finished with value: 0.7389974761503837 and parameters: {'n_estimators': 2883, 'num_leaves': 2606, 'learning_rate': 0.05338925587995259, 'min_child_samples': 438, 'reg_alpha': 46.31547363759558, 'reg_lambda': 187.1716822196988}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:18:16,042] Trial 133 finished with value: 0.7390173790361609 and parameters: {'n_estimators': 3204, 'num_leaves': 2449, 'learning_rate': 0.04477292259445488, 'min_child_samples': 456, 'reg_alpha': 54.84891485003217, 'reg_lambda': 171.1734528427847}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:18:24,357] Trial 134 finished with value: 0.7392726796912165 and parameters: {'n_estimators': 3057, 'num_leaves': 2198, 'learning_rate': 0.06656088392179237, 'min_child_samples': 468, 'reg_alpha': 41.1587099339887, 'reg_lambda': 183.95168410640306}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:18:32,756] Trial 135 finished with value: 0.7392023368126022 and parameters: {'n_estimators': 3032, 'num_leaves': 3154, 'learning_rate': 0.07933798983788273, 'min_child_samples': 470, 'reg_alpha': 40.95853864713134, 'reg_lambda': 179.2416114114514}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:18:39,570] Trial 136 finished with value: 0.7389500387120732 and parameters: {'n_estimators': 2768, 'num_leaves': 2234, 'learning_rate': 0.13758238506179968, 'min_child_samples': 484, 'reg_alpha': 29.0448636996437, 'reg_lambda': 191.52971343965166}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:18:47,005] Trial 137 finished with value: 0.739088128032199 and parameters: {'n_estimators': 3095, 'num_leaves': 2171, 'learning_rate': 0.10069847156520409, 'min_child_samples': 500, 'reg_alpha': 49.18606542592837, 'reg_lambda': 198.64442925574522}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:18:58,728] Trial 138 finished with value: 0.739209808746798 and parameters: {'n_estimators': 2918, 'num_leaves': 2785, 'learning_rate': 0.030944494275136396, 'min_child_samples': 467, 'reg_alpha': 34.66821966151635, 'reg_lambda': 165.28059710700748}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:19:06,890] Trial 139 finished with value: 0.738496292797291 and parameters: {'n_estimators': 2812, 'num_leaves': 3042, 'learning_rate': 0.28643178710993517, 'min_child_samples': 477, 'reg_alpha': 23.42542719141738, 'reg_lambda': 182.71483073228333}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:19:21,784] Trial 140 finished with value: 0.7392471788578134 and parameters: {'n_estimators': 3552, 'num_leaves': 2553, 'learning_rate': 0.07069964908860688, 'min_child_samples': 447, 'reg_alpha': 40.15587606337489, 'reg_lambda': 174.75681381042665}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:19:30,815] Trial 141 finished with value: 0.7391266016550833 and parameters: {'n_estimators': 3432, 'num_leaves': 2535, 'learning_rate': 0.0699012823865407, 'min_child_samples': 448, 'reg_alpha': 38.388146123400844, 'reg_lambda': 176.22160674937464}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:19:38,923] Trial 142 finished with value: 0.7391898547048413 and parameters: {'n_estimators': 3599, 'num_leaves': 2657, 'learning_rate': 0.08769111303754981, 'min_child_samples': 488, 'reg_alpha': 44.93900309346145, 'reg_lambda': 186.9195570813357}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:19:48,119] Trial 143 finished with value: 0.7391605881502361 and parameters: {'n_estimators': 3505, 'num_leaves': 2338, 'learning_rate': 0.05431818666128772, 'min_child_samples': 460, 'reg_alpha': 50.50839867398526, 'reg_lambda': 195.7130046432463}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:19:56,562] Trial 144 finished with value: 0.7391677886434802 and parameters: {'n_estimators': 3268, 'num_leaves': 2877, 'learning_rate': 0.06536074367043711, 'min_child_samples': 430, 'reg_alpha': 41.05390143603436, 'reg_lambda': 123.43631732538594}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:20:07,216] Trial 145 finished with value: 0.7389771170350069 and parameters: {'n_estimators': 3044, 'num_leaves': 2699, 'learning_rate': 0.04319946020202173, 'min_child_samples': 453, 'reg_alpha': 56.11206830573381, 'reg_lambda': 184.28457536257332}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:20:15,493] Trial 146 finished with value: 0.7391646827325913 and parameters: {'n_estimators': 2965, 'num_leaves': 2003, 'learning_rate': 0.07491640691200653, 'min_child_samples': 474, 'reg_alpha': 31.57835031586904, 'reg_lambda': 172.82812126635648}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:20:25,395] Trial 147 finished with value: 0.7390620394247353 and parameters: {'n_estimators': 3096, 'num_leaves': 2594, 'learning_rate': 0.05653121752444657, 'min_child_samples': 226, 'reg_alpha': 37.19360104299318, 'reg_lambda': 174.5183590949733}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:20:38,043] Trial 148 finished with value: 0.7391341445815279 and parameters: {'n_estimators': 3186, 'num_leaves': 2419, 'learning_rate': 0.034992491461123515, 'min_child_samples': 418, 'reg_alpha': 27.313625792203187, 'reg_lambda': 156.08452189565165}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:20:45,094] Trial 149 finished with value: 0.7390410601711843 and parameters: {'n_estimators': 3307, 'num_leaves': 2274, 'learning_rate': 0.1057256137560196, 'min_child_samples': 443, 'reg_alpha': 47.00348839500457, 'reg_lambda': 165.13454784196992}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:20:54,108] Trial 150 finished with value: 0.7390278670969309 and parameters: {'n_estimators': 3684, 'num_leaves': 2814, 'learning_rate': 0.09519420691913738, 'min_child_samples': 461, 'reg_alpha': 41.777282678420455, 'reg_lambda': 182.38230513961864}. Best is trial 91 with value: 0.7393402277720325.
# ...
# [I 2025-02-24 20:29:53,287] Trial 203 finished with value: 0.739211298540021 and parameters: {'n_estimators': 4464, 'num_leaves': 2611, 'learning_rate': 0.025328093148896176, 'min_child_samples': 469, 'reg_alpha': 41.879333558131805, 'reg_lambda': 15.028251172360013}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:30:04,720] Trial 204 finished with value: 0.7390712788571276 and parameters: {'n_estimators': 4989, 'num_leaves': 2496, 'learning_rate': 0.04938748149802599, 'min_child_samples': 494, 'reg_alpha': 51.834003160887136, 'reg_lambda': 185.97512993627308}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:30:11,862] Trial 205 finished with value: 0.739097752701942 and parameters: {'n_estimators': 2939, 'num_leaves': 2781, 'learning_rate': 0.08726423847051254, 'min_child_samples': 480, 'reg_alpha': 46.23648053268616, 'reg_lambda': 21.94166839354345}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:30:22,062] Trial 206 finished with value: 0.7392164235539888 and parameters: {'n_estimators': 4696, 'num_leaves': 2128, 'learning_rate': 0.0712339003439728, 'min_child_samples': 458, 'reg_alpha': 40.36633248432516, 'reg_lambda': 91.7875635611298}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:30:31,036] Trial 207 finished with value: 0.7391961051547549 and parameters: {'n_estimators': 3083, 'num_leaves': 2877, 'learning_rate': 0.05938417484905247, 'min_child_samples': 470, 'reg_alpha': 36.7729097805802, 'reg_lambda': 196.511729781698}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:30:38,543] Trial 208 finished with value: 0.7390312319207276 and parameters: {'n_estimators': 3188, 'num_leaves': 2341, 'learning_rate': 0.11178168334679879, 'min_child_samples': 499, 'reg_alpha': 43.95263124055271, 'reg_lambda': 190.21017197860556}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:30:46,951] Trial 209 finished with value: 0.7392768609258754 and parameters: {'n_estimators': 2873, 'num_leaves': 2694, 'learning_rate': 0.0372191652371062, 'min_child_samples': 485, 'reg_alpha': 49.23288389146242, 'reg_lambda': 45.77318520781393}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:31:01,399] Trial 210 finished with value: 0.7390319575032714 and parameters: {'n_estimators': 2781, 'num_leaves': 1991, 'learning_rate': 0.012158735738819766, 'min_child_samples': 486, 'reg_alpha': 51.25213885889619, 'reg_lambda': 144.320000075063}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:31:09,945] Trial 211 finished with value: 0.739206005441464 and parameters: {'n_estimators': 2871, 'num_leaves': 2717, 'learning_rate': 0.03683649050349809, 'min_child_samples': 478, 'reg_alpha': 47.47961961492539, 'reg_lambda': 46.72896400967552}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:31:17,980] Trial 212 finished with value: 0.7392367617892923 and parameters: {'n_estimators': 2990, 'num_leaves': 2574, 'learning_rate': 0.04618173640398976, 'min_child_samples': 466, 'reg_alpha': 42.706117885235415, 'reg_lambda': 49.82436340703662}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:31:26,662] Trial 213 finished with value: 0.7391065964569472 and parameters: {'n_estimators': 2888, 'num_leaves': 2573, 'learning_rate': 0.040912343606196055, 'min_child_samples': 464, 'reg_alpha': 54.38387807871944, 'reg_lambda': 50.30104380865122}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:31:36,612] Trial 214 finished with value: 0.7392595492571826 and parameters: {'n_estimators': 3028, 'num_leaves': 2697, 'learning_rate': 0.028238918053088972, 'min_child_samples': 487, 'reg_alpha': 41.02919869494311, 'reg_lambda': 54.816312604880025}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:31:45,819] Trial 215 finished with value: 0.7392312442299483 and parameters: {'n_estimators': 2579, 'num_leaves': 2689, 'learning_rate': 0.030292979353771548, 'min_child_samples': 487, 'reg_alpha': 37.64987466331479, 'reg_lambda': 57.348059188435315}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:32:00,842] Trial 216 finished with value: 0.7391328938651429 and parameters: {'n_estimators': 2524, 'num_leaves': 2794, 'learning_rate': 0.01657591302518148, 'min_child_samples': 485, 'reg_alpha': 32.76839704366818, 'reg_lambda': 54.40600994363688}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:32:10,608] Trial 217 finished with value: 0.739271261934246 and parameters: {'n_estimators': 2636, 'num_leaves': 2653, 'learning_rate': 0.02950468778331279, 'min_child_samples': 475, 'reg_alpha': 37.318291782583955, 'reg_lambda': 63.085863193396385}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:32:27,521] Trial 218 finished with value: 0.7392545787557566 and parameters: {'n_estimators': 2742, 'num_leaves': 2546, 'learning_rate': 0.019820069123674806, 'min_child_samples': 473, 'reg_alpha': 39.61994784864029, 'reg_lambda': 62.095361916446286}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:32:41,065] Trial 219 finished with value: 0.7390848289806329 and parameters: {'n_estimators': 2493, 'num_leaves': 2465, 'learning_rate': 0.01884272410059134, 'min_child_samples': 473, 'reg_alpha': 30.735535299136288, 'reg_lambda': 65.85661667374674}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:32:50,546] Trial 220 finished with value: 0.7381146927554438 and parameters: {'n_estimators': 2701, 'num_leaves': 2896, 'learning_rate': 0.022384444848543864, 'min_child_samples': 477, 'reg_alpha': 92.65502809644414, 'reg_lambda': 60.851465326358486}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:33:00,280] Trial 221 finished with value: 0.7392201130629237 and parameters: {'n_estimators': 2763, 'num_leaves': 2620, 'learning_rate': 0.02899948912618621, 'min_child_samples': 466, 'reg_alpha': 39.62085989147534, 'reg_lambda': 61.90650605533473}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:33:10,035] Trial 222 finished with value: 0.7392341402961017 and parameters: {'n_estimators': 2621, 'num_leaves': 2549, 'learning_rate': 0.03615732120590947, 'min_child_samples': 456, 'reg_alpha': 35.70252238867997, 'reg_lambda': 56.77539435008583}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:33:30,643] Trial 223 finished with value: 0.7392567690754357 and parameters: {'n_estimators': 4815, 'num_leaves': 2653, 'learning_rate': 0.01053745705623959, 'min_child_samples': 471, 'reg_alpha': 42.994162715045945, 'reg_lambda': 52.522134284032234}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:34:10,276] Trial 224 finished with value: 0.7387223561298437 and parameters: {'n_estimators': 4698, 'num_leaves': 2744, 'learning_rate': 0.001443915063273505, 'min_child_samples': 492, 'reg_alpha': 45.213661715345935, 'reg_lambda': 64.03471959179642}. Best is trial 91 with value: 0.7393402277720325.
# [I 2025-02-24 20:34:23,752] Trial 225 finished with value: 0.7393347738969117 and parameters: {'n_estimators': 4945, 'num_leaves': 2655, 'learning_rate': 0.013191163168394728, 'min_child_samples': 479, 'reg_alpha': 39.82472315181771, 'reg_lambda': 68.48812160161256}. Best is trial 91 with value: 0.7393402277720325.
# [W 2025-02-24 20:34:25,171] Trial 226 failed with parameters: {'n_estimators': 4913, 'num_leaves': 2659, 'learning_rate': 0.008721317687286722, 'min_child_samples': 478, 'reg_alpha': 35.540471253359264, 'reg_lambda': 68.12348802905933} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\optuna\study\_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\juneh\AppData\Local\Temp\ipykernel_6376\2579625111.py", line 24, in objective
#     model.fit(IVF_X_train, IVF_y_train)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\lightgbm\sklearn.py", line 1284, in fit
#     super().fit(
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\lightgbm\sklearn.py", line 955, in fit
#     self._Booster = train(
#                     ^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\lightgbm\engine.py", line 307, in train
#     booster.update(fobj=fobj)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\lightgbm\basic.py", line 4136, in update
#     _LIB.LGBM_BoosterUpdateOneIter(
# KeyboardInterrupt
# [W 2025-02-24 20:34:25,286] Trial 226 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 33
#      31 # Optuna 스터디 생성 및 최적화 실행
#      32 study = optuna.create_study(direction='maximize')
# ---> 33 study.optimize(objective, n_trials=800)
#      35 # 최적의 하이퍼파라미터 출력
#      36 print("Best trial:")
#
# File c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\optuna\study\study.py:475, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     373 def optimize(
#     374     self,
#     375     func: ObjectiveFuncType,
#    (...)
#     382     show_progress_bar: bool = False,
#     383 ) -> None:
#     384     """Optimize an objective function.
#     385
#     386     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     473             If nested invocation of this method occurs.
#     474     """
# --> 475     _optimize(
#     476         study=self,
#     477         func=func,
#     478         n_trials=n_trials,
#     479         timeout=timeout,
#     480         n_jobs=n_jobs,
#     481         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     482         callbacks=callbacks,
#     483         gc_after_trial=gc_after_trial,
#     484         show_progress_bar=show_progress_bar,
#     485     )
#
# File c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\optuna\study\_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\optuna\study\_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\optuna\study\_optimize.py:248, in _run_trial(study, func, catch)
#     241         assert False, "Should not reach."
#     243 if (
#     244     frozen_trial.state == TrialState.FAIL
#     245     and func_err is not None
#     246     and not isinstance(func_err, catch)
#     247 ):
# --> 248     raise func_err
#     249 return frozen_trial
#
# File c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\optuna\study\_optimize.py:197, in _run_trial(study, func, catch)
#     195 with get_heartbeat_thread(trial._trial_id, study._storage):
#     196     try:
# --> 197         value_or_values = func(trial)
#     198     except exceptions.TrialPruned as e:
#     199         # TODO(mamu): Handle multi-objective cases.
#     200         state = TrialState.PRUNED
#
# Cell In[8], line 24, in objective(trial)
#       7 param = {
#       8     'n_estimators': trial.suggest_int('n_estimators', 500, 5000),
#       9     'num_leaves': trial.suggest_int('num_leaves', 1000, 5000),
#    (...)
#      20     'verbose': -1
#      21 }
#      23 model = lgb.LGBMClassifier(**param)
# ---> 24 model.fit(IVF_X_train, IVF_y_train)
#      26 y_pred_proba = model.predict_proba(IVF_X_test)[:, 1]
#      28 auc = roc_auc_score(IVF_y_test, y_pred_proba)
#
# File c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\lightgbm\sklearn.py:1284, in LGBMClassifier.fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1281         else:
#    1282             valid_sets.append((valid_x, self._le.transform(valid_y)))
# -> 1284 super().fit(
#    1285     X,
#    1286     _y,
#    1287     sample_weight=sample_weight,
#    1288     init_score=init_score,
#    1289     eval_set=valid_sets,
#    1290     eval_names=eval_names,
#    1291     eval_sample_weight=eval_sample_weight,
#    1292     eval_class_weight=eval_class_weight,
#    1293     eval_init_score=eval_init_score,
#    1294     eval_metric=eval_metric,
#    1295     feature_name=feature_name,
#    1296     categorical_feature=categorical_feature,
#    1297     callbacks=callbacks,
#    1298     init_model=init_model,
#    1299 )
#    1300 return self
#
# File c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\lightgbm\sklearn.py:955, in LGBMModel.fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#     952 evals_result: _EvalResultDict = {}
#     953 callbacks.append(record_evaluation(evals_result))
# --> 955 self._Booster = train(
#     956     params=params,
#     957     train_set=train_set,
#     958     num_boost_round=self.n_estimators,
#     959     valid_sets=valid_sets,
#     960     valid_names=eval_names,
#     961     feval=eval_metrics_callable,  # type: ignore[arg-type]
#     962     init_model=init_model,
#     963     callbacks=callbacks,
#     964 )
#     966 self._evals_result = evals_result
#     967 self._best_iteration = self._Booster.best_iteration
#
# File c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\lightgbm\engine.py:307, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, feature_name, categorical_feature, keep_training_booster, callbacks)
#     295 for cb in callbacks_before_iter:
#     296     cb(
#     297         callback.CallbackEnv(
#     298             model=booster,
#    (...)
#     304         )
#     305     )
# --> 307 booster.update(fobj=fobj)
#     309 evaluation_result_list: List[_LGBM_BoosterEvalMethodResultType] = []
#     310 # check evaluation result.
#
# File c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\lightgbm\basic.py:4136, in Booster.update(self, train_set, fobj)
#    4133 if self.__set_objective_to_none:
#    4134     raise LightGBMError("Cannot update due to null objective function.")
#    4135 _safe_call(
# -> 4136     _LIB.LGBM_BoosterUpdateOneIter(
#    4137         self._handle,
#    4138         ctypes.byref(is_finished),
#    4139     )
#    4140 )
#    4141 self.__is_predicted_cur_iter = [False for _ in range(self.__num_dataset)]
#    4142 return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
# import optuna
# import lightgbm as lgb
# from sklearn.metrics import roc_auc_score

# # 목적 함수 정의
# def objective(trial):
#     param = {
#         'n_estimators': trial.suggest_int('n_estimators', 1000, 8000),
#         'max_depth': trial.suggest_int('max_depth', 3, 300),
#         'learning_rate': trial.suggest_float('learning_rate', 1e-5, 1e-1, log=True),
#         'num_leaves': trial.suggest_int('num_leaves', 2, 2048),
#         'min_child_samples': trial.suggest_int('min_child_samples', 1, 100),
#         'subsample': trial.suggest_float('subsample', 0.6, 1.0),
#         'reg_alpha': trial.suggest_float('reg_alpha', 1e-3, 10.0, log=True),
#         'reg_lambda': trial.suggest_float('reg_lambda', 1e-3, 10.0, log=True),
        
#         'boosting_type' : 'gbdt',
#         'random_state': 42,
#         'objective': 'binary',
#         'metric': 'auc',
#         'verbose': -1,   
#         'njobs': -1
#     }

#     model = lgb.LGBMClassifier(**param)
#     model.fit(IVF_X_train, IVF_y_train)
    
#     y_pred_proba = model.predict_proba(IVF_X_test)[:, 1]
    
#     auc = roc_auc_score(IVF_y_test, y_pred_proba)
#     return auc

# # Optuna 스터디 생성 및 최적화 실행
# study = optuna.create_study(direction='maximize')
# study.optimize(objective, n_trials=800)

# # 최적의 하이퍼파라미터 출력
# print("Best trial:")
# trial = study.best_trial
# print(f"  Value: {trial.value}")
# print("  Params: ")
# for key, value in trial.params.items():
#     print(f"    {key}: {value}")

# %% [markdown]
# .
