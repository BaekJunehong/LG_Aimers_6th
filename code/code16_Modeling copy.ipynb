# %% [markdown]
# ## 난임 환자 대상 임신 성공 여부 예측

# %% [markdown]
# ### LGAimers 6th 온라인 해커톤

# %% [markdown]
# Import

# %%
import pandas as pd
import lightgbm as lgb
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### Data Load

# %%
# 데이터 로드
IVF_train = pd.read_csv('../data/IVF_train_dataset_16.csv')
IVF_test = pd.read_csv('../data/IVF_test_dataset_16.csv')

DI_train = pd.read_csv('../data/DI_train_dataset.csv')
DI_test = pd.read_csv('../data/DI_test_dataset.csv')

# Total_train = pd.read_csv('train_eda_code_14.csv')
# Total_test = pd.read_csv('test_eda_code_14.csv')

# %%
# ID 열을 제외한 특성과 타겟 변수 분리
IVF_X = IVF_train.drop(['임신_성공_여부', 'ID'], axis=1)
IVF_y = IVF_train['임신_성공_여부']

DI_X = DI_train.drop(['임신_성공_여부', 'ID'], axis=1)
DI_y = DI_train['임신_성공_여부']

# Total_X = Total_train.drop(['임신_성공_여부', 'ID'], axis=1)
# Total_y = Total_train['임신_성공_여부']

# %% [markdown]
# ### 인코딩

# %%
IVF_categorical_columns = [
    "시술_시기_코드",
    "시술_당시_나이",
    "임신_시도_또는_마지막_임신_경과_연수",
    "배란_유도_유형",
    "난자_출처",
    "정자_출처",
    "난자_기증자_나이",
    "정자_기증자_나이",
    "난자_채취_경과일",
    "난자_해동_경과일",
    "난자_혼합_경과일",
    "배아_이식_경과일",
    "배아_해동_경과일",
    "변환된_특정_시술_유형"
]

# %%
DI_categorical_columns = [
    "시술_시기_코드",
    "시술_당시_나이",
    "임신_시도_또는_마지막_임신_경과_연수",
    "정자_기증자_나이",
    "변환된_특정_시술_유형"
]

# %%
# 모든 범주형 변수를 문자열로 변환
IVF_X[IVF_categorical_columns] = IVF_X[IVF_categorical_columns].astype(str)
DI_X[DI_categorical_columns] = DI_X[DI_categorical_columns].astype(str)
IVF_test[IVF_categorical_columns] = IVF_test[IVF_categorical_columns].astype(str)
DI_test[DI_categorical_columns] = DI_test[DI_categorical_columns].astype(str)
# Total_X[Total_categorical_columns] = Total_X[Total_categorical_columns].astype(str)
# Total_test[Total_categorical_columns] = Total_test[Total_categorical_columns].astype(str)

# OrdinalEncoder를 사용하여 범주형 변수 인코딩
IVF_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
DI_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
# Total_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

IVF_X[IVF_categorical_columns] = IVF_encoder.fit_transform(IVF_X[IVF_categorical_columns])
DI_X[DI_categorical_columns] = DI_encoder.fit_transform(DI_X[DI_categorical_columns])
IVF_test[IVF_categorical_columns] = IVF_encoder.transform(IVF_test[IVF_categorical_columns])
DI_test[DI_categorical_columns] = DI_encoder.transform(DI_test[DI_categorical_columns])
# Total_X[Total_categorical_columns] = Total_encoder.fit_transform(Total_X[Total_categorical_columns])
# Total_test[Total_categorical_columns] = Total_encoder.transform(Total_test[Total_categorical_columns])

# %%
# import category_encoders as ce

# # 모든 범주형 변수를 문자열로 변환
# IVF_X[IVF_categorical_columns] = IVF_X[IVF_categorical_columns].astype(str)
# DI_X[DI_categorical_columns] = DI_X[DI_categorical_columns].astype(str)
# IVF_test[IVF_categorical_columns] = IVF_test[IVF_categorical_columns].astype(str)
# DI_test[DI_categorical_columns] = DI_test[DI_categorical_columns].astype(str)

# # 타겟 인코더를 사용하여 범주형 변수 인코딩
# IVF_target_encoder = ce.TargetEncoder(cols=IVF_categorical_columns)
# DI_target_encoder = ce.TargetEncoder(cols=DI_categorical_columns)

# # 타겟 인코딩을 위해 타겟 변수가 필요합니다. 예시로 IVF_y와 DI_y를 사용합니다.
# IVF_X[IVF_categorical_columns] = IVF_target_encoder.fit_transform(IVF_X[IVF_categorical_columns], IVF_y)
# DI_X[DI_categorical_columns] = DI_target_encoder.fit_transform(DI_X[DI_categorical_columns], DI_y)
# IVF_test[IVF_categorical_columns] = IVF_target_encoder.transform(IVF_test[IVF_categorical_columns])
# DI_test[DI_categorical_columns] = DI_target_encoder.transform(DI_test[DI_categorical_columns])

# %% [markdown]
# ## Modeling

# %%
# 데이터 분할
IVF_X_train, IVF_X_test, IVF_y_train, IVF_y_test = train_test_split(IVF_X, IVF_y, test_size=0.2, random_state=42)
DI_X_train, DI_X_test, DI_y_train, DI_y_test = train_test_split(DI_X, DI_y, test_size=0.2, random_state=42)
# Total_X_train, Total_X_test, Total_y_train, Total_y_test = train_test_split(Total_X, Total_y, test_size=0.2, random_state=42)

# %%
import optuna
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# 목적 함수 정의
def objective(trial):
    param = {
        'iterations': trial.suggest_int('iterations', 100, 3000),
        'depth': trial.suggest_int('depth', 4, 10),  # 일반적으로 4~10
        'learning_rate': trial.suggest_float('learning_rate', 1e-5, 0.3, log=True),  # 0.3까지
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1e-5, 10.0, log=True),  # L2 정규화
        'bagging_temperature': trial.suggest_float('bagging_temperature', 0.0, 1.0),
        'random_strength': trial.suggest_float('random_strength', 1.0, 10.0),  # 일반적으로 1~10
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1.0, 10.0),  # 클래스 불균형 조정
        'border_count': trial.suggest_int('border_count', 1, 255),  # 경계 수
        'eval_metric': 'AUC',
        'random_seed': 42,
        'logging_level': 'Silent'
    }

    model = CatBoostClassifier(**param)
    model.fit(IVF_X_train, IVF_y_train, eval_set=[(IVF_X_test, IVF_y_test)], verbose=False)
    
    y_pred_proba = model.predict_proba(IVF_X_test)[:, 1]
    auc = roc_auc_score(IVF_y_test, y_pred_proba)
    
    return auc

# Optuna 스터디 생성 및 최적화
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=800)

# 최적의 하이퍼파라미터 출력
print("Best trial:")
trial = study.best_trial
print("  Value: {}".format(trial.value))
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))

# 최적의 하이퍼파라미터로 모델 학습
best_params = trial.params
IVF_model = CatBoostClassifier(**best_params)
IVF_model.fit(IVF_X_train, IVF_y_train)

# 예측
y_pred = IVF_model.predict(IVF_X_test)
y_pred_proba = IVF_model.predict_proba(IVF_X_test)[:, 1]

# 평가
accuracy = accuracy_score(IVF_y_test, y_pred)
f1 = f1_score(IVF_y_test, y_pred)
auc = roc_auc_score(IVF_y_test, y_pred_proba)
cm = confusion_matrix(IVF_y_test, y_pred)

# 결과 출력
print()
print("--- Model Performance ---")
print(f"Model Accuracy: {accuracy}")
print(f"Model F1 Score: {f1}")
print(f"Model AUC: {auc}")

# 혼동 행렬 출력
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=IVF_model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# [I 2025-02-04 11:03:58,163] A new study created in memory with name: no-name-c61db470-8377-4158-b842-4b6b98abf5b2
# [I 2025-02-04 11:06:11,962] Trial 0 finished with value: 0.7373700112086738 and parameters: {'iterations': 2052, 'depth': 9, 'learning_rate': 0.025897770233892888, 'l2_leaf_reg': 0.0006992433232489245, 'bagging_temperature': 0.8853982580807832, 'random_strength': 2.4417263011863253, 'scale_pos_weight': 8.543540776688435, 'border_count': 95}. Best is trial 0 with value: 0.7373700112086738.
# [I 2025-02-04 11:10:17,520] Trial 1 finished with value: 0.7385600855969414 and parameters: {'iterations': 2508, 'depth': 8, 'learning_rate': 0.004202534394505805, 'l2_leaf_reg': 0.0069163056042262855, 'bagging_temperature': 0.5341806475842303, 'random_strength': 1.448000333156041, 'scale_pos_weight': 6.616481695245056, 'border_count': 153}. Best is trial 1 with value: 0.7385600855969414.
# [I 2025-02-04 11:13:36,845] Trial 2 finished with value: 0.7247748065312969 and parameters: {'iterations': 1802, 'depth': 9, 'learning_rate': 6.517532496907014e-05, 'l2_leaf_reg': 4.427912798605182, 'bagging_temperature': 0.9908522511791563, 'random_strength': 5.6466145453716, 'scale_pos_weight': 1.576584947932638, 'border_count': 77}. Best is trial 1 with value: 0.7385600855969414.
# [I 2025-02-04 11:15:47,131] Trial 3 finished with value: 0.7330724244298159 and parameters: {'iterations': 1442, 'depth': 7, 'learning_rate': 0.0036455192927712927, 'l2_leaf_reg': 0.0007515649503262938, 'bagging_temperature': 0.25847934985348753, 'random_strength': 9.339983048760976, 'scale_pos_weight': 3.217541951629676, 'border_count': 56}. Best is trial 1 with value: 0.7385600855969414.
# [I 2025-02-04 11:17:19,820] Trial 4 finished with value: 0.7235018319883908 and parameters: {'iterations': 1077, 'depth': 7, 'learning_rate': 3.8127790477832485e-05, 'l2_leaf_reg': 0.015455000989564456, 'bagging_temperature': 0.47569927638818965, 'random_strength': 3.501207911005222, 'scale_pos_weight': 4.048438115009619, 'border_count': 24}. Best is trial 1 with value: 0.7385600855969414.
# [I 2025-02-04 11:23:01,849] Trial 5 finished with value: 0.7306768327511399 and parameters: {'iterations': 2974, 'depth': 9, 'learning_rate': 0.0009001618019178152, 'l2_leaf_reg': 0.050276269199951734, 'bagging_temperature': 0.0036431345809032623, 'random_strength': 4.956429681572809, 'scale_pos_weight': 7.879057098782963, 'border_count': 146}. Best is trial 1 with value: 0.7385600855969414.
# [I 2025-02-04 11:26:34,357] Trial 6 finished with value: 0.7386730687170475 and parameters: {'iterations': 2466, 'depth': 7, 'learning_rate': 0.035846957380700685, 'l2_leaf_reg': 0.2001953456293015, 'bagging_temperature': 0.9238914159339727, 'random_strength': 6.956423260007514, 'scale_pos_weight': 7.237256568891103, 'border_count': 47}. Best is trial 6 with value: 0.7386730687170475.
# [I 2025-02-04 11:29:34,475] Trial 7 finished with value: 0.715063123259223 and parameters: {'iterations': 1954, 'depth': 8, 'learning_rate': 0.00010837030066774433, 'l2_leaf_reg': 0.12690607839982457, 'bagging_temperature': 0.2214310555143032, 'random_strength': 6.637280023346334, 'scale_pos_weight': 6.969302493971833, 'border_count': 136}. Best is trial 6 with value: 0.7386730687170475.
# [I 2025-02-04 11:30:02,838] Trial 8 finished with value: 0.7187701255195578 and parameters: {'iterations': 445, 'depth': 4, 'learning_rate': 0.0002686282157646681, 'l2_leaf_reg': 0.006805769036982549, 'bagging_temperature': 0.266178528829931, 'random_strength': 9.127261028386513, 'scale_pos_weight': 1.974410018831378, 'border_count': 103}. Best is trial 6 with value: 0.7386730687170475.
# [I 2025-02-04 11:30:57,850] Trial 9 finished with value: 0.7149575066289431 and parameters: {'iterations': 602, 'depth': 8, 'learning_rate': 0.0005649800120008324, 'l2_leaf_reg': 1.3705476388686053, 'bagging_temperature': 0.23642578613803455, 'random_strength': 6.87207051585217, 'scale_pos_weight': 7.381931584431858, 'border_count': 58}. Best is trial 6 with value: 0.7386730687170475.
# [I 2025-02-04 11:34:19,691] Trial 10 finished with value: 0.737957935605871 and parameters: {'iterations': 3000, 'depth': 5, 'learning_rate': 0.15994274635680789, 'l2_leaf_reg': 2.317441659615444e-05, 'bagging_temperature': 0.7654236609805244, 'random_strength': 8.134155469457648, 'scale_pos_weight': 9.92715856715247, 'border_count': 233}. Best is trial 6 with value: 0.7386730687170475.
# [I 2025-02-04 11:37:33,346] Trial 11 finished with value: 0.7399458083591302 and parameters: {'iterations': 2418, 'depth': 6, 'learning_rate': 0.00877482972441737, 'l2_leaf_reg': 0.31960777473489266, 'bagging_temperature': 0.6685591075749021, 'random_strength': 1.0170672388935993, 'scale_pos_weight': 5.986662049872015, 'border_count': 191}. Best is trial 11 with value: 0.7399458083591302.
# [I 2025-02-04 11:40:55,112] Trial 12 finished with value: 0.7398836901413507 and parameters: {'iterations': 2479, 'depth': 6, 'learning_rate': 0.03498788890912183, 'l2_leaf_reg': 0.45160450585111367, 'bagging_temperature': 0.7047080198211146, 'random_strength': 4.030575195305696, 'scale_pos_weight': 4.9974535587598865, 'border_count': 209}. Best is trial 11 with value: 0.7399458083591302.
# [I 2025-02-04 11:43:59,602] Trial 13 finished with value: 0.7399441191612081 and parameters: {'iterations': 2458, 'depth': 5, 'learning_rate': 0.01597932273536678, 'l2_leaf_reg': 0.837953232677099, 'bagging_temperature': 0.6704987495994572, 'random_strength': 3.7519258813306924, 'scale_pos_weight': 5.07203454458473, 'border_count': 226}. Best is trial 11 with value: 0.7399458083591302.
# [I 2025-02-04 11:47:04,715] Trial 14 finished with value: 0.7397792438391736 and parameters: {'iterations': 2280, 'depth': 5, 'learning_rate': 0.008579522850325733, 'l2_leaf_reg': 6.4665978581437695, 'bagging_temperature': 0.5993677205499324, 'random_strength': 1.3616595081500646, 'scale_pos_weight': 5.280883927119616, 'border_count': 191}. Best is trial 11 with value: 0.7399458083591302.
# [I 2025-02-04 11:48:48,825] Trial 15 finished with value: 0.7389278807783901 and parameters: {'iterations': 1415, 'depth': 4, 'learning_rate': 0.22024432311094683, 'l2_leaf_reg': 1.1515321287644453, 'bagging_temperature': 0.7026526415625177, 'random_strength': 3.0033402316318676, 'scale_pos_weight': 3.7780654161597496, 'border_count': 184}. Best is trial 11 with value: 0.7399458083591302.
# [I 2025-02-04 11:53:07,573] Trial 16 finished with value: 0.7219982339049442 and parameters: {'iterations': 2753, 'depth': 6, 'learning_rate': 1.1147448722152861e-05, 'l2_leaf_reg': 0.06940794926366765, 'bagging_temperature': 0.4452298134389233, 'random_strength': 2.310438817845456, 'scale_pos_weight': 6.017070369827879, 'border_count': 242}. Best is trial 11 with value: 0.7399458083591302.
# [I 2025-02-04 11:55:13,323] Trial 17 finished with value: 0.7387588075176381 and parameters: {'iterations': 1708, 'depth': 5, 'learning_rate': 0.009950150678545292, 'l2_leaf_reg': 0.7715192736098011, 'bagging_temperature': 0.8116363948640011, 'random_strength': 4.613203524679801, 'scale_pos_weight': 4.765147910978515, 'border_count': 252}. Best is trial 11 with value: 0.7399458083591302.
# [I 2025-02-04 11:56:37,831] Trial 18 finished with value: 0.7399180817099237 and parameters: {'iterations': 1037, 'depth': 6, 'learning_rate': 0.07304674772170608, 'l2_leaf_reg': 6.705104598766549, 'bagging_temperature': 0.6368138656722291, 'random_strength': 1.1150901872050505, 'scale_pos_weight': 5.691749158061764, 'border_count': 172}. Best is trial 11 with value: 0.7399458083591302.
# [I 2025-02-04 12:04:58,940] Trial 19 finished with value: 0.7373979905067662 and parameters: {'iterations': 2202, 'depth': 10, 'learning_rate': 0.0022146552001828745, 'l2_leaf_reg': 0.0015165565844269355, 'bagging_temperature': 0.37954372619885535, 'random_strength': 2.3371189989930325, 'scale_pos_weight': 2.516846321404776, 'border_count': 214}. Best is trial 11 with value: 0.7399458083591302.
# [I 2025-02-04 12:08:25,923] Trial 20 finished with value: 0.7395570840363062 and parameters: {'iterations': 2688, 'depth': 5, 'learning_rate': 0.01142165207124948, 'l2_leaf_reg': 7.376284182215718e-05, 'bagging_temperature': 0.5531419981474512, 'random_strength': 5.604821584498117, 'scale_pos_weight': 4.096803143920342, 'border_count': 219}. Best is trial 11 with value: 0.7399458083591302.
# [I 2025-02-04 12:09:48,612] Trial 21 finished with value: 0.7400414370063935 and parameters: {'iterations': 958, 'depth': 6, 'learning_rate': 0.07714377781419703, 'l2_leaf_reg': 3.8332508595997328, 'bagging_temperature': 0.6098046352036417, 'random_strength': 1.5119158182293768, 'scale_pos_weight': 5.954203668798619, 'border_count': 172}. Best is trial 21 with value: 0.7400414370063935.
# [I 2025-02-04 12:09:58,745] Trial 22 finished with value: 0.7371745267433272 and parameters: {'iterations': 128, 'depth': 6, 'learning_rate': 0.06355627734442673, 'l2_leaf_reg': 2.4425013948547076, 'bagging_temperature': 0.671353694198685, 'random_strength': 1.9695650098253508, 'scale_pos_weight': 6.2096355634406475, 'border_count': 169}. Best is trial 21 with value: 0.7400414370063935.
# [I 2025-02-04 12:11:05,238] Trial 23 finished with value: 0.7385789350830255 and parameters: {'iterations': 1058, 'depth': 4, 'learning_rate': 0.017831198041504112, 'l2_leaf_reg': 0.35240463953527285, 'bagging_temperature': 0.791050762522236, 'random_strength': 3.281331421535963, 'scale_pos_weight': 8.269546058591073, 'border_count': 197}. Best is trial 21 with value: 0.7400414370063935.
# [I 2025-02-04 12:11:46,990] Trial 24 finished with value: 0.739027215638647 and parameters: {'iterations': 528, 'depth': 6, 'learning_rate': 0.10228835081392229, 'l2_leaf_reg': 0.026233246538133116, 'bagging_temperature': 0.40813447527879143, 'random_strength': 4.0079732187023085, 'scale_pos_weight': 4.821983925473365, 'border_count': 116}. Best is trial 21 with value: 0.7400414370063935.
# [I 2025-02-04 12:12:46,340] Trial 25 finished with value: 0.7358325853186309 and parameters: {'iterations': 825, 'depth': 5, 'learning_rate': 0.005717362375922534, 'l2_leaf_reg': 9.18769472981174, 'bagging_temperature': 0.58653066844273, 'random_strength': 1.0360931351578753, 'scale_pos_weight': 6.3417856474467245, 'border_count': 229}. Best is trial 21 with value: 0.7400414370063935.
# [I 2025-02-04 12:14:23,964] Trial 26 finished with value: 0.7301492183573829 and parameters: {'iterations': 1256, 'depth': 6, 'learning_rate': 0.0015318941786396424, 'l2_leaf_reg': 1.8606062329582271, 'bagging_temperature': 0.747302562308065, 'random_strength': 2.778814644706589, 'scale_pos_weight': 5.5161341468814635, 'border_count': 164}. Best is trial 21 with value: 0.7400414370063935.
# [I 2025-02-04 12:16:37,494] Trial 27 finished with value: 0.7377922971171609 and parameters: {'iterations': 1598, 'depth': 7, 'learning_rate': 0.2818272912188522, 'l2_leaf_reg': 0.2494309726001258, 'bagging_temperature': 0.8700518886720161, 'random_strength': 1.9645764926399727, 'scale_pos_weight': 9.145310964094556, 'border_count': 201}. Best is trial 21 with value: 0.7400414370063935.
# [I 2025-02-04 12:18:51,161] Trial 28 finished with value: 0.7402430111450898 and parameters: {'iterations': 1967, 'depth': 5, 'learning_rate': 0.0521046237790756, 'l2_leaf_reg': 0.792636642411224, 'bagging_temperature': 0.6370251940764404, 'random_strength': 1.783992346967984, 'scale_pos_weight': 3.3424400067385553, 'border_count': 181}. Best is trial 28 with value: 0.7402430111450898.
# [I 2025-02-04 12:20:59,086] Trial 29 finished with value: 0.7401533333186894 and parameters: {'iterations': 2068, 'depth': 4, 'learning_rate': 0.04704192042603802, 'l2_leaf_reg': 3.26177980008773, 'bagging_temperature': 0.37071721675134334, 'random_strength': 1.8356378807222131, 'scale_pos_weight': 2.7907387957746965, 'border_count': 131}. Best is trial 28 with value: 0.7402430111450898.
# [I 2025-02-04 12:22:51,617] Trial 30 finished with value: 0.7401431260949041 and parameters: {'iterations': 1866, 'depth': 4, 'learning_rate': 0.04168315162325006, 'l2_leaf_reg': 3.3817554863674193, 'bagging_temperature': 0.32359031540940775, 'random_strength': 1.9634023976765935, 'scale_pos_weight': 2.934353297139727, 'border_count': 115}. Best is trial 28 with value: 0.7402430111450898.
# [I 2025-02-04 12:24:49,919] Trial 31 finished with value: 0.7402431312055108 and parameters: {'iterations': 1971, 'depth': 4, 'learning_rate': 0.03872471316004019, 'l2_leaf_reg': 3.070777448263026, 'bagging_temperature': 0.33136126073597005, 'random_strength': 1.7318114347101865, 'scale_pos_weight': 2.7752275915645725, 'border_count': 115}. Best is trial 31 with value: 0.7402431312055108.
# [I 2025-02-04 12:26:46,201] Trial 32 finished with value: 0.7402657693808776 and parameters: {'iterations': 1966, 'depth': 4, 'learning_rate': 0.03018066608577502, 'l2_leaf_reg': 2.411118941565078, 'bagging_temperature': 0.3265736026402542, 'random_strength': 2.6656650976581346, 'scale_pos_weight': 2.7754890127031535, 'border_count': 122}. Best is trial 32 with value: 0.7402657693808776.
# [I 2025-02-04 12:28:52,344] Trial 33 finished with value: 0.7397891660499598 and parameters: {'iterations': 2065, 'depth': 4, 'learning_rate': 0.01813617967432597, 'l2_leaf_reg': 0.7316589723508313, 'bagging_temperature': 0.1569958745843097, 'random_strength': 2.7799583848360867, 'scale_pos_weight': 1.0837941511467575, 'border_count': 85}. Best is trial 32 with value: 0.7402657693808776.
# [I 2025-02-04 12:30:59,844] Trial 34 finished with value: 0.7398924660361179 and parameters: {'iterations': 2086, 'depth': 4, 'learning_rate': 0.14084532000013245, 'l2_leaf_reg': 9.490539286488353, 'bagging_temperature': 0.3589720261452837, 'random_strength': 2.575301308394346, 'scale_pos_weight': 2.2707513779071657, 'border_count': 125}. Best is trial 32 with value: 0.7402657693808776.
# [I 2025-02-04 12:32:44,394] Trial 35 finished with value: 0.7401207499644559 and parameters: {'iterations': 1715, 'depth': 4, 'learning_rate': 0.02930449297257554, 'l2_leaf_reg': 2.379332090119395, 'bagging_temperature': 0.502483503257591, 'random_strength': 1.7173668930989123, 'scale_pos_weight': 3.3618399632629616, 'border_count': 96}. Best is trial 32 with value: 0.7402657693808776.
# [I 2025-02-04 12:34:55,338] Trial 36 finished with value: 0.7358122376872944 and parameters: {'iterations': 2221, 'depth': 4, 'learning_rate': 0.003988380627697124, 'l2_leaf_reg': 0.06773174157619671, 'bagging_temperature': 0.14257824082603623, 'random_strength': 3.4236729103228996, 'scale_pos_weight': 1.576121008596719, 'border_count': 147}. Best is trial 32 with value: 0.7402657693808776.
# [I 2025-02-04 12:37:05,405] Trial 37 finished with value: 0.7400022284049326 and parameters: {'iterations': 1914, 'depth': 5, 'learning_rate': 0.05644625218041283, 'l2_leaf_reg': 3.1385743302246936, 'bagging_temperature': 0.31501265633293024, 'random_strength': 4.363258936811361, 'scale_pos_weight': 3.003623355069812, 'border_count': 81}. Best is trial 32 with value: 0.7402657693808776.
# [I 2025-02-04 12:38:27,949] Trial 38 finished with value: 0.7397729547611249 and parameters: {'iterations': 1352, 'depth': 4, 'learning_rate': 0.02495892352249185, 'l2_leaf_reg': 0.53961749557888, 'bagging_temperature': 0.43570741730387963, 'random_strength': 6.171768517270975, 'scale_pos_weight': 4.299325466715448, 'border_count': 130}. Best is trial 32 with value: 0.7402657693808776.
# [I 2025-02-04 12:40:11,722] Trial 39 finished with value: 0.7392127580571379 and parameters: {'iterations': 1540, 'depth': 5, 'learning_rate': 0.13955155271118752, 'l2_leaf_reg': 0.1881218209844262, 'bagging_temperature': 0.14950500345967158, 'random_strength': 4.970020794500563, 'scale_pos_weight': 3.5998423719972124, 'border_count': 156}. Best is trial 32 with value: 0.7402657693808776.
# [I 2025-02-04 12:42:11,282] Trial 40 finished with value: 0.7344266349855265 and parameters: {'iterations': 2011, 'depth': 4, 'learning_rate': 0.002319054504733138, 'l2_leaf_reg': 0.004423087901580355, 'bagging_temperature': 0.5046506004349944, 'random_strength': 2.2452082402476368, 'scale_pos_weight': 2.6621556510046807, 'border_count': 15}. Best is trial 32 with value: 0.7402657693808776.
# [I 2025-02-04 12:44:02,853] Trial 41 finished with value: 0.7403061806745552 and parameters: {'iterations': 1858, 'depth': 4, 'learning_rate': 0.04318875055653522, 'l2_leaf_reg': 2.606046153857667, 'bagging_temperature': 0.31974491554583045, 'random_strength': 1.7716186910674439, 'scale_pos_weight': 2.975960036183962, 'border_count': 110}. Best is trial 41 with value: 0.7403061806745552.
# [I 2025-02-04 12:45:51,160] Trial 42 finished with value: 0.7399086731489383 and parameters: {'iterations': 1803, 'depth': 4, 'learning_rate': 0.04691519501166161, 'l2_leaf_reg': 1.1890848520546256, 'bagging_temperature': 0.29345109862903085, 'random_strength': 1.6674654872474777, 'scale_pos_weight': 1.9217261351430228, 'border_count': 104}. Best is trial 41 with value: 0.7403061806745552.
# [I 2025-02-04 12:48:10,891] Trial 43 finished with value: 0.7399237997179703 and parameters: {'iterations': 2311, 'depth': 4, 'learning_rate': 0.09953752346169317, 'l2_leaf_reg': 1.6601073656243408, 'bagging_temperature': 0.21967355745661693, 'random_strength': 3.0498259617290717, 'scale_pos_weight': 1.3348256701886072, 'border_count': 63}. Best is trial 41 with value: 0.7403061806745552.
# [I 2025-02-04 12:50:34,528] Trial 44 finished with value: 0.7400123166123007 and parameters: {'iterations': 2140, 'depth': 5, 'learning_rate': 0.02435784716078545, 'l2_leaf_reg': 5.004091038323568, 'bagging_temperature': 0.046199265320218896, 'random_strength': 1.5035133870144721, 'scale_pos_weight': 2.0410965128422855, 'border_count': 137}. Best is trial 41 with value: 0.7403061806745552.
# [I 2025-02-04 12:52:09,706] Trial 45 finished with value: 0.7392296364643118 and parameters: {'iterations': 1605, 'depth': 4, 'learning_rate': 0.19714154151097765, 'l2_leaf_reg': 0.12138920559659648, 'bagging_temperature': 0.36308404343122275, 'random_strength': 7.631114557961149, 'scale_pos_weight': 3.345612409067242, 'border_count': 115}. Best is trial 41 with value: 0.7403061806745552.
# [I 2025-02-04 12:54:23,089] Trial 46 finished with value: 0.7401357241089536 and parameters: {'iterations': 1995, 'depth': 5, 'learning_rate': 0.04259120350094191, 'l2_leaf_reg': 4.633691754990217, 'bagging_temperature': 0.19545970330383577, 'random_strength': 2.073646154083091, 'scale_pos_weight': 2.7103044505060048, 'border_count': 44}. Best is trial 41 with value: 0.7403061806745552.
# [I 2025-02-04 12:56:56,679] Trial 47 finished with value: 0.7387514420718156 and parameters: {'iterations': 2620, 'depth': 4, 'learning_rate': 0.006600531019513107, 'l2_leaf_reg': 0.00016117315539986745, 'bagging_temperature': 0.44359722418703745, 'random_strength': 2.683914645553675, 'scale_pos_weight': 4.368571045406031, 'border_count': 141}. Best is trial 41 with value: 0.7403061806745552.
# [I 2025-02-04 12:59:40,833] Trial 48 finished with value: 0.7400939190703898 and parameters: {'iterations': 2351, 'depth': 5, 'learning_rate': 0.013979691193216135, 'l2_leaf_reg': 1.43881821834677, 'bagging_temperature': 0.2741492902472613, 'random_strength': 1.4344998410254401, 'scale_pos_weight': 2.2888914303256067, 'border_count': 71}. Best is trial 41 with value: 0.7403061806745552.
# [I 2025-02-04 13:01:33,739] Trial 49 finished with value: 0.7251068863475316 and parameters: {'iterations': 1739, 'depth': 4, 'learning_rate': 0.00046283272726902017, 'l2_leaf_reg': 0.5195518467583351, 'bagging_temperature': 0.3385283494299554, 'random_strength': 3.1246065865275114, 'scale_pos_weight': 3.912380625970739, 'border_count': 92}. Best is trial 41 with value: 0.7403061806745552.
# [I 2025-02-04 13:03:44,573] Trial 50 finished with value: 0.7389416543186786 and parameters: {'iterations': 1881, 'depth': 5, 'learning_rate': 0.10809413185861003, 'l2_leaf_reg': 0.025562884563703592, 'bagging_temperature': 0.39247240507264375, 'random_strength': 3.727567908579397, 'scale_pos_weight': 3.04317736116924, 'border_count': 127}. Best is trial 41 with value: 0.7403061806745552.
# [I 2025-02-04 13:05:40,579] Trial 51 finished with value: 0.7399156585774285 and parameters: {'iterations': 1842, 'depth': 4, 'learning_rate': 0.038531860699873445, 'l2_leaf_reg': 3.0478339598785547, 'bagging_temperature': 0.24797491984973444, 'random_strength': 1.8956904011698494, 'scale_pos_weight': 2.896327877869769, 'border_count': 113}. Best is trial 41 with value: 0.7403061806745552.
# [I 2025-02-04 13:07:55,523] Trial 52 finished with value: 0.740107736458832 and parameters: {'iterations': 1980, 'depth': 4, 'learning_rate': 0.024950320480726002, 'l2_leaf_reg': 0.988868016647732, 'bagging_temperature': 0.3126789781656335, 'random_strength': 2.3260291686993213, 'scale_pos_weight': 3.413508287058285, 'border_count': 111}. Best is trial 41 with value: 0.7403061806745552.
# [I 2025-02-04 13:10:11,786] Trial 53 finished with value: 0.7398664202328042 and parameters: {'iterations': 2127, 'depth': 4, 'learning_rate': 0.054192062645914744, 'l2_leaf_reg': 5.335073925403037, 'bagging_temperature': 0.33178763039649317, 'random_strength': 1.2846073712682586, 'scale_pos_weight': 1.7676494703555614, 'border_count': 100}. Best is trial 41 with value: 0.7403061806745552.
# [I 2025-02-04 13:13:22,660] Trial 54 finished with value: 0.7388993711264384 and parameters: {'iterations': 1634, 'depth': 9, 'learning_rate': 0.07960442165065214, 'l2_leaf_reg': 2.0609009954065964, 'bagging_temperature': 0.19329870110558361, 'random_strength': 1.7713095600130322, 'scale_pos_weight': 2.3949736320142057, 'border_count': 151}. Best is trial 41 with value: 0.7403061806745552.
# [I 2025-02-04 13:14:56,689] Trial 55 finished with value: 0.7399906952964987 and parameters: {'iterations': 1468, 'depth': 4, 'learning_rate': 0.03279722216561079, 'l2_leaf_reg': 8.618536014574754, 'bagging_temperature': 0.4802736499710426, 'random_strength': 9.65435245062742, 'scale_pos_weight': 3.670699416479531, 'border_count': 123}. Best is trial 41 with value: 0.7403061806745552.
# [I 2025-02-04 13:17:11,441] Trial 56 finished with value: 0.7401737310622016 and parameters: {'iterations': 1897, 'depth': 5, 'learning_rate': 0.01866835132846914, 'l2_leaf_reg': 2.808230190338921, 'bagging_temperature': 0.5384069929139408, 'random_strength': 2.421920429838357, 'scale_pos_weight': 3.003349554420082, 'border_count': 158}. Best is trial 41 with value: 0.7403061806745552.
# [I 2025-02-04 13:20:50,525] Trial 57 finished with value: 0.7264208411661099 and parameters: {'iterations': 2566, 'depth': 7, 'learning_rate': 0.0001157049059393429, 'l2_leaf_reg': 0.6669090643350192, 'bagging_temperature': 0.5511873608625636, 'random_strength': 2.5845365541647523, 'scale_pos_weight': 4.425663781777089, 'border_count': 183}. Best is trial 41 with value: 0.7403061806745552.
# [I 2025-02-04 13:23:29,139] Trial 58 finished with value: 0.7402230122109759 and parameters: {'iterations': 2380, 'depth': 5, 'learning_rate': 0.017454225177906336, 'l2_leaf_reg': 0.1295109079641408, 'bagging_temperature': 0.41776815530393874, 'random_strength': 1.0314469985803307, 'scale_pos_weight': 1.5349136329413693, 'border_count': 155}. Best is trial 41 with value: 0.7403061806745552.
# [I 2025-02-04 13:26:38,710] Trial 59 finished with value: 0.7403462056868783 and parameters: {'iterations': 2883, 'depth': 5, 'learning_rate': 0.013477017585612414, 'l2_leaf_reg': 0.15172526494967195, 'bagging_temperature': 0.42429802350293805, 'random_strength': 1.124104372710776, 'scale_pos_weight': 2.3019174207631323, 'border_count': 160}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 13:36:29,918] Trial 60 finished with value: 0.7387975170853496 and parameters: {'iterations': 2881, 'depth': 10, 'learning_rate': 0.005458203776705045, 'l2_leaf_reg': 0.149848355839366, 'bagging_temperature': 0.4388529715791232, 'random_strength': 1.0109324155693897, 'scale_pos_weight': 1.4574624653533121, 'border_count': 182}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 13:39:56,024] Trial 61 finished with value: 0.7400980261807888 and parameters: {'iterations': 2793, 'depth': 5, 'learning_rate': 0.01261692061119764, 'l2_leaf_reg': 0.09145987157698275, 'bagging_temperature': 0.5229118394920647, 'random_strength': 1.2293140939279419, 'scale_pos_weight': 2.035057519308992, 'border_count': 165}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 13:42:55,653] Trial 62 finished with value: 0.7400164164146741 and parameters: {'iterations': 2386, 'depth': 5, 'learning_rate': 0.01895084778167033, 'l2_leaf_reg': 0.042603533579732296, 'bagging_temperature': 0.411600885041081, 'random_strength': 1.4975746482061782, 'scale_pos_weight': 2.4596039681585338, 'border_count': 159}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 13:45:40,688] Trial 63 finished with value: 0.7395739352993849 and parameters: {'iterations': 2201, 'depth': 5, 'learning_rate': 0.008244583426388294, 'l2_leaf_reg': 1.0171288824862805, 'bagging_temperature': 0.5792020415859662, 'random_strength': 2.288845163150916, 'scale_pos_weight': 1.7465242522503899, 'border_count': 142}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 13:49:38,735] Trial 64 finished with value: 0.7400918373270913 and parameters: {'iterations': 2884, 'depth': 6, 'learning_rate': 0.00962512905665993, 'l2_leaf_reg': 0.2402855997289236, 'bagging_temperature': 0.4701200326138538, 'random_strength': 1.309930993471473, 'scale_pos_weight': 3.1760141119785708, 'border_count': 177}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 13:52:11,367] Trial 65 finished with value: 0.7399309939471925 and parameters: {'iterations': 1732, 'depth': 7, 'learning_rate': 0.020946643305344546, 'l2_leaf_reg': 0.3709839617208535, 'bagging_temperature': 0.6373638764393258, 'random_strength': 2.0512251196140587, 'scale_pos_weight': 1.1263641417775907, 'border_count': 149}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 13:55:21,618] Trial 66 finished with value: 0.7400663177016225 and parameters: {'iterations': 2528, 'depth': 5, 'learning_rate': 0.015643618504637493, 'l2_leaf_reg': 0.010808857041981763, 'bagging_temperature': 0.40793927662437457, 'random_strength': 2.8411854657311117, 'scale_pos_weight': 2.209160165989009, 'border_count': 191}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 13:58:11,053] Trial 67 finished with value: 0.7367981414997627 and parameters: {'iterations': 2238, 'depth': 5, 'learning_rate': 0.002800707263729369, 'l2_leaf_reg': 2.0033633919436884, 'bagging_temperature': 0.2827264861258221, 'random_strength': 1.7209191499184104, 'scale_pos_weight': 2.6035977081677775, 'border_count': 159}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:00:56,734] Trial 68 finished with value: 0.7352230009774965 and parameters: {'iterations': 1941, 'depth': 6, 'learning_rate': 0.0014239650704165148, 'l2_leaf_reg': 0.30728589597044165, 'bagging_temperature': 0.47450792428215344, 'random_strength': 1.054987905056654, 'scale_pos_weight': 3.570366832666739, 'border_count': 134}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:04:19,878] Trial 69 finished with value: 0.7398961398849981 and parameters: {'iterations': 2642, 'depth': 5, 'learning_rate': 0.06589629337909696, 'l2_leaf_reg': 0.47213677312894886, 'bagging_temperature': 0.5384156367276403, 'random_strength': 2.2245239294326358, 'scale_pos_weight': 1.3254124967608167, 'border_count': 174}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:06:27,031] Trial 70 finished with value: 0.7385043953096975 and parameters: {'iterations': 1225, 'depth': 8, 'learning_rate': 0.0298661911884758, 'l2_leaf_reg': 0.0026904793349719677, 'bagging_temperature': 0.3604085944091002, 'random_strength': 8.73201240331554, 'scale_pos_weight': 4.008983520666183, 'border_count': 206}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:08:45,128] Trial 71 finished with value: 0.7399732854914619 and parameters: {'iterations': 2068, 'depth': 4, 'learning_rate': 0.08349081643287427, 'l2_leaf_reg': 3.4964297815448586, 'bagging_temperature': 0.3949396585967983, 'random_strength': 1.6094571964180366, 'scale_pos_weight': 2.8070236250610816, 'border_count': 131}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:10:59,990] Trial 72 finished with value: 0.7401562168567988 and parameters: {'iterations': 1813, 'depth': 5, 'learning_rate': 0.0485615298981148, 'l2_leaf_reg': 7.27340454635972, 'bagging_temperature': 0.3539579138856648, 'random_strength': 2.449072205662563, 'scale_pos_weight': 3.1793475998683114, 'border_count': 104}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:13:25,870] Trial 73 finished with value: 0.7399663595711804 and parameters: {'iterations': 1779, 'depth': 6, 'learning_rate': 0.012178375715679821, 'l2_leaf_reg': 7.161996304233184, 'bagging_temperature': 0.29786926475586073, 'random_strength': 2.435269521430643, 'scale_pos_weight': 3.2592010364006945, 'border_count': 106}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:15:48,203] Trial 74 finished with value: 0.7402677174917075 and parameters: {'iterations': 1918, 'depth': 5, 'learning_rate': 0.03215419451486325, 'l2_leaf_reg': 1.408257217808357, 'bagging_temperature': 0.7252898313254961, 'random_strength': 3.352246536462249, 'scale_pos_weight': 2.4840561849911373, 'border_count': 85}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:17:40,704] Trial 75 finished with value: 0.740085531544984 and parameters: {'iterations': 1509, 'depth': 5, 'learning_rate': 0.0333690365386496, 'l2_leaf_reg': 0.8240143863595162, 'bagging_temperature': 0.7193350738778121, 'random_strength': 3.5862916018104567, 'scale_pos_weight': 1.7750510052436388, 'border_count': 90}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:20:44,199] Trial 76 finished with value: 0.7248718414514905 and parameters: {'iterations': 2171, 'depth': 6, 'learning_rate': 1.2792224488035143e-05, 'l2_leaf_reg': 1.8539986082478221, 'bagging_temperature': 0.6606791213052242, 'random_strength': 3.2482315922247755, 'scale_pos_weight': 2.1377505652161095, 'border_count': 118}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:22:46,723] Trial 77 finished with value: 0.7400715920081136 and parameters: {'iterations': 1660, 'depth': 5, 'learning_rate': 0.021358502210022307, 'l2_leaf_reg': 1.2943615648297886, 'bagging_temperature': 0.7817550525047741, 'random_strength': 5.142161544004597, 'scale_pos_weight': 2.514940905743743, 'border_count': 164}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:25:33,727] Trial 78 finished with value: 0.7390600934019127 and parameters: {'iterations': 2301, 'depth': 5, 'learning_rate': 0.12201266539981016, 'l2_leaf_reg': 0.03573109724695884, 'bagging_temperature': 0.9226214130852427, 'random_strength': 2.842125086090319, 'scale_pos_weight': 1.6661828852747125, 'border_count': 45}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:27:46,377] Trial 79 finished with value: 0.7396132201131129 and parameters: {'iterations': 1969, 'depth': 4, 'learning_rate': 0.19872979807269942, 'l2_leaf_reg': 2.5102510788474213, 'bagging_temperature': 0.7385157740099966, 'random_strength': 4.126070419458367, 'scale_pos_weight': 7.097714097468227, 'border_count': 75}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:30:08,544] Trial 80 finished with value: 0.7402267643601305 and parameters: {'iterations': 1895, 'depth': 5, 'learning_rate': 0.015854725217909576, 'l2_leaf_reg': 0.6354151913365337, 'bagging_temperature': 0.8560284177842109, 'random_strength': 1.370749201731769, 'scale_pos_weight': 3.0360887518590034, 'border_count': 145}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:32:32,549] Trial 81 finished with value: 0.7392273323482338 and parameters: {'iterations': 1883, 'depth': 5, 'learning_rate': 0.007566617203597182, 'l2_leaf_reg': 1.4135109820875527, 'bagging_temperature': 0.8475785093700273, 'random_strength': 1.3115319070732983, 'scale_pos_weight': 2.8898924196413645, 'border_count': 142}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:35:25,586] Trial 82 finished with value: 0.7401205348997019 and parameters: {'iterations': 2032, 'depth': 6, 'learning_rate': 0.01737323543688962, 'l2_leaf_reg': 0.6070634766638333, 'bagging_temperature': 0.972622501937084, 'random_strength': 2.116037114757584, 'scale_pos_weight': 2.3910189782777875, 'border_count': 154}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:38:30,370] Trial 83 finished with value: 0.7401362033066335 and parameters: {'iterations': 2459, 'depth': 5, 'learning_rate': 0.026761498919344383, 'l2_leaf_reg': 4.215191787188701, 'bagging_temperature': 0.6261217321514214, 'random_strength': 1.5752208763013382, 'scale_pos_weight': 3.783215909366666, 'border_count': 120}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:40:35,935] Trial 84 finished with value: 0.7402153325200518 and parameters: {'iterations': 1678, 'depth': 5, 'learning_rate': 0.060365257293088, 'l2_leaf_reg': 0.3799056125850289, 'bagging_temperature': 0.568595951505466, 'random_strength': 1.829081467348181, 'scale_pos_weight': 2.6600863858629067, 'border_count': 169}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:42:22,370] Trial 85 finished with value: 0.7400706889449475 and parameters: {'iterations': 1593, 'depth': 4, 'learning_rate': 0.06571425242679563, 'l2_leaf_reg': 0.21831216166822484, 'bagging_temperature': 0.6842827579333323, 'random_strength': 1.832094162193027, 'scale_pos_weight': 2.6649646267246836, 'border_count': 191}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:44:07,953] Trial 86 finished with value: 0.7401440865782714 and parameters: {'iterations': 1397, 'depth': 5, 'learning_rate': 0.03557409345959702, 'l2_leaf_reg': 0.11706977238063934, 'bagging_temperature': 0.5766418480170373, 'random_strength': 1.2438564432306487, 'scale_pos_weight': 1.886818821383862, 'border_count': 167}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:46:02,655] Trial 87 finished with value: 0.7400591735845761 and parameters: {'iterations': 1700, 'depth': 4, 'learning_rate': 0.09060164283167545, 'l2_leaf_reg': 0.39919417870063767, 'bagging_temperature': 0.8520057040732617, 'random_strength': 1.4821701963688507, 'scale_pos_weight': 2.126482390703217, 'border_count': 87}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:48:29,925] Trial 88 finished with value: 0.737858278148483 and parameters: {'iterations': 1829, 'depth': 6, 'learning_rate': 0.004801819074397682, 'l2_leaf_reg': 0.27830346277016205, 'bagging_temperature': 0.9005960884766997, 'random_strength': 1.9873458562426978, 'scale_pos_weight': 3.544226913288377, 'border_count': 97}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:51:02,329] Trial 89 finished with value: 0.7394611505399742 and parameters: {'iterations': 2114, 'depth': 5, 'learning_rate': 0.04968898684865568, 'l2_leaf_reg': 0.062275903445564676, 'bagging_temperature': 0.9716114564280477, 'random_strength': 1.1405382355292417, 'scale_pos_weight': 1.0026647893455638, 'border_count': 178}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:51:12,218] Trial 90 finished with value: 0.7252518619157997 and parameters: {'iterations': 131, 'depth': 4, 'learning_rate': 0.011189724009060925, 'l2_leaf_reg': 0.17553528218126577, 'bagging_temperature': 0.8077358254158564, 'random_strength': 6.350154387822088, 'scale_pos_weight': 1.5034033460365293, 'border_count': 109}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:53:36,136] Trial 91 finished with value: 0.7400343440455264 and parameters: {'iterations': 1921, 'depth': 5, 'learning_rate': 0.015213020304880755, 'l2_leaf_reg': 0.8453625958262321, 'bagging_temperature': 0.5230369122469837, 'random_strength': 2.52002298611848, 'scale_pos_weight': 3.0487562351636486, 'border_count': 146}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:55:47,557] Trial 92 finished with value: 0.7401990982631362 and parameters: {'iterations': 1763, 'depth': 5, 'learning_rate': 0.023886132646302488, 'l2_leaf_reg': 2.523071789671274, 'bagging_temperature': 0.5998554004500511, 'random_strength': 1.6829172218231214, 'scale_pos_weight': 2.7011155677720557, 'border_count': 137}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:57:49,275] Trial 93 finished with value: 0.7401119041214432 and parameters: {'iterations': 1666, 'depth': 5, 'learning_rate': 0.037955138495201345, 'l2_leaf_reg': 1.1038385836217512, 'bagging_temperature': 0.6161670563956666, 'random_strength': 1.75462575104181, 'scale_pos_weight': 2.6572865261347998, 'border_count': 126}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 14:59:44,045] Trial 94 finished with value: 0.740083562554081 and parameters: {'iterations': 1748, 'depth': 4, 'learning_rate': 0.025050538029589293, 'l2_leaf_reg': 0.6620187905240269, 'bagging_temperature': 0.6519766680361337, 'random_strength': 1.5180134465085284, 'scale_pos_weight': 2.303906396796043, 'border_count': 137}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:02:11,174] Trial 95 finished with value: 0.7396521844177175 and parameters: {'iterations': 1981, 'depth': 5, 'learning_rate': 0.16322525136990354, 'l2_leaf_reg': 5.360121225038615, 'bagging_temperature': 0.7009435114947802, 'random_strength': 2.1232859636782857, 'scale_pos_weight': 1.9798941468133764, 'border_count': 140}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:04:42,971] Trial 96 finished with value: 0.7390405767974897 and parameters: {'iterations': 1578, 'depth': 8, 'learning_rate': 0.06324122669174276, 'l2_leaf_reg': 1.621580505541569, 'bagging_temperature': 0.5654346703374638, 'random_strength': 1.8562161609198984, 'scale_pos_weight': 3.4028772216578167, 'border_count': 33}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:06:51,431] Trial 97 finished with value: 0.7401490027915072 and parameters: {'iterations': 1784, 'depth': 5, 'learning_rate': 0.04152564394931554, 'l2_leaf_reg': 0.4709783917107137, 'bagging_temperature': 0.45836436882358167, 'random_strength': 1.3201288642161433, 'scale_pos_weight': 2.813169315334968, 'border_count': 152}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:08:27,158] Trial 98 finished with value: 0.7400143346713758 and parameters: {'iterations': 1513, 'depth': 4, 'learning_rate': 0.02900426165584948, 'l2_leaf_reg': 2.397520855714651, 'bagging_temperature': 0.5996347687716023, 'random_strength': 1.0702425491994811, 'scale_pos_weight': 2.465782370192085, 'border_count': 199}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:10:51,518] Trial 99 finished with value: 0.7393649758787966 and parameters: {'iterations': 1852, 'depth': 6, 'learning_rate': 0.05089613772183928, 'l2_leaf_reg': 0.10536740476677742, 'bagging_temperature': 0.25879488238634085, 'random_strength': 1.6438878657258158, 'scale_pos_weight': 3.11303921931227, 'border_count': 66}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:13:01,057] Trial 100 finished with value: 0.7400059335739224 and parameters: {'iterations': 2035, 'depth': 4, 'learning_rate': 0.022241636618957, 'l2_leaf_reg': 1.0256676293620084, 'bagging_temperature': 0.4960169722623632, 'random_strength': 1.4103452567833465, 'scale_pos_weight': 3.8022757079087084, 'border_count': 122}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:15:16,972] Trial 101 finished with value: 0.7400350779800995 and parameters: {'iterations': 1916, 'depth': 5, 'learning_rate': 0.014163447313723397, 'l2_leaf_reg': 2.4692426753133083, 'bagging_temperature': 0.5975704150657635, 'random_strength': 2.9413741091653556, 'scale_pos_weight': 2.974571130972133, 'border_count': 169}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:17:52,930] Trial 102 finished with value: 0.7398600810425797 and parameters: {'iterations': 2119, 'depth': 5, 'learning_rate': 0.010101126449544369, 'l2_leaf_reg': 3.1501809019749567, 'bagging_temperature': 0.4197608456009913, 'random_strength': 2.3004099222425207, 'scale_pos_weight': 3.2734388911985803, 'border_count': 159}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:21:21,842] Trial 103 finished with value: 0.7401435844125109 and parameters: {'iterations': 2764, 'depth': 5, 'learning_rate': 0.017296126088660307, 'l2_leaf_reg': 4.1881084683859, 'bagging_temperature': 0.3845968816563747, 'random_strength': 1.9582594459444849, 'scale_pos_weight': 4.200705633698195, 'border_count': 147}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:23:45,001] Trial 104 finished with value: 0.7376423614875034 and parameters: {'iterations': 1885, 'depth': 5, 'learning_rate': 0.006645004364174621, 'l2_leaf_reg': 1.529333392779227, 'bagging_temperature': 0.3400026946197906, 'random_strength': 2.6264027116928914, 'scale_pos_weight': 4.549271765025456, 'border_count': 155}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:26:32,330] Trial 105 finished with value: 0.7396229084670793 and parameters: {'iterations': 2233, 'depth': 5, 'learning_rate': 0.020522450854417826, 'l2_leaf_reg': 0.8270789611313638, 'bagging_temperature': 0.550429857726184, 'random_strength': 1.6858408654414152, 'scale_pos_weight': 9.819217923926498, 'border_count': 133}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:28:31,536] Trial 106 finished with value: 0.7385800156268139 and parameters: {'iterations': 1683, 'depth': 5, 'learning_rate': 0.07574892384456862, 'l2_leaf_reg': 0.00029047949650371353, 'bagging_temperature': 0.5040587954416915, 'random_strength': 2.109636382760544, 'scale_pos_weight': 7.647209044718895, 'border_count': 161}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:30:53,552] Trial 107 finished with value: 0.7401077448108613 and parameters: {'iterations': 1783, 'depth': 6, 'learning_rate': 0.03866636250489393, 'l2_leaf_reg': 6.037522582814203, 'bagging_temperature': 0.30425551282499635, 'random_strength': 1.1592311925476335, 'scale_pos_weight': 2.571810575751112, 'border_count': 172}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:33:26,162] Trial 108 finished with value: 0.7400160614534296 and parameters: {'iterations': 2392, 'depth': 4, 'learning_rate': 0.027688676089529525, 'l2_leaf_reg': 0.351889409502002, 'bagging_temperature': 0.23603010930026555, 'random_strength': 2.4358893803627923, 'scale_pos_weight': 2.2541340720001006, 'border_count': 186}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:37:00,558] Trial 109 finished with value: 0.7390765980557762 and parameters: {'iterations': 2937, 'depth': 5, 'learning_rate': 0.10991691824572002, 'l2_leaf_reg': 1.7795610211421538e-05, 'bagging_temperature': 0.37760802907118457, 'random_strength': 7.262728361677493, 'scale_pos_weight': 3.489077497801072, 'border_count': 129}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:38:26,205] Trial 110 finished with value: 0.7401832701236446 and parameters: {'iterations': 1306, 'depth': 4, 'learning_rate': 0.03259607159889228, 'l2_leaf_reg': 9.99077064290285, 'bagging_temperature': 0.7586148355823781, 'random_strength': 1.0135816266243844, 'scale_pos_weight': 3.1018269956569844, 'border_count': 142}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:40:38,134] Trial 111 finished with value: 0.7400843413808114 and parameters: {'iterations': 2011, 'depth': 4, 'learning_rate': 0.03241042252199438, 'l2_leaf_reg': 2.7292561984530153, 'bagging_temperature': 0.7832158090485255, 'random_strength': 1.305083946510572, 'scale_pos_weight': 2.7475113525446155, 'border_count': 144}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:41:54,695] Trial 112 finished with value: 0.7390914928559957 and parameters: {'iterations': 1199, 'depth': 4, 'learning_rate': 0.013585323551746152, 'l2_leaf_reg': 9.626372889870607, 'bagging_temperature': 0.7419984203502112, 'random_strength': 1.4546177017032829, 'scale_pos_weight': 2.970310018137167, 'border_count': 136}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:43:30,575] Trial 113 finished with value: 0.7402560977309699 and parameters: {'iterations': 1437, 'depth': 4, 'learning_rate': 0.05308854097801764, 'l2_leaf_reg': 1.9988366902378627, 'bagging_temperature': 0.6376761579588004, 'random_strength': 1.0396022944304624, 'scale_pos_weight': 3.192018450879593, 'border_count': 156}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:45:00,887] Trial 114 finished with value: 0.7402847295313499 and parameters: {'iterations': 1289, 'depth': 4, 'learning_rate': 0.05667779471167478, 'l2_leaf_reg': 1.9223340786560312, 'bagging_temperature': 0.6425102813130731, 'random_strength': 1.0535372794667073, 'scale_pos_weight': 3.2573371453248874, 'border_count': 152}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:46:41,711] Trial 115 finished with value: 0.7400242234740448 and parameters: {'iterations': 1418, 'depth': 4, 'learning_rate': 0.059625528323678983, 'l2_leaf_reg': 1.9654634993322677, 'bagging_temperature': 0.6446375283386011, 'random_strength': 1.1941791961893684, 'scale_pos_weight': 3.3245569921463263, 'border_count': 177}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:47:44,837] Trial 116 finished with value: 0.7399168685776705 and parameters: {'iterations': 887, 'depth': 4, 'learning_rate': 0.04914110002071486, 'l2_leaf_reg': 1.235157117020986, 'bagging_temperature': 0.7137725007523763, 'random_strength': 1.0031420456900413, 'scale_pos_weight': 2.768782144436499, 'border_count': 153}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:49:04,395] Trial 117 finished with value: 0.7391723645115227 and parameters: {'iterations': 1133, 'depth': 4, 'learning_rate': 0.29164625532732497, 'l2_leaf_reg': 0.6347987233841627, 'bagging_temperature': 0.6931598981527034, 'random_strength': 1.8064552916252063, 'scale_pos_weight': 2.5245685572796637, 'border_count': 164}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:50:46,777] Trial 118 finished with value: 0.7399692389332752 and parameters: {'iterations': 1456, 'depth': 4, 'learning_rate': 0.0816961335589556, 'l2_leaf_reg': 4.1932534395043595, 'bagging_temperature': 0.6775067279151588, 'random_strength': 1.5998525684684264, 'scale_pos_weight': 2.130277852739999, 'border_count': 82}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:52:21,969] Trial 119 finished with value: 0.7396548184389521 and parameters: {'iterations': 1382, 'depth': 4, 'learning_rate': 0.1361088644340566, 'l2_leaf_reg': 1.446404186432897, 'bagging_temperature': 0.6074007411862474, 'random_strength': 1.2557179380084036, 'scale_pos_weight': 3.603295114444774, 'border_count': 150}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:53:39,672] Trial 120 finished with value: 0.7399642433757613 and parameters: {'iterations': 1268, 'depth': 4, 'learning_rate': 0.058101366678265196, 'l2_leaf_reg': 1.9512021942614837, 'bagging_temperature': 0.62621087858959, 'random_strength': 1.4044703988112168, 'scale_pos_weight': 6.789362403246452, 'border_count': 111}. Best is trial 59 with value: 0.7403462056868783.
# [I 2025-02-04 15:54:58,295] Trial 121 finished with value: 0.7401848016770138 and parameters: {'iterations': 1269, 'depth': 4, 'learning_rate': 0.04297278197000214, 'l2_leaf_reg': 6.952680304074816, 'bagging_temperature': 0.8322725448557677, 'random_strength': 1.054096591475267, 'scale_pos_weight': 3.1740718448456593, 'border_count': 138}. Best is trial 59 with value: 0.7403462056868783.
# ...
# [I 2025-02-04 18:45:32,844] Trial 214 finished with value: 0.7402490726303407 and parameters: {'iterations': 1745, 'depth': 4, 'learning_rate': 0.027583295107013125, 'l2_leaf_reg': 3.571341909950044, 'bagging_temperature': 0.3929835766111033, 'random_strength': 1.377310124007486, 'scale_pos_weight': 3.073579519911157, 'border_count': 80}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 18:47:13,382] Trial 215 finished with value: 0.7400422732533253 and parameters: {'iterations': 1747, 'depth': 4, 'learning_rate': 0.027256362557683912, 'l2_leaf_reg': 3.2171913048169083, 'bagging_temperature': 0.37960356395024064, 'random_strength': 1.1676980261702201, 'scale_pos_weight': 3.063510757497942, 'border_count': 78}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 18:48:55,986] Trial 216 finished with value: 0.7399657738851271 and parameters: {'iterations': 1806, 'depth': 4, 'learning_rate': 0.020940755321386624, 'l2_leaf_reg': 4.863527970974698, 'bagging_temperature': 0.4125406305942788, 'random_strength': 5.388562143528091, 'scale_pos_weight': 2.9315636651917147, 'border_count': 70}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 18:50:39,772] Trial 217 finished with value: 0.7403233524467575 and parameters: {'iterations': 1833, 'depth': 4, 'learning_rate': 0.030138437052096297, 'l2_leaf_reg': 2.289675837790804, 'bagging_temperature': 0.3499685572489222, 'random_strength': 1.371772009327614, 'scale_pos_weight': 3.3848996003647396, 'border_count': 88}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 18:52:24,942] Trial 218 finished with value: 0.7400913884055175 and parameters: {'iterations': 1824, 'depth': 4, 'learning_rate': 0.029584374961584982, 'l2_leaf_reg': 2.5177973503550377, 'bagging_temperature': 0.3524586367232492, 'random_strength': 1.3707438912115661, 'scale_pos_weight': 3.2604436520367193, 'border_count': 81}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 18:54:14,464] Trial 219 finished with value: 0.7399699008315956 and parameters: {'iterations': 1927, 'depth': 4, 'learning_rate': 0.03831878353390503, 'l2_leaf_reg': 2.0283820913484965, 'bagging_temperature': 0.389391548006474, 'random_strength': 1.6825211150727508, 'scale_pos_weight': 3.525828993065873, 'border_count': 86}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 18:55:53,982] Trial 220 finished with value: 0.7400458353938137 and parameters: {'iterations': 1730, 'depth': 4, 'learning_rate': 0.044230779340509445, 'l2_leaf_reg': 2.95749599289614, 'bagging_temperature': 0.31252164582211545, 'random_strength': 1.4434775528686696, 'scale_pos_weight': 3.7128238347901936, 'border_count': 96}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 18:57:46,535] Trial 221 finished with value: 0.7401252339601763 and parameters: {'iterations': 1973, 'depth': 4, 'learning_rate': 0.02412369099036372, 'l2_leaf_reg': 4.328913902454365, 'bagging_temperature': 0.3482667799833509, 'random_strength': 1.1552131529102714, 'scale_pos_weight': 3.3674948315938806, 'border_count': 60}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 18:59:32,154] Trial 222 finished with value: 0.7399951761602082 and parameters: {'iterations': 1865, 'depth': 4, 'learning_rate': 0.03300982792790805, 'l2_leaf_reg': 0.01749647504366061, 'bagging_temperature': 0.3710480634910121, 'random_strength': 1.2919125210314484, 'scale_pos_weight': 3.0246859449331227, 'border_count': 92}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:01:54,982] Trial 223 finished with value: 0.7401135505152153 and parameters: {'iterations': 2483, 'depth': 4, 'learning_rate': 0.020311734826531952, 'l2_leaf_reg': 1.6606690797538597, 'bagging_temperature': 0.43162922188741193, 'random_strength': 1.5927935162183573, 'scale_pos_weight': 3.1994895573330915, 'border_count': 83}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:03:07,493] Trial 224 finished with value: 0.7396156432456084 and parameters: {'iterations': 1278, 'depth': 4, 'learning_rate': 0.015470695973527107, 'l2_leaf_reg': 3.283242640317263, 'bagging_temperature': 0.34301005085120845, 'random_strength': 1.1074973147423475, 'scale_pos_weight': 2.846111151858942, 'border_count': 89}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:04:53,180] Trial 225 finished with value: 0.7401296396556221 and parameters: {'iterations': 1790, 'depth': 4, 'learning_rate': 0.02821302004228155, 'l2_leaf_reg': 2.2545609002769145, 'bagging_temperature': 0.39620425747602545, 'random_strength': 1.003091028634566, 'scale_pos_weight': 4.783638093289746, 'border_count': 76}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:06:39,938] Trial 226 finished with value: 0.739825443089143 and parameters: {'iterations': 1857, 'depth': 4, 'learning_rate': 0.050836589728361005, 'l2_leaf_reg': 6.2907150139919, 'bagging_temperature': 0.2981296043309148, 'random_strength': 1.3977342506339325, 'scale_pos_weight': 2.5288023256391705, 'border_count': 98}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:08:37,585] Trial 227 finished with value: 0.7401670619668205 and parameters: {'iterations': 2070, 'depth': 4, 'learning_rate': 0.03483662762855637, 'l2_leaf_reg': 3.63964387443317, 'bagging_temperature': 0.32819997178617766, 'random_strength': 1.7217834969775003, 'scale_pos_weight': 3.4597779680812835, 'border_count': 80}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:10:14,339] Trial 228 finished with value: 0.7401058029640535 and parameters: {'iterations': 1679, 'depth': 4, 'learning_rate': 0.02563356021420375, 'l2_leaf_reg': 5.027232362844125, 'bagging_temperature': 0.8643858790980465, 'random_strength': 1.3107928177658281, 'scale_pos_weight': 3.0767756425544763, 'border_count': 113}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:11:56,173] Trial 229 finished with value: 0.739884804093256 and parameters: {'iterations': 1759, 'depth': 4, 'learning_rate': 0.0451174868289658, 'l2_leaf_reg': 1.5533417645007108, 'bagging_temperature': 0.8867875267546695, 'random_strength': 1.5375769988618697, 'scale_pos_weight': 2.1579404614657123, 'border_count': 206}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:13:47,074] Trial 230 finished with value: 0.7400289371505704 and parameters: {'iterations': 1919, 'depth': 4, 'learning_rate': 0.03753492126564919, 'l2_leaf_reg': 1.2600280671685784, 'bagging_temperature': 0.9506426837052794, 'random_strength': 1.0071644003389004, 'scale_pos_weight': 2.691626874923146, 'border_count': 103}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:15:32,532] Trial 231 finished with value: 0.7400782214313556 and parameters: {'iterations': 1642, 'depth': 5, 'learning_rate': 0.05873786431426743, 'l2_leaf_reg': 2.316595189640156, 'bagging_temperature': 0.36214034466887873, 'random_strength': 1.8349053023772686, 'scale_pos_weight': 2.58141156102386, 'border_count': 72}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:17:25,185] Trial 232 finished with value: 0.7402113214579893 and parameters: {'iterations': 1698, 'depth': 5, 'learning_rate': 0.05086572563261696, 'l2_leaf_reg': 0.5772191416827502, 'bagging_temperature': 0.4118973660803891, 'random_strength': 2.2494562113025123, 'scale_pos_weight': 2.867880770320278, 'border_count': 152}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:19:36,130] Trial 233 finished with value: 0.7401441565265166 and parameters: {'iterations': 2014, 'depth': 5, 'learning_rate': 0.030393419646122258, 'l2_leaf_reg': 3.889736154945674, 'bagging_temperature': 0.4801046142391692, 'random_strength': 2.011741890105209, 'scale_pos_weight': 3.230878066440535, 'border_count': 85}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:21:23,238] Trial 234 finished with value: 0.740067775130732 and parameters: {'iterations': 1818, 'depth': 4, 'learning_rate': 0.04145415302938436, 'l2_leaf_reg': 2.5732645480980447, 'bagging_temperature': 0.8173069579166177, 'random_strength': 1.4352053970394203, 'scale_pos_weight': 2.294904477005059, 'border_count': 92}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:23:31,476] Trial 235 finished with value: 0.7399414078837026 and parameters: {'iterations': 2330, 'depth': 4, 'learning_rate': 0.06927170210923814, 'l2_leaf_reg': 0.037438954063867914, 'bagging_temperature': 0.37865967567631925, 'random_strength': 3.588531922975837, 'scale_pos_weight': 3.001845313465218, 'border_count': 237}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:25:10,247] Trial 236 finished with value: 0.7401943115063544 and parameters: {'iterations': 1733, 'depth': 4, 'learning_rate': 0.025718991671224222, 'l2_leaf_reg': 7.6743763593629835, 'bagging_temperature': 0.34543143526876097, 'random_strength': 1.6964675404873428, 'scale_pos_weight': 2.7892732441324926, 'border_count': 124}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:27:10,825] Trial 237 finished with value: 0.7400839947715963 and parameters: {'iterations': 1894, 'depth': 5, 'learning_rate': 0.03437426423783831, 'l2_leaf_reg': 0.07524678698406895, 'bagging_temperature': 0.8512803821363083, 'random_strength': 1.2609048783243226, 'scale_pos_weight': 2.4327991856829856, 'border_count': 156}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:28:43,263] Trial 238 finished with value: 0.7398927322570513 and parameters: {'iterations': 1632, 'depth': 4, 'learning_rate': 0.01950834527291189, 'l2_leaf_reg': 0.12627416727483595, 'bagging_temperature': 0.8813781716537564, 'random_strength': 2.643171218565045, 'scale_pos_weight': 3.3890880220213173, 'border_count': 150}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:30:54,391] Trial 239 finished with value: 0.740080198774288 and parameters: {'iterations': 1973, 'depth': 5, 'learning_rate': 0.04500557891278366, 'l2_leaf_reg': 0.9922327721101849, 'bagging_temperature': 0.9165781559819297, 'random_strength': 1.5793874045927225, 'scale_pos_weight': 2.6043800047092382, 'border_count': 116}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:32:06,533] Trial 240 finished with value: 0.7401528906611377 and parameters: {'iterations': 1193, 'depth': 4, 'learning_rate': 0.05588338537199706, 'l2_leaf_reg': 1.9783040257646034, 'bagging_temperature': 0.45089615293537266, 'random_strength': 1.8032889527426723, 'scale_pos_weight': 3.1157763197934805, 'border_count': 106}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:33:05,632] Trial 241 finished with value: 0.7400040073871694 and parameters: {'iterations': 1872, 'depth': 4, 'learning_rate': 0.038608482647594373, 'l2_leaf_reg': 5.564067482699636, 'bagging_temperature': 0.6983249851650124, 'random_strength': 1.851807866207284, 'scale_pos_weight': 2.503932312649185, 'border_count': 160}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:34:00,380] Trial 242 finished with value: 0.7398651434163279 and parameters: {'iterations': 1777, 'depth': 4, 'learning_rate': 0.03159982337798188, 'l2_leaf_reg': 4.511345627591226, 'bagging_temperature': 0.6712696660761468, 'random_strength': 2.1506343376064336, 'scale_pos_weight': 1.3204569105471466, 'border_count': 166}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:34:59,565] Trial 243 finished with value: 0.7401136570035887 and parameters: {'iterations': 1914, 'depth': 4, 'learning_rate': 0.024299462968359067, 'l2_leaf_reg': 3.749569752474772, 'bagging_temperature': 0.7141340917502786, 'random_strength': 1.9335219137950994, 'scale_pos_weight': 2.753416522748236, 'border_count': 154}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:35:57,026] Trial 244 finished with value: 0.7400071049460291 and parameters: {'iterations': 1838, 'depth': 4, 'learning_rate': 0.034049659499526735, 'l2_leaf_reg': 3.030669865591655, 'bagging_temperature': 0.6494925980096774, 'random_strength': 1.1969115127289305, 'scale_pos_weight': 1.9964717961203482, 'border_count': 161}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:36:49,252] Trial 245 finished with value: 0.7401862131699625 and parameters: {'iterations': 1689, 'depth': 4, 'learning_rate': 0.03927301533762069, 'l2_leaf_reg': 5.510930229003282, 'bagging_temperature': 0.32578846195304045, 'random_strength': 2.329212514708664, 'scale_pos_weight': 2.9284383663599156, 'border_count': 146}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:38:00,830] Trial 246 finished with value: 0.740055907941127 and parameters: {'iterations': 1964, 'depth': 4, 'learning_rate': 0.05021545928709666, 'l2_leaf_reg': 7.865278038000218, 'bagging_temperature': 0.8622540139019668, 'random_strength': 1.5079413425786576, 'scale_pos_weight': 2.3797713972065546, 'border_count': 171}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:38:56,811] Trial 247 finished with value: 0.7401067843274938 and parameters: {'iterations': 1892, 'depth': 4, 'learning_rate': 0.06404048103150509, 'l2_leaf_reg': 2.7485443557368923, 'bagging_temperature': 0.7526502961435134, 'random_strength': 1.7544954924612308, 'scale_pos_weight': 3.233033305502553, 'border_count': 100}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:39:56,055] Trial 248 finished with value: 0.740258167990228 and parameters: {'iterations': 1804, 'depth': 4, 'learning_rate': 0.02874087536097099, 'l2_leaf_reg': 4.604417538924963, 'bagging_temperature': 0.3641953800161938, 'random_strength': 1.3559471868328248, 'scale_pos_weight': 3.6314195416491497, 'border_count': 86}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:40:58,566] Trial 249 finished with value: 0.7400274191692486 and parameters: {'iterations': 1755, 'depth': 5, 'learning_rate': 0.021829064545240414, 'l2_leaf_reg': 0.25402026676143724, 'bagging_temperature': 0.36839963214677224, 'random_strength': 1.309008144243854, 'scale_pos_weight': 3.6101512922181405, 'border_count': 87}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:41:59,637] Trial 250 finished with value: 0.7402347948362844 and parameters: {'iterations': 1808, 'depth': 4, 'learning_rate': 0.017777402816754443, 'l2_leaf_reg': 1.9974492114043463, 'bagging_temperature': 0.290679625105578, 'random_strength': 1.430142941279615, 'scale_pos_weight': 3.69629770469547, 'border_count': 83}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:42:54,628] Trial 251 finished with value: 0.740055840080889 and parameters: {'iterations': 1812, 'depth': 4, 'learning_rate': 0.016022751382630714, 'l2_leaf_reg': 1.9715064559156172, 'bagging_temperature': 0.2681398367580819, 'random_strength': 1.1475997730491116, 'scale_pos_weight': 3.8883022638464975, 'border_count': 80}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:43:51,705] Trial 252 finished with value: 0.7401105249926081 and parameters: {'iterations': 1820, 'depth': 4, 'learning_rate': 0.018296562063105943, 'l2_leaf_reg': 1.3397850739937422, 'bagging_temperature': 0.28706947959379076, 'random_strength': 1.3857413719170735, 'scale_pos_weight': 3.682119859130485, 'border_count': 221}. Best is trial 162 with value: 0.740407128520467.
# [I 2025-02-04 19:44:34,983] Trial 253 finished with value: 0.7400392195426193 and parameters: {'iterations': 1379, 'depth': 4, 'learning_rate': 0.02755694462201931, 'l2_leaf_reg': 3.301564431855395, 'bagging_temperature': 0.3020224362866106, 'random_strength': 1.1987833824898217, 'scale_pos_weight': 3.823668707888897, 'border_count': 94}. Best is trial 162 with value: 0.740407128520467.

# %% [markdown]
# ---

# %%
# 모델 초기화
IVF_model = lgb.LGBMClassifier(
    n_estimators=1258,
    num_leaves=923,
    max_depth=5,
    learning_rate=0.024413717866391526,
    min_child_samples=105,
    subsample=0.4890106069104924,
    colsample_bytree=0.4494069713807123,
    reg_alpha=3.0197481977859035,
    reg_lambda=0.4793565720612017,
    min_split_gain=0.29685405151668676,
    random_state=42,
    boosting_type='gbdt',
    verbose=-1
    )

# 모델 학습
IVF_model.fit(IVF_X_train, IVF_y_train)

# 예측
y_pred = IVF_model.predict(IVF_X_test)
y_pred_proba = IVF_model.predict_proba(IVF_X_test)[:, 1]

# 평가
accuracy = accuracy_score(IVF_y_test, y_pred)
f1 = f1_score(IVF_y_test, y_pred)
auc = roc_auc_score(IVF_y_test, y_pred_proba)
cm = confusion_matrix(IVF_y_test, y_pred)

# 결과 출력
print()
print("--- Model Performance ---")
print(f"Model Accuracy: {accuracy}")
print(f"Model F1 Score: {f1}")
print(f"Model AUC: {auc}")

# 혼동 행렬 출력
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=IVF_model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# --- Model Performance ---
# Model Accuracy: 0.7458959029013617
# Model F1 Score: 0.2033600802407222
# Model AUC: 0.7405188588361808

# %% [markdown]
# ### DI 데이터

# %%
# 모델 초기화
DI_model = lgb.LGBMClassifier(
    n_estimators=2443,
    num_leaves=280,
    max_depth=149,
    learning_rate=0.061743249432816755,
    min_child_samples=176,
    subsample=0.9103802819067428,
    colsample_bytree=0.6636673663468106,
    reg_alpha=0.01173260476029451,
    reg_lambda=59.000778013447324,
    min_split_gain=1.1755604684312402,
    random_state=42,
    boosting_type='gbdt',
    verbose=-1
)

# 모델 학습
DI_model.fit(DI_X_train, DI_y_train)

# 예측
y_pred = DI_model.predict(DI_X_test)
y_pred_proba = DI_model.predict_proba(DI_X_test)[:, 1]

# 평가
accuracy = accuracy_score(DI_y_test, y_pred)
f1 = f1_score(DI_y_test, y_pred)
auc = roc_auc_score(DI_y_test, y_pred_proba)
cm = confusion_matrix(DI_y_test, y_pred)

# 결과 출력
print()
print("--- Model Performance ---")
print(f"Model Accuracy: {accuracy}")
print(f"Model F1 Score: {f1}")
print(f"Model AUC: {auc}")

# 혼동 행렬 출력
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=DI_model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# --- Model Performance ---
# Model Accuracy: 0.8664546899841018
# Model F1 Score: 0.0
# Model AUC: 0.7105176933158585

# %%
# 예측
IVF_y_pred = IVF_model.predict(IVF_X_test)
IVF_y_pred_proba = IVF_model.predict_proba(IVF_X_test)[:, 1]

DI_y_pred = DI_model.predict(DI_X_test)
DI_y_pred_proba = DI_model.predict_proba(DI_X_test)[:, 1]

# 예측 결과 병합
y_test = pd.concat([IVF_y_test, DI_y_test])
y_pred = pd.concat([pd.Series(IVF_y_pred, index=IVF_y_test.index), pd.Series(DI_y_pred, index=DI_y_test.index)])
y_pred_proba = pd.concat([pd.Series(IVF_y_pred_proba, index=IVF_y_test.index), pd.Series(DI_y_pred_proba, index=DI_y_test.index)])

# 평가
accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred_proba)
cm = confusion_matrix(y_test, y_pred)

# 결과 출력
print()
print("--- Model Performance ---")
print(f"Model Accuracy: {accuracy}")
print(f"Model F1 Score: {f1}")
print(f"Model AUC: {auc}")

# 혼동 행렬 출력
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=IVF_model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# --- Model Performance ---
# Model Accuracy: 0.7488540833642162
# Model F1 Score: 0.2012406947890819
# Model AUC: 0.742169537176292

# %% [markdown]
# ## 제출

# %%
# 모델 구축
# IVF_model = CatBoostClassifier(
#     iterations=680,
#     depth=10,
#     learning_rate=0.01,
#     random_seed=42,
#     verbose=0
# )

# DI_model = CatBoostClassifier(
#     iterations=500,
#     depth=10,
#     learning_rate=0.01,
#     random_seed=42,
#     verbose=0
# )

# 모델 학습 및 예측
IVF_model.fit(IVF_X, IVF_y)
IVF_pred_proba = IVF_model.predict_proba(IVF_test.drop('ID', axis=1))[:, 1]

DI_model.fit(DI_X, DI_y)
DI_pred_proba = DI_model.predict_proba(DI_test.drop('ID', axis=1))[:, 1]

# %%
# 예측 결과 병합
IVF_test['probability'] = IVF_pred_proba
DI_test['probability'] = DI_pred_proba

# 최종 제출 파일 생성
submission = pd.concat([IVF_test[['ID', 'probability']], DI_test[['ID', 'probability']]], axis=0)
submission = submission.sort_values(by='ID')  

# 제출 파일 저장
submission.to_csv('./code16_submit.csv', index=False, encoding='utf-8')

# %% [markdown]
# .
