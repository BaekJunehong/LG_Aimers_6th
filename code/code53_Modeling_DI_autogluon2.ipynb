# %% [markdown]
# ## 난임 환자 대상 임신 성공 여부 예측

# %% [markdown]
# ### LGAimers 6th 온라인 해커톤

# %% [markdown]
# Import

# %%
import pandas as pd
import lightgbm as lgb
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
import lightgbm as lgb
import xgboost as xgb
from catboost import CatBoostClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ### Data Load

# %%
# 데이터 로드
DI_train = pd.read_csv('../data/DI_train_dataset_53.csv')
DI_test = pd.read_csv('../data/DI_test_dataset_53.csv')

# %% [markdown]
# ### 인코딩

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
import autogluon.core as ag

train_data = TabularDataset(DI_train)
test_data = TabularDataset(DI_test)

label = '임신_성공_여부'
eval_metric = 'roc_auc'

# %%
from autogluon.tabular import TabularPredictor

# 시간 제한 설정 
time_limit =  1 * 60 * 60

# # GPU를 사용할 수 없는 모델을 제외하도록 설정
# exclude_model_types = [
#     'KNN',  # K-Nearest Neighbors
#     'RF',   # Random Forest
#     'XT',   # Extra Trees
#     'LR',   # Linear Regression
#     'NN'    # Tabular Neural Network
# ]

# TabularPredictor 객체 생성 및 학습
predictor = TabularPredictor(
    label=label,
    eval_metric=eval_metric,
    path='AutogluonModels/ag-20250224_code53_DI'  # 모델 저장 경로
).fit(
    train_data,
    presets='best_quality',  # 'best_quality', 'medium_quality', 'good_quality' 등의 프리셋 설정
    # num_stack_levels=0,  # 스택 레벨 설정 / dynamic_stacking=True(디폴트)인 경우 무시
    num_bag_folds=5,  # 배깅 설정
    time_limit=time_limit,  # 시간 제한 설정
    # num_gpus=1,  # GPU 사용 설정
    # excluded_model_types=exclude_model_types  # 제외할 모델 유형 설정
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.11.8
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          16
# Memory Avail:       9.82 GB / 15.86 GB (61.9%)
# Disk Space Avail:   174.17 GB / 476.30 GB (36.6%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=5, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-02-25 00:37:13,695	INFO worker.py:1810 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 		Context path: "c:\Users\juneh\OneDrive\바탕 화면\git_Aimers6th\LG_Aimers_6th\code\AutogluonModels\ag-20250224_code53_DI\ds_sub_fit\sub_fit_ho"
# (_dystack pid=25896) Running DyStack sub-fit ...
# (_dystack pid=25896) Beginning AutoGluon training ... Time limit = 893s
# (_dystack pid=25896) AutoGluon will save models to "c:\Users\juneh\OneDrive\바탕 화면\git_Aimers6th\LG_Aimers_6th\code\AutogluonModels\ag-20250224_code53_DI\ds_sub_fit\sub_fit_ho"
# (_dystack pid=25896) Train Data Rows:    5592
# (_dystack pid=25896) Train Data Columns: 34
# (_dystack pid=25896) Label Column:       임신_성공_여부
# (_dystack pid=25896) Problem Type:       binary
# (_dystack pid=25896) Preprocessing data ...
# (_dystack pid=25896) Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# (_dystack pid=25896) Using Feature Generators to preprocess the data ...
# (_dystack pid=25896) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=25896) 	Available Memory:                    9517.58 MB
# (_dystack pid=25896) 	Train Data (Original)  Memory Usage: 1.78 MB (0.0% of available memory)
# (_dystack pid=25896) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=25896) 	Stage 1 Generators:
# (_dystack pid=25896) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=25896) 			Note: Converting 17 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=25896) 	Stage 2 Generators:
# (_dystack pid=25896) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=25896) 	Stage 3 Generators:
# (_dystack pid=25896) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=25896) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=25896) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=25896) 	Stage 4 Generators:
# (_dystack pid=25896) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=25896) 	Stage 5 Generators:
# (_dystack pid=25896) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=25896) 	Unused Original Features (Count: 1): ['ID']
# (_dystack pid=25896) 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# (_dystack pid=25896) 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# (_dystack pid=25896) 		These features do not need to be present at inference time.
# (_dystack pid=25896) 		('object', []) : 1 | ['ID']
# (_dystack pid=25896) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=25896) 		('float', []) :  5 | ['시술_당시_나이', '임신_시도_또는_마지막_임신_경과_연수', 'IVF_임신_시술_비율', 'DI_임신_시술_비율', '임신_성공률']
# (_dystack pid=25896) 		('int', [])   : 28 | ['배란_자극_여부', '남성_주_불임_원인', '남성_부_불임_원인', '여성_주_불임_원인', '여성_부_불임_원인', ...]
# (_dystack pid=25896) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=25896) 		('float', [])     :  5 | ['시술_당시_나이', '임신_시도_또는_마지막_임신_경과_연수', 'IVF_임신_시술_비율', 'DI_임신_시술_비율', '임신_성공률']
# (_dystack pid=25896) 		('int', [])       : 11 | ['총_시술_횟수', '클리닉_내_총_시술_횟수', 'IVF_시술_횟수', 'DI_시술_횟수', '총_임신_횟수', ...]
# (_dystack pid=25896) 		('int', ['bool']) : 17 | ['배란_자극_여부', '남성_주_불임_원인', '남성_부_불임_원인', '여성_주_불임_원인', '여성_부_불임_원인', ...]
# (_dystack pid=25896) 	0.1s = Fit runtime
# (_dystack pid=25896) 	33 features in original data used to generate 33 features in processed data.
# (_dystack pid=25896) 	Train Data (Processed) Memory Usage: 0.77 MB (0.0% of available memory)
# (_dystack pid=25896) Data preprocessing and feature engineering runtime = 0.14s ...
# (_dystack pid=25896) AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# (_dystack pid=25896) 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# (_dystack pid=25896) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=25896) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=25896) User-specified model hyperparameters to be fit:
# (_dystack pid=25896) {
# (_dystack pid=25896) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=25896) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# (_dystack pid=25896) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=25896) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=25896) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=25896) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=25896) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=25896) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=25896) }
# (_dystack pid=25896) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=25896) Fitting 110 L1 models, fit_strategy="sequential" ...
# (_dystack pid=25896) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 594.91s of the 892.58s of remaining time.
# (_dystack pid=25896) 	0.5772	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	0.0s	 = Training   runtime
# (_dystack pid=25896) 	0.12s	 = Validation runtime
# (_dystack pid=25896) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 592.78s of the 890.45s of remaining time.
# (_dystack pid=25896) 	0.5717	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	0.01s	 = Training   runtime
# (_dystack pid=25896) 	0.05s	 = Validation runtime
# (_dystack pid=25896) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 592.71s of the 890.39s of remaining time.
# (_dystack pid=25896) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.12%)
# (_dystack pid=25896) 	0.6696	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	1.06s	 = Training   runtime
# (_dystack pid=25896) 	0.01s	 = Validation runtime
# (_dystack pid=25896) Fitting model: LightGBM_BAG_L1 ... Training model for up to 588.72s of the 886.39s of remaining time.
# (_dystack pid=25896) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.13%)
# (_dystack pid=25896) 	0.6586	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	0.85s	 = Training   runtime
# (_dystack pid=25896) 	0.01s	 = Validation runtime
# (_dystack pid=25896) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 584.56s of the 882.24s of remaining time.
# (_dystack pid=25896) 	0.6072	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	0.77s	 = Training   runtime
# (_dystack pid=25896) 	0.2s	 = Validation runtime
# (_dystack pid=25896) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 583.53s of the 881.20s of remaining time.
# (_dystack pid=25896) 	0.6121	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	0.6s	 = Training   runtime
# (_dystack pid=25896) 	0.2s	 = Validation runtime
# (_dystack pid=25896) Fitting model: CatBoost_BAG_L1 ... Training model for up to 582.65s of the 880.32s of remaining time.
# (_dystack pid=25896) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.19%)
# (_dystack pid=25896) 	0.6759	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	2.46s	 = Training   runtime
# (_dystack pid=25896) 	0.01s	 = Validation runtime
# (_dystack pid=25896) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 577.28s of the 874.95s of remaining time.
# (_dystack pid=25896) 	0.6056	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	0.67s	 = Training   runtime
# (_dystack pid=25896) 	0.23s	 = Validation runtime
# (_dystack pid=25896) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 576.29s of the 873.97s of remaining time.
# (_dystack pid=25896) 	0.6067	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	0.51s	 = Training   runtime
# (_dystack pid=25896) 	0.2s	 = Validation runtime
# (_dystack pid=25896) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 575.50s of the 873.17s of remaining time.
# (_dystack pid=25896) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.10%)
# (_ray_fit pid=16652) No improvement since epoch 7: early stopping
# (_dystack pid=25896) 	0.6534	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	9.77s	 = Training   runtime
# (_dystack pid=25896) 	0.12s	 = Validation runtime
# (_dystack pid=25896) Fitting model: XGBoost_BAG_L1 ... Training model for up to 562.72s of the 860.40s of remaining time.
# (_dystack pid=25896) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.25%)
# (_dystack pid=25896) 	0.662	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	1.84s	 = Training   runtime
# (_dystack pid=25896) 	0.02s	 = Validation runtime
# (_dystack pid=25896) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 557.38s of the 855.05s of remaining time.
# (_dystack pid=25896) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.08%)
# (_ray_fit pid=19372) No improvement since epoch 8: early stopping [repeated 3x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (_dystack pid=25896) 	Warning: Exception caused NeuralNetTorch_BAG_L1 to fail during training... Skipping this model.
# (_dystack pid=25896) 		ray::_ray_fit() (pid=24392, ip=127.0.0.1)
# (_dystack pid=25896)   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
# (_dystack pid=25896)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=25896)     out = self._fit(**kwargs)
# (_dystack pid=25896)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
# (_dystack pid=25896)     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
# (_dystack pid=25896)                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
# (_dystack pid=25896)     dataset = self._process_train_data(
# (_dystack pid=25896)               ^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
# (_dystack pid=25896)     self.processor = create_preprocessor(
# (_dystack pid=25896)                      ^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
# (_dystack pid=25896)     return ColumnTransformer(
# (_dystack pid=25896)            ^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896) TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# (_dystack pid=25896) Detailed Traceback:
# (_dystack pid=25896) Traceback (most recent call last):
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 2106, in _train_and_save
# (_dystack pid=25896)     model = self._train_single(**model_fit_kwargs)
# (_dystack pid=25896)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1993, in _train_single
# (_dystack pid=25896)     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=25896)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=25896)     out = self._fit(**kwargs)
# (_dystack pid=25896)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 270, in _fit
# (_dystack pid=25896)     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
# (_dystack pid=25896)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 298, in _fit
# (_dystack pid=25896)     self._fit_folds(
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 724, in _fit_folds
# (_dystack pid=25896)     fold_fitting_strategy.after_all_folds_scheduled()
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 690, in after_all_folds_scheduled
# (_dystack pid=25896)     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 631, in _run_parallel
# (_dystack pid=25896)     self._process_fold_results(finished, unfinished, fold_ctx)
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 587, in _process_fold_results
# (_dystack pid=25896)     raise processed_exception
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 550, in _process_fold_results
# (_dystack pid=25896)     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
# (_dystack pid=25896)                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
# (_dystack pid=25896)     return fn(*args, **kwargs)
# (_dystack pid=25896)            ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
# (_dystack pid=25896)     return func(*args, **kwargs)
# (_dystack pid=25896)            ^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 2753, in get
# (_dystack pid=25896)     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
# (_dystack pid=25896)                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 904, in get_objects
# (_dystack pid=25896)     raise value.as_instanceof_cause()
# (_dystack pid=25896) ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=24392, ip=127.0.0.1)
# (_dystack pid=25896)   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
# (_dystack pid=25896)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=25896)     out = self._fit(**kwargs)
# (_dystack pid=25896)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
# (_dystack pid=25896)     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
# (_dystack pid=25896)                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
# (_dystack pid=25896)     dataset = self._process_train_data(
# (_dystack pid=25896)               ^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
# (_dystack pid=25896)     self.processor = create_preprocessor(
# (_dystack pid=25896)                      ^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
# (_dystack pid=25896)     return ColumnTransformer(
# (_dystack pid=25896)            ^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896) TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# (_dystack pid=25896) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 551.10s of the 848.77s of remaining time.
# (_dystack pid=25896) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.35%)
# (_dystack pid=25896) 	0.6395	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	1.39s	 = Training   runtime
# (_dystack pid=25896) 	0.01s	 = Validation runtime
# (_dystack pid=25896) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 546.40s of the 844.08s of remaining time.
# (_dystack pid=25896) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.22%)
# (_dystack pid=25896) 	0.6801	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	2.75s	 = Training   runtime
# (_dystack pid=25896) 	0.01s	 = Validation runtime
# (_dystack pid=25896) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 540.23s of the 837.90s of remaining time.
# (_dystack pid=25896) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.06%)
# (_dystack pid=25896) 	Warning: Exception caused NeuralNetTorch_r79_BAG_L1 to fail during training... Skipping this model.
# (_dystack pid=25896) 		ray::_ray_fit() (pid=19804, ip=127.0.0.1)
# (_dystack pid=25896)   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
# (_dystack pid=25896)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=25896)     out = self._fit(**kwargs)
# (_dystack pid=25896)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
# (_dystack pid=25896)     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
# (_dystack pid=25896)                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
# (_dystack pid=25896)     dataset = self._process_train_data(
# (_dystack pid=25896)               ^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
# (_dystack pid=25896)     self.processor = create_preprocessor(
# (_dystack pid=25896)                      ^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
# (_dystack pid=25896)     return ColumnTransformer(
# (_dystack pid=25896)            ^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896) TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# (_dystack pid=25896) Detailed Traceback:
# (_dystack pid=25896) Traceback (most recent call last):
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 2106, in _train_and_save
# (_dystack pid=25896)     model = self._train_single(**model_fit_kwargs)
# (_dystack pid=25896)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1993, in _train_single
# (_dystack pid=25896)     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=25896)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=25896)     out = self._fit(**kwargs)
# (_dystack pid=25896)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 270, in _fit
# (_dystack pid=25896)     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
# (_dystack pid=25896)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 298, in _fit
# (_dystack pid=25896)     self._fit_folds(
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 724, in _fit_folds
# (_dystack pid=25896)     fold_fitting_strategy.after_all_folds_scheduled()
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 690, in after_all_folds_scheduled
# (_dystack pid=25896)     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 631, in _run_parallel
# (_dystack pid=25896)     self._process_fold_results(finished, unfinished, fold_ctx)
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 587, in _process_fold_results
# (_dystack pid=25896)     raise processed_exception
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 550, in _process_fold_results
# (_dystack pid=25896)     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
# (_dystack pid=25896)                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
# (_dystack pid=25896)     return fn(*args, **kwargs)
# (_dystack pid=25896)            ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
# (_dystack pid=25896)     return func(*args, **kwargs)
# (_dystack pid=25896)            ^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 2753, in get
# (_dystack pid=25896)     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
# (_dystack pid=25896)                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 904, in get_objects
# (_dystack pid=25896)     raise value.as_instanceof_cause()
# (_dystack pid=25896) ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=19804, ip=127.0.0.1)
# (_dystack pid=25896)   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
# (_dystack pid=25896)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=25896)     out = self._fit(**kwargs)
# (_dystack pid=25896)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
# (_dystack pid=25896)     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
# (_dystack pid=25896)                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
# (_dystack pid=25896)     dataset = self._process_train_data(
# (_dystack pid=25896)               ^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
# (_dystack pid=25896)     self.processor = create_preprocessor(
# (_dystack pid=25896)                      ^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
# (_dystack pid=25896)     return ColumnTransformer(
# (_dystack pid=25896)            ^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896) TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# (_dystack pid=25896) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=25896) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=25896) Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 534.04s of the 831.71s of remaining time.
# (_dystack pid=25896) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.19%)
# (_dystack pid=25896) 	0.6566	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	1.58s	 = Training   runtime
# (_dystack pid=25896) 	0.01s	 = Validation runtime
# (_dystack pid=25896) Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 529.22s of the 826.89s of remaining time.
# (_dystack pid=25896) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.12%)
# (_ray_fit pid=5424) No improvement since epoch 6: early stopping
# (_dystack pid=25896) 	0.648	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	22.08s	 = Training   runtime
# (_dystack pid=25896) 	0.21s	 = Validation runtime
# (_dystack pid=25896) Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 503.74s of the 801.42s of remaining time.
# (_dystack pid=25896) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.69%)
# (_dystack pid=25896) 	0.6709	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	6.21s	 = Training   runtime
# (_dystack pid=25896) 	0.01s	 = Validation runtime
# (_dystack pid=25896) Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 494.40s of the 792.07s of remaining time.
# (_dystack pid=25896) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.11%)
# (_ray_fit pid=21368) No improvement since epoch 20: early stopping [repeated 4x across cluster]
# (_dystack pid=25896) 	0.6718	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	1.14s	 = Training   runtime
# (_dystack pid=25896) 	0.06s	 = Validation runtime
# (_dystack pid=25896) Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 490.01s of the 787.68s of remaining time.
# (_dystack pid=25896) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.07%)
# (_dystack pid=25896) 	Warning: Exception caused NeuralNetTorch_r22_BAG_L1 to fail during training... Skipping this model.
# (_dystack pid=25896) 		ray::_ray_fit() (pid=20112, ip=127.0.0.1)
# (_dystack pid=25896)   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
# (_dystack pid=25896)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=25896)     out = self._fit(**kwargs)
# (_dystack pid=25896)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
# (_dystack pid=25896)     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
# (_dystack pid=25896)                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
# (_dystack pid=25896)     dataset = self._process_train_data(
# (_dystack pid=25896)               ^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
# (_dystack pid=25896)     self.processor = create_preprocessor(
# (_dystack pid=25896)                      ^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
# (_dystack pid=25896)     return ColumnTransformer(
# (_dystack pid=25896)            ^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896) TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# (_dystack pid=25896) Detailed Traceback:
# (_dystack pid=25896) Traceback (most recent call last):
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 2106, in _train_and_save
# (_dystack pid=25896)     model = self._train_single(**model_fit_kwargs)
# (_dystack pid=25896)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1993, in _train_single
# (_dystack pid=25896)     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=25896)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=25896)     out = self._fit(**kwargs)
# (_dystack pid=25896)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 270, in _fit
# (_dystack pid=25896)     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
# (_dystack pid=25896)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 298, in _fit
# (_dystack pid=25896)     self._fit_folds(
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 724, in _fit_folds
# (_dystack pid=25896)     fold_fitting_strategy.after_all_folds_scheduled()
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 690, in after_all_folds_scheduled
# (_dystack pid=25896)     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 631, in _run_parallel
# (_dystack pid=25896)     self._process_fold_results(finished, unfinished, fold_ctx)
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 587, in _process_fold_results
# (_dystack pid=25896)     raise processed_exception
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 550, in _process_fold_results
# (_dystack pid=25896)     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
# (_dystack pid=25896)                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
# (_dystack pid=25896)     return fn(*args, **kwargs)
# (_dystack pid=25896)            ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
# (_dystack pid=25896)     return func(*args, **kwargs)
# (_dystack pid=25896)            ^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 2753, in get
# (_dystack pid=25896)     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
# (_dystack pid=25896)                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 904, in get_objects
# (_dystack pid=25896)     raise value.as_instanceof_cause()
# (_dystack pid=25896) ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=20112, ip=127.0.0.1)
# (_dystack pid=25896)   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
# (_dystack pid=25896)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=25896)     out = self._fit(**kwargs)
# (_dystack pid=25896)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
# (_dystack pid=25896)     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
# (_dystack pid=25896)                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
# (_dystack pid=25896)     dataset = self._process_train_data(
# (_dystack pid=25896)               ^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
# (_dystack pid=25896)     self.processor = create_preprocessor(
# (_dystack pid=25896)                      ^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
# (_dystack pid=25896)     return ColumnTransformer(
# (_dystack pid=25896)            ^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896) TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# (_dystack pid=25896) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=25896) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=25896) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=25896) Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 483.81s of the 781.48s of remaining time.
# (_dystack pid=25896) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=1.41%)
# (_dystack pid=25896) 	0.6406	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	2.72s	 = Training   runtime
# (_dystack pid=25896) 	0.06s	 = Validation runtime
# (_dystack pid=25896) Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 477.70s of the 775.37s of remaining time.
# (_dystack pid=25896) 	0.6045	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	0.87s	 = Training   runtime
# (_dystack pid=25896) 	0.24s	 = Validation runtime
# (_dystack pid=25896) Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 476.48s of the 774.15s of remaining time.
# (_dystack pid=25896) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.11%)
# (_dystack pid=25896) 	0.6825	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	2.57s	 = Training   runtime
# (_dystack pid=25896) 	0.02s	 = Validation runtime
# (_dystack pid=25896) Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 470.65s of the 768.33s of remaining time.
# (_dystack pid=25896) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.13%)
# (_dystack pid=25896) 	0.658	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	6.0s	 = Training   runtime
# (_dystack pid=25896) 	0.06s	 = Validation runtime
# (_dystack pid=25896) Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 460.96s of the 758.63s of remaining time.
# (_ray_fit pid=4328) No improvement since epoch 8: early stopping
# (_dystack pid=25896) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.86%)
# (_dystack pid=25896) 	0.6742	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	5.45s	 = Training   runtime
# (_dystack pid=25896) 	0.01s	 = Validation runtime
# (_dystack pid=25896) Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 451.62s of the 749.29s of remaining time.
# (_dystack pid=25896) 	0.6147	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	0.83s	 = Training   runtime
# (_dystack pid=25896) 	0.18s	 = Validation runtime
# (_dystack pid=25896) Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 450.52s of the 748.19s of remaining time.
# (_dystack pid=25896) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.38%)
# ...
# (_dystack pid=25896)     self._process_fold_results(finished, unfinished, fold_ctx)
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 587, in _process_fold_results
# (_dystack pid=25896)     raise processed_exception
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 550, in _process_fold_results
# (_dystack pid=25896)     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
# (_dystack pid=25896)                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
# (_dystack pid=25896)     return fn(*args, **kwargs)
# (_dystack pid=25896)            ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
# (_dystack pid=25896)     return func(*args, **kwargs)
# (_dystack pid=25896)            ^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 2753, in get
# (_dystack pid=25896)     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
# (_dystack pid=25896)                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 904, in get_objects
# (_dystack pid=25896)     raise value.as_instanceof_cause()
# (_dystack pid=25896) ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=17832, ip=127.0.0.1)
# (_dystack pid=25896)   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
# (_dystack pid=25896)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=25896)     out = self._fit(**kwargs)
# (_dystack pid=25896)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
# (_dystack pid=25896)     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
# (_dystack pid=25896)                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
# (_dystack pid=25896)     dataset = self._process_train_data(
# (_dystack pid=25896)               ^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
# (_dystack pid=25896)     self.processor = create_preprocessor(
# (_dystack pid=25896)                      ^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
# (_dystack pid=25896)     return ColumnTransformer(
# (_dystack pid=25896)            ^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896) TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# (_dystack pid=25896) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=25896) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=25896) Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 413.35s of the 711.02s of remaining time.
# (_dystack pid=25896) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.32%)
# (_dystack pid=25896) 	0.6585	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	0.82s	 = Training   runtime
# (_dystack pid=25896) 	0.01s	 = Validation runtime
# (_dystack pid=25896) Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 409.32s of the 706.99s of remaining time.
# (_dystack pid=25896) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.08%)
# (_dystack pid=25896) 	Warning: Exception caused NeuralNetTorch_r86_BAG_L1 to fail during training... Skipping this model.
# (_dystack pid=25896) 		ray::_ray_fit() (pid=11956, ip=127.0.0.1)
# (_dystack pid=25896)   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
# (_dystack pid=25896)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=25896)     out = self._fit(**kwargs)
# (_dystack pid=25896)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
# (_dystack pid=25896)     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
# (_dystack pid=25896)                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
# (_dystack pid=25896)     dataset = self._process_train_data(
# (_dystack pid=25896)               ^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
# (_dystack pid=25896)     self.processor = create_preprocessor(
# (_dystack pid=25896)                      ^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
# (_dystack pid=25896)     return ColumnTransformer(
# (_dystack pid=25896)            ^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896) TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# (_dystack pid=25896) Detailed Traceback:
# (_dystack pid=25896) Traceback (most recent call last):
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 2106, in _train_and_save
# (_dystack pid=25896)     model = self._train_single(**model_fit_kwargs)
# (_dystack pid=25896)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1993, in _train_single
# (_dystack pid=25896)     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=25896)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=25896)     out = self._fit(**kwargs)
# (_dystack pid=25896)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 270, in _fit
# (_dystack pid=25896)     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
# (_dystack pid=25896)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 298, in _fit
# (_dystack pid=25896)     self._fit_folds(
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 724, in _fit_folds
# (_dystack pid=25896)     fold_fitting_strategy.after_all_folds_scheduled()
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 690, in after_all_folds_scheduled
# (_dystack pid=25896)     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 631, in _run_parallel
# (_dystack pid=25896)     self._process_fold_results(finished, unfinished, fold_ctx)
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 587, in _process_fold_results
# (_dystack pid=25896)     raise processed_exception
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 550, in _process_fold_results
# (_dystack pid=25896)     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
# (_dystack pid=25896)                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
# (_dystack pid=25896)     return fn(*args, **kwargs)
# (_dystack pid=25896)            ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
# (_dystack pid=25896)     return func(*args, **kwargs)
# (_dystack pid=25896)            ^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 2753, in get
# (_dystack pid=25896)     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
# (_dystack pid=25896)                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 904, in get_objects
# (_dystack pid=25896)     raise value.as_instanceof_cause()
# (_dystack pid=25896) ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=11956, ip=127.0.0.1)
# (_dystack pid=25896)   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
# (_dystack pid=25896)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=25896)     out = self._fit(**kwargs)
# (_dystack pid=25896)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
# (_dystack pid=25896)     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
# (_dystack pid=25896)                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
# (_dystack pid=25896)     dataset = self._process_train_data(
# (_dystack pid=25896)               ^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
# (_dystack pid=25896)     self.processor = create_preprocessor(
# (_dystack pid=25896)                      ^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
# (_dystack pid=25896)     return ColumnTransformer(
# (_dystack pid=25896)            ^^^^^^^^^^^^^^^^^^
# (_dystack pid=25896) TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# (_dystack pid=25896) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=25896) Fitting model: CatBoost_r50_BAG_L1 ... Training model for up to 403.27s of the 700.95s of remaining time.
# (_dystack pid=25896) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.14%)
# (_dystack pid=25896) 	0.679	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	2.5s	 = Training   runtime
# (_dystack pid=25896) 	0.0s	 = Validation runtime
# (_dystack pid=25896) Fitting model: NeuralNetFastAI_r11_BAG_L1 ... Training model for up to 397.62s of the 695.30s of remaining time.
# (_dystack pid=25896) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.17%)
# (_ray_fit pid=23660) No improvement since epoch 10: early stopping
# (_dystack pid=25896) 	0.6628	 = Validation score   (roc_auc)
# (_dystack pid=25896) 	27.37s	 = Training   runtime
# (_dystack pid=25896) 	0.25s	 = Validation runtime
# (_dystack pid=25896) Fitting model: XGBoost_r194_BAG_L1 ... Training model for up to 366.74s of the 664.41s of remaining time.
# (_dystack pid=25896) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.69%)

# %%
print(predictor.leaderboard(silent = True))
# Out:
#                           model  score_val eval_metric  pred_time_val  \
# 0           WeightedEnsemble_L3   0.725367     roc_auc       3.127192
# 1         ExtraTreesEntr_BAG_L2   0.718222     roc_auc       2.656744
# 2         ExtraTreesGini_BAG_L2   0.708253     roc_auc       2.667659
# 3            CatBoost_r9_BAG_L2   0.700075     roc_auc       2.476366
# 4             LightGBMXT_BAG_L2   0.699705     roc_auc       2.474246
# 5               CatBoost_BAG_L2   0.698803     roc_auc       2.455585
# 6           WeightedEnsemble_L2   0.690819     roc_auc       0.462723
# 7          CatBoost_r177_BAG_L2   0.689251     roc_auc       2.470236
# 8          CatBoost_r137_BAG_L1   0.687894     roc_auc       0.017632
# 9           CatBoost_r50_BAG_L1   0.686979     roc_auc       0.036760
# 10          LightGBM_r96_BAG_L2   0.686639     roc_auc       2.502582
# 11      RandomForestEntr_BAG_L2   0.686125     roc_auc       2.676092
# 12              CatBoost_BAG_L1   0.685897     roc_auc       0.018174
# 13          CatBoost_r13_BAG_L1   0.685120     roc_auc       0.017078
# 14         LightGBM_r131_BAG_L2   0.685119     roc_auc       2.464825
# 15              LightGBM_BAG_L2   0.683527     roc_auc       2.462040
# 16         CatBoost_r177_BAG_L1   0.683437     roc_auc       0.015626
# 17          CatBoost_r69_BAG_L1   0.682186     roc_auc       0.020379
# 18          CatBoost_r70_BAG_L1   0.681395     roc_auc       0.020897
# 19           CatBoost_r9_BAG_L1   0.680524     roc_auc       0.006552
# 20      RandomForestGini_BAG_L2   0.679538     roc_auc       2.656215
# 21          LightGBM_r96_BAG_L1   0.679136     roc_auc       0.046887
# 22              LightGBM_BAG_L1   0.676844     roc_auc       0.031783
# 23            LightGBMXT_BAG_L1   0.675480     roc_auc       0.007897
# 24           XGBoost_r89_BAG_L1   0.675129     roc_auc       0.015506
# 25  NeuralNetFastAI_r143_BAG_L1   0.675020     roc_auc       0.097995
# 26         LightGBM_r130_BAG_L1   0.674602     roc_auc       0.000000
# 27         LightGBM_r131_BAG_L1   0.672927     roc_auc       0.015626
# 28   NeuralNetFastAI_r11_BAG_L1   0.672852     roc_auc       0.287135
# 29               XGBoost_BAG_L1   0.672322     roc_auc       0.000000
# 30         LightGBMLarge_BAG_L2   0.672142     roc_auc       2.448641
# 31  NeuralNetFastAI_r191_BAG_L2   0.671418     roc_auc       2.666785
# 32          XGBoost_r194_BAG_L1   0.665165     roc_auc       0.067449
# 33  NeuralNetFastAI_r103_BAG_L1   0.664316     roc_auc       0.121196
# 34       NeuralNetFastAI_BAG_L2   0.663764     roc_auc       2.575482
# 35         LightGBM_r188_BAG_L1   0.656620     roc_auc       0.031268
# 36         LightGBMLarge_BAG_L1   0.655701     roc_auc       0.033294
# 37       ExtraTrees_r172_BAG_L1   0.654999     roc_auc       0.273572
# 38         LightGBM_r161_BAG_L1   0.651598     roc_auc       0.053154
# 39       NeuralNetFastAI_BAG_L1   0.648211     roc_auc       0.119833
# 40  NeuralNetFastAI_r145_BAG_L1   0.647058     roc_auc       0.166215
# 41               XGBoost_BAG_L2   0.638904     roc_auc       2.499801
# 42  NeuralNetFastAI_r191_BAG_L1   0.637791     roc_auc       0.186792
# 43  NeuralNetFastAI_r102_BAG_L1   0.635994     roc_auc       0.066770
# 44      RandomForestEntr_BAG_L1   0.634897     roc_auc       0.199933
# 45     RandomForest_r195_BAG_L1   0.631557     roc_auc       0.234785
# 46      RandomForestGini_BAG_L1   0.630684     roc_auc       0.206629
# 47        ExtraTrees_r42_BAG_L1   0.628988     roc_auc       0.256254
# 48        ExtraTreesGini_BAG_L1   0.626972     roc_auc       0.213809
# 49        ExtraTreesEntr_BAG_L1   0.624904     roc_auc       0.202573
# 50           XGBoost_r33_BAG_L2   0.610240     roc_auc       2.512896
# 51           XGBoost_r33_BAG_L1   0.584686     roc_auc       0.030550
# 52        KNeighborsUnif_BAG_L1   0.575343     roc_auc       0.257155
# 53        KNeighborsDist_BAG_L1   0.573841     roc_auc       0.055864
#
#       fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0   119.149461                0.001000           0.461098            3
# 1    90.926901                0.210329           0.611200            2
# 2    91.044171                0.221245           0.728470            2
# 3   114.075665                0.029952          23.759964            2
# 4    93.233000                0.027832           2.917299            2
# 5    97.899597                0.009170           7.583896            2
# 6    59.580088                0.000000           0.362496            2
# 7    97.290854                0.023821           6.975152            2
# 8     4.221373                0.017632           4.221373            1
# 9     4.098523                0.036760           4.098523            1
# 10   93.484859                0.056168           3.169157            2
# 11   91.354152                0.229678           1.038450            2
# 12    4.443961                0.018174           4.443961            1
# 13    7.398367                0.017078           7.398367            1
# 14   93.767988                0.018410           3.452287            2
# 15   93.029063                0.015626           2.713362            2
# 16    4.097918                0.015626           4.097918            1
# 17    4.151901                0.020379           4.151901            1
# 18    5.514240                0.020897           5.514240            1
# 19    8.287330                0.006552           8.287330            1
# 20   91.226251                0.209801           0.910549            2
# 21    2.502217                0.046887           2.502217            1
# 22    1.959680                0.031783           1.959680            1
# 23    1.211126                0.007897           1.211126            1
# 24    3.142190                0.015506           3.142190            1
# 25    9.409786                0.097995           9.409786            1
# 26    2.357283                0.000000           2.357283            1
# 27    2.638342                0.015626           2.638342            1
# 28   30.588433                0.287135          30.588433            1
# 29    3.428654                0.000000           3.428654            1
# 30   95.209882                0.002227           4.894181            2
# 31  114.431394                0.220371          24.115693            2
# 32    3.407973                0.067449           3.407973            1
# 33   16.880608                0.121196          16.880608            1
# 34  102.099071                0.129067          11.783370            2
# 35    2.633979                0.031268           2.633979            1
# 36    2.342480                0.033294           2.342480            1
# 37    0.920293                0.273572           0.920293            1
# 38    3.785657                0.053154           3.785657            1
# 39   11.750417                0.119833          11.750417            1
# 40   20.907492                0.166215          20.907492            1
# 41   92.983222                0.053386           2.667521            2
# 42   24.768458                0.186792          24.768458            1
# 43    7.550277                0.066770           7.550277            1
# 44    0.602863                0.199933           0.602863            1
# 45    0.991062                0.234785           0.991062            1
# 46    0.777361                0.206629           0.777361            1
# 47    1.041957                0.256254           1.041957            1
# 48    0.667218                0.213809           0.667218            1
# 49    0.603021                0.202573           0.603021            1
# 50   93.617747                0.066482           3.302046            2
# 51    2.615635                0.030550           2.615635            1
# 52    0.013624                0.257155           0.013624            1
# 53    0.006797                0.055864           0.006797            1
#
#     can_infer  fit_order
# 0        True         54
# 1        True         44
# 2        True         43
# 3        True         51
# 4        True         38
# 5        True         42
# 6        True         37
# 7        True         48
# 8        True         20
# 9        True         28
# 10       True         52
# 11       True         41
# 12       True          7
# 13       True         22
# 14       True         49
# 15       True         39
# 16       True         13
# 17       True         32
# 18       True         36
# 19       True         16
# 20       True         40
# 21       True         17
# 22       True          4
# 23       True          3
# 24       True         26
# 25       True         35
# 26       True         27
# 27       True         14
# 28       True         29
# 29       True         11
# 30       True         47
# 31       True         50
# 32       True         30
# 33       True         33
# 34       True         45
# 35       True         24
# 36       True         12
# 37       True         31
# 38       True         34
# 39       True         10
# 40       True         25
# 41       True         46
# 42       True         15
# 43       True         21
# 44       True          6
# 45       True         23
# 46       True          5
# 47       True         19
# 48       True          8
# 49       True          9
# 50       True         53
# 51       True         18
# 52       True          1
# 53       True          2

# %%
# predictor.feature_importance(train_data)

# %%
# 최적의 모델 가져오기
model_to_use = predictor.model_best

# 확률 예측
prob_predictions = predictor.predict_proba(test_data, model=model_to_use)

# %%
# 예측 결과를 test_data에 추가
test_data['probability'] = prob_predictions.iloc[:, 1]

# 최종 제출 파일 생성
submission = test_data[['ID', 'probability']]
submission = submission.sort_values(by='ID')

# 제출 파일 저장
submission.to_csv('../submission/code53_DI_lgbm2.csv', index=False, encoding='utf-8')

# 예측 결과 확인
print(submission.head())
# Out:
#            ID  probability
# 0  TEST_00026     0.083821
# 1  TEST_00051     0.204894
# 2  TEST_00076     0.011036
# 3  TEST_00088     0.153002
# 4  TEST_00100     0.100460

# %%
import pandas as pd

# 첫 번째 제출 파일 읽기
submission_ivf = pd.read_csv('../submission/code53_IVF_lgbm2.csv')
submission_di = pd.read_csv('../submission/code53_DI_lgbm2.csv')

# 두 데이터프레임 병합 (ID를 기준으로)
merged_submission = pd.concat([submission_ivf, submission_di]).sort_values(by='ID')

# 병합된 데이터프레임 저장
merged_submission.to_csv('../submission/code53_merged_lgbm2.csv', index=False, encoding='utf-8')

# 예측 결과 확인
print(merged_submission.head())
# Out:
#            ID  probability
# 0  TEST_00000     0.001556
# 1  TEST_00001     0.002249
# 2  TEST_00002     0.151962
# 3  TEST_00003     0.103942
# 4  TEST_00004     0.512530
# 2025-02-24 21:47:51,578	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-02-24 21:47:51,581	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-02-24 21:49:03,187	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-02-24 21:49:12,469	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-02-24 21:49:12,469	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-02-24 21:50:28,962	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-02-24 21:50:28,962	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-02-24 21:50:28,962	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.

# %% [markdown]
# 데이콘 PUBLIC xx

# %% [markdown]
# ----

# %% [markdown]
# .
