# %% [markdown]
# ## 난임 환자 대상 임신 성공 여부 예측

# %% [markdown]
# ### LGAimers 6th 온라인 해커톤

# %% [markdown]
# Import

# %%
import pandas as pd
import lightgbm as lgb
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### Data Load

# %%
# 데이터 로드
IVF_train = pd.read_csv('../data/IVF_train_dataset.csv')
IVF_test = pd.read_csv('../data/IVF_test_dataset.csv')

DI_train = pd.read_csv('../data/DI_train_dataset.csv')
DI_test = pd.read_csv('../data/DI_test_dataset.csv')

# %%
# ID 열을 제외한 특성과 타겟 변수 분리
IVF_X = IVF_train.drop(['임신_성공_여부', 'ID'], axis=1)
IVF_y = IVF_train['임신_성공_여부']

DI_X = DI_train.drop(['임신_성공_여부', 'ID'], axis=1)
DI_y = DI_train['임신_성공_여부']

# %% [markdown]
# ### 인코딩

# %%
IVF_categorical_columns = [
    "시술_시기_코드",
    "시술_당시_나이",
    "임신_시도_또는_마지막_임신_경과_연수",
    "배란_유도_유형",
    "착상_전_유전_검사_사용_여부",
    "남성_주_불임_원인",
    "남성_부_불임_원인",
    "여성_주_불임_원인",
    "여성_부_불임_원인",
    "부부_주_불임_원인",
    "부부_부_불임_원인",
    "불명확_불임_원인",
    "불임_원인_-_난관_질환",
    "불임_원인_-_남성_요인",
    "불임_원인_-_배란_장애",
    "불임_원인_-_여성_요인",
    "불임_원인_-_자궁경부_문제",
    "불임_원인_-_자궁내막증",
    "불임_원인_-_정자_농도",
    "불임_원인_-_정자_면역학적_요인",
    "불임_원인_-_정자_운동성",
    "불임_원인_-_정자_형태",
    "총_시술_횟수",
    "클리닉_내_총_시술_횟수",
    "IVF_시술_횟수",
    "DI_시술_횟수",
    "총_임신_횟수",
    "IVF_임신_횟수",
    "DI_임신_횟수",
    "총_출산_횟수",
    "IVF_출산_횟수",
    "DI_출산_횟수",
    "난자_출처",
    "정자_출처",
    "난자_기증자_나이",
    "정자_기증자_나이",
    "PGD_시술_여부",
    "PGS_시술_여부",
    "난자_채취_경과일",
    "난자_해동_경과일",
    "난자_혼합_경과일",
    "배아_이식_경과일",
    "배아_해동_경과일",
    "변환된_특정_시술_유형"
]

# %%
DI_categorical_columns = [
    "시술_시기_코드",
    "시술_당시_나이",
    "임신_시도_또는_마지막_임신_경과_연수",
    "총_시술_횟수",
    "클리닉_내_총_시술_횟수",
    "IVF_시술_횟수",
    "DI_시술_횟수",
    "총_임신_횟수",
    "IVF_임신_횟수",
    "DI_임신_횟수",
    "총_출산_횟수",
    "IVF_출산_횟수",
    "DI_출산_횟수",
    "정자_기증자_나이",
    "변환된_특정_시술_유형"
]

# %%
# 모든 범주형 변수를 문자열로 변환
IVF_X[IVF_categorical_columns] = IVF_X[IVF_categorical_columns].astype(str)
DI_X[DI_categorical_columns] = DI_X[DI_categorical_columns].astype(str)
IVF_test[IVF_categorical_columns] = IVF_test[IVF_categorical_columns].astype(str)
DI_test[DI_categorical_columns] = DI_test[DI_categorical_columns].astype(str)

# OrdinalEncoder를 사용하여 범주형 변수 인코딩
IVF_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
DI_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

IVF_X[IVF_categorical_columns] = IVF_encoder.fit_transform(IVF_X[IVF_categorical_columns])
DI_X[DI_categorical_columns] = DI_encoder.fit_transform(DI_X[DI_categorical_columns])
IVF_test[IVF_categorical_columns] = IVF_encoder.transform(IVF_test[IVF_categorical_columns])
DI_test[DI_categorical_columns] = DI_encoder.transform(DI_test[DI_categorical_columns])

# %%
# import category_encoders as ce

# # 모든 범주형 변수를 문자열로 변환
# IVF_X[IVF_categorical_columns] = IVF_X[IVF_categorical_columns].astype(str)
# DI_X[DI_categorical_columns] = DI_X[DI_categorical_columns].astype(str)
# IVF_test[IVF_categorical_columns] = IVF_test[IVF_categorical_columns].astype(str)
# DI_test[DI_categorical_columns] = DI_test[DI_categorical_columns].astype(str)

# # 타겟 인코더를 사용하여 범주형 변수 인코딩
# IVF_target_encoder = ce.TargetEncoder(cols=IVF_categorical_columns)
# DI_target_encoder = ce.TargetEncoder(cols=DI_categorical_columns)

# # 타겟 인코딩을 위해 타겟 변수가 필요합니다. 예시로 IVF_y와 DI_y를 사용합니다.
# IVF_X[IVF_categorical_columns] = IVF_target_encoder.fit_transform(IVF_X[IVF_categorical_columns], IVF_y)
# DI_X[DI_categorical_columns] = DI_target_encoder.fit_transform(DI_X[DI_categorical_columns], DI_y)
# IVF_test[IVF_categorical_columns] = IVF_target_encoder.transform(IVF_test[IVF_categorical_columns])
# DI_test[DI_categorical_columns] = DI_target_encoder.transform(DI_test[DI_categorical_columns])

# %% [markdown]
# ## Modeling

# %%
# 데이터 분할
IVF_X_train, IVF_X_test, IVF_y_train, IVF_y_test = train_test_split(IVF_X, IVF_y, test_size=0.2, random_state=42)
DI_X_train, DI_X_test, DI_y_train, DI_y_test = train_test_split(DI_X, DI_y, test_size=0.2, random_state=42)

# %% [markdown]
# ### DI 데이터

# %%
import optuna
import lightgbm as lgb
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
import optuna
import lightgbm as lgb
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# 목적 함수 정의
def objective(trial):
    param = {
        'objective': 'binary',
        'metric': 'auc',
        'verbose': -1,
        'boosting_type': 'gbdt',
        'n_estimators': trial.suggest_int('n_estimators', 100, 3000),
        'num_leaves': trial.suggest_int('num_leaves', 10, 2048),
        'max_depth': trial.suggest_int('max_depth', 5, 200),
        'learning_rate': trial.suggest_float('learning_rate', 1e-5, 1e-1, log=True),
        'min_child_samples': trial.suggest_int('min_child_samples', 1, 200),
        'subsample': trial.suggest_float('subsample', 0.1, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.1, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-5, 1e2, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-5, 1e2, log=True),
        'min_split_gain': trial.suggest_float('min_split_gain', 1e-5, 1e1, log=True),
        'random_state': 42,
    }

    model = lgb.LGBMClassifier(**param)
    model.fit(DI_X_train, DI_y_train, eval_set=[(DI_X_test, DI_y_test)])
    
    y_pred_proba = model.predict_proba(DI_X_test)[:, 1]
    auc = roc_auc_score(DI_y_test, y_pred_proba)
    
    return auc

# Optuna 스터디 생성 및 최적화
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=800)

# 최적의 하이퍼파라미터 출력
print("Best trial:")
trial = study.best_trial
print("  Value: {}".format(trial.value))
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))

# 최적의 하이퍼파라미터로 모델 학습
best_params = trial.params
DI_model = lgb.LGBMClassifier(**best_params)
DI_model.fit(DI_X_train, DI_y_train)

# 예측
y_pred = DI_model.predict(DI_X_test)
y_pred_proba = DI_model.predict_proba(DI_X_test)[:, 1]

# 평가
accuracy = accuracy_score(DI_y_test, y_pred)
f1 = f1_score(DI_y_test, y_pred)
auc = roc_auc_score(DI_y_test, y_pred_proba)
cm = confusion_matrix(DI_y_test, y_pred)

# 결과 출력
print()
print("--- Model Performance ---")
print(f"Model Accuracy: {accuracy}")
print(f"Model F1 Score: {f1}")
print(f"Model AUC: {auc}")

# 혼동 행렬 출력
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=DI_model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# [I 2025-02-03 18:17:48,226] A new study created in memory with name: no-name-37b45ef3-01be-48e1-af8c-1a41a462ef23
# [I 2025-02-03 18:17:50,514] Trial 0 finished with value: 0.661697247706422 and parameters: {'n_estimators': 1391, 'num_leaves': 110, 'max_depth': 27, 'learning_rate': 0.001732951285957403, 'min_child_samples': 10, 'subsample': 0.146436812909073, 'colsample_bytree': 0.20753439465675652, 'reg_alpha': 0.22321981682633252, 'reg_lambda': 2.3101565562511053e-05, 'min_split_gain': 0.00015293901484663075}. Best is trial 0 with value: 0.661697247706422.
# [I 2025-02-03 18:17:52,555] Trial 1 finished with value: 0.6828527741371777 and parameters: {'n_estimators': 1523, 'num_leaves': 1829, 'max_depth': 61, 'learning_rate': 0.002871257024944965, 'min_child_samples': 51, 'subsample': 0.33927841028133754, 'colsample_bytree': 0.10811427993082742, 'reg_alpha': 0.0912505260963746, 'reg_lambda': 0.06838418165623614, 'min_split_gain': 1.2623983040547008e-05}. Best is trial 1 with value: 0.6828527741371777.
# [I 2025-02-03 18:17:54,730] Trial 2 finished with value: 0.690885757972914 and parameters: {'n_estimators': 1451, 'num_leaves': 687, 'max_depth': 22, 'learning_rate': 4.319907525817224e-05, 'min_child_samples': 126, 'subsample': 0.751272879494992, 'colsample_bytree': 0.5824988938126702, 'reg_alpha': 0.23141820219487866, 'reg_lambda': 0.08958123474666291, 'min_split_gain': 0.0005270103990787578}. Best is trial 2 with value: 0.690885757972914.
# [I 2025-02-03 18:17:55,613] Trial 3 finished with value: 0.6916775884665792 and parameters: {'n_estimators': 453, 'num_leaves': 1144, 'max_depth': 90, 'learning_rate': 0.005838173663424107, 'min_child_samples': 107, 'subsample': 0.7561650287525399, 'colsample_bytree': 0.7767174163170819, 'reg_alpha': 0.011004947816397947, 'reg_lambda': 3.340772809469406e-05, 'min_split_gain': 7.76323513646994e-05}. Best is trial 3 with value: 0.6916775884665792.
# [I 2025-02-03 18:17:56,788] Trial 4 finished with value: 0.6665164919178681 and parameters: {'n_estimators': 1000, 'num_leaves': 569, 'max_depth': 40, 'learning_rate': 0.0003231090827939951, 'min_child_samples': 109, 'subsample': 0.8366884427501567, 'colsample_bytree': 0.9602756010545441, 'reg_alpha': 37.174225972262555, 'reg_lambda': 0.061527430961296134, 'min_split_gain': 0.00020348530743601387}. Best is trial 3 with value: 0.6916775884665792.
# [I 2025-02-03 18:17:58,883] Trial 5 finished with value: 0.7052861511577108 and parameters: {'n_estimators': 1954, 'num_leaves': 87, 'max_depth': 133, 'learning_rate': 0.06627802472506875, 'min_child_samples': 87, 'subsample': 0.827604133648514, 'colsample_bytree': 0.3844710282221656, 'reg_alpha': 13.879608940396066, 'reg_lambda': 0.6678262082358717, 'min_split_gain': 0.0006151543666879212}. Best is trial 5 with value: 0.7052861511577108.
# [I 2025-02-03 18:18:02,625] Trial 6 finished with value: 0.6957814547837483 and parameters: {'n_estimators': 2556, 'num_leaves': 1573, 'max_depth': 67, 'learning_rate': 5.150404795844028e-05, 'min_child_samples': 199, 'subsample': 0.7950909357063615, 'colsample_bytree': 0.9123697084945781, 'reg_alpha': 0.08814136691781213, 'reg_lambda': 1.972123073812352, 'min_split_gain': 0.25364761547312253}. Best is trial 5 with value: 0.7052861511577108.
# [I 2025-02-03 18:18:06,136] Trial 7 finished with value: 0.6816459152468326 and parameters: {'n_estimators': 2717, 'num_leaves': 72, 'max_depth': 49, 'learning_rate': 0.012721641782036962, 'min_child_samples': 7, 'subsample': 0.1514732058194051, 'colsample_bytree': 0.4174213418299171, 'reg_alpha': 1.0932622532437248, 'reg_lambda': 3.1633280476711323, 'min_split_gain': 0.004671206459428548}. Best is trial 5 with value: 0.7052861511577108.
# [I 2025-02-03 18:18:08,647] Trial 8 finished with value: 0.6834125163826998 and parameters: {'n_estimators': 1888, 'num_leaves': 1830, 'max_depth': 164, 'learning_rate': 2.6464824531036536e-05, 'min_child_samples': 150, 'subsample': 0.2974036273612609, 'colsample_bytree': 0.6925911826699321, 'reg_alpha': 0.001456416020029204, 'reg_lambda': 85.04105694144359, 'min_split_gain': 4.956287314201301e-05}. Best is trial 5 with value: 0.7052861511577108.
# [I 2025-02-03 18:18:10,763] Trial 9 finished with value: 0.6964231105286152 and parameters: {'n_estimators': 1527, 'num_leaves': 343, 'max_depth': 56, 'learning_rate': 2.3745260519168833e-05, 'min_child_samples': 175, 'subsample': 0.48825486335510404, 'colsample_bytree': 0.724749074678925, 'reg_alpha': 0.0007091477730049635, 'reg_lambda': 0.00013255030114882338, 'min_split_gain': 0.15780375762676602}. Best is trial 5 with value: 0.7052861511577108.
# [I 2025-02-03 18:18:13,243] Trial 10 finished with value: 0.7006498470948013 and parameters: {'n_estimators': 2182, 'num_leaves': 1145, 'max_depth': 154, 'learning_rate': 0.06558600860069486, 'min_child_samples': 61, 'subsample': 0.9625597986799024, 'colsample_bytree': 0.3739484663395072, 'reg_alpha': 1.3804215990235785e-05, 'reg_lambda': 0.0011753166157775696, 'min_split_gain': 8.587650516141897}. Best is trial 5 with value: 0.7052861511577108.
# [I 2025-02-03 18:18:15,667] Trial 11 finished with value: 0.696491371778069 and parameters: {'n_estimators': 2137, 'num_leaves': 1124, 'max_depth': 142, 'learning_rate': 0.08233007973688751, 'min_child_samples': 67, 'subsample': 0.9599707231520116, 'colsample_bytree': 0.36524269909318163, 'reg_alpha': 1.0176188863382192e-05, 'reg_lambda': 0.001388536502456489, 'min_split_gain': 6.4709838498346315}. Best is trial 5 with value: 0.7052861511577108.
# [I 2025-02-03 18:18:18,182] Trial 12 finished with value: 0.6938728702490169 and parameters: {'n_estimators': 2191, 'num_leaves': 1392, 'max_depth': 198, 'learning_rate': 0.06150829427674849, 'min_child_samples': 68, 'subsample': 0.9821639175614106, 'colsample_bytree': 0.35715546645752283, 'reg_alpha': 46.19305827401539, 'reg_lambda': 0.0014620202461925733, 'min_split_gain': 0.00381530615967414}. Best is trial 5 with value: 0.7052861511577108.
# [I 2025-02-03 18:18:21,489] Trial 13 finished with value: 0.7001774792485803 and parameters: {'n_estimators': 2991, 'num_leaves': 830, 'max_depth': 133, 'learning_rate': 0.021005507582601935, 'min_child_samples': 44, 'subsample': 0.619380596106638, 'colsample_bytree': 0.496003873416329, 'reg_alpha': 4.9770051906783396e-05, 'reg_lambda': 0.00435626747813111, 'min_split_gain': 6.362899959140361}. Best is trial 5 with value: 0.7052861511577108.
# [I 2025-02-03 18:18:24,022] Trial 14 finished with value: 0.6903478593272172 and parameters: {'n_estimators': 1967, 'num_leaves': 902, 'max_depth': 113, 'learning_rate': 0.0004481968701589713, 'min_child_samples': 82, 'subsample': 0.6357223082802781, 'colsample_bytree': 0.22962305736077418, 'reg_alpha': 4.177533059513829, 'reg_lambda': 0.9982727550337102, 'min_split_gain': 0.10343415504166568}. Best is trial 5 with value: 0.7052861511577108.
# [I 2025-02-03 18:18:25,489] Trial 15 finished with value: 0.6752730449978156 and parameters: {'n_estimators': 995, 'num_leaves': 1375, 'max_depth': 180, 'learning_rate': 0.028253009436608478, 'min_child_samples': 41, 'subsample': 0.8719742788326659, 'colsample_bytree': 0.5592233393101187, 'reg_alpha': 0.0031857194662122277, 'reg_lambda': 0.008197314599584045, 'min_split_gain': 0.030060895199632245}. Best is trial 5 with value: 0.7052861511577108.
# [I 2025-02-03 18:18:28,183] Trial 16 finished with value: 0.7030662953254696 and parameters: {'n_estimators': 2368, 'num_leaves': 327, 'max_depth': 148, 'learning_rate': 0.007396716330539907, 'min_child_samples': 92, 'subsample': 0.9187027309160858, 'colsample_bytree': 0.26070896329286203, 'reg_alpha': 0.00013149110283417736, 'reg_lambda': 41.489333239599816, 'min_split_gain': 0.8154439617820617}. Best is trial 5 with value: 0.7052861511577108.
# [I 2025-02-03 18:18:30,863] Trial 17 finished with value: 0.7051769331585845 and parameters: {'n_estimators': 2471, 'num_leaves': 349, 'max_depth': 118, 'learning_rate': 0.008690699975135817, 'min_child_samples': 133, 'subsample': 0.655509955845643, 'colsample_bytree': 0.24186790984432643, 'reg_alpha': 0.00024372406018642395, 'reg_lambda': 88.02346016281332, 'min_split_gain': 0.7733078739296407}. Best is trial 5 with value: 0.7052861511577108.
# [I 2025-02-03 18:18:34,407] Trial 18 finished with value: 0.6527877894276977 and parameters: {'n_estimators': 2901, 'num_leaves': 377, 'max_depth': 114, 'learning_rate': 0.0006041991605850271, 'min_child_samples': 135, 'subsample': 0.4743888675674237, 'colsample_bytree': 0.11094602219743976, 'reg_alpha': 5.457077283799275, 'reg_lambda': 10.667160436707707, 'min_split_gain': 0.0017837701344343858}. Best is trial 5 with value: 0.7052861511577108.
# [I 2025-02-03 18:18:37,052] Trial 19 finished with value: 0.6647717343818262 and parameters: {'n_estimators': 1867, 'num_leaves': 20, 'max_depth': 93, 'learning_rate': 0.028121789198929062, 'min_child_samples': 159, 'subsample': 0.6740275857874848, 'colsample_bytree': 0.4761776511516554, 'reg_alpha': 0.000181076389845214, 'reg_lambda': 0.3982602596744465, 'min_split_gain': 0.0008680018268344504}. Best is trial 5 with value: 0.7052861511577108.
# [I 2025-02-03 18:18:40,637] Trial 20 finished with value: 0.6927970729576234 and parameters: {'n_estimators': 2577, 'num_leaves': 534, 'max_depth': 127, 'learning_rate': 0.004772450946465202, 'min_child_samples': 122, 'subsample': 0.5389704249624038, 'colsample_bytree': 0.30468603360131574, 'reg_alpha': 0.015063980589801358, 'reg_lambda': 18.39427884483667, 'min_split_gain': 0.019590973335345506}. Best is trial 5 with value: 0.7052861511577108.
# [I 2025-02-03 18:18:43,525] Trial 21 finished with value: 0.7012969637396244 and parameters: {'n_estimators': 2417, 'num_leaves': 264, 'max_depth': 160, 'learning_rate': 0.009772499211260737, 'min_child_samples': 92, 'subsample': 0.8931650335266719, 'colsample_bytree': 0.25830513187468584, 'reg_alpha': 0.00014437715513787241, 'reg_lambda': 93.47575571124369, 'min_split_gain': 0.9078196943344666}. Best is trial 5 with value: 0.7052861511577108.
# [I 2025-02-03 18:18:46,828] Trial 22 finished with value: 0.6869839449541284 and parameters: {'n_estimators': 2338, 'num_leaves': 264, 'max_depth': 82, 'learning_rate': 0.001301941643639186, 'min_child_samples': 88, 'subsample': 0.7059484001325839, 'colsample_bytree': 0.1839275688015985, 'reg_alpha': 0.00041546810163745616, 'reg_lambda': 14.512520070612554, 'min_split_gain': 0.9622252902826047}. Best is trial 5 with value: 0.7052861511577108.
# [I 2025-02-03 18:18:49,250] Trial 23 finished with value: 0.6739405854084753 and parameters: {'n_estimators': 1754, 'num_leaves': 496, 'max_depth': 111, 'learning_rate': 0.00014809236318016832, 'min_child_samples': 105, 'subsample': 0.8806952733658762, 'colsample_bytree': 0.29427553998622896, 'reg_alpha': 0.004474459410878345, 'reg_lambda': 29.20506332429817, 'min_split_gain': 1.3594787910634418}. Best is trial 5 with value: 0.7052861511577108.
# [I 2025-02-03 18:18:53,601] Trial 24 finished with value: 0.679259501965924 and parameters: {'n_estimators': 2743, 'num_leaves': 695, 'max_depth': 143, 'learning_rate': 0.007841213554574194, 'min_child_samples': 137, 'subsample': 0.7902631136145377, 'colsample_bytree': 0.44653707433558665, 'reg_alpha': 8.030935495599494e-05, 'reg_lambda': 0.3981348029550622, 'min_split_gain': 0.037836025378582695}. Best is trial 5 with value: 0.7052861511577108.
# [I 2025-02-03 18:18:57,858] Trial 25 finished with value: 0.6970347313237222 and parameters: {'n_estimators': 2367, 'num_leaves': 189, 'max_depth': 175, 'learning_rate': 0.0028476317695965317, 'min_child_samples': 29, 'subsample': 0.6024429951380489, 'colsample_bytree': 0.16216485160743166, 'reg_alpha': 0.0005137563381231885, 'reg_lambda': 4.811382564061119, 'min_split_gain': 0.4180869455743572}. Best is trial 5 with value: 0.7052861511577108.
# [I 2025-02-03 18:19:00,783] Trial 26 finished with value: 0.7043223023154215 and parameters: {'n_estimators': 1733, 'num_leaves': 432, 'max_depth': 132, 'learning_rate': 0.01676468422672508, 'min_child_samples': 83, 'subsample': 0.7217076823863641, 'colsample_bytree': 0.29489224295338257, 'reg_alpha': 2.873540169726487e-05, 'reg_lambda': 0.357325351126478, 'min_split_gain': 1.9409496230038266}. Best is trial 5 with value: 0.7052861511577108.
# [I 2025-02-03 18:19:03,621] Trial 27 finished with value: 0.7062390782000874 and parameters: {'n_estimators': 1705, 'num_leaves': 452, 'max_depth': 126, 'learning_rate': 0.039724362372430363, 'min_child_samples': 78, 'subsample': 0.716299989053989, 'colsample_bytree': 0.339996433072709, 'reg_alpha': 3.1540401391894345e-05, 'reg_lambda': 0.21320121370913037, 'min_split_gain': 2.18934814133947}. Best is trial 27 with value: 0.7062390782000874.
# [I 2025-02-03 18:19:05,545] Trial 28 finished with value: 0.699544014853648 and parameters: {'n_estimators': 1171, 'num_leaves': 10, 'max_depth': 101, 'learning_rate': 0.044235111559861075, 'min_child_samples': 117, 'subsample': 0.4084798419682343, 'colsample_bytree': 0.6133205890483147, 'reg_alpha': 13.474523640803593, 'reg_lambda': 0.021768577917344056, 'min_split_gain': 2.7412592907725637}. Best is trial 27 with value: 0.7062390782000874.
# [I 2025-02-03 18:19:06,132] Trial 29 finished with value: 0.6946319353429445 and parameters: {'n_estimators': 199, 'num_leaves': 171, 'max_depth': 73, 'learning_rate': 0.039326644909109414, 'min_child_samples': 162, 'subsample': 0.5590175263620956, 'colsample_bytree': 0.4001805697463776, 'reg_alpha': 0.9702960765634265, 'reg_lambda': 0.19859863876348818, 'min_split_gain': 0.06798067636670309}. Best is trial 27 with value: 0.7062390782000874.
# [I 2025-02-03 18:19:11,878] Trial 30 finished with value: 0.681476627348187 and parameters: {'n_estimators': 1156, 'num_leaves': 729, 'max_depth': 114, 'learning_rate': 0.0023127724396727802, 'min_child_samples': 17, 'subsample': 0.6847247760728172, 'colsample_bytree': 0.50300814645775, 'reg_alpha': 3.0300981700684226e-05, 'reg_lambda': 0.9635274236425071, 'min_split_gain': 0.007097686248586262}. Best is trial 27 with value: 0.7062390782000874.
# [I 2025-02-03 18:19:14,906] Trial 31 finished with value: 0.7053161861074706 and parameters: {'n_estimators': 1719, 'num_leaves': 500, 'max_depth': 130, 'learning_rate': 0.018898936929361898, 'min_child_samples': 76, 'subsample': 0.7399549269185042, 'colsample_bytree': 0.31846586639552965, 'reg_alpha': 2.7651375039461706e-05, 'reg_lambda': 0.02391397959526804, 'min_split_gain': 2.340461249982999}. Best is trial 27 with value: 0.7062390782000874.
# [I 2025-02-03 18:19:17,709] Trial 32 finished with value: 0.7028697029270423 and parameters: {'n_estimators': 1631, 'num_leaves': 620, 'max_depth': 125, 'learning_rate': 0.016245068144832717, 'min_child_samples': 68, 'subsample': 0.8355981794107777, 'colsample_bytree': 0.3250379162671233, 'reg_alpha': 2.0196840169073864e-05, 'reg_lambda': 0.010091737496050308, 'min_split_gain': 3.3262750507582703}. Best is trial 27 with value: 0.7062390782000874.
# [I 2025-02-03 18:19:20,000] Trial 33 finished with value: 0.7038690476190477 and parameters: {'n_estimators': 1323, 'num_leaves': 174, 'max_depth': 102, 'learning_rate': 0.03801785003386609, 'min_child_samples': 82, 'subsample': 0.7829863365152157, 'colsample_bytree': 0.17487206439661931, 'reg_alpha': 0.00027566179309392773, 'reg_lambda': 0.030579678729721473, 'min_split_gain': 0.42789250415542407}. Best is trial 27 with value: 0.7062390782000874.
# [I 2025-02-03 18:19:23,607] Trial 34 finished with value: 0.7018239405854085 and parameters: {'n_estimators': 2027, 'num_leaves': 916, 'max_depth': 13, 'learning_rate': 0.004992327489240504, 'min_child_samples': 57, 'subsample': 0.6503453692859719, 'colsample_bytree': 0.22292842909143468, 'reg_alpha': 5.9196543097433806e-05, 'reg_lambda': 0.08841480406876734, 'min_split_gain': 3.235487822015648}. Best is trial 27 with value: 0.7062390782000874.
# [I 2025-02-03 18:19:26,009] Trial 35 finished with value: 0.684881498470948 and parameters: {'n_estimators': 1390, 'num_leaves': 440, 'max_depth': 123, 'learning_rate': 0.08996359660201396, 'min_child_samples': 100, 'subsample': 0.7251500456296491, 'colsample_bytree': 0.12663089150738943, 'reg_alpha': 94.72936574273116, 'reg_lambda': 5.782290345010254, 'min_split_gain': 2.4235415054101457e-05}. Best is trial 27 with value: 0.7062390782000874.
# [I 2025-02-03 18:19:28,604] Trial 36 finished with value: 0.6686926605504587 and parameters: {'n_estimators': 732, 'num_leaves': 1948, 'max_depth': 137, 'learning_rate': 0.02177210176638392, 'min_child_samples': 77, 'subsample': 0.8307693712468329, 'colsample_bytree': 0.4340036113818806, 'reg_alpha': 0.040606362008544526, 'reg_lambda': 0.153609801209149, 'min_split_gain': 0.00026216322319302514}. Best is trial 27 with value: 0.7062390782000874.
# [I 2025-02-03 18:19:31,607] Trial 37 finished with value: 0.7025283966797727 and parameters: {'n_estimators': 1658, 'num_leaves': 589, 'max_depth': 91, 'learning_rate': 0.012950852058268179, 'min_child_samples': 133, 'subsample': 0.582164701963342, 'colsample_bytree': 0.32275723945088175, 'reg_alpha': 0.30889277362380524, 'reg_lambda': 1.0379585796851753e-05, 'min_split_gain': 0.3461009360255097}. Best is trial 27 with value: 0.7062390782000874.
# [I 2025-02-03 18:19:36,731] Trial 38 finished with value: 0.6482033639143732 and parameters: {'n_estimators': 2069, 'num_leaves': 102, 'max_depth': 174, 'learning_rate': 0.048764882976170994, 'min_child_samples': 110, 'subsample': 0.767890597763649, 'colsample_bytree': 0.6179362845936061, 'reg_alpha': 0.001229396141118559, 'reg_lambda': 1.3441325464065375, 'min_split_gain': 0.00041023292581903495}. Best is trial 27 with value: 0.7062390782000874.
# [I 2025-02-03 18:19:42,853] Trial 39 finished with value: 0.6313073394495412 and parameters: {'n_estimators': 1848, 'num_leaves': 263, 'max_depth': 156, 'learning_rate': 0.09842945207535804, 'min_child_samples': 48, 'subsample': 0.10906346581810772, 'colsample_bytree': 0.8370636737628407, 'reg_alpha': 0.002891642652687939, 'reg_lambda': 0.0004115685188511098, 'min_split_gain': 0.0001032071284962152}. Best is trial 27 with value: 0.7062390782000874.
# [I 2025-02-03 18:19:46,864] Trial 40 finished with value: 0.684742245522062 and parameters: {'n_estimators': 1519, 'num_leaves': 748, 'max_depth': 120, 'learning_rate': 0.004401945326889061, 'min_child_samples': 98, 'subsample': 0.740693032364099, 'colsample_bytree': 0.25170880167161436, 'reg_alpha': 0.01301943504297229, 'reg_lambda': 0.03543219420311892, 'min_split_gain': 0.20853068986150575}. Best is trial 27 with value: 0.7062390782000874.
# [I 2025-02-03 18:19:50,905] Trial 41 finished with value: 0.7045243556138051 and parameters: {'n_estimators': 1771, 'num_leaves': 366, 'max_depth': 131, 'learning_rate': 0.014466311661737024, 'min_child_samples': 75, 'subsample': 0.7160905203540938, 'colsample_bytree': 0.29103556153598287, 'reg_alpha': 2.796987776200076e-05, 'reg_lambda': 0.20930110223755266, 'min_split_gain': 2.0345030935832735}. Best is trial 27 with value: 0.7062390782000874.
# [I 2025-02-03 18:19:54,691] Trial 42 finished with value: 0.6800185670598515 and parameters: {'n_estimators': 1258, 'num_leaves': 445, 'max_depth': 148, 'learning_rate': 1.1339689239532353e-05, 'min_child_samples': 31, 'subsample': 0.685619133895071, 'colsample_bytree': 0.3609208034030054, 'reg_alpha': 1.0428868363832105e-05, 'reg_lambda': 0.05857339421018986, 'min_split_gain': 0.6012671403964721}. Best is trial 27 with value: 0.7062390782000874.
# [I 2025-02-03 18:19:57,631] Trial 43 finished with value: 0.7040028396679773 and parameters: {'n_estimators': 1772, 'num_leaves': 349, 'max_depth': 107, 'learning_rate': 0.012170510263335902, 'min_child_samples': 73, 'subsample': 0.83493747946178, 'colsample_bytree': 0.39689442650492746, 'reg_alpha': 4.557277870094472e-05, 'reg_lambda': 0.01637290167505471, 'min_split_gain': 4.842606073907616}. Best is trial 27 with value: 0.7062390782000874.
# [I 2025-02-03 18:20:01,164] Trial 44 finished with value: 0.7070336391437309 and parameters: {'n_estimators': 2220, 'num_leaves': 158, 'max_depth': 134, 'learning_rate': 0.028482530473901417, 'min_child_samples': 57, 'subsample': 0.525658059995044, 'colsample_bytree': 0.20238700891354877, 'reg_alpha': 9.370096850191881e-05, 'reg_lambda': 0.003599203687324948, 'min_split_gain': 1.5403958017684682}. Best is trial 44 with value: 0.7070336391437309.
# [I 2025-02-03 18:20:04,860] Trial 45 finished with value: 0.6984982525120139 and parameters: {'n_estimators': 2234, 'num_leaves': 159, 'max_depth': 137, 'learning_rate': 0.029202034866922976, 'min_child_samples': 61, 'subsample': 0.47936339162479225, 'colsample_bytree': 0.19689975841852386, 'reg_alpha': 9.471404772228197e-05, 'reg_lambda': 0.00461659270493011, 'min_split_gain': 0.1618726916155653}. Best is trial 44 with value: 0.7070336391437309.
# [I 2025-02-03 18:20:08,718] Trial 46 finished with value: 0.696002621231979 and parameters: {'n_estimators': 2545, 'num_leaves': 98, 'max_depth': 166, 'learning_rate': 0.062426897048861896, 'min_child_samples': 193, 'subsample': 0.24865123422091373, 'colsample_bytree': 0.1455563663114473, 'reg_alpha': 0.0009973709850558865, 'reg_lambda': 0.00018355896774896143, 'min_split_gain': 7.889701768759661}. Best is trial 44 with value: 0.7070336391437309.
# [I 2025-02-03 18:20:11,791] Trial 47 finished with value: 0.7054308650065532 and parameters: {'n_estimators': 1953, 'num_leaves': 250, 'max_depth': 99, 'learning_rate': 0.024394144348841868, 'min_child_samples': 52, 'subsample': 0.503895621862568, 'colsample_bytree': 0.21846074520956382, 'reg_alpha': 0.13852990751137806, 'reg_lambda': 0.002555339644378868, 'min_split_gain': 1.4932103509424834}. Best is trial 44 with value: 0.7070336391437309.
# [I 2025-02-03 18:20:14,941] Trial 48 finished with value: 0.704450633464395 and parameters: {'n_estimators': 1953, 'num_leaves': 223, 'max_depth': 80, 'learning_rate': 0.05680335642881801, 'min_child_samples': 38, 'subsample': 0.4375140299309503, 'colsample_bytree': 0.34433637797623556, 'reg_alpha': 0.11912605118039162, 'reg_lambda': 0.0034136573003189412, 'min_split_gain': 1.5779253650414344}. Best is trial 44 with value: 0.7070336391437309.
# [I 2025-02-03 18:20:19,847] Trial 49 finished with value: 0.6537789427697684 and parameters: {'n_estimators': 2087, 'num_leaves': 1030, 'max_depth': 33, 'learning_rate': 0.00017582373451738658, 'min_child_samples': 59, 'subsample': 0.3669219385474736, 'colsample_bytree': 0.22174710421951088, 'reg_alpha': 0.35828112265179946, 'reg_lambda': 0.00098607642275855, 'min_split_gain': 0.0022024617628543797}. Best is trial 44 with value: 0.7070336391437309.
# [I 2025-02-03 18:20:22,377] Trial 50 finished with value: 0.7057721712538226 and parameters: {'n_estimators': 1590, 'num_leaves': 64, 'max_depth': 97, 'learning_rate': 0.03182487984052115, 'min_child_samples': 53, 'subsample': 0.5304623773717183, 'colsample_bytree': 0.10467909442889278, 'reg_alpha': 1.8058096142302529, 'reg_lambda': 0.00044653579649377975, 'min_split_gain': 0.06920954448874934}. Best is trial 44 with value: 0.7070336391437309.
# [I 2025-02-03 18:20:24,996] Trial 51 finished with value: 0.7069571865443425 and parameters: {'n_estimators': 1574, 'num_leaves': 98, 'max_depth': 96, 'learning_rate': 0.022813582259317112, 'min_child_samples': 52, 'subsample': 0.5383877316855152, 'colsample_bytree': 0.11472906655058397, 'reg_alpha': 1.9278160937952182, 'reg_lambda': 7.059901596884028e-05, 'min_split_gain': 0.0798285938045959}. Best is trial 44 with value: 0.7070336391437309.
# [I 2025-02-03 18:20:27,596] Trial 52 finished with value: 0.7057557885539536 and parameters: {'n_estimators': 1489, 'num_leaves': 72, 'max_depth': 102, 'learning_rate': 0.022950417956804393, 'min_child_samples': 54, 'subsample': 0.5261363779522421, 'colsample_bytree': 0.11077491919249799, 'reg_alpha': 1.2241214501299573, 'reg_lambda': 4.7856210827900355e-05, 'min_split_gain': 0.09869230852744698}. Best is trial 44 with value: 0.7070336391437309.
# [I 2025-02-03 18:20:29,979] Trial 53 finished with value: 0.70935998252512 and parameters: {'n_estimators': 1467, 'num_leaves': 57, 'max_depth': 99, 'learning_rate': 0.02608115842295412, 'min_child_samples': 52, 'subsample': 0.5385377107160912, 'colsample_bytree': 0.13270118503336675, 'reg_alpha': 3.4127604180617883, 'reg_lambda': 5.4544840517711575e-05, 'min_split_gain': 0.08944101885704205}. Best is trial 53 with value: 0.70935998252512.
# [I 2025-02-03 18:20:32,331] Trial 54 finished with value: 0.7044779379641765 and parameters: {'n_estimators': 1459, 'num_leaves': 39, 'max_depth': 64, 'learning_rate': 0.03987911815429519, 'min_child_samples': 33, 'subsample': 0.5294713716669283, 'colsample_bytree': 0.10054116050167272, 'reg_alpha': 1.6536537879068456, 'reg_lambda': 6.0379448155498015e-05, 'min_split_gain': 0.07496929296183062}. Best is trial 53 with value: 0.70935998252512.
# [I 2025-02-03 18:20:34,046] Trial 55 finished with value: 0.6999890782000874 and parameters: {'n_estimators': 973, 'num_leaves': 104, 'max_depth': 84, 'learning_rate': 0.03411562960740867, 'min_child_samples': 13, 'subsample': 0.42567587609240354, 'colsample_bytree': 0.14844061984519216, 'reg_alpha': 2.3320765704717825, 'reg_lambda': 4.257769092912174e-05, 'min_split_gain': 0.020614790453189705}. Best is trial 53 with value: 0.70935998252512.
# [I 2025-02-03 18:20:35,572] Trial 56 finished with value: 0.6950906509392748 and parameters: {'n_estimators': 816, 'num_leaves': 114, 'max_depth': 54, 'learning_rate': 0.00943468918505664, 'min_child_samples': 52, 'subsample': 0.570365147541073, 'colsample_bytree': 0.13323637901741675, 'reg_alpha': 0.5994743331826144, 'reg_lambda': 0.00010937199703215915, 'min_split_gain': 0.010493278956167296}. Best is trial 53 with value: 0.70935998252512.
# [I 2025-02-03 18:20:38,082] Trial 57 finished with value: 0.7059687636522498 and parameters: {'n_estimators': 1597, 'num_leaves': 24, 'max_depth': 94, 'learning_rate': 0.06745847655422106, 'min_child_samples': 65, 'subsample': 0.5129446496512318, 'colsample_bytree': 0.10212961221458558, 'reg_alpha': 10.350158578489387, 'reg_lambda': 1.9786861571572793e-05, 'min_split_gain': 0.10662132522802499}. Best is trial 53 with value: 0.70935998252512.
# [I 2025-02-03 18:20:40,561] Trial 58 finished with value: 0.7040738313674093 and parameters: {'n_estimators': 1595, 'num_leaves': 16, 'max_depth': 94, 'learning_rate': 0.07258682770758017, 'min_child_samples': 20, 'subsample': 0.4603080539754136, 'colsample_bytree': 0.17992790824759228, 'reg_alpha': 12.978303169305518, 'reg_lambda': 1.7806570005490127e-05, 'min_split_gain': 0.04297447931095276}. Best is trial 53 with value: 0.70935998252512.
# [I 2025-02-03 18:20:42,564] Trial 59 finished with value: 0.7068425076452599 and parameters: {'n_estimators': 1268, 'num_leaves': 280, 'max_depth': 73, 'learning_rate': 0.05410326260985147, 'min_child_samples': 66, 'subsample': 0.603382956006846, 'colsample_bytree': 0.16418930849540203, 'reg_alpha': 6.37904923339213, 'reg_lambda': 0.0003424639743811361, 'min_split_gain': 0.016668202220126983}. Best is trial 53 with value: 0.70935998252512.
# [I 2025-02-03 18:20:44,682] Trial 60 finished with value: 0.705463630406291 and parameters: {'n_estimators': 1152, 'num_leaves': 1624, 'max_depth': 72, 'learning_rate': 0.05773372443202637, 'min_child_samples': 64, 'subsample': 0.6257339971332813, 'colsample_bytree': 0.1567010826915478, 'reg_alpha': 6.789541557257388, 'reg_lambda': 2.503040660648226e-05, 'min_split_gain': 0.013753156412741057}. Best is trial 53 with value: 0.70935998252512.
# [I 2025-02-03 18:20:46,704] Trial 61 finished with value: 0.6946155526430755 and parameters: {'n_estimators': 1337, 'num_leaves': 292, 'max_depth': 76, 'learning_rate': 0.030776697605809807, 'min_child_samples': 46, 'subsample': 0.5835095956438955, 'colsample_bytree': 0.1875585470738701, 'reg_alpha': 28.328326092128417, 'reg_lambda': 0.0004350872165004826, 'min_split_gain': 0.04476393579701642}. Best is trial 53 with value: 0.70935998252512.
# [I 2025-02-03 18:20:48,624] Trial 62 finished with value: 0.7097640891218872 and parameters: {'n_estimators': 1252, 'num_leaves': 173, 'max_depth': 88, 'learning_rate': 0.08034160506302554, 'min_child_samples': 38, 'subsample': 0.5096446013926248, 'colsample_bytree': 0.1038169296859165, 'reg_alpha': 4.558696413934799, 'reg_lambda': 0.00022846490338370308, 'min_split_gain': 0.024914772176280835}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:20:50,576] Trial 63 finished with value: 0.7009365443425077 and parameters: {'n_estimators': 1242, 'num_leaves': 152, 'max_depth': 83, 'learning_rate': 0.0936886039938798, 'min_child_samples': 39, 'subsample': 0.3858038782384172, 'colsample_bytree': 0.13452177867925735, 'reg_alpha': 3.6728782202307046, 'reg_lambda': 0.00019538995867998403, 'min_split_gain': 0.025648694463184272}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:20:52,274] Trial 64 finished with value: 0.7066076889471384 and parameters: {'n_estimators': 1076, 'num_leaves': 217, 'max_depth': 42, 'learning_rate': 0.052802305074228985, 'min_child_samples': 3, 'subsample': 0.6079808860415048, 'colsample_bytree': 0.2055491887787246, 'reg_alpha': 8.903475885495316, 'reg_lambda': 8.702233002319624e-05, 'min_split_gain': 0.005359177839274925}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:20:53,929] Trial 65 finished with value: 0.6946728920926168 and parameters: {'n_estimators': 1038, 'num_leaves': 216, 'max_depth': 50, 'learning_rate': 0.042340185148443246, 'min_child_samples': 7, 'subsample': 0.6241341446257033, 'colsample_bytree': 0.20132045708153024, 'reg_alpha': 28.457331941035903, 'reg_lambda': 0.0007802819011996694, 'min_split_gain': 0.005040219679981858}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:20:55,690] Trial 66 finished with value: 0.7001993228484054 and parameters: {'n_estimators': 1075, 'num_leaves': 315, 'max_depth': 24, 'learning_rate': 0.049988783008398256, 'min_child_samples': 21, 'subsample': 0.6079478238768514, 'colsample_bytree': 0.2688657888580096, 'reg_alpha': 4.018265975671112, 'reg_lambda': 6.771868713465346e-05, 'min_split_gain': 0.0013222893729172673}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:20:57,078] Trial 67 finished with value: 0.7037598296199215 and parameters: {'n_estimators': 849, 'num_leaves': 424, 'max_depth': 42, 'learning_rate': 0.02082692117854274, 'min_child_samples': 1, 'subsample': 0.5699993665351364, 'colsample_bytree': 0.9984836900037324, 'reg_alpha': 7.683253965457703, 'reg_lambda': 0.00011731579734592243, 'min_split_gain': 0.014276774371348196}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:20:59,767] Trial 68 finished with value: 0.6752566622979468 and parameters: {'n_estimators': 1382, 'num_leaves': 211, 'max_depth': 59, 'learning_rate': 0.006407823279752041, 'min_child_samples': 26, 'subsample': 0.46142640108549315, 'colsample_bytree': 0.15553269686151397, 'reg_alpha': 0.773014753529782, 'reg_lambda': 0.0002233195432686117, 'min_split_gain': 0.0026955446364100486}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:01,062] Trial 69 finished with value: 0.6716879641764962 and parameters: {'n_estimators': 699, 'num_leaves': 1339, 'max_depth': 108, 'learning_rate': 0.0007738913674042808, 'min_child_samples': 41, 'subsample': 0.6601373383064209, 'colsample_bytree': 0.27081388329845624, 'reg_alpha': 19.495093580794666, 'reg_lambda': 8.381926940335041e-05, 'min_split_gain': 0.006912053774619899}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:02,035] Trial 70 finished with value: 0.6982497815640017 and parameters: {'n_estimators': 586, 'num_leaves': 401, 'max_depth': 87, 'learning_rate': 0.07668842521812647, 'min_child_samples': 70, 'subsample': 0.5534390846692195, 'colsample_bytree': 0.20464697809756255, 'reg_alpha': 67.66698048614398, 'reg_lambda': 0.0005816293865208419, 'min_split_gain': 0.003707120012182851}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:03,931] Trial 71 finished with value: 0.70743501529052 and parameters: {'n_estimators': 1233, 'num_leaves': 139, 'max_depth': 68, 'learning_rate': 0.06748638276574757, 'min_child_samples': 64, 'subsample': 0.5030588716668112, 'colsample_bytree': 0.12357350337528003, 'reg_alpha': 8.351092321680563, 'reg_lambda': 1.0023549940928668e-05, 'min_split_gain': 0.12329531833267679}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:05,426] Trial 72 finished with value: 0.6991207951070335 and parameters: {'n_estimators': 909, 'num_leaves': 135, 'max_depth': 69, 'learning_rate': 0.05263268423209777, 'min_child_samples': 44, 'subsample': 0.4984989524694072, 'colsample_bytree': 0.1298258301218853, 'reg_alpha': 2.5592451599003785, 'reg_lambda': 1.436320134889e-05, 'min_split_gain': 0.0297295406348795}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:07,359] Trial 73 finished with value: 0.7003440366972478 and parameters: {'n_estimators': 1253, 'num_leaves': 284, 'max_depth': 32, 'learning_rate': 0.07507576108535158, 'min_child_samples': 83, 'subsample': 0.5881663748958869, 'colsample_bytree': 0.16845998179990584, 'reg_alpha': 20.34402191572845, 'reg_lambda': 3.07655935030528e-05, 'min_split_gain': 0.20016874252972444}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:09,128] Trial 74 finished with value: 0.6944626474442989 and parameters: {'n_estimators': 1130, 'num_leaves': 194, 'max_depth': 42, 'learning_rate': 0.026996770617934304, 'min_child_samples': 36, 'subsample': 0.44674767160140044, 'colsample_bytree': 0.23609624616418334, 'reg_alpha': 45.5264592631998, 'reg_lambda': 0.00030237184075583904, 'min_split_gain': 0.05305449610127622}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:11,414] Trial 75 finished with value: 0.706793359545653 and parameters: {'n_estimators': 1430, 'num_leaves': 327, 'max_depth': 14, 'learning_rate': 0.03869892538087159, 'min_child_samples': 92, 'subsample': 0.4876105383979025, 'colsample_bytree': 0.17099442294162034, 'reg_alpha': 4.996585087952578, 'reg_lambda': 0.0016790633484587295, 'min_split_gain': 0.2885894718029917}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:13,774] Trial 76 finished with value: 0.7026294233289646 and parameters: {'n_estimators': 1437, 'num_leaves': 300, 'max_depth': 63, 'learning_rate': 0.012020584001430957, 'min_child_samples': 59, 'subsample': 0.3230855873045537, 'colsample_bytree': 0.17170879623189067, 'reg_alpha': 5.367471529039097, 'reg_lambda': 0.0018218434910697956, 'min_split_gain': 0.27234014269562407}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:15,969] Trial 77 finished with value: 0.7054390563564875 and parameters: {'n_estimators': 1292, 'num_leaves': 527, 'max_depth': 14, 'learning_rate': 0.018178975445011094, 'min_child_samples': 92, 'subsample': 0.48599967727641524, 'colsample_bytree': 0.12933040688805353, 'reg_alpha': 10.432062667514463, 'reg_lambda': 3.742704013700722e-05, 'min_split_gain': 0.1142251901083254}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:17,785] Trial 78 finished with value: 0.7017065312363476 and parameters: {'n_estimators': 1080, 'num_leaves': 153, 'max_depth': 8, 'learning_rate': 0.04595909306485482, 'min_child_samples': 28, 'subsample': 0.5469737254548362, 'colsample_bytree': 0.1991075270410544, 'reg_alpha': 0.5901182966817965, 'reg_lambda': 1.1059997722750184e-05, 'min_split_gain': 0.486648198365648}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:19,697] Trial 79 finished with value: 0.7083497160332023 and parameters: {'n_estimators': 1197, 'num_leaves': 245, 'max_depth': 198, 'learning_rate': 0.09907132846634115, 'min_child_samples': 70, 'subsample': 0.4062412142627658, 'colsample_bytree': 0.16415584124357377, 'reg_alpha': 2.8998938584383303, 'reg_lambda': 0.00027843791893521994, 'min_split_gain': 0.14396801022201966}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:21,876] Trial 80 finished with value: 0.6990934906072521 and parameters: {'n_estimators': 1404, 'num_leaves': 80, 'max_depth': 199, 'learning_rate': 0.09002807731644345, 'min_child_samples': 71, 'subsample': 0.4061070368189532, 'colsample_bytree': 0.7137539103718551, 'reg_alpha': 3.232515709231995, 'reg_lambda': 0.0017429965867605617, 'min_split_gain': 0.14652975287888667}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:23,848] Trial 81 finished with value: 0.7089094582787243 and parameters: {'n_estimators': 1206, 'num_leaves': 235, 'max_depth': 186, 'learning_rate': 0.0682801932650835, 'min_child_samples': 48, 'subsample': 0.49937067454982664, 'colsample_bytree': 0.23997982823505032, 'reg_alpha': 7.351854613139017, 'reg_lambda': 0.0001441723124048911, 'min_split_gain': 0.06428603460503449}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:25,807] Trial 82 finished with value: 0.7077025993883792 and parameters: {'n_estimators': 1220, 'num_leaves': 371, 'max_depth': 179, 'learning_rate': 0.07142155826047236, 'min_child_samples': 64, 'subsample': 0.5104198513150009, 'colsample_bytree': 0.24312745435823557, 'reg_alpha': 6.2709169495612604, 'reg_lambda': 0.0002713919441330875, 'min_split_gain': 0.26678396686785194}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:27,830] Trial 83 finished with value: 0.7029652686762778 and parameters: {'n_estimators': 1203, 'num_leaves': 385, 'max_depth': 192, 'learning_rate': 0.07139500026056692, 'min_child_samples': 47, 'subsample': 0.5141404780918597, 'colsample_bytree': 0.2376985468392676, 'reg_alpha': 17.88690993785535, 'reg_lambda': 0.00023712806434343146, 'min_split_gain': 0.055425777032757584}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:29,360] Trial 84 finished with value: 0.6983944954128442 and parameters: {'n_estimators': 953, 'num_leaves': 266, 'max_depth': 190, 'learning_rate': 0.09561439517522849, 'min_child_samples': 64, 'subsample': 0.3481445511816915, 'colsample_bytree': 0.12324545781336943, 'reg_alpha': 1.5072027712693046, 'reg_lambda': 0.0007886401614388206, 'min_split_gain': 0.03527244999343049}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:31,590] Trial 85 finished with value: 0.696455875928353 and parameters: {'n_estimators': 1331, 'num_leaves': 143, 'max_depth': 184, 'learning_rate': 0.061909308958248116, 'min_child_samples': 56, 'subsample': 0.28158258319366425, 'colsample_bytree': 0.1464804252331044, 'reg_alpha': 0.04440168667323371, 'reg_lambda': 0.00014506036323089753, 'min_split_gain': 0.08558953352865677}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:34,010] Trial 86 finished with value: 0.6897225862822193 and parameters: {'n_estimators': 1201, 'num_leaves': 194, 'max_depth': 167, 'learning_rate': 0.0014886862882648054, 'min_child_samples': 49, 'subsample': 0.42066495068002696, 'colsample_bytree': 0.284234847213097, 'reg_alpha': 2.1781093793405257, 'reg_lambda': 0.0003505100152471226, 'min_split_gain': 0.13655440024257368}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:36,481] Trial 87 finished with value: 0.7064711664482307 and parameters: {'n_estimators': 1519, 'num_leaves': 627, 'max_depth': 189, 'learning_rate': 0.03282872566635331, 'min_child_samples': 61, 'subsample': 0.458449156856702, 'colsample_bytree': 0.250123673048291, 'reg_alpha': 3.033275314064642, 'reg_lambda': 5.762546782819857e-05, 'min_split_gain': 0.2002605862039417}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:38,582] Trial 88 finished with value: 0.7073640235910879 and parameters: {'n_estimators': 1321, 'num_leaves': 61, 'max_depth': 171, 'learning_rate': 0.025334633739137448, 'min_child_samples': 42, 'subsample': 0.3952758985646227, 'colsample_bytree': 0.21982998633480938, 'reg_alpha': 6.017026702008403, 'reg_lambda': 0.000142593206574909, 'min_split_gain': 0.6813555129910774}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:40,437] Trial 89 finished with value: 0.706547619047619 and parameters: {'n_estimators': 1126, 'num_leaves': 71, 'max_depth': 174, 'learning_rate': 0.016695666151685842, 'min_child_samples': 36, 'subsample': 0.38214324135038386, 'colsample_bytree': 0.22256848032174825, 'reg_alpha': 1.0291776009110412, 'reg_lambda': 0.00011854061070890731, 'min_split_gain': 1.0224930404542316}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:44,638] Trial 90 finished with value: 0.6958579073831367 and parameters: {'n_estimators': 2752, 'num_leaves': 122, 'max_depth': 180, 'learning_rate': 0.022488578347644218, 'min_child_samples': 43, 'subsample': 0.4695503734563213, 'colsample_bytree': 0.8562582899971196, 'reg_alpha': 0.007090555459471125, 'reg_lambda': 2.4360531965531233e-05, 'min_split_gain': 0.7074487115881407}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:46,804] Trial 91 finished with value: 0.7064001747487986 and parameters: {'n_estimators': 1350, 'num_leaves': 227, 'max_depth': 179, 'learning_rate': 0.07654446610265431, 'min_child_samples': 50, 'subsample': 0.5383636138722433, 'colsample_bytree': 0.18337840871269026, 'reg_alpha': 5.931478839015831, 'reg_lambda': 0.00016942820164017616, 'min_split_gain': 0.3720528193714574}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:48,868] Trial 92 finished with value: 0.7039864569681082 and parameters: {'n_estimators': 1278, 'num_leaves': 46, 'max_depth': 193, 'learning_rate': 0.04727113076891184, 'min_child_samples': 69, 'subsample': 0.5071957961093329, 'colsample_bytree': 0.15825857963863704, 'reg_alpha': 14.762223967783271, 'reg_lambda': 0.000603583220088698, 'min_split_gain': 0.01973488183670701}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:50,436] Trial 93 finished with value: 0.6958169506334644 and parameters: {'n_estimators': 1010, 'num_leaves': 341, 'max_depth': 185, 'learning_rate': 0.06076115064396704, 'min_child_samples': 54, 'subsample': 0.5508112160085359, 'colsample_bytree': 0.11852346404223282, 'reg_alpha': 28.1580468338536, 'reg_lambda': 0.00028263353169129116, 'min_split_gain': 1.1278848581368435}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:52,330] Trial 94 finished with value: 0.7002157055482744 and parameters: {'n_estimators': 1207, 'num_leaves': 480, 'max_depth': 170, 'learning_rate': 0.09995356873003988, 'min_child_samples': 57, 'subsample': 0.4097704945821813, 'colsample_bytree': 0.143384289996525, 'reg_alpha': 9.399288730664283, 'reg_lambda': 7.911939098519382e-05, 'min_split_gain': 0.5820112931695347}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:54,958] Trial 95 finished with value: 0.7077981651376147 and parameters: {'n_estimators': 1549, 'num_leaves': 10, 'max_depth': 158, 'learning_rate': 0.026084980050867485, 'min_child_samples': 80, 'subsample': 0.44298045384071455, 'colsample_bytree': 0.18622862984183788, 'reg_alpha': 4.28207095552973, 'reg_lambda': 0.006262115226764883, 'min_split_gain': 0.05935680476234158}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:21:57,941] Trial 96 finished with value: 0.7037270642201836 and parameters: {'n_estimators': 1537, 'num_leaves': 63, 'max_depth': 160, 'learning_rate': 0.03586685333973608, 'min_child_samples': 34, 'subsample': 0.44645389598550844, 'colsample_bytree': 0.21636119991884192, 'reg_alpha': 4.230520590951216, 'reg_lambda': 0.012179900625705965, 'min_split_gain': 0.215651196769113}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:22:00,691] Trial 97 finished with value: 0.6933868501529051 and parameters: {'n_estimators': 1681, 'num_leaves': 171, 'max_depth': 155, 'learning_rate': 0.026727717369047145, 'min_child_samples': 80, 'subsample': 0.3890963295450394, 'colsample_bytree': 0.2616644963115598, 'reg_alpha': 1.6300010529088191, 'reg_lambda': 0.007394791496802396, 'min_split_gain': 0.05890860722580654}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:22:03,164] Trial 98 finished with value: 0.6979084753167322 and parameters: {'n_estimators': 1473, 'num_leaves': 111, 'max_depth': 147, 'learning_rate': 0.013681605921318387, 'min_child_samples': 86, 'subsample': 0.36176526037040246, 'colsample_bytree': 0.18698547149490147, 'reg_alpha': 0.5232326709112901, 'reg_lambda': 0.001191863082619226, 'min_split_gain': 0.13160280407700378}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:22:06,469] Trial 99 finished with value: 0.6990934906072521 and parameters: {'n_estimators': 1835, 'num_leaves': 26, 'max_depth': 197, 'learning_rate': 5.60798257312305e-05, 'min_child_samples': 77, 'subsample': 0.3264550971576694, 'colsample_bytree': 0.3059215003014744, 'reg_alpha': 3.144886588216932, 'reg_lambda': 3.102091396606851e-05, 'min_split_gain': 0.08395526336140616}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:22:07,991] Trial 100 finished with value: 0.7036588029707296 and parameters: {'n_estimators': 885, 'num_leaves': 101, 'max_depth': 162, 'learning_rate': 0.024949271252461786, 'min_child_samples': 62, 'subsample': 0.4329402883271568, 'colsample_bytree': 0.24295822758143815, 'reg_alpha': 12.974874477970491, 'reg_lambda': 4.805333144440405e-05, 'min_split_gain': 0.026376548302690362}. Best is trial 62 with value: 0.7097640891218872.
# [I 2025-02-03 18:22:10,391] Trial 101 finished with value: 0.7103620576671035 and parameters: {'n_estimators': 1376, 'num_leaves': 243, 'max_depth': 88, 'learning_rate': 0.04739869511243712, 'min_child_samples': 67, 'subsample': 0.5204913282291438, 'colsample_bytree': 0.11598827321152515, 'reg_alpha': 6.675645626883216, 'reg_lambda': 0.00014444016889496905, 'min_split_gain': 0.011728325280206493}. Best is trial 101 with value: 0.7103620576671035.
# [I 2025-02-03 18:22:12,593] Trial 102 finished with value: 0.7086282219309742 and parameters: {'n_estimators': 1333, 'num_leaves': 240, 'max_depth': 88, 'learning_rate': 0.04414499348070578, 'min_child_samples': 41, 'subsample': 0.4876123150424389, 'colsample_bytree': 0.11184595112548448, 'reg_alpha': 7.616219480452576, 'reg_lambda': 0.00014137408419373504, 'min_split_gain': 0.011200225813279016}. Best is trial 101 with value: 0.7103620576671035.
# [I 2025-02-03 18:22:14,741] Trial 103 finished with value: 0.7095893403232854 and parameters: {'n_estimators': 1339, 'num_leaves': 253, 'max_depth': 87, 'learning_rate': 0.04521326654340614, 'min_child_samples': 72, 'subsample': 0.47768711984594636, 'colsample_bytree': 0.10206540087646812, 'reg_alpha': 7.3047700280852075, 'reg_lambda': 0.005505443243056647, 'min_split_gain': 0.008829432663678473}. Best is trial 101 with value: 0.7103620576671035.
# [I 2025-02-03 18:22:16,913] Trial 104 finished with value: 0.7093272171253822 and parameters: {'n_estimators': 1381, 'num_leaves': 248, 'max_depth': 78, 'learning_rate': 0.04071509523850453, 'min_child_samples': 71, 'subsample': 0.47766209050099767, 'colsample_bytree': 0.1071850427542659, 'reg_alpha': 7.3287613249979, 'reg_lambda': 0.00014453475672221265, 'min_split_gain': 0.009976694394392409}. Best is trial 101 with value: 0.7103620576671035.
# [I 2025-02-03 18:22:19,019] Trial 105 finished with value: 0.6976081258191349 and parameters: {'n_estimators': 1357, 'num_leaves': 254, 'max_depth': 87, 'learning_rate': 0.07845463771958534, 'min_child_samples': 73, 'subsample': 0.47996733927236385, 'colsample_bytree': 0.10116330688480486, 'reg_alpha': 38.53221537982878, 'reg_lambda': 0.000106276893240829, 'min_split_gain': 0.010111251277025425}. Best is trial 101 with value: 0.7103620576671035.
# ...
# [I 2025-02-03 18:48:23,092] Trial 766 finished with value: 0.6888925294888597 and parameters: {'n_estimators': 1192, 'num_leaves': 805, 'max_depth': 129, 'learning_rate': 0.011054210795040867, 'min_child_samples': 175, 'subsample': 0.31997760390925384, 'colsample_bytree': 0.335749502583348, 'reg_alpha': 0.03791744768443426, 'reg_lambda': 0.00014524127922420696, 'min_split_gain': 6.687587131968197e-05}. Best is trial 366 with value: 0.7117354740061161.
# [I 2025-02-03 18:48:25,252] Trial 767 finished with value: 0.6991590214067278 and parameters: {'n_estimators': 1076, 'num_leaves': 1484, 'max_depth': 123, 'learning_rate': 0.006859281776338036, 'min_child_samples': 179, 'subsample': 0.19103366385316922, 'colsample_bytree': 0.21827968563540046, 'reg_alpha': 15.357050623347561, 'reg_lambda': 0.000537172613372077, 'min_split_gain': 0.0007008327950351858}. Best is trial 366 with value: 0.7117354740061161.
# [I 2025-02-03 18:48:29,837] Trial 768 finished with value: 0.6684742245522062 and parameters: {'n_estimators': 2324, 'num_leaves': 1562, 'max_depth': 114, 'learning_rate': 1.0305425104014263e-05, 'min_child_samples': 189, 'subsample': 0.4092132538616266, 'colsample_bytree': 0.15983062256118868, 'reg_alpha': 2.7090601476033616, 'reg_lambda': 3.0017673168975447, 'min_split_gain': 0.0009768468521441363}. Best is trial 366 with value: 0.7117354740061161.
# [I 2025-02-03 18:48:31,916] Trial 769 finished with value: 0.7078363914373089 and parameters: {'n_estimators': 1026, 'num_leaves': 1528, 'max_depth': 144, 'learning_rate': 0.009824847350615869, 'min_child_samples': 171, 'subsample': 0.35549389492260053, 'colsample_bytree': 0.2671286572117728, 'reg_alpha': 4.003122574227386, 'reg_lambda': 28.373983281028472, 'min_split_gain': 0.0019031600561213995}. Best is trial 366 with value: 0.7117354740061161.
# [I 2025-02-03 18:48:34,207] Trial 770 finished with value: 0.7120085190039318 and parameters: {'n_estimators': 1171, 'num_leaves': 1352, 'max_depth': 133, 'learning_rate': 0.013047268869340142, 'min_child_samples': 165, 'subsample': 0.24314691590400292, 'colsample_bytree': 0.19334614890476431, 'reg_alpha': 5.901900488743287, 'reg_lambda': 3.858355492244645e-05, 'min_split_gain': 0.00045035353026440803}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:48:36,830] Trial 771 finished with value: 0.7036806465705547 and parameters: {'n_estimators': 1285, 'num_leaves': 1326, 'max_depth': 138, 'learning_rate': 0.006006442940635781, 'min_child_samples': 176, 'subsample': 0.256831472338506, 'colsample_bytree': 0.4587651750380308, 'reg_alpha': 5.04955848925347, 'reg_lambda': 2.845073565978391e-05, 'min_split_gain': 0.0002439147179344201}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:48:39,270] Trial 772 finished with value: 0.705919615552643 and parameters: {'n_estimators': 1226, 'num_leaves': 1347, 'max_depth': 134, 'learning_rate': 0.00480750513808368, 'min_child_samples': 166, 'subsample': 0.26173043530589224, 'colsample_bytree': 0.18320119834051973, 'reg_alpha': 1.5760833888288006, 'reg_lambda': 2.5586339915188047e-05, 'min_split_gain': 0.00038171811048266676}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:48:41,753] Trial 773 finished with value: 0.6882781782437746 and parameters: {'n_estimators': 1391, 'num_leaves': 1259, 'max_depth': 140, 'learning_rate': 0.007848221115308182, 'min_child_samples': 35, 'subsample': 0.2382350178888178, 'colsample_bytree': 0.14487641996963516, 'reg_alpha': 10.083254400440078, 'reg_lambda': 3.328883781038927e-05, 'min_split_gain': 0.00043833213294063836}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:48:43,996] Trial 774 finished with value: 0.7061708169506334 and parameters: {'n_estimators': 1176, 'num_leaves': 1365, 'max_depth': 133, 'learning_rate': 0.012748909954604273, 'min_child_samples': 197, 'subsample': 0.24017137589824328, 'colsample_bytree': 0.16586406758694544, 'reg_alpha': 3.434694740944997, 'reg_lambda': 1.5755751590928692e-05, 'min_split_gain': 0.00038573462761802313}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:48:46,317] Trial 775 finished with value: 0.7116016819571866 and parameters: {'n_estimators': 1244, 'num_leaves': 1373, 'max_depth': 137, 'learning_rate': 0.009145400387717252, 'min_child_samples': 174, 'subsample': 0.2199905973572159, 'colsample_bytree': 0.19118632540615355, 'reg_alpha': 6.352311128894369, 'reg_lambda': 3.907602114282302e-05, 'min_split_gain': 0.00034855867429522665}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:48:48,569] Trial 776 finished with value: 0.7112712975098296 and parameters: {'n_estimators': 1155, 'num_leaves': 1199, 'max_depth': 137, 'learning_rate': 0.008331420363161948, 'min_child_samples': 172, 'subsample': 0.21225778042238613, 'colsample_bytree': 0.19661518682928633, 'reg_alpha': 5.781097144781783, 'reg_lambda': 3.823803276652741e-05, 'min_split_gain': 0.0002775839279524401}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:48:50,950] Trial 777 finished with value: 0.6989788117081696 and parameters: {'n_estimators': 1237, 'num_leaves': 1224, 'max_depth': 142, 'learning_rate': 0.0023913248332453328, 'min_child_samples': 171, 'subsample': 0.20396082355019735, 'colsample_bytree': 0.2007973172408049, 'reg_alpha': 8.928597659477559, 'reg_lambda': 4.2404465871614204e-05, 'min_split_gain': 0.0002930957912100747}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:48:53,147] Trial 778 finished with value: 0.7066322629969419 and parameters: {'n_estimators': 1182, 'num_leaves': 1265, 'max_depth': 145, 'learning_rate': 0.009187922051266555, 'min_child_samples': 168, 'subsample': 0.20870746051304806, 'colsample_bytree': 0.19079942025179414, 'reg_alpha': 12.58099814966297, 'reg_lambda': 1.2052157809365579e-05, 'min_split_gain': 0.00022346696862454788}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:48:55,561] Trial 779 finished with value: 0.7055619266055047 and parameters: {'n_estimators': 1222, 'num_leaves': 1363, 'max_depth': 139, 'learning_rate': 0.006771561926622491, 'min_child_samples': 173, 'subsample': 0.22464968540925032, 'colsample_bytree': 0.22150934601375835, 'reg_alpha': 6.384331062966847, 'reg_lambda': 2.362245532625849e-05, 'min_split_gain': 0.00030434061781871806}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:48:57,746] Trial 780 finished with value: 0.7111402359108782 and parameters: {'n_estimators': 1147, 'num_leaves': 1023, 'max_depth': 138, 'learning_rate': 0.010405583965284081, 'min_child_samples': 177, 'subsample': 0.22133544657693127, 'colsample_bytree': 0.20375079904492058, 'reg_alpha': 7.685541112043778, 'reg_lambda': 3.307908817928549e-05, 'min_split_gain': 0.0003267570826819439}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:49:00,417] Trial 781 finished with value: 0.7113095238095238 and parameters: {'n_estimators': 1271, 'num_leaves': 1148, 'max_depth': 137, 'learning_rate': 0.010250494031100062, 'min_child_samples': 182, 'subsample': 0.21567468020582226, 'colsample_bytree': 0.19171125975126407, 'reg_alpha': 5.89588050767794, 'reg_lambda': 3.428816734488669e-05, 'min_split_gain': 0.0002077261681516345}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:49:03,028] Trial 782 finished with value: 0.704450633464395 and parameters: {'n_estimators': 1294, 'num_leaves': 1047, 'max_depth': 147, 'learning_rate': 0.011183994945219398, 'min_child_samples': 177, 'subsample': 0.21746126759787943, 'colsample_bytree': 0.22544120808045431, 'reg_alpha': 4.731105170521595, 'reg_lambda': 3.460250967074196e-05, 'min_split_gain': 0.00021622703990385918}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:49:05,555] Trial 783 finished with value: 0.7106432940148537 and parameters: {'n_estimators': 1275, 'num_leaves': 1196, 'max_depth': 140, 'learning_rate': 0.013068484759091984, 'min_child_samples': 181, 'subsample': 0.18279867837744826, 'colsample_bytree': 0.20749064681549073, 'reg_alpha': 8.673031672600672, 'reg_lambda': 2.9859410948809355e-05, 'min_split_gain': 0.00019032672002854644}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:49:08,185] Trial 784 finished with value: 0.7044752075141983 and parameters: {'n_estimators': 1346, 'num_leaves': 1165, 'max_depth': 143, 'learning_rate': 0.010496012571182428, 'min_child_samples': 177, 'subsample': 0.21727420370658676, 'colsample_bytree': 0.24936506230978556, 'reg_alpha': 5.336326630827901, 'reg_lambda': 4.0014601352751395e-05, 'min_split_gain': 0.0001507700245334381}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:49:10,435] Trial 785 finished with value: 0.6949759720401921 and parameters: {'n_estimators': 1251, 'num_leaves': 1093, 'max_depth': 137, 'learning_rate': 0.012695994442360102, 'min_child_samples': 173, 'subsample': 0.21975717210296103, 'colsample_bytree': 0.5260576549851292, 'reg_alpha': 34.18447422519505, 'reg_lambda': 1.9433690138937282e-05, 'min_split_gain': 0.0002613445928308051}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:49:12,945] Trial 786 finished with value: 0.7082514198339886 and parameters: {'n_estimators': 1340, 'num_leaves': 1187, 'max_depth': 152, 'learning_rate': 0.009701689004905641, 'min_child_samples': 184, 'subsample': 0.1708722471177433, 'colsample_bytree': 0.193925702747027, 'reg_alpha': 11.214463356434614, 'reg_lambda': 2.6604229613503004e-05, 'min_split_gain': 0.00018226982428653425}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:49:15,186] Trial 787 finished with value: 0.7078500436871996 and parameters: {'n_estimators': 1216, 'num_leaves': 1300, 'max_depth': 146, 'learning_rate': 0.010153634377044552, 'min_child_samples': 170, 'subsample': 0.2015944273037777, 'colsample_bytree': 0.23125529272183942, 'reg_alpha': 7.916784579305992, 'reg_lambda': 1.8109375782723216e-05, 'min_split_gain': 0.0001467671563746456}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:49:17,691] Trial 788 finished with value: 0.7091087811271297 and parameters: {'n_estimators': 1278, 'num_leaves': 943, 'max_depth': 142, 'learning_rate': 0.013628203683499977, 'min_child_samples': 178, 'subsample': 0.19837745187606487, 'colsample_bytree': 0.20856589596302844, 'reg_alpha': 5.3410358787244565, 'reg_lambda': 3.735637395097527e-05, 'min_split_gain': 0.00031274740298367404}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:49:20,029] Trial 789 finished with value: 0.7049557667103539 and parameters: {'n_estimators': 1189, 'num_leaves': 1169, 'max_depth': 138, 'learning_rate': 0.008075024592200242, 'min_child_samples': 175, 'subsample': 0.18996024336395037, 'colsample_bytree': 0.1839469169936796, 'reg_alpha': 15.94583069598333, 'reg_lambda': 2.093995085587657e-05, 'min_split_gain': 0.00024340615686543893}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:49:22,641] Trial 790 finished with value: 0.6920707732634339 and parameters: {'n_estimators': 1309, 'num_leaves': 1219, 'max_depth': 194, 'learning_rate': 0.000608047401366335, 'min_child_samples': 186, 'subsample': 0.2272891103488191, 'colsample_bytree': 0.198707155600387, 'reg_alpha': 4.138328739435588, 'reg_lambda': 3.2233217382769576e-05, 'min_split_gain': 0.00032434064172220625}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:49:25,007] Trial 791 finished with value: 0.7011549803407601 and parameters: {'n_estimators': 1237, 'num_leaves': 1314, 'max_depth': 137, 'learning_rate': 0.004069444197579627, 'min_child_samples': 166, 'subsample': 0.2305673202663543, 'colsample_bytree': 0.23157221761591393, 'reg_alpha': 7.595399151715774, 'reg_lambda': 5.130409243232596e-05, 'min_split_gain': 0.0002118776159055444}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:49:27,519] Trial 792 finished with value: 0.6902413717780691 and parameters: {'n_estimators': 1166, 'num_leaves': 1263, 'max_depth': 141, 'learning_rate': 0.011437061018761746, 'min_child_samples': 171, 'subsample': 0.19928336042128, 'colsample_bytree': 0.5634130143310192, 'reg_alpha': 2.955346490992101, 'reg_lambda': 4.1589022552136365e-05, 'min_split_gain': 0.0002521219523250679}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:49:30,059] Trial 793 finished with value: 0.7075906509392748 and parameters: {'n_estimators': 1384, 'num_leaves': 1070, 'max_depth': 137, 'learning_rate': 0.008817657079067585, 'min_child_samples': 181, 'subsample': 0.2180459182608128, 'colsample_bytree': 0.28948633768774756, 'reg_alpha': 12.077733674624142, 'reg_lambda': 1.5156811005383206e-05, 'min_split_gain': 0.00016527839745698894}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:49:32,453] Trial 794 finished with value: 0.710072629969419 and parameters: {'n_estimators': 1162, 'num_leaves': 1129, 'max_depth': 143, 'learning_rate': 0.006073147084082933, 'min_child_samples': 176, 'subsample': 0.17697400904222788, 'colsample_bytree': 0.2106202446535703, 'reg_alpha': 6.112466846082969, 'reg_lambda': 2.8281021726095914e-05, 'min_split_gain': 0.0003182823132622225}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:49:34,875] Trial 795 finished with value: 0.7082787243337701 and parameters: {'n_estimators': 1232, 'num_leaves': 1231, 'max_depth': 147, 'learning_rate': 0.01073053351313808, 'min_child_samples': 188, 'subsample': 0.2406011673529655, 'colsample_bytree': 0.18263330441734538, 'reg_alpha': 4.359772272911211, 'reg_lambda': 2.270589523961257e-05, 'min_split_gain': 0.0003053345545168622}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:49:37,356] Trial 796 finished with value: 0.7104002839667978 and parameters: {'n_estimators': 1313, 'num_leaves': 1316, 'max_depth': 136, 'learning_rate': 0.007305084666833556, 'min_child_samples': 168, 'subsample': 0.2112382101418827, 'colsample_bytree': 0.21424649191538758, 'reg_alpha': 8.45813620784696, 'reg_lambda': 4.1330898919955344e-05, 'min_split_gain': 0.00020866941813381656}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:49:39,637] Trial 797 finished with value: 0.7074486675404106 and parameters: {'n_estimators': 1171, 'num_leaves': 1160, 'max_depth': 28, 'learning_rate': 0.014004179564939297, 'min_child_samples': 173, 'subsample': 0.23064447307862954, 'colsample_bytree': 0.2487881198284736, 'reg_alpha': 6.506904027604957, 'reg_lambda': 2.95925242716821e-05, 'min_split_gain': 0.00014110155868545036}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:49:41,979] Trial 798 finished with value: 0.7075442332896461 and parameters: {'n_estimators': 1239, 'num_leaves': 1241, 'max_depth': 149, 'learning_rate': 0.009041452692981226, 'min_child_samples': 180, 'subsample': 0.20568356827584683, 'colsample_bytree': 0.18981067470097618, 'reg_alpha': 11.376002725422488, 'reg_lambda': 5.600361091491412e-05, 'min_split_gain': 0.0003259657591745958}. Best is trial 770 with value: 0.7120085190039318.
# [I 2025-02-03 18:49:44,260] Trial 799 finished with value: 0.7054718217562255 and parameters: {'n_estimators': 1170, 'num_leaves': 979, 'max_depth': 134, 'learning_rate': 0.011836369022682439, 'min_child_samples': 163, 'subsample': 0.1928512371948672, 'colsample_bytree': 0.23081173905854185, 'reg_alpha': 5.141212530282324, 'reg_lambda': 3.724375411585278e-05, 'min_split_gain': 0.00019606689607608486}. Best is trial 770 with value: 0.7120085190039318.
# Best trial:
#   Value: 0.7120085190039318
#   Params:
#     n_estimators: 1171
#     num_leaves: 1352
#     max_depth: 133
#     learning_rate: 0.013047268869340142
#     min_child_samples: 165
#     subsample: 0.24314691590400292
#     colsample_bytree: 0.19334614890476431
#     reg_alpha: 5.901900488743287
#     reg_lambda: 3.858355492244645e-05
#     min_split_gain: 0.00045035353026440803
#
# --- Model Performance ---
# Model Accuracy: 0.8664546899841018
# Model F1 Score: 0.0
# Model AUC: 0.7076589121887288

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# 모델 초기화
DI_model = LGBMClassifier(
    n_estimators=1171,
    num_leaves=1352,
    max_depth=133,
    learning_rate=0.013047268869340142,
    min_child_samples=165,
    subsample=0.24314691590400292,
    colsample_bytree=0.19334614890476431,
    reg_alpha=5.901900488743287,
    reg_lambda=3.858355492244645e-05,
    min_split_gain=0.00045035353026440803,
    random_state=42,
    objective='binary',
    metric='auc',
    verbose=-1,
    boosting_type='gbdt'
)

# 모델 학습
DI_model.fit(DI_X_train, DI_y_train)

# 예측
y_pred = DI_model.predict(DI_X_test)
y_pred_proba = DI_model.predict_proba(DI_X_test)[:, 1]

# 평가
accuracy = accuracy_score(DI_y_test, y_pred)
f1 = f1_score(DI_y_test, y_pred)
auc = roc_auc_score(DI_y_test, y_pred_proba)
cm = confusion_matrix(DI_y_test, y_pred)

# 결과 출력
print()
print("--- Model Performance ---")
print(f"Model Accuracy: {accuracy}")
print(f"Model F1 Score: {f1}")
print(f"Model AUC: {auc}")

# 혼동 행렬 출력
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=DI_model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# --- Model Performance ---
# Model Accuracy: 0.8664546899841018
# Model F1 Score: 0.0
# Model AUC: 0.7120085190039318

# %% [markdown]
# ## 제출

# %%
# 모델 구축
# IVF_model = CatBoostClassifier(
#     iterations=680,
#     depth=10,
#     learning_rate=0.01,
#     random_seed=42,
#     verbose=0
# )

# DI_model = CatBoostClassifier(
#     iterations=500,
#     depth=10,
#     learning_rate=0.01,
#     random_seed=42,
#     verbose=0
# )

# 모델 학습 및 예측
IVF_model.fit(IVF_X, IVF_y)
IVF_pred_proba = IVF_model.predict_proba(IVF_test.drop('ID', axis=1))[:, 1]

DI_model.fit(DI_X, DI_y)
DI_pred_proba = DI_model.predict_proba(DI_test.drop('ID', axis=1))[:, 1]

# %%
# 예측 결과 병합
IVF_test['probability'] = IVF_pred_proba
DI_test['probability'] = DI_pred_proba

# 최종 제출 파일 생성
submission = pd.concat([IVF_test[['ID', 'probability']], DI_test[['ID', 'probability']]], axis=0)
submission = submission.sort_values(by='ID')  

# 제출 파일 저장
submission.to_csv('./code14_submit.csv', index=False, encoding='utf-8')

# %% [markdown]
# .
