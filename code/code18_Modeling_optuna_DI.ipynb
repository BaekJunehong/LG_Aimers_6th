# %% [markdown]
# ## 난임 환자 대상 임신 성공 여부 예측

# %% [markdown]
# ### LGAimers 6th 온라인 해커톤

# %% [markdown]
# Import

# %%
import pandas as pd
import lightgbm as lgb
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
import lightgbm as lgb
import xgboost as xgb
from catboost import CatBoostClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ### Data Load

# %%
# 데이터 로드
IVF_train = pd.read_csv('../data/IVF_train_dataset_18.csv')
IVF_test = pd.read_csv('../data/IVF_test_dataset_18.csv')

DI_train = pd.read_csv('../data/DI_train_dataset_18.csv')
DI_test = pd.read_csv('../data/DI_test_dataset_18.csv')

# %%
# ID 열을 제외한 특성과 타겟 변수 분리
IVF_X = IVF_train.drop(['임신_성공_여부', 'ID'], axis=1)
IVF_y = IVF_train['임신_성공_여부']

DI_X = DI_train.drop(['임신_성공_여부', 'ID'], axis=1)
DI_y = DI_train['임신_성공_여부']

# %% [markdown]
# ### 인코딩

# %%
IVF_categorical_columns = [
    "시술_시기_코드",
    "시술_당시_나이",
    "배란_유도_유형",
    "난자_출처",
    "정자_출처",
    "난자_기증자_나이",
    "정자_기증자_나이",
    "난자_채취_경과일",
    "난자_해동_경과일",
    "변환된_특정_시술_유형"
]

# %%
DI_categorical_columns = [
    "시술_시기_코드",
    "시술_당시_나이",
    "정자_기증자_나이",
    "변환된_특정_시술_유형"
]

# %%
# 모든 범주형 변수를 문자열로 변환
IVF_X[IVF_categorical_columns] = IVF_X[IVF_categorical_columns].astype(str)
DI_X[DI_categorical_columns] = DI_X[DI_categorical_columns].astype(str)
IVF_test[IVF_categorical_columns] = IVF_test[IVF_categorical_columns].astype(str)
DI_test[DI_categorical_columns] = DI_test[DI_categorical_columns].astype(str)

# OrdinalEncoder를 사용하여 범주형 변수 인코딩
IVF_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
DI_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

IVF_X[IVF_categorical_columns] = IVF_encoder.fit_transform(IVF_X[IVF_categorical_columns])
DI_X[DI_categorical_columns] = DI_encoder.fit_transform(DI_X[DI_categorical_columns])
IVF_test[IVF_categorical_columns] = IVF_encoder.transform(IVF_test[IVF_categorical_columns])
DI_test[DI_categorical_columns] = DI_encoder.transform(DI_test[DI_categorical_columns])

# %% [markdown]
# ## Modeling

# %%
# 데이터 분할
IVF_X_train, IVF_X_test, IVF_y_train, IVF_y_test = train_test_split(IVF_X, IVF_y, test_size=0.2, random_state=42)
DI_X_train, DI_X_test, DI_y_train, DI_y_test = train_test_split(DI_X, DI_y, test_size=0.2, random_state=42)

# %% [markdown]
# ### Optuna - DI

# %%
import optuna
import lightgbm as lgb
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# 목적 함수 정의
def objective(trial):
    param = {
        'objective': 'binary',
        'metric': 'auc',
        'verbose': -1,
        'boosting_type': 'gbdt',
        'n_estimators': trial.suggest_int('n_estimators', 100, 5000),  
        'num_leaves': trial.suggest_int('num_leaves', 10, 4096), 
        'max_depth': trial.suggest_int('max_depth', 3, 300), 
        'learning_rate': trial.suggest_float('learning_rate', 1e-6, 1.0, log=True), 
        'min_child_samples': trial.suggest_int('min_child_samples', 1, 300), 
        'subsample': trial.suggest_float('subsample', 0.1, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.1, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-6, 1e3, log=True),  
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-6, 1e3, log=True),  
        'min_split_gain': trial.suggest_float('min_split_gain', 1e-6, 1e2, log=True),  
        'feature_fraction': trial.suggest_float('feature_fraction', 0.1, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.1, 1.0),
        'random_state': 42,
    }

    model = lgb.LGBMClassifier(**param)
    model.fit(DI_X_train, DI_y_train, eval_set=[(DI_X_test, DI_y_test)])
    
    y_pred_proba = model.predict_proba(DI_X_test)[:, 1]
    auc = roc_auc_score(DI_y_test, y_pred_proba)
    
    return auc

# Optuna 스터디 생성 및 최적화
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=800)

# 최적의 하이퍼파라미터 출력
print("Best trial:")
trial = study.best_trial
print("  Value: {}".format(trial.value))
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))

# 최적의 하이퍼파라미터로 모델 학습
best_params = trial.params
DI_model = lgb.LGBMClassifier(**best_params)
DI_model.fit(DI_X_train, DI_y_train)

# 예측
y_pred = DI_model.predict(DI_X_test)
y_pred_proba = DI_model.predict_proba(DI_X_test)[:, 1]

# 평가
accuracy = accuracy_score(DI_y_test, y_pred)
f1 = f1_score(DI_y_test, y_pred)
auc = roc_auc_score(DI_y_test, y_pred_proba)
cm = confusion_matrix(DI_y_test, y_pred)

# 결과 출력
print()
print("--- Model Performance ---")
print(f"Model Accuracy: {accuracy}")
print(f"Model F1 Score: {f1}")
print(f"Model AUC: {auc}")

# 혼동 행렬 출력
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=DI_model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# [I 2025-02-04 22:20:09,357] A new study created in memory with name: no-name-4c9cdfb6-61aa-4821-8234-f769b12fa4d3
# [I 2025-02-04 22:20:16,048] Trial 0 finished with value: 0.5 and parameters: {'n_estimators': 3296, 'num_leaves': 405, 'max_depth': 229, 'learning_rate': 5.097198186360367e-05, 'min_child_samples': 210, 'subsample': 0.4603977006031815, 'colsample_bytree': 0.3455612771061047, 'reg_alpha': 267.436261271025, 'reg_lambda': 2.0233784872916862, 'min_split_gain': 30.91092199395858, 'feature_fraction': 0.9755912364539063, 'bagging_fraction': 0.6557817104020044}. Best is trial 0 with value: 0.5.
# [I 2025-02-04 22:20:29,231] Trial 1 finished with value: 0.678191896024465 and parameters: {'n_estimators': 3720, 'num_leaves': 1590, 'max_depth': 69, 'learning_rate': 2.674431795909303e-05, 'min_child_samples': 295, 'subsample': 0.7183742183304929, 'colsample_bytree': 0.5011431260522243, 'reg_alpha': 2.1098773532830173e-05, 'reg_lambda': 1.0906557328610154, 'min_split_gain': 0.0002098966726715548, 'feature_fraction': 0.2867770635925927, 'bagging_fraction': 0.8723668931289963}. Best is trial 1 with value: 0.678191896024465.
# [I 2025-02-04 22:20:54,243] Trial 2 finished with value: 0.64099497597204 and parameters: {'n_estimators': 4591, 'num_leaves': 1728, 'max_depth': 63, 'learning_rate': 0.03296868500242815, 'min_child_samples': 150, 'subsample': 0.7250535390361066, 'colsample_bytree': 0.6245102060126555, 'reg_alpha': 0.19540412488194656, 'reg_lambda': 0.0003566212939713385, 'min_split_gain': 0.0001776893073567914, 'feature_fraction': 0.8181661325535425, 'bagging_fraction': 0.688436547031795}. Best is trial 1 with value: 0.678191896024465.
# [I 2025-02-04 22:21:09,062] Trial 3 finished with value: 0.6347531673219747 and parameters: {'n_estimators': 3898, 'num_leaves': 995, 'max_depth': 232, 'learning_rate': 0.8644522408499545, 'min_child_samples': 12, 'subsample': 0.3276583450072957, 'colsample_bytree': 0.9137897362909588, 'reg_alpha': 0.08689043144046844, 'reg_lambda': 14.793718811884284, 'min_split_gain': 0.0003311210856338731, 'feature_fraction': 0.6852538561839857, 'bagging_fraction': 0.329999453002984}. Best is trial 1 with value: 0.678191896024465.
# [I 2025-02-04 22:21:22,134] Trial 4 finished with value: 0.7076534512887724 and parameters: {'n_estimators': 4025, 'num_leaves': 2032, 'max_depth': 80, 'learning_rate': 0.13284678836843, 'min_child_samples': 158, 'subsample': 0.7763114459121392, 'colsample_bytree': 0.690770864897684, 'reg_alpha': 14.530041308981836, 'reg_lambda': 0.007460586254509881, 'min_split_gain': 0.0020855162840193397, 'feature_fraction': 0.8068557508014025, 'bagging_fraction': 0.9387086226439251}. Best is trial 4 with value: 0.7076534512887724.
# [I 2025-02-04 22:22:30,979] Trial 11 finished with value: 0.6938018785495849 and parameters: {'n_estimators': 2537, 'num_leaves': 2727, 'max_depth': 153, 'learning_rate': 0.0008384850542029727, 'min_child_samples': 78, 'subsample': 0.8204834332428232, 'colsample_bytree': 0.7353978236036153, 'reg_alpha': 0.0018810062612524775, 'reg_lambda': 0.016811024334115302, 'min_split_gain': 0.011325447824115166, 'feature_fraction': 0.5282760457681002, 'bagging_fraction': 0.15695468831874076}. Best is trial 4 with value: 0.7076534512887724.
# [I 2025-02-04 22:22:39,214] Trial 12 finished with value: 0.7016737658366099 and parameters: {'n_estimators': 2308, 'num_leaves': 3119, 'max_depth': 154, 'learning_rate': 0.10567241412449484, 'min_child_samples': 63, 'subsample': 0.6005185175203233, 'colsample_bytree': 0.8029219201890909, 'reg_alpha': 6.501465998316355, 'reg_lambda': 647.8210919894206, 'min_split_gain': 0.004503713560184636, 'feature_fraction': 0.5216729570720305, 'bagging_fraction': 0.35818615588134883}. Best is trial 4 with value: 0.7076534512887724.
# [I 2025-02-04 22:22:45,149] Trial 13 finished with value: 0.7045161642638705 and parameters: {'n_estimators': 2065, 'num_leaves': 3371, 'max_depth': 178, 'learning_rate': 0.15658812455170093, 'min_child_samples': 195, 'subsample': 0.5540849774298916, 'colsample_bytree': 0.9530697184596295, 'reg_alpha': 3.928951499776526, 'reg_lambda': 297.19412333816024, 'min_split_gain': 0.06053470198883681, 'feature_fraction': 0.6876815624162311, 'bagging_fraction': 0.39918168130206333}. Best is trial 4 with value: 0.7076534512887724.
# [I 2025-02-04 22:22:46,469] Trial 14 finished with value: 0.7084288990825688 and parameters: {'n_estimators': 376, 'num_leaves': 3962, 'max_depth': 200, 'learning_rate': 0.10206144785670015, 'min_child_samples': 199, 'subsample': 0.49514467687139685, 'colsample_bytree': 0.9902458667611012, 'reg_alpha': 4.962752244338601, 'reg_lambda': 0.00018264440638841354, 'min_split_gain': 0.0911485667626157, 'feature_fraction': 0.7237406131975571, 'bagging_fraction': 0.5315557846028013}. Best is trial 14 with value: 0.7084288990825688.
# [I 2025-02-04 22:22:53,417] Trial 15 finished with value: 0.6949650502402795 and parameters: {'n_estimators': 1688, 'num_leaves': 4068, 'max_depth': 4, 'learning_rate': 0.04039976825052349, 'min_child_samples': 172, 'subsample': 0.4216913715257303, 'colsample_bytree': 0.5731154965028152, 'reg_alpha': 48.059512914712045, 'reg_lambda': 0.0001519253500558385, 'min_split_gain': 1.1017852286309817, 'feature_fraction': 0.9506021778867979, 'bagging_fraction': 0.5700236405322399}. Best is trial 14 with value: 0.7084288990825688.
# [I 2025-02-04 22:22:54,498] Trial 16 finished with value: 0.7067332896461336 and parameters: {'n_estimators': 290, 'num_leaves': 2242, 'max_depth': 208, 'learning_rate': 0.0025399590056697, 'min_child_samples': 238, 'subsample': 0.9330451700378825, 'colsample_bytree': 0.9983649304265034, 'reg_alpha': 2.574404863635221, 'reg_lambda': 1.5809277458612516e-06, 'min_split_gain': 0.3499636433725756, 'feature_fraction': 0.7802254823927919, 'bagging_fraction': 0.7652959652065408}. Best is trial 14 with value: 0.7084288990825688.
# [I 2025-02-04 22
. Best is trial 14 with value: 0.7084288990825688.
# [I 2025-02-04 22:23:30,253] Trial 24 finished with value: 0.6965159458278725 and parameters: {'n_estimators': 479, 'num_leaves': 2157, 'max_depth': 103, 'learning_rate': 0.0015303000898666409, 'min_child_samples': 222, 'subsample': 0.9069338628109049, 'colsample_bytree': 0.761573963226226, 'reg_alpha': 18.36453822226171, 'reg_lambda': 0.07536910720274857, 'min_split_gain': 0.021943939092475228, 'feature_fraction': 0.9072471743422093, 'bagging_fraction': 0.8670000347817339}. Best is trial 14 with value: 0.7084288990825688.
# [I 2025-02-04 22:23:34,854] Trial 25 finished with value: 0.5 and parameters: {'n_estimators': 1830, 'num_leaves': 1326, 'max_depth': 255, 'learning_rate': 0.00025868118813209196, 'min_child_samples': 269, 'subsample': 0.7555350508815957, 'colsample_bytree': 0.9155405830981287, 'reg_alpha': 154.78945385242505, 'reg_lambda': 1.3394003467874817e-06, 'min_split_gain': 0.0022692768020225, 'feature_fraction': 0.42185136843719523, 'bagging_fraction': 0.5975045377635365}. Best is trial 14 with value: 0.7084288990825688.
# [I 2025-02-04 22:23:35,486] Trial 26 finished with value: 0.6900010921799913 and parameters: {'n_estimators': 130, 'num_leaves': 2000, 'max_depth': 121, 'learning_rate': 2.6827773592056533e-06, 'min_child_samples': 152, 'subsample': 0.9197473119283963, 'colsample_bytree': 0.8251660050851322, 'reg_alpha': 1.1157613335929826e-06, 'reg_lambda': 0.0009330720182950804, 'min_split_gain': 0.17338675235851633, 'feature_fraction': 0.6255802690830594, 'bagging_fraction': 0.7417540887883725}. Best is trial 14 with value: 0.7084288990825688.
# [I 2025-02-04 22:23:37,463] Trial 27 finished with value: 0.7029761904761904 and parameters: {'n_estimators': 669, 'num_leaves': 3407, 'max_depth': 179, 'learning_rate': 0.005755610028732591, 'min_child_samples': 224, 'subsample': 0.6792396205957805, 'colsample_bytree': 0.6957537072544315, 'reg_alpha': 2.455306535680827, 'reg_lambda': 7.657824549533077e-05, 'min_split_gain': 1.7313432787419079, 'feature_fraction': 0.7710420189892744, 'bagging_fraction': 0.8473786516944876}. Best is trial 14 with value: 0.7084288990825688.
# [I 2025-02-04 22:23:40,584] Trial 28 finished with value: 0.6974552206203583 and parameters: {'n_estimators': 1229, 'num_leaves': 4073, 'max_depth': 34, 'learning_rate': 0.3836229205383554, 'min_child_samples': 189, 'subsample': 0.5519952594931885, 'colsample_bytree': 0.5927972969680504, 'reg_alpha': 0.4816419291772976, 'reg_lambda': 9.110676434068353e-06, 'min_split_gain': 11.911564126694527, 'feature_fraction': 0.9907272481299794, 'bagging_fraction': 0.9172319495788765}. Best is trial 14 with value: 0.7084288990825688.
# [I 2025-02-04 22:23:51,161] Trial 29 finished with value: 0.5 and parameters: {'n_estimators': 4208, 'num_leaves': 2468, 'max_depth': 213, 'learning_rate': 0.00034610828065501163, 'min_child_samples': 277, 'subsample': 0.8185528341243311, 'colsample_bytree': 0.3117047034940784, 'reg_alpha': 167.4164971934971, 'reg_lambda': 0.002129810247440401, 'min_split_gain': 0.0011584908662088974, 'feature_fraction': 0.579021745861658, 'bagging_fraction': 0.4687129712205218}. Best is trial 14 with value: 0.7084288990825688.
# [I 2025-02-04 22
# [I 2025-02-04 22:29:08,679] Trial 78 finished with value: 0.700158366098733 and parameters: {'n_estimators': 2236, 'num_leaves': 3946, 'max_depth': 238, 'learning_rate': 0.7004192482362169, 'min_child_samples': 139, 'subsample': 0.2911949787154316, 'colsample_bytree': 0.6586912534532381, 'reg_alpha': 35.73865803969091, 'reg_lambda': 9.58891400691001e-05, 'min_split_gain': 0.0008630827077848744, 'feature_fraction': 0.6492173929954445, 'bagging_fraction': 0.3444463727605646}. Best is trial 76 with value: 0.7095702271734381.
# [I 2025-02-04 22:29:12,971] Trial 79 finished with value: 0.7044369812145042 and parameters: {'n_estimators': 1646, 'num_leaves': 3669, 'max_depth': 179, 'learning_rate': 0.3228778185659284, 'min_child_samples': 104, 'subsample': 0.34698395826993267, 'colsample_bytree': 0.7340278099966955, 'reg_alpha': 11.919054217304856, 'reg_lambda': 0.006859952625195335, 'min_split_gain': 0.0022353971092352706, 'feature_fraction': 0.9291677717967646, 'bagging_fraction': 0.26969354558148223}. Best is trial 76 with value: 0.7095702271734381.
# [I 2025-02-04 22:29:21,834] Trial 80 finished with value: 0.7015481651376146 and parameters: {'n_estimators': 3314, 'num_leaves': 4006, 'max_depth': 199, 'learning_rate': 0.12852998267811683, 'min_child_samples': 154, 'subsample': 0.14354691516284912, 'colsample_bytree': 0.5258445544809418, 'reg_alpha': 20.81915037035487, 'reg_lambda': 0.0004976022955130718, 'min_split_gain': 0.015229822661766527, 'feature_fraction': 0.7610452562567074, 'bagging_fraction': 0.2014514081688217}. Best is trial 76 with value: 0.7095702271734381.
# [I 2025-02-04 22:29:28,684] Trial 81 finished with value: 0.7082350371341197 and parameters: {'n_estimators': 2323, 'num_leaves': 3796, 'max_depth': 168, 'learning_rate': 0.07082566242629212, 'min_child_samples': 169, 'subsample': 0.24660707525909886, 'colsample_bytree': 0.781103435714238, 'reg_alpha': 7.124093492873714, 'reg_lambda': 0.01132095616727853, 'min_split_gain': 0.005663785055432968, 'feature_fraction': 0.7180081443225643, 'bagging_fraction': 0.23548204443358836}. Best is trial 76 with value: 0.7095702271734381.
# [I 2025-02-04 22:29:35,524] Trial 82 finished with value: 0.7051605504587156 and parameters: {'n_estimators': 2350, 'num_leaves': 3777, 'max_depth': 170, 'learning_rate': 0.07442109233073217, 'min_child_samples': 167, 'subsample': 0.2699282373266256, 'colsample_bytree': 0.6895900285218622, 'reg_alpha': 4.774359499377326, 'reg_lambda': 0.004399643717653823, 'min_split_gain': 0.010155767695187886, 'feature_fraction': 0.7184356290609325, 'bagging_fraction': 0.30199359165010764}. Best is trial 76 with value: 0.7095702271734381.
. Best is trial 280 with value: 0.7293223023154216.
# [I 2025-02-05 00:15:07,072] Trial 797 finished with value: 0.7150748143294015 and parameters: {'n_estimators': 4919, 'num_leaves': 2071, 'max_depth': 117, 'learning_rate': 0.7852255816765004, 'min_child_samples': 144, 'subsample': 0.11542790070343671, 'colsample_bytree': 0.5083010415009911, 'reg_alpha': 0.5043594811775982, 'reg_lambda': 0.0008741945722223073, 'min_split_gain': 3.205912777827967, 'feature_fraction': 0.5044468311035506, 'bagging_fraction': 0.49642541971745857}. Best is trial 280 with value: 0.7293223023154216.
# [I 2025-02-05 00:15:17,810] Trial 798 finished with value: 0.6944408038444736 and parameters: {'n_estimators': 4901, 'num_leaves': 2518, 'max_depth': 107, 'learning_rate': 0.0001874307022117423, 'min_child_samples': 125, 'subsample': 0.1714274491302441, 'colsample_bytree': 0.7940762432312513, 'reg_alpha': 0.13720557234343556, 'reg_lambda': 0.0019472578208913785, 'min_split_gain': 2.035421349914644, 'feature_fraction': 0.47619138441505193, 'bagging_fraction': 0.4474609551965357}. Best is trial 280 with value: 0.7293223023154216.
# [I 2025-02-05 00:15:21,402] Trial 799 finished with value: 0.6902550240279599 and parameters: {'n_estimators': 1470, 'num_leaves': 3851, 'max_depth': 124, 'learning_rate': 1.3322124317407464e-06, 'min_child_samples': 156, 'subsample': 0.14992930775925048, 'colsample_bytree': 0.4721215985602941, 'reg_alpha': 1.479067941228756, 'reg_lambda': 0.0039666926655899095, 'min_split_gain': 4.596295357129279, 'feature_fraction': 0.5191555349810849, 'bagging_fraction': 0.5187765574112486}. Best is trial 280 with value: 0.7293223023154216.
# Best trial:
#   Value: 0.7293223023154216
#   Params:
#     n_estimators: 4985
#     num_leaves: 3589
#     max_depth: 116
#     learning_rate: 0.9408098052377414
#     min_child_samples: 147
#     subsample: 0.1000438910979532
#     colsample_bytree: 0.7737092399079467
#     reg_alpha: 0.8391999025069735
#     reg_lambda: 0.001615734040141712
#     min_split_gain: 2.9310167497312576
#     feature_fraction: 0.5056932399627928
#     bagging_fraction: 0.5168135492726376
#
# --- Model Performance ---
# Model Accuracy: 0.8672496025437202
# Model F1 Score: 0.011834319526627219
# Model AUC: 0.6910741590214067

# %% [markdown]
# ### IVF 데이터

# %%
# 모델 초기화
IVF_model = lgb.LGBMClassifier(
    n_estimators=1258,
    num_leaves=923,
    max_depth=5,
    learning_rate=0.024413717866391526,
    min_child_samples=105,
    subsample=0.4890106069104924,
    colsample_bytree=0.4494069713807123,
    reg_alpha=3.0197481977859035,
    reg_lambda=0.4793565720612017,
    min_split_gain=0.29685405151668676,
    random_state=42,
    boosting_type='gbdt',
    verbose=-1
)

# 모델 학습
IVF_model.fit(IVF_X_train, IVF_y_train)

# 예측
y_pred = IVF_model.predict(IVF_X_test)
y_pred_proba = IVF_model.predict_proba(IVF_X_test)[:, 1]

# 평가
accuracy = accuracy_score(IVF_y_test, y_pred)
f1 = f1_score(IVF_y_test, y_pred)
auc = roc_auc_score(IVF_y_test, y_pred_proba)
cm = confusion_matrix(IVF_y_test, y_pred)

# 결과 출력
print()
print("--- Model Performance ---")
print(f"Model Accuracy: {accuracy}")
print(f"Model F1 Score: {f1}")
print(f"Model AUC: {auc}")

# 혼동 행렬 출력
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=IVF_model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# --- Model Performance ---
# Model Accuracy: 0.7462958149207174
# Model F1 Score: 0.20341536916122552
# Model AUC: 0.7401785794151994

# %% [markdown]
# ### DI 데이터

# %%
# 모델 초기화
DI_model = lgb.LGBMClassifier(
    n_estimators=2443,
    num_leaves=280,
    max_depth=149,
    learning_rate=0.061743249432816755,
    min_child_samples=176,
    subsample=0.9103802819067428,
    colsample_bytree=0.6636673663468106,
    reg_alpha=0.01173260476029451,
    reg_lambda=59.000778013447324,
    min_split_gain=1.1755604684312402,
    random_state=42,
    boosting_type='gbdt',
    verbose=-1
)

# 모델 학습
DI_model.fit(DI_X_train, DI_y_train)

# 예측
y_pred = DI_model.predict(DI_X_test)
y_pred_proba = DI_model.predict_proba(DI_X_test)[:, 1]

# 평가
accuracy = accuracy_score(DI_y_test, y_pred)
f1 = f1_score(DI_y_test, y_pred)
auc = roc_auc_score(DI_y_test, y_pred_proba)
cm = confusion_matrix(DI_y_test, y_pred)

# 결과 출력
print()
print("--- Model Performance ---")
print(f"Model Accuracy: {accuracy}")
print(f"Model F1 Score: {f1}")
print(f"Model AUC: {auc}")

# 혼동 행렬 출력
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=DI_model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# --- Model Performance ---
# Model Accuracy: 0.8664546899841018
# Model F1 Score: 0.0
# Model AUC: 0.7085135430318916

# %%
# 예측
IVF_y_pred = IVF_model.predict(IVF_X_test)
IVF_y_pred_proba = IVF_model.predict_proba(IVF_X_test)[:, 1]

DI_y_pred = DI_model.predict(DI_X_test)
DI_y_pred_proba = DI_model.predict_proba(DI_X_test)[:, 1]

# 예측 결과 병합
y_test = pd.concat([IVF_y_test, DI_y_test])
y_pred = pd.concat([pd.Series(IVF_y_pred, index=IVF_y_test.index), pd.Series(DI_y_pred, index=DI_y_test.index)])
y_pred_proba = pd.concat([pd.Series(IVF_y_pred_proba, index=IVF_y_test.index), pd.Series(DI_y_pred_proba, index=DI_y_test.index)])

# 평가
accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred_proba)
cm = confusion_matrix(y_test, y_pred)

# 결과 출력
print()
print("--- Model Performance ---")
print(f"Model Accuracy: {accuracy}")
print(f"Model F1 Score: {f1}")
print(f"Model AUC: {auc}")

# 혼동 행렬 출력
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=IVF_model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# --- Model Performance ---
# Model Accuracy: 0.749244182644483
# Model F1 Score: 0.20129224652087474
# Model AUC: 0.741842257077582

# %% [markdown]
# 데이콘 PUBLIC 몰루??

# %% [markdown]
# ## 제출

# %%
# 모델 구축
IVF_model = lgb.LGBMClassifier(
    n_estimators=1258,
    num_leaves=923,
    max_depth=5,
    learning_rate=0.024413717866391526,
    min_child_samples=105,
    subsample=0.4890106069104924,
    colsample_bytree=0.4494069713807123,
    reg_alpha=3.0197481977859035,
    reg_lambda=0.4793565720612017,
    min_split_gain=0.29685405151668676,
    random_state=42,
    boosting_type='gbdt',
    verbose=-1
)

DI_model = lgb.LGBMClassifier(
    n_estimators=2443,
    num_leaves=280,
    max_depth=149,
    learning_rate=0.061743249432816755,
    min_child_samples=176,
    subsample=0.9103802819067428,
    colsample_bytree=0.6636673663468106,
    reg_alpha=0.01173260476029451,
    reg_lambda=59.000778013447324,
    min_split_gain=1.1755604684312402,
    random_state=42,
    boosting_type='gbdt',
    verbose=-1
)

# 모델 학습 및 예측
IVF_model.fit(IVF_X, IVF_y)
IVF_pred_proba = IVF_model.predict_proba(IVF_test.drop('ID', axis=1))[:, 1]

DI_model.fit(DI_X, DI_y)
DI_pred_proba = DI_model.predict_proba(DI_test.drop('ID', axis=1))[:, 1]

# %%
# 예측 결과 병합
IVF_test['probability'] = IVF_pred_proba
DI_test['probability'] = DI_pred_proba

# 최종 제출 파일 생성
submission = pd.concat([IVF_test[['ID', 'probability']], DI_test[['ID', 'probability']]], axis=0)
submission = submission.sort_values(by='ID')  

# 제출 파일 저장
submission.to_csv('.submission/code18_submit.csv', index=False, encoding='utf-8')

# %% [markdown]
# .
