# %% [markdown]
# ## 난임 환자 대상 임신 성공 여부 예측

# %% [markdown]
# ### LGAimers 6th 온라인 해커톤

# %% [markdown]
# Import

# %%
import pandas as pd

# 두 CSV 파일을 읽어옵니다.
df1 = pd.read_csv('../submission/code26_submit_testing.csv')
df2 = pd.read_csv('../submission/code26_submit_xgb_testing.csv')

# ID를 기준으로 병합합니다.
merged_df = pd.merge(df1, df2, on='ID', suffixes=('_df1', '_df2'))

# 'probability' 열을 소프트 보팅하여 새로운 'probability' 열 생성
merged_df['probability'] = (merged_df['probability_df1'] + merged_df['probability_df2']) / 2

# 최종 제출 파일 생성
submission = merged_df[['ID', 'probability']]
submission = submission.sort_values(by='ID')

# 제출 파일 저장
submission.to_csv('../submission/code28_soft_voting_submit_LgbmXgb.csv', index=False, encoding='utf-8')

# %% [markdown]
# 데이콘 PUBLIC 0.7394729894

# %%
import pandas as pd

# 두 CSV 파일을 읽어옵니다.
df1 = pd.read_csv('../submission/code26_submit_testing.csv')
df2 = pd.read_csv('../submission/code26_submit_xgb_testing.csv')

# ID를 기준으로 병합합니다.
merged_df = pd.merge(df1, df2, on='ID', suffixes=('_df1', '_df2'))

# 'probability' 열을 조건에 따라 선택하여 새로운 'probability' 열 생성
def select_probability(row):
    if row['probability_df1'] > 0.8 and row['probability_df2'] > 0.8:
        return max(row['probability_df1'], row['probability_df2'])
    elif row['probability_df1'] < 0.5 and row['probability_df2'] < 0.5:
        return min(row['probability_df1'], row['probability_df2'])
    else:
        return row['probability_df1']

merged_df['probability'] = merged_df.apply(select_probability, axis=1)

# 최종 제출 파일 생성
submission = merged_df[['ID', 'probability']]
submission = submission.sort_values(by='ID')

# 제출 파일 저장
submission.to_csv('../submission/code28_voting_upgrad_submit_LgbmXgb.csv', index=False, encoding='utf-8')

# %% [markdown]
# 데이콘 PUBLIC 0.7392099624

# %%
import pandas as pd

# 두 CSV 파일을 읽어옵니다.
df1 = pd.read_csv('../submission/code26_submit_testing.csv')
df2 = pd.read_csv('../submission/code26_submit_xgb_testing.csv')

# ID를 기준으로 병합합니다.
merged_df = pd.merge(df1, df2, on='ID', suffixes=('_df1', '_df2'))

# 'probability' 열을 조건에 따라 선택하여 새로운 'probability' 열 생성
def select_probability(row):
    if row['probability_df1'] > 0.35 and row['probability_df2'] > 0.35:
        return max(row['probability_df1'], row['probability_df2'])
    elif row['probability_df1'] < 0.25 and row['probability_df2'] < 0.25:
        return min(row['probability_df1'], row['probability_df2'])
    else:
        return row['probability_df1']

merged_df['probability'] = merged_df.apply(select_probability, axis=1)

# 최종 제출 파일 생성
submission = merged_df[['ID', 'probability']]
submission = submission.sort_values(by='ID')

# 제출 파일 저장
submission.to_csv('../submission/code28_voting_upgrad_submit_LgbmXgb_xx.csv', index=False, encoding='utf-8')

# %%
import pandas as pd

# 두 CSV 파일을 읽어옵니다.
df1 = pd.read_csv('../submission/code26_submit_testing.csv')
df2 = pd.read_csv('../submission/code26_submit_xgb_testing.csv')

# ID를 기준으로 병합하여 값이 다른 행을 찾습니다.
merged_df = pd.merge(df1, df2, on='ID', suffixes=('_df1', '_df2'))

# 'probability' 열의 값이 다른 행을 필터링합니다.
different_rows = merged_df[merged_df['probability_df1'] != merged_df['probability_df2']]

# %%
different_rows.tail(50)
# Out:
#                ID  probability_df1  probability_df2
# 90017  TEST_90017         0.529201         0.486262
# 90018  TEST_90018         0.056604         0.048049
# 90019  TEST_90019         0.447655         0.403214
# 90020  TEST_90020         0.000405         0.000958
# 90021  TEST_90021         0.453078         0.401443
# 90022  TEST_90022         0.000449         0.001010
# 90023  TEST_90023         0.657001         0.622058
# 90024  TEST_90024         0.000291         0.000444
# 90025  TEST_90025         0.558374         0.527393
# 90026  TEST_90026         0.422382         0.366257
# 90027  TEST_90027         0.039235         0.032595
# 90028  TEST_90028         0.223336         0.216669
# 90029  TEST_90029         0.081708         0.082414
# 90030  TEST_90030         0.474509         0.418522
# 90031  TEST_90031         0.181340         0.175883
# 90032  TEST_90032         0.186692         0.185137
# 90033  TEST_90033         0.291185         0.262903
# 90034  TEST_90034         0.588703         0.556877
# 90035  TEST_90035         0.488544         0.463450
# 90036  TEST_90036         0.362375         0.338403
# 90037  TEST_90037         0.592724         0.559089
# 90038  TEST_90038         0.584009         0.537773
# 90039  TEST_90039         0.258512         0.237623
# 90040  TEST_90040         0.000493         0.001197
# 90041  TEST_90041         0.393142         0.351765
# 90042  TEST_90042         0.000472         0.000667
# 90043  TEST_90043         0.239674         0.251854
# 90044  TEST_90044         0.526428         0.488350
# 90045  TEST_90045         0.448490         0.420851
# 90046  TEST_90046         0.193813         0.233192
# 90047  TEST_90047         0.726722         0.681112
# 90048  TEST_90048         0.810968         0.823342
# 90049  TEST_90049         0.547643         0.543876
# 90050  TEST_90050         0.000234         0.000607
# 90051  TEST_90051         0.247197         0.231017
# 90052  TEST_90052         0.316199         0.300774
# 90053  TEST_90053         0.734649         0.690176
# 90054  TEST_90054         0.333937         0.296108
# 90055  TEST_90055         0.437767         0.405057
# 90056  TEST_90056         0.000395         0.000594
# 90057  TEST_90057         0.437969         0.391766
# 90058  TEST_90058         0.289581         0.273646
# 90059  TEST_90059         0.577916         0.544263
# 90060  TEST_90060         0.384438         0.369071
# 90061  TEST_90061         0.551967         0.510165
# 90062  TEST_90062         0.000806         0.001687
# 90063  TEST_90063         0.431523         0.378891
# 90064  TEST_90064         0.738606         0.635446
# 90065  TEST_90065         0.306037         0.266505
# 90066  TEST_90066         0.000422         0.000854

# %% [markdown]
# .
