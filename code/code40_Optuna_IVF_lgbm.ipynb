# %% [markdown]
# ## 난임 환자 대상 임신 성공 여부 예측

# %% [markdown]
# ### LGAimers 6th 온라인 해커톤

# %% [markdown]
# Import

# %%
import pandas as pd
import lightgbm as lgb
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data Load

# %%
# 데이터 로드
IVF_train = pd.read_csv('../data/IVF_train_dataset_40.csv')
IVF_test = pd.read_csv('../data/IVF_test_dataset_40.csv')

# %%
# ID 열을 제외한 특성과 타겟 변수 분리
IVF_X = IVF_train.drop(['임신_성공_여부', 'ID'], axis=1)
IVF_y = IVF_train['임신_성공_여부']

# %%
print(f"IVF_X shape: {IVF_X.shape}")
print(f"IVF_test shape: {IVF_test.drop('ID', axis=1).shape}")
# Out:
# IVF_X shape: (250052, 70)
# IVF_test shape: (87891, 66)

# %% [markdown]
# ### 인코딩

# %%
IVF_categorical_columns = [
    "시술_당시_나이",
    "난자_출처",
    "정자_출처",
    "난자_기증자_나이",
    "정자_기증자_나이",
    "채취_해동_차이",
    "해동_혼합_차이",
    "혼합_이식_차이",
    "이식_해동_차이"
]

# %%
# 모든 범주형 변수를 문자열로 변환
IVF_X[IVF_categorical_columns] = IVF_X[IVF_categorical_columns].astype(str)
IVF_test[IVF_categorical_columns] = IVF_test[IVF_categorical_columns].astype(str)

# OrdinalEncoder를 사용하여 범주형 변수 인코딩
IVF_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

IVF_X[IVF_categorical_columns] = IVF_encoder.fit_transform(IVF_X[IVF_categorical_columns])
IVF_test[IVF_categorical_columns] = IVF_encoder.transform(IVF_test[IVF_categorical_columns])

# %% [markdown]
# ## Modeling

# %%
# 데이터 분할
IVF_X_train, IVF_X_test, IVF_y_train, IVF_y_test = train_test_split(IVF_X, IVF_y, test_size=0.2, random_state=42)

# %% [markdown]
# ### IVF 데이터

# %%
import optuna
import lightgbm as lgb
from sklearn.metrics import roc_auc_score

# 목적 함수 정의
def objective(trial):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 500, 5000),
        'num_leaves': trial.suggest_int('num_leaves', 1000, 5000),
        'learning_rate': trial.suggest_float('learning_rate', 0.00005, 0.5),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 500),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 200.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 200.0),

        'random_state': 42,
        'n_jobs': -1,
        'metric': 'auc',
        'objective': 'binary',
        'boosting_type': 'gbdt',
        'verbose': -1
    }

    model = lgb.LGBMClassifier(**param)
    model.fit(IVF_X_train, IVF_y_train)
    
    y_pred_proba = model.predict_proba(IVF_X_test)[:, 1]
    
    auc = roc_auc_score(IVF_y_test, y_pred_proba)
    return auc

# Optuna 스터디 생성 및 최적화 실행
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=800)

# 최적의 하이퍼파라미터 출력
print("Best trial:")
trial = study.best_trial
print(f"  Value: {trial.value}")
print("  Params: ")
for key, value in trial.params.items():
    print(f"    {key}: {value}")
# Out:
# [I 2025-02-18 20:54:56,252] A new study created in memory with name: no-name-07d57dc0-53a7-42f0-a721-09aa26889776
# [I 2025-02-18 20:54:59,789] Trial 0 finished with value: 0.7366870417622595 and parameters: {'n_estimators': 2910, 'num_leaves': 2753, 'learning_rate': 0.2985073362673544, 'min_child_samples': 275, 'reg_alpha': 162.8840913068425, 'reg_lambda': 174.57772039280832}. Best is trial 0 with value: 0.7366870417622595.
# [I 2025-02-18 20:55:01,969] Trial 1 finished with value: 0.7375556747315895 and parameters: {'n_estimators': 1587, 'num_leaves': 2031, 'learning_rate': 0.31769813302090305, 'min_child_samples': 172, 'reg_alpha': 94.97302291429637, 'reg_lambda': 63.01853798853514}. Best is trial 1 with value: 0.7375556747315895.
# [I 2025-02-18 20:55:07,017] Trial 2 finished with value: 0.7371818399889667 and parameters: {'n_estimators': 3560, 'num_leaves': 2735, 'learning_rate': 0.09110944027727194, 'min_child_samples': 292, 'reg_alpha': 132.99211454239784, 'reg_lambda': 142.09002755241607}. Best is trial 1 with value: 0.7375556747315895.
# [I 2025-02-18 20:55:09,849] Trial 3 finished with value: 0.7376962623524739 and parameters: {'n_estimators': 1435, 'num_leaves': 2829, 'learning_rate': 0.11412022050831903, 'min_child_samples': 138, 'reg_alpha': 97.99263443960112, 'reg_lambda': 71.83209205490206}. Best is trial 3 with value: 0.7376962623524739.
# [I 2025-02-18 20:55:12,631] Trial 4 finished with value: 0.7374641876468458 and parameters: {'n_estimators': 2097, 'num_leaves': 3423, 'learning_rate': 0.35854281607102884, 'min_child_samples': 149, 'reg_alpha': 86.91546413279976, 'reg_lambda': 31.43561349289874}. Best is trial 3 with value: 0.7376962623524739.
# [I 2025-02-18 20:55:16,468] Trial 5 finished with value: 0.737091736209073 and parameters: {'n_estimators': 3260, 'num_leaves': 2466, 'learning_rate': 0.15443703967723996, 'min_child_samples': 467, 'reg_alpha': 139.46421474070323, 'reg_lambda': 104.25646583764828}. Best is trial 3 with value: 0.7376962623524739.
# [I 2025-02-18 20:55:52,993] Trial 6 finished with value: 0.6859681120273724 and parameters: {'n_estimators': 3911, 'num_leaves': 3605, 'learning_rate': 0.3529045373833893, 'min_child_samples': 7, 'reg_alpha': 1.7948313202395427, 'reg_lambda': 13.538218032328198}. Best is trial 3 with value: 0.7376962623524739.
# [I 2025-02-18 20:55:58,842] Trial 7 finished with value: 0.7367230786806009 and parameters: {'n_estimators': 3319, 'num_leaves': 3161, 'learning_rate': 0.04117873348062424, 'min_child_samples': 244, 'reg_alpha': 185.20585780099157, 'reg_lambda': 96.80594393824254}. Best is trial 3 with value: 0.7376962623524739.
# [I 2025-02-18 20:56:03,262] Trial 8 finished with value: 0.7370079288152536 and parameters: {'n_estimators': 2545, 'num_leaves': 2220, 'learning_rate': 0.07440023224416395, 'min_child_samples': 30, 'reg_alpha': 127.54494363677387, 'reg_lambda': 172.25132506753008}. Best is trial 3 with value: 0.7376962623524739.
# [I 2025-02-18 20:56:11,962] Trial 9 finished with value: 0.7221725261399934 and parameters: {'n_estimators': 3398, 'num_leaves': 3068, 'learning_rate': 0.4795811038583609, 'min_child_samples': 306, 'reg_alpha': 7.743602135795702, 'reg_lambda': 120.03101727544544}. Best is trial 3 with value: 0.7376962623524739.
# [I 2025-02-18 20:56:14,107] Trial 10 finished with value: 0.7380954580320092 and parameters: {'n_estimators': 976, 'num_leaves': 4899, 'learning_rate': 0.18423672747468822, 'min_child_samples': 438, 'reg_alpha': 51.042496261037854, 'reg_lambda': 58.96077953454479}. Best is trial 10 with value: 0.7380954580320092.
# [I 2025-02-18 20:56:15,919] Trial 11 finished with value: 0.7380192436768102 and parameters: {'n_estimators': 559, 'num_leaves': 4932, 'learning_rate': 0.18371797192778133, 'min_child_samples': 493, 'reg_alpha': 47.52824290020443, 'reg_lambda': 65.929441964997}. Best is trial 10 with value: 0.7380954580320092.
# [I 2025-02-18 20:56:17,573] Trial 12 finished with value: 0.7381728729914174 and parameters: {'n_estimators': 554, 'num_leaves': 4929, 'learning_rate': 0.20107419679459249, 'min_child_samples': 494, 'reg_alpha': 49.53770524569017, 'reg_lambda': 51.35116912115875}. Best is trial 12 with value: 0.7381728729914174.
# [I 2025-02-18 20:56:18,973] Trial 13 finished with value: 0.7378497893547223 and parameters: {'n_estimators': 500, 'num_leaves': 4939, 'learning_rate': 0.22520586575292095, 'min_child_samples': 409, 'reg_alpha': 51.56430083465108, 'reg_lambda': 35.228133123401506}. Best is trial 12 with value: 0.7381728729914174.
# [I 2025-02-18 20:56:49,319] Trial 14 finished with value: 0.7331792312242685 and parameters: {'n_estimators': 4886, 'num_leaves': 4418, 'learning_rate': 0.00030318671611850867, 'min_child_samples': 386, 'reg_alpha': 50.03115018457112, 'reg_lambda': 41.19614281704098}. Best is trial 12 with value: 0.7381728729914174.
# [I 2025-02-18 20:56:51,769] Trial 15 finished with value: 0.7377585225547512 and parameters: {'n_estimators': 1219, 'num_leaves': 4053, 'learning_rate': 0.23987705081410332, 'min_child_samples': 386, 'reg_alpha': 29.728863008718847, 'reg_lambda': 84.02811883281625}. Best is trial 12 with value: 0.7381728729914174.
# [I 2025-02-18 20:56:53,741] Trial 16 finished with value: 0.73800835054262 and parameters: {'n_estimators': 965, 'num_leaves': 1210, 'learning_rate': 0.17847260195162173, 'min_child_samples': 438, 'reg_alpha': 68.95597888675292, 'reg_lambda': 1.2710572131187376}. Best is trial 12 with value: 0.7381728729914174.
# [I 2025-02-18 20:56:57,018] Trial 17 finished with value: 0.7368441434330404 and parameters: {'n_estimators': 2005, 'num_leaves': 4355, 'learning_rate': 0.4541173019948487, 'min_child_samples': 344, 'reg_alpha': 22.481366029933355, 'reg_lambda': 51.22732687727078}. Best is trial 12 with value: 0.7381728729914174.
# [I 2025-02-18 20:57:00,421] Trial 18 finished with value: 0.7381110711067469 and parameters: {'n_estimators': 1874, 'num_leaves': 3959, 'learning_rate': 0.13784883399425021, 'min_child_samples': 489, 'reg_alpha': 65.78986341038885, 'reg_lambda': 130.8690867571081}. Best is trial 12 with value: 0.7381728729914174.
# [I 2025-02-18 20:57:03,962] Trial 19 finished with value: 0.7380637902689855 and parameters: {'n_estimators': 1946, 'num_leaves': 3956, 'learning_rate': 0.2787544738997463, 'min_child_samples': 498, 'reg_alpha': 72.89711894549627, 'reg_lambda': 146.8986998116111}. Best is trial 12 with value: 0.7381728729914174.
# [I 2025-02-18 20:57:08,283] Trial 20 finished with value: 0.7373036877441512 and parameters: {'n_estimators': 2415, 'num_leaves': 4471, 'learning_rate': 0.1246929229732452, 'min_child_samples': 354, 'reg_alpha': 115.4182918685215, 'reg_lambda': 133.49062003273357}. Best is trial 12 with value: 0.7381728729914174.
# [I 2025-02-18 20:57:10,394] Trial 21 finished with value: 0.7378271616193921 and parameters: {'n_estimators': 824, 'num_leaves': 4702, 'learning_rate': 0.19839817323111628, 'min_child_samples': 443, 'reg_alpha': 68.00741148048851, 'reg_lambda': 193.72340078721885}. Best is trial 12 with value: 0.7381728729914174.
# [I 2025-02-18 20:57:13,353] Trial 22 finished with value: 0.7382660565821086 and parameters: {'n_estimators': 1119, 'num_leaves': 3978, 'learning_rate': 0.14403012118259723, 'min_child_samples': 451, 'reg_alpha': 33.037265876680515, 'reg_lambda': 93.39057945907881}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:57:17,632] Trial 23 finished with value: 0.7378880531328709 and parameters: {'n_estimators': 1571, 'num_leaves': 3922, 'learning_rate': 0.13944035894918785, 'min_child_samples': 474, 'reg_alpha': 28.591360057205385, 'reg_lambda': 108.92474843076184}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:57:22,251] Trial 24 finished with value: 0.7378881992933832 and parameters: {'n_estimators': 1367, 'num_leaves': 3598, 'learning_rate': 0.059895651773709785, 'min_child_samples': 417, 'reg_alpha': 80.09337417884427, 'reg_lambda': 92.54125867472757}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:57:26,735] Trial 25 finished with value: 0.7379531530251038 and parameters: {'n_estimators': 1810, 'num_leaves': 4254, 'learning_rate': 0.23011220207774238, 'min_child_samples': 348, 'reg_alpha': 36.06442776634915, 'reg_lambda': 120.54425482148994}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:57:38,329] Trial 26 finished with value: 0.7359488330381823 and parameters: {'n_estimators': 1063, 'num_leaves': 3783, 'learning_rate': 0.033236386011383706, 'min_child_samples': 500, 'reg_alpha': 12.330472228803632, 'reg_lambda': 84.5698505971081}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:57:40,814] Trial 27 finished with value: 0.7379030836535662 and parameters: {'n_estimators': 739, 'num_leaves': 4655, 'learning_rate': 0.09961596741522685, 'min_child_samples': 455, 'reg_alpha': 63.63028301043529, 'reg_lambda': 154.99522618320242}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:57:44,875] Trial 28 finished with value: 0.7382425153435757 and parameters: {'n_estimators': 2351, 'num_leaves': 4170, 'learning_rate': 0.15168845832375555, 'min_child_samples': 393, 'reg_alpha': 44.091334453840304, 'reg_lambda': 128.48514656149058}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:57:49,413] Trial 29 finished with value: 0.7381343200242549 and parameters: {'n_estimators': 2879, 'num_leaves': 4180, 'learning_rate': 0.2637659247973201, 'min_child_samples': 213, 'reg_alpha': 36.81567106963949, 'reg_lambda': 163.87233496414126}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:57:56,309] Trial 30 finished with value: 0.7375412570410427 and parameters: {'n_estimators': 4270, 'num_leaves': 3413, 'learning_rate': 0.21332150225467617, 'min_child_samples': 398, 'reg_alpha': 109.939783411295, 'reg_lambda': 78.01243546265674}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:58:00,925] Trial 31 finished with value: 0.7377336836196686 and parameters: {'n_estimators': 2913, 'num_leaves': 4146, 'learning_rate': 0.2743476264516349, 'min_child_samples': 233, 'reg_alpha': 38.691984426528784, 'reg_lambda': 160.57048499482548}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:58:07,324] Trial 32 finished with value: 0.7353693024304129 and parameters: {'n_estimators': 2884, 'num_leaves': 4614, 'learning_rate': 0.3037560516680345, 'min_child_samples': 206, 'reg_alpha': 15.723167423448213, 'reg_lambda': 183.11550585465548}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:58:11,375] Trial 33 finished with value: 0.7375999707628863 and parameters: {'n_estimators': 2334, 'num_leaves': 1469, 'learning_rate': 0.3432731673021146, 'min_child_samples': 76, 'reg_alpha': 37.980320425734575, 'reg_lambda': 115.40020391992957}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:58:16,146] Trial 34 finished with value: 0.7376271733222555 and parameters: {'n_estimators': 2681, 'num_leaves': 4284, 'learning_rate': 0.26586058751728375, 'min_child_samples': 284, 'reg_alpha': 22.99252842540696, 'reg_lambda': 159.85743781382754}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:58:21,544] Trial 35 finished with value: 0.7378397502155262 and parameters: {'n_estimators': 3764, 'num_leaves': 4581, 'learning_rate': 0.41116910269094453, 'min_child_samples': 196, 'reg_alpha': 55.17867254500821, 'reg_lambda': 136.69925383488305}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:58:25,387] Trial 36 finished with value: 0.7377308929978851 and parameters: {'n_estimators': 2192, 'num_leaves': 3681, 'learning_rate': 0.1480929278801759, 'min_child_samples': 329, 'reg_alpha': 79.07436542864947, 'reg_lambda': 168.89850725683462}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:58:30,383] Trial 37 finished with value: 0.737691091402345 and parameters: {'n_estimators': 2964, 'num_leaves': 3350, 'learning_rate': 0.15894270820478762, 'min_child_samples': 115, 'reg_alpha': 92.46316363123564, 'reg_lambda': 25.74787744790094}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:58:33,177] Trial 38 finished with value: 0.7380160876537456 and parameters: {'n_estimators': 1722, 'num_leaves': 2810, 'learning_rate': 0.25245377642033073, 'min_child_samples': 168, 'reg_alpha': 41.791764945591424, 'reg_lambda': 145.97602171250935}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:58:36,229] Trial 39 finished with value: 0.7366379756782393 and parameters: {'n_estimators': 1292, 'num_leaves': 4771, 'learning_rate': 0.09206041505699639, 'min_child_samples': 267, 'reg_alpha': 180.01838587607097, 'reg_lambda': 199.44590354519772}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:58:41,128] Trial 40 finished with value: 0.7370742825558824 and parameters: {'n_estimators': 3065, 'num_leaves': 2501, 'learning_rate': 0.31977527294833735, 'min_child_samples': 370, 'reg_alpha': 144.25359382850687, 'reg_lambda': 183.04716721333688}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:58:44,547] Trial 41 finished with value: 0.7380107047708737 and parameters: {'n_estimators': 1536, 'num_leaves': 3813, 'learning_rate': 0.11915933944020453, 'min_child_samples': 460, 'reg_alpha': 61.086604296836015, 'reg_lambda': 127.39884960536168}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:58:59,584] Trial 42 finished with value: 0.7203701456930494 and parameters: {'n_estimators': 2261, 'num_leaves': 4107, 'learning_rate': 0.17053317470243884, 'min_child_samples': 476, 'reg_alpha': 4.613119420939654, 'reg_lambda': 105.09971760288506}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:59:03,489] Trial 43 finished with value: 0.7380930724836459 and parameters: {'n_estimators': 2694, 'num_leaves': 3566, 'learning_rate': 0.2086336201662512, 'min_child_samples': 427, 'reg_alpha': 58.21790171516127, 'reg_lambda': 96.65405135951232}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:59:05,985] Trial 44 finished with value: 0.7381295082113852 and parameters: {'n_estimators': 708, 'num_leaves': 4129, 'learning_rate': 0.13435548153457322, 'min_child_samples': 470, 'reg_alpha': 26.766414710202486, 'reg_lambda': 129.60964608105843}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:59:10,351] Trial 45 finished with value: 0.7371557670415578 and parameters: {'n_estimators': 627, 'num_leaves': 3143, 'learning_rate': 0.07145484436532462, 'min_child_samples': 311, 'reg_alpha': 17.516313382201613, 'reg_lambda': 142.56993339536405}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:59:29,928] Trial 46 finished with value: 0.7122579219645016 and parameters: {'n_estimators': 1056, 'num_leaves': 4240, 'learning_rate': 0.10742863403491104, 'min_child_samples': 409, 'reg_alpha': 0.3740627659022948, 'reg_lambda': 52.45333421524017}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:59:32,027] Trial 47 finished with value: 0.737640882134317 and parameters: {'n_estimators': 808, 'num_leaves': 4817, 'learning_rate': 0.19774836314213118, 'min_child_samples': 226, 'reg_alpha': 29.082023003754372, 'reg_lambda': 70.76737711188741}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:59:34,459] Trial 48 finished with value: 0.7382545161656491 and parameters: {'n_estimators': 1192, 'num_leaves': 4454, 'learning_rate': 0.16720187760280156, 'min_child_samples': 454, 'reg_alpha': 44.886551166843134, 'reg_lambda': 122.73098206649436}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:59:36,987] Trial 49 finished with value: 0.7380975637873918 and parameters: {'n_estimators': 1178, 'num_leaves': 4465, 'learning_rate': 0.16397089504698853, 'min_child_samples': 446, 'reg_alpha': 45.71321181682944, 'reg_lambda': 114.05239255887459}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:59:42,796] Trial 50 finished with value: 0.7379178876254673 and parameters: {'n_estimators': 3655, 'num_leaves': 1837, 'learning_rate': 0.24720405990434713, 'min_child_samples': 383, 'reg_alpha': 34.49488583929481, 'reg_lambda': 89.26998371732265}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:59:44,609] Trial 51 finished with value: 0.7378419332271796 and parameters: {'n_estimators': 527, 'num_leaves': 4487, 'learning_rate': 0.18360124766472852, 'min_child_samples': 473, 'reg_alpha': 23.34513380165282, 'reg_lambda': 121.47216529323751}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:59:46,828] Trial 52 finished with value: 0.738059927455443 and parameters: {'n_estimators': 878, 'num_leaves': 4969, 'learning_rate': 0.13027348461380261, 'min_child_samples': 425, 'reg_alpha': 47.519709923664124, 'reg_lambda': 152.89831210847228}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:59:53,636] Trial 53 finished with value: 0.7351535006098359 and parameters: {'n_estimators': 4126, 'num_leaves': 4110, 'learning_rate': 0.22593352000976574, 'min_child_samples': 468, 'reg_alpha': 14.112685167700405, 'reg_lambda': 127.5825603451685}. Best is trial 22 with value: 0.7382660565821086.
# [I 2025-02-18 20:59:55,434] Trial 54 finished with value: 0.738283408966944 and parameters: {'n_estimators': 722, 'num_leaves': 4371, 'learning_rate': 0.18954552517282786, 'min_child_samples': 484, 'reg_alpha': 55.4293644607058, 'reg_lambda': 139.25813603477906}. Best is trial 54 with value: 0.738283408966944.
# [I 2025-02-18 21:00:00,931] Trial 55 finished with value: 0.7381453687149905 and parameters: {'n_estimators': 3213, 'num_leaves': 4325, 'learning_rate': 0.19745455896476463, 'min_child_samples': 433, 'reg_alpha': 51.28487293833709, 'reg_lambda': 138.0319178771483}. Best is trial 54 with value: 0.738283408966944.
# [I 2025-02-18 21:00:05,510] Trial 56 finished with value: 0.7377837425511695 and parameters: {'n_estimators': 3396, 'num_leaves': 4392, 'learning_rate': 0.1892619282771278, 'min_child_samples': 441, 'reg_alpha': 82.94924509060763, 'reg_lambda': 139.07051338303205}. Best is trial 54 with value: 0.738283408966944.
# [I 2025-02-18 21:00:10,144] Trial 57 finished with value: 0.7378343182644824 and parameters: {'n_estimators': 3147, 'num_leaves': 4841, 'learning_rate': 0.15479222839546575, 'min_child_samples': 485, 'reg_alpha': 74.47550123769868, 'reg_lambda': 102.6033588869506}. Best is trial 54 with value: 0.738283408966944.
# [I 2025-02-18 21:00:13,087] Trial 58 finished with value: 0.7382646931133283 and parameters: {'n_estimators': 1411, 'num_leaves': 4571, 'learning_rate': 0.21598385995450722, 'min_child_samples': 401, 'reg_alpha': 55.5397980915547, 'reg_lambda': 109.81895926722434}. Best is trial 54 with value: 0.738283408966944.
# [I 2025-02-18 21:00:15,742] Trial 59 finished with value: 0.7376625713103568 and parameters: {'n_estimators': 1150, 'num_leaves': 5000, 'learning_rate': 0.2130649930520587, 'min_child_samples': 371, 'reg_alpha': 91.96111102414656, 'reg_lambda': 113.26305804788136}. Best is trial 54 with value: 0.738283408966944.
# [I 2025-02-18 21:00:18,331] Trial 60 finished with value: 0.737520341471715 and parameters: {'n_estimators': 1491, 'num_leaves': 4576, 'learning_rate': 0.17371129769617327, 'min_child_samples': 415, 'reg_alpha': 100.36901285647224, 'reg_lambda': 58.85055537018812}. Best is trial 54 with value: 0.738283408966944.
# [I 2025-02-18 21:00:20,599] Trial 61 finished with value: 0.7382332049189343 and parameters: {'n_estimators': 933, 'num_leaves': 4715, 'learning_rate': 0.20199051915012758, 'min_child_samples': 457, 'reg_alpha': 52.332500428222936, 'reg_lambda': 123.22422643891544}. Best is trial 54 with value: 0.738283408966944.
# [I 2025-02-18 21:00:22,842] Trial 62 finished with value: 0.7380524931053789 and parameters: {'n_estimators': 944, 'num_leaves': 4728, 'learning_rate': 0.23617726522025823, 'min_child_samples': 454, 'reg_alpha': 59.56181934214379, 'reg_lambda': 122.97440659314438}. Best is trial 54 with value: 0.738283408966944.
# [I 2025-02-18 21:00:26,243] Trial 63 finished with value: 0.7378422641763398 and parameters: {'n_estimators': 1278, 'num_leaves': 4536, 'learning_rate': 0.21089945443859648, 'min_child_samples': 396, 'reg_alpha': 71.98778359976723, 'reg_lambda': 109.83400185453857}. Best is trial 54 with value: 0.738283408966944.
# [I 2025-02-18 21:00:30,050] Trial 64 finished with value: 0.7380879558217073 and parameters: {'n_estimators': 1395, 'num_leaves': 4687, 'learning_rate': 0.1568415978698089, 'min_child_samples': 455, 'reg_alpha': 44.52728079401169, 'reg_lambda': 95.7059269585475}. Best is trial 54 with value: 0.738283408966944.
# [I 2025-02-18 21:00:33,632] Trial 65 finished with value: 0.7379992311706486 and parameters: {'n_estimators': 1720, 'num_leaves': 4341, 'learning_rate': 0.17735862668253158, 'min_child_samples': 486, 'reg_alpha': 54.44240860258921, 'reg_lambda': 19.70920465715882}. Best is trial 54 with value: 0.738283408966944.
# [I 2025-02-18 21:00:36,337] Trial 66 finished with value: 0.7380601446082042 and parameters: {'n_estimators': 1057, 'num_leaves': 3965, 'learning_rate': 0.11642828320150798, 'min_child_samples': 494, 'reg_alpha': 44.046108889512126, 'reg_lambda': 40.67563468227553}. Best is trial 54 with value: 0.738283408966944.
# [I 2025-02-18 21:00:38,314] Trial 67 finished with value: 0.7379374835741684 and parameters: {'n_estimators': 659, 'num_leaves': 4848, 'learning_rate': 0.14218903666762114, 'min_child_samples': 397, 'reg_alpha': 31.973030420651455, 'reg_lambda': 1.3040428351955384}. Best is trial 54 with value: 0.738283408966944.
# [I 2025-02-18 21:00:40,394] Trial 68 finished with value: 0.7379137773830572 and parameters: {'n_estimators': 862, 'num_leaves': 3870, 'learning_rate': 0.21550264256177148, 'min_child_samples': 434, 'reg_alpha': 62.74664552937574, 'reg_lambda': 150.2681045012945}. Best is trial 54 with value: 0.738283408966944.
# [I 2025-02-18 21:00:41,973] Trial 69 finished with value: 0.737954537373957 and parameters: {'n_estimators': 514, 'num_leaves': 4645, 'learning_rate': 0.29297450602154607, 'min_child_samples': 412, 'reg_alpha': 68.19616628538316, 'reg_lambda': 78.43406780035414}. Best is trial 54 with value: 0.738283408966944.
# [I 2025-02-18 21:00:45,152] Trial 70 finished with value: 0.7383035770296511 and parameters: {'n_estimators': 1632, 'num_leaves': 4019, 'learning_rate': 0.1941391856550694, 'min_child_samples': 483, 'reg_alpha': 52.31537794073837, 'reg_lambda': 106.33688801204758}. Best is trial 70 with value: 0.7383035770296511.
# [I 2025-02-18 21:00:48,230] Trial 71 finished with value: 0.738395956737524 and parameters: {'n_estimators': 1666, 'num_leaves': 4025, 'learning_rate': 0.1936246484961827, 'min_child_samples': 499, 'reg_alpha': 51.37437676900026, 'reg_lambda': 118.11609173871238}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:00:51,718] Trial 72 finished with value: 0.7381861568939891 and parameters: {'n_estimators': 2050, 'num_leaves': 3737, 'learning_rate': 0.18826267135503177, 'min_child_samples': 480, 'reg_alpha': 51.96094392116834, 'reg_lambda': 104.47424122743334}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:00:54,779] Trial 73 finished with value: 0.7379770534008958 and parameters: {'n_estimators': 1678, 'num_leaves': 3985, 'learning_rate': 0.23419937936434565, 'min_child_samples': 459, 'reg_alpha': 40.718610635661854, 'reg_lambda': 120.53861579980588}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:00:58,387] Trial 74 finished with value: 0.7383156321399149 and parameters: {'n_estimators': 1869, 'num_leaves': 3518, 'learning_rate': 0.16873387519838656, 'min_child_samples': 499, 'reg_alpha': 57.98830677061315, 'reg_lambda': 87.96482490344737}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:01:02,355] Trial 75 finished with value: 0.7379516172957197 and parameters: {'n_estimators': 1883, 'num_leaves': 3549, 'learning_rate': 0.16577253757270044, 'min_child_samples': 483, 'reg_alpha': 58.940118134955256, 'reg_lambda': 87.89687932502731}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:01:06,282] Trial 76 finished with value: 0.7380510210602181 and parameters: {'n_estimators': 2474, 'num_leaves': 3244, 'learning_rate': 0.14467822196900632, 'min_child_samples': 499, 'reg_alpha': 65.56928488690944, 'reg_lambda': 98.92436371997987}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:01:10,189] Trial 77 finished with value: 0.7381088432029361 and parameters: {'n_estimators': 1610, 'num_leaves': 4024, 'learning_rate': 0.10085331851378398, 'min_child_samples': 447, 'reg_alpha': 36.219397614695595, 'reg_lambda': 81.3030459767511}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:01:14,394] Trial 78 finished with value: 0.7373068301951682 and parameters: {'n_estimators': 2141, 'num_leaves': 4237, 'learning_rate': 0.2237843638587297, 'min_child_samples': 424, 'reg_alpha': 19.858413578283127, 'reg_lambda': 132.98667451773855}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:01:23,927] Trial 79 finished with value: 0.7332449669147305 and parameters: {'n_estimators': 1381, 'num_leaves': 3844, 'learning_rate': 0.07732955847853791, 'min_child_samples': 499, 'reg_alpha': 8.955739501576414, 'reg_lambda': 111.00040553384723}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:01:27,368] Trial 80 finished with value: 0.7380185431503542 and parameters: {'n_estimators': 1824, 'num_leaves': 3672, 'learning_rate': 0.25834385015079864, 'min_child_samples': 471, 'reg_alpha': 76.8896881338968, 'reg_lambda': 106.21699729155472}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:01:30,422] Trial 81 finished with value: 0.7382768672400095 and parameters: {'n_estimators': 1266, 'num_leaves': 4371, 'learning_rate': 0.19269053277207673, 'min_child_samples': 462, 'reg_alpha': 55.7000501111922, 'reg_lambda': 116.38543554813592}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:01:33,730] Trial 82 finished with value: 0.7379496806689301 and parameters: {'n_estimators': 1446, 'num_leaves': 4403, 'learning_rate': 0.14981954811768605, 'min_child_samples': 466, 'reg_alpha': 41.28275046310192, 'reg_lambda': 116.57223690793006}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:01:36,522] Trial 83 finished with value: 0.7381812281527096 and parameters: {'n_estimators': 1285, 'num_leaves': 4189, 'learning_rate': 0.177310720619686, 'min_child_samples': 484, 'reg_alpha': 56.16278024620918, 'reg_lambda': 91.84600460343954}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:01:41,363] Trial 84 finished with value: 0.7380159404492295 and parameters: {'n_estimators': 1943, 'num_leaves': 4080, 'learning_rate': 0.12443513164233116, 'min_child_samples': 436, 'reg_alpha': 69.86031465871355, 'reg_lambda': 116.59386153850271}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:01:44,358] Trial 85 finished with value: 0.7382779874559369 and parameters: {'n_estimators': 1159, 'num_leaves': 3446, 'learning_rate': 0.1928132166394754, 'min_child_samples': 449, 'reg_alpha': 46.80830620328085, 'reg_lambda': 134.01394015613218}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:01:46,864] Trial 86 finished with value: 0.738274801156766 and parameters: {'n_estimators': 1149, 'num_leaves': 3525, 'learning_rate': 0.240623168711606, 'min_child_samples': 447, 'reg_alpha': 47.573196582231304, 'reg_lambda': 100.41586475744893}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:01:49,131] Trial 87 finished with value: 0.7378873839265248 and parameters: {'n_estimators': 1096, 'num_leaves': 3018, 'learning_rate': 0.24453755051360687, 'min_child_samples': 445, 'reg_alpha': 49.27227769800065, 'reg_lambda': 101.5609373644034}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:01:52,098] Trial 88 finished with value: 0.7376608163402041 and parameters: {'n_estimators': 1673, 'num_leaves': 3500, 'learning_rate': 0.2746714446962312, 'min_child_samples': 476, 'reg_alpha': 87.48591924276242, 'reg_lambda': 95.58647430057947}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:01:55,080] Trial 89 finished with value: 0.738130559523071 and parameters: {'n_estimators': 1594, 'num_leaves': 3303, 'learning_rate': 0.19267652675400793, 'min_child_samples': 489, 'reg_alpha': 64.789397776959, 'reg_lambda': 99.77474152948997}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:01:58,941] Trial 90 finished with value: 0.7382511617818891 and parameters: {'n_estimators': 1325, 'num_leaves': 3418, 'learning_rate': 0.2234753973252552, 'min_child_samples': 468, 'reg_alpha': 25.91083236555263, 'reg_lambda': 74.23110188011582}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:02:02,553] Trial 91 finished with value: 0.7381962899935147 and parameters: {'n_estimators': 1216, 'num_leaves': 2601, 'learning_rate': 0.18477105652308656, 'min_child_samples': 448, 'reg_alpha': 32.14400204973667, 'reg_lambda': 107.57446533712263}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:02:05,100] Trial 92 finished with value: 0.7382856932469525 and parameters: {'n_estimators': 766, 'num_leaves': 3718, 'learning_rate': 0.16739016080431168, 'min_child_samples': 462, 'reg_alpha': 47.00197879932854, 'reg_lambda': 87.03553790262588}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:02:07,921] Trial 93 finished with value: 0.7380328773206082 and parameters: {'n_estimators': 994, 'num_leaves': 3672, 'learning_rate': 0.1958515452627035, 'min_child_samples': 406, 'reg_alpha': 55.9020832161135, 'reg_lambda': 86.81796783985308}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:02:10,511] Trial 94 finished with value: 0.7382101334820484 and parameters: {'n_estimators': 1486, 'num_leaves': 3874, 'learning_rate': 0.20503318088471167, 'min_child_samples': 422, 'reg_alpha': 48.55494852895387, 'reg_lambda': 67.44997196533873}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:02:12,486] Trial 95 finished with value: 0.7379057844910349 and parameters: {'n_estimators': 766, 'num_leaves': 3773, 'learning_rate': 0.21846014348481446, 'min_child_samples': 462, 'reg_alpha': 37.6771565752427, 'reg_lambda': 80.14079691389982}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:02:14,584] Trial 96 finished with value: 0.7381532509426247 and parameters: {'n_estimators': 1110, 'num_leaves': 3466, 'learning_rate': 0.1671786119679865, 'min_child_samples': 500, 'reg_alpha': 59.76699521813703, 'reg_lambda': 142.82295243546767}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:02:17,678] Trial 97 finished with value: 0.7381695634998147 and parameters: {'n_estimators': 988, 'num_leaves': 3627, 'learning_rate': 0.23524164152140287, 'min_child_samples': 489, 'reg_alpha': 40.839996323134116, 'reg_lambda': 94.43701874900201}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:02:27,040] Trial 98 finished with value: 0.7382483200039262 and parameters: {'n_estimators': 4821, 'num_leaves': 3152, 'learning_rate': 0.13409385165461066, 'min_child_samples': 438, 'reg_alpha': 47.55765688955965, 'reg_lambda': 91.51668970196066}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:02:28,894] Trial 99 finished with value: 0.7363493974065162 and parameters: {'n_estimators': 813, 'num_leaves': 3730, 'learning_rate': 0.41004828749620365, 'min_child_samples': 480, 'reg_alpha': 198.4454952276111, 'reg_lambda': 134.67800054406138}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:02:30,965] Trial 100 finished with value: 0.73789690941592 and parameters: {'n_estimators': 653, 'num_leaves': 2864, 'learning_rate': 0.20419720920172502, 'min_child_samples': 464, 'reg_alpha': 33.3089051441347, 'reg_lambda': 126.24512483747277}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:02:33,457] Trial 101 finished with value: 0.7382820997863543 and parameters: {'n_estimators': 1204, 'num_leaves': 4492, 'learning_rate': 0.17288958590921494, 'min_child_samples': 450, 'reg_alpha': 44.351508129085694, 'reg_lambda': 111.51104144944078}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:02:35,973] Trial 102 finished with value: 0.7380997332269975 and parameters: {'n_estimators': 1246, 'num_leaves': 3329, 'learning_rate': 0.17762624856390918, 'min_child_samples': 430, 'reg_alpha': 54.020377290128216, 'reg_lambda': 111.33393417082527}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:02:39,890] Trial 103 finished with value: 0.7381608471132559 and parameters: {'n_estimators': 1391, 'num_leaves': 4295, 'learning_rate': 0.15801846770255829, 'min_child_samples': 452, 'reg_alpha': 64.29746517287053, 'reg_lambda': 117.27267127372066}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:02:43,191] Trial 104 finished with value: 0.7381210820578441 and parameters: {'n_estimators': 1780, 'num_leaves': 4505, 'learning_rate': 0.18836248438416245, 'min_child_samples': 474, 'reg_alpha': 44.25271649976342, 'reg_lambda': 83.7083264271092}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:02:46,562] Trial 105 finished with value: 0.7382226416899008 and parameters: {'n_estimators': 1587, 'num_leaves': 4040, 'learning_rate': 0.17082117421351078, 'min_child_samples': 462, 'reg_alpha': 49.45512454040539, 'reg_lambda': 100.64067502225178}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:02:48,869] Trial 106 finished with value: 0.7379600559773046 and parameters: {'n_estimators': 894, 'num_leaves': 3893, 'learning_rate': 0.2531739566363487, 'min_child_samples': 489, 'reg_alpha': 29.17741112339571, 'reg_lambda': 106.21762911834222}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:02:51,279] Trial 107 finished with value: 0.7380922143126369 and parameters: {'n_estimators': 1136, 'num_leaves': 1004, 'learning_rate': 0.1836478753100884, 'min_child_samples': 446, 'reg_alpha': 61.58670356648969, 'reg_lambda': 130.30017605116154}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:02:54,098] Trial 108 finished with value: 0.7371523385335379 and parameters: {'n_estimators': 1467, 'num_leaves': 4179, 'learning_rate': 0.21293479005226093, 'min_child_samples': 368, 'reg_alpha': 132.85411201135105, 'reg_lambda': 124.66562743741272}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:02:56,409] Trial 109 finished with value: 0.7376637531225001 and parameters: {'n_estimators': 722, 'num_leaves': 3228, 'learning_rate': 0.1607587037041165, 'min_child_samples': 27, 'reg_alpha': 38.65396558776884, 'reg_lambda': 119.00690472237389}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:02:59,008] Trial 110 finished with value: 0.7368053044088752 and parameters: {'n_estimators': 1015, 'num_leaves': 3586, 'learning_rate': 0.1465392271192829, 'min_child_samples': 478, 'reg_alpha': 156.1502167658885, 'reg_lambda': 113.56446897540181}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:03:01,639] Trial 111 finished with value: 0.7381935327798482 and parameters: {'n_estimators': 1213, 'num_leaves': 4382, 'learning_rate': 0.1980525450792225, 'min_child_samples': 454, 'reg_alpha': 45.01371060986394, 'reg_lambda': 108.93088914973546}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:03:04,108] Trial 112 finished with value: 0.7381097243420253 and parameters: {'n_estimators': 1165, 'num_leaves': 4440, 'learning_rate': 0.17170918800360402, 'min_child_samples': 418, 'reg_alpha': 53.83011519665798, 'reg_lambda': 146.33926053014744}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:03:06,728] Trial 113 finished with value: 0.7378450046859478 and parameters: {'n_estimators': 1327, 'num_leaves': 4580, 'learning_rate': 0.22947446852582504, 'min_child_samples': 259, 'reg_alpha': 57.50635367128609, 'reg_lambda': 74.20552839959963}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:03:11,367] Trial 114 finished with value: 0.7382423608310339 and parameters: {'n_estimators': 1528, 'num_leaves': 4297, 'learning_rate': 0.13500301992736355, 'min_child_samples': 437, 'reg_alpha': 52.0142356090672, 'reg_lambda': 140.57531322352946}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:03:13,973] Trial 115 finished with value: 0.7379668075489749 and parameters: {'n_estimators': 1047, 'num_leaves': 3994, 'learning_rate': 0.2047824523462732, 'min_child_samples': 403, 'reg_alpha': 34.39770758064719, 'reg_lambda': 89.3494299319203}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:03:15,937] Trial 116 finished with value: 0.7381449187494129 and parameters: {'n_estimators': 596, 'num_leaves': 2225, 'learning_rate': 0.1545266720330154, 'min_child_samples': 92, 'reg_alpha': 47.27051195123368, 'reg_lambda': 102.82870790404512}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:03:18,477] Trial 117 finished with value: 0.7382238370740917 and parameters: {'n_estimators': 891, 'num_leaves': 4224, 'learning_rate': 0.16374813926931514, 'min_child_samples': 470, 'reg_alpha': 42.37075255000808, 'reg_lambda': 98.09297461363822}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:03:21,519] Trial 118 finished with value: 0.7379737397332784 and parameters: {'n_estimators': 1371, 'num_leaves': 3505, 'learning_rate': 0.11013456492458959, 'min_child_samples': 490, 'reg_alpha': 67.44895173637448, 'reg_lambda': 133.36597914794166}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:03:24,287] Trial 119 finished with value: 0.7374622301399831 and parameters: {'n_estimators': 1247, 'num_leaves': 3800, 'learning_rate': 0.24080806819902614, 'min_child_samples': 458, 'reg_alpha': 23.772814124385512, 'reg_lambda': 120.67383784905373}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:03:27,722] Trial 120 finished with value: 0.7380040200154376 and parameters: {'n_estimators': 1961, 'num_leaves': 4121, 'learning_rate': 0.1805491635536399, 'min_child_samples': 476, 'reg_alpha': 74.42651923992082, 'reg_lambda': 112.52785510775541}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:03:31,045] Trial 121 finished with value: 0.7376258975497827 and parameters: {'n_estimators': 1355, 'num_leaves': 3412, 'learning_rate': 0.22208004632303277, 'min_child_samples': 467, 'reg_alpha': 25.985910577440485, 'reg_lambda': 84.15680672233387}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:03:34,918] Trial 122 finished with value: 0.7370457906519928 and parameters: {'n_estimators': 1291, 'num_leaves': 3423, 'learning_rate': 0.19585339112677488, 'min_child_samples': 440, 'reg_alpha': 19.331802297738548, 'reg_lambda': 66.03173962896737}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:03:37,352] Trial 123 finished with value: 0.7379722885681909 and parameters: {'n_estimators': 1150, 'num_leaves': 3639, 'learning_rate': 0.21599337862782808, 'min_child_samples': 429, 'reg_alpha': 38.373221132381644, 'reg_lambda': 72.72201228296709}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:03:41,175] Trial 124 finished with value: 0.7381628714363531 and parameters: {'n_estimators': 1640, 'num_leaves': 4540, 'learning_rate': 0.1898168850132497, 'min_child_samples': 500, 'reg_alpha': 29.41416910486894, 'reg_lambda': 76.90133715688415}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:03:46,136] Trial 125 finished with value: 0.7382599898768394 and parameters: {'n_estimators': 1776, 'num_leaves': 3927, 'learning_rate': 0.2270849817444789, 'min_child_samples': 450, 'reg_alpha': 59.33719994837369, 'reg_lambda': 91.9483316605764}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:03:51,420] Trial 126 finished with value: 0.7382323603199732 and parameters: {'n_estimators': 1777, 'num_leaves': 3981, 'learning_rate': 0.20812299793712152, 'min_child_samples': 449, 'reg_alpha': 60.61293310445967, 'reg_lambda': 93.85416610368408}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:03:56,206] Trial 127 finished with value: 0.7382497690810064 and parameters: {'n_estimators': 1515, 'num_leaves': 3904, 'learning_rate': 0.26216789449791966, 'min_child_samples': 386, 'reg_alpha': 56.72149052270781, 'reg_lambda': 105.13660782603131}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:04:02,185] Trial 128 finished with value: 0.7374724331877538 and parameters: {'n_estimators': 2046, 'num_leaves': 3752, 'learning_rate': 0.12273377608749952, 'min_child_samples': 483, 'reg_alpha': 118.07001360145625, 'reg_lambda': 124.78173262403442}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:04:08,374] Trial 129 finished with value: 0.7381345194289539 and parameters: {'n_estimators': 1900, 'num_leaves': 4448, 'learning_rate': 0.17583764307857994, 'min_child_samples': 313, 'reg_alpha': 51.3688651416714, 'reg_lambda': 87.54440008122677}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:04:10,508] Trial 130 finished with value: 0.737799627066859 and parameters: {'n_estimators': 954, 'num_leaves': 4071, 'learning_rate': 0.23134266213761612, 'min_child_samples': 418, 'reg_alpha': 70.58323755722617, 'reg_lambda': 97.99433416781861}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:04:13,385] Trial 131 finished with value: 0.7379958872269251 and parameters: {'n_estimators': 1415, 'num_leaves': 3583, 'learning_rate': 0.24491961305901339, 'min_child_samples': 465, 'reg_alpha': 46.46739658679972, 'reg_lambda': 81.87053815084312}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:04:16,858] Trial 132 finished with value: 0.7381627273638479 and parameters: {'n_estimators': 1708, 'num_leaves': 4770, 'learning_rate': 0.19016182163713552, 'min_child_samples': 455, 'reg_alpha': 41.68939442604669, 'reg_lambda': 91.7643847096248}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:04:19,813] Trial 133 finished with value: 0.7381673502120552 and parameters: {'n_estimators': 1554, 'num_leaves': 4620, 'learning_rate': 0.2243883630167249, 'min_child_samples': 471, 'reg_alpha': 51.00810721052069, 'reg_lambda': 57.85910263007071}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:04:22,611] Trial 134 finished with value: 0.7377917886873785 and parameters: {'n_estimators': 1203, 'num_leaves': 3384, 'learning_rate': 0.2072912705016422, 'min_child_samples': 491, 'reg_alpha': 34.476687312710816, 'reg_lambda': 108.72844523698029}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:04:24,983] Trial 135 finished with value: 0.7379870622639857 and parameters: {'n_estimators': 809, 'num_leaves': 4352, 'learning_rate': 0.1666563287883307, 'min_child_samples': 444, 'reg_alpha': 57.87372778029278, 'reg_lambda': 117.01446526409437}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:04:27,741] Trial 136 finished with value: 0.7382669241491502 and parameters: {'n_estimators': 1077, 'num_leaves': 3710, 'learning_rate': 0.1442853993980792, 'min_child_samples': 430, 'reg_alpha': 44.19983698602185, 'reg_lambda': 129.96629949191785}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:04:30,211] Trial 137 finished with value: 0.7382446962672217 and parameters: {'n_estimators': 1090, 'num_leaves': 3727, 'learning_rate': 0.14132514440831348, 'min_child_samples': 428, 'reg_alpha': 45.53751583204178, 'reg_lambda': 136.21893755752666}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:04:32,519] Trial 138 finished with value: 0.7381088567749836 and parameters: {'n_estimators': 727, 'num_leaves': 3832, 'learning_rate': 0.15184245071641775, 'min_child_samples': 410, 'reg_alpha': 62.416434257637015, 'reg_lambda': 129.49690183558113}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:04:34,913] Trial 139 finished with value: 0.7380990514926075 and parameters: {'n_estimators': 962, 'num_leaves': 3894, 'learning_rate': 0.18218862242749734, 'min_child_samples': 456, 'reg_alpha': 53.57829419138772, 'reg_lambda': 151.14743036929983}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:04:37,388] Trial 140 finished with value: 0.7382162534315043 and parameters: {'n_estimators': 1100, 'num_leaves': 4230, 'learning_rate': 0.16985164202166292, 'min_child_samples': 435, 'reg_alpha': 40.91095253043411, 'reg_lambda': 121.60259030261808}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:04:40,075] Trial 141 finished with value: 0.7379693068937374 and parameters: {'n_estimators': 1273, 'num_leaves': 3508, 'learning_rate': 0.19461592023536892, 'min_child_samples': 480, 'reg_alpha': 37.052193219275814, 'reg_lambda': 113.78445791893655}. Best is trial 71 with value: 0.738395956737524.
# [I 2025-02-18 21:04:42,807] Trial 142 finished with value: 0.7384840581183976 and parameters: {'n_estimators': 1442, 'num_leaves': 3260, 'learning_rate': 0.22465216504700322, 'min_child_samples': 464, 'reg_alpha': 48.72218909184579, 'reg_lambda': 102.7197983159577}. Best is trial 142 with value: 0.7384840581183976.
# [I 2025-02-18 21:04:45,374] Trial 143 finished with value: 0.7380946792052786 and parameters: {'n_estimators': 1402, 'num_leaves': 3684, 'learning_rate': 0.21505036477132, 'min_child_samples': 451, 'reg_alpha': 48.49279998207681, 'reg_lambda': 102.20251248621096}. Best is trial 142 with value: 0.7384840581183976.
# [I 2025-02-18 21:04:48,383] Trial 144 finished with value: 0.7380407261401252 and parameters: {'n_estimators': 1475, 'num_leaves': 3283, 'learning_rate': 0.16091797316865483, 'min_child_samples': 444, 'reg_alpha': 54.34270126737756, 'reg_lambda': 126.88273100067585}. Best is trial 142 with value: 0.7384840581183976.
# [I 2025-02-18 21:04:51,172] Trial 145 finished with value: 0.7380017680995428 and parameters: {'n_estimators': 1618, 'num_leaves': 3548, 'learning_rate': 0.20266974132042798, 'min_child_samples': 462, 'reg_alpha': 42.328745995316766, 'reg_lambda': 108.7013400249834}. Best is trial 142 with value: 0.7384840581183976.
# [I 2025-02-18 21:04:54,540] Trial 146 finished with value: 0.7382735681884434 and parameters: {'n_estimators': 1818, 'num_leaves': 2910, 'learning_rate': 0.1268247575819813, 'min_child_samples': 474, 'reg_alpha': 48.45786226709177, 'reg_lambda': 97.85975964365116}. Best is trial 142 with value: 0.7384840581183976.
# [I 2025-02-18 21:04:57,455] Trial 147 finished with value: 0.7381451557382437 and parameters: {'n_estimators': 1790, 'num_leaves': 2908, 'learning_rate': 0.13186144408810035, 'min_child_samples': 484, 'reg_alpha': 66.04099038906426, 'reg_lambda': 99.20539093156442}. Best is trial 142 with value: 0.7384840581183976.
# [I 2025-02-18 21:05:00,908] Trial 148 finished with value: 0.7381409139513726 and parameters: {'n_estimators': 2202, 'num_leaves': 3120, 'learning_rate': 0.14851930612721698, 'min_child_samples': 500, 'reg_alpha': 48.73142034200173, 'reg_lambda': 94.71584206169447}. Best is trial 142 with value: 0.7384840581183976.
# [I 2025-02-18 21:05:04,172] Trial 149 finished with value: 0.7381611801504235 and parameters: {'n_estimators': 1855, 'num_leaves': 3011, 'learning_rate': 0.09969009140770876, 'min_child_samples': 474, 'reg_alpha': 58.238928326511086, 'reg_lambda': 104.44393493885791}. Best is trial 142 with value: 0.7384840581183976.
# [I 2025-02-18 21:05:06,858] Trial 150 finished with value: 0.7379514920152803 and parameters: {'n_estimators': 1643, 'num_leaves': 2690, 'learning_rate': 0.1826722833326444, 'min_child_samples': 489, 'reg_alpha': 49.52647150996552, 'reg_lambda': 89.22440181364951}. Best is trial 142 with value: 0.7384840581183976.
# [I 2025-02-18 21:05:09,385] Trial 151 finished with value: 0.7381228860961689 and parameters: {'n_estimators': 1178, 'num_leaves': 4480, 'learning_rate': 0.1423003415693637, 'min_child_samples': 462, 'reg_alpha': 52.96448000999965, 'reg_lambda': 115.58357371911018}. Best is trial 142 with value: 0.7384840581183976.
# ...
# [I 2025-02-18 21:25:12,001] Trial 540 finished with value: 0.7383068583331549 and parameters: {'n_estimators': 1470, 'num_leaves': 1994, 'learning_rate': 0.18565479235321697, 'min_child_samples': 478, 'reg_alpha': 39.48112334894856, 'reg_lambda': 124.95345683071459}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:25:14,315] Trial 541 finished with value: 0.737680449873037 and parameters: {'n_estimators': 1370, 'num_leaves': 2286, 'learning_rate': 0.22261415758952563, 'min_child_samples': 469, 'reg_alpha': 64.13851359774787, 'reg_lambda': 136.48064753446067}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:25:16,684] Trial 542 finished with value: 0.7382213533893842 and parameters: {'n_estimators': 1108, 'num_leaves': 2503, 'learning_rate': 0.1385510526716536, 'min_child_samples': 454, 'reg_alpha': 51.283138545829246, 'reg_lambda': 118.19104804539495}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:25:18,364] Trial 543 finished with value: 0.7384316178145477 and parameters: {'n_estimators': 593, 'num_leaves': 2343, 'learning_rate': 0.1819496298905878, 'min_child_samples': 484, 'reg_alpha': 46.469728331486806, 'reg_lambda': 135.8592239687075}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:25:19,998] Trial 544 finished with value: 0.7380386642328964 and parameters: {'n_estimators': 595, 'num_leaves': 2335, 'learning_rate': 0.16743256513695567, 'min_child_samples': 443, 'reg_alpha': 44.81617020592778, 'reg_lambda': 134.62352166314326}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:25:21,716] Trial 545 finished with value: 0.7378145009870052 and parameters: {'n_estimators': 574, 'num_leaves': 2005, 'learning_rate': 0.17817986757743715, 'min_child_samples': 481, 'reg_alpha': 37.14444063108761, 'reg_lambda': 129.31988633101014}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:25:23,350] Trial 546 finished with value: 0.7380805204276396 and parameters: {'n_estimators': 651, 'num_leaves': 1997, 'learning_rate': 0.25062160314050547, 'min_child_samples': 230, 'reg_alpha': 41.997544767878885, 'reg_lambda': 138.25670080411774}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:25:25,050] Trial 547 finished with value: 0.7381672343276489 and parameters: {'n_estimators': 554, 'num_leaves': 3384, 'learning_rate': 0.15568286053561944, 'min_child_samples': 464, 'reg_alpha': 46.57659816745335, 'reg_lambda': 133.65574373693784}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:25:26,968] Trial 548 finished with value: 0.7381767232769161 and parameters: {'n_estimators': 701, 'num_leaves': 2168, 'learning_rate': 0.17862710589804973, 'min_child_samples': 474, 'reg_alpha': 47.8219281243232, 'reg_lambda': 124.15759073531311}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:25:28,981] Trial 549 finished with value: 0.7381652256646067 and parameters: {'n_estimators': 744, 'num_leaves': 2195, 'learning_rate': 0.1652331527976043, 'min_child_samples': 455, 'reg_alpha': 40.45728587137555, 'reg_lambda': 130.74928880527574}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:25:30,682] Trial 550 finished with value: 0.7382518268122207 and parameters: {'n_estimators': 605, 'num_leaves': 2227, 'learning_rate': 0.20064491179625538, 'min_child_samples': 483, 'reg_alpha': 32.45036194989394, 'reg_lambda': 138.12574521090258}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:25:32,230] Trial 551 finished with value: 0.7368733682274993 and parameters: {'n_estimators': 680, 'num_leaves': 2347, 'learning_rate': 0.39699446476351385, 'min_child_samples': 341, 'reg_alpha': 98.94044865916078, 'reg_lambda': 143.05483763423297}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:25:34,016] Trial 552 finished with value: 0.7381838089297574 and parameters: {'n_estimators': 789, 'num_leaves': 2087, 'learning_rate': 0.19061624189063042, 'min_child_samples': 466, 'reg_alpha': 43.97609023915936, 'reg_lambda': 128.91770691478627}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:25:36,036] Trial 553 finished with value: 0.7381410141757239 and parameters: {'n_estimators': 901, 'num_leaves': 2255, 'learning_rate': 0.17306007265999568, 'min_child_samples': 482, 'reg_alpha': 54.327112149932766, 'reg_lambda': 132.49827100038914}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:25:37,880] Trial 554 finished with value: 0.7382119928525672 and parameters: {'n_estimators': 865, 'num_leaves': 3849, 'learning_rate': 0.2088100459239474, 'min_child_samples': 472, 'reg_alpha': 48.160060808689565, 'reg_lambda': 15.20491472310323}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:25:40,662] Trial 555 finished with value: 0.737964017971195 and parameters: {'n_estimators': 1010, 'num_leaves': 1943, 'learning_rate': 0.1815767170392681, 'min_child_samples': 215, 'reg_alpha': 42.75769511563287, 'reg_lambda': 138.6033704559806}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:25:42,813] Trial 556 finished with value: 0.7381593677600695 and parameters: {'n_estimators': 801, 'num_leaves': 2599, 'learning_rate': 0.15709612864437092, 'min_child_samples': 486, 'reg_alpha': 34.69372829928288, 'reg_lambda': 144.41272204116135}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:25:44,477] Trial 557 finished with value: 0.7383110009396785 and parameters: {'n_estimators': 629, 'num_leaves': 3335, 'learning_rate': 0.1943095974020701, 'min_child_samples': 459, 'reg_alpha': 37.99904840490553, 'reg_lambda': 121.4499141338237}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:25:46,662] Trial 558 finished with value: 0.738321988034198 and parameters: {'n_estimators': 930, 'num_leaves': 2470, 'learning_rate': 0.16849238338349937, 'min_child_samples': 441, 'reg_alpha': 50.318270030162694, 'reg_lambda': 140.9413085033659}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:25:48,369] Trial 559 finished with value: 0.7375362406034556 and parameters: {'n_estimators': 763, 'num_leaves': 4123, 'learning_rate': 0.3292923703563055, 'min_child_samples': 476, 'reg_alpha': 45.545300203737575, 'reg_lambda': 136.182317023382}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:25:50,555] Trial 560 finished with value: 0.7380925974619803 and parameters: {'n_estimators': 1061, 'num_leaves': 3354, 'learning_rate': 0.21685555645435706, 'min_child_samples': 490, 'reg_alpha': 53.57176347270277, 'reg_lambda': 127.57656775482073}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:25:52,494] Trial 561 finished with value: 0.7381708507563276 and parameters: {'n_estimators': 877, 'num_leaves': 1493, 'learning_rate': 0.18317048581626008, 'min_child_samples': 452, 'reg_alpha': 57.84095894961001, 'reg_lambda': 133.263029212676}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:25:56,679] Trial 562 finished with value: 0.7379193179104816 and parameters: {'n_estimators': 2983, 'num_leaves': 1884, 'learning_rate': 0.2011951854309221, 'min_child_samples': 471, 'reg_alpha': 48.241328602320756, 'reg_lambda': 145.06617863594641}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:25:58,359] Trial 563 finished with value: 0.7380702756197224 and parameters: {'n_estimators': 500, 'num_leaves': 2122, 'learning_rate': 0.16125390320310837, 'min_child_samples': 483, 'reg_alpha': 40.77961496248702, 'reg_lambda': 154.14717274991443}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:26:00,263] Trial 564 finished with value: 0.7381275580125481 and parameters: {'n_estimators': 672, 'num_leaves': 2306, 'learning_rate': 0.14699527167575385, 'min_child_samples': 492, 'reg_alpha': 44.83319575845145, 'reg_lambda': 102.33030920778099}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:26:02,331] Trial 565 finished with value: 0.7382743146510604 and parameters: {'n_estimators': 990, 'num_leaves': 3425, 'learning_rate': 0.1746805678315006, 'min_child_samples': 463, 'reg_alpha': 52.576167395457794, 'reg_lambda': 126.33340400163117}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:26:04,093] Trial 566 finished with value: 0.7380086992398425 and parameters: {'n_estimators': 741, 'num_leaves': 3267, 'learning_rate': 0.18881458288244285, 'min_child_samples': 478, 'reg_alpha': 58.788065259227295, 'reg_lambda': 139.3620616132672}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:26:08,209] Trial 567 finished with value: 0.7381853592751928 and parameters: {'n_estimators': 2677, 'num_leaves': 3917, 'learning_rate': 0.17932090442273346, 'min_child_samples': 468, 'reg_alpha': 49.155718438217285, 'reg_lambda': 46.80073637281432}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:26:10,861] Trial 568 finished with value: 0.7381225541030049 and parameters: {'n_estimators': 916, 'num_leaves': 3311, 'learning_rate': 0.23285638399605413, 'min_child_samples': 491, 'reg_alpha': 40.57911167529988, 'reg_lambda': 146.60506638711325}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:26:12,813] Trial 569 finished with value: 0.7368163802437057 and parameters: {'n_estimators': 1048, 'num_leaves': 2417, 'learning_rate': 0.1942862518926072, 'min_child_samples': 435, 'reg_alpha': 154.90864713764682, 'reg_lambda': 118.80866445049125}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:26:17,568] Trial 570 finished with value: 0.7382814441520557 and parameters: {'n_estimators': 2871, 'num_leaves': 3445, 'learning_rate': 0.16860704293684833, 'min_child_samples': 482, 'reg_alpha': 45.43731357102371, 'reg_lambda': 151.92614118479992}. Best is trial 266 with value: 0.7385101133177441.
# [I 2025-02-18 21:26:19,671] Trial 571 finished with value: 0.7380529848311028 and parameters: {'n_estimators': 808, 'num_leaves': 3231, 'learning_rate': 0.2085361192018286, 'min_child_samples': 460, 'reg_alpha': 37.10072776667409, 'reg_lambda': 98.38137001601025}. Best is trial 266 with value: 0.7385101133177441.
# [W 2025-02-18 21:26:21,871] Trial 572 failed with parameters: {'n_estimators': 1494, 'num_leaves': 3373, 'learning_rate': 0.13451090010775624, 'min_child_samples': 449, 'reg_alpha': 51.2002214154758, 'reg_lambda': 131.69382948632193} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\_optimize.py", line 196, in _run_trial
#     value_or_values = func(trial)
#   File "C:\Users\juneh\AppData\Local\Temp\ipykernel_24376\2579625111.py", line 24, in objective
#     model.fit(IVF_X_train, IVF_y_train)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\sklearn.py", line 1298, in fit
#     init_model=init_model,
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\sklearn.py", line 963, in fit
#     callbacks=callbacks,
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\engine.py", line 307, in train
#     booster.update(fobj=fobj)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\basic.py", line 4138, in update
#     ctypes.byref(is_finished),
# KeyboardInterrupt
# [W 2025-02-18 21:26:21,873] Trial 572 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24376\2579625111.py in <module>
#      31 # Optuna 스터디 생성 및 최적화 실행
#      32 study = optuna.create_study(direction='maximize')
# ---> 33 study.optimize(objective, n_trials=800)
#      34
#      35 # 최적의 하이퍼파라미터 출력
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     458             callbacks=callbacks,
#     459             gc_after_trial=gc_after_trial,
# --> 460             show_progress_bar=show_progress_bar,
#     461         )
#     462
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      70                 reseed_sampler_rng=False,
#      71                 time_start=None,
# ---> 72                 progress_bar=progress_bar,
#      73             )
#      74         else:
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157
#     158         try:
# --> 159             frozen_trial = _run_trial(study, func, catch)
#     160         finally:
#     161             # The following line mitigates memory problems that can be occurred in some
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\_optimize.py in _run_trial(study, func, catch)
#     245         and not isinstance(func_err, catch)
#     246     ):
# --> 247         raise func_err
#     248     return frozen_trial
#     249
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\_optimize.py in _run_trial(study, func, catch)
#     194     with get_heartbeat_thread(trial._trial_id, study._storage):
#     195         try:
# --> 196             value_or_values = func(trial)
#     197         except exceptions.TrialPruned as e:
#     198             # TODO(mamu): Handle multi-objective cases.
#
# ~\AppData\Local\Temp\ipykernel_24376\2579625111.py in objective(trial)
#      22
#      23     model = lgb.LGBMClassifier(**param)
# ---> 24     model.fit(IVF_X_train, IVF_y_train)
#      25
#      26     y_pred_proba = model.predict_proba(IVF_X_test)[:, 1]
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1296             categorical_feature=categorical_feature,
#    1297             callbacks=callbacks,
# -> 1298             init_model=init_model,
#    1299         )
#    1300         return self
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#     961             feval=eval_metrics_callable,  # type: ignore[arg-type]
#     962             init_model=init_model,
# --> 963             callbacks=callbacks,
#     964         )
#     965
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, feature_name, categorical_feature, keep_training_booster, callbacks)
#     305             )
#     306
# --> 307         booster.update(fobj=fobj)
#     308
#     309         evaluation_result_list: List[_LGBM_BoosterEvalMethodResultType] = []
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\basic.py in update(self, train_set, fobj)
#    4136                 _LIB.LGBM_BoosterUpdateOneIter(
#    4137                     self._handle,
# -> 4138                     ctypes.byref(is_finished),
#    4139                 )
#    4140             )
#
# KeyboardInterrupt:

# %%
# import optuna
# import lightgbm as lgb
# from sklearn.metrics import roc_auc_score

# # 목적 함수 정의
# def objective(trial):
#     param = {
#         'n_estimators': trial.suggest_int('n_estimators', 1000, 8000),
#         'max_depth': trial.suggest_int('max_depth', 3, 300),
#         'learning_rate': trial.suggest_float('learning_rate', 1e-5, 1e-1, log=True),
#         'num_leaves': trial.suggest_int('num_leaves', 2, 2048),
#         'min_child_samples': trial.suggest_int('min_child_samples', 1, 100),
#         'subsample': trial.suggest_float('subsample', 0.6, 1.0),
#         'reg_alpha': trial.suggest_float('reg_alpha', 1e-3, 10.0, log=True),
#         'reg_lambda': trial.suggest_float('reg_lambda', 1e-3, 10.0, log=True),
        
#         'boosting_type' : 'gbdt',
#         'random_state': 42,
#         'objective': 'binary',
#         'metric': 'auc',
#         'verbose': -1,   
#         'njobs': -1
#     }

#     model = lgb.LGBMClassifier(**param)
#     model.fit(IVF_X_train, IVF_y_train)
    
#     y_pred_proba = model.predict_proba(IVF_X_test)[:, 1]
    
#     auc = roc_auc_score(IVF_y_test, y_pred_proba)
#     return auc

# # Optuna 스터디 생성 및 최적화 실행
# study = optuna.create_study(direction='maximize')
# study.optimize(objective, n_trials=800)

# # 최적의 하이퍼파라미터 출력
# print("Best trial:")
# trial = study.best_trial
# print(f"  Value: {trial.value}")
# print("  Params: ")
# for key, value in trial.params.items():
#     print(f"    {key}: {value}")

# %% [markdown]
# .
