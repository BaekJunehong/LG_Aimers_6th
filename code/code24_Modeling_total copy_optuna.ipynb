# %% [markdown]
# ## 난임 환자 대상 임신 성공 여부 예측

# %% [markdown]
# ### LGAimers 6th 온라인 해커톤

# %% [markdown]
# Import

# %%
import pandas as pd
import lightgbm as lgb
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
import lightgbm as lgb
import xgboost as xgb
from catboost import CatBoostClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ### Data Load

# %%
# 데이터 로드
Total_train = pd.read_csv('../data/Total_train_dataset_24.csv')
Total_test = pd.read_csv('../data/Total_test_dataset_24.csv')

# %%
# ID 열을 제외한 특성과 타겟 변수 분리
Total_X = Total_train.drop(['임신_성공_여부', 'ID'], axis=1)
Total_y = Total_train['임신_성공_여부']

# %% [markdown]
# ### 인코딩

# %%
Total_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256342 entries, 0 to 256341
# Data columns (total 78 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   시술_시기_코드                256342 non-null  object
#  1   시술_당시_나이                256342 non-null  object
#  2   임신_시도_또는_마지막_임신_경과_연수   256342 non-null  object
#  3   시술_유형                   256342 non-null  object
#  4   배란_자극_여부                256342 non-null  int64
#  5   배란_유도_유형                256342 non-null  object
#  6   단일_배아_이식_여부             256342 non-null  object
#  7   착상_전_유전_검사_사용_여부        256342 non-null  float64
#  8   착상_전_유전_진단_사용_여부        256342 non-null  object
#  9   남성_주_불임_원인              256342 non-null  int64
#  10  남성_부_불임_원인              256342 non-null  int64
#  11  여성_주_불임_원인              256342 non-null  int64
#  12  여성_부_불임_원인              256342 non-null  int64
#  13  부부_주_불임_원인              256342 non-null  int64
#  14  부부_부_불임_원인              256342 non-null  int64
#  15  불명확_불임_원인               256342 non-null  int64
#  16  불임_원인_-_난관_질환           256342 non-null  int64
#  17  불임_원인_-_남성_요인           256342 non-null  int64
#  18  불임_원인_-_배란_장애           256342 non-null  int64
#  19  불임_원인_-_자궁경부_문제         256342 non-null  int64
#  20  불임_원인_-_자궁내막증           256342 non-null  int64
#  21  불임_원인_-_정자_농도           256342 non-null  int64
#  22  불임_원인_-_정자_면역학적_요인      256342 non-null  int64
#  23  불임_원인_-_정자_운동성          256342 non-null  int64
#  24  불임_원인_-_정자_형태           256342 non-null  int64
#  25  배아_생성_주요_이유             256342 non-null  object
#  26  총_시술_횟수                 256342 non-null  int64
#  27  클리닉_내_총_시술_횟수           256342 non-null  int64
#  28  IVF_시술_횟수               256342 non-null  int64
#  29  DI_시술_횟수                256342 non-null  int64
#  30  총_임신_횟수                 256342 non-null  int64
#  31  IVF_임신_횟수               256342 non-null  int64
#  32  DI_임신_횟수                256342 non-null  int64
#  33  총_출산_횟수                 256342 non-null  int64
#  34  IVF_출산_횟수               256342 non-null  int64
#  35  DI_출산_횟수                256342 non-null  int64
#  36  총_생성_배아_수               256342 non-null  object
#  37  미세주입된_난자_수              256342 non-null  object
#  38  미세주입에서_생성된_배아_수         256342 non-null  object
#  39  이식된_배아_수                256342 non-null  object
#  40  미세주입_배아_이식_수            256342 non-null  object
#  41  저장된_배아_수                256342 non-null  object
#  42  미세주입_후_저장된_배아_수         256342 non-null  object
#  43  해동된_배아_수                256342 non-null  object
#  44  해동_난자_수                 256342 non-null  object
#  45  수집된_신선_난자_수             256342 non-null  object
#  46  저장된_신선_난자_수             256342 non-null  object
#  47  혼합된_난자_수                256342 non-null  object
#  48  파트너_정자와_혼합된_난자_수        256342 non-null  object
#  49  기증자_정자와_혼합된_난자_수        256342 non-null  object
#  50  난자_출처                   256342 non-null  object
#  51  정자_출처                   256342 non-null  object
#  52  난자_기증자_나이               256342 non-null  object
#  53  정자_기증자_나이               256342 non-null  object
#  54  동결_배아_사용_여부             256342 non-null  object
#  55  신선_배아_사용_여부             256342 non-null  object
#  56  기증_배아_사용_여부             256342 non-null  object
#  57  대리모_여부                  256342 non-null  object
#  58  PGD_시술_여부               256342 non-null  float64
#  59  PGS_시술_여부               256342 non-null  float64
#  60  난자_채취_경과일               256342 non-null  object
#  61  난자_해동_경과일               256342 non-null  object
#  62  난자_혼합_경과일               256342 non-null  object
#  63  배아_이식_경과일               256342 non-null  object
#  64  배아_해동_경과일               256342 non-null  object
#  65  변환된_특정_시술_유형            256342 non-null  object
#  66  특정_시술_유형_ICSI_더미        256342 non-null  int64
#  67  특정_시술_유형_IVF_더미         256342 non-null  int64
#  68  특정_시술_유형_AH_더미          256342 non-null  int64
#  69  특정_시술_유형_BLASTOCYST_더미  256342 non-null  int64
#  70  배아_생성_주요_이유_현재시술용       256342 non-null  int64
#  71  IVF_임신_시술_비율            256342 non-null  float64
#  72  IVF_출산_임신_비율            256342 non-null  float64
#  73  DI_임신_시술_비율             256342 non-null  float64
#  74  DI_출산_임신_비율             256342 non-null  float64
#  75  임신_성공률                  256342 non-null  float64
#  76  출산_성공률                  256342 non-null  float64
#  77  기증자_나이_더미               256342 non-null  int64
# dtypes: float64(9), int64(33), object(36)
# memory usage: 152.5+ MB

# %%
Total_categorical_columns = [
    "시술_시기_코드",
    "시술_당시_나이",
    "임신_시도_또는_마지막_임신_경과_연수",
    "시술_유형",
    "배란_유도_유형",
    "단일_배아_이식_여부",
    "착상_전_유전_진단_사용_여부",
    "배아_생성_주요_이유",
    "총_생성_배아_수",
    "미세주입된_난자_수",
    "미세주입에서_생성된_배아_수",
    "이식된_배아_수",
    "미세주입_배아_이식_수",
    "저장된_배아_수",
    "미세주입_후_저장된_배아_수",
    "해동된_배아_수",
    "해동_난자_수",
    "수집된_신선_난자_수",
    "저장된_신선_난자_수",
    "혼합된_난자_수",
    "파트너_정자와_혼합된_난자_수",
    "기증자_정자와_혼합된_난자_수",
    "난자_출처",
    "정자_출처",
    "난자_기증자_나이",
    "정자_기증자_나이",
    "동결_배아_사용_여부",
    "신선_배아_사용_여부",
    "기증_배아_사용_여부",
    "대리모_여부",
    "변환된_특정_시술_유형",
    "난자_채취_경과일",
    "난자_해동_경과일",
    "난자_혼합_경과일",
    "배아_이식_경과일", 
    "배아_해동_경과일"
]

# %%
# 모든 범주형 변수를 문자열로 변환
Total_X[Total_categorical_columns] = Total_X[Total_categorical_columns].astype(str)
Total_test[Total_categorical_columns] = Total_test[Total_categorical_columns].astype(str)

# OrdinalEncoder를 사용하여 범주형 변수 인코딩
Total_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

Total_X[Total_categorical_columns] = Total_encoder.fit_transform(Total_X[Total_categorical_columns])
Total_test[Total_categorical_columns] = Total_encoder.transform(Total_test[Total_categorical_columns])

# %% [markdown]
# ## Modeling

# %%
# 데이터 분할
Total_X_train, Total_X_test, Total_y_train, Total_y_test = train_test_split(Total_X, Total_y, test_size=0.2, random_state=42)

# %% [markdown]
# ### Total 데이터

# %% [markdown]
# optuna

# %%
import optuna
import lightgbm as lgb
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# 목적 함수 정의
def objective(trial):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 200, 6000),
        'num_leaves': trial.suggest_int('num_leaves', 2, 512),
        'max_depth': trial.suggest_int('max_depth', -1, 512),
        'learning_rate': trial.suggest_float('learning_rate', 1e-4, 1e-1, log=True),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
        'subsample': trial.suggest_float('subsample', 0.2, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.2, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 10.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 10.0, log=True),
        'min_split_gain': trial.suggest_float('min_split_gain', 1e-8, 1.0, log=True),
        'random_state': 42,
        'boosting_type': 'gbdt',
        'verbose': -1
    }

    model = lgb.LGBMClassifier(**param)
    model.fit(Total_X_train, Total_y_train)
    
    y_pred_proba = model.predict_proba(Total_X_test)[:, 1]
    
    auc = roc_auc_score(Total_y_test, y_pred_proba)
    return auc

# Optuna 스터디 생성 및 최적화 실행
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=800)

# 최적의 하이퍼파라미터 출력
print("Best trial:")
trial = study.best_trial
print(f"  Value: {trial.value}")
print("  Params: ")
for key, value in trial.params.items():
    print(f"    {key}: {value}")
# Out:
# [I 2025-02-08 13:13:14,347] A new study created in memory with name: no-name-21c201ce-763a-4048-98ed-187eafd8b5d9
# [I 2025-02-08 13:14:32,661] Trial 0 finished with value: 0.7333521378956961 and parameters: {'n_estimators': 4249, 'num_leaves': 420, 'max_depth': 299, 'learning_rate': 0.0012538872297914356, 'min_child_samples': 100, 'subsample': 0.9395680516967388, 'colsample_bytree': 0.9023922466667516, 'reg_alpha': 0.008375438677157884, 'reg_lambda': 1.1570286267727987e-08, 'min_split_gain': 0.014810322064906461}. Best is trial 0 with value: 0.7333521378956961.
# [I 2025-02-08 13:15:22,643] Trial 1 finished with value: 0.7234344484640398 and parameters: {'n_estimators': 4203, 'num_leaves': 314, 'max_depth': 507, 'learning_rate': 0.00970231385858288, 'min_child_samples': 14, 'subsample': 0.2779523944249139, 'colsample_bytree': 0.6290223105777315, 'reg_alpha': 0.30248056982824134, 'reg_lambda': 5.820652691004129e-05, 'min_split_gain': 2.6501914825294283e-05}. Best is trial 0 with value: 0.7333521378956961.
# [I 2025-02-08 13:16:35,627] Trial 2 finished with value: 0.7333299222015552 and parameters: {'n_estimators': 3638, 'num_leaves': 457, 'max_depth': 423, 'learning_rate': 0.00019645580393887655, 'min_child_samples': 89, 'subsample': 0.7659202230150699, 'colsample_bytree': 0.9999350412182657, 'reg_alpha': 1.2409588353823624, 'reg_lambda': 0.09124374411310295, 'min_split_gain': 5.632604238737203e-08}. Best is trial 0 with value: 0.7333521378956961.
# [I 2025-02-08 13:16:47,914] Trial 3 finished with value: 0.7337476471443629 and parameters: {'n_estimators': 1394, 'num_leaves': 106, 'max_depth': 366, 'learning_rate': 0.00019886411096787078, 'min_child_samples': 89, 'subsample': 0.9233897299739577, 'colsample_bytree': 0.9176322701809378, 'reg_alpha': 1.476697027417429e-07, 'reg_lambda': 4.218340878915651, 'min_split_gain': 1.3988789927893872e-08}. Best is trial 3 with value: 0.7337476471443629.
. Best is trial 85 with value: 0.7382528860638866.
# [I 2025-02-08 13:49:09,485] Trial 95 finished with value: 0.7379567028046432 and parameters: {'n_estimators': 3164, 'num_leaves': 243, 'max_depth': 499, 'learning_rate': 0.004712787786318185, 'min_child_samples': 98, 'subsample': 0.2230797152521318, 'colsample_bytree': 0.4060437164210692, 'reg_alpha': 0.937685487628385, 'reg_lambda': 5.3785588510947475e-05, 'min_split_gain': 0.9820255542268518}. Best is trial 85 with value: 0.7382528860638866.
# [I 2025-02-08 13:49:46,173] Trial 96 finished with value: 0.7346057915106305 and parameters: {'n_estimators': 2783, 'num_leaves': 213, 'max_depth': 450, 'learning_rate': 0.006224405615118405, 'min_child_samples': 82, 'subsample': 0.32888301495829514, 'colsample_bytree': 0.3493682383568831, 'reg_alpha': 2.36200541455334, 'reg_lambda': 0.010540784816761413, 'min_split_gain': 1.984857989336488e-05}. Best is trial 85 with value: 0.7382528860638866.
# [I 2025-02-08 13:50:17,970] Trial 97 finished with value: 0.7381824965491635 and parameters: {'n_estimators': 3401, 'num_leaves': 277, 'max_depth': 483, 'learning_rate': 0.0034056147712668143, 'min_child_samples': 73, 'subsample': 0.35280740295950486, 'colsample_bytree': 0.4013321573063767, 'reg_alpha': 5.565686156563415, 'reg_lambda': 2.0869340783091412e-05, 'min_split_gain': 0.3269807926402867}. Best is trial 85 with value: 0.7382528860638866.
# [I 2025-02-08 13:50:50,310] Trial 98 finished with value: 0.7373796712751715 and parameters: {'n_estimators': 3356, 'num_leaves': 282, 'max_depth': 484, 'learning_rate': 0.0022675937895040342, 'min_child_samples': 73, 'subsample': 0.3049479495883267, 'colsample_bytree': 0.30981400671174364, 'reg_alpha': 5.518455830567126, 'reg_lambda': 3.5949094238992e-06, 'min_split_gain': 0.3502974780840155}. Best is trial 85 with value: 0.7382528860638866.
# [I 2025-02-08 13:52:04,182] Trial 99 finished with value: 0.7347986121659222 and parameters: {'n_estimators': 4012, 'num_leaves': 340, 'max_depth': 29, 'learning_rate': 0.00039623542878928174, 'min_child_samples': 93, 'subsample': 0.2727631146245219, 'colsample_bytree': 0.46360767197918923, 'reg_alpha': 1.306524631313117, 'reg_lambda': 1.019424406213661e-05, 'min_split_gain': 0.10401252039227936}. Best is trial 85 with value: 0.7382528860638866.
# [I 2025-02-08 13:52:59,213] Trial 100 finished with value: 0.7369614250967388 and parameters: {'n_estimators': 3748, 'num_leaves': 309, 'max_depth': 501, 'learning_rate': 0.0031956393814544393, 'min_child_samples': 84, 'subsample': 0.34549680959637297, 'colsample_bytree': 0.44499347526368704, 'reg_alpha': 6.680297306748242, 'reg_lambda': 2.0614556947034162e-05, 'min_split_gain': 0.024420824477307826}. Best is trial 85 with value: 0.7382528860638866.
# [I 2025-02-08 13:53:28,329] Trial 101 finished with value: 0.73782102951507 and parameters: {'n_estimators': 2806, 'num_leaves': 272, 'max_depth': 449, 'learning_rate': 0.004294506326391046, 'min_child_samples': 71, 'subsample': 0.2350034195875597, 'colsample_bytree': 0.39995447096367037, 'reg_alpha': 4.148771446307317, 'reg_lambda': 3.2195138463982785e-05, 'min_split_gain': 0.21838065692071604}. Best is trial 85 with value: 0.7382528860638866.
# [I 2025-02-08 13:54:05,642] Trial 102 finished with value: 0.7377005451105859 and parameters: {'n_estimators': 3540, 'num_leaves': 120, 'max_depth': 466, 'learning_rate': 0.0027402141735408327, 'min_child_samples': 76, 'subsample': 0.2580956118329833, 'colsample_bytree': 0.37553318543553005, 'reg_alpha': 3.1160885173946617, 'reg_lambda': 9.271960879124285e-05, 'min_split_gain': 0.13775953624354093}. Best is trial 85 with value: 0.7382528860638866.
# [I 2025-02-08 13
. Best is trial 237 with value: 0.7386094951424671.
# [I 2025-02-08 15:20:24,270] Trial 435 finished with value: 0.7360108186639662 and parameters: {'n_estimators': 1826, 'num_leaves': 23, 'max_depth': 283, 'learning_rate': 0.07386270539196636, 'min_child_samples': 35, 'subsample': 0.85456584838047, 'colsample_bytree': 0.3484991147078299, 'reg_alpha': 3.125909512564333, 'reg_lambda': 0.000902201809624515, 'min_split_gain': 0.012621727733932714}. Best is trial 237 with value: 0.7386094951424671.
# [I 2025-02-08 15:20:35,172] Trial 436 finished with value: 0.7120906899522521 and parameters: {'n_estimators': 2181, 'num_leaves': 2, 'max_depth': 221, 'learning_rate': 0.0014387587146271858, 'min_child_samples': 37, 'subsample': 0.3827761815955634, 'colsample_bytree': 0.37685202424310316, 'reg_alpha': 9.961348034567155, 'reg_lambda': 0.0064259989944589905, 'min_split_gain': 0.007486222304411886}. Best is trial 237 with value: 0.7386094951424671.
# [I 2025-02-08 15:20:53,476] Trial 437 finished with value: 0.7371231937319805 and parameters: {'n_estimators': 2593, 'num_leaves': 38, 'max_depth': 237, 'learning_rate': 0.015859860686528, 'min_child_samples': 40, 'subsample': 0.301671788970853, 'colsample_bytree': 0.2413513486587608, 'reg_alpha': 4.779185215976883, 'reg_lambda': 0.0022041507078184625, 'min_split_gain': 0.0037073219230059303}. Best is trial 237 with value: 0.7386094951424671.
# [I 2025-02-08 15:21:09,227] Trial 438 finished with value: 0.7384299472390295 and parameters: {'n_estimators': 2812, 'num_leaves': 27, 'max_depth': 215, 'learning_rate': 0.023123637250474918, 'min_child_samples': 33, 'subsample': 0.34453503819502673, 'colsample_bytree': 0.3147261377816382, 'reg_alpha': 6.613363794520807, 'reg_lambda': 0.07041586476962272, 'min_split_gain': 0.023686472673282315}. Best is trial 237 with value: 0.7386094951424671.
# [I 2025-02-08 15:21:20,419] Trial 439 finished with value: 0.7383673673739841 and parameters: {'n_estimators': 1987, 'num_leaves': 13, 'max_depth': 180, 'learning_rate': 0.03323265496483282, 'min_child_samples': 37, 'subsample': 0.40151880434517373, 'colsample_bytree': 0.3363414042852269, 'reg_alpha': 9.920939376043838, 'reg_lambda': 0.01998239914010239, 'min_split_gain': 0.016555122991233965}. Best is trial 237 with value: 0.7386094951424671.
# [I 2025-02-08 15:21:37,518] Trial 440 finished with value: 0.7374446737012469 and parameters: {'n_estimators': 2481, 'num_leaves': 45, 'max_depth': 204, 'learning_rate': 0.013908294980380941, 'min_child_samples': 41, 'subsample': 0.37113552573501524, 'colsample_bytree': 0.36473850185681134, 'reg_alpha': 2.292362169164902, 'reg_lambda': 0.009837199234712251, 'min_split_gain': 0.05070998560776835}. Best is trial 237 with value: 0.7386094951424671.
# [I 2025-02-08 15:21:52,480] Trial 441 finished with value: 0.7382311007840119 and parameters: {'n_estimators': 3108, 'num_leaves': 33, 'max_depth': 193, 'learning_rate': 0.09048468436568373, 'min_child_samples': 35, 'subsample': 0.5821203425177865, 'colsample_bytree': 0.4009263002241082, 'reg_alpha': 4.800270342906504, 'reg_lambda': 0.0032824899723402465, 'min_split_gain': 0.08191643011204852}. Best is trial 237 with value: 0.7386094951424671.
# [I 2025-02-08 15:22:06,668] Trial 442 finished with value: 0.7377499795711174 and parameters: {'n_estimators': 2355, 'num_leaves': 58, 'max_depth': 256, 'learning_rate': 0.028271776525309517, 'min_child_samples': 39, 'subsample': 0.32008494876004656, 'colsample_bytree': 0.4404910526717019, 'reg_alpha': 7.05605190035805, 'reg_lambda': 2.569947560403704e-07, 'min_split_gain': 0.010303244340624821}. Best is trial 237 with value: 0.7386094951424671.
# [I 2025-02-08 15:22:18,922] Trial 443 finished with value: 0.7379605844305481 and parameters: {'n_estimators': 1843, 'num_leaves': 19, 'max_depth': 231, 'learning_rate': 0.01830573385444103, 'min_child_samples': 30, 'subsample': 0.36036746218130156, 'colsample_bytree': 0.49624763520807413, 'reg_alpha': 3.7485447470893773, 'reg_lambda': 0.0047567900746524686, 'min_split_gain': 0.027634911841658102}. Best is trial 237 with value: 0.7386094951424671.
# [I 2025-02-08 15:22:31,272] Trial 444 finished with value: 0.7380750904203629 and parameters: {'n_estimators': 2066, 'num_leaves': 10, 'max_depth': 273, 'learning_rate': 0.021585038120660267, 'min_child_samples': 57, 'subsample': 0.3874286877282965, 'colsample_bytree': 0.3826858438203243, 'reg_alpha': 6.702110286382432, 'reg_lambda': 0.14099347636835727, 'min_split_gain': 0.04374403015079752}. Best is trial 237 with value: 0.7386094951424671.
# [I 2025-02-08 15:22:41,522] Trial 445 finished with value: 0.7355416789601275 and parameters: {'n_estimators': 1652, 'num_leaves': 27, 'max_depth': 224, 'learning_rate': 0.03984285554082457, 'min_child_samples': 32, 'subsample': 0.33383898694760866, 'colsample_bytree': 0.3466572166047723, 'reg_alpha': 0.00013697946275132908, 'reg_lambda': 0.01500088526240018, 'min_split_gain': 4.1368294911619784e-05}. Best is trial 237 with value: 0.7386094951424671.
# [I 2025-02-08 15:22:55,104] Trial 446 finished with value: 0.7362142535719862 and parameters: {'n_estimators': 2708, 'num_leaves': 49, 'max_depth': 211, 'learning_rate': 0.01246369596805668, 'min_child_samples': 38, 'subsample': 0.2810354091376474, 'colsample_bytree': 0.8640395283637343, 'reg_alpha': 4.960608867691598, 'reg_lambda': 0.08701194952546319, 'min_split_gain': 0.01707729213110985}. Best is trial 237 with value: 0.7386094951424671.
# [I 2025-02-08 15:23:05,848] Trial 447 finished with value: 0.7383940520712968 and parameters: {'n_estimators': 2234, 'num_leaves': 40, 'max_depth': 246, 'learning_rate': 0.06597796865620409, 'min_child_samples': 41, 'subsample': 0.35463932033576206, 'colsample_bytree': 0.3262326995542671, 'reg_alpha': 7.015263954956558, 'reg_lambda': 0.032679156624724454, 'min_split_gain': 0.06965518928748059}. Best is trial 237 with value: 0.7386094951424671.
# [I 2025-02-08 15:23:09,543] Trial 448 finished with value: 0.738298526758306 and parameters: {'n_estimators': 628, 'num_leaves': 21, 'max_depth': 169, 'learning_rate': 0.09994474446052093, 'min_child_samples': 34, 'subsample': 0.30880948712910977, 'colsample_bytree': 0.29925584500101454, 'reg_alpha': 3.0468752005207276, 'reg_lambda': 0.0077313023579557855, 'min_split_gain': 0.13505456835326382}. Best is trial 237 with value: 0.7386094951424671.
# [I 2025-02-08 15:23:26,636] Trial 449 finished with value: 0.7384945044430085 and parameters: {'n_estimators': 2870, 'num_leaves': 34, 'max_depth': 198, 'learning_rate': 0.016566480572297832, 'min_child_samples': 37, 'subsample': 0.6736281194377768, 'colsample_bytree': 0.3624957498893856, 'reg_alpha': 9.761017338166695, 'reg_lambda': 0.0014262088428740548, 'min_split_gain': 0.03176939592417258}. Best is trial 237 with value: 0.7386094951424671.
# [I 2025-02-08 15:23:45,920] Trial 450 finished with value: 0.7373019321406973 and parameters: {'n_estimators': 2917, 'num_leaves': 69, 'max_depth': 185, 'learning_rate': 0.017113602320515668, 'min_child_samples': 36, 'subsample': 0.5657923812786394, 'colsample_bytree': 0.3573769822955098, 'reg_alpha': 4.985491515076351, 'reg_lambda': 0.0013719856482804493, 'min_split_gain': 0.012475169045923816}. Best is trial 237 with value: 0.7386094951424671.
# [I 2025-02-08 15:24:05,276] Trial 451 finished with value: 0.7383062060990776 and parameters: {'n_estimators': 3042, 'num_leaves': 13, 'max_depth': 239, 'learning_rate': 0.01511210867924578, 'min_child_samples': 31, 'subsample': 0.6797410262912547, 'colsample_bytree': 0.3390184387512323, 'reg_alpha': 7.057453458468594, 'reg_lambda': 0.0010680837402136099, 'min_split_gain': 0.007496361262309034}. Best is trial 237 with value: 0.7386094951424671.
# [W 2025-02-08 15:24:12,983] Trial 452 failed with parameters: {'n_estimators': 2872, 'num_leaves': 37, 'max_depth': 287, 'learning_rate': 0.012919610357115287, 'min_child_samples': 28, 'subsample': 0.318076706877982, 'colsample_bytree': 0.31863711539099404, 'reg_alpha': 9.978706100146471, 'reg_lambda': 0.0018428450387176299, 'min_split_gain': 0.022406794461495357} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\_optimize.py", line 196, in _run_trial
#     value_or_values = func(trial)
#   File "C:\Users\juneh\AppData\Local\Temp\ipykernel_18372\3013099825.py", line 26, in objective
#     model.fit(Total_X_train, Total_y_train)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\sklearn.py", line 1298, in fit
#     init_model=init_model,
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\sklearn.py", line 963, in fit
#     callbacks=callbacks,
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\engine.py", line 307, in train
#     booster.update(fobj=fobj)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\basic.py", line 4138, in update
#     ctypes.byref(is_finished),
# KeyboardInterrupt
# [W 2025-02-08 15:24:13,006] Trial 452 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18372\3013099825.py in <module>
#      33 # Optuna 스터디 생성 및 최적화 실행
#      34 study = optuna.create_study(direction='maximize')
# ---> 35 study.optimize(objective, n_trials=800)
#      36
#      37 # 최적의 하이퍼파라미터 출력
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     458             callbacks=callbacks,
#     459             gc_after_trial=gc_after_trial,
# --> 460             show_progress_bar=show_progress_bar,
#     461         )
#     462
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      70                 reseed_sampler_rng=False,
#      71                 time_start=None,
# ---> 72                 progress_bar=progress_bar,
#      73             )
#      74         else:
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157
#     158         try:
# --> 159             frozen_trial = _run_trial(study, func, catch)
#     160         finally:
#     161             # The following line mitigates memory problems that can be occurred in some
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\_optimize.py in _run_trial(study, func, catch)
#     245         and not isinstance(func_err, catch)
#     246     ):
# --> 247         raise func_err
#     248     return frozen_trial
#     249
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\_optimize.py in _run_trial(study, func, catch)
#     194     with get_heartbeat_thread(trial._trial_id, study._storage):
#     195         try:
# --> 196             value_or_values = func(trial)
#     197         except exceptions.TrialPruned as e:
#     198             # TODO(mamu): Handle multi-objective cases.
#
# ~\AppData\Local\Temp\ipykernel_18372\3013099825.py in objective(trial)
#      24
#      25     model = lgb.LGBMClassifier(**param)
# ---> 26     model.fit(Total_X_train, Total_y_train)
#      27
#      28     y_pred_proba = model.predict_proba(Total_X_test)[:, 1]
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1296             categorical_feature=categorical_feature,
#    1297             callbacks=callbacks,
# -> 1298             init_model=init_model,
#    1299         )
#    1300         return self
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#     961             feval=eval_metrics_callable,  # type: ignore[arg-type]
#     962             init_model=init_model,
# --> 963             callbacks=callbacks,
#     964         )
#     965
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, feature_name, categorical_feature, keep_training_booster, callbacks)
#     305             )
#     306
# --> 307         booster.update(fobj=fobj)
#     308
#     309         evaluation_result_list: List[_LGBM_BoosterEvalMethodResultType] = []
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\basic.py in update(self, train_set, fobj)
#    4136                 _LIB.LGBM_BoosterUpdateOneIter(
#    4137                     self._handle,
# -> 4138                     ctypes.byref(is_finished),
#    4139                 )
#    4140             )
#
# KeyboardInterrupt:

# %% [markdown]
# 최적의 파라미터로 학습

# %%
import lightgbm as lgb
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# 모델 초기화
Total_model = lgb.LGBMClassifier(
    n_estimators=5471,  # 트리의 개수 (부스팅 반복 횟수)
    num_leaves=13,  # 하나의 트리가 가질 수 있는 최대 리프 노드 수
    max_depth=279,  # 트리의 최대 깊이 (-1이면 제한 없음)
    learning_rate=0.007075124517450591,  # 학습률 (0과 1 사이의 값)
    min_child_samples=26,  # 리프 노드가 되기 위한 최소한의 데이터 수
    subsample=0.29772991936701476,  # 각 트리를 학습할 때 사용하는 데이터 샘플링 비율
    colsample_bytree=0.8913054521763838,  # 각 트리를 학습할 때 사용하는 피처 샘플링 비율
    reg_alpha=0.0004860363321690653,  # L1 정규화 (Lasso) 계수
    reg_lambda=311.08056657247363,  # L2 정규화 (Ridge) 계수
    min_split_gain=0.18214905183450955,  # 노드를 분할하기 위한 최소 손실 감소 값
    random_state=42,  # 랜덤 시드 값 (재현성을 위해 설정)
    boosting_type='gbdt',  # 부스팅 유형 ('gbdt', 'dart', 'goss', 'rf' 중 하나)
    verbose=-1  # 학습 과정의 출력을 제어 (음수이면 출력을 억제)
)

# 모델 학습
Total_model.fit(Total_X_train, Total_y_train)

# 예측
y_pred = Total_model.predict(Total_X_test)
y_pred_proba = Total_model.predict_proba(Total_X_test)[:, 1]

# 평가
accuracy = accuracy_score(Total_y_test, y_pred)
f1 = f1_score(Total_y_test, y_pred)
auc = roc_auc_score(Total_y_test, y_pred_proba)
cm = confusion_matrix(Total_y_test, y_pred)

# 결과 출력
print()
print("--- Model Performance ---")
print(f"Model Accuracy: {accuracy}")
print(f"Model F1 Score: {f1}")
print(f"Model AUC: {auc}")

# 혼동 행렬 출력
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=Total_model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# --- Model Performance ---
# Model Accuracy: 0.7445044763892411
# Model F1 Score: 0.18685207027127693
# Model AUC: 0.7379306489208997

# %% [markdown]
# 데이콘 PUBLIC ??

# %% [markdown]
# ## 제출

# %%
# 모델 학습 및 예측
Total_model.fit(Total_X, Total_y)
Total_pred_proba = Total_model.predict_proba(Total_test.drop('ID', axis=1))[:, 1]
Total_test['probability'] = Total_pred_proba

# 최종 제출 파일 생성
submission = Total_test[['ID', 'probability']]
submission = submission.sort_values(by='ID')

# %%
# 제출 파일 저장
submission.to_csv('../submission/code24_total_submit.csv', index=False, encoding='utf-8')

# %%
import pandas as pd

# 두 CSV 파일을 읽어옵니다.
df1 = pd.read_csv('../submission/code24_submit.csv')
df2 = pd.read_csv('../submission/code24_total_submit.csv')

# ID를 기준으로 병합합니다.
merged_df = pd.merge(df1, df2, on='ID', suffixes=('_df1', '_df2'))

# 'probability' 열을 소프트 보팅하여 새로운 'probability' 열 생성
merged_df['probability'] = (merged_df['probability_df1'] + merged_df['probability_df2']) / 2

# 최종 제출 파일 생성
submission = merged_df[['ID', 'probability']]
submission = submission.sort_values(by='ID')

# 제출 파일 저장
submission.to_csv('../submission/code24_soft_voting_submit.csv', index=False, encoding='utf-8')

# %% [markdown]
# 데이콘 PUBLIC ??

# %% [markdown]
# .
