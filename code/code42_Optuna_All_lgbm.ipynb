# %% [markdown]
# ## 난임 환자 대상 임신 성공 여부 예측

# %% [markdown]
# ### LGAimers 6th 온라인 해커톤

# %% [markdown]
# Import

# %%
import pandas as pd
import optuna
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import lightgbm as lgb

# %% [markdown]
# ### Data Load

# %%
# 데이터 로드
Total_train = pd.read_csv('../data/Total_train_dataset_42.csv')
Total_test = pd.read_csv('../data/Total_test_dataset_42.csv')

# %%
# ID 열을 제외한 특성과 타겟 변수 분리
Total_X = Total_train.drop(['임신_성공_여부', 'ID'], axis=1)
Total_y = Total_train['임신_성공_여부']

# %% [markdown]
# ### 인코딩

# %%
Total_categorical_columns = [
    "시술_당시_나이",
    "난자_출처",
    "정자_출처",
    "난자_기증자_나이",
    "정자_기증자_나이"
]

# %%
# 모든 범주형 변수를 문자열로 변환
Total_X[Total_categorical_columns] = Total_X[Total_categorical_columns].astype(str)
Total_test[Total_categorical_columns] = Total_test[Total_categorical_columns].astype(str)

# OrdinalEncoder를 사용하여 범주형 변수 인코딩
Total_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

Total_X[Total_categorical_columns] = Total_encoder.fit_transform(Total_X[Total_categorical_columns])
Total_test[Total_categorical_columns] = Total_encoder.transform(Total_test[Total_categorical_columns])

# %% [markdown]
# ## Modeling

# %%
# from sklearn.utils import resample
# from sklearn.model_selection import train_test_split
# import numpy as np

# # 다운샘플링을 위한 데이터 준비
# # 예시로 클래스 0과 클래스 1이 있다고 가정
# class_0 = Total_X[Total_y == 0]
# class_1 = Total_X[Total_y == 1]

# # 클래스 0을 클래스 1의 수에 맞춰 다운샘플링
# class_0_downsampled = resample(class_0, 
#                                replace=False,    # 복원 추출하지 않음
#                                n_samples=len(class_1),  # 클래스 1의 수에 맞춤
#                                random_state=42)  # 재현성을 위한 랜덤 시드

# # 다운샘플링된 데이터와 클래스 1 데이터를 합침
# X_downsampled = np.vstack((class_0_downsampled, class_1))
# y_downsampled = np.hstack((np.zeros(len(class_0_downsampled)), np.ones(len(class_1))))

# %%
# 데이터 분할
Total_X_train, Total_X_test, Total_y_train, Total_y_test = train_test_split(Total_X, 
                                                                            Total_y, 
                                                                            test_size=0.2, 
                                                                            random_state=42,
                                                                            stratify=Total_y)

# %% [markdown]
# ### Total 데이터

# %% [markdown]
# optuna

# %%
# 목적 함수 정의
def objective(trial):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 500, 3500),
        'num_leaves': trial.suggest_int('num_leaves', 500, 3500),
        'max_depth': trial.suggest_int('max_depth', 5, 350),
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.2),
        'min_child_samples': trial.suggest_int('min_child_samples', 3, 350),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 10.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 10.0),

        'random_state': 42,
        'n_jobs': -1,
        'metric': 'auc',
        'objective': 'binary',
        'boosting_type': 'gbdt',
        'verbose': -1
    }

    model = lgb.LGBMClassifier(**param)
    model.fit(Total_X_train, Total_y_train)
    
    y_pred_proba = model.predict_proba(Total_X_test)[:, 1]
    
    auc = roc_auc_score(Total_y_test, y_pred_proba)
    return auc

# Optuna 스터디 생성 및 최적화 실행
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=500)

# 최적의 하이퍼파라미터 출력
print("Best trial:")
trial = study.best_trial
print(f"  Value: {trial.value}")
print("  Params: ")
for key, value in trial.params.items():
    print(f"    {key}: {value}")
# Out:
# [I 2025-02-19 00:14:18,718] A new study created in memory with name: no-name-22d322e5-48eb-4824-94fb-22b056ed75c9
# [I 2025-02-19 00:14:35,234] Trial 0 finished with value: 0.7155434077636846 and parameters: {'n_estimators': 2166, 'num_leaves': 919, 'max_depth': 276, 'learning_rate': 0.12298338520138044, 'min_child_samples': 154, 'subsample': 0.8908234068708585, 'colsample_bytree': 0.7846042603074108, 'reg_alpha': 5.644640257732113, 'reg_lambda': 9.536086549031863}. Best is trial 0 with value: 0.7155434077636846.
# [I 2025-02-19 00:14:52,489] Trial 1 finished with value: 0.7129168236277944 and parameters: {'n_estimators': 2960, 'num_leaves': 1728, 'max_depth': 145, 'learning_rate': 0.13810937855612546, 'min_child_samples': 114, 'subsample': 0.6297244552990051, 'colsample_bytree': 0.9893658713112174, 'reg_alpha': 5.58664065046797, 'reg_lambda': 6.931972234523675}. Best is trial 0 with value: 0.7155434077636846.
# [I 2025-02-19 00:15:06,961] Trial 2 finished with value: 0.7272115455562151 and parameters: {'n_estimators': 2671, 'num_leaves': 782, 'max_depth': 194, 'learning_rate': 0.07209259950577994, 'min_child_samples': 240, 'subsample': 0.9995803450206799, 'colsample_bytree': 0.9561266358375747, 'reg_alpha': 8.954553635058598, 'reg_lambda': 0.7295577340911674}. Best is trial 2 with value: 0.7272115455562151.
# [I 2025-02-19 00:16:07,360] Trial 3 finished with value: 0.7243116753186898 and parameters: {'n_estimators': 1333, 'num_leaves': 2078, 'max_depth': 43, 'learning_rate': 0.01379476511793164, 'min_child_samples': 14, 'subsample': 0.8782594719502277, 'colsample_bytree': 0.5148528052150858, 'reg_alpha': 4.84496639581457, 'reg_lambda': 0.18268911431094992}. Best is trial 2 with value: 0.7272115455562151.
# [I 2025-02-19 00:17:08,496] Trial 4 finished with value: 0.7180564338495319 and parameters: {'n_estimators': 2759, 'num_leaves': 3311, 'max_depth': 77, 'learning_rate': 0.023049275830952443, 'min_child_samples': 177, 'subsample': 0.7071139447152156, 'colsample_bytree': 0.7326286516239522, 'reg_alpha': 4.904423378454595, 'reg_lambda': 4.291260099008899}. Best is trial 2 with value: 0.7272115455562151.
# [I 2025-02-19 00:17:32,242] Trial 5 finished with value: 0.7305467421700325 and parameters: {'n_estimators': 1931, 'num_leaves': 1411, 'max_depth': 296, 'learning_rate': 0.029643504683038342, 'min_child_samples': 272, 'subsample': 0.9081285200331789, 'colsample_bytree': 0.535520835355632, 'reg_alpha': 8.404298859076171, 'reg_lambda': 2.712997246698202}. Best is trial 5 with value: 0.7305467421700325.
# [I 2025-02-19 00:17:52,345] Trial 6 finished with value: 0.7323220459915762 and parameters: {'n_estimators': 778, 'num_leaves': 3047, 'max_depth': 131, 'learning_rate': 0.011822843291043331, 'min_child_samples': 229, 'subsample': 0.8581484159642901, 'colsample_bytree': 0.7563666764551894, 'reg_alpha': 3.833745955494164, 'reg_lambda': 0.2541721812412634}. Best is trial 6 with value: 0.7323220459915762.
# [I 2025-02-19 00:18:43,935] Trial 7 finished with value: 0.7268790848115874 and parameters: {'n_estimators': 948, 'num_leaves': 1962, 'max_depth': 82, 'learning_rate': 0.013791153569999964, 'min_child_samples': 14, 'subsample': 0.8365879823941302, 'colsample_bytree': 0.5046942673865571, 'reg_alpha': 3.9345259218287056, 'reg_lambda': 4.772993370058622}. Best is trial 6 with value: 0.7323220459915762.
# [I 2025-02-19 00:18:54,001] Trial 8 finished with value: 0.7199090824757359 and parameters: {'n_estimators': 858, 'num_leaves': 1100, 'max_depth': 218, 'learning_rate': 0.13967434304403062, 'min_child_samples': 273, 'subsample': 0.9699953062750437, 'colsample_bytree': 0.7898595849236878, 'reg_alpha': 6.657014997527187, 'reg_lambda': 4.4888734738391225}. Best is trial 6 with value: 0.7323220459915762.
# [I 2025-02-19 00:19:15,604] Trial 9 finished with value: 0.7085952102175122 and parameters: {'n_estimators': 3204, 'num_leaves': 2333, 'max_depth': 34, 'learning_rate': 0.17358490043228614, 'min_child_samples': 191, 'subsample': 0.636900683775524, 'colsample_bytree': 0.6098024402461684, 'reg_alpha': 4.4328711714610405, 'reg_lambda': 6.696311246600707}. Best is trial 6 with value: 0.7323220459915762.
# [I 2025-02-19 00:19:29,627] Trial 10 finished with value: 0.7160458650541746 and parameters: {'n_estimators': 550, 'num_leaves': 3481, 'max_depth': 136, 'learning_rate': 0.07214202144789174, 'min_child_samples': 350, 'subsample': 0.5044871719940613, 'colsample_bytree': 0.8929396583818254, 'reg_alpha': 0.7254068383442882, 'reg_lambda': 2.2284587495226686}. Best is trial 6 with value: 0.7323220459915762.
# [I 2025-02-19 00:19:41,063] Trial 11 finished with value: 0.7309063588775109 and parameters: {'n_estimators': 1823, 'num_leaves': 2827, 'max_depth': 326, 'learning_rate': 0.053602971266452346, 'min_child_samples': 300, 'subsample': 0.8125259948278122, 'colsample_bytree': 0.672985327634626, 'reg_alpha': 9.796401946771311, 'reg_lambda': 2.351452411233735}. Best is trial 6 with value: 0.7323220459915762.
# [I 2025-02-19 00:20:20,241] Trial 12 finished with value: 0.709010285530658 and parameters: {'n_estimators': 1625, 'num_leaves': 2778, 'max_depth': 258, 'learning_rate': 0.05887611135435876, 'min_child_samples': 334, 'subsample': 0.7848574429231389, 'colsample_bytree': 0.6729014125362696, 'reg_alpha': 2.310071519244338, 'reg_lambda': 1.9959094470294225}. Best is trial 6 with value: 0.7323220459915762.
# [I 2025-02-19 00:20:35,703] Trial 13 finished with value: 0.729834460316216 and parameters: {'n_estimators': 1265, 'num_leaves': 2564, 'max_depth': 332, 'learning_rate': 0.05139337044697691, 'min_child_samples': 239, 'subsample': 0.7842679245499435, 'colsample_bytree': 0.6783947882628032, 'reg_alpha': 9.807446120960472, 'reg_lambda': 1.41621503800327}. Best is trial 6 with value: 0.7323220459915762.
# [I 2025-02-19 00:20:49,017] Trial 14 finished with value: 0.7240909061666722 and parameters: {'n_estimators': 2233, 'num_leaves': 2986, 'max_depth': 139, 'learning_rate': 0.10035509949454711, 'min_child_samples': 306, 'subsample': 0.7195599875760663, 'colsample_bytree': 0.8703906342105432, 'reg_alpha': 7.372826731739286, 'reg_lambda': 3.453249194297152}. Best is trial 6 with value: 0.7323220459915762.
# [I 2025-02-19 00:21:06,389] Trial 15 finished with value: 0.73558043589644 and parameters: {'n_estimators': 506, 'num_leaves': 2949, 'max_depth': 214, 'learning_rate': 0.0025077859635462794, 'min_child_samples': 101, 'subsample': 0.8284749823531083, 'colsample_bytree': 0.6119600786747168, 'reg_alpha': 2.901148187935774, 'reg_lambda': 0.6231118595467667}. Best is trial 15 with value: 0.73558043589644.
# [I 2025-02-19 00:21:22,768] Trial 16 finished with value: 0.7357862009148501 and parameters: {'n_estimators': 526, 'num_leaves': 3175, 'max_depth': 234, 'learning_rate': 0.003171506173227345, 'min_child_samples': 87, 'subsample': 0.9047548159393981, 'colsample_bytree': 0.598191028414607, 'reg_alpha': 2.7816048729473444, 'reg_lambda': 0.29884644661425386}. Best is trial 16 with value: 0.7357862009148501.
# [I 2025-02-19 00:21:51,150] Trial 17 finished with value: 0.7180960960699794 and parameters: {'n_estimators': 592, 'num_leaves': 3236, 'max_depth': 226, 'learning_rate': 0.03810393336814588, 'min_child_samples': 80, 'subsample': 0.9642341733707412, 'colsample_bytree': 0.5863299262431514, 'reg_alpha': 2.34786273553161, 'reg_lambda': 6.131324274286644}. Best is trial 16 with value: 0.7357862009148501.
# [I 2025-02-19 00:22:48,048] Trial 18 finished with value: 0.7351303516000742 and parameters: {'n_estimators': 1215, 'num_leaves': 2493, 'max_depth': 245, 'learning_rate': 0.0011865222324687888, 'min_child_samples': 62, 'subsample': 0.9278445606425669, 'colsample_bytree': 0.6004480018716316, 'reg_alpha': 0.3365440636636179, 'reg_lambda': 8.43647634549467}. Best is trial 16 with value: 0.7357862009148501.
# [I 2025-02-19 00:23:23,170] Trial 19 finished with value: 0.7011746103095007 and parameters: {'n_estimators': 1054, 'num_leaves': 3441, 'max_depth': 182, 'learning_rate': 0.09464620292051117, 'min_child_samples': 123, 'subsample': 0.7322715758236817, 'colsample_bytree': 0.6273474003200759, 'reg_alpha': 2.592243764248471, 'reg_lambda': 1.1422948653801184}. Best is trial 16 with value: 0.7357862009148501.
# [I 2025-02-19 00:24:19,612] Trial 20 finished with value: 0.6873758309408922 and parameters: {'n_estimators': 1607, 'num_leaves': 536, 'max_depth': 207, 'learning_rate': 0.16490862931199832, 'min_child_samples': 77, 'subsample': 0.6534004741699818, 'colsample_bytree': 0.563342042475385, 'reg_alpha': 1.5718384356929738, 'reg_lambda': 3.020854186209248}. Best is trial 16 with value: 0.7357862009148501.
# [I 2025-02-19 00:24:53,875] Trial 21 finished with value: 0.7347432076238511 and parameters: {'n_estimators': 507, 'num_leaves': 2451, 'max_depth': 257, 'learning_rate': 0.0010961851788280487, 'min_child_samples': 57, 'subsample': 0.9264194459093695, 'colsample_bytree': 0.64018102122073, 'reg_alpha': 0.08237298867176607, 'reg_lambda': 9.244800168238081}. Best is trial 16 with value: 0.7357862009148501.
# [I 2025-02-19 00:26:10,860] Trial 22 finished with value: 0.7343069410692673 and parameters: {'n_estimators': 1186, 'num_leaves': 2661, 'max_depth': 234, 'learning_rate': 0.004765592014651973, 'min_child_samples': 61, 'subsample': 0.9371819268871802, 'colsample_bytree': 0.5697966767805122, 'reg_alpha': 3.152835842773214, 'reg_lambda': 8.371074869293368}. Best is trial 16 with value: 0.7357862009148501.
# [I 2025-02-19 00:27:14,557] Trial 23 finished with value: 0.690656165619743 and parameters: {'n_estimators': 808, 'num_leaves': 2214, 'max_depth': 284, 'learning_rate': 0.1949618120832095, 'min_child_samples': 113, 'subsample': 0.8520663021999665, 'colsample_bytree': 0.6446886884533006, 'reg_alpha': 1.3687257505308912, 'reg_lambda': 8.092503772712874}. Best is trial 16 with value: 0.7357862009148501.
# [I 2025-02-19 00:31:56,150] Trial 24 finished with value: 0.6893118893656165 and parameters: {'n_estimators': 1399, 'num_leaves': 3073, 'max_depth': 161, 'learning_rate': 0.03489057908899558, 'min_child_samples': 36, 'subsample': 0.8083431290787388, 'colsample_bytree': 0.7106886635727254, 'reg_alpha': 0.07354094006765255, 'reg_lambda': 5.764999867953383}. Best is trial 16 with value: 0.7357862009148501.
# [I 2025-02-19 00:32:46,592] Trial 25 finished with value: 0.7154002822480756 and parameters: {'n_estimators': 766, 'num_leaves': 2804, 'max_depth': 246, 'learning_rate': 0.032651637055929855, 'min_child_samples': 137, 'subsample': 0.9039725466446119, 'colsample_bytree': 0.551264123169483, 'reg_alpha': 1.3267094075460415, 'reg_lambda': 1.509431662695658}. Best is trial 16 with value: 0.7357862009148501.
# [I 2025-02-19 00:33:24,189] Trial 26 finished with value: 0.7360308676715833 and parameters: {'n_estimators': 969, 'num_leaves': 1751, 'max_depth': 296, 'learning_rate': 0.0016592690640856167, 'min_child_samples': 93, 'subsample': 0.9536042375144276, 'colsample_bytree': 0.5972694600899582, 'reg_alpha': 3.4088426403320096, 'reg_lambda': 7.837922105351242}. Best is trial 26 with value: 0.7360308676715833.
# [I 2025-02-19 00:34:10,395] Trial 27 finished with value: 0.7050765467948279 and parameters: {'n_estimators': 1017, 'num_leaves': 1720, 'max_depth': 310, 'learning_rate': 0.07740330055990478, 'min_child_samples': 90, 'subsample': 0.9761372905129737, 'colsample_bytree': 0.7072072521342528, 'reg_alpha': 3.2874956237840354, 'reg_lambda': 3.8439546196183514}. Best is trial 26 with value: 0.7360308676715833.
# [I 2025-02-19 00:34:31,585] Trial 28 finished with value: 0.7172238627853564 and parameters: {'n_estimators': 614, 'num_leaves': 1548, 'max_depth': 274, 'learning_rate': 0.045550157108287116, 'min_child_samples': 151, 'subsample': 0.772065396642015, 'colsample_bytree': 0.8389602366725745, 'reg_alpha': 2.945322895393176, 'reg_lambda': 5.440098189572419}. Best is trial 26 with value: 0.7360308676715833.
# [I 2025-02-19 00:35:27,011] Trial 29 finished with value: 0.7201679631000572 and parameters: {'n_estimators': 2103, 'num_leaves': 1212, 'max_depth': 341, 'learning_rate': 0.022564777785015432, 'min_child_samples': 97, 'subsample': 0.8830442223646581, 'colsample_bytree': 0.7895937912321422, 'reg_alpha': 5.939591480390021, 'reg_lambda': 9.516893090237462}. Best is trial 26 with value: 0.7360308676715833.
# [I 2025-02-19 00:36:00,985] Trial 30 finished with value: 0.7071008489442642 and parameters: {'n_estimators': 3477, 'num_leaves': 1868, 'max_depth': 308, 'learning_rate': 0.11579634130519069, 'min_child_samples': 200, 'subsample': 0.9495953454194512, 'colsample_bytree': 0.5991768611264074, 'reg_alpha': 3.79795803167604, 'reg_lambda': 0.016891187673245156}. Best is trial 26 with value: 0.7360308676715833.
# [I 2025-02-19 00:36:49,093] Trial 31 finished with value: 0.7350893113780754 and parameters: {'n_estimators': 1078, 'num_leaves': 2254, 'max_depth': 269, 'learning_rate': 0.0027181086134410843, 'min_child_samples': 41, 'subsample': 0.9148665020945019, 'colsample_bytree': 0.5862102375714018, 'reg_alpha': 2.0883158367533037, 'reg_lambda': 7.7196143755500675}. Best is trial 26 with value: 0.7360308676715833.
# [I 2025-02-19 00:38:10,609] Trial 32 finished with value: 0.7111607711233143 and parameters: {'n_estimators': 1520, 'num_leaves': 2505, 'max_depth': 206, 'learning_rate': 0.018661247162051392, 'min_child_samples': 103, 'subsample': 0.8765033134009717, 'colsample_bytree': 0.6230939452953757, 'reg_alpha': 0.7252571527679819, 'reg_lambda': 7.349573883822748}. Best is trial 26 with value: 0.7360308676715833.
# [I 2025-02-19 00:38:27,256] Trial 33 finished with value: 0.7366653966813752 and parameters: {'n_estimators': 779, 'num_leaves': 3168, 'max_depth': 244, 'learning_rate': 0.0042886492046434925, 'min_child_samples': 159, 'subsample': 0.9855567999120918, 'colsample_bytree': 0.6531476717545975, 'reg_alpha': 5.583475594427352, 'reg_lambda': 8.768047296270582}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:38:44,540] Trial 34 finished with value: 0.7309396552867565 and parameters: {'n_estimators': 683, 'num_leaves': 3243, 'max_depth': 181, 'learning_rate': 0.02191330588625189, 'min_child_samples': 156, 'subsample': 0.9773677672609046, 'colsample_bytree': 0.6579912147644952, 'reg_alpha': 5.698433248841096, 'reg_lambda': 6.606578729040546}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:39:31,829] Trial 35 finished with value: 0.7153595001531686 and parameters: {'n_estimators': 2380, 'num_leaves': 3091, 'max_depth': 280, 'learning_rate': 0.04098075782810191, 'min_child_samples': 136, 'subsample': 0.9969562187864212, 'colsample_bytree': 0.5309368049680894, 'reg_alpha': 4.281298657661918, 'reg_lambda': 9.871023367773393}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:39:55,946] Trial 36 finished with value: 0.7329862338042128 and parameters: {'n_estimators': 902, 'num_leaves': 3340, 'max_depth': 164, 'learning_rate': 0.013331990880616842, 'min_child_samples': 165, 'subsample': 0.8914430288140696, 'colsample_bytree': 0.7100287906309983, 'reg_alpha': 6.564983398802918, 'reg_lambda': 8.916904117912363}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:40:16,836] Trial 37 finished with value: 0.7163840979176928 and parameters: {'n_estimators': 691, 'num_leaves': 2900, 'max_depth': 203, 'learning_rate': 0.06463244046346514, 'min_child_samples': 124, 'subsample': 0.826421895745914, 'colsample_bytree': 0.7525526048609482, 'reg_alpha': 4.946804605429329, 'reg_lambda': 0.8170849683073419}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:40:42,849] Trial 38 finished with value: 0.7256384723975171 and parameters: {'n_estimators': 944, 'num_leaves': 1467, 'max_depth': 311, 'learning_rate': 0.027674391631733325, 'min_child_samples': 207, 'subsample': 0.8581085482451866, 'colsample_bytree': 0.5407478990824865, 'reg_alpha': 3.646962182191759, 'reg_lambda': 7.373823692386901}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:41:04,500] Trial 39 finished with value: 0.7344365020062035 and parameters: {'n_estimators': 523, 'num_leaves': 2089, 'max_depth': 237, 'learning_rate': 0.01098725193711275, 'min_child_samples': 32, 'subsample': 0.993201509126383, 'colsample_bytree': 0.56790676380078, 'reg_alpha': 5.333410640407987, 'reg_lambda': 0.5261684226488901}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:41:26,032] Trial 40 finished with value: 0.7110800925079843 and parameters: {'n_estimators': 769, 'num_leaves': 1679, 'max_depth': 295, 'learning_rate': 0.08809208642877693, 'min_child_samples': 174, 'subsample': 0.5262631224934488, 'colsample_bytree': 0.9979334927472849, 'reg_alpha': 4.409966194607645, 'reg_lambda': 5.071347265401518}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:43:03,427] Trial 41 finished with value: 0.7327915692435455 and parameters: {'n_estimators': 1111, 'num_leaves': 3153, 'max_depth': 251, 'learning_rate': 0.004196532050049826, 'min_child_samples': 3, 'subsample': 0.9474316865662387, 'colsample_bytree': 0.6082388816156199, 'reg_alpha': 2.822222203073921, 'reg_lambda': 8.72997047802845}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:44:11,516] Trial 42 finished with value: 0.7203151074559256 and parameters: {'n_estimators': 1423, 'num_leaves': 2699, 'max_depth': 225, 'learning_rate': 0.014693803985930854, 'min_child_samples': 67, 'subsample': 0.9228761688633524, 'colsample_bytree': 0.5038462840469934, 'reg_alpha': 1.973362173643546, 'reg_lambda': 8.21092094657355}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:44:44,408] Trial 43 finished with value: 0.7275179493637247 and parameters: {'n_estimators': 1197, 'num_leaves': 2923, 'max_depth': 194, 'learning_rate': 0.02694231412305321, 'min_child_samples': 53, 'subsample': 0.9520992396298105, 'colsample_bytree': 0.6108341084775472, 'reg_alpha': 7.63330904885478, 'reg_lambda': 9.9721144637062}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:45:34,942] Trial 44 finished with value: 0.726657675305823 and parameters: {'n_estimators': 944, 'num_leaves': 1904, 'max_depth': 242, 'learning_rate': 0.009551371492637378, 'min_child_samples': 89, 'subsample': 0.9028228285588114, 'colsample_bytree': 0.6535275165078082, 'reg_alpha': 0.83868590641812, 'reg_lambda': 8.66414342533947}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:45:53,975] Trial 45 finished with value: 0.7317556804043492 and parameters: {'n_estimators': 698, 'num_leaves': 2444, 'max_depth': 88, 'learning_rate': 0.02023529586697964, 'min_child_samples': 108, 'subsample': 0.8700338690894511, 'colsample_bytree': 0.5851251019410967, 'reg_alpha': 6.129677915840256, 'reg_lambda': 7.561372255128541}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:46:12,173] Trial 46 finished with value: 0.7352648804907307 and parameters: {'n_estimators': 836, 'num_leaves': 3316, 'max_depth': 112, 'learning_rate': 0.0014987732824790624, 'min_child_samples': 138, 'subsample': 0.9277845210448794, 'colsample_bytree': 0.5277865617139522, 'reg_alpha': 3.5019812766251555, 'reg_lambda': 7.004974196692548}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:46:53,286] Trial 47 finished with value: 0.704651199016226 and parameters: {'n_estimators': 2583, 'num_leaves': 3352, 'max_depth': 98, 'learning_rate': 0.1224318496594302, 'min_child_samples': 142, 'subsample': 0.9991301255585203, 'colsample_bytree': 0.5242783334541363, 'reg_alpha': 3.459001990170538, 'reg_lambda': 6.985608832766841}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:47:16,258] Trial 48 finished with value: 0.7336629785070676 and parameters: {'n_estimators': 861, 'num_leaves': 3143, 'max_depth': 116, 'learning_rate': 0.011136645230334558, 'min_child_samples': 190, 'subsample': 0.9641498796702215, 'colsample_bytree': 0.5523203230579803, 'reg_alpha': 4.144698637025983, 'reg_lambda': 6.598454067676953}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:47:32,480] Trial 49 finished with value: 0.7279559989808349 and parameters: {'n_estimators': 515, 'num_leaves': 3447, 'max_depth': 43, 'learning_rate': 0.02959610796293854, 'min_child_samples': 124, 'subsample': 0.678556788018816, 'colsample_bytree': 0.6943959098384761, 'reg_alpha': 5.207413079735825, 'reg_lambda': 1.7979270856395555}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:47:50,434] Trial 50 finished with value: 0.7220692140792523 and parameters: {'n_estimators': 651, 'num_leaves': 2992, 'max_depth': 65, 'learning_rate': 0.048360587833608006, 'min_child_samples': 226, 'subsample': 0.832854068493277, 'colsample_bytree': 0.9380799934729829, 'reg_alpha': 4.782316932756828, 'reg_lambda': 6.171841824800166}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:48:51,821] Trial 51 finished with value: 0.7356077586491042 and parameters: {'n_estimators': 1792, 'num_leaves': 3303, 'max_depth': 264, 'learning_rate': 0.0018860196484974437, 'min_child_samples': 76, 'subsample': 0.9340622258335052, 'colsample_bytree': 0.6319788968792548, 'reg_alpha': 2.6331792613370357, 'reg_lambda': 7.995419729749639}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:50:14,191] Trial 52 finished with value: 0.7157984810134022 and parameters: {'n_estimators': 1803, 'num_leaves': 3224, 'max_depth': 219, 'learning_rate': 0.01669118495511704, 'min_child_samples': 76, 'subsample': 0.9378385549970181, 'colsample_bytree': 0.6291554323080529, 'reg_alpha': 2.624880572258263, 'reg_lambda': 7.946441334720857}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:50:33,977] Trial 53 finished with value: 0.7354416876206298 and parameters: {'n_estimators': 843, 'num_leaves': 3482, 'max_depth': 15, 'learning_rate': 0.00621570863654732, 'min_child_samples': 120, 'subsample': 0.8971164527817483, 'colsample_bytree': 0.6679160977522277, 'reg_alpha': 1.7686420596646297, 'reg_lambda': 9.07918202644741}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:52:53,174] Trial 54 finished with value: 0.7155057132659137 and parameters: {'n_estimators': 2914, 'num_leaves': 3446, 'max_depth': 298, 'learning_rate': 0.008808327496252814, 'min_child_samples': 90, 'subsample': 0.8968830733241172, 'colsample_bytree': 0.687110014516561, 'reg_alpha': 1.8837941278345238, 'reg_lambda': 9.15482185196025}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:53:48,748] Trial 55 finished with value: 0.7088623260888576 and parameters: {'n_estimators': 1324, 'num_leaves': 3165, 'max_depth': 265, 'learning_rate': 0.03914214831576123, 'min_child_samples': 119, 'subsample': 0.8056757499001634, 'colsample_bytree': 0.7283214640218707, 'reg_alpha': 2.3402818780044825, 'reg_lambda': 9.492941681981018}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:55:25,685] Trial 56 finished with value: 0.7059454343552227 and parameters: {'n_estimators': 1866, 'num_leaves': 3364, 'max_depth': 287, 'learning_rate': 0.02364121657599843, 'min_child_samples': 105, 'subsample': 0.9631600990654787, 'colsample_bytree': 0.6638091111081847, 'reg_alpha': 1.7307877562580236, 'reg_lambda': 2.7142994048719604}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:56:39,132] Trial 57 finished with value: 0.717197873358401 and parameters: {'n_estimators': 1006, 'num_leaves': 2977, 'max_depth': 260, 'learning_rate': 0.01584630836045583, 'min_child_samples': 22, 'subsample': 0.8535574953520857, 'colsample_bytree': 0.6390527330818108, 'reg_alpha': 3.0322256412202933, 'reg_lambda': 0.46098566348576464}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:56:48,833] Trial 58 finished with value: 0.7173631322793329 and parameters: {'n_estimators': 605, 'num_leaves': 1206, 'max_depth': 11, 'learning_rate': 0.1451242483381314, 'min_child_samples': 49, 'subsample': 0.8722160288949086, 'colsample_bytree': 0.6175448706222556, 'reg_alpha': 2.5934714529743594, 'reg_lambda': 8.923593167631253}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:57:33,034] Trial 59 finished with value: 0.7270510590080914 and parameters: {'n_estimators': 748, 'num_leaves': 3486, 'max_depth': 323, 'learning_rate': 0.006913494799729993, 'min_child_samples': 73, 'subsample': 0.5691194119621477, 'colsample_bytree': 0.7295140162469393, 'reg_alpha': 1.0761991097213046, 'reg_lambda': 0.7734821299003836}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:58:10,382] Trial 60 finished with value: 0.7168482024863279 and parameters: {'n_estimators': 1156, 'num_leaves': 2684, 'max_depth': 228, 'learning_rate': 0.033359151171549695, 'min_child_samples': 86, 'subsample': 0.7630211544722152, 'colsample_bytree': 0.6724357261688256, 'reg_alpha': 4.601207777829941, 'reg_lambda': 1.1172281139084386}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:58:26,732] Trial 61 finished with value: 0.7347719729098398 and parameters: {'n_estimators': 817, 'num_leaves': 3268, 'max_depth': 18, 'learning_rate': 0.001052904728820412, 'min_child_samples': 132, 'subsample': 0.9166324582610865, 'colsample_bytree': 0.5874817785376559, 'reg_alpha': 3.4335446661831748, 'reg_lambda': 8.074468870661658}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:58:50,251] Trial 62 finished with value: 0.7349147122276074 and parameters: {'n_estimators': 855, 'num_leaves': 3069, 'max_depth': 57, 'learning_rate': 0.00803804342906512, 'min_child_samples': 150, 'subsample': 0.9443111524192805, 'colsample_bytree': 0.5687210607310662, 'reg_alpha': 3.790820397310731, 'reg_lambda': 8.557914043831143}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 00:59:38,159] Trial 63 finished with value: 0.7218504851240563 and parameters: {'n_estimators': 1673, 'num_leaves': 3357, 'max_depth': 160, 'learning_rate': 0.019506304837900258, 'min_child_samples': 164, 'subsample': 0.980226663126748, 'colsample_bytree': 0.6467599917687998, 'reg_alpha': 4.038644355570774, 'reg_lambda': 6.91325223019701}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 01:00:04,155] Trial 64 finished with value: 0.7358019089411809 and parameters: {'n_estimators': 1007, 'num_leaves': 2825, 'max_depth': 192, 'learning_rate': 0.0013000187552265066, 'min_child_samples': 99, 'subsample': 0.9118856413948038, 'colsample_bytree': 0.5994639165484772, 'reg_alpha': 2.8467912696930564, 'reg_lambda': 7.856524566963938}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 01:00:50,549] Trial 65 finished with value: 0.7296307235810694 and parameters: {'n_estimators': 1031, 'num_leaves': 2910, 'max_depth': 191, 'learning_rate': 0.009310132622726591, 'min_child_samples': 99, 'subsample': 0.8879201674759671, 'colsample_bytree': 0.5978557368641886, 'reg_alpha': 2.853602731263326, 'reg_lambda': 4.179409822891787}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 01:01:49,416] Trial 66 finished with value: 0.7126335112742368 and parameters: {'n_estimators': 1276, 'num_leaves': 2787, 'max_depth': 213, 'learning_rate': 0.026871058056225108, 'min_child_samples': 109, 'subsample': 0.9096804208538138, 'colsample_bytree': 0.8108567582887111, 'reg_alpha': 2.1729068366816247, 'reg_lambda': 9.231677413171212}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 01:02:31,725] Trial 67 finished with value: 0.7246472723074823 and parameters: {'n_estimators': 596, 'num_leaves': 3193, 'max_depth': 150, 'learning_rate': 0.01538842819516011, 'min_child_samples': 66, 'subsample': 0.84178794538502, 'colsample_bytree': 0.6369411573635289, 'reg_alpha': 1.616906212873866, 'reg_lambda': 3.4058571221725957}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 01:04:15,419] Trial 68 finished with value: 0.6914183771954802 and parameters: {'n_estimators': 2272, 'num_leaves': 2067, 'max_depth': 195, 'learning_rate': 0.056775875036539185, 'min_child_samples': 82, 'subsample': 0.9592945956932586, 'colsample_bytree': 0.6235129739113617, 'reg_alpha': 1.278370724290877, 'reg_lambda': 7.956884024046194}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 01:04:34,052] Trial 69 finished with value: 0.736357828323563 and parameters: {'n_estimators': 699, 'num_leaves': 2848, 'max_depth': 168, 'learning_rate': 0.005578650249344862, 'min_child_samples': 116, 'subsample': 0.9846187563048876, 'colsample_bytree': 0.5491889150393565, 'reg_alpha': 3.226776640521513, 'reg_lambda': 8.404787797229446}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 01:05:41,190] Trial 70 finished with value: 0.7073045171764518 and parameters: {'n_estimators': 2021, 'num_leaves': 2596, 'max_depth': 170, 'learning_rate': 0.04195241518888982, 'min_child_samples': 96, 'subsample': 0.9802476591351599, 'colsample_bytree': 0.5616415694473872, 'reg_alpha': 3.204126499547484, 'reg_lambda': 8.35708866627993}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 01:05:55,939] Trial 71 finished with value: 0.7349097174683816 and parameters: {'n_estimators': 694, 'num_leaves': 2835, 'max_depth': 234, 'learning_rate': 0.0012697937342577175, 'min_child_samples': 117, 'subsample': 0.9371991471019051, 'colsample_bytree': 0.5798808345911375, 'reg_alpha': 2.41783557163017, 'reg_lambda': 8.908896561378148}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 01:06:23,703] Trial 72 finished with value: 0.7339799277990725 and parameters: {'n_estimators': 940, 'num_leaves': 3030, 'max_depth': 248, 'learning_rate': 0.006875751847682072, 'min_child_samples': 124, 'subsample': 0.9876767591354186, 'colsample_bytree': 0.6000141266802099, 'reg_alpha': 2.849423938718081, 'reg_lambda': 7.649523826623523}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 01:06:44,170] Trial 73 finished with value: 0.7290182475600835 and parameters: {'n_estimators': 590, 'num_leaves': 1827, 'max_depth': 218, 'learning_rate': 0.022725830568846726, 'min_child_samples': 98, 'subsample': 0.9660329920570324, 'colsample_bytree': 0.5442747767677556, 'reg_alpha': 3.218368673233714, 'reg_lambda': 9.723109159536879}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 01:07:09,510] Trial 74 finished with value: 0.7294121286534019 and parameters: {'n_estimators': 506, 'num_leaves': 3124, 'max_depth': 258, 'learning_rate': 0.013904567168456384, 'min_child_samples': 71, 'subsample': 0.9320984207997749, 'colsample_bytree': 0.7684021196994759, 'reg_alpha': 2.115901570332016, 'reg_lambda': 7.302430832132009}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 01:07:34,782] Trial 75 finished with value: 0.7352764515340175 and parameters: {'n_estimators': 758, 'num_leaves': 2375, 'max_depth': 274, 'learning_rate': 0.00585331541656558, 'min_child_samples': 112, 'subsample': 0.9126812257886614, 'colsample_bytree': 0.6136021388779715, 'reg_alpha': 2.5950634961277323, 'reg_lambda': 8.297107722365547}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 01:08:08,929] Trial 76 finished with value: 0.72612511543245 and parameters: {'n_estimators': 986, 'num_leaves': 2889, 'max_depth': 349, 'learning_rate': 0.019424609559155922, 'min_child_samples': 129, 'subsample': 0.8927888602379102, 'colsample_bytree': 0.5820784521919505, 'reg_alpha': 3.7147201514462127, 'reg_lambda': 7.806068815261557}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 01:08:47,044] Trial 77 finished with value: 0.6940054122897248 and parameters: {'n_estimators': 1076, 'num_leaves': 2724, 'max_depth': 182, 'learning_rate': 0.19983520891554596, 'min_child_samples': 145, 'subsample': 0.9480769182220664, 'colsample_bytree': 0.5165385647117176, 'reg_alpha': 1.8908058383890658, 'reg_lambda': 9.446485056505688}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 01:09:05,465] Trial 78 finished with value: 0.7292448027301427 and parameters: {'n_estimators': 654, 'num_leaves': 3276, 'max_depth': 207, 'learning_rate': 0.03488917141691093, 'min_child_samples': 160, 'subsample': 0.9746974986849865, 'colsample_bytree': 0.5552679099735157, 'reg_alpha': 6.921880413185449, 'reg_lambda': 0.29431457091003377}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 01:10:19,487] Trial 79 finished with value: 0.720822801747989 and parameters: {'n_estimators': 1442, 'num_leaves': 2582, 'max_depth': 227, 'learning_rate': 0.012984814743296645, 'min_child_samples': 42, 'subsample': 0.8201439017923308, 'colsample_bytree': 0.655755014625135, 'reg_alpha': 3.0078412095056257, 'reg_lambda': 9.063863444474965}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 01:10:41,227] Trial 80 finished with value: 0.7361445180517012 and parameters: {'n_estimators': 887, 'num_leaves': 3412, 'max_depth': 291, 'learning_rate': 0.006586825384258125, 'min_child_samples': 174, 'subsample': 0.8771695721671947, 'colsample_bytree': 0.6303604414776931, 'reg_alpha': 5.5581899442418035, 'reg_lambda': 8.660379233932451}. Best is trial 33 with value: 0.7366653966813752.
# [I 2025-02-19 01:10:58,491] Trial 81 finished with value: 0.7368412130003604 and parameters: {'n_estimators': 744, 'num_leaves': 3403, 'max_depth': 297, 'learning_rate': 0.0055141305332604106, 'min_child_samples': 184, 'subsample': 0.8767909277105354, 'colsample_bytree': 0.6316710275172656, 'reg_alpha': 6.136503083006312, 'reg_lambda': 8.8591101232979}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:11:17,101] Trial 82 finished with value: 0.7350272854235155 and parameters: {'n_estimators': 725, 'num_leaves': 1597, 'max_depth': 292, 'learning_rate': 0.01202730318972111, 'min_child_samples': 178, 'subsample': 0.8641837164737523, 'colsample_bytree': 0.6303770912592362, 'reg_alpha': 6.232853265660896, 'reg_lambda': 8.64918980207423}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:11:35,203] Trial 83 finished with value: 0.7352258179193734 and parameters: {'n_estimators': 922, 'num_leaves': 3015, 'max_depth': 305, 'learning_rate': 0.0014189656555617975, 'min_child_samples': 219, 'subsample': 0.8446457509527687, 'colsample_bytree': 0.5965253456833618, 'reg_alpha': 5.1545295541025995, 'reg_lambda': 8.448437663904453}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:11:52,693] Trial 84 finished with value: 0.7317970492419921 and parameters: {'n_estimators': 593, 'num_leaves': 3226, 'max_depth': 273, 'learning_rate': 0.02487436230343087, 'min_child_samples': 186, 'subsample': 0.878872577624834, 'colsample_bytree': 0.5759111132213682, 'reg_alpha': 5.560197679470924, 'reg_lambda': 7.429777476988685}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:12:24,831] Trial 85 finished with value: 0.7285882812921318 and parameters: {'n_estimators': 1138, 'num_leaves': 3395, 'max_depth': 284, 'learning_rate': 0.017345623126182503, 'min_child_samples': 171, 'subsample': 0.9301559249319284, 'colsample_bytree': 0.6083000477337496, 'reg_alpha': 5.770857632501818, 'reg_lambda': 0.01031392325897773}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:12:41,246] Trial 86 finished with value: 0.7367639754177231 and parameters: {'n_estimators': 798, 'num_leaves': 3119, 'max_depth': 323, 'learning_rate': 0.005680163163138245, 'min_child_samples': 210, 'subsample': 0.9537627865220176, 'colsample_bytree': 0.6897067148129227, 'reg_alpha': 6.6510449917541274, 'reg_lambda': 8.192036429870445}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:12:59,217] Trial 87 finished with value: 0.736399848435714 and parameters: {'n_estimators': 886, 'num_leaves': 3116, 'max_depth': 325, 'learning_rate': 0.0068343202446790345, 'min_child_samples': 261, 'subsample': 0.9198904097935564, 'colsample_bytree': 0.6789581456657454, 'reg_alpha': 6.899687321962932, 'reg_lambda': 8.08434080122633}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:13:16,975] Trial 88 finished with value: 0.7355533434725655 and parameters: {'n_estimators': 903, 'num_leaves': 3080, 'max_depth': 322, 'learning_rate': 0.010048063073760292, 'min_child_samples': 254, 'subsample': 0.9574752785830264, 'colsample_bytree': 0.6869271805009916, 'reg_alpha': 7.667282306536657, 'reg_lambda': 8.782244325004903}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:13:32,852] Trial 89 finished with value: 0.7293838855783759 and parameters: {'n_estimators': 796, 'num_leaves': 2853, 'max_depth': 332, 'learning_rate': 0.03219946234079177, 'min_child_samples': 302, 'subsample': 0.9904673547564142, 'colsample_bytree': 0.7036306524008683, 'reg_alpha': 6.736890503783997, 'reg_lambda': 7.233482112882675}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:13:43,206] Trial 90 finished with value: 0.7215149169263624 and parameters: {'n_estimators': 1236, 'num_leaves': 1784, 'max_depth': 317, 'learning_rate': 0.1715224062257113, 'min_child_samples': 274, 'subsample': 0.9078416921023322, 'colsample_bytree': 0.6547727857252349, 'reg_alpha': 7.236316237941839, 'reg_lambda': 8.2180152103085}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:14:04,310] Trial 91 finished with value: 0.7362333703606718 and parameters: {'n_estimators': 1057, 'num_leaves': 3198, 'max_depth': 298, 'learning_rate': 0.005789919837912746, 'min_child_samples': 207, 'subsample': 0.9188641419006537, 'colsample_bytree': 0.6764394691933425, 'reg_alpha': 6.330262054952962, 'reg_lambda': 7.8233489974178125}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:14:26,011] Trial 92 finished with value: 0.7353300814085193 and parameters: {'n_estimators': 1069, 'num_leaves': 870, 'max_depth': 335, 'learning_rate': 0.007611374377307028, 'min_child_samples': 203, 'subsample': 0.9226193339550076, 'colsample_bytree': 0.6810030690537952, 'reg_alpha': 6.3352478524433025, 'reg_lambda': 7.823377930461817}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:14:38,792] Trial 93 finished with value: 0.7217111997453358 and parameters: {'n_estimators': 983, 'num_leaves': 3399, 'max_depth': 299, 'learning_rate': 0.10784432665757636, 'min_child_samples': 211, 'subsample': 0.9537580889492521, 'colsample_bytree': 0.6968424248420101, 'reg_alpha': 6.535186869693518, 'reg_lambda': 8.522364784765644}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:14:54,940] Trial 94 finished with value: 0.7366382714952158 and parameters: {'n_estimators': 856, 'num_leaves': 3175, 'max_depth': 315, 'learning_rate': 0.005576863643440566, 'min_child_samples': 247, 'subsample': 0.9713597287932263, 'colsample_bytree': 0.7207798591121068, 'reg_alpha': 5.955968683536373, 'reg_lambda': 9.294942751481559}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:15:14,654] Trial 95 finished with value: 0.7302986969267865 and parameters: {'n_estimators': 901, 'num_leaves': 3108, 'max_depth': 314, 'learning_rate': 0.02058567065657209, 'min_child_samples': 245, 'subsample': 0.9729326866904155, 'colsample_bytree': 0.7201082956088574, 'reg_alpha': 5.964308398778699, 'reg_lambda': 9.294715755003768}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:15:32,268] Trial 96 finished with value: 0.7336778595339083 and parameters: {'n_estimators': 792, 'num_leaves': 3291, 'max_depth': 342, 'learning_rate': 0.013182159152971913, 'min_child_samples': 261, 'subsample': 0.9839432316739327, 'colsample_bytree': 0.7482369730790346, 'reg_alpha': 5.445800181104161, 'reg_lambda': 9.631290930721246}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:15:48,175] Trial 97 finished with value: 0.7368086433181578 and parameters: {'n_estimators': 882, 'num_leaves': 3200, 'max_depth': 302, 'learning_rate': 0.005024872653387011, 'min_child_samples': 290, 'subsample': 0.9445114014800456, 'colsample_bytree': 0.7181011879221805, 'reg_alpha': 7.008247021089932, 'reg_lambda': 7.641660223507696}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:16:03,431] Trial 98 finished with value: 0.7366725775785089 and parameters: {'n_estimators': 871, 'num_leaves': 3188, 'max_depth': 303, 'learning_rate': 0.005892241536889361, 'min_child_samples': 310, 'subsample': 0.9453163365599218, 'colsample_bytree': 0.7640437054676592, 'reg_alpha': 6.962820488893068, 'reg_lambda': 8.906744826733066}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:16:16,745] Trial 99 finished with value: 0.7313509728651242 and parameters: {'n_estimators': 668, 'num_leaves': 3175, 'max_depth': 306, 'learning_rate': 0.029033462093889052, 'min_child_samples': 288, 'subsample': 0.9995371124903616, 'colsample_bytree': 0.7625470729459607, 'reg_alpha': 7.1907046207830145, 'reg_lambda': 8.794585870411035}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:16:30,931] Trial 100 finished with value: 0.7367834600419658 and parameters: {'n_estimators': 881, 'num_leaves': 3407, 'max_depth': 332, 'learning_rate': 0.006256358282587729, 'min_child_samples': 313, 'subsample': 0.9440252480974248, 'colsample_bytree': 0.7414013625747188, 'reg_alpha': 7.890685306353785, 'reg_lambda': 9.343163345471346}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:16:45,101] Trial 101 finished with value: 0.7367847606053899 and parameters: {'n_estimators': 888, 'num_leaves': 3409, 'max_depth': 331, 'learning_rate': 0.0059221991395789165, 'min_child_samples': 289, 'subsample': 0.9447616519268224, 'colsample_bytree': 0.775611288681927, 'reg_alpha': 8.189253451470844, 'reg_lambda': 9.366847066878297}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:16:57,409] Trial 102 finished with value: 0.7350569015361104 and parameters: {'n_estimators': 727, 'num_leaves': 3234, 'max_depth': 327, 'learning_rate': 0.016651810933295826, 'min_child_samples': 338, 'subsample': 0.9421158414389168, 'colsample_bytree': 0.7422717024564703, 'reg_alpha': 8.367743601216768, 'reg_lambda': 9.812316993075104}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:17:11,465] Trial 103 finished with value: 0.7356667665022834 and parameters: {'n_estimators': 794, 'num_leaves': 3328, 'max_depth': 339, 'learning_rate': 0.0112243391731915, 'min_child_samples': 310, 'subsample': 0.9686497391674124, 'colsample_bytree': 0.7758143516235132, 'reg_alpha': 8.148720411183016, 'reg_lambda': 9.383747949498831}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:17:26,940] Trial 104 finished with value: 0.7368128914944105 and parameters: {'n_estimators': 850, 'num_leaves': 3047, 'max_depth': 318, 'learning_rate': 0.005611347397947733, 'min_child_samples': 314, 'subsample': 0.9207917532876293, 'colsample_bytree': 0.8033761748288087, 'reg_alpha': 8.913956293761967, 'reg_lambda': 9.035622545950257}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:17:48,834] Trial 105 finished with value: 0.7338706645867183 and parameters: {'n_estimators': 877, 'num_leaves': 2952, 'max_depth': 346, 'learning_rate': 0.017950676612258853, 'min_child_samples': 316, 'subsample': 0.9459145511012857, 'colsample_bytree': 0.8066929416002875, 'reg_alpha': 9.417446824578791, 'reg_lambda': 8.987772838086213}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:18:06,702] Trial 106 finished with value: 0.7367906846221459 and parameters: {'n_estimators': 832, 'num_leaves': 3053, 'max_depth': 318, 'learning_rate': 0.005557052513537026, 'min_child_samples': 293, 'subsample': 0.9567453810053276, 'colsample_bytree': 0.801961985704783, 'reg_alpha': 8.689737250701882, 'reg_lambda': 9.632562070646692}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:18:16,329] Trial 107 finished with value: 0.7262325092089819 and parameters: {'n_estimators': 851, 'num_leaves': 3017, 'max_depth': 318, 'learning_rate': 0.15071231512854796, 'min_child_samples': 291, 'subsample': 0.9656716862481733, 'colsample_bytree': 0.7984617686744154, 'reg_alpha': 8.878114957249405, 'reg_lambda': 9.99191142069829}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:18:30,879] Trial 108 finished with value: 0.7329692123081033 and parameters: {'n_estimators': 751, 'num_leaves': 3126, 'max_depth': 330, 'learning_rate': 0.024588933258994847, 'min_child_samples': 326, 'subsample': 0.9564640543663578, 'colsample_bytree': 0.7832088902273471, 'reg_alpha': 8.876837699876994, 'reg_lambda': 9.631892926612247}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:18:54,927] Trial 109 finished with value: 0.7338441966318465 and parameters: {'n_estimators': 1141, 'num_leaves': 3492, 'max_depth': 303, 'learning_rate': 0.011653552414833793, 'min_child_samples': 280, 'subsample': 0.9265422154010893, 'colsample_bytree': 0.825647017892137, 'reg_alpha': 7.995729529827089, 'reg_lambda': 9.230823585817635}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:19:05,704] Trial 110 finished with value: 0.7288537461428863 and parameters: {'n_estimators': 956, 'num_leaves': 612, 'max_depth': 313, 'learning_rate': 0.07474397233275702, 'min_child_samples': 294, 'subsample': 0.936992404781985, 'colsample_bytree': 0.7357766885416981, 'reg_alpha': 9.155509064651525, 'reg_lambda': 9.535519606411649}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:19:20,051] Trial 111 finished with value: 0.7364258408410591 and parameters: {'n_estimators': 642, 'num_leaves': 3049, 'max_depth': 323, 'learning_rate': 0.005134707601614395, 'min_child_samples': 320, 'subsample': 0.9835755424558865, 'colsample_bytree': 0.8505253800506523, 'reg_alpha': 6.991077484701978, 'reg_lambda': 9.132336335787313}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:19:36,091] Trial 112 finished with value: 0.7363874861336112 and parameters: {'n_estimators': 645, 'num_leaves': 3055, 'max_depth': 325, 'learning_rate': 0.0050049940911384445, 'min_child_samples': 325, 'subsample': 0.9739747111846224, 'colsample_bytree': 0.8666642397670004, 'reg_alpha': 7.619805492413631, 'reg_lambda': 9.142092768198033}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:19:56,833] Trial 113 finished with value: 0.7340875618323592 and parameters: {'n_estimators': 803, 'num_leaves': 3281, 'max_depth': 337, 'learning_rate': 0.01422746837993484, 'min_child_samples': 314, 'subsample': 0.9519936390956246, 'colsample_bytree': 0.8457414672106447, 'reg_alpha': 6.926182202301473, 'reg_lambda': 8.85781888083085}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:20:07,861] Trial 114 finished with value: 0.7367883535359481 and parameters: {'n_estimators': 558, 'num_leaves': 3168, 'max_depth': 318, 'learning_rate': 0.00914105161086582, 'min_child_samples': 345, 'subsample': 0.961783898330409, 'colsample_bytree': 0.7210522502301212, 'reg_alpha': 8.55254010732369, 'reg_lambda': 9.82726240068716}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:20:20,116] Trial 115 finished with value: 0.735462044913002 and parameters: {'n_estimators': 546, 'num_leaves': 3353, 'max_depth': 319, 'learning_rate': 0.02103906278357883, 'min_child_samples': 349, 'subsample': 0.9603774607174932, 'colsample_bytree': 0.7183620788793218, 'reg_alpha': 8.397227948229911, 'reg_lambda': 9.797751545675421}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:20:34,132] Trial 116 finished with value: 0.7365608522308177 and parameters: {'n_estimators': 584, 'num_leaves': 3189, 'max_depth': 309, 'learning_rate': 0.009931642601158216, 'min_child_samples': 324, 'subsample': 0.9927341374102409, 'colsample_bytree': 0.7579801361572093, 'reg_alpha': 7.862644816744363, 'reg_lambda': 9.382229140295987}. Best is trial 81 with value: 0.7368412130003604.
# [I 2025-02-19 01:20:45,834] Trial 117 finished with value: 0.7368210929863532 and parameters: {'n_estimators': 555, 'num_leaves': 3419, 'max_depth': 282, 'learning_rate': 0.009306105879020187, 'min_child_samples': 337, 'subsample': 0.9912548406842435, 'colsample_bytree': 0.76102597674046, 'reg_alpha': 8.655974064398501, 'reg_lambda': 9.41227668795402}. Best is trial 81 with value: 0.7368412130003604.
# ...
# [I 2025-02-19 01:59:42,063] Trial 292 finished with value: 0.7336022342527979 and parameters: {'n_estimators': 733, 'num_leaves': 3195, 'max_depth': 287, 'learning_rate': 0.0010557662046443332, 'min_child_samples': 257, 'subsample': 0.8501181987777611, 'colsample_bytree': 0.7280096913305285, 'reg_alpha': 9.634252820135064, 'reg_lambda': 9.42902612454704}. Best is trial 222 with value: 0.7371122424755358.
# [I 2025-02-19 02:00:08,393] Trial 293 finished with value: 0.732736386635307 and parameters: {'n_estimators': 1364, 'num_leaves': 2159, 'max_depth': 299, 'learning_rate': 0.016080418261051447, 'min_child_samples': 270, 'subsample': 0.8810035598548852, 'colsample_bytree': 0.7092546680386689, 'reg_alpha': 9.996182273985271, 'reg_lambda': 9.129840743627543}. Best is trial 222 with value: 0.7371122424755358.
# [I 2025-02-19 02:00:20,786] Trial 294 finished with value: 0.7294333864122058 and parameters: {'n_estimators': 801, 'num_leaves': 3326, 'max_depth': 294, 'learning_rate': 0.07032035876568077, 'min_child_samples': 278, 'subsample': 0.861434618979195, 'colsample_bytree': 0.7227768959495495, 'reg_alpha': 9.428286796952342, 'reg_lambda': 8.875720038575263}. Best is trial 222 with value: 0.7371122424755358.
# [I 2025-02-19 02:00:30,292] Trial 295 finished with value: 0.7367981583942493 and parameters: {'n_estimators': 556, 'num_leaves': 3424, 'max_depth': 274, 'learning_rate': 0.005773279308228891, 'min_child_samples': 265, 'subsample': 0.8742551264400442, 'colsample_bytree': 0.7397298553918907, 'reg_alpha': 9.79525835709941, 'reg_lambda': 9.206061094180683}. Best is trial 222 with value: 0.7371122424755358.
# [I 2025-02-19 02:00:42,258] Trial 296 finished with value: 0.7367164830112265 and parameters: {'n_estimators': 553, 'num_leaves': 3259, 'max_depth': 302, 'learning_rate': 0.010869767558289067, 'min_child_samples': 256, 'subsample': 0.8874018612789628, 'colsample_bytree': 0.7340491882485733, 'reg_alpha': 9.601348539461245, 'reg_lambda': 8.95177366174594}. Best is trial 222 with value: 0.7371122424755358.
# [I 2025-02-19 02:00:56,158] Trial 297 finished with value: 0.736983052844493 and parameters: {'n_estimators': 794, 'num_leaves': 3108, 'max_depth': 284, 'learning_rate': 0.005239945309699078, 'min_child_samples': 263, 'subsample': 0.8659722766135703, 'colsample_bytree': 0.704748147954899, 'reg_alpha': 9.276218851919605, 'reg_lambda': 9.497861771910138}. Best is trial 222 with value: 0.7371122424755358.
# [I 2025-02-19 02:01:12,611] Trial 298 finished with value: 0.7367941594099199 and parameters: {'n_estimators': 809, 'num_leaves': 3117, 'max_depth': 281, 'learning_rate': 0.004425853355394364, 'min_child_samples': 247, 'subsample': 0.8575205035903153, 'colsample_bytree': 0.6954037871790318, 'reg_alpha': 9.816315897266863, 'reg_lambda': 9.54877782203669}. Best is trial 222 with value: 0.7371122424755358.
# [I 2025-02-19 02:01:30,487] Trial 299 finished with value: 0.7362178043042414 and parameters: {'n_estimators': 751, 'num_leaves': 3081, 'max_depth': 307, 'learning_rate': 0.010858975795727073, 'min_child_samples': 261, 'subsample': 0.8680216462890152, 'colsample_bytree': 0.7209610181459501, 'reg_alpha': 9.536903190893215, 'reg_lambda': 9.385565976555492}. Best is trial 222 with value: 0.7371122424755358.
# [I 2025-02-19 02:01:45,330] Trial 300 finished with value: 0.7367325295811662 and parameters: {'n_estimators': 806, 'num_leaves': 3165, 'max_depth': 293, 'learning_rate': 0.004024546863481717, 'min_child_samples': 253, 'subsample': 0.8424602015373833, 'colsample_bytree': 0.6873161101208514, 'reg_alpha': 9.999815797847896, 'reg_lambda': 9.779797420685101}. Best is trial 222 with value: 0.7371122424755358.
# [I 2025-02-19 02:02:01,823] Trial 301 finished with value: 0.7358644839122092 and parameters: {'n_estimators': 724, 'num_leaves': 3243, 'max_depth': 285, 'learning_rate': 0.014386489487779493, 'min_child_samples': 285, 'subsample': 0.8755341701420618, 'colsample_bytree': 0.6670739699082552, 'reg_alpha': 9.63054394825388, 'reg_lambda': 9.28957170793626}. Best is trial 222 with value: 0.7371122424755358.
# [I 2025-02-19 02:02:16,653] Trial 302 finished with value: 0.7368348263404321 and parameters: {'n_estimators': 667, 'num_leaves': 3150, 'max_depth': 299, 'learning_rate': 0.007765845234067573, 'min_child_samples': 276, 'subsample': 0.8563462767787777, 'colsample_bytree': 0.70442433715063, 'reg_alpha': 9.295354968899744, 'reg_lambda': 1.8797957755304697}. Best is trial 222 with value: 0.7371122424755358.
# [I 2025-02-19 02:02:29,220] Trial 303 finished with value: 0.7354124338787598 and parameters: {'n_estimators': 609, 'num_leaves': 3366, 'max_depth': 313, 'learning_rate': 0.018965328847508105, 'min_child_samples': 266, 'subsample': 0.5063331354064591, 'colsample_bytree': 0.7119605584045766, 'reg_alpha': 9.760199445411526, 'reg_lambda': 9.559659391727205}. Best is trial 222 with value: 0.7371122424755358.
# [I 2025-02-19 02:02:40,492] Trial 304 finished with value: 0.7366665076206663 and parameters: {'n_estimators': 677, 'num_leaves': 3203, 'max_depth': 276, 'learning_rate': 0.004498941333419687, 'min_child_samples': 258, 'subsample': 0.8640468461080174, 'colsample_bytree': 0.6795630814436545, 'reg_alpha': 9.469758412760113, 'reg_lambda': 9.102642126671014}. Best is trial 222 with value: 0.7371122424755358.
# [I 2025-02-19 02:02:48,444] Trial 305 finished with value: 0.733176151804781 and parameters: {'n_estimators': 553, 'num_leaves': 3308, 'max_depth': 305, 'learning_rate': 0.0011326370635626687, 'min_child_samples': 249, 'subsample': 0.8800573150884274, 'colsample_bytree': 0.7322436604980139, 'reg_alpha': 9.799271786395856, 'reg_lambda': 9.352674832964556}. Best is trial 222 with value: 0.7371122424755358.
# [I 2025-02-19 02:02:59,993] Trial 306 finished with value: 0.7369688757103756 and parameters: {'n_estimators': 501, 'num_leaves': 3253, 'max_depth': 290, 'learning_rate': 0.009439996607135376, 'min_child_samples': 241, 'subsample': 0.8985038378931806, 'colsample_bytree': 0.7147855900961181, 'reg_alpha': 8.959737149955693, 'reg_lambda': 9.014743296618043}. Best is trial 222 with value: 0.7371122424755358.
# [I 2025-02-19 02:03:11,266] Trial 307 finished with value: 0.7304242390234632 and parameters: {'n_estimators': 505, 'num_leaves': 3429, 'max_depth': 102, 'learning_rate': 0.056905119442910636, 'min_child_samples': 273, 'subsample': 0.9152285870326435, 'colsample_bytree': 0.7431570740946079, 'reg_alpha': 8.968237384747846, 'reg_lambda': 9.856821911173677}. Best is trial 222 with value: 0.7371122424755358.
# [I 2025-02-19 02:03:24,142] Trial 308 finished with value: 0.7337565664553758 and parameters: {'n_estimators': 641, 'num_leaves': 3259, 'max_depth': 292, 'learning_rate': 0.023457061297098257, 'min_child_samples': 265, 'subsample': 0.8999849058811273, 'colsample_bytree': 0.7182138384442028, 'reg_alpha': 9.124755480547462, 'reg_lambda': 9.225723740046018}. Best is trial 222 with value: 0.7371122424755358.
# [I 2025-02-19 02:03:39,914] Trial 309 finished with value: 0.735662328701898 and parameters: {'n_estimators': 783, 'num_leaves': 3343, 'max_depth': 155, 'learning_rate': 0.011917316047056366, 'min_child_samples': 243, 'subsample': 0.9242688880459383, 'colsample_bytree': 0.7302655929064784, 'reg_alpha': 8.872870168330532, 'reg_lambda': 9.566443846616904}. Best is trial 222 with value: 0.7371122424755358.
# [I 2025-02-19 02:03:55,390] Trial 310 finished with value: 0.7363854111889121 and parameters: {'n_estimators': 708, 'num_leaves': 3258, 'max_depth': 298, 'learning_rate': 0.009357740856923548, 'min_child_samples': 237, 'subsample': 0.7161423154942461, 'colsample_bytree': 0.744465221151446, 'reg_alpha': 9.258472164700347, 'reg_lambda': 9.063308131151711}. Best is trial 222 with value: 0.7371122424755358.
# [I 2025-02-19 02:04:06,984] Trial 311 finished with value: 0.7359482501246755 and parameters: {'n_estimators': 602, 'num_leaves': 3391, 'max_depth': 288, 'learning_rate': 0.015252596719339963, 'min_child_samples': 281, 'subsample': 0.8905388276518847, 'colsample_bytree': 0.7223708828611966, 'reg_alpha': 9.34047571202752, 'reg_lambda': 8.760303719413644}. Best is trial 222 with value: 0.7371122424755358.
# [I 2025-02-19 02:04:15,016] Trial 312 finished with value: 0.7367386313084971 and parameters: {'n_estimators': 505, 'num_leaves': 3315, 'max_depth': 314, 'learning_rate': 0.006499417883748483, 'min_child_samples': 263, 'subsample': 0.9098853586986515, 'colsample_bytree': 0.6993380370172961, 'reg_alpha': 9.500649685225346, 'reg_lambda': 9.39525918937905}. Best is trial 222 with value: 0.7371122424755358.
# [I 2025-02-19 02:04:27,920] Trial 313 finished with value: 0.736484724594675 and parameters: {'n_estimators': 670, 'num_leaves': 3120, 'max_depth': 304, 'learning_rate': 0.011397427356732572, 'min_child_samples': 272, 'subsample': 0.900865794562125, 'colsample_bytree': 0.7394728223222882, 'reg_alpha': 9.840613762545978, 'reg_lambda': 9.188234414308965}. Best is trial 222 with value: 0.7371122424755358.
# [I 2025-02-19 02:04:37,331] Trial 314 finished with value: 0.7362267533719539 and parameters: {'n_estimators': 575, 'num_leaves': 3212, 'max_depth': 294, 'learning_rate': 0.004334825484164239, 'min_child_samples': 221, 'subsample': 0.8850221333332091, 'colsample_bytree': 0.7277031240658027, 'reg_alpha': 9.64853065117524, 'reg_lambda': 9.02749298946718}. Best is trial 222 with value: 0.7371122424755358.
# [I 2025-02-19 02:04:52,672] Trial 315 finished with value: 0.734443492286408 and parameters: {'n_estimators': 723, 'num_leaves': 3344, 'max_depth': 309, 'learning_rate': 0.01737570838850443, 'min_child_samples': 250, 'subsample': 0.7796850453720487, 'colsample_bytree': 0.7499358920583973, 'reg_alpha': 9.145761098358328, 'reg_lambda': 8.76019789706468}. Best is trial 222 with value: 0.7371122424755358.
# [I 2025-02-19 02:05:05,048] Trial 316 finished with value: 0.7368468788900249 and parameters: {'n_estimators': 632, 'num_leaves': 3468, 'max_depth': 299, 'learning_rate': 0.008916496682955834, 'min_child_samples': 285, 'subsample': 0.8738904747933192, 'colsample_bytree': 0.7136773429829165, 'reg_alpha': 9.398358499894933, 'reg_lambda': 9.64419711527746}. Best is trial 222 with value: 0.7371122424755358.
# [W 2025-02-19 02:05:05,961] Trial 317 failed with parameters: {'n_estimators': 563, 'num_leaves': 3270, 'max_depth': 287, 'learning_rate': 0.013093747612557462, 'min_child_samples': 276, 'subsample': 0.8933131001209039, 'colsample_bytree': 0.736285668484828, 'reg_alpha': 9.811754766290344, 'reg_lambda': 9.315691246602215} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\_optimize.py", line 196, in _run_trial
#     value_or_values = func(trial)
#   File "C:\Users\juneh\AppData\Local\Temp\ipykernel_21748\341327754.py", line 23, in objective
#     model.fit(Total_X_train, Total_y_train)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\sklearn.py", line 1298, in fit
#     init_model=init_model,
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\sklearn.py", line 963, in fit
#     callbacks=callbacks,
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\engine.py", line 307, in train
#     booster.update(fobj=fobj)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\basic.py", line 4138, in update
#     ctypes.byref(is_finished),
# KeyboardInterrupt
# [W 2025-02-19 02:05:05,961] Trial 317 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21748\341327754.py in <module>
#      30 # Optuna 스터디 생성 및 최적화 실행
#      31 study = optuna.create_study(direction='maximize')
# ---> 32 study.optimize(objective, n_trials=500)
#      33
#      34 # 최적의 하이퍼파라미터 출력
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     458             callbacks=callbacks,
#     459             gc_after_trial=gc_after_trial,
# --> 460             show_progress_bar=show_progress_bar,
#     461         )
#     462
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      70                 reseed_sampler_rng=False,
#      71                 time_start=None,
# ---> 72                 progress_bar=progress_bar,
#      73             )
#      74         else:
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157
#     158         try:
# --> 159             frozen_trial = _run_trial(study, func, catch)
#     160         finally:
#     161             # The following line mitigates memory problems that can be occurred in some
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\_optimize.py in _run_trial(study, func, catch)
#     245         and not isinstance(func_err, catch)
#     246     ):
# --> 247         raise func_err
#     248     return frozen_trial
#     249
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\optuna\study\_optimize.py in _run_trial(study, func, catch)
#     194     with get_heartbeat_thread(trial._trial_id, study._storage):
#     195         try:
# --> 196             value_or_values = func(trial)
#     197         except exceptions.TrialPruned as e:
#     198             # TODO(mamu): Handle multi-objective cases.
#
# ~\AppData\Local\Temp\ipykernel_21748\341327754.py in objective(trial)
#      21
#      22     model = lgb.LGBMClassifier(**param)
# ---> 23     model.fit(Total_X_train, Total_y_train)
#      24
#      25     y_pred_proba = model.predict_proba(Total_X_test)[:, 1]
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1296             categorical_feature=categorical_feature,
#    1297             callbacks=callbacks,
# -> 1298             init_model=init_model,
#    1299         )
#    1300         return self
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#     961             feval=eval_metrics_callable,  # type: ignore[arg-type]
#     962             init_model=init_model,
# --> 963             callbacks=callbacks,
#     964         )
#     965
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, feature_name, categorical_feature, keep_training_booster, callbacks)
#     305             )
#     306
# --> 307         booster.update(fobj=fobj)
#     308
#     309         evaluation_result_list: List[_LGBM_BoosterEvalMethodResultType] = []
#
# c:\Users\juneh\AppData\Local\Programs\Python\Python37\lib\site-packages\lightgbm\basic.py in update(self, train_set, fobj)
#    4136                 _LIB.LGBM_BoosterUpdateOneIter(
#    4137                     self._handle,
# -> 4138                     ctypes.byref(is_finished),
#    4139                 )
#    4140             )
#
# KeyboardInterrupt:

# %% [markdown]
# [I 2025-02-16 14:01:21,962] Trial 25 finished with value: 0.7450160562701532 and parameters: {'n_estimators': 2379, 'num_leaves': 1214, 'max_depth': 320, 'learning_rate': 0.0016910462182733038, 'min_child_samples': 321, 'subsample': 0.9245577554285245, 'colsample_bytree': 0.8027573271184746, 'reg_alpha': 8.590190533433615, 'reg_lambda': 6.615930936160601}. Best is trial 25 with value: 0.7450160562701532

# %% [markdown]
# .
