# %% [markdown]
# ## 난임 환자 대상 임신 성공 여부 예측

# %% [markdown]
# ### LGAimers 6th 온라인 해커톤

# %% [markdown]
# Import

# %%
import pandas as pd
import lightgbm as lgb
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### Data Load

# %%
# 데이터 로드
IVF_train = pd.read_csv('../data/IVF_train_dataset.csv')
IVF_test = pd.read_csv('../data/IVF_test_dataset.csv')

DI_train = pd.read_csv('../data/DI_train_dataset.csv')
DI_test = pd.read_csv('../data/DI_test_dataset.csv')

# %%
# ID 열을 제외한 특성과 타겟 변수 분리
IVF_X = IVF_train.drop(['임신_성공_여부', 'ID'], axis=1)
IVF_y = IVF_train['임신_성공_여부']

DI_X = DI_train.drop(['임신_성공_여부', 'ID'], axis=1)
DI_y = DI_train['임신_성공_여부']

# %% [markdown]
# ### 인코딩

# %%
IVF_categorical_columns = [
    "시술_시기_코드",
    "시술_당시_나이",
    "임신_시도_또는_마지막_임신_경과_연수",
    "배란_유도_유형",
    "착상_전_유전_검사_사용_여부",
    "남성_주_불임_원인",
    "남성_부_불임_원인",
    "여성_주_불임_원인",
    "여성_부_불임_원인",
    "부부_주_불임_원인",
    "부부_부_불임_원인",
    "불명확_불임_원인",
    "불임_원인_-_난관_질환",
    "불임_원인_-_남성_요인",
    "불임_원인_-_배란_장애",
    "불임_원인_-_여성_요인",
    "불임_원인_-_자궁경부_문제",
    "불임_원인_-_자궁내막증",
    "불임_원인_-_정자_농도",
    "불임_원인_-_정자_면역학적_요인",
    "불임_원인_-_정자_운동성",
    "불임_원인_-_정자_형태",
    "총_시술_횟수",
    "클리닉_내_총_시술_횟수",
    "IVF_시술_횟수",
    "DI_시술_횟수",
    "총_임신_횟수",
    "IVF_임신_횟수",
    "DI_임신_횟수",
    "총_출산_횟수",
    "IVF_출산_횟수",
    "DI_출산_횟수",
    "난자_출처",
    "정자_출처",
    "난자_기증자_나이",
    "정자_기증자_나이",
    "PGD_시술_여부",
    "PGS_시술_여부",
    "난자_채취_경과일",
    "난자_해동_경과일",
    "난자_혼합_경과일",
    "배아_이식_경과일",
    "배아_해동_경과일",
    "변환된_특정_시술_유형"
]

# %%
DI_categorical_columns = [
    "시술_시기_코드",
    "시술_당시_나이",
    "임신_시도_또는_마지막_임신_경과_연수",
    "총_시술_횟수",
    "클리닉_내_총_시술_횟수",
    "IVF_시술_횟수",
    "DI_시술_횟수",
    "총_임신_횟수",
    "IVF_임신_횟수",
    "DI_임신_횟수",
    "총_출산_횟수",
    "IVF_출산_횟수",
    "DI_출산_횟수",
    "정자_기증자_나이",
    "변환된_특정_시술_유형"
]

# %%
# 모든 범주형 변수를 문자열로 변환
IVF_X[IVF_categorical_columns] = IVF_X[IVF_categorical_columns].astype(str)
DI_X[DI_categorical_columns] = DI_X[DI_categorical_columns].astype(str)
IVF_test[IVF_categorical_columns] = IVF_test[IVF_categorical_columns].astype(str)
DI_test[DI_categorical_columns] = DI_test[DI_categorical_columns].astype(str)

# OrdinalEncoder를 사용하여 범주형 변수 인코딩
IVF_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
DI_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

IVF_X[IVF_categorical_columns] = IVF_encoder.fit_transform(IVF_X[IVF_categorical_columns])
DI_X[DI_categorical_columns] = DI_encoder.fit_transform(DI_X[DI_categorical_columns])
IVF_test[IVF_categorical_columns] = IVF_encoder.transform(IVF_test[IVF_categorical_columns])
DI_test[DI_categorical_columns] = DI_encoder.transform(DI_test[DI_categorical_columns])

# %%
# import category_encoders as ce

# # 모든 범주형 변수를 문자열로 변환
# IVF_X[IVF_categorical_columns] = IVF_X[IVF_categorical_columns].astype(str)
# DI_X[DI_categorical_columns] = DI_X[DI_categorical_columns].astype(str)
# IVF_test[IVF_categorical_columns] = IVF_test[IVF_categorical_columns].astype(str)
# DI_test[DI_categorical_columns] = DI_test[DI_categorical_columns].astype(str)

# # 타겟 인코더를 사용하여 범주형 변수 인코딩
# IVF_target_encoder = ce.TargetEncoder(cols=IVF_categorical_columns)
# DI_target_encoder = ce.TargetEncoder(cols=DI_categorical_columns)

# # 타겟 인코딩을 위해 타겟 변수가 필요합니다. 예시로 IVF_y와 DI_y를 사용합니다.
# IVF_X[IVF_categorical_columns] = IVF_target_encoder.fit_transform(IVF_X[IVF_categorical_columns], IVF_y)
# DI_X[DI_categorical_columns] = DI_target_encoder.fit_transform(DI_X[DI_categorical_columns], DI_y)
# IVF_test[IVF_categorical_columns] = IVF_target_encoder.transform(IVF_test[IVF_categorical_columns])
# DI_test[DI_categorical_columns] = DI_target_encoder.transform(DI_test[DI_categorical_columns])

# %% [markdown]
# ## Modeling

# %%
# 데이터 분할
IVF_X_train, IVF_X_test, IVF_y_train, IVF_y_test = train_test_split(IVF_X, IVF_y, test_size=0.2, random_state=42)
DI_X_train, DI_X_test, DI_y_train, DI_y_test = train_test_split(DI_X, DI_y, test_size=0.2, random_state=42)

# %% [markdown]
# ### DI 데이터

# %%
import optuna
import lightgbm as lgb
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
import optuna
import lightgbm as lgb
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# 목적 함수 정의
def objective(trial):
    param = {
        'objective': 'binary',
        'metric': 'auc',
        'verbose': -1,
        'boosting_type': 'gbdt',
        'n_estimators': trial.suggest_int('n_estimators', 100, 3000),
        'num_leaves': trial.suggest_int('num_leaves', 10, 2048),
        'max_depth': trial.suggest_int('max_depth', 5, 200),
        'learning_rate': trial.suggest_float('learning_rate', 1e-5, 1e-1, log=True),
        'min_child_samples': trial.suggest_int('min_child_samples', 1, 200),
        'subsample': trial.suggest_float('subsample', 0.1, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.1, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-5, 1e2, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-5, 1e2, log=True),
        'min_split_gain': trial.suggest_float('min_split_gain', 1e-5, 1e1, log=True),
        'max_bin': trial.suggest_int('max_bin', 10, 512),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 1, 200),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1, 10),
        'random_state': 42,
    }

    model = lgb.LGBMClassifier(**param)
    model.fit(DI_X_train, DI_y_train, eval_set=[(DI_X_test, DI_y_test)])
    
    y_pred_proba = model.predict_proba(DI_X_test)[:, 1]
    auc = roc_auc_score(DI_y_test, y_pred_proba)
    
    return auc

# Optuna 스터디 생성 및 최적화
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=800)

# 최적의 하이퍼파라미터 출력
print("Best trial:")
trial = study.best_trial
print("  Value: {}".format(trial.value))
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))

# 최적의 하이퍼파라미터로 모델 학습
best_params = trial.params
DI_model = lgb.LGBMClassifier(**best_params)
DI_model.fit(DI_X_train, DI_y_train)

# 예측
y_pred = DI_model.predict(DI_X_test)
y_pred_proba = DI_model.predict_proba(DI_X_test)[:, 1]

# 평가
accuracy = accuracy_score(DI_y_test, y_pred)
f1 = f1_score(DI_y_test, y_pred)
auc = roc_auc_score(DI_y_test, y_pred_proba)
cm = confusion_matrix(DI_y_test, y_pred)

# 결과 출력
print()
print("--- Model Performance ---")
print(f"Model Accuracy: {accuracy}")
print(f"Model F1 Score: {f1}")
print(f"Model AUC: {auc}")

# 혼동 행렬 출력
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=DI_model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# [I 2025-02-03 21:39:10,781] A new study created in memory with name: no-name-d19abc3c-a3e7-4ca5-88fd-1ef5cff12eaa
# [I 2025-02-03 21:39:24,982] Trial 0 finished with value: 0.6946974661424202 and parameters: {'n_estimators': 2790, 'num_leaves': 507, 'max_depth': 115, 'learning_rate': 0.0004742390857782837, 'min_child_samples': 112, 'subsample': 0.9384866409549946, 'colsample_bytree': 0.4896550715286233, 'reg_alpha': 0.05404427453088194, 'reg_lambda': 1.5345623106399482e-05, 'min_split_gain': 9.729394827555798e-05, 'max_bin': 362, 'min_data_in_leaf': 107, 'scale_pos_weight': 3.260552826659435}. Best is trial 0 with value: 0.6946974661424202.
# [I 2025-02-03 21:39:27,904] Trial 1 finished with value: 0.6909922455220621 and parameters: {'n_estimators': 1133, 'num_leaves': 646, 'max_depth': 19, 'learning_rate': 0.0005220424708653508, 'min_child_samples': 184, 'subsample': 0.5806757252002122, 'colsample_bytree': 0.5322155379669862, 'reg_alpha': 0.0270231718249231, 'reg_lambda': 85.48115327490959, 'min_split_gain': 0.0004895725452697587, 'max_bin': 481, 'min_data_in_leaf': 192, 'scale_pos_weight': 2.265920075208616}. Best is trial 0 with value: 0.6946974661424202.
# [I 2025-02-03 21:39:33,852] Trial 2 finished with value: 0.6917704237658366 and parameters: {'n_estimators': 2069, 'num_leaves': 1227, 'max_depth': 50, 'learning_rate': 8.483827033652574e-05, 'min_child_samples': 100, 'subsample': 0.31457791590120127, 'colsample_bytree': 0.46221379147309016, 'reg_alpha': 11.668178628092631, 'reg_lambda': 0.012227225419741479, 'min_split_gain': 0.0017687319511616951, 'max_bin': 143, 'min_data_in_leaf': 125, 'scale_pos_weight': 2.672460569025987}. Best is trial 0 with value: 0.6946974661424202.
# [I 2025-02-03 21:39:47,310] Trial 3 finished with value: 0.671630624726955 and parameters: {'n_estimators': 2630, 'num_leaves': 1456, 'max_depth': 179, 'learning_rate': 0.0003549099769434239, 'min_child_samples': 35, 'subsample': 0.9512015203814161, 'colsample_bytree': 0.26551932345568946, 'reg_alpha': 1.7583218172085142e-05, 'reg_lambda': 6.0686418859646926e-05, 'min_split_gain': 0.00019559455772931528, 'max_bin': 250, 'min_data_in_leaf': 134, 'scale_pos_weight': 7.967443843361561}. Best is trial 0 with value: 0.6946974661424202.
# [I 2025-02-03 21:39:55,996] Trial 4 finished with value: 0.6946455875928353 and parameters: {'n_estimators': 1638, 'num_leaves': 1272, 'max_depth': 162, 'learning_rate': 0.0011531021279753172, 'min_child_samples': 91, 'subsample': 0.36255933828372233, 'colsample_bytree': 0.6364446525275204, 'reg_alpha': 0.03894583441965204, 'reg_lambda': 1.6346194046115974, 'min_split_gain': 1.0668593993714912, 'max_bin': 494, 'min_data_in_leaf': 56, 'scale_pos_weight': 2.255213322358379}. Best is trial 0 with value: 0.6946974661424202.
# [I 2025-02-03 21:39:58,197] Trial 5 finished with value: 0.6934005024027959 and parameters: {'n_estimators': 432, 'num_leaves': 1467, 'max_depth': 155, 'learning_rate': 0.0012772012737600888, 'min_child_samples': 22, 'subsample': 0.6959307803177657, 'colsample_bytree': 0.4683693179016333, 'reg_alpha': 3.6543570999514034e-05, 'reg_lambda': 9.536158729579876e-05, 'min_split_gain': 0.0006627831202631881, 'max_bin': 38, 'min_data_in_leaf': 152, 'scale_pos_weight': 1.66482891813788}. Best is trial 0 with value: 0.6946974661424202.
# [I 2025-02-03 21:40:08,246] Trial 6 finished with value: 0.6909294451725645 and parameters: {'n_estimators': 1860, 'num_leaves': 1385, 'max_depth': 165, 'learning_rate': 0.0008265524041814667, 'min_child_samples': 13, 'subsample': 0.5316012495300061, 'colsample_bytree': 0.24938825743242904, 'reg_alpha': 0.2347640427806925, 'reg_lambda': 0.07847783098146804, 'min_split_gain': 6.228098418858619e-05, 'max_bin': 73, 'min_data_in_leaf': 70, 'scale_pos_weight': 2.3537776573346574}. Best is trial 0 with value: 0.6946974661424202.
# [I 2025-02-03 21:40:10,622] Trial 7 finished with value: 0.6890427042376583 and parameters: {'n_estimators': 748, 'num_leaves': 295, 'max_depth': 69, 'learning_rate': 2.2686691272361482e-05, 'min_child_samples': 48, 'subsample': 0.47319892078729453, 'colsample_bytree': 0.3860624507881637, 'reg_alpha': 0.755025152110216, 'reg_lambda': 4.6331633503834375, 'min_split_gain': 6.607473414310702e-05, 'max_bin': 427, 'min_data_in_leaf': 131, 'scale_pos_weight': 1.779347365859568}. Best is trial 0 with value: 0.6946974661424202.
# [I 2025-02-03 21:40:14,297] Trial 8 finished with value: 0.7116999781564002 and parameters: {'n_estimators': 1292, 'num_leaves': 529, 'max_depth': 172, 'learning_rate': 1.2652031672238098e-05, 'min_child_samples': 22, 'subsample': 0.5023907481879295, 'colsample_bytree': 0.971134721160793, 'reg_alpha': 3.628218098260307, 'reg_lambda': 0.00018392436021083284, 'min_split_gain': 2.6074891025450513e-05, 'max_bin': 323, 'min_data_in_leaf': 143, 'scale_pos_weight': 6.848515289401421}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:40:16,381] Trial 9 finished with value: 0.6968108344255133 and parameters: {'n_estimators': 510, 'num_leaves': 1354, 'max_depth': 75, 'learning_rate': 0.005871057600159243, 'min_child_samples': 24, 'subsample': 0.3499668353636989, 'colsample_bytree': 0.4035733585215856, 'reg_alpha': 2.3385677781979304, 'reg_lambda': 2.8299079224880482e-05, 'min_split_gain': 0.0007488408151712593, 'max_bin': 102, 'min_data_in_leaf': 79, 'scale_pos_weight': 5.292886312016006}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:40:18,580] Trial 10 finished with value: 0.6941377238968982 and parameters: {'n_estimators': 1229, 'num_leaves': 69, 'max_depth': 200, 'learning_rate': 0.09010836969939262, 'min_child_samples': 151, 'subsample': 0.13756300449706332, 'colsample_bytree': 0.9903164366026928, 'reg_alpha': 72.89474462775416, 'reg_lambda': 0.0019669651056613054, 'min_split_gain': 0.06235938081241783, 'max_bin': 292, 'min_data_in_leaf': 199, 'scale_pos_weight': 9.92243224667725}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:40:20,974] Trial 11 finished with value: 0.6951671035386631 and parameters: {'n_estimators': 301, 'num_leaves': 1891, 'max_depth': 106, 'learning_rate': 0.01817777278962325, 'min_child_samples': 62, 'subsample': 0.19773510803827055, 'colsample_bytree': 0.7841455083950101, 'reg_alpha': 4.885908924163921, 'reg_lambda': 0.000786014649997035, 'min_split_gain': 1.1941958746978478e-05, 'max_bin': 202, 'min_data_in_leaf': 17, 'scale_pos_weight': 5.420465164200913}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:40:26,776] Trial 12 finished with value: 0.665519877675841 and parameters: {'n_estimators': 884, 'num_leaves': 839, 'max_depth': 73, 'learning_rate': 0.006297327670466069, 'min_child_samples': 6, 'subsample': 0.7346204749577285, 'colsample_bytree': 0.9378648181653079, 'reg_alpha': 0.0017294524385077776, 'reg_lambda': 1.0252092698536389e-05, 'min_split_gain': 0.018384003484160357, 'max_bin': 343, 'min_data_in_leaf': 63, 'scale_pos_weight': 5.504260999844954}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:40:27,291] Trial 13 finished with value: 0.7067114460463084 and parameters: {'n_estimators': 102, 'num_leaves': 1839, 'max_depth': 130, 'learning_rate': 1.7249200106496074e-05, 'min_child_samples': 68, 'subsample': 0.337040361804112, 'colsample_bytree': 0.6984338882073899, 'reg_alpha': 2.504162870933265, 'reg_lambda': 0.0004955556003153192, 'min_split_gain': 0.005846120201930864, 'max_bin': 143, 'min_data_in_leaf': 165, 'scale_pos_weight': 6.121353813006454}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:40:32,723] Trial 14 finished with value: 0.6549776103101791 and parameters: {'n_estimators': 2276, 'num_leaves': 1962, 'max_depth': 132, 'learning_rate': 1.088356805328018e-05, 'min_child_samples': 69, 'subsample': 0.4307777008421386, 'colsample_bytree': 0.7635987676189779, 'reg_alpha': 91.44029739547274, 'reg_lambda': 0.00041250419979863175, 'min_split_gain': 0.32956194675265627, 'max_bin': 214, 'min_data_in_leaf': 166, 'scale_pos_weight': 7.177557573294419}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:40:34,394] Trial 15 finished with value: 0.696281127129751 and parameters: {'n_estimators': 130, 'num_leaves': 1676, 'max_depth': 139, 'learning_rate': 7.237750826897117e-05, 'min_child_samples': 123, 'subsample': 0.6646316536232583, 'colsample_bytree': 0.8441800442986527, 'reg_alpha': 0.0013026631305191265, 'reg_lambda': 0.012965866357078248, 'min_split_gain': 4.611289937028347, 'max_bin': 151, 'min_data_in_leaf': 168, 'scale_pos_weight': 6.946706257156656}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:40:37,688] Trial 16 finished with value: 0.6932830930537351 and parameters: {'n_estimators': 1272, 'num_leaves': 1015, 'max_depth': 198, 'learning_rate': 5.092415254369703e-05, 'min_child_samples': 75, 'subsample': 0.23465897214354037, 'colsample_bytree': 0.6226001055176545, 'reg_alpha': 18.649878650284748, 'reg_lambda': 0.0003018995973420569, 'min_split_gain': 0.0056568849478126765, 'max_bin': 305, 'min_data_in_leaf': 169, 'scale_pos_weight': 9.132519805274518}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:40:45,877] Trial 17 finished with value: 0.6792185452162517 and parameters: {'n_estimators': 1564, 'num_leaves': 783, 'max_depth': 132, 'learning_rate': 1.0267101781435453e-05, 'min_child_samples': 44, 'subsample': 0.8220665906994858, 'colsample_bytree': 0.865216240089774, 'reg_alpha': 0.506543988115397, 'reg_lambda': 0.0027691746583939276, 'min_split_gain': 1.4327436841242277e-05, 'max_bin': 400, 'min_data_in_leaf': 100, 'scale_pos_weight': 4.20644337687337}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:40:48,845] Trial 18 finished with value: 0.7081176277850589 and parameters: {'n_estimators': 784, 'num_leaves': 379, 'max_depth': 92, 'learning_rate': 0.0001851330714226976, 'min_child_samples': 138, 'subsample': 0.5814088042766669, 'colsample_bytree': 0.7452110846920419, 'reg_alpha': 1.7031488292576196, 'reg_lambda': 0.08696566511911741, 'min_split_gain': 0.08995592789656605, 'max_bin': 11, 'min_data_in_leaf': 148, 'scale_pos_weight': 6.359258126952227}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:40:53,409] Trial 19 finished with value: 0.6960053516819572 and parameters: {'n_estimators': 888, 'num_leaves': 406, 'max_depth': 28, 'learning_rate': 0.0001973119368603092, 'min_child_samples': 145, 'subsample': 0.5763757250049837, 'colsample_bytree': 0.8950987347451275, 'reg_alpha': 0.004317228579667821, 'reg_lambda': 0.05098390098698763, 'min_split_gain': 0.12623033812181994, 'max_bin': 23, 'min_data_in_leaf': 106, 'scale_pos_weight': 8.033547517767001}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:40:56,508] Trial 20 finished with value: 0.674650502402796 and parameters: {'n_estimators': 692, 'num_leaves': 30, 'max_depth': 80, 'learning_rate': 0.0001642952436015917, 'min_child_samples': 191, 'subsample': 0.8281772831091322, 'colsample_bytree': 0.14097752611939446, 'reg_alpha': 0.17829050920749573, 'reg_lambda': 0.4838232301977822, 'min_split_gain': 0.024866677385092472, 'max_bin': 222, 'min_data_in_leaf': 148, 'scale_pos_weight': 4.185584340182662}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:40:59,624] Trial 21 finished with value: 0.7044451725644386 and parameters: {'n_estimators': 1134, 'num_leaves': 248, 'max_depth': 116, 'learning_rate': 2.285445513195963e-05, 'min_child_samples': 149, 'subsample': 0.4648938121662594, 'colsample_bytree': 0.6896956042561356, 'reg_alpha': 2.162141026716508, 'reg_lambda': 0.24969823284378093, 'min_split_gain': 0.006579409065736589, 'max_bin': 147, 'min_data_in_leaf': 182, 'scale_pos_weight': 6.8240433528423265}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:41:00,246] Trial 22 finished with value: 0.6986129314110966 and parameters: {'n_estimators': 202, 'num_leaves': 567, 'max_depth': 144, 'learning_rate': 3.515684884359627e-05, 'min_child_samples': 127, 'subsample': 0.6339273919571532, 'colsample_bytree': 0.7166248362043275, 'reg_alpha': 8.06287948864806, 'reg_lambda': 0.004830381801862078, 'min_split_gain': 0.6399745695003649, 'max_bin': 83, 'min_data_in_leaf': 151, 'scale_pos_weight': 6.378367256156538}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:41:02,341] Trial 23 finished with value: 0.7023509174311927 and parameters: {'n_estimators': 568, 'num_leaves': 948, 'max_depth': 96, 'learning_rate': 0.00011540237674269923, 'min_child_samples': 171, 'subsample': 0.2808512885273139, 'colsample_bytree': 0.6115727165262513, 'reg_alpha': 0.9850974631323701, 'reg_lambda': 0.0002819740871240534, 'min_split_gain': 0.07434587896507484, 'max_bin': 186, 'min_data_in_leaf': 118, 'scale_pos_weight': 6.087437553993949}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:41:05,437] Trial 24 finished with value: 0.6951206858890344 and parameters: {'n_estimators': 1372, 'num_leaves': 730, 'max_depth': 180, 'learning_rate': 2.0145905072576497e-05, 'min_child_samples': 85, 'subsample': 0.3794203427652843, 'colsample_bytree': 0.7961918693776158, 'reg_alpha': 17.384684341588947, 'reg_lambda': 0.12117503055943549, 'min_split_gain': 5.461701101782191, 'max_bin': 275, 'min_data_in_leaf': 140, 'scale_pos_weight': 7.923685424139699}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:41:08,423] Trial 25 finished with value: 0.6878003494975972 and parameters: {'n_estimators': 963, 'num_leaves': 219, 'max_depth': 91, 'learning_rate': 3.8427683701094685e-05, 'min_child_samples': 57, 'subsample': 0.5215344518876633, 'colsample_bytree': 0.9311941911704885, 'reg_alpha': 0.18654379321618497, 'reg_lambda': 0.0001165954660280534, 'min_split_gain': 0.00323256134083236, 'max_bin': 18, 'min_data_in_leaf': 176, 'scale_pos_weight': 4.651193738508331}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:41:12,169] Trial 26 finished with value: 0.6928871778069026 and parameters: {'n_estimators': 1761, 'num_leaves': 1716, 'max_depth': 46, 'learning_rate': 1.0418099285829732e-05, 'min_child_samples': 114, 'subsample': 0.4238186760135052, 'colsample_bytree': 0.999980103482126, 'reg_alpha': 34.28673385864203, 'reg_lambda': 0.017755023612287743, 'min_split_gain': 0.19886153672202017, 'max_bin': 119, 'min_data_in_leaf': 161, 'scale_pos_weight': 8.688992479501817}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:41:15,854] Trial 27 finished with value: 0.6998662079510702 and parameters: {'n_estimators': 1440, 'num_leaves': 1147, 'max_depth': 115, 'learning_rate': 0.00025051677501212907, 'min_child_samples': 1, 'subsample': 0.6135640158562949, 'colsample_bytree': 0.6977241506620232, 'reg_alpha': 4.877233229266036, 'reg_lambda': 0.001150816816607768, 'min_split_gain': 0.03206588294946032, 'max_bin': 64, 'min_data_in_leaf': 186, 'scale_pos_weight': 6.023292773389245}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:41:16,989] Trial 28 finished with value: 0.7013679554390563 and parameters: {'n_estimators': 408, 'num_leaves': 432, 'max_depth': 176, 'learning_rate': 5.975789461578743e-05, 'min_child_samples': 166, 'subsample': 0.1200804790263027, 'colsample_bytree': 0.8135749755255892, 'reg_alpha': 1.8962485045510846, 'reg_lambda': 4.538422569222351, 'min_split_gain': 1.8004389479440777, 'max_bin': 325, 'min_data_in_leaf': 96, 'scale_pos_weight': 7.508093902548946}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:41:20,038] Trial 29 finished with value: 0.6947575360419398 and parameters: {'n_estimators': 686, 'num_leaves': 561, 'max_depth': 126, 'learning_rate': 0.002101975308210246, 'min_child_samples': 135, 'subsample': 0.7592845019500605, 'colsample_bytree': 0.5592790121170055, 'reg_alpha': 0.013144826425843236, 'reg_lambda': 0.006292041427798089, 'min_split_gain': 0.00014105192961621078, 'max_bin': 404, 'min_data_in_leaf': 113, 'scale_pos_weight': 3.2241136425304706}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:41:34,016] Trial 30 finished with value: 0.6911642638706859 and parameters: {'n_estimators': 2938, 'num_leaves': 900, 'max_depth': 152, 'learning_rate': 2.0532426442828216e-05, 'min_child_samples': 107, 'subsample': 0.5273394071440579, 'colsample_bytree': 0.7471598237114252, 'reg_alpha': 0.00013012213405285748, 'reg_lambda': 3.47905269063567e-05, 'min_split_gain': 2.8383815855197507e-05, 'max_bin': 167, 'min_data_in_leaf': 89, 'scale_pos_weight': 4.602562194378916}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:41:37,248] Trial 31 finished with value: 0.7060561380515509 and parameters: {'n_estimators': 1083, 'num_leaves': 199, 'max_depth': 115, 'learning_rate': 2.6881052600388274e-05, 'min_child_samples': 155, 'subsample': 0.46978016319944416, 'colsample_bytree': 0.7055476254259906, 'reg_alpha': 2.126344438269094, 'reg_lambda': 0.1828407934015908, 'min_split_gain': 0.007063715055529286, 'max_bin': 244, 'min_data_in_leaf': 186, 'scale_pos_weight': 6.445959469183188}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:41:40,881] Trial 32 finished with value: 0.6985801660113586 and parameters: {'n_estimators': 1063, 'num_leaves': 162, 'max_depth': 110, 'learning_rate': 3.402465502866604e-05, 'min_child_samples': 138, 'subsample': 0.4780915961340686, 'colsample_bytree': 0.5655363390250301, 'reg_alpha': 0.10040627242686391, 'reg_lambda': 0.26078336528534735, 'min_split_gain': 0.001937027341864966, 'max_bin': 253, 'min_data_in_leaf': 194, 'scale_pos_weight': 6.588427924233095}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:41:44,198] Trial 33 finished with value: 0.7064247487986021 and parameters: {'n_estimators': 1015, 'num_leaves': 385, 'max_depth': 57, 'learning_rate': 0.00010305548329419825, 'min_child_samples': 170, 'subsample': 0.4014535146099839, 'colsample_bytree': 0.6473930308635059, 'reg_alpha': 0.4847736628436496, 'reg_lambda': 1.2973443207322668, 'min_split_gain': 0.014037431131599026, 'max_bin': 372, 'min_data_in_leaf': 153, 'scale_pos_weight': 5.74586528646182}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:41:46,697] Trial 34 finished with value: 0.7059987986020095 and parameters: {'n_estimators': 839, 'num_leaves': 662, 'max_depth': 59, 'learning_rate': 0.00010305092220175978, 'min_child_samples': 179, 'subsample': 0.30268928925090827, 'colsample_bytree': 0.6512950516154302, 'reg_alpha': 0.5166446067355885, 'reg_lambda': 1.16857274820061, 'min_split_gain': 0.00028749816643345693, 'max_bin': 442, 'min_data_in_leaf': 141, 'scale_pos_weight': 5.710770148214554}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:41:51,497] Trial 35 finished with value: 0.6884365443425077 and parameters: {'n_estimators': 1393, 'num_leaves': 424, 'max_depth': 88, 'learning_rate': 0.00045572545173399725, 'min_child_samples': 92, 'subsample': 0.3754432451291028, 'colsample_bytree': 0.515187622417602, 'reg_alpha': 0.07793895484676683, 'reg_lambda': 45.91043947942412, 'min_split_gain': 0.015888185093825252, 'max_bin': 366, 'min_data_in_leaf': 129, 'scale_pos_weight': 4.888335608716677}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:41:56,246] Trial 36 finished with value: 0.6835708824814329 and parameters: {'n_estimators': 2029, 'num_leaves': 357, 'max_depth': 5, 'learning_rate': 0.00012312794629755217, 'min_child_samples': 162, 'subsample': 0.2523263387608127, 'colsample_bytree': 0.583292936866872, 'reg_alpha': 0.015484882026838889, 'reg_lambda': 17.985635946550982, 'min_split_gain': 0.0017275025548937277, 'max_bin': 367, 'min_data_in_leaf': 155, 'scale_pos_weight': 7.310319002346836}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:41:58,929] Trial 37 finished with value: 0.6964613368283094 and parameters: {'n_estimators': 609, 'num_leaves': 534, 'max_depth': 46, 'learning_rate': 0.00031331224427584244, 'min_child_samples': 197, 'subsample': 0.5787095491757115, 'colsample_bytree': 0.6608383035400078, 'reg_alpha': 0.39342433916113106, 'reg_lambda': 0.0337603273819334, 'min_split_gain': 0.0683739272467027, 'max_bin': 468, 'min_data_in_leaf': 121, 'scale_pos_weight': 4.0720723153439655}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:41:59,896] Trial 38 finished with value: 0.6895014198339886 and parameters: {'n_estimators': 313, 'num_leaves': 660, 'max_depth': 60, 'learning_rate': 1.582409051268378e-05, 'min_child_samples': 32, 'subsample': 0.4187854504302192, 'colsample_bytree': 0.45349448783680824, 'reg_alpha': 5.419143308571163, 'reg_lambda': 0.9421951131677777, 'min_split_gain': 0.0003783903600023719, 'max_bin': 51, 'min_data_in_leaf': 140, 'scale_pos_weight': 5.994890728204282}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:42:08,145] Trial 39 finished with value: 0.6919342507645259 and parameters: {'n_estimators': 2363, 'num_leaves': 1531, 'max_depth': 29, 'learning_rate': 5.5366723445411736e-05, 'min_child_samples': 180, 'subsample': 0.33638070798429, 'colsample_bytree': 0.8238126567028832, 'reg_alpha': 1.330145828816906, 'reg_lambda': 7.477816590241272, 'min_split_gain': 0.31462746519821416, 'max_bin': 115, 'min_data_in_leaf': 27, 'scale_pos_weight': 5.034074518469489}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:42:12,177] Trial 40 finished with value: 0.6896106378331149 and parameters: {'n_estimators': 1653, 'num_leaves': 1084, 'max_depth': 168, 'learning_rate': 0.0005881684752578956, 'min_child_samples': 43, 'subsample': 0.18462502047060822, 'colsample_bytree': 0.9296266508980264, 'reg_alpha': 31.21874376937992, 'reg_lambda': 0.5937861368769696, 'min_split_gain': 0.0013131036752931679, 'max_bin': 385, 'min_data_in_leaf': 176, 'scale_pos_weight': 3.449365279268499}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:42:15,727] Trial 41 finished with value: 0.706667758846658 and parameters: {'n_estimators': 1063, 'num_leaves': 138, 'max_depth': 127, 'learning_rate': 3.677469414153645e-05, 'min_child_samples': 115, 'subsample': 0.4928566816822811, 'colsample_bytree': 0.727481622330836, 'reg_alpha': 1.8646568890749304, 'reg_lambda': 0.15065034456386833, 'min_split_gain': 0.00878240500133118, 'max_bin': 321, 'min_data_in_leaf': 186, 'scale_pos_weight': 6.451302914187074}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:42:19,460] Trial 42 finished with value: 0.7049175404106597 and parameters: {'n_estimators': 1221, 'num_leaves': 114, 'max_depth': 123, 'learning_rate': 8.017273211169491e-05, 'min_child_samples': 117, 'subsample': 0.5123566513212657, 'colsample_bytree': 0.7373817249090859, 'reg_alpha': 4.155172032974175, 'reg_lambda': 0.00012351857545517587, 'min_split_gain': 0.03644191528276114, 'max_bin': 328, 'min_data_in_leaf': 160, 'scale_pos_weight': 5.756895520105479}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:42:22,376] Trial 43 finished with value: 0.6970019659239843 and parameters: {'n_estimators': 1031, 'num_leaves': 315, 'max_depth': 101, 'learning_rate': 1.5346771141671594e-05, 'min_child_samples': 98, 'subsample': 0.39445355631150536, 'colsample_bytree': 0.6693954360822929, 'reg_alpha': 10.9613631912325, 'reg_lambda': 2.8934620201767385, 'min_split_gain': 0.01042385080553639, 'max_bin': 310, 'min_data_in_leaf': 177, 'scale_pos_weight': 7.770070093821978}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:42:25,109] Trial 44 finished with value: 0.6984900611620795 and parameters: {'n_estimators': 782, 'num_leaves': 13, 'max_depth': 152, 'learning_rate': 3.950699836793217e-05, 'min_child_samples': 77, 'subsample': 0.6120162649745928, 'colsample_bytree': 0.5967878235232075, 'reg_alpha': 0.9095773954568418, 'reg_lambda': 0.07411937993033534, 'min_split_gain': 0.00074684738728293, 'max_bin': 272, 'min_data_in_leaf': 200, 'scale_pos_weight': 1.0417785637840877}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:42:30,692] Trial 45 finished with value: 0.6986675404106596 and parameters: {'n_estimators': 1274, 'num_leaves': 498, 'max_depth': 143, 'learning_rate': 0.00015794179979075154, 'min_child_samples': 17, 'subsample': 0.5568122868296073, 'colsample_bytree': 0.5235357991077709, 'reg_alpha': 0.3063271085746568, 'reg_lambda': 0.02397541182544808, 'min_split_gain': 0.003098985708242265, 'max_bin': 331, 'min_data_in_leaf': 148, 'scale_pos_weight': 6.562343835965216}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:42:32,245] Trial 46 finished with value: 0.7055073176059414 and parameters: {'n_estimators': 486, 'num_leaves': 297, 'max_depth': 187, 'learning_rate': 1.5066438690498962e-05, 'min_child_samples': 133, 'subsample': 0.330136949354166, 'colsample_bytree': 0.8798722253097886, 'reg_alpha': 0.03651631459029671, 'reg_lambda': 2.028062979573427, 'min_split_gain': 0.013385100840675174, 'max_bin': 349, 'min_data_in_leaf': 167, 'scale_pos_weight': 8.43691472065236}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:42:41,059] Trial 47 finished with value: 0.6954892966360855 and parameters: {'n_estimators': 1511, 'num_leaves': 2042, 'max_depth': 84, 'learning_rate': 0.0016190618500659783, 'min_child_samples': 104, 'subsample': 0.6794982929404345, 'colsample_bytree': 0.7818180344742844, 'reg_alpha': 2.9418968160104733, 'reg_lambda': 1.9861819023687543e-05, 'min_split_gain': 0.04255391236005134, 'max_bin': 303, 'min_data_in_leaf': 48, 'scale_pos_weight': 6.942131327274525}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:42:44,679] Trial 48 finished with value: 0.6895314547837483 and parameters: {'n_estimators': 1173, 'num_leaves': 165, 'max_depth': 61, 'learning_rate': 8.662946162238545e-05, 'min_child_samples': 56, 'subsample': 0.44169030976839774, 'colsample_bytree': 0.35231186960538585, 'reg_alpha': 0.8171444782691134, 'reg_lambda': 0.0069239519129250075, 'min_split_gain': 0.12092866336875766, 'max_bin': 424, 'min_data_in_leaf': 157, 'scale_pos_weight': 5.209318750973854}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:42:46,325] Trial 49 finished with value: 0.7030772171253822 and parameters: {'n_estimators': 880, 'num_leaves': 358, 'max_depth': 99, 'learning_rate': 0.06443390567808688, 'min_child_samples': 32, 'subsample': 0.5098780198488381, 'colsample_bytree': 0.7446632422634245, 'reg_alpha': 53.3008520339632, 'reg_lambda': 5.879364753541677e-05, 'min_split_gain': 0.003746088252474109, 'max_bin': 229, 'min_data_in_leaf': 134, 'scale_pos_weight': 6.250594730599105}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:42:46,773] Trial 50 finished with value: 0.7063947138488423 and parameters: {'n_estimators': 123, 'num_leaves': 1268, 'max_depth': 162, 'learning_rate': 4.903701391552059e-05, 'min_child_samples': 158, 'subsample': 0.9119262268806412, 'colsample_bytree': 0.8485273353244347, 'reg_alpha': 7.978533829676442, 'reg_lambda': 0.0006170460960416948, 'min_split_gain': 3.5136709222045116e-05, 'max_bin': 284, 'min_data_in_leaf': 189, 'scale_pos_weight': 7.436911158953269}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:42:47,491] Trial 51 finished with value: 0.7083852118829184 and parameters: {'n_estimators': 216, 'num_leaves': 1791, 'max_depth': 157, 'learning_rate': 4.5875318358978526e-05, 'min_child_samples': 158, 'subsample': 0.9081144499752878, 'colsample_bytree': 0.9604171033252044, 'reg_alpha': 7.184118688686688, 'reg_lambda': 0.0006394880400774164, 'min_split_gain': 0.0001856160524129087, 'max_bin': 288, 'min_data_in_leaf': 191, 'scale_pos_weight': 7.339127319746322}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:42:48,372] Trial 52 finished with value: 0.6961009174311925 and parameters: {'n_estimators': 302, 'num_leaves': 1801, 'max_depth': 132, 'learning_rate': 3.0359896031461883e-05, 'min_child_samples': 143, 'subsample': 0.8713891835275022, 'colsample_bytree': 0.967897750512763, 'reg_alpha': 14.92661559527624, 'reg_lambda': 0.00017127027971825437, 'min_split_gain': 7.260929922116272e-05, 'max_bin': 350, 'min_data_in_leaf': 173, 'scale_pos_weight': 7.1430852309454735}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:42:50,026] Trial 53 finished with value: 0.70956749672346 and parameters: {'n_estimators': 427, 'num_leaves': 1697, 'max_depth': 138, 'learning_rate': 1.4330120558148347e-05, 'min_child_samples': 121, 'subsample': 0.9475108957355, 'colsample_bytree': 0.8910439982080964, 'reg_alpha': 1.50914900956352, 'reg_lambda': 0.0008611736709006645, 'min_split_gain': 0.0001573492613848585, 'max_bin': 381, 'min_data_in_leaf': 181, 'scale_pos_weight': 5.7740576918302535}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:42:50,992] Trial 54 finished with value: 0.6644932284840541 and parameters: {'n_estimators': 386, 'num_leaves': 1557, 'max_depth': 138, 'learning_rate': 1.5871803591893994e-05, 'min_child_samples': 125, 'subsample': 0.9809016931033988, 'colsample_bytree': 0.8954147026308972, 'reg_alpha': 31.978296122473086, 'reg_lambda': 0.002646851322809755, 'min_split_gain': 0.00014294932545904412, 'max_bin': 192, 'min_data_in_leaf': 193, 'scale_pos_weight': 6.779815016691799}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:42:52,860] Trial 55 finished with value: 0.7102036915683705 and parameters: {'n_estimators': 546, 'num_leaves': 1862, 'max_depth': 158, 'learning_rate': 1.3489484954905112e-05, 'min_child_samples': 120, 'subsample': 0.9104790242984018, 'colsample_bytree': 0.9506449314198743, 'reg_alpha': 3.8730989616580853, 'reg_lambda': 0.0016371879370722826, 'min_split_gain': 3.21132466932816e-05, 'max_bin': 511, 'min_data_in_leaf': 180, 'scale_pos_weight': 8.23287795506707}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:42:53,677] Trial 56 finished with value: 0.709583879423329 and parameters: {'n_estimators': 248, 'num_leaves': 1875, 'max_depth': 159, 'learning_rate': 1.2899777612059694e-05, 'min_child_samples': 131, 'subsample': 0.999835408869449, 'colsample_bytree': 0.9659999980083434, 'reg_alpha': 7.621191918449219, 'reg_lambda': 0.0011590011862817715, 'min_split_gain': 3.20918682932906e-05, 'max_bin': 489, 'min_data_in_leaf': 164, 'scale_pos_weight': 9.44998422913292}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:42:55,478] Trial 57 finished with value: 0.709166120576671 and parameters: {'n_estimators': 591, 'num_leaves': 1661, 'max_depth': 168, 'learning_rate': 1.199867324445006e-05, 'min_child_samples': 130, 'subsample': 0.9912492143356393, 'colsample_bytree': 0.9573434522554588, 'reg_alpha': 8.479614609902644, 'reg_lambda': 0.0012431720296668424, 'min_split_gain': 3.231572357868858e-05, 'max_bin': 471, 'min_data_in_leaf': 181, 'scale_pos_weight': 9.6057118317083}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:42:57,330] Trial 58 finished with value: 0.709166120576671 and parameters: {'n_estimators': 552, 'num_leaves': 1665, 'max_depth': 171, 'learning_rate': 1.0507806570052104e-05, 'min_child_samples': 122, 'subsample': 0.9883967728226406, 'colsample_bytree': 0.9619430657432239, 'reg_alpha': 9.18693228971641, 'reg_lambda': 0.0016442786004925805, 'min_split_gain': 2.2981541244680956e-05, 'max_bin': 508, 'min_data_in_leaf': 196, 'scale_pos_weight': 9.852126142640701}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:42:58,940] Trial 59 finished with value: 0.686888379204893 and parameters: {'n_estimators': 568, 'num_leaves': 1669, 'max_depth': 189, 'learning_rate': 1.0045316357329372e-05, 'min_child_samples': 120, 'subsample': 0.9774450356518337, 'colsample_bytree': 0.9082285540599604, 'reg_alpha': 21.36211170843763, 'reg_lambda': 0.0011980623849254313, 'min_split_gain': 2.1929289101389248e-05, 'max_bin': 504, 'min_data_in_leaf': 181, 'scale_pos_weight': 9.940332647585846}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:43:00,493] Trial 60 finished with value: 0.6501856705985146 and parameters: {'n_estimators': 694, 'num_leaves': 1925, 'max_depth': 171, 'learning_rate': 1.3177219479505565e-05, 'min_child_samples': 129, 'subsample': 0.9427509084111265, 'colsample_bytree': 0.9678141122975007, 'reg_alpha': 90.00136288999197, 'reg_lambda': 0.001294042197423252, 'min_split_gain': 5.1407969224603425e-05, 'max_bin': 480, 'min_data_in_leaf': 171, 'scale_pos_weight': 9.469267618805405}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:43:01,189] Trial 61 finished with value: 0.7090760157273919 and parameters: {'n_estimators': 194, 'num_leaves': 1769, 'max_depth': 155, 'learning_rate': 2.218133507908795e-05, 'min_child_samples': 108, 'subsample': 0.9133351876967356, 'colsample_bytree': 0.9685430591958673, 'reg_alpha': 9.108718900782783, 'reg_lambda': 0.0002580440845254476, 'min_split_gain': 1.1572832237259012e-05, 'max_bin': 465, 'min_data_in_leaf': 200, 'scale_pos_weight': 9.226419108566017}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:43:01,924] Trial 62 finished with value: 0.6850125600698995 and parameters: {'n_estimators': 232, 'num_leaves': 1644, 'max_depth': 161, 'learning_rate': 2.3862909554689927e-05, 'min_child_samples': 110, 'subsample': 0.8677970108068593, 'colsample_bytree': 0.9945593717455619, 'reg_alpha': 12.174465712986075, 'reg_lambda': 0.00028422562860027446, 'min_split_gain': 1.1285000195863943e-05, 'max_bin': 457, 'min_data_in_leaf': 197, 'scale_pos_weight': 9.473477413399452}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:43:03,473] Trial 63 finished with value: 0.7109545653123635 and parameters: {'n_estimators': 448, 'num_leaves': 1439, 'max_depth': 182, 'learning_rate': 1.2353235916376527e-05, 'min_child_samples': 98, 'subsample': 0.9828284663999588, 'colsample_bytree': 0.9257889225279704, 'reg_alpha': 3.7802797799057393, 'reg_lambda': 0.00409168484252071, 'min_split_gain': 2.006836740940402e-05, 'max_bin': 506, 'min_data_in_leaf': 182, 'scale_pos_weight': 8.89534516585727}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:43:04,973] Trial 64 finished with value: 0.7110255570117955 and parameters: {'n_estimators': 420, 'num_leaves': 1427, 'max_depth': 186, 'learning_rate': 1.2460993685788874e-05, 'min_child_samples': 146, 'subsample': 0.9977885935491801, 'colsample_bytree': 0.9276762155265386, 'reg_alpha': 3.71641009605491, 'reg_lambda': 0.0036362654279692196, 'min_split_gain': 2.0122912543103563e-05, 'max_bin': 495, 'min_data_in_leaf': 179, 'scale_pos_weight': 8.700236191946843}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:43:06,590] Trial 65 finished with value: 0.7107634338138925 and parameters: {'n_estimators': 456, 'num_leaves': 1387, 'max_depth': 192, 'learning_rate': 1.3251152234308353e-05, 'min_child_samples': 145, 'subsample': 0.9613963432346353, 'colsample_bytree': 0.9216309978477826, 'reg_alpha': 4.027448602312287, 'reg_lambda': 0.004338835448910246, 'min_split_gain': 4.387640858026016e-05, 'max_bin': 487, 'min_data_in_leaf': 164, 'scale_pos_weight': 8.683723859617688}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:43:08,110] Trial 66 finished with value: 0.7108235037134119 and parameters: {'n_estimators': 440, 'num_leaves': 1403, 'max_depth': 192, 'learning_rate': 1.7739722442561832e-05, 'min_child_samples': 145, 'subsample': 0.956169120043631, 'colsample_bytree': 0.9114409676130352, 'reg_alpha': 3.709983330539801, 'reg_lambda': 0.004344359261002682, 'min_split_gain': 1.8041781923247097e-05, 'max_bin': 490, 'min_data_in_leaf': 164, 'scale_pos_weight': 8.623917998581412}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:43:09,276] Trial 67 finished with value: 0.7104849279161205 and parameters: {'n_estimators': 353, 'num_leaves': 1436, 'max_depth': 194, 'learning_rate': 2.6313448542821263e-05, 'min_child_samples': 147, 'subsample': 0.8049323918616857, 'colsample_bytree': 0.8565816287930698, 'reg_alpha': 3.376935388016536, 'reg_lambda': 0.009954729774722991, 'min_split_gain': 9.449985086013657e-05, 'max_bin': 494, 'min_data_in_leaf': 165, 'scale_pos_weight': 8.744466201125926}. Best is trial 8 with value: 0.7116999781564002.
# [I 2025-02-03 21:43:10,591] Trial 68 finished with value: 0.7129559851463521 and parameters: {'n_estimators': 348, 'num_leaves': 1370, 'max_depth': 191, 'learning_rate': 1.982733017937846e-05, 'min_child_samples': 147, 'subsample': 0.805260906026505, 'colsample_bytree': 0.921426709564978, 'reg_alpha': 3.310545731134725, 'reg_lambda': 0.0041425411268376155, 'min_split_gain': 8.978162072857112e-05, 'max_bin': 443, 'min_data_in_leaf': 162, 'scale_pos_weight': 8.689545069325941}. Best is trial 68 with value: 0.7129559851463521.
# [I 2025-02-03 21:43:11,921] Trial 69 finished with value: 0.7128576889471385 and parameters: {'n_estimators': 363, 'num_leaves': 1348, 'max_depth': 196, 'learning_rate': 2.74106724348362e-05, 'min_child_samples': 149, 'subsample': 0.7730110253509592, 'colsample_bytree': 0.9192890920722124, 'reg_alpha': 3.2695096771379117, 'reg_lambda': 0.007675345998976956, 'min_split_gain': 7.675084654282595e-05, 'max_bin': 449, 'min_data_in_leaf': 161, 'scale_pos_weight': 8.828219673737182}. Best is trial 68 with value: 0.7129559851463521.
# [I 2025-02-03 21:43:14,002] Trial 70 finished with value: 0.7069326124945391 and parameters: {'n_estimators': 446, 'num_leaves': 1351, 'max_depth': 183, 'learning_rate': 2.0224694227391246e-05, 'min_child_samples': 142, 'subsample': 0.727491440938567, 'colsample_bytree': 0.9180205136355658, 'reg_alpha': 0.9944682295248884, 'reg_lambda': 0.004029095668736001, 'min_split_gain': 1.827282545753002e-05, 'max_bin': 445, 'min_data_in_leaf': 141, 'scale_pos_weight': 8.905191654880305}. Best is trial 68 with value: 0.7129559851463521.
# [I 2025-02-03 21:43:15,275] Trial 71 finished with value: 0.7102091524683267 and parameters: {'n_estimators': 337, 'num_leaves': 1407, 'max_depth': 197, 'learning_rate': 2.6127381287122734e-05, 'min_child_samples': 150, 'subsample': 0.804135396624377, 'colsample_bytree': 0.8557473764170305, 'reg_alpha': 3.0764295219966304, 'reg_lambda': 0.012554447391820739, 'min_split_gain': 9.44080879135634e-05, 'max_bin': 422, 'min_data_in_leaf': 162, 'scale_pos_weight': 8.69666007341567}. Best is trial 68 with value: 0.7129559851463521.
# [I 2025-02-03 21:43:17,354] Trial 72 finished with value: 0.6998225207514198 and parameters: {'n_estimators': 671, 'num_leaves': 1177, 'max_depth': 194, 'learning_rate': 1.824029605755925e-05, 'min_child_samples': 148, 'subsample': 0.7943460492584442, 'colsample_bytree': 0.8314843285762842, 'reg_alpha': 4.380962555278347, 'reg_lambda': 0.00954422732929319, 'min_split_gain': 5.229386057968682e-05, 'max_bin': 490, 'min_data_in_leaf': 170, 'scale_pos_weight': 8.366729656472659}. Best is trial 68 with value: 0.7129559851463521.
# [I 2025-02-03 21:43:21,223] Trial 73 finished with value: 0.6922619047619047 and parameters: {'n_estimators': 373, 'num_leaves': 1328, 'max_depth': 190, 'learning_rate': 2.9494652714011677e-05, 'min_child_samples': 154, 'subsample': 0.8585716269312588, 'colsample_bytree': 0.8659698220478447, 'reg_alpha': 1.0740546800331216e-05, 'reg_lambda': 0.002902919070621304, 'min_split_gain': 9.300778268848018e-05, 'max_bin': 449, 'min_data_in_leaf': 147, 'scale_pos_weight': 9.036905372904224}. Best is trial 68 with value: 0.7129559851463521.
# [I 2025-02-03 21:43:22,721] Trial 74 finished with value: 0.7007262996941896 and parameters: {'n_estimators': 471, 'num_leaves': 1464, 'max_depth': 200, 'learning_rate': 0.004156472299673251, 'min_child_samples': 173, 'subsample': 0.7622293528416498, 'colsample_bytree': 0.9189245061684091, 'reg_alpha': 22.06178119550792, 'reg_lambda': 0.020579704891050325, 'min_split_gain': 5.0472038304670566e-05, 'max_bin': 482, 'min_data_in_leaf': 156, 'scale_pos_weight': 8.704583484408735}. Best is trial 68 with value: 0.7129559851463521.
# [I 2025-02-03 21:43:23,579] Trial 75 finished with value: 0.7097012887723897 and parameters: {'n_estimators': 166, 'num_leaves': 1535, 'max_depth': 180, 'learning_rate': 6.417364604346526e-05, 'min_child_samples': 140, 'subsample': 0.8458893508504695, 'colsample_bytree': 0.8710813597722687, 'reg_alpha': 2.599197458504242, 'reg_lambda': 0.006833533308131334, 'min_split_gain': 0.0002709638832312147, 'max_bin': 404, 'min_data_in_leaf': 169, 'scale_pos_weight': 7.687157784071638}. Best is trial 68 with value: 0.7129559851463521.
# [I 2025-02-03 21:43:25,108] Trial 76 finished with value: 0.6866098733071211 and parameters: {'n_estimators': 292, 'num_leaves': 1417, 'max_depth': 177, 'learning_rate': 2.9370727810084656e-05, 'min_child_samples': 165, 'subsample': 0.8878992754020332, 'colsample_bytree': 0.9304014072997605, 'reg_alpha': 0.000127305874268771, 'reg_lambda': 0.004290665512515196, 'min_split_gain': 1.5938809678148027e-05, 'max_bin': 432, 'min_data_in_leaf': 159, 'scale_pos_weight': 8.074022534448636}. Best is trial 68 with value: 0.7129559851463521.
# [I 2025-02-03 21:43:36,386] Trial 77 finished with value: 0.7049994539100044 and parameters: {'n_estimators': 2527, 'num_leaves': 1293, 'max_depth': 185, 'learning_rate': 1.945691258789262e-05, 'min_child_samples': 146, 'subsample': 0.9587473231955055, 'colsample_bytree': 0.9964199570648012, 'reg_alpha': 1.5075124786984038, 'reg_lambda': 0.010862946992885817, 'min_split_gain': 7.352010078092977e-05, 'max_bin': 500, 'min_data_in_leaf': 145, 'scale_pos_weight': 8.540018290308629}. Best is trial 68 with value: 0.7129559851463521.
# [I 2025-02-03 21:43:39,662] Trial 78 finished with value: 0.6947930318916558 and parameters: {'n_estimators': 498, 'num_leaves': 1244, 'max_depth': 194, 'learning_rate': 4.277008235130413e-05, 'min_child_samples': 161, 'subsample': 0.8304682863199412, 'colsample_bytree': 0.8104991796959089, 'reg_alpha': 0.5893085138149781, 'reg_lambda': 0.03824157142860723, 'min_split_gain': 1.0102456959504455e-05, 'max_bin': 475, 'min_data_in_leaf': 152, 'scale_pos_weight': 9.22179546232265}. Best is trial 68 with value: 0.7129559851463521.
# [I 2025-02-03 21:43:41,387] Trial 79 finished with value: 0.6921226518130188 and parameters: {'n_estimators': 747, 'num_leaves': 1574, 'max_depth': 191, 'learning_rate': 1.0003990566380722e-05, 'min_child_samples': 188, 'subsample': 0.7140286044929607, 'colsample_bytree': 0.896054347940862, 'reg_alpha': 57.15964940003464, 'reg_lambda': 0.002992213599651275, 'min_split_gain': 0.00011769397046806099, 'max_bin': 457, 'min_data_in_leaf': 172, 'scale_pos_weight': 8.828508280334075}. Best is trial 68 with value: 0.7129559851463521.
# [I 2025-02-03 21:43:41,984] Trial 80 finished with value: 0.6843162953254696 and parameters: {'n_estimators': 100, 'num_leaves': 1175, 'max_depth': 174, 'learning_rate': 2.4521426954338615e-05, 'min_child_samples': 137, 'subsample': 0.9276744231867132, 'colsample_bytree': 0.9423488515407088, 'reg_alpha': 0.26040909676544044, 'reg_lambda': 0.015144224082248128, 'min_split_gain': 4.2619956041210025e-05, 'max_bin': 491, 'min_data_in_leaf': 127, 'scale_pos_weight': 8.27590289811281}. Best is trial 68 with value: 0.7129559851463521.
# [I 2025-02-03 21:43:43,219] Trial 81 finished with value: 0.7096767147225863 and parameters: {'n_estimators': 336, 'num_leaves': 1403, 'max_depth': 196, 'learning_rate': 1.7966010677124627e-05, 'min_child_samples': 153, 'subsample': 0.78853822050331, 'colsample_bytree': 0.8450986996525418, 'reg_alpha': 2.4856653768198655, 'reg_lambda': 0.009283926790536938, 'min_split_gain': 9.375551665836995e-05, 'max_bin': 417, 'min_data_in_leaf': 163, 'scale_pos_weight': 8.558890984700206}. Best is trial 68 with value: 0.7129559851463521.
# [I 2025-02-03 21:43:45,216] Trial 82 finished with value: 0.7110009829619921 and parameters: {'n_estimators': 635, 'num_leaves': 1498, 'max_depth': 182, 'learning_rate': 3.360481963629681e-05, 'min_child_samples': 150, 'subsample': 0.8036887541957076, 'colsample_bytree': 0.8638783265717731, 'reg_alpha': 3.1251626170304605, 'reg_lambda': 0.04884120979028923, 'min_split_gain': 1.680064786141671e-05, 'max_bin': 459, 'min_data_in_leaf': 162, 'scale_pos_weight': 8.986901620224275}. Best is trial 68 with value: 0.7129559851463521.
# [I 2025-02-03 21:43:46,499] Trial 83 finished with value: 0.6971685233726518 and parameters: {'n_estimators': 422, 'num_leaves': 1480, 'max_depth': 181, 'learning_rate': 3.6204220814305596e-05, 'min_child_samples': 147, 'subsample': 0.9659550021243527, 'colsample_bytree': 0.7777160996595948, 'reg_alpha': 5.317230077232392, 'reg_lambda': 0.04737424789797184, 'min_split_gain': 1.7641487514956755e-05, 'max_bin': 457, 'min_data_in_leaf': 175, 'scale_pos_weight': 8.992039198170101}. Best is trial 68 with value: 0.7129559851463521.
# [I 2025-02-03 21:43:48,832] Trial 84 finished with value: 0.7113859764089122 and parameters: {'n_estimators': 648, 'num_leaves': 1492, 'max_depth': 184, 'learning_rate': 1.8131875247875074e-05, 'min_child_samples': 176, 'subsample': 0.7606348313713437, 'colsample_bytree': 0.9046267218744413, 'reg_alpha': 1.2112535828451771, 'reg_lambda': 0.024092484344894045, 'min_split_gain': 2.3263990055836407e-05, 'max_bin': 435, 'min_data_in_leaf': 165, 'scale_pos_weight': 9.727487926328049}. Best is trial 68 with value: 0.7129559851463521.
# [I 2025-02-03 21:43:50,998] Trial 85 finished with value: 0.7102309960681521 and parameters: {'n_estimators': 652, 'num_leaves': 1587, 'max_depth': 185, 'learning_rate': 1.7605220116089735e-05, 'min_child_samples': 177, 'subsample': 0.7518567134326201, 'colsample_bytree': 0.9072890767033222, 'reg_alpha': 1.0398607440704646, 'reg_lambda': 0.02572455890188229, 'min_split_gain': 2.3298283180056372e-05, 'max_bin': 434, 'min_data_in_leaf': 187, 'scale_pos_weight': 9.731686561705459}. Best is trial 68 with value: 0.7129559851463521.
# [I 2025-02-03 21:43:54,281] Trial 86 finished with value: 0.6875573394495413 and parameters: {'n_estimators': 808, 'num_leaves': 1494, 'max_depth': 176, 'learning_rate': 1.2717529225569647e-05, 'min_child_samples': 168, 'subsample': 0.7028129892433668, 'colsample_bytree': 0.9339865615470406, 'reg_alpha': 0.1351594857039885, 'reg_lambda': 0.07522771490698497, 'min_split_gain': 1.9253500525750594e-05, 'max_bin': 413, 'min_data_in_leaf': 134, 'scale_pos_weight': 9.258552611334302}. Best is trial 68 with value: 0.7129559851463521.
# [I 2025-02-03 21:43:57,036] Trial 87 finished with value: 0.7014935561380516 and parameters: {'n_estimators': 950, 'num_leaves': 1095, 'max_depth': 200, 'learning_rate': 3.276754811866201e-05, 'min_child_samples': 81, 'subsample': 0.8928410864819879, 'colsample_bytree': 0.8747440518355334, 'reg_alpha': 5.214449654878697, 'reg_lambda': 0.005865421644820827, 'min_split_gain': 2.556800719787797e-05, 'max_bin': 443, 'min_data_in_leaf': 153, 'scale_pos_weight': 7.847342891405097}. Best is trial 68 with value: 0.7129559851463521.
# [I 2025-02-03 21:43:58,731] Trial 88 finished with value: 0.6956449322848406 and parameters: {'n_estimators': 614, 'num_leaves': 1313, 'max_depth': 188, 'learning_rate': 2.2108978508760888e-05, 'min_child_samples': 198, 'subsample': 0.6492841648262879, 'colsample_bytree': 0.2090255814278486, 'reg_alpha': 1.3404902186415832, 'reg_lambda': 0.002172484546795003, 'min_split_gain': 1.4034316652275403e-05, 'max_bin': 393, 'min_data_in_leaf': 157, 'scale_pos_weight': 9.101389165157576}. Best is trial 68 with value: 0.7129559851463521.
# [I 2025-02-03 21:44:09,213] Trial 89 finished with value: 0.6654789209261687 and parameters: {'n_estimators': 489, 'num_leaves': 1353, 'max_depth': 182, 'learning_rate': 1.6394775997305993e-05, 'min_child_samples': 159, 'subsample': 0.9346612505332462, 'colsample_bytree': 0.9814950538650906, 'reg_alpha': 0.693957745559122, 'reg_lambda': 0.00042614397094184166, 'min_split_gain': 4.074871601367354e-05, 'max_bin': 465, 'min_data_in_leaf': 2, 'scale_pos_weight': 8.094603399605854}. Best is trial 68 with value: 0.7129559851463521.
# ...
# [I 2025-02-03 22:06:08,379] Trial 772 finished with value: 0.7083306028833553 and parameters: {'n_estimators': 348, 'num_leaves': 967, 'max_depth': 130, 'learning_rate': 1.792632456734266e-05, 'min_child_samples': 119, 'subsample': 0.6193975642125699, 'colsample_bytree': 0.9493625513899537, 'reg_alpha': 5.380623141903111, 'reg_lambda': 0.0005716976281985004, 'min_split_gain': 0.0023878501407310106, 'max_bin': 375, 'min_data_in_leaf': 127, 'scale_pos_weight': 4.797456561165729}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:06:13,945] Trial 773 finished with value: 0.7046663390126693 and parameters: {'n_estimators': 2657, 'num_leaves': 1134, 'max_depth': 112, 'learning_rate': 1.4264251435155478e-05, 'min_child_samples': 124, 'subsample': 0.5120478330036493, 'colsample_bytree': 0.9178399697929365, 'reg_alpha': 3.6482664625821113, 'reg_lambda': 2.364451006045901e-05, 'min_split_gain': 0.0048285530080502265, 'max_bin': 416, 'min_data_in_leaf': 144, 'scale_pos_weight': 4.222701354035318}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:06:17,178] Trial 774 finished with value: 0.7056875273044998 and parameters: {'n_estimators': 1535, 'num_leaves': 1068, 'max_depth': 136, 'learning_rate': 1.7540414150665498e-05, 'min_child_samples': 135, 'subsample': 0.6430032594219384, 'colsample_bytree': 0.8773544229688707, 'reg_alpha': 7.321158121980211, 'reg_lambda': 0.00011726561234006399, 'min_split_gain': 0.002486604468332566, 'max_bin': 405, 'min_data_in_leaf': 137, 'scale_pos_weight': 8.277047081150588}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:06:20,727] Trial 775 finished with value: 0.7128440366972477 and parameters: {'n_estimators': 1688, 'num_leaves': 1030, 'max_depth': 102, 'learning_rate': 2.145276736629914e-05, 'min_child_samples': 115, 'subsample': 0.4853675730645177, 'colsample_bytree': 0.9378742827601134, 'reg_alpha': 4.5317470434430485, 'reg_lambda': 0.00025404884027903433, 'min_split_gain': 0.006624829570983417, 'max_bin': 433, 'min_data_in_leaf': 146, 'scale_pos_weight': 4.550473681321583}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:06:21,827] Trial 776 finished with value: 0.699808868501529 and parameters: {'n_estimators': 431, 'num_leaves': 1624, 'max_depth': 120, 'learning_rate': 1.4102656789512459e-05, 'min_child_samples': 110, 'subsample': 0.663840819426535, 'colsample_bytree': 0.9598353989785583, 'reg_alpha': 11.765808464147414, 'reg_lambda': 0.11799010667995448, 'min_split_gain': 0.0038740149976608344, 'max_bin': 364, 'min_data_in_leaf': 130, 'scale_pos_weight': 4.040816380450837}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:06:23,310] Trial 777 finished with value: 0.6985965487112277 and parameters: {'n_estimators': 524, 'num_leaves': 1189, 'max_depth': 126, 'learning_rate': 2.841455386252739e-05, 'min_child_samples': 127, 'subsample': 0.6036314380714116, 'colsample_bytree': 0.9069147833673832, 'reg_alpha': 2.3695129238875308, 'reg_lambda': 0.00032435760210026564, 'min_split_gain': 0.002906131800607829, 'max_bin': 384, 'min_data_in_leaf': 141, 'scale_pos_weight': 4.332429241688831}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:06:24,243] Trial 778 finished with value: 0.7052806902577545 and parameters: {'n_estimators': 334, 'num_leaves': 1097, 'max_depth': 117, 'learning_rate': 1.7181413461541016e-05, 'min_child_samples': 119, 'subsample': 0.3514498237011857, 'colsample_bytree': 0.9786250433145829, 'reg_alpha': 7.026287263696478, 'reg_lambda': 1.8036818343018652e-05, 'min_split_gain': 0.0020192296780058698, 'max_bin': 341, 'min_data_in_leaf': 135, 'scale_pos_weight': 4.851071018677791}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:06:25,860] Trial 779 finished with value: 0.6763543031891656 and parameters: {'n_estimators': 724, 'num_leaves': 1004, 'max_depth': 123, 'learning_rate': 2.218631095390251e-05, 'min_child_samples': 131, 'subsample': 0.5702545664589576, 'colsample_bytree': 0.2270834443031634, 'reg_alpha': 3.504697234779935, 'reg_lambda': 0.00018795023342484498, 'min_split_gain': 0.0037102144374594743, 'max_bin': 372, 'min_data_in_leaf': 120, 'scale_pos_weight': 2.260113656707018}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:06:29,242] Trial 780 finished with value: 0.6840050240279598 and parameters: {'n_estimators': 1817, 'num_leaves': 1151, 'max_depth': 145, 'learning_rate': 1.3026223388020276e-05, 'min_child_samples': 114, 'subsample': 0.6582225958854485, 'colsample_bytree': 0.9253747112581822, 'reg_alpha': 4.368893894003913, 'reg_lambda': 29.657354869692828, 'min_split_gain': 0.0024297498801181087, 'max_bin': 328, 'min_data_in_leaf': 146, 'scale_pos_weight': 3.5242652915788}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:06:33,698] Trial 781 finished with value: 0.6819954128440368 and parameters: {'n_estimators': 1601, 'num_leaves': 1886, 'max_depth': 130, 'learning_rate': 0.0040292426843764025, 'min_child_samples': 122, 'subsample': 0.539228376252274, 'colsample_bytree': 0.8902884689068875, 'reg_alpha': 1.5544868438459876, 'reg_lambda': 1.39550138165593e-05, 'min_split_gain': 0.0003040662554742084, 'max_bin': 361, 'min_data_in_leaf': 135, 'scale_pos_weight': 3.828203145368132}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:06:35,859] Trial 782 finished with value: 0.7076343381389254 and parameters: {'n_estimators': 978, 'num_leaves': 1054, 'max_depth': 112, 'learning_rate': 1.530392719351183e-05, 'min_child_samples': 109, 'subsample': 0.6790495427655532, 'colsample_bytree': 0.9476411314470489, 'reg_alpha': 6.1266073683831985, 'reg_lambda': 2.9049540839454597e-05, 'min_split_gain': 0.004833296707565434, 'max_bin': 386, 'min_data_in_leaf': 142, 'scale_pos_weight': 4.459137773741233}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:06:41,261] Trial 783 finished with value: 0.7019550021843599 and parameters: {'n_estimators': 2475, 'num_leaves': 1106, 'max_depth': 133, 'learning_rate': 1.927783199816407e-05, 'min_child_samples': 118, 'subsample': 0.40685019781757636, 'colsample_bytree': 0.8644726073738361, 'reg_alpha': 3.0092461427180797, 'reg_lambda': 0.0001311913807542033, 'min_split_gain': 0.010911794041475893, 'max_bin': 345, 'min_data_in_leaf': 123, 'scale_pos_weight': 5.083033055491367}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:06:42,241] Trial 784 finished with value: 0.7063319134993447 and parameters: {'n_estimators': 356, 'num_leaves': 985, 'max_depth': 121, 'learning_rate': 3.380772685772734e-05, 'min_child_samples': 113, 'subsample': 0.5852721950156072, 'colsample_bytree': 0.9105818214065656, 'reg_alpha': 9.415351204863, 'reg_lambda': 0.000397275343194075, 'min_split_gain': 0.007656034563122267, 'max_bin': 372, 'min_data_in_leaf': 127, 'scale_pos_weight': 4.156835734533632}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:06:44,741] Trial 785 finished with value: 0.7140099388379204 and parameters: {'n_estimators': 1177, 'num_leaves': 954, 'max_depth': 127, 'learning_rate': 2.2916483243926376e-05, 'min_child_samples': 123, 'subsample': 0.6336527817371874, 'colsample_bytree': 0.9623572703895974, 'reg_alpha': 4.839326719740863, 'reg_lambda': 2.3832341168389694e-05, 'min_split_gain': 0.0018972808758744727, 'max_bin': 397, 'min_data_in_leaf': 139, 'scale_pos_weight': 4.681938200180567}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:06:47,607] Trial 786 finished with value: 0.7056329183049367 and parameters: {'n_estimators': 1340, 'num_leaves': 949, 'max_depth': 125, 'learning_rate': 2.7275392453886116e-05, 'min_child_samples': 129, 'subsample': 0.6324824217588941, 'colsample_bytree': 0.9867138307799088, 'reg_alpha': 5.574086603988071, 'reg_lambda': 2.48385783854596e-05, 'min_split_gain': 0.0028199087358074864, 'max_bin': 416, 'min_data_in_leaf': 138, 'scale_pos_weight': 4.942993578169522}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:06:50,840] Trial 787 finished with value: 0.6809196155526431 and parameters: {'n_estimators': 1159, 'num_leaves': 963, 'max_depth': 117, 'learning_rate': 2.4836454986392428e-05, 'min_child_samples': 139, 'subsample': 0.6227555981647278, 'colsample_bytree': 0.9707270311976521, 'reg_alpha': 0.14785250480971657, 'reg_lambda': 2.1499032353774213e-05, 'min_split_gain': 0.0020188855375234275, 'max_bin': 408, 'min_data_in_leaf': 132, 'scale_pos_weight': 4.632490385424424}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:06:53,055] Trial 788 finished with value: 0.7034622105723023 and parameters: {'n_estimators': 1054, 'num_leaves': 962, 'max_depth': 108, 'learning_rate': 6.109771133346244e-05, 'min_child_samples': 126, 'subsample': 0.6124225228322069, 'colsample_bytree': 0.9967224198358338, 'reg_alpha': 7.8151069234482895, 'reg_lambda': 3.148720928775898e-05, 'min_split_gain': 0.003414230054944574, 'max_bin': 396, 'min_data_in_leaf': 137, 'scale_pos_weight': 4.796865912864752}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:06:55,906] Trial 789 finished with value: 0.7043523372651812 and parameters: {'n_estimators': 1115, 'num_leaves': 1012, 'max_depth': 115, 'learning_rate': 3.414435023315307e-05, 'min_child_samples': 133, 'subsample': 0.6369246425668209, 'colsample_bytree': 0.9608715958924579, 'reg_alpha': 2.094931982311939, 'reg_lambda': 1.4078035416433437e-05, 'min_split_gain': 0.0025980389133135697, 'max_bin': 401, 'min_data_in_leaf': 133, 'scale_pos_weight': 4.65383314650819}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:06:58,789] Trial 790 finished with value: 0.7091961555264308 and parameters: {'n_estimators': 1274, 'num_leaves': 961, 'max_depth': 121, 'learning_rate': 4.4093317171494255e-05, 'min_child_samples': 125, 'subsample': 0.6008628714996797, 'colsample_bytree': 0.9695104281905308, 'reg_alpha': 3.4217814846268033, 'reg_lambda': 2.7722002460903073e-05, 'min_split_gain': 0.003987853238553429, 'max_bin': 404, 'min_data_in_leaf': 140, 'scale_pos_weight': 5.406729933969851}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:07:01,372] Trial 791 finished with value: 0.712658366098733 and parameters: {'n_estimators': 1181, 'num_leaves': 926, 'max_depth': 127, 'learning_rate': 2.8419100021893068e-05, 'min_child_samples': 122, 'subsample': 0.6480709429233991, 'colsample_bytree': 0.9989163731642796, 'reg_alpha': 4.844781539586426, 'reg_lambda': 1.872218871837733e-05, 'min_split_gain': 0.0019460173554678236, 'max_bin': 393, 'min_data_in_leaf': 130, 'scale_pos_weight': 4.503505537505915}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:07:03,755] Trial 792 finished with value: 0.7013379204892967 and parameters: {'n_estimators': 931, 'num_leaves': 1002, 'max_depth': 124, 'learning_rate': 2.4380697605148473e-05, 'min_child_samples': 128, 'subsample': 0.6166160266003369, 'colsample_bytree': 0.9541833391044435, 'reg_alpha': 2.709596050911969, 'reg_lambda': 1.436163219880656e-05, 'min_split_gain': 0.004847173197230426, 'max_bin': 409, 'min_data_in_leaf': 105, 'scale_pos_weight': 5.011794112145642}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:07:06,288] Trial 793 finished with value: 0.7025884665792923 and parameters: {'n_estimators': 1201, 'num_leaves': 1039, 'max_depth': 117, 'learning_rate': 2.0980048593251367e-05, 'min_child_samples': 123, 'subsample': 0.5945456066366552, 'colsample_bytree': 0.980597092531478, 'reg_alpha': 10.85273890367105, 'reg_lambda': 2.2885913750825816e-05, 'min_split_gain': 0.005805870075130122, 'max_bin': 392, 'min_data_in_leaf': 135, 'scale_pos_weight': 4.78173272706659}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:07:09,187] Trial 794 finished with value: 0.7093435998252512 and parameters: {'n_estimators': 1258, 'num_leaves': 931, 'max_depth': 113, 'learning_rate': 2.319015543071702e-05, 'min_child_samples': 131, 'subsample': 0.5705829392250196, 'colsample_bytree': 0.9449630337574016, 'reg_alpha': 3.8996298309301984, 'reg_lambda': 3.5856550121513105e-05, 'min_split_gain': 0.0028066602956720523, 'max_bin': 419, 'min_data_in_leaf': 126, 'scale_pos_weight': 4.3592654518994145}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:07:13,437] Trial 795 finished with value: 0.7084589340323285 and parameters: {'n_estimators': 2015, 'num_leaves': 1724, 'max_depth': 129, 'learning_rate': 3.096981570476743e-05, 'min_child_samples': 121, 'subsample': 0.6300567407369195, 'colsample_bytree': 0.9671495610780003, 'reg_alpha': 5.885727402405363, 'reg_lambda': 1.7870338020072954e-05, 'min_split_gain': 0.0018594092964100864, 'max_bin': 380, 'min_data_in_leaf': 116, 'scale_pos_weight': 4.602827559349696}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:07:15,772] Trial 796 finished with value: 0.7068452380952381 and parameters: {'n_estimators': 1069, 'num_leaves': 989, 'max_depth': 99, 'learning_rate': 1.925870965862732e-05, 'min_child_samples': 125, 'subsample': 0.4606701021966553, 'colsample_bytree': 0.9427683416039544, 'reg_alpha': 7.830890443728083, 'reg_lambda': 3.249968670760081e-05, 'min_split_gain': 0.0031866365749810034, 'max_bin': 386, 'min_data_in_leaf': 142, 'scale_pos_weight': 5.154130133946956}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:07:17,824] Trial 797 finished with value: 0.7122624508519003 and parameters: {'n_estimators': 871, 'num_leaves': 1049, 'max_depth': 78, 'learning_rate': 2.5761977604849906e-05, 'min_child_samples': 118, 'subsample': 0.5908911552702761, 'colsample_bytree': 0.9604781429848378, 'reg_alpha': 4.0061587592917824, 'reg_lambda': 1.336718055647579e-05, 'min_split_gain': 0.0022826392288833905, 'max_bin': 398, 'min_data_in_leaf': 139, 'scale_pos_weight': 4.83959523812617}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:07:20,623] Trial 798 finished with value: 0.7059742245522062 and parameters: {'n_estimators': 1236, 'num_leaves': 1013, 'max_depth': 119, 'learning_rate': 3.5963828910745416e-05, 'min_child_samples': 136, 'subsample': 0.6141184524422977, 'colsample_bytree': 0.9322957291873606, 'reg_alpha': 2.8241191047958965, 'reg_lambda': 2.2572913500191083e-05, 'min_split_gain': 0.0015720411217410204, 'max_bin': 381, 'min_data_in_leaf': 131, 'scale_pos_weight': 4.417228976562206}. Best is trial 521 with value: 0.7143321319353428.
# [I 2025-02-03 22:07:23,138] Trial 799 finished with value: 0.6160850808213194 and parameters: {'n_estimators': 1338, 'num_leaves': 939, 'max_depth': 126, 'learning_rate': 1.9482557849960067e-05, 'min_child_samples': 117, 'subsample': 0.6399908824720941, 'colsample_bytree': 0.9767092327315072, 'reg_alpha': 66.01657066393904, 'reg_lambda': 1.765554342136589e-05, 'min_split_gain': 0.004338165414305057, 'max_bin': 393, 'min_data_in_leaf': 144, 'scale_pos_weight': 4.638558035677978}. Best is trial 521 with value: 0.7143321319353428.
# Best trial:
#   Value: 0.7143321319353428
#   Params:
#     n_estimators: 1565
#     num_leaves: 948
#     max_depth: 131
#     learning_rate: 2.7463618055521622e-05
#     min_child_samples: 127
#     subsample: 0.5905700691120602
#     colsample_bytree: 0.9722490063552287
#     reg_alpha: 5.016229749776295
#     reg_lambda: 1.944808219125952e-05
#     min_split_gain: 0.0018563963748571939
#     max_bin: 381
#     min_data_in_leaf: 126
#     scale_pos_weight: 4.348255852462189
#
# --- Model Performance ---
# Model Accuracy: 0.8664546899841018
# Model F1 Score: 0.0
# Model AUC: 0.713846111839231

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# 모델 초기화
DI_model = LGBMClassifier(
    n_estimators=1171,
    num_leaves=1352,
    max_depth=133,
    learning_rate=0.013047268869340142,
    min_child_samples=165,
    subsample=0.24314691590400292,
    colsample_bytree=0.19334614890476431,
    reg_alpha=5.901900488743287,
    reg_lambda=3.858355492244645e-05,
    min_split_gain=0.00045035353026440803,
    random_state=42,
    objective='binary',
    metric='auc',
    verbose=-1,
    boosting_type='gbdt'
)

# 모델 학습
DI_model.fit(DI_X_train, DI_y_train)

# 예측
y_pred = DI_model.predict(DI_X_test)
y_pred_proba = DI_model.predict_proba(DI_X_test)[:, 1]

# 평가
accuracy = accuracy_score(DI_y_test, y_pred)
f1 = f1_score(DI_y_test, y_pred)
auc = roc_auc_score(DI_y_test, y_pred_proba)
cm = confusion_matrix(DI_y_test, y_pred)

# 결과 출력
print()
print("--- Model Performance ---")
print(f"Model Accuracy: {accuracy}")
print(f"Model F1 Score: {f1}")
print(f"Model AUC: {auc}")

# 혼동 행렬 출력
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=DI_model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# --- Model Performance ---
# Model Accuracy: 0.8664546899841018
# Model F1 Score: 0.0
# Model AUC: 0.7120085190039318

# %% [markdown]
# ## 제출

# %%
# 모델 구축
# IVF_model = CatBoostClassifier(
#     iterations=680,
#     depth=10,
#     learning_rate=0.01,
#     random_seed=42,
#     verbose=0
# )

# DI_model = CatBoostClassifier(
#     iterations=500,
#     depth=10,
#     learning_rate=0.01,
#     random_seed=42,
#     verbose=0
# )

# 모델 학습 및 예측
IVF_model.fit(IVF_X, IVF_y)
IVF_pred_proba = IVF_model.predict_proba(IVF_test.drop('ID', axis=1))[:, 1]

DI_model.fit(DI_X, DI_y)
DI_pred_proba = DI_model.predict_proba(DI_test.drop('ID', axis=1))[:, 1]

# %%
# 예측 결과 병합
IVF_test['probability'] = IVF_pred_proba
DI_test['probability'] = DI_pred_proba

# 최종 제출 파일 생성
submission = pd.concat([IVF_test[['ID', 'probability']], DI_test[['ID', 'probability']]], axis=0)
submission = submission.sort_values(by='ID')  

# 제출 파일 저장
submission.to_csv('./code14_submit.csv', index=False, encoding='utf-8')

# %% [markdown]
# .
