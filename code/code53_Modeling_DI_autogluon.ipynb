# %% [markdown]
# ## 난임 환자 대상 임신 성공 여부 예측

# %% [markdown]
# ### LGAimers 6th 온라인 해커톤

# %% [markdown]
# Import

# %%
import pandas as pd
import lightgbm as lgb
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
import lightgbm as lgb
import xgboost as xgb
from catboost import CatBoostClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ### Data Load

# %%
# 데이터 로드
DI_train = pd.read_csv('../data/DI_train_dataset_53.csv')
DI_test = pd.read_csv('../data/DI_test_dataset_53.csv')

# %% [markdown]
# ### 인코딩

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
import autogluon.core as ag

train_data = TabularDataset(DI_train)
test_data = TabularDataset(DI_test)

label = '임신_성공_여부'
eval_metric = 'roc_auc'

# %%
from autogluon.tabular import TabularPredictor

# 시간 제한 설정 (예: 10분)
time_limit =  1 * 10 * 60

# # GPU를 사용할 수 없는 모델을 제외하도록 설정
# exclude_model_types = [
#     'KNN',  # K-Nearest Neighbors
#     'RF',   # Random Forest
#     'XT',   # Extra Trees
#     'LR',   # Linear Regression
#     'NN'    # Tabular Neural Network
# ]

# TabularPredictor 객체 생성 및 학습
predictor = TabularPredictor(
    label=label,
    eval_metric=eval_metric,
    path='AutogluonModels/ag-20250224_code53_DI'  # 모델 저장 경로
).fit(
    train_data,
    presets='best_quality',  # 'best_quality', 'medium_quality', 'good_quality' 등의 프리셋 설정
    # num_stack_levels=0,  # 스택 레벨 설정 / dynamic_stacking=True(디폴트)인 경우 무시
    num_bag_folds=5,  # 배깅 설정
    time_limit=time_limit,  # 시간 제한 설정
    # num_gpus=1,  # GPU 사용 설정
    # excluded_model_types=exclude_model_types  # 제외할 모델 유형 설정
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.11.8
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          16
# Memory Avail:       10.92 GB / 15.86 GB (68.9%)
# Disk Space Avail:   180.66 GB / 476.30 GB (37.9%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=5, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 150s of the 600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-02-24 22:19:58,409	INFO worker.py:1810 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 		Context path: "c:\Users\juneh\OneDrive\바탕 화면\git_Aimers6th\LG_Aimers_6th\code\AutogluonModels\ag-20250224_code53_DI\ds_sub_fit\sub_fit_ho"
# (_dystack pid=14220) Running DyStack sub-fit ...
# (_dystack pid=14220) Beginning AutoGluon training ... Time limit = 143s
# (_dystack pid=14220) AutoGluon will save models to "c:\Users\juneh\OneDrive\바탕 화면\git_Aimers6th\LG_Aimers_6th\code\AutogluonModels\ag-20250224_code53_DI\ds_sub_fit\sub_fit_ho"
# (_dystack pid=14220) Train Data Rows:    5592
# (_dystack pid=14220) Train Data Columns: 34
# (_dystack pid=14220) Label Column:       임신_성공_여부
# (_dystack pid=14220) Problem Type:       binary
# (_dystack pid=14220) Preprocessing data ...
# (_dystack pid=14220) Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# (_dystack pid=14220) Using Feature Generators to preprocess the data ...
# (_dystack pid=14220) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=14220) 	Available Memory:                    10461.17 MB
# (_dystack pid=14220) 	Train Data (Original)  Memory Usage: 1.78 MB (0.0% of available memory)
# (_dystack pid=14220) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=14220) 	Stage 1 Generators:
# (_dystack pid=14220) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=14220) 			Note: Converting 17 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=14220) 	Stage 2 Generators:
# (_dystack pid=14220) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=14220) 	Stage 3 Generators:
# (_dystack pid=14220) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=14220) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=14220) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=14220) 	Stage 4 Generators:
# (_dystack pid=14220) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=14220) 	Stage 5 Generators:
# (_dystack pid=14220) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=14220) 	Unused Original Features (Count: 1): ['ID']
# (_dystack pid=14220) 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# (_dystack pid=14220) 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# (_dystack pid=14220) 		These features do not need to be present at inference time.
# (_dystack pid=14220) 		('object', []) : 1 | ['ID']
# (_dystack pid=14220) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=14220) 		('float', []) :  5 | ['시술_당시_나이', '임신_시도_또는_마지막_임신_경과_연수', 'IVF_임신_시술_비율', 'DI_임신_시술_비율', '임신_성공률']
# (_dystack pid=14220) 		('int', [])   : 28 | ['배란_자극_여부', '남성_주_불임_원인', '남성_부_불임_원인', '여성_주_불임_원인', '여성_부_불임_원인', ...]
# (_dystack pid=14220) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=14220) 		('float', [])     :  5 | ['시술_당시_나이', '임신_시도_또는_마지막_임신_경과_연수', 'IVF_임신_시술_비율', 'DI_임신_시술_비율', '임신_성공률']
# (_dystack pid=14220) 		('int', [])       : 11 | ['총_시술_횟수', '클리닉_내_총_시술_횟수', 'IVF_시술_횟수', 'DI_시술_횟수', '총_임신_횟수', ...]
# (_dystack pid=14220) 		('int', ['bool']) : 17 | ['배란_자극_여부', '남성_주_불임_원인', '남성_부_불임_원인', '여성_주_불임_원인', '여성_부_불임_원인', ...]
# (_dystack pid=14220) 	0.1s = Fit runtime
# (_dystack pid=14220) 	33 features in original data used to generate 33 features in processed data.
# (_dystack pid=14220) 	Train Data (Processed) Memory Usage: 0.77 MB (0.0% of available memory)
# (_dystack pid=14220) Data preprocessing and feature engineering runtime = 0.14s ...
# (_dystack pid=14220) AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# (_dystack pid=14220) 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# (_dystack pid=14220) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=14220) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=14220) User-specified model hyperparameters to be fit:
# (_dystack pid=14220) {
# (_dystack pid=14220) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=14220) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# (_dystack pid=14220) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=14220) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=14220) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=14220) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=14220) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=14220) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=14220) }
# (_dystack pid=14220) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=14220) Fitting 110 L1 models, fit_strategy="sequential" ...
# (_dystack pid=14220) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 95.32s of the 143.00s of remaining time.
# (_dystack pid=14220) 	0.5772	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	0.0s	 = Training   runtime
# (_dystack pid=14220) 	0.13s	 = Validation runtime
# (_dystack pid=14220) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 93.18s of the 140.87s of remaining time.
# (_dystack pid=14220) 	0.5717	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	0.0s	 = Training   runtime
# (_dystack pid=14220) 	0.05s	 = Validation runtime
# (_dystack pid=14220) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 93.12s of the 140.80s of remaining time.
# (_dystack pid=14220) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.11%)
# (_dystack pid=14220) 	0.6696	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	0.78s	 = Training   runtime
# (_dystack pid=14220) 	0.01s	 = Validation runtime
# (_dystack pid=14220) Fitting model: LightGBM_BAG_L1 ... Training model for up to 89.32s of the 137.00s of remaining time.
# (_dystack pid=14220) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.12%)
# (_dystack pid=14220) 	0.6586	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	0.6s	 = Training   runtime
# (_dystack pid=14220) 	0.0s	 = Validation runtime
# (_dystack pid=14220) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 85.60s of the 133.28s of remaining time.
# (_dystack pid=14220) 	0.6072	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	0.71s	 = Training   runtime
# (_dystack pid=14220) 	0.19s	 = Validation runtime
# (_dystack pid=14220) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 84.62s of the 132.30s of remaining time.
# (_dystack pid=14220) 	0.6121	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	0.52s	 = Training   runtime
# (_dystack pid=14220) 	0.18s	 = Validation runtime
# (_dystack pid=14220) Fitting model: CatBoost_BAG_L1 ... Training model for up to 83.81s of the 131.50s of remaining time.
# (_dystack pid=14220) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.17%)
# (_dystack pid=14220) 	0.6759	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	2.86s	 = Training   runtime
# (_dystack pid=14220) 	0.01s	 = Validation runtime
# (_dystack pid=14220) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 77.84s of the 125.52s of remaining time.
# (_dystack pid=14220) 	0.6056	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	0.74s	 = Training   runtime
# (_dystack pid=14220) 	0.19s	 = Validation runtime
# (_dystack pid=14220) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 76.80s of the 124.48s of remaining time.
# (_dystack pid=14220) 	0.6067	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	0.54s	 = Training   runtime
# (_dystack pid=14220) 	0.2s	 = Validation runtime
# (_dystack pid=14220) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 75.95s of the 123.64s of remaining time.
# (_dystack pid=14220) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.09%)
# (_ray_fit pid=22880) No improvement since epoch 7: early stopping
# (_dystack pid=14220) 	0.6534	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	9.74s	 = Training   runtime
# (_dystack pid=14220) 	0.08s	 = Validation runtime
# (_dystack pid=14220) Fitting model: XGBoost_BAG_L1 ... Training model for up to 63.19s of the 110.87s of remaining time.
# (_dystack pid=14220) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.22%)
# (_dystack pid=14220) 	0.662	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	1.81s	 = Training   runtime
# (_dystack pid=14220) 	0.03s	 = Validation runtime
# (_dystack pid=14220) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 57.73s of the 105.41s of remaining time.
# (_dystack pid=14220) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.06%)
# (_ray_fit pid=13332) No improvement since epoch 8: early stopping [repeated 3x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (_dystack pid=14220) 	Warning: Exception caused NeuralNetTorch_BAG_L1 to fail during training... Skipping this model.
# (_dystack pid=14220) 		ray::_ray_fit() (pid=12636, ip=127.0.0.1)
# (_dystack pid=14220)   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
# (_dystack pid=14220)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=14220)     out = self._fit(**kwargs)
# (_dystack pid=14220)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
# (_dystack pid=14220)     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
# (_dystack pid=14220)                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
# (_dystack pid=14220)     dataset = self._process_train_data(
# (_dystack pid=14220)               ^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
# (_dystack pid=14220)     self.processor = create_preprocessor(
# (_dystack pid=14220)                      ^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
# (_dystack pid=14220)     return ColumnTransformer(
# (_dystack pid=14220)            ^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220) TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# (_dystack pid=14220) Detailed Traceback:
# (_dystack pid=14220) Traceback (most recent call last):
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 2106, in _train_and_save
# (_dystack pid=14220)     model = self._train_single(**model_fit_kwargs)
# (_dystack pid=14220)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1993, in _train_single
# (_dystack pid=14220)     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=14220)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=14220)     out = self._fit(**kwargs)
# (_dystack pid=14220)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 270, in _fit
# (_dystack pid=14220)     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
# (_dystack pid=14220)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 298, in _fit
# (_dystack pid=14220)     self._fit_folds(
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 724, in _fit_folds
# (_dystack pid=14220)     fold_fitting_strategy.after_all_folds_scheduled()
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 690, in after_all_folds_scheduled
# (_dystack pid=14220)     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 631, in _run_parallel
# (_dystack pid=14220)     self._process_fold_results(finished, unfinished, fold_ctx)
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 587, in _process_fold_results
# (_dystack pid=14220)     raise processed_exception
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 550, in _process_fold_results
# (_dystack pid=14220)     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
# (_dystack pid=14220)                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
# (_dystack pid=14220)     return fn(*args, **kwargs)
# (_dystack pid=14220)            ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
# (_dystack pid=14220)     return func(*args, **kwargs)
# (_dystack pid=14220)            ^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 2753, in get
# (_dystack pid=14220)     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
# (_dystack pid=14220)                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 904, in get_objects
# (_dystack pid=14220)     raise value.as_instanceof_cause()
# (_dystack pid=14220) ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=12636, ip=127.0.0.1)
# (_dystack pid=14220)   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
# (_dystack pid=14220)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=14220)     out = self._fit(**kwargs)
# (_dystack pid=14220)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
# (_dystack pid=14220)     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
# (_dystack pid=14220)                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
# (_dystack pid=14220)     dataset = self._process_train_data(
# (_dystack pid=14220)               ^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
# (_dystack pid=14220)     self.processor = create_preprocessor(
# (_dystack pid=14220)                      ^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
# (_dystack pid=14220)     return ColumnTransformer(
# (_dystack pid=14220)            ^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220) TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# (_dystack pid=14220) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 51.47s of the 99.15s of remaining time.
# (_dystack pid=14220) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.33%)
# (_dystack pid=14220) 	0.6395	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	1.15s	 = Training   runtime
# (_dystack pid=14220) 	0.02s	 = Validation runtime
# (_dystack pid=14220) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 47.09s of the 94.77s of remaining time.
# (_dystack pid=14220) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.20%)
# (_dystack pid=14220) 	0.6801	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	2.63s	 = Training   runtime
# (_dystack pid=14220) 	0.02s	 = Validation runtime
# (_dystack pid=14220) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 40.94s of the 88.63s of remaining time.
# (_dystack pid=14220) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.06%)
# (_dystack pid=14220) 	Warning: Exception caused NeuralNetTorch_r79_BAG_L1 to fail during training... Skipping this model.
# (_dystack pid=14220) 		ray::_ray_fit() (pid=23460, ip=127.0.0.1)
# (_dystack pid=14220)   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
# (_dystack pid=14220)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=14220)     out = self._fit(**kwargs)
# (_dystack pid=14220)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
# (_dystack pid=14220)     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
# (_dystack pid=14220)                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
# (_dystack pid=14220)     dataset = self._process_train_data(
# (_dystack pid=14220)               ^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
# (_dystack pid=14220)     self.processor = create_preprocessor(
# (_dystack pid=14220)                      ^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
# (_dystack pid=14220)     return ColumnTransformer(
# (_dystack pid=14220)            ^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220) TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# (_dystack pid=14220) Detailed Traceback:
# (_dystack pid=14220) Traceback (most recent call last):
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 2106, in _train_and_save
# (_dystack pid=14220)     model = self._train_single(**model_fit_kwargs)
# (_dystack pid=14220)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1993, in _train_single
# (_dystack pid=14220)     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=14220)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=14220)     out = self._fit(**kwargs)
# (_dystack pid=14220)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 270, in _fit
# (_dystack pid=14220)     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
# (_dystack pid=14220)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 298, in _fit
# (_dystack pid=14220)     self._fit_folds(
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 724, in _fit_folds
# (_dystack pid=14220)     fold_fitting_strategy.after_all_folds_scheduled()
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 690, in after_all_folds_scheduled
# (_dystack pid=14220)     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 631, in _run_parallel
# (_dystack pid=14220)     self._process_fold_results(finished, unfinished, fold_ctx)
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 587, in _process_fold_results
# (_dystack pid=14220)     raise processed_exception
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 550, in _process_fold_results
# (_dystack pid=14220)     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
# (_dystack pid=14220)                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
# (_dystack pid=14220)     return fn(*args, **kwargs)
# (_dystack pid=14220)            ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
# (_dystack pid=14220)     return func(*args, **kwargs)
# (_dystack pid=14220)            ^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 2753, in get
# (_dystack pid=14220)     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
# (_dystack pid=14220)                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 904, in get_objects
# (_dystack pid=14220)     raise value.as_instanceof_cause()
# (_dystack pid=14220) ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=23460, ip=127.0.0.1)
# (_dystack pid=14220)   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
# (_dystack pid=14220)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=14220)     out = self._fit(**kwargs)
# (_dystack pid=14220)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
# (_dystack pid=14220)     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
# (_dystack pid=14220)                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
# (_dystack pid=14220)     dataset = self._process_train_data(
# (_dystack pid=14220)               ^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
# (_dystack pid=14220)     self.processor = create_preprocessor(
# (_dystack pid=14220)                      ^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
# (_dystack pid=14220)     return ColumnTransformer(
# (_dystack pid=14220)            ^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220) TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# (_dystack pid=14220) Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 34.58s of the 82.26s of remaining time.
# (_dystack pid=14220) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.19%)
# (_dystack pid=14220) 	0.6566	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	1.1s	 = Training   runtime
# (_dystack pid=14220) 	0.05s	 = Validation runtime
# (_dystack pid=14220) Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 30.22s of the 77.91s of remaining time.
# (_dystack pid=14220) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.12%)
# (_ray_fit pid=20828) No improvement since epoch 6: early stopping
# (_dystack pid=14220) 	0.648	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	21.73s	 = Training   runtime
# (_dystack pid=14220) 	0.15s	 = Validation runtime
# (_dystack pid=14220) Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 4.98s of the 52.66s of remaining time.
# (_dystack pid=14220) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.68%)
# (_ray_fit pid=26508) 	Ran out of time, early stopping on iteration 258.
# (_ray_fit pid=23028) No improvement since epoch 20: early stopping [repeated 4x across cluster]
# (_dystack pid=14220) 	0.6709	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	4.02s	 = Training   runtime
# (_dystack pid=14220) 	0.02s	 = Validation runtime
# (_dystack pid=14220) Fitting model: WeightedEnsemble_L2 ... Training model for up to 143.02s of the 45.34s of remaining time.
# (_dystack pid=14220) 	Ensemble Weights: {'CatBoost_r177_BAG_L1': 0.72, 'NeuralNetFastAI_BAG_L1': 0.08, 'NeuralNetFastAI_r191_BAG_L1': 0.08, 'KNeighborsUnif_BAG_L1': 0.04, 'LightGBMXT_BAG_L1': 0.04, 'XGBoost_BAG_L1': 0.04}
# (_dystack pid=14220) 	0.6826	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	0.26s	 = Training   runtime
# (_dystack pid=14220) 	0.0s	 = Validation runtime
# (_dystack pid=14220) Fitting 108 L2 models, fit_strategy="sequential" ...
# (_dystack pid=14220) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 45.06s of the 45.00s of remaining time.
# (_dystack pid=14220) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.22%)
# (_dystack pid=14220) 	0.7022	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	1.4s	 = Training   runtime
# (_dystack pid=14220) 	0.03s	 = Validation runtime
# (_dystack pid=14220) Fitting model: LightGBM_BAG_L2 ... Training model for up to 40.41s of the 40.35s of remaining time.
# (_dystack pid=14220) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.21%)
# (_ray_fit pid=24560) 	Ran out of time, early stopping on iteration 256. [repeated 4x across cluster]
# (_dystack pid=14220) 	0.6855	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	1.25s	 = Training   runtime
# (_dystack pid=14220) 	0.03s	 = Validation runtime
# (_dystack pid=14220) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 36.00s of the 35.94s of remaining time.
# (_dystack pid=14220) 	0.6994	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	0.85s	 = Training   runtime
# (_dystack pid=14220) 	0.24s	 = Validation runtime
# (_dystack pid=14220) Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 34.84s of the 34.78s of remaining time.
# (_dystack pid=14220) 	0.7054	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	0.79s	 = Training   runtime
# (_dystack pid=14220) 	0.18s	 = Validation runtime
# (_dystack pid=14220) Fitting model: CatBoost_BAG_L2 ... Training model for up to 33.82s of the 33.77s of remaining time.
# (_dystack pid=14220) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.31%)
# (_dystack pid=14220) 	0.6997	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	4.9s	 = Training   runtime
# (_dystack pid=14220) 	0.04s	 = Validation runtime
# (_dystack pid=14220) Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 25.85s of the 25.79s of remaining time.
# (_dystack pid=14220) 	0.7142	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	0.71s	 = Training   runtime
# (_dystack pid=14220) 	0.2s	 = Validation runtime
# (_dystack pid=14220) Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 24.85s of the 24.79s of remaining time.
# (_dystack pid=14220) 	0.7205	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	0.56s	 = Training   runtime
# (_dystack pid=14220) 	0.2s	 = Validation runtime
# (_dystack pid=14220) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 24.02s of the 23.96s of remaining time.
# (_dystack pid=14220) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.15%)
# (_ray_fit pid=24088) No improvement since epoch 6: early stopping
# (_dystack pid=14220) 	0.6593	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	9.74s	 = Training   runtime
# (_dystack pid=14220) 	0.11s	 = Validation runtime
# (_dystack pid=14220) Fitting model: XGBoost_BAG_L2 ... Training model for up to 11.04s of the 10.98s of remaining time.
# (_dystack pid=14220) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.40%)
# (_dystack pid=14220) 	0.6894	 = Validation score   (roc_auc)
# (_dystack pid=14220) 	2.45s	 = Training   runtime
# (_dystack pid=14220) 	0.03s	 = Validation runtime
# (_dystack pid=14220) Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 5.14s of the 5.09s of remaining time.
# (_dystack pid=14220) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.12%)
# (_ray_fit pid=22696) No improvement since epoch 7: early stopping
# (_dystack pid=14220) 	Warning: Exception caused NeuralNetTorch_BAG_L2 to fail during training... Skipping this model.
# (_dystack pid=14220) 		ray::_ray_fit() (pid=15624, ip=127.0.0.1)
# (_dystack pid=14220)   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
# (_dystack pid=14220)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=14220)     out = self._fit(**kwargs)
# (_dystack pid=14220)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
# (_dystack pid=14220)     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
# (_dystack pid=14220)                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
# (_dystack pid=14220)     dataset = self._process_train_data(
# (_dystack pid=14220)               ^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
# (_dystack pid=14220)     self.processor = create_preprocessor(
# (_dystack pid=14220)                      ^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
# (_dystack pid=14220)     return ColumnTransformer(
# (_dystack pid=14220)            ^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220) TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# (_dystack pid=14220) Detailed Traceback:
# (_dystack pid=14220) Traceback (most recent call last):
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 2106, in _train_and_save
# (_dystack pid=14220)     model = self._train_single(**model_fit_kwargs)
# (_dystack pid=14220)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1993, in _train_single
# (_dystack pid=14220)     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=14220)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=14220)     out = self._fit(**kwargs)
# (_dystack pid=14220)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 270, in _fit
# (_dystack pid=14220)     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
# (_dystack pid=14220)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 298, in _fit
# (_dystack pid=14220)     self._fit_folds(
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 724, in _fit_folds
# (_dystack pid=14220)     fold_fitting_strategy.after_all_folds_scheduled()
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 690, in after_all_folds_scheduled
# (_dystack pid=14220)     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 631, in _run_parallel
# (_dystack pid=14220)     self._process_fold_results(finished, unfinished, fold_ctx)
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 587, in _process_fold_results
# (_dystack pid=14220)     raise processed_exception
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 550, in _process_fold_results
# (_dystack pid=14220)     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
# (_dystack pid=14220)                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
# (_dystack pid=14220)     return fn(*args, **kwargs)
# (_dystack pid=14220)            ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
# (_dystack pid=14220)     return func(*args, **kwargs)
# (_dystack pid=14220)            ^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 2753, in get
# (_dystack pid=14220)     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
# (_dystack pid=14220)                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 904, in get_objects
# (_dystack pid=14220)     raise value.as_instanceof_cause()
# (_dystack pid=14220) ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=15624, ip=127.0.0.1)
# (_dystack pid=14220)   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
# (_dystack pid=14220)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=14220)     out = self._fit(**kwargs)
# (_dystack pid=14220)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
# (_dystack pid=14220)     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
# (_dystack pid=14220)                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
# (_dystack pid=14220)     dataset = self._process_train_data(
# (_dystack pid=14220)               ^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
# (_dystack pid=14220)     self.processor = create_preprocessor(
# (_dystack pid=14220)                      ^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=14220)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
# (_dystack pid=14220)     return ColumnTransformer(
# (_dystack pid=14220)            ^^^^^^^^^^^^^^^^^^
# ...
#     model = self._train_single(**model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1993, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 270, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 298, in _fit
#     self._fit_folds(
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 724, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 690, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 631, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 587, in _process_fold_results
#     raise processed_exception
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 550, in _process_fold_results
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
#                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 2753, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 904, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=7064, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
#     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# Fitting model: CatBoost_r49_BAG_L1 ... Training model for up to 53.22s of the 53.22s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.46%)
# 	0.6877	 = Validation score   (roc_auc)
# 	3.92s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTrees_r49_BAG_L1 ... Training model for up to 47.44s of the 47.43s of remaining time.
# 	0.6142	 = Validation score   (roc_auc)
# 	0.74s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: LightGBM_r143_BAG_L1 ... Training model for up to 46.37s of the 46.37s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=1.91%)
# 	0.6572	 = Validation score   (roc_auc)
# 	4.3s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForest_r127_BAG_L1 ... Training model for up to 39.79s of the 39.79s of remaining time.
# 	0.6524	 = Validation score   (roc_auc)
# 	1.31s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r134_BAG_L1 ... Training model for up to 38.19s of the 38.19s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.61%)
# 	0.6577	 = Validation score   (roc_auc)
# 	22.17s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: RandomForest_r34_BAG_L1 ... Training model for up to 13.42s of the 13.41s of remaining time.
# 	0.6787	 = Validation score   (roc_auc)
# 	0.75s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: LightGBM_r94_BAG_L1 ... Training model for up to 12.44s of the 12.44s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.34%)
# 	0.6804	 = Validation score   (roc_auc)
# 	2.01s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_r143_BAG_L1 ... Training model for up to 7.97s of the 7.96s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=0.18%)
# 	Warning: Exception caused NeuralNetTorch_r143_BAG_L1 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=23536, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
#     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 2106, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1993, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 270, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 298, in _fit
#     self._fit_folds(
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 724, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 690, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 631, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 587, in _process_fold_results
#     raise processed_exception
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 550, in _process_fold_results
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
#                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 2753, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 904, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=23536, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
#     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 2.38s of remaining time.
# 	Ensemble Weights: {'CatBoost_r177_BAG_L1': 0.36, 'CatBoost_r69_BAG_L1': 0.2, 'NeuralNetFastAI_r37_BAG_L1': 0.2, 'CatBoost_r49_BAG_L1': 0.08, 'ExtraTreesEntr_BAG_L1': 0.04, 'XGBoost_BAG_L1': 0.04, 'XGBoost_r194_BAG_L1': 0.04, 'RandomForest_r34_BAG_L1': 0.04}
# 	0.6918	 = Validation score   (roc_auc)
# 	0.35s	 = Training   runtime
# 	0.02s	 = Validation runtime
# AutoGluon training complete, total runtime = 439.56s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 4154.6 rows/s (1259 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("c:\Users\juneh\OneDrive\바탕 화면\git_Aimers6th\LG_Aimers_6th\code\AutogluonModels\ag-20250224_code53_DI")

# %%
print(predictor.leaderboard(silent = True))
# Out:
#                           model  score_val eval_metric  pred_time_val  \
# 0           WeightedEnsemble_L2   0.691777     roc_auc       0.614007
# 1          CatBoost_r177_BAG_L1   0.689050     roc_auc       0.002189
# 2           CatBoost_r69_BAG_L1   0.688045     roc_auc       0.001308
# 3           CatBoost_r49_BAG_L1   0.687652     roc_auc       0.017584
# 4               CatBoost_BAG_L1   0.686800     roc_auc       0.001079
# 5          CatBoost_r137_BAG_L1   0.686780     roc_auc       0.000000
# 6           CatBoost_r13_BAG_L1   0.686107     roc_auc       0.015631
# 7          CatBoost_r167_BAG_L1   0.685641     roc_auc       0.013370
# 8           CatBoost_r50_BAG_L1   0.685313     roc_auc       0.015630
# 9           CatBoost_r86_BAG_L1   0.684506     roc_auc       0.011335
# 10          CatBoost_r70_BAG_L1   0.684354     roc_auc       0.031250
# 11          LightGBM_r96_BAG_L1   0.682481     roc_auc       0.067323
# 12          LightGBM_r15_BAG_L1   0.682022     roc_auc       0.020171
# 13           CatBoost_r9_BAG_L1   0.681304     roc_auc       0.031250
# 14          LightGBM_r94_BAG_L1   0.680365     roc_auc       0.032266
# 15           XGBoost_r89_BAG_L1   0.679573     roc_auc       0.023240
# 16         LightGBM_r130_BAG_L1   0.679398     roc_auc       0.000000
# 17      RandomForest_r34_BAG_L1   0.678682     roc_auc       0.168787
# 18            LightGBMXT_BAG_L1   0.678676     roc_auc       0.015629
# 19  NeuralNetFastAI_r143_BAG_L1   0.678129     roc_auc       0.084424
# 20              LightGBM_BAG_L1   0.675793     roc_auc       0.017009
# 21         LightGBM_r131_BAG_L1   0.673645     roc_auc       0.050946
# 22               XGBoost_BAG_L1   0.673507     roc_auc       0.025462
# 23          XGBoost_r194_BAG_L1   0.672453     roc_auc       0.066587
# 24   NeuralNetFastAI_r37_BAG_L1   0.671857     roc_auc       0.112102
# 25  NeuralNetFastAI_r103_BAG_L1   0.671133     roc_auc       0.134013
# 26         LightGBM_r196_BAG_L1   0.670248     roc_auc       0.164409
# 27   NeuralNetFastAI_r11_BAG_L1   0.665429     roc_auc       0.427078
# 28         LightGBM_r188_BAG_L1   0.665262     roc_auc       0.015630
# 29           XGBoost_r33_BAG_L1   0.665219     roc_auc       0.068577
# 30  NeuralNetFastAI_r134_BAG_L1   0.657746     roc_auc       0.152681
# 31  NeuralNetFastAI_r191_BAG_L1   0.657505     roc_auc       0.183556
# 32         LightGBM_r143_BAG_L1   0.657189     roc_auc       0.031251
# 33         LightGBMLarge_BAG_L1   0.656140     roc_auc       0.015626
# 34   NeuralNetFastAI_r95_BAG_L1   0.655714     roc_auc       0.214900
# 35         LightGBM_r161_BAG_L1   0.655514     roc_auc       0.058472
# 36       ExtraTrees_r172_BAG_L1   0.654803     roc_auc       0.201343
# 37       NeuralNetFastAI_BAG_L1   0.654651     roc_auc       0.099488
# 38     RandomForest_r127_BAG_L1   0.652381     roc_auc       0.185899
# 39  NeuralNetFastAI_r156_BAG_L1   0.652116     roc_auc       0.069952
# 40  NeuralNetFastAI_r145_BAG_L1   0.650064     roc_auc       0.140634
# 41  NeuralNetFastAI_r102_BAG_L1   0.647374     roc_auc       0.061707
# 42      RandomForest_r39_BAG_L1   0.638000     roc_auc       0.194934
# 43        ExtraTrees_r42_BAG_L1   0.622599     roc_auc       0.255011
# 44     RandomForest_r195_BAG_L1   0.621930     roc_auc       0.196445
# 45      RandomForestEntr_BAG_L1   0.621230     roc_auc       0.232096
# 46      RandomForestGini_BAG_L1   0.619015     roc_auc       0.211957
# 47        ExtraTreesEntr_BAG_L1   0.614413     roc_auc       0.204362
# 48        ExtraTreesGini_BAG_L1   0.614236     roc_auc       0.207729
# 49        ExtraTrees_r49_BAG_L1   0.614236     roc_auc       0.219318
# 50           XGBoost_r98_BAG_L1   0.581546     roc_auc       0.069280
# 51        KNeighborsUnif_BAG_L1   0.575343     roc_auc       0.264029
# 52        KNeighborsDist_BAG_L1   0.573841     roc_auc       0.047311
#
#      fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0   32.312487                0.015625           0.349788            2
# 1    3.824315                0.002189           3.824315            1
# 2    4.187949                0.001308           4.187949            1
# 3    3.917890                0.017584           3.917890            1
# 4    4.017346                0.001079           4.017346            1
# 5    3.811930                0.000000           3.811930            1
# 6    6.527470                0.015631           6.527470            1
# 7    4.215165                0.013370           4.215165            1
# 8    3.981299                0.015630           3.981299            1
# 9    5.921314                0.011335           5.921314            1
# 10   5.200755                0.031250           5.200755            1
# 11   2.549087                0.067323           2.549087            1
# 12   2.053003                0.020171           2.053003            1
# 13   7.906738                0.031250           7.906738            1
# 14   2.014009                0.032266           2.014009            1
# 15   2.931270                0.023240           2.931270            1
# 16   2.184360                0.000000           2.184360            1
# 17   0.748319                0.168787           0.748319            1
# 18   0.769895                0.015629           0.769895            1
# 19   8.736063                0.084424           8.736063            1
# 20   1.982937                0.017009           1.982937            1
# 21   2.586444                0.050946           2.586444            1
# 22   2.919722                0.025462           2.919722            1
# 23   3.300046                0.066587           3.300046            1
# 24  12.473017                0.112102          12.473017            1
# 25  16.843901                0.134013          16.843901            1
# 26   5.045661                0.164409           5.045661            1
# 27  30.828884                0.427078          30.828884            1
# 28   2.583214                0.015630           2.583214            1
# 29   3.983293                0.068577           3.983293            1
# 30  22.168254                0.152681          22.168254            1
# 31  24.947190                0.183556          24.947190            1
# 32   4.295583                0.031251           4.295583            1
# 33   2.582983                0.015626           2.582983            1
# 34  23.182112                0.214900          23.182112            1
# 35   3.528711                0.058472           3.528711            1
# 36   0.800066                0.201343           0.800066            1
# 37  11.202811                0.099488          11.202811            1
# 38   1.314233                0.185899           1.314233            1
# 39   7.961097                0.069952           7.961097            1
# 40  20.769205                0.140634          20.769205            1
# 41   7.148693                0.061707           7.148693            1
# 42   0.947591                0.194934           0.947591            1
# 43   1.022446                0.255011           1.022446            1
# 44   0.910035                0.196445           0.910035            1
# 45   0.680141                0.232096           0.680141            1
# 46   0.793810                0.211957           0.793810            1
# 47   0.591441                0.204362           0.591441            1
# 48   0.688206                0.207729           0.688206            1
# 49   0.740936                0.219318           0.740936            1
# 50   2.676086                0.069280           2.676086            1
# 51   0.000000                0.264029           0.000000            1
# 52   0.021116                0.047311           0.021116            1
#
#     can_infer  fit_order
# 0        True         53
# 1        True         13
# 2        True         32
# 3        True         46
# 4        True          7
# 5        True         20
# 6        True         22
# 7        True         40
# 8        True         28
# 9        True         44
# 10       True         36
# 11       True         17
# 12       True         43
# 13       True         16
# 14       True         52
# 15       True         26
# 16       True         27
# 17       True         51
# 18       True          3
# 19       True         35
# 20       True          4
# 21       True         14
# 22       True         11
# 23       True         30
# 24       True         45
# 25       True         33
# 26       True         38
# 27       True         29
# 28       True         24
# 29       True         18
# 30       True         50
# 31       True         15
# 32       True         48
# 33       True         12
# 34       True         41
# 35       True         34
# 36       True         31
# 37       True         10
# 38       True         49
# 39       True         37
# 40       True         25
# 41       True         21
# 42       True         39
# 43       True         19
# 44       True         23
# 45       True          6
# 46       True          5
# 47       True          9
# 48       True          8
# 49       True         47
# 50       True         42
# 51       True          1
# 52       True          2

# %%
# predictor.feature_importance(train_data)

# %%
# 최적의 모델 가져오기
model_to_use = predictor.model_best

# 확률 예측
prob_predictions = predictor.predict_proba(test_data, model=model_to_use)

# %%
# 예측 결과를 test_data에 추가
test_data['probability'] = prob_predictions.iloc[:, 1]

# 최종 제출 파일 생성
submission = test_data[['ID', 'probability']]
submission = submission.sort_values(by='ID')

# 제출 파일 저장
submission.to_csv('../submission/code53_DI_lgbm.csv', index=False, encoding='utf-8')

# 예측 결과 확인
print(submission.head())
# Out:
#            ID  probability
# 0  TEST_00026     0.132956
# 1  TEST_00051     0.198429
# 2  TEST_00076     0.023503
# 3  TEST_00088     0.132904
# 4  TEST_00100     0.105105
# 2025-02-24 22:30:17,260	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-02-24 22:30:17,260	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-02-24 22:30:17,260	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.

# %%
import pandas as pd

# 첫 번째 제출 파일 읽기
submission_ivf = pd.read_csv('../submission/code53_IVF_lgbm.csv')
submission_di = pd.read_csv('../submission/code53_DI_lgbm.csv')

# 두 데이터프레임 병합 (ID를 기준으로)
merged_submission = pd.concat([submission_ivf, submission_di]).sort_values(by='ID')

# 병합된 데이터프레임 저장
merged_submission.to_csv('../submission/code53_merged_lgbm.csv', index=False, encoding='utf-8')

# 예측 결과 확인
print(merged_submission.head())
# Out:
#            ID  probability
# 0  TEST_00000     0.001028
# 1  TEST_00001     0.000996
# 2  TEST_00002     0.144262
# 3  TEST_00003     0.083543
# 4  TEST_00004     0.451441
# 2025-02-24 22:30:32,791	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-02-24 22:30:32,791	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-02-24 22:31:24,104	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-02-24 22:31:24,104	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 2025-02-24 22:31:24,104	ERROR worker.py:422 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.

# %% [markdown]
# 데이콘 PUBLIC 0.7364224587

# %%
import pandas as pd

# 첫 번째 제출 파일 읽기
submission_ivf = pd.read_csv('../submission/code53_IVF_lgbm.csv')
submission_di = pd.read_csv('../submission/code53_DI_lgbm.csv')

# %%
submission_ivf.describe()
# Out:
#         probability
# count  87891.000000
# mean       0.259847
# std        0.163363
# min        0.000577
# 25%        0.142820
# 50%        0.271060
# 75%        0.382169
# max        0.790706

# %%
submission_di.describe()
# Out:
#        probability
# count  2176.000000
# mean      0.129465
# std       0.068597
# min       0.015006
# 25%       0.080296
# 50%       0.124530
# 75%       0.167702
# max       0.379589

# %% [markdown]
# ----

# %% [markdown]
# .
