# %% [markdown]
# ## 난임 환자 대상 임신 성공 여부 예측

# %% [markdown]
# ### LGAimers 6th 온라인 해커톤

# %% [markdown]
# Import

# %%
import pandas as pd
import lightgbm as lgb
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### Data Load

# %%
# 데이터 로드
IVF_train = pd.read_csv('../data/IVF_train_dataset.csv')
IVF_test = pd.read_csv('../data/IVF_test_dataset.csv')

DI_train = pd.read_csv('../data/DI_train_dataset.csv')
DI_test = pd.read_csv('../data/DI_test_dataset.csv')

# %%
# ID 열을 제외한 특성과 타겟 변수 분리
IVF_X = IVF_train.drop(['임신_성공_여부', 'ID'], axis=1)
IVF_y = IVF_train['임신_성공_여부']

DI_X = DI_train.drop(['임신_성공_여부', 'ID'], axis=1)
DI_y = DI_train['임신_성공_여부']

# %% [markdown]
# ### 인코딩

# %%
IVF_categorical_columns = [
    "시술_시기_코드",
    "시술_당시_나이",
    "임신_시도_또는_마지막_임신_경과_연수",
    "배란_유도_유형",
    "착상_전_유전_검사_사용_여부",
    "남성_주_불임_원인",
    "남성_부_불임_원인",
    "여성_주_불임_원인",
    "여성_부_불임_원인",
    "부부_주_불임_원인",
    "부부_부_불임_원인",
    "불명확_불임_원인",
    "불임_원인_-_난관_질환",
    "불임_원인_-_남성_요인",
    "불임_원인_-_배란_장애",
    "불임_원인_-_여성_요인",
    "불임_원인_-_자궁경부_문제",
    "불임_원인_-_자궁내막증",
    "불임_원인_-_정자_농도",
    "불임_원인_-_정자_면역학적_요인",
    "불임_원인_-_정자_운동성",
    "불임_원인_-_정자_형태",
    "총_시술_횟수",
    "클리닉_내_총_시술_횟수",
    "IVF_시술_횟수",
    "DI_시술_횟수",
    "총_임신_횟수",
    "IVF_임신_횟수",
    "DI_임신_횟수",
    "총_출산_횟수",
    "IVF_출산_횟수",
    "DI_출산_횟수",
    "난자_출처",
    "정자_출처",
    "난자_기증자_나이",
    "정자_기증자_나이",
    "PGD_시술_여부",
    "PGS_시술_여부",
    "난자_채취_경과일",
    "난자_해동_경과일",
    "난자_혼합_경과일",
    "배아_이식_경과일",
    "배아_해동_경과일",
    "변환된_특정_시술_유형"
]

# %%
DI_categorical_columns = [
    "시술_시기_코드",
    "시술_당시_나이",
    "임신_시도_또는_마지막_임신_경과_연수",
    "총_시술_횟수",
    "클리닉_내_총_시술_횟수",
    "IVF_시술_횟수",
    "DI_시술_횟수",
    "총_임신_횟수",
    "IVF_임신_횟수",
    "DI_임신_횟수",
    "총_출산_횟수",
    "IVF_출산_횟수",
    "DI_출산_횟수",
    "정자_기증자_나이",
    "변환된_특정_시술_유형"
]

# %%
# 모든 범주형 변수를 문자열로 변환
IVF_X[IVF_categorical_columns] = IVF_X[IVF_categorical_columns].astype(str)
DI_X[DI_categorical_columns] = DI_X[DI_categorical_columns].astype(str)
IVF_test[IVF_categorical_columns] = IVF_test[IVF_categorical_columns].astype(str)
DI_test[DI_categorical_columns] = DI_test[DI_categorical_columns].astype(str)

# OrdinalEncoder를 사용하여 범주형 변수 인코딩
IVF_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
DI_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

IVF_X[IVF_categorical_columns] = IVF_encoder.fit_transform(IVF_X[IVF_categorical_columns])
DI_X[DI_categorical_columns] = DI_encoder.fit_transform(DI_X[DI_categorical_columns])
IVF_test[IVF_categorical_columns] = IVF_encoder.transform(IVF_test[IVF_categorical_columns])
DI_test[DI_categorical_columns] = DI_encoder.transform(DI_test[DI_categorical_columns])

# %%
# import category_encoders as ce

# # 모든 범주형 변수를 문자열로 변환
# IVF_X[IVF_categorical_columns] = IVF_X[IVF_categorical_columns].astype(str)
# DI_X[DI_categorical_columns] = DI_X[DI_categorical_columns].astype(str)
# IVF_test[IVF_categorical_columns] = IVF_test[IVF_categorical_columns].astype(str)
# DI_test[DI_categorical_columns] = DI_test[DI_categorical_columns].astype(str)

# # 타겟 인코더를 사용하여 범주형 변수 인코딩
# IVF_target_encoder = ce.TargetEncoder(cols=IVF_categorical_columns)
# DI_target_encoder = ce.TargetEncoder(cols=DI_categorical_columns)

# # 타겟 인코딩을 위해 타겟 변수가 필요합니다. 예시로 IVF_y와 DI_y를 사용합니다.
# IVF_X[IVF_categorical_columns] = IVF_target_encoder.fit_transform(IVF_X[IVF_categorical_columns], IVF_y)
# DI_X[DI_categorical_columns] = DI_target_encoder.fit_transform(DI_X[DI_categorical_columns], DI_y)
# IVF_test[IVF_categorical_columns] = IVF_target_encoder.transform(IVF_test[IVF_categorical_columns])
# DI_test[DI_categorical_columns] = DI_target_encoder.transform(DI_test[DI_categorical_columns])

# %% [markdown]
# ## Modeling

# %%
# 데이터 분할
IVF_X_train, IVF_X_test, IVF_y_train, IVF_y_test = train_test_split(IVF_X, IVF_y, test_size=0.2, random_state=42)
DI_X_train, DI_X_test, DI_y_train, DI_y_test = train_test_split(DI_X, DI_y, test_size=0.2, random_state=42)

# %% [markdown]
# ### DI 데이터

# %%
import optuna
import lightgbm as lgb
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
import optuna
import lightgbm as lgb
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# 목적 함수 정의
def objective(trial):
    param = {
        'objective': 'binary',
        'metric': 'auc',
        'verbose': -1,
        'boosting_type': 'goss',
        'n_estimators': trial.suggest_int('n_estimators', 100, 3000),
        'num_leaves': trial.suggest_int('num_leaves', 10, 2048),
        'max_depth': trial.suggest_int('max_depth', 5, 200),
        'learning_rate': trial.suggest_float('learning_rate', 1e-5, 1e-1, log=True),
        'min_child_samples': trial.suggest_int('min_child_samples', 1, 200),
        'subsample': trial.suggest_float('subsample', 0.1, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.1, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-5, 1e2, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-5, 1e2, log=True),
        'min_split_gain': trial.suggest_float('min_split_gain', 1e-5, 1e1, log=True),
        'random_state': 42,
    }

    model = lgb.LGBMClassifier(**param)
    model.fit(DI_X_train, DI_y_train, eval_set=[(DI_X_test, DI_y_test)])
    
    y_pred_proba = model.predict_proba(DI_X_test)[:, 1]
    auc = roc_auc_score(DI_y_test, y_pred_proba)
    
    return auc

# Optuna 스터디 생성 및 최적화
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=800)

# 최적의 하이퍼파라미터 출력
print("Best trial:")
trial = study.best_trial
print("  Value: {}".format(trial.value))
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))

# 최적의 하이퍼파라미터로 모델 학습
best_params = trial.params
DI_model = lgb.LGBMClassifier(**best_params)
DI_model.fit(DI_X_train, DI_y_train)

# 예측
y_pred = DI_model.predict(DI_X_test)
y_pred_proba = DI_model.predict_proba(DI_X_test)[:, 1]

# 평가
accuracy = accuracy_score(DI_y_test, y_pred)
f1 = f1_score(DI_y_test, y_pred)
auc = roc_auc_score(DI_y_test, y_pred_proba)
cm = confusion_matrix(DI_y_test, y_pred)

# 결과 출력
print()
print("--- Model Performance ---")
print(f"Model Accuracy: {accuracy}")
print(f"Model F1 Score: {f1}")
print(f"Model AUC: {auc}")

# 혼동 행렬 출력
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=DI_model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# [I 2025-02-03 21:25:22,317] A new study created in memory with name: no-name-0346f4b0-f81c-4181-a6a9-39620b2cf8e5
# [I 2025-02-03 21:25:29,550] Trial 0 finished with value: 0.6342726081258191 and parameters: {'n_estimators': 2893, 'num_leaves': 879, 'max_depth': 13, 'learning_rate': 0.037915310625704045, 'min_child_samples': 50, 'subsample': 0.2950429901478345, 'colsample_bytree': 0.7431909601207684, 'reg_alpha': 0.056108047717512134, 'reg_lambda': 0.01773496657787598, 'min_split_gain': 2.0071657869779497e-05}. Best is trial 0 with value: 0.6342726081258191.
# [I 2025-02-03 21:25:32,199] Trial 1 finished with value: 0.7102064220183486 and parameters: {'n_estimators': 1484, 'num_leaves': 191, 'max_depth': 139, 'learning_rate': 0.019829104394649064, 'min_child_samples': 50, 'subsample': 0.2220612845311788, 'colsample_bytree': 0.3091009104404655, 'reg_alpha': 15.232143522022305, 'reg_lambda': 0.593241097004056, 'min_split_gain': 0.00036921775503952594}. Best is trial 1 with value: 0.7102064220183486.
# [I 2025-02-03 21:25:35,675] Trial 2 finished with value: 0.6853811708169506 and parameters: {'n_estimators': 1880, 'num_leaves': 1469, 'max_depth': 91, 'learning_rate': 0.08926921463808617, 'min_child_samples': 105, 'subsample': 0.4985968094605626, 'colsample_bytree': 0.41932064919730816, 'reg_alpha': 0.07993903031259524, 'reg_lambda': 0.006660786234750549, 'min_split_gain': 1.8406115145654502}. Best is trial 1 with value: 0.7102064220183486.
# [I 2025-02-03 21:25:36,149] Trial 3 finished with value: 0.6675704456094365 and parameters: {'n_estimators': 198, 'num_leaves': 676, 'max_depth': 197, 'learning_rate': 0.0024136142476121445, 'min_child_samples': 148, 'subsample': 0.14333952315200807, 'colsample_bytree': 0.2516017754978806, 'reg_alpha': 4.458498951692154, 'reg_lambda': 2.608768715714628, 'min_split_gain': 1.0991215361197484}. Best is trial 1 with value: 0.7102064220183486.
# [I 2025-02-03 21:25:38,369] Trial 4 finished with value: 0.7032519659239842 and parameters: {'n_estimators': 1391, 'num_leaves': 36, 'max_depth': 171, 'learning_rate': 0.018175979097178812, 'min_child_samples': 123, 'subsample': 0.516217233873092, 'colsample_bytree': 0.798533351053992, 'reg_alpha': 19.214455120516746, 'reg_lambda': 0.347372027829887, 'min_split_gain': 3.1789104021657337}. Best is trial 1 with value: 0.7102064220183486.
# [I 2025-02-03 21:25:39,682] Trial 5 finished with value: 0.6777195281782439 and parameters: {'n_estimators': 445, 'num_leaves': 843, 'max_depth': 54, 'learning_rate': 0.0003574275580462654, 'min_child_samples': 73, 'subsample': 0.4580828141910266, 'colsample_bytree': 0.9415120503236127, 'reg_alpha': 2.1817963650658447e-05, 'reg_lambda': 0.006850476288141128, 'min_split_gain': 0.14492220635082084}. Best is trial 1 with value: 0.7102064220183486.
# [I 2025-02-03 21:25:40,676] Trial 6 finished with value: 0.6932994757536043 and parameters: {'n_estimators': 549, 'num_leaves': 1206, 'max_depth': 40, 'learning_rate': 0.0028202804526935702, 'min_child_samples': 164, 'subsample': 0.3970923310520147, 'colsample_bytree': 0.7568214411400229, 'reg_alpha': 18.94188230700096, 'reg_lambda': 0.2922013935474404, 'min_split_gain': 0.6609257034864278}. Best is trial 1 with value: 0.7102064220183486.
# [I 2025-02-03 21:25:42,369] Trial 7 finished with value: 0.6881143512450852 and parameters: {'n_estimators': 814, 'num_leaves': 1235, 'max_depth': 114, 'learning_rate': 0.0001081159952651377, 'min_child_samples': 125, 'subsample': 0.5633826187351334, 'colsample_bytree': 0.44581129545794407, 'reg_alpha': 0.0915056025599331, 'reg_lambda': 0.0018662882034420187, 'min_split_gain': 1.3592341671423358}. Best is trial 1 with value: 0.7102064220183486.
# [I 2025-02-03 21:25:48,686] Trial 8 finished with value: 0.6934660332022717 and parameters: {'n_estimators': 2785, 'num_leaves': 1692, 'max_depth': 23, 'learning_rate': 0.0003681854313541123, 'min_child_samples': 167, 'subsample': 0.7028671426323624, 'colsample_bytree': 0.8363637988107179, 'reg_alpha': 5.4392337197291116e-05, 'reg_lambda': 0.0737651672796071, 'min_split_gain': 0.07799771636053626}. Best is trial 1 with value: 0.7102064220183486.
# [I 2025-02-03 21:25:54,254] Trial 9 finished with value: 0.698410878112713 and parameters: {'n_estimators': 2683, 'num_leaves': 1830, 'max_depth': 64, 'learning_rate': 0.0016171652367637727, 'min_child_samples': 151, 'subsample': 0.21615995272771701, 'colsample_bytree': 0.711851237730807, 'reg_alpha': 0.00011617879116072317, 'reg_lambda': 0.0035802119882946673, 'min_split_gain': 0.0005352451533100316}. Best is trial 1 with value: 0.7102064220183486.
# [I 2025-02-03 21:25:58,334] Trial 10 finished with value: 0.6945937090432502 and parameters: {'n_estimators': 1912, 'num_leaves': 57, 'max_depth': 140, 'learning_rate': 0.012072031804815331, 'min_child_samples': 3, 'subsample': 0.9740593791738985, 'colsample_bytree': 0.12393933298584825, 'reg_alpha': 0.0014588794097066837, 'reg_lambda': 1.344094602426549e-05, 'min_split_gain': 0.0015362845970225553}. Best is trial 1 with value: 0.7102064220183486.
# [I 2025-02-03 21:26:00,363] Trial 11 finished with value: 0.6844337046745304 and parameters: {'n_estimators': 1231, 'num_leaves': 48, 'max_depth': 174, 'learning_rate': 1.2571843645196537e-05, 'min_child_samples': 55, 'subsample': 0.7264065440045663, 'colsample_bytree': 0.5414293715133187, 'reg_alpha': 92.09550106616922, 'reg_lambda': 65.62072746104418, 'min_split_gain': 8.902349429828304e-05}. Best is trial 1 with value: 0.7102064220183486.
# [I 2025-02-03 21:26:02,803] Trial 12 finished with value: 0.7022553516819572 and parameters: {'n_estimators': 1357, 'num_leaves': 411, 'max_depth': 149, 'learning_rate': 0.014511212394587528, 'min_child_samples': 200, 'subsample': 0.3207434760254494, 'colsample_bytree': 0.2976667477974996, 'reg_alpha': 1.9082163516336434, 'reg_lambda': 3.201066299520451, 'min_split_gain': 0.005700754748981684}. Best is trial 1 with value: 0.7102064220183486.
# [I 2025-02-03 21:26:05,932] Trial 13 finished with value: 0.7110828964613368 and parameters: {'n_estimators': 1947, 'num_leaves': 403, 'max_depth': 147, 'learning_rate': 0.018583641561640257, 'min_child_samples': 9, 'subsample': 0.10264701713989316, 'colsample_bytree': 0.5844140905992485, 'reg_alpha': 0.8331438343003049, 'reg_lambda': 0.9519769254537314, 'min_split_gain': 9.255278903132957}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:26:10,679] Trial 14 finished with value: 0.7007044560943644 and parameters: {'n_estimators': 2136, 'num_leaves': 441, 'max_depth': 113, 'learning_rate': 0.006646755218109615, 'min_child_samples': 4, 'subsample': 0.11216799223313814, 'colsample_bytree': 0.6036784614101369, 'reg_alpha': 0.7629895330287517, 'reg_lambda': 83.58626258950503, 'min_split_gain': 0.03557474940766176}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:26:15,831] Trial 15 finished with value: 0.6475753604193971 and parameters: {'n_estimators': 2301, 'num_leaves': 403, 'max_depth': 138, 'learning_rate': 0.08540032951827595, 'min_child_samples': 28, 'subsample': 0.24016141496939375, 'colsample_bytree': 0.3746091696093487, 'reg_alpha': 0.005407065160395216, 'reg_lambda': 9.464405899658448, 'min_split_gain': 0.00041202810463261794}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:26:18,605] Trial 16 finished with value: 0.6876310615989516 and parameters: {'n_estimators': 1022, 'num_leaves': 589, 'max_depth': 83, 'learning_rate': 0.006176119181961375, 'min_child_samples': 30, 'subsample': 0.17267707113117226, 'colsample_bytree': 0.5830079471898085, 'reg_alpha': 0.5370214768684324, 'reg_lambda': 0.00018782905720426612, 'min_split_gain': 0.008617235723271232}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:26:21,336] Trial 17 finished with value: 0.6842016164263871 and parameters: {'n_estimators': 1680, 'num_leaves': 266, 'max_depth': 159, 'learning_rate': 0.000598247161861319, 'min_child_samples': 81, 'subsample': 0.10304978770670276, 'colsample_bytree': 0.14080928772592002, 'reg_alpha': 78.38311964139709, 'reg_lambda': 0.42404869495739284, 'min_split_gain': 1.0673578748733802e-05}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:26:29,929] Trial 18 finished with value: 0.6714613368283092 and parameters: {'n_estimators': 2452, 'num_leaves': 2047, 'max_depth': 194, 'learning_rate': 0.03467154395987283, 'min_child_samples': 29, 'subsample': 0.3614589241639601, 'colsample_bytree': 0.5080275457232665, 'reg_alpha': 5.8245069622055246, 'reg_lambda': 10.24924340977645, 'min_split_gain': 0.0001313520453362695}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:26:33,121] Trial 19 finished with value: 0.6870412844036697 and parameters: {'n_estimators': 1691, 'num_leaves': 265, 'max_depth': 125, 'learning_rate': 7.845669301488397e-05, 'min_child_samples': 55, 'subsample': 0.2554704754163002, 'colsample_bytree': 0.6529464485858565, 'reg_alpha': 0.010732723321668412, 'reg_lambda': 0.09224773447904185, 'min_split_gain': 9.819429760301754}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:26:37,493] Trial 20 finished with value: 0.6980613805155089 and parameters: {'n_estimators': 2042, 'num_leaves': 647, 'max_depth': 96, 'learning_rate': 0.004256984066758721, 'min_child_samples': 81, 'subsample': 0.6949983278545738, 'colsample_bytree': 0.23965571789248558, 'reg_alpha': 0.32090408523429387, 'reg_lambda': 3.286067910534178, 'min_split_gain': 0.0034487759233516988}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:26:39,785] Trial 21 finished with value: 0.7076370685889034 and parameters: {'n_estimators': 1430, 'num_leaves': 38, 'max_depth': 173, 'learning_rate': 0.020291929456485204, 'min_child_samples': 112, 'subsample': 0.6191519470582573, 'colsample_bytree': 0.9892939674901582, 'reg_alpha': 12.422091387395852, 'reg_lambda': 0.5481557846162809, 'min_split_gain': 4.567630505802555}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:26:41,780] Trial 22 finished with value: 0.7051250546089995 and parameters: {'n_estimators': 1060, 'num_leaves': 249, 'max_depth': 175, 'learning_rate': 0.028862873397620344, 'min_child_samples': 105, 'subsample': 0.6009700408817651, 'colsample_bytree': 0.8719897678762978, 'reg_alpha': 12.953498287304049, 'reg_lambda': 0.994300302521735, 'min_split_gain': 6.913110651167892}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:26:46,011] Trial 23 finished with value: 0.6723023154215815 and parameters: {'n_estimators': 1503, 'num_leaves': 217, 'max_depth': 155, 'learning_rate': 0.00880863591843868, 'min_child_samples': 17, 'subsample': 0.824692857006798, 'colsample_bytree': 0.9921239257411503, 'reg_alpha': 2.249853760278658, 'reg_lambda': 0.07962645527576954, 'min_split_gain': 0.28784904641784353}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:26:50,310] Trial 24 finished with value: 0.6627839667977282 and parameters: {'n_estimators': 1747, 'num_leaves': 510, 'max_depth': 125, 'learning_rate': 0.05977040609883049, 'min_child_samples': 68, 'subsample': 0.4116496846337724, 'colsample_bytree': 0.486536767994046, 'reg_alpha': 0.2277677073288327, 'reg_lambda': 16.15315556245848, 'min_split_gain': 0.02606554112867868}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:26:52,726] Trial 25 finished with value: 0.7038308213193535 and parameters: {'n_estimators': 1173, 'num_leaves': 824, 'max_depth': 177, 'learning_rate': 0.02783629436374353, 'min_child_samples': 46, 'subsample': 0.6042352541524474, 'colsample_bytree': 0.35366710483787744, 'reg_alpha': 30.017723977487915, 'reg_lambda': 1.1912327496384623, 'min_split_gain': 0.41849928907262784}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:26:54,309] Trial 26 finished with value: 0.6991835954565313 and parameters: {'n_estimators': 791, 'num_leaves': 166, 'max_depth': 133, 'learning_rate': 0.0011451330320337457, 'min_child_samples': 99, 'subsample': 0.7874085976676206, 'colsample_bytree': 0.6753522783217345, 'reg_alpha': 1.8218665087979018, 'reg_lambda': 0.1473841925113176, 'min_split_gain': 4.43394926404434}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:27:00,294] Trial 27 finished with value: 0.6690640017474879 and parameters: {'n_estimators': 2457, 'num_leaves': 334, 'max_depth': 160, 'learning_rate': 0.015391154061271626, 'min_child_samples': 16, 'subsample': 0.19187958412023717, 'colsample_bytree': 0.9021711956465561, 'reg_alpha': 5.910701218359008, 'reg_lambda': 0.022026607884133523, 'min_split_gain': 0.0016783254359396913}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:27:03,920] Trial 28 finished with value: 0.6979521625163827 and parameters: {'n_estimators': 1555, 'num_leaves': 127, 'max_depth': 111, 'learning_rate': 0.004337930888144771, 'min_child_samples': 122, 'subsample': 0.8917763783053139, 'colsample_bytree': 0.19535365993197046, 'reg_alpha': 1.117340628223225, 'reg_lambda': 1.0763414879366844, 'min_split_gain': 4.445938705069901e-05}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:27:08,825] Trial 29 finished with value: 0.7015072083879423 and parameters: {'n_estimators': 2130, 'num_leaves': 952, 'max_depth': 192, 'learning_rate': 0.04462142790245498, 'min_child_samples': 44, 'subsample': 0.29761682409913714, 'colsample_bytree': 0.3469091228362284, 'reg_alpha': 41.16784763683534, 'reg_lambda': 0.02092186461403764, 'min_split_gain': 0.03247422445693981}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:27:18,446] Trial 30 finished with value: 0.6492955439056357 and parameters: {'n_estimators': 2978, 'num_leaves': 760, 'max_depth': 145, 'learning_rate': 0.02335809817657808, 'min_child_samples': 90, 'subsample': 0.6298221053596766, 'colsample_bytree': 0.753815773987758, 'reg_alpha': 0.024586421742407744, 'reg_lambda': 0.0008398816905094885, 'min_split_gain': 0.0005600308387419664}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:27:20,515] Trial 31 finished with value: 0.709269877675841 and parameters: {'n_estimators': 999, 'num_leaves': 199, 'max_depth': 178, 'learning_rate': 0.048879055636816514, 'min_child_samples': 105, 'subsample': 0.6220994416287217, 'colsample_bytree': 0.8737460403392505, 'reg_alpha': 10.210580989670058, 'reg_lambda': 0.7681407801263698, 'min_split_gain': 5.775291058001661}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:27:22,641] Trial 32 finished with value: 0.6995440148536479 and parameters: {'n_estimators': 909, 'num_leaves': 533, 'max_depth': 182, 'learning_rate': 0.05743585201056089, 'min_child_samples': 113, 'subsample': 0.6546449307772205, 'colsample_bytree': 0.9068208240705043, 'reg_alpha': 5.575827236159483, 'reg_lambda': 0.7073399261157464, 'min_split_gain': 2.6653718321544106}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:27:25,672] Trial 33 finished with value: 0.6937117737003058 and parameters: {'n_estimators': 1314, 'num_leaves': 124, 'max_depth': 165, 'learning_rate': 0.09111039377114248, 'min_child_samples': 139, 'subsample': 0.4900644767377913, 'colsample_bytree': 0.9690756355013532, 'reg_alpha': 10.643740421534602, 'reg_lambda': 4.02552014439154, 'min_split_gain': 1.2019507689641384}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:27:29,959] Trial 34 finished with value: 0.7105422673656618 and parameters: {'n_estimators': 1850, 'num_leaves': 12, 'max_depth': 187, 'learning_rate': 0.008263288675983776, 'min_child_samples': 94, 'subsample': 0.5704387913844794, 'colsample_bytree': 0.8000722117150031, 'reg_alpha': 0.16876588852421523, 'reg_lambda': 24.79507599742012, 'min_split_gain': 4.381023972580094}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:27:33,897] Trial 35 finished with value: 0.7108562691131499 and parameters: {'n_estimators': 1838, 'num_leaves': 335, 'max_depth': 199, 'learning_rate': 0.008784518866023232, 'min_child_samples': 68, 'subsample': 0.5442463877374076, 'colsample_bytree': 0.6196805685528463, 'reg_alpha': 0.11598984967037831, 'reg_lambda': 43.565579475278945, 'min_split_gain': 2.815949774646114}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:27:38,492] Trial 36 finished with value: 0.7100698995194408 and parameters: {'n_estimators': 1860, 'num_leaves': 1133, 'max_depth': 198, 'learning_rate': 0.0028480567533121204, 'min_child_samples': 64, 'subsample': 0.14729534039266265, 'colsample_bytree': 0.6346554023290955, 'reg_alpha': 0.08011911026271176, 'reg_lambda': 30.154484869618447, 'min_split_gain': 2.1139366085074904}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:27:45,057] Trial 37 finished with value: 0.6895969855832241 and parameters: {'n_estimators': 1989, 'num_leaves': 372, 'max_depth': 187, 'learning_rate': 0.009055292544615533, 'min_child_samples': 40, 'subsample': 0.5389890175867604, 'colsample_bytree': 0.42697110429142393, 'reg_alpha': 0.1431680513160823, 'reg_lambda': 32.604489191504264, 'min_split_gain': 0.17970626413124968}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:27:52,669] Trial 38 finished with value: 0.7016819571865445 and parameters: {'n_estimators': 2271, 'num_leaves': 1399, 'max_depth': 78, 'learning_rate': 0.001953017182814675, 'min_child_samples': 80, 'subsample': 0.4280431292544824, 'colsample_bytree': 0.7985808328457249, 'reg_alpha': 0.0400941808917001, 'reg_lambda': 7.342705245590232, 'min_split_gain': 1.0504358678966754}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:27:57,491] Trial 39 finished with value: 0.705078636959371 and parameters: {'n_estimators': 1611, 'num_leaves': 716, 'max_depth': 200, 'learning_rate': 0.003947056956593354, 'min_child_samples': 62, 'subsample': 0.48077538466063674, 'colsample_bytree': 0.7139005705582167, 'reg_alpha': 0.010100016372094837, 'reg_lambda': 35.94270390121235, 'min_split_gain': 0.6633667124471023}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:28:01,939] Trial 40 finished with value: 0.7008682830930536 and parameters: {'n_estimators': 1795, 'num_leaves': 328, 'max_depth': 151, 'learning_rate': 0.010308825406585467, 'min_child_samples': 14, 'subsample': 0.260120593795377, 'colsample_bytree': 0.475201918626015, 'reg_alpha': 0.0011919914003511573, 'reg_lambda': 0.17509160629961987, 'min_split_gain': 2.2127385208347836}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:28:06,499] Trial 41 finished with value: 0.7109764089121887 and parameters: {'n_estimators': 1871, 'num_leaves': 1109, 'max_depth': 188, 'learning_rate': 0.0030934201154536635, 'min_child_samples': 66, 'subsample': 0.15801587649023432, 'colsample_bytree': 0.6400904775937899, 'reg_alpha': 0.06579359097100086, 'reg_lambda': 23.23905425406965, 'min_split_gain': 2.58066950547372}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:28:10,525] Trial 42 finished with value: 0.7085162734818697 and parameters: {'n_estimators': 1905, 'num_leaves': 1118, 'max_depth': 187, 'learning_rate': 0.0065301066942784905, 'min_child_samples': 89, 'subsample': 0.3568052711997648, 'colsample_bytree': 0.5454516881480009, 'reg_alpha': 0.3024462071725282, 'reg_lambda': 18.305058228142432, 'min_split_gain': 9.175929086901228}. Best is trial 13 with value: 0.7110828964613368.
# [I 2025-02-03 21:28:14,787] Trial 43 finished with value: 0.7122133027522937 and parameters: {'n_estimators': 2229, 'num_leaves': 1351, 'max_depth': 166, 'learning_rate': 0.016062349199289828, 'min_child_samples': 74, 'subsample': 0.15918430234560266, 'colsample_bytree': 0.6957171806244911, 'reg_alpha': 0.026850809364564777, 'reg_lambda': 99.3353493016197, 'min_split_gain': 3.405801326958736}. Best is trial 43 with value: 0.7122133027522937.
# [I 2025-02-03 21:28:21,077] Trial 44 finished with value: 0.7003413062472694 and parameters: {'n_estimators': 2536, 'num_leaves': 1418, 'max_depth': 164, 'learning_rate': 0.0010181533166988273, 'min_child_samples': 72, 'subsample': 0.14782651753372728, 'colsample_bytree': 0.6884513236064067, 'reg_alpha': 0.0211807299236736, 'reg_lambda': 65.07498156187273, 'min_split_gain': 0.6909461094493217}. Best is trial 43 with value: 0.7122133027522937.
# [I 2025-02-03 21:28:25,384] Trial 45 finished with value: 0.7100316732197467 and parameters: {'n_estimators': 2287, 'num_leaves': 1317, 'max_depth': 185, 'learning_rate': 0.015892271355999802, 'min_child_samples': 94, 'subsample': 0.20208457146985695, 'colsample_bytree': 0.7939309143604107, 'reg_alpha': 0.0024644189480336094, 'reg_lambda': 91.90351565861486, 'min_split_gain': 3.736568722547922}. Best is trial 43 with value: 0.7122133027522937.
# [I 2025-02-03 21:28:30,465] Trial 46 finished with value: 0.7043141109654871 and parameters: {'n_estimators': 2152, 'num_leaves': 1529, 'max_depth': 200, 'learning_rate': 0.0032332760941486617, 'min_child_samples': 56, 'subsample': 0.11958504366986218, 'colsample_bytree': 0.6107903618936065, 'reg_alpha': 0.0587102100659426, 'reg_lambda': 5.47740528071023, 'min_split_gain': 1.6614620072288901}. Best is trial 43 with value: 0.7122133027522937.
# [I 2025-02-03 21:28:36,224] Trial 47 finished with value: 0.6918687199650503 and parameters: {'n_estimators': 1987, 'num_leaves': 943, 'max_depth': 170, 'learning_rate': 0.0056871568980889015, 'min_child_samples': 38, 'subsample': 0.545665064127401, 'colsample_bytree': 0.5674855167023313, 'reg_alpha': 0.14690149323801244, 'reg_lambda': 19.011420962028303, 'min_split_gain': 0.1099345656354208}. Best is trial 43 with value: 0.7122133027522937.
# [I 2025-02-03 21:28:43,686] Trial 48 finished with value: 0.6967999126256007 and parameters: {'n_estimators': 2615, 'num_leaves': 1591, 'max_depth': 191, 'learning_rate': 0.0015180400807688604, 'min_child_samples': 77, 'subsample': 0.32925463567566926, 'colsample_bytree': 0.7249270468340275, 'reg_alpha': 0.5773617922641539, 'reg_lambda': 1.7401915606802496, 'min_split_gain': 0.4158230765497748}. Best is trial 43 with value: 0.7122133027522937.
# [I 2025-02-03 21:28:48,423] Trial 49 finished with value: 0.7081285495849716 and parameters: {'n_estimators': 2369, 'num_leaves': 1089, 'max_depth': 9, 'learning_rate': 0.010068296658107457, 'min_child_samples': 86, 'subsample': 0.2755094873864622, 'colsample_bytree': 0.7802968255607142, 'reg_alpha': 0.0004172779361565892, 'reg_lambda': 42.52391844342935, 'min_split_gain': 3.2841542582187566}. Best is trial 43 with value: 0.7122133027522937.
# [I 2025-02-03 21:28:53,136] Trial 50 finished with value: 0.6944025775447794 and parameters: {'n_estimators': 2165, 'num_leaves': 1249, 'max_depth': 164, 'learning_rate': 0.00045059480237950086, 'min_child_samples': 138, 'subsample': 0.17083553771178234, 'colsample_bytree': 0.6489078248216854, 'reg_alpha': 0.01368711756892586, 'reg_lambda': 10.900552201934675, 'min_split_gain': 9.681333007941875}. Best is trial 43 with value: 0.7122133027522937.
# [I 2025-02-03 21:28:57,707] Trial 51 finished with value: 0.6820445609436435 and parameters: {'n_estimators': 1804, 'num_leaves': 483, 'max_depth': 130, 'learning_rate': 0.013589120061431164, 'min_child_samples': 51, 'subsample': 0.20350397517760505, 'colsample_bytree': 0.6111114576076659, 'reg_alpha': 0.11328153724651692, 'reg_lambda': 2.326122158397497, 'min_split_gain': 1.0111040125738566}. Best is trial 43 with value: 0.7122133027522937.
# [I 2025-02-03 21:29:00,719] Trial 52 finished with value: 0.7108999563128003 and parameters: {'n_estimators': 1572, 'num_leaves': 1017, 'max_depth': 140, 'learning_rate': 0.021103268739466247, 'min_child_samples': 70, 'subsample': 0.22207934035846894, 'colsample_bytree': 0.5352757263404248, 'reg_alpha': 0.03988794995983414, 'reg_lambda': 99.82923812893243, 'min_split_gain': 5.615025961198922}. Best is trial 43 with value: 0.7122133027522937.
# [I 2025-02-03 21:29:04,059] Trial 53 finished with value: 0.7119375273044998 and parameters: {'n_estimators': 1648, 'num_leaves': 1046, 'max_depth': 142, 'learning_rate': 0.018644293498133496, 'min_child_samples': 65, 'subsample': 0.23270745363589668, 'colsample_bytree': 0.5088132343544275, 'reg_alpha': 0.04345076492497515, 'reg_lambda': 88.03149563309013, 'min_split_gain': 5.209027897128465}. Best is trial 43 with value: 0.7122133027522937.
# [I 2025-02-03 21:29:07,628] Trial 54 finished with value: 0.7026103101791177 and parameters: {'n_estimators': 1647, 'num_leaves': 1049, 'max_depth': 143, 'learning_rate': 0.020769791976665855, 'min_child_samples': 73, 'subsample': 0.23902635358056498, 'colsample_bytree': 0.5324830178312667, 'reg_alpha': 0.003979351475201745, 'reg_lambda': 50.992865848487355, 'min_split_gain': 1.5395466868761876}. Best is trial 43 with value: 0.7122133027522937.
# [I 2025-02-03 21:29:10,605] Trial 55 finished with value: 0.7115143075578856 and parameters: {'n_estimators': 1474, 'num_leaves': 1194, 'max_depth': 150, 'learning_rate': 0.03355587234813024, 'min_child_samples': 58, 'subsample': 0.10387245227503492, 'colsample_bytree': 0.5041583169246566, 'reg_alpha': 0.07246183270619536, 'reg_lambda': 96.99030338914767, 'min_split_gain': 2.5460465904446212}. Best is trial 43 with value: 0.7122133027522937.
# [I 2025-02-03 21:29:14,022] Trial 56 finished with value: 0.7106105286151159 and parameters: {'n_estimators': 1455, 'num_leaves': 1194, 'max_depth': 150, 'learning_rate': 0.03496534849578328, 'min_child_samples': 36, 'subsample': 0.12831198326661358, 'colsample_bytree': 0.47333360067435815, 'reg_alpha': 0.03102185282474225, 'reg_lambda': 89.61494642266607, 'min_split_gain': 5.486840719713075}. Best is trial 43 with value: 0.7122133027522937.
# [I 2025-02-03 21:29:20,508] Trial 57 finished with value: 0.671909130624727 and parameters: {'n_estimators': 1279, 'num_leaves': 991, 'max_depth': 119, 'learning_rate': 0.030858181393441327, 'min_child_samples': 60, 'subsample': 0.16788161347911557, 'colsample_bytree': 0.5169154092785172, 'reg_alpha': 0.05533892015645337, 'reg_lambda': 13.188218827630202, 'min_split_gain': 0.31519548060764535}. Best is trial 43 with value: 0.7122133027522937.
# [I 2025-02-03 21:29:22,682] Trial 58 finished with value: 0.6776867627785059 and parameters: {'n_estimators': 1156, 'num_leaves': 1291, 'max_depth': 138, 'learning_rate': 0.0001486682423928982, 'min_child_samples': 23, 'subsample': 0.2291602865434187, 'colsample_bytree': 0.5757588672438001, 'reg_alpha': 0.01592476180006637, 'reg_lambda': 88.09324005686494, 'min_split_gain': 7.199803157734161}. Best is trial 43 with value: 0.7122133027522937.
# [I 2025-02-03 21:29:23,611] Trial 59 finished with value: 0.6774027959807777 and parameters: {'n_estimators': 305, 'num_leaves': 1787, 'max_depth': 155, 'learning_rate': 0.0760471537606401, 'min_child_samples': 3, 'subsample': 0.10565503404065701, 'colsample_bytree': 0.4317988311270922, 'reg_alpha': 0.006039422467050972, 'reg_lambda': 4.841397485559492, 'min_split_gain': 0.755263319596589}. Best is trial 43 with value: 0.7122133027522937.
# [I 2025-02-03 21:29:26,587] Trial 60 finished with value: 0.6965923984272607 and parameters: {'n_estimators': 1526, 'num_leaves': 836, 'max_depth': 104, 'learning_rate': 0.021163032974798605, 'min_child_samples': 196, 'subsample': 0.15579759044123634, 'colsample_bytree': 0.6741300156948811, 'reg_alpha': 0.044921503632091096, 'reg_lambda': 0.009141768103781499, 'min_split_gain': 1.7998760545565147}. Best is trial 43 with value: 0.7122133027522937.
# [I 2025-02-03 21:29:30,620] Trial 61 finished with value: 0.7090104849279162 and parameters: {'n_estimators': 2053, 'num_leaves': 1180, 'max_depth': 23, 'learning_rate': 0.011921846987896506, 'min_child_samples': 67, 'subsample': 0.1013627616830945, 'colsample_bytree': 0.5926992517407599, 'reg_alpha': 0.3977336162832862, 'reg_lambda': 40.21090875002303, 'min_split_gain': 2.4378140650508473}. Best is trial 43 with value: 0.7122133027522937.
# [I 2025-02-03 21:29:33,905] Trial 62 finished with value: 0.7138816076889472 and parameters: {'n_estimators': 1723, 'num_leaves': 1342, 'max_depth': 130, 'learning_rate': 0.016765061436986896, 'min_child_samples': 47, 'subsample': 0.189527530786878, 'colsample_bytree': 0.5042919425099889, 'reg_alpha': 0.9490444905025057, 'reg_lambda': 60.114766331225745, 'min_split_gain': 3.2769735819034596}. Best is trial 62 with value: 0.7138816076889472.
# [I 2025-02-03 21:29:37,040] Trial 63 finished with value: 0.714332131935343 and parameters: {'n_estimators': 1710, 'num_leaves': 1385, 'max_depth': 131, 'learning_rate': 0.04587683932614265, 'min_child_samples': 50, 'subsample': 0.28549859575964964, 'colsample_bytree': 0.3973051985508041, 'reg_alpha': 1.2208917070017666, 'reg_lambda': 20.659049042408537, 'min_split_gain': 5.755323610603894}. Best is trial 63 with value: 0.714332131935343.
# [I 2025-02-03 21:29:40,420] Trial 64 finished with value: 0.7071264744429883 and parameters: {'n_estimators': 1705, 'num_leaves': 1339, 'max_depth': 125, 'learning_rate': 0.04097924887909562, 'min_child_samples': 49, 'subsample': 0.28946719486906636, 'colsample_bytree': 0.410534885722094, 'reg_alpha': 1.2373998040369698, 'reg_lambda': 7.938584056872181, 'min_split_gain': 3.496433563935348}. Best is trial 63 with value: 0.714332131935343.
# [I 2025-02-03 21:29:43,320] Trial 65 finished with value: 0.7085490388816077 and parameters: {'n_estimators': 1395, 'num_leaves': 1501, 'max_depth': 132, 'learning_rate': 0.059985682370381974, 'min_child_samples': 33, 'subsample': 0.17744436167471653, 'colsample_bytree': 0.29459509093677705, 'reg_alpha': 3.4372530806320705, 'reg_lambda': 22.585342123697917, 'min_split_gain': 7.556576598095512}. Best is trial 63 with value: 0.714332131935343.
# [I 2025-02-03 21:29:47,359] Trial 66 finished with value: 0.7077599388379205 and parameters: {'n_estimators': 1985, 'num_leaves': 1639, 'max_depth': 107, 'learning_rate': 0.026022872008526283, 'min_child_samples': 56, 'subsample': 0.13550900741644942, 'colsample_bytree': 0.3997782524505946, 'reg_alpha': 0.86724077944798, 'reg_lambda': 58.89675572160685, 'min_split_gain': 1.6505540031544124}. Best is trial 63 with value: 0.714332131935343.
# [I 2025-02-03 21:29:51,302] Trial 67 finished with value: 0.6993774574049804 and parameters: {'n_estimators': 1735, 'num_leaves': 1256, 'max_depth': 157, 'learning_rate': 0.015545855122243263, 'min_child_samples': 45, 'subsample': 0.19482467613911422, 'colsample_bytree': 0.46579285426690664, 'reg_alpha': 2.8359484135761974, 'reg_lambda': 15.185106317572043, 'min_split_gain': 0.9147811361591341}. Best is trial 63 with value: 0.714332131935343.
# [I 2025-02-03 21:29:55,327] Trial 68 finished with value: 0.6694517256443862 and parameters: {'n_estimators': 1640, 'num_leaves': 1395, 'max_depth': 119, 'learning_rate': 0.07041453577856827, 'min_child_samples': 24, 'subsample': 0.3064872857778715, 'colsample_bytree': 0.5018653939306668, 'reg_alpha': 0.5799725176129181, 'reg_lambda': 53.81602680070078, 'min_split_gain': 0.45238593892220247}. Best is trial 63 with value: 0.714332131935343.
# [I 2025-02-03 21:29:59,589] Trial 69 finished with value: 0.7053462210572302 and parameters: {'n_estimators': 2222, 'num_leaves': 891, 'max_depth': 95, 'learning_rate': 0.04446484913351728, 'min_child_samples': 8, 'subsample': 0.2613264028635046, 'colsample_bytree': 0.45225190362218465, 'reg_alpha': 0.2334482179296406, 'reg_lambda': 2.5065702978560232e-05, 'min_split_gain': 4.453779309791131}. Best is trial 63 with value: 0.714332131935343.
# [I 2025-02-03 21:30:05,199] Trial 70 finished with value: 0.6766710353866318 and parameters: {'n_estimators': 2099, 'num_leaves': 1451, 'max_depth': 146, 'learning_rate': 0.029998412879970175, 'min_child_samples': 60, 'subsample': 0.358838320749523, 'colsample_bytree': 0.3886000828742145, 'reg_alpha': 0.46651551295694027, 'reg_lambda': 6.576987898513152, 'min_split_gain': 0.19563414156309308}. Best is trial 63 with value: 0.714332131935343.
# [I 2025-02-03 21:30:08,314] Trial 71 finished with value: 0.7144959589340323 and parameters: {'n_estimators': 1575, 'num_leaves': 1160, 'max_depth': 139, 'learning_rate': 0.020119908496946316, 'min_child_samples': 77, 'subsample': 0.21875662418822478, 'colsample_bytree': 0.5588794853750383, 'reg_alpha': 0.07168073152960333, 'reg_lambda': 27.92425578337421, 'min_split_gain': 5.400471695040279}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:30:11,359] Trial 72 finished with value: 0.6676114023591088 and parameters: {'n_estimators': 1446, 'num_leaves': 1348, 'max_depth': 135, 'learning_rate': 2.21356048852783e-05, 'min_child_samples': 79, 'subsample': 0.21744140652690125, 'colsample_bytree': 0.555170989393923, 'reg_alpha': 1.1188643731346472e-05, 'reg_lambda': 20.79720603605644, 'min_split_gain': 9.77466121896947}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:30:17,148] Trial 73 finished with value: 0.6762013979903888 and parameters: {'n_estimators': 1728, 'num_leaves': 1163, 'max_depth': 170, 'learning_rate': 0.017931455657877796, 'min_child_samples': 52, 'subsample': 0.13433351117280734, 'colsample_bytree': 0.49902549539163843, 'reg_alpha': 0.08206647817084843, 'reg_lambda': 11.216283517271295, 'min_split_gain': 0.05535233571291157}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:30:21,105] Trial 74 finished with value: 0.7139198339886413 and parameters: {'n_estimators': 1930, 'num_leaves': 1090, 'max_depth': 128, 'learning_rate': 0.03635760205358656, 'min_child_samples': 85, 'subsample': 0.2348828404384737, 'colsample_bytree': 0.584775447219023, 'reg_alpha': 1.4183884174395363, 'reg_lambda': 33.33351330381763, 'min_split_gain': 5.787917485688699}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:30:25,036] Trial 75 finished with value: 0.7122952162516382 and parameters: {'n_estimators': 1946, 'num_leaves': 1065, 'max_depth': 127, 'learning_rate': 0.03833536573646104, 'min_child_samples': 85, 'subsample': 0.19163022538681984, 'colsample_bytree': 0.3484094241456164, 'reg_alpha': 1.732183547303349, 'reg_lambda': 32.219956284639636, 'min_split_gain': 5.966432095229322}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:30:27,975] Trial 76 finished with value: 0.7132208387942334 and parameters: {'n_estimators': 1511, 'num_leaves': 1232, 'max_depth': 118, 'learning_rate': 0.05382104413066406, 'min_child_samples': 84, 'subsample': 0.2434048944610958, 'colsample_bytree': 0.3339624890469807, 'reg_alpha': 1.201515791667738, 'reg_lambda': 31.09721184460725, 'min_split_gain': 5.851229773450568}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:30:31,382] Trial 77 finished with value: 0.7106951725644386 and parameters: {'n_estimators': 1349, 'num_leaves': 1053, 'max_depth': 121, 'learning_rate': 0.04899851695978103, 'min_child_samples': 86, 'subsample': 0.24054436394802356, 'colsample_bytree': 0.3429225274333674, 'reg_alpha': 1.3067126857469693, 'reg_lambda': 31.77123917447137, 'min_split_gain': 5.950164658051661}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:30:36,159] Trial 78 finished with value: 0.7073640235910879 and parameters: {'n_estimators': 1595, 'num_leaves': 1280, 'max_depth': 110, 'learning_rate': 0.09979608640339666, 'min_child_samples': 95, 'subsample': 0.3399552558860275, 'colsample_bytree': 0.31634748088504017, 'reg_alpha': 2.0756136527030296, 'reg_lambda': 56.27035784850926, 'min_split_gain': 3.9928522323082434}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:30:40,282] Trial 79 finished with value: 0.7106132590650939 and parameters: {'n_estimators': 1965, 'num_leaves': 935, 'max_depth': 128, 'learning_rate': 0.06702502543757975, 'min_child_samples': 76, 'subsample': 0.30684569187934924, 'colsample_bytree': 0.2405543758753839, 'reg_alpha': 4.321124513082735, 'reg_lambda': 30.934159038528595, 'min_split_gain': 6.512566548471065}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:30:44,693] Trial 80 finished with value: 0.6920816950633464 and parameters: {'n_estimators': 1803, 'num_leaves': 1368, 'max_depth': 114, 'learning_rate': 0.05308015327815948, 'min_child_samples': 101, 'subsample': 0.3815880195025809, 'colsample_bytree': 0.31745899762684726, 'reg_alpha': 1.5485773607260276, 'reg_lambda': 12.385588424706297, 'min_split_gain': 1.239314593291067}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:30:48,217] Trial 81 finished with value: 0.7067169069462648 and parameters: {'n_estimators': 1563, 'num_leaves': 1180, 'max_depth': 137, 'learning_rate': 0.03741765118613718, 'min_child_samples': 110, 'subsample': 0.2644466086303653, 'colsample_bytree': 0.26751259946865485, 'reg_alpha': 0.22777017220901682, 'reg_lambda': 60.70094264240386, 'min_split_gain': 2.992621399708817}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:30:51,828] Trial 82 finished with value: 0.7135839886413281 and parameters: {'n_estimators': 1504, 'num_leaves': 1233, 'max_depth': 126, 'learning_rate': 0.025094243391857857, 'min_child_samples': 84, 'subsample': 0.18974857410798415, 'colsample_bytree': 0.36938630299026004, 'reg_alpha': 6.880448414857609, 'reg_lambda': 41.89872747726807, 'min_split_gain': 2.054090687636693}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:30:54,541] Trial 83 finished with value: 0.7032383136740936 and parameters: {'n_estimators': 1233, 'num_leaves': 1242, 'max_depth': 122, 'learning_rate': 0.02447848805219835, 'min_child_samples': 84, 'subsample': 0.18377228145127306, 'colsample_bytree': 0.36739256534795645, 'reg_alpha': 30.178156965482476, 'reg_lambda': 26.208156796983282, 'min_split_gain': 4.868398170971093}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:30:59,446] Trial 84 finished with value: 0.7071892747924857 and parameters: {'n_estimators': 1908, 'num_leaves': 1569, 'max_depth': 100, 'learning_rate': 0.013253478501586202, 'min_child_samples': 92, 'subsample': 0.2796606828413585, 'colsample_bytree': 0.38046940152923936, 'reg_alpha': 6.115414531517757, 'reg_lambda': 39.41145402681101, 'min_split_gain': 6.899518637962457}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:31:02,920] Trial 85 finished with value: 0.7102309960681521 and parameters: {'n_estimators': 1653, 'num_leaves': 1457, 'max_depth': 129, 'learning_rate': 0.0261431223173699, 'min_child_samples': 99, 'subsample': 0.24567321160201003, 'colsample_bytree': 0.18773117237616924, 'reg_alpha': 7.342953032627348, 'reg_lambda': 17.508664444972354, 'min_split_gain': 2.0680734269866465}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:31:06,477] Trial 86 finished with value: 0.7055755788553953 and parameters: {'n_estimators': 1766, 'num_leaves': 1108, 'max_depth': 115, 'learning_rate': 0.08282723550801402, 'min_child_samples': 74, 'subsample': 0.18336457707087656, 'colsample_bytree': 0.27459989525742495, 'reg_alpha': 0.8366765139416233, 'reg_lambda': 8.39420203172273, 'min_split_gain': 3.3487283721228693}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:31:10,544] Trial 87 finished with value: 0.7111620795107034 and parameters: {'n_estimators': 2071, 'num_leaves': 1310, 'max_depth': 140, 'learning_rate': 0.042274285789284737, 'min_child_samples': 83, 'subsample': 0.20003917951127725, 'colsample_bytree': 0.34082166732011093, 'reg_alpha': 2.745203884724823, 'reg_lambda': 63.903476662011165, 'min_split_gain': 4.026485122575722}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:31:13,593] Trial 88 finished with value: 0.7091360856269114 and parameters: {'n_estimators': 1517, 'num_leaves': 995, 'max_depth': 133, 'learning_rate': 0.018216840568896782, 'min_child_samples': 89, 'subsample': 0.21903025208738586, 'colsample_bytree': 0.4478740281520448, 'reg_alpha': 17.571839147748996, 'reg_lambda': 4.175381705573332, 'min_split_gain': 1.3855588179811111}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:31:18,430] Trial 89 finished with value: 0.707071865443425 and parameters: {'n_estimators': 2409, 'num_leaves': 881, 'max_depth': 125, 'learning_rate': 0.007269541045307951, 'min_child_samples': 63, 'subsample': 0.3183365956660251, 'colsample_bytree': 0.4065491092498766, 'reg_alpha': 3.8906624454206105, 'reg_lambda': 27.359989374755447, 'min_split_gain': 7.764203402505083}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:31:21,288] Trial 90 finished with value: 0.7111784622105723 and parameters: {'n_estimators': 1364, 'num_leaves': 1215, 'max_depth': 118, 'learning_rate': 0.010981726659002903, 'min_child_samples': 42, 'subsample': 0.2756766322071216, 'colsample_bytree': 0.3717590026790276, 'reg_alpha': 1.8392157952488366, 'reg_lambda': 0.0018502720942443396, 'min_split_gain': 5.2228047819169285}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:31:24,411] Trial 91 finished with value: 0.709444626474443 and parameters: {'n_estimators': 1456, 'num_leaves': 1148, 'max_depth': 151, 'learning_rate': 0.03267426864103379, 'min_child_samples': 71, 'subsample': 0.15526120510711877, 'colsample_bytree': 0.5271055368421538, 'reg_alpha': 0.0082719184242009, 'reg_lambda': 75.77011528027718, 'min_split_gain': 2.5090797641457323}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:31:28,166] Trial 92 finished with value: 0.6999180865006552 and parameters: {'n_estimators': 1688, 'num_leaves': 1077, 'max_depth': 142, 'learning_rate': 0.03827023336197609, 'min_child_samples': 78, 'subsample': 0.2045129242377558, 'colsample_bytree': 0.4885028090967063, 'reg_alpha': 0.33187373208489335, 'reg_lambda': 45.78337426140963, 'min_split_gain': 2.069175966062818}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:31:31,477] Trial 93 finished with value: 0.7126802096985584 and parameters: {'n_estimators': 1515, 'num_leaves': 1209, 'max_depth': 153, 'learning_rate': 0.05885663039493827, 'min_child_samples': 56, 'subsample': 0.12986968262379314, 'colsample_bytree': 0.5524013699864231, 'reg_alpha': 0.02125802948245711, 'reg_lambda': 83.57665965299006, 'min_split_gain': 3.1408964973184923}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:31:34,038] Trial 94 finished with value: 0.701414373088685 and parameters: {'n_estimators': 1143, 'num_leaves': 1231, 'max_depth': 126, 'learning_rate': 0.05665858447637486, 'min_child_samples': 66, 'subsample': 0.22779786229532667, 'colsample_bytree': 0.552109041607967, 'reg_alpha': 0.02758156562159811, 'reg_lambda': 17.639753051129006, 'min_split_gain': 3.214635070459198}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:31:37,581] Trial 95 finished with value: 0.7110938182612494 and parameters: {'n_estimators': 1600, 'num_leaves': 1425, 'max_depth': 145, 'learning_rate': 0.06967074751745395, 'min_child_samples': 48, 'subsample': 0.12884445696263108, 'colsample_bytree': 0.43579503172319356, 'reg_alpha': 0.7651906673317288, 'reg_lambda': 40.4882122555949, 'min_split_gain': 4.959584032745317}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:31:42,005] Trial 96 finished with value: 0.7071647007426825 and parameters: {'n_estimators': 1855, 'num_leaves': 1036, 'max_depth': 135, 'learning_rate': 0.023348207691427418, 'min_child_samples': 81, 'subsample': 0.1690743155073134, 'colsample_bytree': 0.5932863185783013, 'reg_alpha': 0.02003487885455091, 'reg_lambda': 71.85861681925444, 'min_split_gain': 9.320549851467494}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:31:48,605] Trial 97 finished with value: 0.690186762778506 and parameters: {'n_estimators': 1928, 'num_leaves': 1494, 'max_depth': 131, 'learning_rate': 0.05195035133604517, 'min_child_samples': 103, 'subsample': 0.23932810195912518, 'colsample_bytree': 0.32634724838612816, 'reg_alpha': 9.46855781729592, 'reg_lambda': 98.73151242968794, 'min_split_gain': 0.014210483774617696}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:31:51,474] Trial 98 finished with value: 0.7022717343818261 and parameters: {'n_estimators': 1277, 'num_leaves': 1331, 'max_depth': 153, 'learning_rate': 0.01735031924530451, 'min_child_samples': 97, 'subsample': 0.14596945342013865, 'colsample_bytree': 0.6296808028353458, 'reg_alpha': 1.0646150059264845, 'reg_lambda': 27.30941952028653, 'min_split_gain': 1.6018530366600108}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:31:55,294] Trial 99 finished with value: 0.6754969418960244 and parameters: {'n_estimators': 1525, 'num_leaves': 1128, 'max_depth': 162, 'learning_rate': 0.029909325731607407, 'min_child_samples': 53, 'subsample': 0.1858515640703983, 'colsample_bytree': 0.5671610613366801, 'reg_alpha': 0.014303458536204246, 'reg_lambda': 10.773490728347307, 'min_split_gain': 0.9012256597772158}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:31:57,996] Trial 100 finished with value: 0.6849442988204455 and parameters: {'n_estimators': 676, 'num_leaves': 1281, 'max_depth': 147, 'learning_rate': 0.00022695786997335542, 'min_child_samples': 87, 'subsample': 0.20986882233602977, 'colsample_bytree': 0.6933624710530882, 'reg_alpha': 0.00418215073659907, 'reg_lambda': 0.043274163362500326, 'min_split_gain': 0.5269220220375546}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:32:01,129] Trial 101 finished with value: 0.7134501965923984 and parameters: {'n_estimators': 1469, 'num_leaves': 1196, 'max_depth': 167, 'learning_rate': 0.03654249944217708, 'min_child_samples': 57, 'subsample': 0.12028989489470931, 'colsample_bytree': 0.4602637383999137, 'reg_alpha': 0.10167021753788999, 'reg_lambda': 75.79105799961312, 'min_split_gain': 2.940969704157363}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:32:03,946] Trial 102 finished with value: 0.7119730231542158 and parameters: {'n_estimators': 1396, 'num_leaves': 1363, 'max_depth': 169, 'learning_rate': 0.04743890480295519, 'min_child_samples': 63, 'subsample': 0.2566485004162316, 'colsample_bytree': 0.36095329566702006, 'reg_alpha': 0.10814008785705206, 'reg_lambda': 47.64884130504107, 'min_split_gain': 6.723791698182894}. Best is trial 71 with value: 0.7144959589340323.
# [I 2025-02-03 21:32:06,771] Trial 103 finished with value: 0.7148645696810835 and parameters: {'n_estimators': 1409, 'num_leaves': 1373, 'max_depth': 179, 'learning_rate': 0.08155958961193363, 'min_child_samples': 70, 'subsample': 0.1186249606782504, 'colsample_bytree': 0.35887922585310994, 'reg_alpha': 0.16946255363946755, 'reg_lambda': 44.30227571169, 'min_split_gain': 6.821566867798449}. Best is trial 103 with value: 0.7148645696810835.
# [I 2025-02-03 21:32:10,612] Trial 104 finished with value: 0.6629314110965487 and parameters: {'n_estimators': 1322, 'num_leaves': 1378, 'max_depth': 50, 'learning_rate': 0.08885838328124412, 'min_child_samples': 75, 'subsample': 0.12059317069256573, 'colsample_bytree': 0.3000552738967245, 'reg_alpha': 0.5683603028083037, 'reg_lambda': 15.103599970597163, 'min_split_gain': 0.00017935893832058598}. Best is trial 103 with value: 0.7148645696810835.
# [I 2025-02-03 21:32:13,666] Trial 105 finished with value: 0.7059742245522062 and parameters: {'n_estimators': 1487, 'num_leaves': 1269, 'max_depth': 173, 'learning_rate': 0.06861477887768176, 'min_child_samples': 70, 'subsample': 0.15740965738654908, 'colsample_bytree': 0.4621306563235681, 'reg_alpha': 0.23711018514885437, 'reg_lambda': 33.84563667717806, 'min_split_gain': 3.6703438934735795}. Best is trial 103 with value: 0.7148645696810835.
# [I 2025-02-03 21:32:16,057] Trial 106 finished with value: 0.7143785495849716 and parameters: {'n_estimators': 1088, 'num_leaves': 1207, 'max_depth': 181, 'learning_rate': 0.03625946595175846, 'min_child_samples': 59, 'subsample': 0.13770109930732377, 'colsample_bytree': 0.42366138178830426, 'reg_alpha': 0.1665661212724996, 'reg_lambda': 65.79491718826402, 'min_split_gain': 2.7656387299367524}. Best is trial 103 with value: 0.7148645696810835.
# ...
# [I 2025-02-03 22:09:19,503] Trial 766 finished with value: 0.7115115771079075 and parameters: {'n_estimators': 1239, 'num_leaves': 1330, 'max_depth': 9, 'learning_rate': 0.08347101116030542, 'min_child_samples': 43, 'subsample': 0.22741683582471786, 'colsample_bytree': 0.21422293303029405, 'reg_alpha': 1.2864543561906985, 'reg_lambda': 37.33631216412258, 'min_split_gain': 2.0901918759028155}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:09:21,153] Trial 767 finished with value: 0.6623634775010921 and parameters: {'n_estimators': 1036, 'num_leaves': 789, 'max_depth': 19, 'learning_rate': 5.740622902330678e-05, 'min_child_samples': 62, 'subsample': 0.18614730004673768, 'colsample_bytree': 0.18702187051860852, 'reg_alpha': 12.357309563946231, 'reg_lambda': 23.11894866120125, 'min_split_gain': 6.424886823285702}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:09:23,420] Trial 768 finished with value: 0.672730996068152 and parameters: {'n_estimators': 1351, 'num_leaves': 1554, 'max_depth': 155, 'learning_rate': 0.002203611852632466, 'min_child_samples': 33, 'subsample': 0.1662016146824105, 'colsample_bytree': 0.22723887537929052, 'reg_alpha': 0.8793066392466514, 'reg_lambda': 0.7180086250092701, 'min_split_gain': 3.8882548969066026}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:09:25,434] Trial 769 finished with value: 0.7120767802533858 and parameters: {'n_estimators': 1270, 'num_leaves': 844, 'max_depth': 143, 'learning_rate': 0.06374292784041219, 'min_child_samples': 52, 'subsample': 0.24770885304393456, 'colsample_bytree': 0.24432285736517886, 'reg_alpha': 0.46165726537128754, 'reg_lambda': 29.734630447208946, 'min_split_gain': 7.843568334562437}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:09:27,202] Trial 770 finished with value: 0.712308868501529 and parameters: {'n_estimators': 1102, 'num_leaves': 1105, 'max_depth': 169, 'learning_rate': 0.04713589774229843, 'min_child_samples': 38, 'subsample': 0.14142483001010178, 'colsample_bytree': 0.20343158257660007, 'reg_alpha': 1.539948286290111, 'reg_lambda': 44.106939229273635, 'min_split_gain': 5.1476492112125545}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:09:29,101] Trial 771 finished with value: 0.7136822848405417 and parameters: {'n_estimators': 1181, 'num_leaves': 1281, 'max_depth': 146, 'learning_rate': 0.05528387444398714, 'min_child_samples': 47, 'subsample': 0.20797297310029197, 'colsample_bytree': 0.1687731149515184, 'reg_alpha': 0.5983970151230116, 'reg_lambda': 16.982222361934365, 'min_split_gain': 7.865509106903455}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:09:33,166] Trial 772 finished with value: 0.6915301441677588 and parameters: {'n_estimators': 2616, 'num_leaves': 1183, 'max_depth': 154, 'learning_rate': 0.083263230205132, 'min_child_samples': 28, 'subsample': 0.23999050702177174, 'colsample_bytree': 0.30993404553849324, 'reg_alpha': 1.0740476853499301, 'reg_lambda': 0.0063506613675187295, 'min_split_gain': 2.8828069774587783}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:09:35,330] Trial 773 finished with value: 0.7147799257317605 and parameters: {'n_estimators': 1382, 'num_leaves': 1459, 'max_depth': 14, 'learning_rate': 0.06820101853979832, 'min_child_samples': 42, 'subsample': 0.27411519282206687, 'colsample_bytree': 0.22113877984759786, 'reg_alpha': 1.2325315520794082e-05, 'reg_lambda': 0.5147907345498562, 'min_split_gain': 5.980921178571531}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:09:36,185] Trial 774 finished with value: 0.6718381389252948 and parameters: {'n_estimators': 348, 'num_leaves': 1369, 'max_depth': 8, 'learning_rate': 0.09924283512129053, 'min_child_samples': 38, 'subsample': 0.2226286969377062, 'colsample_bytree': 0.19224492710813557, 'reg_alpha': 0.00027655586807947554, 'reg_lambda': 1.0468418303885756, 'min_split_gain': 0.0007585677878315441}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:09:38,265] Trial 775 finished with value: 0.6550622542595019 and parameters: {'n_estimators': 984, 'num_leaves': 744, 'max_depth': 158, 'learning_rate': 0.0714772241378026, 'min_child_samples': 24, 'subsample': 0.2593130359518569, 'colsample_bytree': 0.2743865528513405, 'reg_alpha': 0.697840516781965, 'reg_lambda': 0.2614705279743717, 'min_split_gain': 0.043902592514949844}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:09:40,585] Trial 776 finished with value: 0.7102992573176058 and parameters: {'n_estimators': 1465, 'num_leaves': 1138, 'max_depth': 151, 'learning_rate': 0.035866880286619496, 'min_child_samples': 32, 'subsample': 0.6560120565085287, 'colsample_bytree': 0.24487905843281313, 'reg_alpha': 1.2129988621411965, 'reg_lambda': 3.5493362303542626, 'min_split_gain': 3.9848202029845083}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:09:42,638] Trial 777 finished with value: 0.6984873307121013 and parameters: {'n_estimators': 1214, 'num_leaves': 1228, 'max_depth': 166, 'learning_rate': 0.046912861353687406, 'min_child_samples': 49, 'subsample': 0.1884885832821723, 'colsample_bytree': 0.2142208585341246, 'reg_alpha': 0.3786105925879769, 'reg_lambda': 0.0011342666557949523, 'min_split_gain': 1.6735022446300862}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:09:43,982] Trial 778 finished with value: 0.7103456749672346 and parameters: {'n_estimators': 767, 'num_leaves': 1330, 'max_depth': 141, 'learning_rate': 0.06007183226751864, 'min_child_samples': 44, 'subsample': 0.15694933387204574, 'colsample_bytree': 0.23582057716597282, 'reg_alpha': 5.850712860618108, 'reg_lambda': 27.156331800124693, 'min_split_gain': 4.791041532454304}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:09:46,068] Trial 779 finished with value: 0.6664154652686762 and parameters: {'n_estimators': 1278, 'num_leaves': 1278, 'max_depth': 147, 'learning_rate': 1.0122836496438014e-05, 'min_child_samples': 16, 'subsample': 0.2339198745499842, 'colsample_bytree': 0.5092987466091795, 'reg_alpha': 1.7181120359049398, 'reg_lambda': 44.110284595675935, 'min_split_gain': 9.970131394198456}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:09:50,508] Trial 780 finished with value: 0.7122979467016164 and parameters: {'n_estimators': 2991, 'num_leaves': 1405, 'max_depth': 159, 'learning_rate': 0.08494798541419518, 'min_child_samples': 35, 'subsample': 0.12948424618688092, 'colsample_bytree': 0.18360704390163374, 'reg_alpha': 0.9199893806613073, 'reg_lambda': 0.8164010307933592, 'min_split_gain': 6.2302419019977355}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:09:52,680] Trial 781 finished with value: 0.7108644604630843 and parameters: {'n_estimators': 1393, 'num_leaves': 1190, 'max_depth': 164, 'learning_rate': 0.09934233342215915, 'min_child_samples': 40, 'subsample': 0.2056621312964144, 'colsample_bytree': 0.2602664724754678, 'reg_alpha': 3.6814663892502115, 'reg_lambda': 20.735049619417644, 'min_split_gain': 7.518426633834968}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:09:56,366] Trial 782 finished with value: 0.7132426823940585 and parameters: {'n_estimators': 2416, 'num_leaves': 635, 'max_depth': 150, 'learning_rate': 0.05310730791279979, 'min_child_samples': 55, 'subsample': 0.5150670272501028, 'colsample_bytree': 0.2032710665339033, 'reg_alpha': 2.2406275532322635, 'reg_lambda': 1.3233482773783107, 'min_split_gain': 3.378629636323953}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:09:58,679] Trial 783 finished with value: 0.715642747924858 and parameters: {'n_estimators': 1443, 'num_leaves': 1486, 'max_depth': 113, 'learning_rate': 0.07445197922891586, 'min_child_samples': 44, 'subsample': 0.26596026702824105, 'colsample_bytree': 0.22265932075519934, 'reg_alpha': 0.49749076464295494, 'reg_lambda': 10.206058204706565, 'min_split_gain': 5.063852678255331}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:10:00,977] Trial 784 finished with value: 0.6779379641764962 and parameters: {'n_estimators': 1346, 'num_leaves': 800, 'max_depth': 140, 'learning_rate': 3.407371157799054e-05, 'min_child_samples': 30, 'subsample': 0.15579637670551916, 'colsample_bytree': 0.3156928115219698, 'reg_alpha': 1.3155133069314604, 'reg_lambda': 2.4329310236900707, 'min_split_gain': 2.5614177161393794}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:10:01,396] Trial 785 finished with value: 0.7007399519440805 and parameters: {'n_estimators': 110, 'num_leaves': 710, 'max_depth': 66, 'learning_rate': 0.036610274578181015, 'min_child_samples': 37, 'subsample': 0.2856481802506886, 'colsample_bytree': 0.23548931108801108, 'reg_alpha': 0.7926463635272213, 'reg_lambda': 0.40374841859349864, 'min_split_gain': 7.92788592656526}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:10:05,793] Trial 786 finished with value: 0.7048793141109655 and parameters: {'n_estimators': 2937, 'num_leaves': 1253, 'max_depth': 160, 'learning_rate': 0.06633069891053198, 'min_child_samples': 132, 'subsample': 0.16957191538948124, 'colsample_bytree': 0.28190837320419965, 'reg_alpha': 0.3964155152672379, 'reg_lambda': 32.42783637233294, 'min_split_gain': 4.1809577111758855}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:10:09,537] Trial 787 finished with value: 0.7120958934032329 and parameters: {'n_estimators': 2478, 'num_leaves': 1148, 'max_depth': 12, 'learning_rate': 0.04419979422442221, 'min_child_samples': 50, 'subsample': 0.21668834235054096, 'colsample_bytree': 0.2527126377356719, 'reg_alpha': 1.7722971889817827, 'reg_lambda': 0.17968435472443506, 'min_split_gain': 6.101780497152824}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:10:11,631] Trial 788 finished with value: 0.7098596548711227 and parameters: {'n_estimators': 1310, 'num_leaves': 1291, 'max_depth': 90, 'learning_rate': 0.08410359900641771, 'min_child_samples': 42, 'subsample': 0.7229367197133577, 'colsample_bytree': 0.16425288192208448, 'reg_alpha': 0.6057753498460601, 'reg_lambda': 15.18288230231622, 'min_split_gain': 9.9448978293183}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:10:13,930] Trial 789 finished with value: 0.7063291830493665 and parameters: {'n_estimators': 1472, 'num_leaves': 1203, 'max_depth': 153, 'learning_rate': 0.06313050323860978, 'min_child_samples': 33, 'subsample': 0.11737806809987567, 'colsample_bytree': 0.2107285687468691, 'reg_alpha': 9.278133483939277, 'reg_lambda': 0.6374743438771768, 'min_split_gain': 3.408492729800905}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:10:15,464] Trial 790 finished with value: 0.7140208606378331 and parameters: {'n_estimators': 892, 'num_leaves': 1344, 'max_depth': 5, 'learning_rate': 0.09997233557546988, 'min_child_samples': 46, 'subsample': 0.18390967211057502, 'colsample_bytree': 0.19155823032879082, 'reg_alpha': 1.154340551246648, 'reg_lambda': 0.9301530267808098, 'min_split_gain': 5.312490668280614}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:10:17,633] Trial 791 finished with value: 0.71054499781564 and parameters: {'n_estimators': 1383, 'num_leaves': 1440, 'max_depth': 16, 'learning_rate': 0.05210257461854623, 'min_child_samples': 39, 'subsample': 0.24268698964447794, 'colsample_bytree': 0.22609959177139838, 'reg_alpha': 2.7304526766502044, 'reg_lambda': 37.503764729441485, 'min_split_gain': 6.5376248045613785}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:10:19,596] Trial 792 finished with value: 0.7034349060725207 and parameters: {'n_estimators': 1237, 'num_leaves': 868, 'max_depth': 146, 'learning_rate': 0.07626427003574707, 'min_child_samples': 35, 'subsample': 0.26845759622300763, 'colsample_bytree': 0.27215583991916775, 'reg_alpha': 4.849813733316723, 'reg_lambda': 46.687951556366585, 'min_split_gain': 9.97637793063196}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:10:20,413] Trial 793 finished with value: 0.7109873307121013 and parameters: {'n_estimators': 405, 'num_leaves': 1096, 'max_depth': 142, 'learning_rate': 0.05920130326180573, 'min_child_samples': 52, 'subsample': 0.531681654967713, 'colsample_bytree': 0.24955027854646133, 'reg_alpha': 0.8041968992111532, 'reg_lambda': 22.56089899285817, 'min_split_gain': 4.363356869760176}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:10:20,996] Trial 794 finished with value: 0.6783065749235473 and parameters: {'n_estimators': 216, 'num_leaves': 774, 'max_depth': 168, 'learning_rate': 0.000961451692061829, 'min_child_samples': 41, 'subsample': 0.13439249492481126, 'colsample_bytree': 0.3000096290213337, 'reg_alpha': 0.01813305633516615, 'reg_lambda': 1.7768680993744623, 'min_split_gain': 7.3669579751705205}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:10:22,877] Trial 795 finished with value: 0.7045653123634775 and parameters: {'n_estimators': 1065, 'num_leaves': 1360, 'max_depth': 155, 'learning_rate': 0.04140680771403323, 'min_child_samples': 1, 'subsample': 0.29965350387428014, 'colsample_bytree': 0.20527654310667778, 'reg_alpha': 1.671168476509227, 'reg_lambda': 0.6779869858797755, 'min_split_gain': 2.3730765521773085}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:10:25,224] Trial 796 finished with value: 0.7126556356487548 and parameters: {'n_estimators': 1443, 'num_leaves': 1241, 'max_depth': 161, 'learning_rate': 0.08375897426397809, 'min_child_samples': 26, 'subsample': 0.22739892073390694, 'colsample_bytree': 0.17954418262677285, 'reg_alpha': 0.39317904364349404, 'reg_lambda': 1.0922768961055789, 'min_split_gain': 5.286832878814732}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:10:27,047] Trial 797 finished with value: 0.710703363914373 and parameters: {'n_estimators': 1123, 'num_leaves': 728, 'max_depth': 76, 'learning_rate': 0.07283536909784835, 'min_child_samples': 44, 'subsample': 0.20492246655253105, 'colsample_bytree': 0.22880226519264246, 'reg_alpha': 0.9888724811995101, 'reg_lambda': 0.4405216280939707, 'min_split_gain': 3.5819665382485883}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:10:31,430] Trial 798 finished with value: 0.7122542595019659 and parameters: {'n_estimators': 2943, 'num_leaves': 1161, 'max_depth': 19, 'learning_rate': 0.05182469124305407, 'min_child_samples': 48, 'subsample': 0.5696315782398473, 'colsample_bytree': 0.32239678295866325, 'reg_alpha': 0.6138576618062396, 'reg_lambda': 27.04611387463597, 'min_split_gain': 7.42831982204269}. Best is trial 751 with value: 0.7197001965923985.
# [I 2025-02-03 22:10:33,308] Trial 799 finished with value: 0.7133519003931849 and parameters: {'n_estimators': 1176, 'num_leaves': 1523, 'max_depth': 139, 'learning_rate': 0.09933591981977857, 'min_child_samples': 37, 'subsample': 0.2509739306520146, 'colsample_bytree': 0.5401777678313431, 'reg_alpha': 2.1874074718806407, 'reg_lambda': 73.55461668500723, 'min_split_gain': 4.7164207572152455}. Best is trial 751 with value: 0.7197001965923985.
# Best trial:
#   Value: 0.7197001965923985
#   Params:
#     n_estimators: 1119
#     num_leaves: 709
#     max_depth: 147
#     learning_rate: 0.09973801385024506
#     min_child_samples: 42
#     subsample: 0.21368510292350004
#     colsample_bytree: 0.22900959888866157
#     reg_alpha: 0.74082973613568
#     reg_lambda: 4.355725246951781
#     min_split_gain: 6.196347618859403
#
# --- Model Performance ---
# Model Accuracy: 0.8664546899841018
# Model F1 Score: 0.0
# Model AUC: 0.6935615989515074

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# 모델 초기화
DI_model = LGBMClassifier(
    n_estimators=1171,
    num_leaves=1352,
    max_depth=133,
    learning_rate=0.013047268869340142,
    min_child_samples=165,
    subsample=0.24314691590400292,
    colsample_bytree=0.19334614890476431,
    reg_alpha=5.901900488743287,
    reg_lambda=3.858355492244645e-05,
    min_split_gain=0.00045035353026440803,
    random_state=42,
    objective='binary',
    metric='auc',
    verbose=-1,
    boosting_type='gbdt'
)

# 모델 학습
DI_model.fit(DI_X_train, DI_y_train)

# 예측
y_pred = DI_model.predict(DI_X_test)
y_pred_proba = DI_model.predict_proba(DI_X_test)[:, 1]

# 평가
accuracy = accuracy_score(DI_y_test, y_pred)
f1 = f1_score(DI_y_test, y_pred)
auc = roc_auc_score(DI_y_test, y_pred_proba)
cm = confusion_matrix(DI_y_test, y_pred)

# 결과 출력
print()
print("--- Model Performance ---")
print(f"Model Accuracy: {accuracy}")
print(f"Model F1 Score: {f1}")
print(f"Model AUC: {auc}")

# 혼동 행렬 출력
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=DI_model.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# --- Model Performance ---
# Model Accuracy: 0.8664546899841018
# Model F1 Score: 0.0
# Model AUC: 0.7120085190039318

# %% [markdown]
# ## 제출

# %%
# 모델 구축
# IVF_model = CatBoostClassifier(
#     iterations=680,
#     depth=10,
#     learning_rate=0.01,
#     random_seed=42,
#     verbose=0
# )

# DI_model = CatBoostClassifier(
#     iterations=500,
#     depth=10,
#     learning_rate=0.01,
#     random_seed=42,
#     verbose=0
# )

# 모델 학습 및 예측
IVF_model.fit(IVF_X, IVF_y)
IVF_pred_proba = IVF_model.predict_proba(IVF_test.drop('ID', axis=1))[:, 1]

DI_model.fit(DI_X, DI_y)
DI_pred_proba = DI_model.predict_proba(DI_test.drop('ID', axis=1))[:, 1]

# %%
# 예측 결과 병합
IVF_test['probability'] = IVF_pred_proba
DI_test['probability'] = DI_pred_proba

# 최종 제출 파일 생성
submission = pd.concat([IVF_test[['ID', 'probability']], DI_test[['ID', 'probability']]], axis=0)
submission = submission.sort_values(by='ID')  

# 제출 파일 저장
submission.to_csv('./code14_submit.csv', index=False, encoding='utf-8')

# %% [markdown]
# .
