# %% [markdown]
# ## 난임 환자 대상 임신 성공 여부 예측

# %% [markdown]
# ### LGAimers 6th 온라인 해커톤

# %% [markdown]
# Import

# %%
import pandas as pd
import lightgbm as lgb
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
import lightgbm as lgb
import xgboost as xgb
from catboost import CatBoostClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ### Data Load

# %%
# 데이터 로드
Total_train = pd.read_csv('../data/Total_train_dataset_51.csv')
Total_test = pd.read_csv('../data/Total_test_dataset_51.csv')

# %% [markdown]
# ### 인코딩

# %%
from autogluon.tabular import TabularDataset, TabularPredictor
import autogluon.core as ag

train_data = TabularDataset(Total_train)
test_data = TabularDataset(Total_test)

label = '임신_성공_여부'
eval_metric = 'roc_auc'

# %%
from autogluon.tabular import TabularPredictor

# 시간 제한 설정 (예: 12 * 60분)
time_limit =  12 * 60 * 60

# # GPU를 사용할 수 없는 모델을 제외하도록 설정
# exclude_model_types = [
#     'KNN',  # K-Nearest Neighbors
#     'RF',   # Random Forest
#     'XT',   # Extra Trees
#     'LR',   # Linear Regression
#     'NN'    # Tabular Neural Network
# ]

# TabularPredictor 객체 생성 및 학습
predictor = TabularPredictor(
    label=label,
    eval_metric=eval_metric,
    path='AutogluonModels/ag-20250224_1'  # 모델 저장 경로
).fit(
    train_data,
    presets='best_quality',  # 'best_quality', 'medium_quality', 'good_quality' 등의 프리셋 설정
    # num_stack_levels=0,  # 스택 레벨 설정 / dynamic_stacking=True(디폴트)인 경우 무시
    num_bag_folds=5,  # 배깅 설정
    time_limit=time_limit,  # 시간 제한 설정
    # num_gpus=1,  # GPU 사용 설정
    # excluded_model_types=exclude_model_types  # 제외할 모델 유형 설정
)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="AutogluonModels/ag-20250224_1"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.11.8
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          16
# Memory Avail:       10.37 GB / 15.86 GB (65.4%)
# Disk Space Avail:   188.18 GB / 476.30 GB (39.5%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=5, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 10800s of the 43200s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-02-24 03:17:58,180	INFO worker.py:1810 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 		Context path: "c:\Users\juneh\OneDrive\바탕 화면\git_Aimers6th\LG_Aimers_6th\code\AutogluonModels\ag-20250224_1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=12236) Running DyStack sub-fit ...
# (_dystack pid=12236) Beginning AutoGluon training ... Time limit = 10792s
# (_dystack pid=12236) AutoGluon will save models to "c:\Users\juneh\OneDrive\바탕 화면\git_Aimers6th\LG_Aimers_6th\code\AutogluonModels\ag-20250224_1\ds_sub_fit\sub_fit_ho"
# (_dystack pid=12236) Train Data Rows:    227861
# (_dystack pid=12236) Train Data Columns: 88
# (_dystack pid=12236) Label Column:       임신_성공_여부
# (_dystack pid=12236) Problem Type:       binary
# (_dystack pid=12236) Preprocessing data ...
# (_dystack pid=12236) Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# (_dystack pid=12236) Using Feature Generators to preprocess the data ...
# (_dystack pid=12236) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=12236) 	Available Memory:                    9639.47 MB
# (_dystack pid=12236) 	Train Data (Original)  Memory Usage: 166.24 MB (1.7% of available memory)
# (_dystack pid=12236) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=12236) 	Stage 1 Generators:
# (_dystack pid=12236) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=12236) 			Note: Converting 19 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=12236) 	Stage 2 Generators:
# (_dystack pid=12236) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=12236) 	Stage 3 Generators:
# (_dystack pid=12236) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=12236) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=12236) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=12236) 	Stage 4 Generators:
# (_dystack pid=12236) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=12236) 	Stage 5 Generators:
# (_dystack pid=12236) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=12236) 	Unused Original Features (Count: 3): ['ID', '특정_시술_유형_IVI', '정자_출처_미할당']
# (_dystack pid=12236) 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# (_dystack pid=12236) 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# (_dystack pid=12236) 		These features do not need to be present at inference time.
# (_dystack pid=12236) 		('int', [])    : 2 | ['특정_시술_유형_IVI', '정자_출처_미할당']
# (_dystack pid=12236) 		('object', []) : 1 | ['ID']
# (_dystack pid=12236) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=12236) 		('float', []) : 50 | ['시술_당시_나이', '임신_시도_또는_마지막_임신_경과_연수', '단일_배아_이식_여부', '착상_전_유전_검사_사용_여부', '착상_전_유전_진단_사용_여부', ...]
# (_dystack pid=12236) 		('int', [])   : 35 | ['배란_자극_여부', '남성_주_불임_원인', '남성_부_불임_원인', '여성_주_불임_원인', '여성_부_불임_원인', ...]
# (_dystack pid=12236) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=12236) 		('float', [])     : 50 | ['시술_당시_나이', '임신_시도_또는_마지막_임신_경과_연수', '단일_배아_이식_여부', '착상_전_유전_검사_사용_여부', '착상_전_유전_진단_사용_여부', ...]
# (_dystack pid=12236) 		('int', [])       : 18 | ['배란_자극_여부', '남성_주_불임_원인', '남성_부_불임_원인', '여성_주_불임_원인', '여성_부_불임_원인', ...]
# (_dystack pid=12236) 		('int', ['bool']) : 17 | ['시술_유형_IVF', '시술_유형_DI', '특정_시술_유형_AH', '특정_시술_유형_BLASTOCYST', '특정_시술_유형_GenericDI', ...]
# (_dystack pid=12236) 	2.2s = Fit runtime
# (_dystack pid=12236) 	85 features in original data used to generate 85 features in processed data.
# (_dystack pid=12236) 	Train Data (Processed) Memory Usage: 121.91 MB (1.3% of available memory)
# (_dystack pid=12236) Data preprocessing and feature engineering runtime = 2.33s ...
# (_dystack pid=12236) AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# (_dystack pid=12236) 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# (_dystack pid=12236) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=12236) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=12236) User-specified model hyperparameters to be fit:
# (_dystack pid=12236) {
# (_dystack pid=12236) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=12236) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# (_dystack pid=12236) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=12236) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=12236) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=12236) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=12236) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=12236) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=12236) }
# (_dystack pid=12236) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=12236) Fitting 110 L1 models, fit_strategy="sequential" ...
# (_dystack pid=12236) Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 7191.60s of the 10790.10s of remaining time.
# (_dystack pid=12236) 	0.6538	 = Validation score   (roc_auc)
# (_dystack pid=12236) 	0.45s	 = Training   runtime
# (_dystack pid=12236) 	49.73s	 = Validation runtime
# (_dystack pid=12236) Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 7137.85s of the 10736.34s of remaining time.
# (_dystack pid=12236) 	0.6416	 = Validation score   (roc_auc)
# (_dystack pid=12236) 	0.43s	 = Training   runtime
# (_dystack pid=12236) 	47.81s	 = Validation runtime
# (_dystack pid=12236) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 7089.21s of the 10687.71s of remaining time.
# (_dystack pid=12236) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=8.80%)
# (_dystack pid=12236) 	0.7381	 = Validation score   (roc_auc)
# (_dystack pid=12236) 	8.55s	 = Training   runtime
# (_dystack pid=12236) 	1.94s	 = Validation runtime
# (_dystack pid=12236) Fitting model: LightGBM_BAG_L1 ... Training model for up to 7076.85s of the 10675.34s of remaining time.
# (_dystack pid=12236) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=9.07%)
# (_dystack pid=12236) 	0.7383	 = Validation score   (roc_auc)
# (_dystack pid=12236) 	6.33s	 = Training   runtime
# (_dystack pid=12236) 	1.14s	 = Validation runtime
# (_dystack pid=12236) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 7066.93s of the 10665.43s of remaining time.
# (_dystack pid=12236) 	0.7261	 = Validation score   (roc_auc)
# (_dystack pid=12236) 	36.87s	 = Training   runtime
# (_dystack pid=12236) 	11.5s	 = Validation runtime
# (_dystack pid=12236) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 7017.82s of the 10616.31s of remaining time.
# (_dystack pid=12236) 	0.7274	 = Validation score   (roc_auc)
# (_dystack pid=12236) 	38.54s	 = Training   runtime
# (_dystack pid=12236) 	12.17s	 = Validation runtime
# (_dystack pid=12236) Fitting model: CatBoost_BAG_L1 ... Training model for up to 6966.39s of the 10564.88s of remaining time.
# (_dystack pid=12236) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=9.99%)
# (_dystack pid=12236) 	0.7387	 = Validation score   (roc_auc)
# (_dystack pid=12236) 	68.17s	 = Training   runtime
# (_dystack pid=12236) 	0.09s	 = Validation runtime
# (_dystack pid=12236) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 6895.16s of the 10493.65s of remaining time.
# (_dystack pid=12236) 	0.7278	 = Validation score   (roc_auc)
# (_dystack pid=12236) 	35.69s	 = Training   runtime
# (_dystack pid=12236) 	12.38s	 = Validation runtime
# (_dystack pid=12236) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 6846.38s of the 10444.87s of remaining time.
# (_dystack pid=12236) 	0.7282	 = Validation score   (roc_auc)
# (_dystack pid=12236) 	37.07s	 = Training   runtime
# (_dystack pid=12236) 	13.27s	 = Validation runtime
# (_dystack pid=12236) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 6795.23s of the 10393.73s of remaining time.
# (_dystack pid=12236) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=15.25%)
# (_dystack pid=12236) 	0.7368	 = Validation score   (roc_auc)
# (_dystack pid=12236) 	256.51s	 = Training   runtime
# (_dystack pid=12236) 	3.53s	 = Validation runtime
# (_dystack pid=12236) Fitting model: XGBoost_BAG_L1 ... Training model for up to 6534.15s of the 10132.64s of remaining time.
# (_dystack pid=12236) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=12.03%)
# (_dystack pid=12236) 	0.7381	 = Validation score   (roc_auc)
# (_dystack pid=12236) 	126.48s	 = Training   runtime
# (_dystack pid=12236) 	0.99s	 = Validation runtime
# (_dystack pid=12236) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 6404.07s of the 10002.57s of remaining time.
# (_dystack pid=12236) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=8.21%)
# (_dystack pid=12236) 	Warning: Exception caused NeuralNetTorch_BAG_L1 to fail during training... Skipping this model.
# (_dystack pid=12236) 		ray::_ray_fit() (pid=12824, ip=127.0.0.1)
# (_dystack pid=12236)   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
# (_dystack pid=12236)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=12236)     out = self._fit(**kwargs)
# (_dystack pid=12236)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
# (_dystack pid=12236)     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
# (_dystack pid=12236)                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
# (_dystack pid=12236)     dataset = self._process_train_data(
# (_dystack pid=12236)               ^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
# (_dystack pid=12236)     self.processor = create_preprocessor(
# (_dystack pid=12236)                      ^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
# (_dystack pid=12236)     return ColumnTransformer(
# (_dystack pid=12236)            ^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236) TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# (_dystack pid=12236) Detailed Traceback:
# (_dystack pid=12236) Traceback (most recent call last):
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 2106, in _train_and_save
# (_dystack pid=12236)     model = self._train_single(**model_fit_kwargs)
# (_dystack pid=12236)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1993, in _train_single
# (_dystack pid=12236)     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=12236)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=12236)     out = self._fit(**kwargs)
# (_dystack pid=12236)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 270, in _fit
# (_dystack pid=12236)     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
# (_dystack pid=12236)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 298, in _fit
# (_dystack pid=12236)     self._fit_folds(
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 724, in _fit_folds
# (_dystack pid=12236)     fold_fitting_strategy.after_all_folds_scheduled()
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 690, in after_all_folds_scheduled
# (_dystack pid=12236)     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 631, in _run_parallel
# (_dystack pid=12236)     self._process_fold_results(finished, unfinished, fold_ctx)
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 587, in _process_fold_results
# (_dystack pid=12236)     raise processed_exception
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 550, in _process_fold_results
# (_dystack pid=12236)     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
# (_dystack pid=12236)                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
# (_dystack pid=12236)     return fn(*args, **kwargs)
# (_dystack pid=12236)            ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
# (_dystack pid=12236)     return func(*args, **kwargs)
# (_dystack pid=12236)            ^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 2753, in get
# (_dystack pid=12236)     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
# (_dystack pid=12236)                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 904, in get_objects
# (_dystack pid=12236)     raise value.as_instanceof_cause()
# (_dystack pid=12236) ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=12824, ip=127.0.0.1)
# (_dystack pid=12236)   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
# (_dystack pid=12236)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=12236)     out = self._fit(**kwargs)
# (_dystack pid=12236)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
# (_dystack pid=12236)     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
# (_dystack pid=12236)                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
# (_dystack pid=12236)     dataset = self._process_train_data(
# (_dystack pid=12236)               ^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
# (_dystack pid=12236)     self.processor = create_preprocessor(
# (_dystack pid=12236)                      ^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
# (_dystack pid=12236)     return ColumnTransformer(
# (_dystack pid=12236)            ^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236) TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# (_dystack pid=12236) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 6397.33s of the 9995.82s of remaining time.
# (_dystack pid=12236) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=9.56%)
# (_dystack pid=12236) 	0.7374	 = Validation score   (roc_auc)
# (_dystack pid=12236) 	9.01s	 = Training   runtime
# (_dystack pid=12236) 	1.8s	 = Validation runtime
# (_dystack pid=12236) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 6384.50s of the 9982.99s of remaining time.
# (_dystack pid=12236) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=9.13%)
# (_dystack pid=12236) 	0.7388	 = Validation score   (roc_auc)
# (_dystack pid=12236) 	46.04s	 = Training   runtime
# (_dystack pid=12236) 	0.08s	 = Validation runtime
# (_dystack pid=12236) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 6335.00s of the 9933.49s of remaining time.
# (_dystack pid=12236) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=7.89%)
# (_dystack pid=12236) 	Warning: Exception caused NeuralNetTorch_r79_BAG_L1 to fail during training... Skipping this model.
# (_dystack pid=12236) 		ray::_ray_fit() (pid=2028, ip=127.0.0.1)
# (_dystack pid=12236)   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
# (_dystack pid=12236)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=12236)     out = self._fit(**kwargs)
# (_dystack pid=12236)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
# (_dystack pid=12236)     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
# (_dystack pid=12236)                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
# (_dystack pid=12236)     dataset = self._process_train_data(
# (_dystack pid=12236)               ^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
# (_dystack pid=12236)     self.processor = create_preprocessor(
# (_dystack pid=12236)                      ^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
# (_dystack pid=12236)     return ColumnTransformer(
# (_dystack pid=12236)            ^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236) TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# (_dystack pid=12236) Detailed Traceback:
# (_dystack pid=12236) Traceback (most recent call last):
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 2106, in _train_and_save
# (_dystack pid=12236)     model = self._train_single(**model_fit_kwargs)
# (_dystack pid=12236)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1993, in _train_single
# (_dystack pid=12236)     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=12236)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=12236)     out = self._fit(**kwargs)
# (_dystack pid=12236)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 270, in _fit
# (_dystack pid=12236)     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
# (_dystack pid=12236)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 298, in _fit
# (_dystack pid=12236)     self._fit_folds(
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 724, in _fit_folds
# (_dystack pid=12236)     fold_fitting_strategy.after_all_folds_scheduled()
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 690, in after_all_folds_scheduled
# (_dystack pid=12236)     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 631, in _run_parallel
# (_dystack pid=12236)     self._process_fold_results(finished, unfinished, fold_ctx)
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 587, in _process_fold_results
# (_dystack pid=12236)     raise processed_exception
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 550, in _process_fold_results
# (_dystack pid=12236)     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
# (_dystack pid=12236)                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
# (_dystack pid=12236)     return fn(*args, **kwargs)
# (_dystack pid=12236)            ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
# (_dystack pid=12236)     return func(*args, **kwargs)
# (_dystack pid=12236)            ^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 2753, in get
# (_dystack pid=12236)     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
# (_dystack pid=12236)                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 904, in get_objects
# (_dystack pid=12236)     raise value.as_instanceof_cause()
# (_dystack pid=12236) ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=2028, ip=127.0.0.1)
# (_dystack pid=12236)   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
# (_dystack pid=12236)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=12236)     out = self._fit(**kwargs)
# (_dystack pid=12236)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
# (_dystack pid=12236)     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
# (_dystack pid=12236)                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
# (_dystack pid=12236)     dataset = self._process_train_data(
# (_dystack pid=12236)               ^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
# (_dystack pid=12236)     self.processor = create_preprocessor(
# (_dystack pid=12236)                      ^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
# (_dystack pid=12236)     return ColumnTransformer(
# (_dystack pid=12236)            ^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236) TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# (_dystack pid=12236) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=12236) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=19508, ip=127.0.0.1)
# (_dystack pid=12236)   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
# (_dystack pid=12236)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=12236)     out = self._fit(**kwargs)
# (_dystack pid=12236)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
# (_dystack pid=12236)     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
# (_dystack pid=12236)                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
# (_dystack pid=12236)     dataset = self._process_train_data(
# (_dystack pid=12236)               ^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
# (_dystack pid=12236)     self.processor = create_preprocessor(
# (_dystack pid=12236)                      ^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
# (_dystack pid=12236)     return ColumnTransformer(
# (_dystack pid=12236)            ^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236) TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# (_dystack pid=12236) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=12236) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=12236) Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 6328.49s of the 9926.98s of remaining time.
# (_dystack pid=12236) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=9.15%)
# (_dystack pid=12236) 	0.7384	 = Validation score   (roc_auc)
# (_dystack pid=12236) 	20.8s	 = Training   runtime
# (_dystack pid=12236) 	5.68s	 = Validation runtime
# (_dystack pid=12236) Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 6303.19s of the 9901.68s of remaining time.
# (_dystack pid=12236) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=14.60%)
# (_ray_fit pid=19724) No improvement since epoch 12: early stopping
# (_ray_fit pid=20084) No improvement since epoch 15: early stopping
# (_ray_fit pid=11584) No improvement since epoch 18: early stopping
# (_dystack pid=12236) 	0.736	 = Validation score   (roc_auc)
# (_dystack pid=12236) 	833.89s	 = Training   runtime
# (_dystack pid=12236) 	5.82s	 = Validation runtime
# (_dystack pid=12236) Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 5464.99s of the 9063.48s of remaining time.
# (_dystack pid=12236) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=10.40%)
# (_dystack pid=12236) 	0.7383	 = Validation score   (roc_auc)
# (_dystack pid=12236) 	84.66s	 = Training   runtime
# (_dystack pid=12236) 	0.34s	 = Validation runtime
# (_dystack pid=12236) Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 5376.76s of the 8975.25s of remaining time.
# (_dystack pid=12236) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=8.62%)
# (_ray_fit pid=18284) [1000]	valid_set's binary_logloss: 0.488355
# (_ray_fit pid=14796) [2000]	valid_set's binary_logloss: 0.489752 [repeated 5x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (_dystack pid=12236) 	0.7381	 = Validation score   (roc_auc)
# (_dystack pid=12236) 	52.53s	 = Training   runtime
# (_dystack pid=12236) 	12.4s	 = Validation runtime
# (_dystack pid=12236) Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 5318.78s of the 8917.27s of remaining time.
# (_dystack pid=12236) 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (5 workers, per: cpus=3, gpus=0, memory=7.88%)
# (_dystack pid=12236) 	Warning: Exception caused NeuralNetTorch_r22_BAG_L1 to fail during training... Skipping this model.
# (_dystack pid=12236) 		ray::_ray_fit() (pid=11796, ip=127.0.0.1)
# (_dystack pid=12236)   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
# (_dystack pid=12236)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=12236)     out = self._fit(**kwargs)
# (_dystack pid=12236)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
# (_dystack pid=12236)     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
# (_dystack pid=12236)                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
# (_dystack pid=12236)     dataset = self._process_train_data(
# (_dystack pid=12236)               ^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
# (_dystack pid=12236)     self.processor = create_preprocessor(
# (_dystack pid=12236)                      ^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
# (_dystack pid=12236)     return ColumnTransformer(
# (_dystack pid=12236)            ^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236) TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# (_dystack pid=12236) Detailed Traceback:
# (_dystack pid=12236) Traceback (most recent call last):
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 2106, in _train_and_save
# (_dystack pid=12236)     model = self._train_single(**model_fit_kwargs)
# (_dystack pid=12236)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1993, in _train_single
# (_dystack pid=12236)     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=12236)             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=12236)     out = self._fit(**kwargs)
# (_dystack pid=12236)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 270, in _fit
# (_dystack pid=12236)     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
# (_dystack pid=12236)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 298, in _fit
# (_dystack pid=12236)     self._fit_folds(
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 724, in _fit_folds
# (_dystack pid=12236)     fold_fitting_strategy.after_all_folds_scheduled()
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 690, in after_all_folds_scheduled
# (_dystack pid=12236)     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 631, in _run_parallel
# (_dystack pid=12236)     self._process_fold_results(finished, unfinished, fold_ctx)
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 587, in _process_fold_results
# (_dystack pid=12236)     raise processed_exception
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 550, in _process_fold_results
# (_dystack pid=12236)     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
# (_dystack pid=12236)                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
# (_dystack pid=12236)     return fn(*args, **kwargs)
# (_dystack pid=12236)            ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
# (_dystack pid=12236)     return func(*args, **kwargs)
# (_dystack pid=12236)            ^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 2753, in get
# (_dystack pid=12236)     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
# (_dystack pid=12236)                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 904, in get_objects
# (_dystack pid=12236)     raise value.as_instanceof_cause()
# (_dystack pid=12236) ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=11796, ip=127.0.0.1)
# (_dystack pid=12236)   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
# (_dystack pid=12236)     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
# (_dystack pid=12236)     out = self._fit(**kwargs)
# (_dystack pid=12236)           ^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
# (_dystack pid=12236)     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
# (_dystack pid=12236)                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
# (_dystack pid=12236)     dataset = self._process_train_data(
# (_dystack pid=12236)               ^^^^^^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
# (_dystack pid=12236)     self.processor = create_preprocessor(
# (_dystack pid=12236)                      ^^^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236)   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
# (_dystack pid=12236)     return ColumnTransformer(
# (_dystack pid=12236)            ^^^^^^^^^^^^^^^^^^
# (_dystack pid=12236) TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# (_dystack pid=12236) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=12236) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# ...
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
#     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 2106, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1993, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 270, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 298, in _fit
#     self._fit_folds(
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 724, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 690, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 631, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 587, in _process_fold_results
#     raise processed_exception
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 550, in _process_fold_results
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
#                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 2753, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 904, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=10248, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
#     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# Fitting model: NeuralNetTorch_r89_BAG_L1 ... Training model for up to 2453.22s of the 2453.22s of remaining time.
# 	Memory not enough to fit 5 folds in parallel. Will train 2 folds in parallel instead (Estimated 30.62% memory usage per fold, 61.23%/80.00% total).
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=8, gpus=0, memory=30.62%)
# 	Warning: Exception caused NeuralNetTorch_r89_BAG_L1 to fail during training... Skipping this model.
# 		ray::_ray_fit() (pid=10080, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
#     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# Detailed Traceback:
# Traceback (most recent call last):
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 2106, in _train_and_save
#     model = self._train_single(**model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\trainer\abstract_trainer.py", line 1993, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, X_test=X_test, y_test=y_test, total_resources=total_resources, **model_fit_kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py", line 270, in _fit
#     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 298, in _fit
#     self._fit_folds(
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py", line 724, in _fit_folds
#     fold_fitting_strategy.after_all_folds_scheduled()
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 690, in after_all_folds_scheduled
#     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 631, in _run_parallel
#     self._process_fold_results(finished, unfinished, fold_ctx)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 587, in _process_fold_results
#     raise processed_exception
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 550, in _process_fold_results
#     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size, fit_num_cpus, fit_num_gpus = self.ray.get(finished)
#                                                                                                                                      ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 2753, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 904, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TypeError): ray::_ray_fit() (pid=10080, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 1862, in ray._raylet.execute_task
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 413, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 925, in fit
#     out = self._fit(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 201, in _fit
#     train_dataset = self._generate_dataset(X, y, train_params=processor_kwargs, is_train=True)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 669, in _generate_dataset
#     dataset = self._process_train_data(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\torch\tabular_nn_torch.py", line 734, in _process_train_data
#     self.processor = create_preprocessor(
#                      ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\autogluon\tabular\models\tabular_nn\utils\data_preprocessor.py", line 40, in create_preprocessor
#     return ColumnTransformer(
#            ^^^^^^^^^^^^^^^^^^
# TypeError: ColumnTransformer.__init__() got an unexpected keyword argument 'force_int_remainder_cols'
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 3227.22s of the 2447.08s of remaining time.
# 	Ensemble Weights: {'XGBoost_BAG_L1': 0.143, 'NeuralNetFastAI_r187_BAG_L1': 0.143, 'CatBoost_r137_BAG_L1': 0.095, 'CatBoost_r13_BAG_L1': 0.095, 'CatBoost_r5_BAG_L1': 0.095, 'NeuralNetFastAI_r127_BAG_L1': 0.095, 'LightGBM_r96_BAG_L1': 0.048, 'NeuralNetFastAI_r102_BAG_L1': 0.048, 'XGBoost_r89_BAG_L1': 0.048, 'LightGBM_r130_BAG_L1': 0.048, 'CatBoost_r69_BAG_L1': 0.048, 'NeuralNetFastAI_r134_BAG_L1': 0.048, 'RandomForest_r34_BAG_L1': 0.048}
# 	0.74	 = Validation score   (roc_auc)
# 	64.62s	 = Training   runtime
# 	0.04s	 = Validation runtime
# AutoGluon training complete, total runtime = 29891.99s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 2158.4 rows/s (51269 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("c:\Users\juneh\OneDrive\바탕 화면\git_Aimers6th\LG_Aimers_6th\code\AutogluonModels\ag-20250224_1")

# %%
print(predictor.leaderboard(silent = True))
# Out:
#                        model  score_val eval_metric  pred_time_val  \
# 0        WeightedEnsemble_L2   0.739996     roc_auc      33.410904
# 1        CatBoost_r13_BAG_L1   0.739343     roc_auc       0.128871
# 2        CatBoost_r12_BAG_L1   0.739291     roc_auc       0.094613
# 3        CatBoost_r60_BAG_L1   0.739238     roc_auc       0.084701
# 4       CatBoost_r198_BAG_L1   0.739223     roc_auc       0.088770
# ..                       ...        ...         ...            ...
# 85  RandomForest_r195_BAG_L1   0.695217     roc_auc       7.449611
# 86    ExtraTrees_r197_BAG_L1   0.691850     roc_auc       4.438708
# 87   RandomForest_r16_BAG_L1   0.681459     roc_auc       4.022356
# 88     KNeighborsUnif_BAG_L1   0.654629     roc_auc      79.884666
# 89     KNeighborsDist_BAG_L1   0.642139     roc_auc      78.347403
#
#        fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0   3025.766378                0.043166          64.620088            2
# 1    208.661610                0.128871         208.661610            1
# 2    113.376055                0.094613         113.376055            1
# 3     89.255076                0.084701          89.255076            1
# 4    103.815535                0.088770         103.815535            1
# ..          ...                     ...                ...          ...
# 85   112.462590                7.449611         112.462590            1
# 86    80.380079                4.438708          80.380079            1
# 87    77.301647                4.022356          77.301647            1
# 88     0.560397               79.884666           0.560397            1
# 89     0.546092               78.347403           0.546092            1
#
#     can_infer  fit_order
# 0        True         90
# 1        True         22
# 2        True         80
# 3        True         66
# 4        True         85
# ..        ...        ...
# 85       True         23
# 86       True         76
# 87       True         78
# 88       True          1
# 89       True          2
#
# [90 rows x 10 columns]

# %%
# predictor.feature_importance(train_data)

# %%
# 최적의 모델 가져오기
model_to_use = predictor.model_best

# 확률 예측
prob_predictions = predictor.predict_proba(test_data, model=model_to_use)

# %%
# 예측 결과를 test_data에 추가
test_data['probability'] = prob_predictions.iloc[:, 1]

# 최종 제출 파일 생성
submission = test_data[['ID', 'probability']]
submission = submission.sort_values(by='ID')

# 제출 파일 저장
submission.to_csv('../submission/code51_all_autogluon.csv', index=False, encoding='utf-8')

# 예측 결과 확인
print(submission.head())
# Out:
#            ID  probability
# 0  TEST_00000     0.000937
# 1  TEST_00001     0.005474
# 2  TEST_00002     0.163996
# 3  TEST_00003     0.100915
# 4  TEST_00004     0.524633

# %% [markdown]
# PUBLIC 0.7406434323

# %% [markdown]
# ----

# %% [markdown]
# .
