# %% [markdown]
# ## 난임 환자 대상 임신 성공 여부 예측

# %% [markdown]
# ### LGAimers 6th 온라인 해커톤

# %% [markdown]
# ### Import

# %%
import pandas as pd
import matplotlib.pyplot as plt
import lightgbm as lgb
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

# %%
def train_and_evaluate(model, X_train, y_train, X_test, y_test):
    # 모델 학습
    model.fit(X_train, y_train)
    
    # 예측
    y_pred = model.predict(X_test)
    y_pred_proba = model.predict_proba(X_test)[:, 1]
    
    # 평가
    accuracy = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    auc = roc_auc_score(y_test, y_pred_proba)
    cm = confusion_matrix(y_test, y_pred)
    
    # 결과 출력
    print()
    print("--- Model Performance ---")
    print(f"Model Accuracy: {accuracy}")
    print(f"Model F1 Score: {f1}")
    print(f"Model AUC: {auc}")
    
    # 혼동 행렬 출력
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
    disp.plot(cmap=plt.cm.Blues)
    plt.show()
    
    return y_pred, y_pred_proba

# %% [markdown]
# ### Data Load

# %%
# 데이터 로드
IVF_train = pd.read_csv('../data/IVF_train_dataset_54.csv')
IVF_test = pd.read_csv('../data/IVF_test_dataset_54.csv')

DI_train = pd.read_csv('../data/DI_train_dataset_54.csv')
DI_test = pd.read_csv('../data/DI_test_dataset_54.csv')

# %%
# ID 열을 제외한 특성과 타겟 변수 분리
IVF_X = IVF_train.drop(['임신_성공_여부', 'ID'], axis=1)
IVF_y = IVF_train['임신_성공_여부']

DI_X = DI_train.drop(['임신_성공_여부', 'ID'], axis=1)
DI_y = DI_train['임신_성공_여부']

# %%
print(f"IVF_X shape: {IVF_X.shape}")
print(f"IVF_test shape: {IVF_test.drop('ID', axis=1).shape}")

print(f"DI_X shape: {DI_X.shape}")
print(f"DI_test shape: {DI_test.drop('ID', axis=1).shape}")
# Out:
# IVF_X shape: (250052, 77)
# IVF_test shape: (87891, 77)
# DI_X shape: (6289, 31)
# DI_test shape: (2176, 31)

# %% [markdown]
# ### 인코딩

# %%
IVF_categorical_columns = [
    "시술_시기_코드",
    "시술_당시_나이",
    "특정_시술_유형",
    "배란_유도_유형",
    "난자_출처",
    "정자_출처",
    "난자_기증자_나이",
    "정자_기증자_나이",
    "채취_해동_차이",
    "해동_혼합_차이",
    "혼합_이식_차이",
    "이식_해동_차이"
]

# %%
DI_categorical_columns = [
    "시술_시기_코드",
    "시술_당시_나이",
    "특정_시술_유형",
    "정자_기증자_나이"
]

# %%
# 모든 범주형 변수를 문자열로 변환
IVF_X[IVF_categorical_columns] = IVF_X[IVF_categorical_columns].astype(str)
DI_X[DI_categorical_columns] = DI_X[DI_categorical_columns].astype(str)
IVF_test[IVF_categorical_columns] = IVF_test[IVF_categorical_columns].astype(str)
DI_test[DI_categorical_columns] = DI_test[DI_categorical_columns].astype(str)

# OrdinalEncoder를 사용하여 범주형 변수 인코딩
IVF_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
DI_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

IVF_X[IVF_categorical_columns] = IVF_encoder.fit_transform(IVF_X[IVF_categorical_columns])
DI_X[DI_categorical_columns] = DI_encoder.fit_transform(DI_X[DI_categorical_columns])
IVF_test[IVF_categorical_columns] = IVF_encoder.transform(IVF_test[IVF_categorical_columns])
DI_test[DI_categorical_columns] = DI_encoder.transform(DI_test[DI_categorical_columns])

# %% [markdown]
# ## Modeling

# %%
# 데이터 분할
IVF_X_train, IVF_X_test, IVF_y_train, IVF_y_test = train_test_split(IVF_X, IVF_y, test_size=0.2, random_state=42)
DI_X_train, DI_X_test, DI_y_train, DI_y_test = train_test_split(DI_X, DI_y, test_size=0.2, random_state=42)

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, accuracy_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import lightgbm as lgb
from catboost import CatBoostClassifier
import xgboost as xgb
import optuna

# 데이터 준비 함수
def prepare_data(X, y):
    return X, y

# 모델 학습 및 예측 함수
def train_and_predict(model, X_train, y_train, X_test):
    model.fit(X_train, y_train)
    y_pred_proba = model.predict_proba(X_test)[:, 1]
    y_pred = (y_pred_proba > 0.5).astype(int)
    return y_pred, y_pred_proba

# Optuna를 사용한 하이퍼파라미터 최적화 함수
def optimize_model(model_class, X_train, y_train, n_trials=1):
    def objective(trial):
        if model_class == lgb.LGBMClassifier:
            params = {
                'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1, log=True),
                'num_leaves': trial.suggest_int('num_leaves', 20, 150),
                'min_child_samples': trial.suggest_int('min_child_samples', 5, 30),
                'subsample': trial.suggest_float('subsample', 0.5, 1.0),
                'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
                'verbose': -1
            }
        elif model_class == CatBoostClassifier:
            params = {
                'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1, log=True),
                'depth': trial.suggest_int('depth', 4, 10),
                'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1e-5, 1e-1, log=True),
                'border_count': trial.suggest_int('border_count', 32, 255),
                'verbose': 0
            }
        elif model_class == xgb.XGBClassifier:
            params = {
                'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1, log=True),
                'max_depth': trial.suggest_int('max_depth', 3, 10),
                'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
                'subsample': trial.suggest_float('subsample', 0.5, 1.0),
                'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0)
            }
        model = model_class(**params)
        model.fit(X_train, y_train)
        y_pred_proba = model.predict_proba(X_train)[:, 1]
        auc = roc_auc_score(y_train, y_pred_proba)
        return auc

    study = optuna.create_study(direction='maximize')
    study.optimize(objective, n_trials=n_trials)
    return model_class(**study.best_params)

# IVF 데이터 준비
X_train, y_train = prepare_data(IVF_X_train, IVF_y_train)

# 모델 최적화 및 학습
lgb_model = optimize_model(lgb.LGBMClassifier, X_train, y_train)
cat_model = optimize_model(CatBoostClassifier, X_train, y_train)
xgb_model = optimize_model(xgb.XGBClassifier, X_train, y_train)

# DI 데이터 준비
X_train, y_train = prepare_data(DI_X_train, DI_y_train)

# 모델 최적화 및 학습
lgb_model = optimize_model(lgb.LGBMClassifier, X_train, y_train)
cat_model = optimize_model(CatBoostClassifier, X_train, y_train)
xgb_model = optimize_model(xgb.XGBClassifier, X_train, y_train)

# 전체 학습 데이터를 사용하여 모델 학습 및 예측
IVF_X, IVF_y = prepare_data(IVF_X_train, IVF_y_train)
DI_X, DI_y = prepare_data(DI_X_train, DI_y_train)

# IVF 데이터 학습 및 예측
IVF_lgb_pred, IVF_lgb_pred_proba = train_and_predict(lgb_model, IVF_X, IVF_y, IVF_X_test)
IVF_cat_pred, IVF_cat_pred_proba = train_and_predict(cat_model, IVF_X, IVF_y, IVF_X_test)
IVF_xgb_pred, IVF_xgb_pred_proba = train_and_predict(xgb_model, IVF_X, IVF_y, IVF_X_test)

# DI 데이터 학습 및 예측
DI_lgb_pred, DI_lgb_pred_proba = train_and_predict(lgb_model, DI_X, DI_y, DI_X_test)
DI_cat_pred, DI_cat_pred_proba = train_and_predict(cat_model, DI_X, DI_y, DI_X_test)
DI_xgb_pred, DI_xgb_pred_proba = train_and_predict(xgb_model, DI_X, DI_y, DI_X_test)

# 스태킹을 위한 데이터 준비
IVF_stack_train = np.vstack((IVF_lgb_pred_proba, IVF_cat_pred_proba, IVF_xgb_pred_proba)).T
DI_stack_train = np.vstack((DI_lgb_pred_proba, DI_cat_pred_proba, DI_xgb_pred_proba)).T

# 메타 모델 학습 및 예측
meta_model = LogisticRegression()
meta_model.fit(np.vstack((IVF_stack_train, DI_stack_train)), np.hstack((IVF_y, DI_y)))

# IVF 데이터에 대한 메타 모델 예측
IVF_stack_test = np.vstack((IVF_lgb_pred_proba, IVF_cat_pred_proba, IVF_xgb_pred_proba)).T
IVF_meta_pred_test_proba = meta_model.predict_proba(IVF_stack_test)[:, 1]

# DI 데이터에 대한 메타 모델 예측
DI_stack_test = np.vstack((DI_lgb_pred_proba, DI_cat_pred_proba, DI_xgb_pred_proba)).T
DI_meta_pred_test_proba = meta_model.predict_proba(DI_stack_test)[:, 1]

# 예측 결과 병합
IVF_X_test['probability'] = IVF_meta_pred_test_proba
DI_X_test['probability'] = DI_meta_pred_test_proba

# 최종 제출 파일 생성
submission = pd.concat([IVF_X_test[['ID', 'probability']], DI_X_test[['ID', 'probability']]], axis=0)
submission = submission.sort_values(by='ID')

# 제출 파일 저장
submission.to_csv('../submission/code54_stacking.csv', index=False, encoding='utf-8')
# Out:
# [I 2025-02-26 23:33:47,899] A new study created in memory with name: no-name-bdc79d1b-61d7-46ea-84c6-a388bfca4e80
# [I 2025-02-26 23:33:49,224] Trial 0 finished with value: 0.7500638653809963 and parameters: {'learning_rate': 0.06929149475402178, 'num_leaves': 41, 'min_child_samples': 8, 'subsample': 0.9247459756023721, 'colsample_bytree': 0.6710284392415388}. Best is trial 0 with value: 0.7500638653809963.
# [I 2025-02-26 23:33:49,225] A new study created in memory with name: no-name-17603d6d-9b44-4a94-b324-7fd609b63a0f
# [I 2025-02-26 23:34:12,238] Trial 0 finished with value: 0.7841891477564719 and parameters: {'learning_rate': 0.09648395324636447, 'depth': 6, 'l2_leaf_reg': 0.0017136802737390804, 'border_count': 91}. Best is trial 0 with value: 0.7841891477564719.
# [I 2025-02-26 23:34:12,238] A new study created in memory with name: no-name-06abcf13-7389-4fed-98d5-8c1627384bf5
# [I 2025-02-26 23:34:13,125] Trial 0 finished with value: 0.733822123456658 and parameters: {'learning_rate': 0.06259168667973546, 'max_depth': 3, 'min_child_weight': 7, 'subsample': 0.7841278204246391, 'colsample_bytree': 0.9341600848874821}. Best is trial 0 with value: 0.733822123456658.
# [I 2025-02-26 23:34:13,125] A new study created in memory with name: no-name-2bb2bb35-f24d-4cd8-bc4d-345f657b2c4e
# [I 2025-02-26 23:34:13,270] Trial 0 finished with value: 0.9021497610598268 and parameters: {'learning_rate': 0.016112888395163553, 'num_leaves': 121, 'min_child_samples': 29, 'subsample': 0.957354025771032, 'colsample_bytree': 0.7499227293764252}. Best is trial 0 with value: 0.9021497610598268.
# [I 2025-02-26 23:34:13,270] A new study created in memory with name: no-name-192144c3-4526-44d5-ad05-4c934ed2b247
# [I 2025-02-26 23:34:16,015] Trial 0 finished with value: 0.9764597346229985 and parameters: {'learning_rate': 0.03216286171393302, 'depth': 6, 'l2_leaf_reg': 0.04925173573955499, 'border_count': 182}. Best is trial 0 with value: 0.9764597346229985.
# [I 2025-02-26 23:34:16,015] A new study created in memory with name: no-name-1c8fcc13-95c7-4dd8-a84a-fdb453306853
# [I 2025-02-26 23:34:16,123] Trial 0 finished with value: 0.8200882418458426 and parameters: {'learning_rate': 0.06407228825234192, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.7217847970482313, 'colsample_bytree': 0.6662945257536854}. Best is trial 0 with value: 0.8200882418458426.
# 0:	learn: 0.6712654	total: 24.4ms	remaining: 24.4s
# 1:	learn: 0.6520321	total: 48.9ms	remaining: 24.4s
# 2:	learn: 0.6384739	total: 73.5ms	remaining: 24.4s
# 3:	learn: 0.6227285	total: 96.7ms	remaining: 24.1s
# 4:	learn: 0.6095764	total: 122ms	remaining: 24.3s
# 5:	learn: 0.6022344	total: 143ms	remaining: 23.7s
# 6:	learn: 0.5947143	total: 165ms	remaining: 23.4s
# 7:	learn: 0.5848844	total: 190ms	remaining: 23.5s
# 8:	learn: 0.5792618	total: 211ms	remaining: 23.2s
# 9:	learn: 0.5741795	total: 233ms	remaining: 23.1s
# 10:	learn: 0.5696187	total: 256ms	remaining: 23s
# 11:	learn: 0.5649718	total: 280ms	remaining: 23.1s
# 12:	learn: 0.5578269	total: 309ms	remaining: 23.5s
# 13:	learn: 0.5519203	total: 338ms	remaining: 23.8s
# 14:	learn: 0.5487429	total: 364ms	remaining: 23.9s
# 15:	learn: 0.5459510	total: 388ms	remaining: 23.9s
# 16:	learn: 0.5425609	total: 415ms	remaining: 24s
# 17:	learn: 0.5397502	total: 443ms	remaining: 24.2s
# 18:	learn: 0.5376692	total: 469ms	remaining: 24.2s
# 19:	learn: 0.5354447	total: 494ms	remaining: 24.2s
# 20:	learn: 0.5332769	total: 547ms	remaining: 25.5s
# 21:	learn: 0.5316989	total: 570ms	remaining: 25.3s
# 22:	learn: 0.5300420	total: 593ms	remaining: 25.2s
# 23:	learn: 0.5281367	total: 616ms	remaining: 25s
# 24:	learn: 0.5261247	total: 638ms	remaining: 24.9s
# 25:	learn: 0.5248737	total: 661ms	remaining: 24.8s
# 26:	learn: 0.5237599	total: 685ms	remaining: 24.7s
# 27:	learn: 0.5224696	total: 705ms	remaining: 24.5s
# 28:	learn: 0.5211977	total: 725ms	remaining: 24.3s
# 29:	learn: 0.5199484	total: 749ms	remaining: 24.2s
# 30:	learn: 0.5177869	total: 771ms	remaining: 24.1s
# 31:	learn: 0.5168172	total: 791ms	remaining: 23.9s
# 32:	learn: 0.5159306	total: 813ms	remaining: 23.8s
# 33:	learn: 0.5150672	total: 835ms	remaining: 23.7s
# 34:	learn: 0.5136692	total: 856ms	remaining: 23.6s
# 35:	learn: 0.5127878	total: 879ms	remaining: 23.5s
# 36:	learn: 0.5120923	total: 899ms	remaining: 23.4s
# 37:	learn: 0.5113428	total: 920ms	remaining: 23.3s
# 38:	learn: 0.5108520	total: 943ms	remaining: 23.2s
# 39:	learn: 0.5102382	total: 966ms	remaining: 23.2s
# 40:	learn: 0.5092774	total: 986ms	remaining: 23.1s
# 41:	learn: 0.5079217	total: 1.01s	remaining: 23s
# 42:	learn: 0.5075183	total: 1.03s	remaining: 23s
# 43:	learn: 0.5071573	total: 1.05s	remaining: 22.9s
# 44:	learn: 0.5065491	total: 1.08s	remaining: 22.9s
# 45:	learn: 0.5059584	total: 1.1s	remaining: 22.8s
# 46:	learn: 0.5055343	total: 1.12s	remaining: 22.7s
# 47:	learn: 0.5051436	total: 1.15s	remaining: 22.7s
# 48:	learn: 0.5048018	total: 1.17s	remaining: 22.8s
# 49:	learn: 0.5044849	total: 1.2s	remaining: 22.8s
# 50:	learn: 0.5041986	total: 1.22s	remaining: 22.8s
# 51:	learn: 0.5039417	total: 1.25s	remaining: 22.7s
# 52:	learn: 0.5030727	total: 1.28s	remaining: 22.8s
# 53:	learn: 0.5028013	total: 1.3s	remaining: 22.8s
# 54:	learn: 0.5026116	total: 1.32s	remaining: 22.8s
# 55:	learn: 0.5023733	total: 1.35s	remaining: 22.7s
# 56:	learn: 0.5019854	total: 1.37s	remaining: 22.7s
# 57:	learn: 0.5016904	total: 1.4s	remaining: 22.7s
# 58:	learn: 0.5014412	total: 1.42s	remaining: 22.7s
# 59:	learn: 0.5012658	total: 1.45s	remaining: 22.7s
# 60:	learn: 0.5011104	total: 1.47s	remaining: 22.7s
# 61:	learn: 0.5009514	total: 1.5s	remaining: 22.7s
# 62:	learn: 0.5007930	total: 1.52s	remaining: 22.6s
# 63:	learn: 0.5005675	total: 1.54s	remaining: 22.6s
# 64:	learn: 0.5001842	total: 1.56s	remaining: 22.5s
# 65:	learn: 0.4999888	total: 1.59s	remaining: 22.5s
# 66:	learn: 0.4997971	total: 1.61s	remaining: 22.5s
# 67:	learn: 0.4996801	total: 1.64s	remaining: 22.5s
# 68:	learn: 0.4995280	total: 1.66s	remaining: 22.4s
# 69:	learn: 0.4993696	total: 1.69s	remaining: 22.4s
# 70:	learn: 0.4992330	total: 1.72s	remaining: 22.5s
# 71:	learn: 0.4987053	total: 1.75s	remaining: 22.5s
# 72:	learn: 0.4985840	total: 1.77s	remaining: 22.5s
# 73:	learn: 0.4984315	total: 1.79s	remaining: 22.5s
# 74:	learn: 0.4982662	total: 1.82s	remaining: 22.4s
# 75:	learn: 0.4981310	total: 1.84s	remaining: 22.4s
# 76:	learn: 0.4980467	total: 1.86s	remaining: 22.3s
# 77:	learn: 0.4979748	total: 1.88s	remaining: 22.3s
# 78:	learn: 0.4978734	total: 1.9s	remaining: 22.2s
# 79:	learn: 0.4976498	total: 1.93s	remaining: 22.2s
# 80:	learn: 0.4975042	total: 1.95s	remaining: 22.1s
# 81:	learn: 0.4974333	total: 1.97s	remaining: 22.1s
# 82:	learn: 0.4973383	total: 1.99s	remaining: 22s
# 83:	learn: 0.4972705	total: 2.02s	remaining: 22s
# 84:	learn: 0.4972102	total: 2.05s	remaining: 22.1s
# 85:	learn: 0.4971299	total: 2.07s	remaining: 22s
# 86:	learn: 0.4970276	total: 2.09s	remaining: 21.9s
# 87:	learn: 0.4969286	total: 2.11s	remaining: 21.9s
# 88:	learn: 0.4968614	total: 2.13s	remaining: 21.9s
# 89:	learn: 0.4967991	total: 2.15s	remaining: 21.8s
# 90:	learn: 0.4967008	total: 2.18s	remaining: 21.7s
# 91:	learn: 0.4966357	total: 2.2s	remaining: 21.7s
# 92:	learn: 0.4965551	total: 2.22s	remaining: 21.7s
# 93:	learn: 0.4962395	total: 2.25s	remaining: 21.6s
# 94:	learn: 0.4961518	total: 2.27s	remaining: 21.6s
# 95:	learn: 0.4961080	total: 2.29s	remaining: 21.6s
# 96:	learn: 0.4960368	total: 2.31s	remaining: 21.6s
# 97:	learn: 0.4959908	total: 2.34s	remaining: 21.5s
# 98:	learn: 0.4959222	total: 2.36s	remaining: 21.5s
# 99:	learn: 0.4958727	total: 2.38s	remaining: 21.4s
# 100:	learn: 0.4958211	total: 2.4s	remaining: 21.4s
# 101:	learn: 0.4956868	total: 2.42s	remaining: 21.3s
# 102:	learn: 0.4956220	total: 2.45s	remaining: 21.3s
# 103:	learn: 0.4955663	total: 2.47s	remaining: 21.2s
# 104:	learn: 0.4955175	total: 2.49s	remaining: 21.2s
# 105:	learn: 0.4954802	total: 2.51s	remaining: 21.2s
# 106:	learn: 0.4953954	total: 2.54s	remaining: 21.2s
# 107:	learn: 0.4953365	total: 2.56s	remaining: 21.1s
# 108:	learn: 0.4952761	total: 2.58s	remaining: 21.1s
# 109:	learn: 0.4952166	total: 2.6s	remaining: 21.1s
# 110:	learn: 0.4951621	total: 2.63s	remaining: 21s
# 111:	learn: 0.4951114	total: 2.65s	remaining: 21s
# 112:	learn: 0.4950460	total: 2.67s	remaining: 20.9s
# 113:	learn: 0.4950064	total: 2.69s	remaining: 20.9s
# 114:	learn: 0.4949383	total: 2.71s	remaining: 20.9s
# 115:	learn: 0.4948804	total: 2.73s	remaining: 20.8s
# 116:	learn: 0.4948196	total: 2.76s	remaining: 20.8s
# 117:	learn: 0.4947566	total: 2.78s	remaining: 20.8s
# 118:	learn: 0.4947242	total: 2.8s	remaining: 20.7s
# 119:	learn: 0.4947010	total: 2.83s	remaining: 20.7s
# 120:	learn: 0.4946237	total: 2.85s	remaining: 20.7s
# 121:	learn: 0.4944336	total: 2.87s	remaining: 20.7s
# 122:	learn: 0.4942740	total: 2.9s	remaining: 20.7s
# 123:	learn: 0.4942109	total: 2.92s	remaining: 20.6s
# 124:	learn: 0.4941570	total: 2.94s	remaining: 20.6s
# 125:	learn: 0.4941261	total: 2.97s	remaining: 20.6s
# 126:	learn: 0.4940884	total: 2.99s	remaining: 20.5s
# 127:	learn: 0.4940498	total: 3.01s	remaining: 20.5s
# 128:	learn: 0.4940178	total: 3.03s	remaining: 20.5s
# 129:	learn: 0.4939290	total: 3.06s	remaining: 20.5s
# 130:	learn: 0.4938968	total: 3.08s	remaining: 20.4s
# 131:	learn: 0.4938691	total: 3.11s	remaining: 20.4s
# 132:	learn: 0.4938306	total: 3.13s	remaining: 20.4s
# 133:	learn: 0.4937661	total: 3.15s	remaining: 20.4s
# 134:	learn: 0.4937280	total: 3.18s	remaining: 20.4s
# 135:	learn: 0.4937016	total: 3.2s	remaining: 20.3s
# 136:	learn: 0.4936814	total: 3.22s	remaining: 20.3s
# 137:	learn: 0.4936374	total: 3.24s	remaining: 20.2s
# 138:	learn: 0.4935189	total: 3.26s	remaining: 20.2s
# 139:	learn: 0.4934804	total: 3.29s	remaining: 20.2s
# 140:	learn: 0.4934454	total: 3.31s	remaining: 20.2s
# 141:	learn: 0.4933975	total: 3.33s	remaining: 20.1s
# 142:	learn: 0.4933679	total: 3.35s	remaining: 20.1s
# 143:	learn: 0.4933425	total: 3.37s	remaining: 20.1s
# 144:	learn: 0.4933214	total: 3.4s	remaining: 20s
# 145:	learn: 0.4932602	total: 3.42s	remaining: 20s
# 146:	learn: 0.4932399	total: 3.44s	remaining: 20s
# 147:	learn: 0.4931593	total: 3.46s	remaining: 19.9s
# 148:	learn: 0.4931421	total: 3.49s	remaining: 19.9s
# 149:	learn: 0.4931142	total: 3.51s	remaining: 19.9s
# 150:	learn: 0.4930869	total: 3.53s	remaining: 19.9s
# 151:	learn: 0.4930559	total: 3.56s	remaining: 19.8s
# 152:	learn: 0.4930284	total: 3.58s	remaining: 19.8s
# 153:	learn: 0.4930089	total: 3.6s	remaining: 19.8s
# 154:	learn: 0.4929860	total: 3.63s	remaining: 19.8s
# 155:	learn: 0.4929503	total: 3.65s	remaining: 19.7s
# 156:	learn: 0.4929326	total: 3.67s	remaining: 19.7s
# 157:	learn: 0.4929122	total: 3.69s	remaining: 19.7s
# 158:	learn: 0.4928902	total: 3.71s	remaining: 19.6s
# 159:	learn: 0.4928583	total: 3.73s	remaining: 19.6s
# 160:	learn: 0.4928322	total: 3.76s	remaining: 19.6s
# 161:	learn: 0.4928038	total: 3.78s	remaining: 19.6s
# 162:	learn: 0.4926974	total: 3.8s	remaining: 19.5s
# 163:	learn: 0.4926688	total: 3.83s	remaining: 19.5s
# 164:	learn: 0.4926475	total: 3.85s	remaining: 19.5s
# 165:	learn: 0.4926138	total: 3.87s	remaining: 19.4s
# 166:	learn: 0.4925891	total: 3.89s	remaining: 19.4s
# 167:	learn: 0.4925122	total: 3.91s	remaining: 19.4s
# 168:	learn: 0.4924906	total: 3.94s	remaining: 19.4s
# 169:	learn: 0.4924579	total: 3.96s	remaining: 19.3s
# 170:	learn: 0.4924358	total: 3.98s	remaining: 19.3s
# 171:	learn: 0.4924048	total: 4s	remaining: 19.3s
# 172:	learn: 0.4923820	total: 4.03s	remaining: 19.3s
# 173:	learn: 0.4923587	total: 4.05s	remaining: 19.2s
# 174:	learn: 0.4923362	total: 4.07s	remaining: 19.2s
# 175:	learn: 0.4923227	total: 4.09s	remaining: 19.2s
# 176:	learn: 0.4922973	total: 4.11s	remaining: 19.1s
# 177:	learn: 0.4922640	total: 4.13s	remaining: 19.1s
# 178:	learn: 0.4922465	total: 4.16s	remaining: 19.1s
# 179:	learn: 0.4922173	total: 4.18s	remaining: 19s
# 180:	learn: 0.4922040	total: 4.2s	remaining: 19s
# 181:	learn: 0.4921736	total: 4.22s	remaining: 19s
# 182:	learn: 0.4920814	total: 4.25s	remaining: 19s
# 183:	learn: 0.4920652	total: 4.27s	remaining: 18.9s
# 184:	learn: 0.4920499	total: 4.29s	remaining: 18.9s
# 185:	learn: 0.4919940	total: 4.32s	remaining: 18.9s
# 186:	learn: 0.4919797	total: 4.33s	remaining: 18.8s
# 187:	learn: 0.4919597	total: 4.36s	remaining: 18.8s
# 188:	learn: 0.4919499	total: 4.38s	remaining: 18.8s
# 189:	learn: 0.4919372	total: 4.4s	remaining: 18.8s
# 190:	learn: 0.4919235	total: 4.42s	remaining: 18.7s
# 191:	learn: 0.4919037	total: 4.45s	remaining: 18.7s
# 192:	learn: 0.4918370	total: 4.47s	remaining: 18.7s
# 193:	learn: 0.4918121	total: 4.49s	remaining: 18.7s
# 194:	learn: 0.4917439	total: 4.51s	remaining: 18.6s
# 195:	learn: 0.4917206	total: 4.54s	remaining: 18.6s
# 196:	learn: 0.4916990	total: 4.56s	remaining: 18.6s
# 197:	learn: 0.4916799	total: 4.58s	remaining: 18.6s
# 198:	learn: 0.4916692	total: 4.61s	remaining: 18.5s
# 199:	learn: 0.4916497	total: 4.63s	remaining: 18.5s
# 200:	learn: 0.4916366	total: 4.65s	remaining: 18.5s
# 201:	learn: 0.4916157	total: 4.68s	remaining: 18.5s
# 202:	learn: 0.4915996	total: 4.7s	remaining: 18.5s
# 203:	learn: 0.4915834	total: 4.72s	remaining: 18.4s
# 204:	learn: 0.4915640	total: 4.74s	remaining: 18.4s
# 205:	learn: 0.4915450	total: 4.77s	remaining: 18.4s
# 206:	learn: 0.4915314	total: 4.79s	remaining: 18.4s
# 207:	learn: 0.4915161	total: 4.81s	remaining: 18.3s
# 208:	learn: 0.4914990	total: 4.84s	remaining: 18.3s
# 209:	learn: 0.4914823	total: 4.86s	remaining: 18.3s
# 210:	learn: 0.4914689	total: 4.88s	remaining: 18.3s
# 211:	learn: 0.4914366	total: 4.9s	remaining: 18.2s
# 212:	learn: 0.4914223	total: 4.93s	remaining: 18.2s
# 213:	learn: 0.4914046	total: 4.95s	remaining: 18.2s
# 214:	learn: 0.4913810	total: 4.97s	remaining: 18.1s
# 215:	learn: 0.4913618	total: 4.99s	remaining: 18.1s
# 216:	learn: 0.4913353	total: 5.03s	remaining: 18.1s
# 217:	learn: 0.4913132	total: 5.05s	remaining: 18.1s
# 218:	learn: 0.4912926	total: 5.07s	remaining: 18.1s
# 219:	learn: 0.4912824	total: 5.09s	remaining: 18.1s
# 220:	learn: 0.4912655	total: 5.11s	remaining: 18s
# 221:	learn: 0.4912473	total: 5.14s	remaining: 18s
# 222:	learn: 0.4912264	total: 5.16s	remaining: 18s
# 223:	learn: 0.4912145	total: 5.18s	remaining: 18s
# 224:	learn: 0.4911934	total: 5.2s	remaining: 17.9s
# 225:	learn: 0.4911776	total: 5.23s	remaining: 17.9s
# 226:	learn: 0.4911627	total: 5.25s	remaining: 17.9s
# 227:	learn: 0.4911511	total: 5.28s	remaining: 17.9s
# 228:	learn: 0.4911295	total: 5.3s	remaining: 17.8s
# 229:	learn: 0.4911128	total: 5.32s	remaining: 17.8s
# 230:	learn: 0.4910983	total: 5.35s	remaining: 17.8s
# 231:	learn: 0.4910848	total: 5.37s	remaining: 17.8s
# 232:	learn: 0.4910745	total: 5.39s	remaining: 17.7s
# 233:	learn: 0.4910649	total: 5.41s	remaining: 17.7s
# 234:	learn: 0.4910457	total: 5.43s	remaining: 17.7s
# 235:	learn: 0.4910305	total: 5.46s	remaining: 17.7s
# 236:	learn: 0.4910173	total: 5.48s	remaining: 17.6s
# 237:	learn: 0.4910057	total: 5.5s	remaining: 17.6s
# 238:	learn: 0.4909818	total: 5.52s	remaining: 17.6s
# 239:	learn: 0.4909689	total: 5.54s	remaining: 17.6s
# 240:	learn: 0.4909496	total: 5.57s	remaining: 17.5s
# 241:	learn: 0.4908981	total: 5.59s	remaining: 17.5s
# 242:	learn: 0.4908877	total: 5.61s	remaining: 17.5s
# 243:	learn: 0.4908700	total: 5.63s	remaining: 17.5s
# 244:	learn: 0.4908525	total: 5.66s	remaining: 17.4s
# 245:	learn: 0.4908289	total: 5.68s	remaining: 17.4s
# 246:	learn: 0.4908134	total: 5.71s	remaining: 17.4s
# 247:	learn: 0.4907998	total: 5.73s	remaining: 17.4s
# 248:	learn: 0.4907866	total: 5.75s	remaining: 17.3s
# 249:	learn: 0.4907771	total: 5.77s	remaining: 17.3s
# 250:	learn: 0.4907585	total: 5.79s	remaining: 17.3s
# 251:	learn: 0.4907444	total: 5.82s	remaining: 17.3s
# 252:	learn: 0.4907375	total: 5.84s	remaining: 17.2s
# 253:	learn: 0.4907239	total: 5.87s	remaining: 17.2s
# 254:	learn: 0.4907129	total: 5.89s	remaining: 17.2s
# 255:	learn: 0.4906981	total: 5.91s	remaining: 17.2s
# 256:	learn: 0.4906697	total: 5.94s	remaining: 17.2s
# 257:	learn: 0.4906542	total: 5.96s	remaining: 17.1s
# 258:	learn: 0.4906381	total: 5.99s	remaining: 17.1s
# 259:	learn: 0.4906215	total: 6.01s	remaining: 17.1s
# 260:	learn: 0.4906053	total: 6.03s	remaining: 17.1s
# 261:	learn: 0.4905910	total: 6.05s	remaining: 17s
# 262:	learn: 0.4905787	total: 6.07s	remaining: 17s
# 263:	learn: 0.4905678	total: 6.09s	remaining: 17s
# 264:	learn: 0.4905488	total: 6.12s	remaining: 17s
# 265:	learn: 0.4905382	total: 6.14s	remaining: 17s
# 266:	learn: 0.4905289	total: 6.17s	remaining: 16.9s
# 267:	learn: 0.4905119	total: 6.19s	remaining: 16.9s
# 268:	learn: 0.4905021	total: 6.21s	remaining: 16.9s
# 269:	learn: 0.4904699	total: 6.24s	remaining: 16.9s
# 270:	learn: 0.4904540	total: 6.26s	remaining: 16.8s
# 271:	learn: 0.4904347	total: 6.29s	remaining: 16.8s
# 272:	learn: 0.4904204	total: 6.31s	remaining: 16.8s
# 273:	learn: 0.4904043	total: 6.34s	remaining: 16.8s
# 274:	learn: 0.4903923	total: 6.37s	remaining: 16.8s
# 275:	learn: 0.4903717	total: 6.39s	remaining: 16.8s
# 276:	learn: 0.4903580	total: 6.41s	remaining: 16.7s
# 277:	learn: 0.4903434	total: 6.44s	remaining: 16.7s
# 278:	learn: 0.4903270	total: 6.46s	remaining: 16.7s
# 279:	learn: 0.4903093	total: 6.48s	remaining: 16.7s
# 280:	learn: 0.4902917	total: 6.51s	remaining: 16.7s
# 281:	learn: 0.4902697	total: 6.53s	remaining: 16.6s
# 282:	learn: 0.4902201	total: 6.56s	remaining: 16.6s
# 283:	learn: 0.4902055	total: 6.58s	remaining: 16.6s
# 284:	learn: 0.4901881	total: 6.61s	remaining: 16.6s
# 285:	learn: 0.4901721	total: 6.63s	remaining: 16.5s
# 286:	learn: 0.4901505	total: 6.65s	remaining: 16.5s
# 287:	learn: 0.4901391	total: 6.67s	remaining: 16.5s
# 288:	learn: 0.4901229	total: 6.69s	remaining: 16.5s
# 289:	learn: 0.4901063	total: 6.71s	remaining: 16.4s
# 290:	learn: 0.4900962	total: 6.74s	remaining: 16.4s
# 291:	learn: 0.4900780	total: 6.76s	remaining: 16.4s
# 292:	learn: 0.4900645	total: 6.79s	remaining: 16.4s
# 293:	learn: 0.4900563	total: 6.81s	remaining: 16.4s
# 294:	learn: 0.4900432	total: 6.83s	remaining: 16.3s
# 295:	learn: 0.4900026	total: 6.85s	remaining: 16.3s
# 296:	learn: 0.4899884	total: 6.88s	remaining: 16.3s
# 297:	learn: 0.4899754	total: 6.9s	remaining: 16.3s
# 298:	learn: 0.4899615	total: 6.92s	remaining: 16.2s
# 299:	learn: 0.4899448	total: 6.94s	remaining: 16.2s
# 300:	learn: 0.4899308	total: 6.96s	remaining: 16.2s
# 301:	learn: 0.4899176	total: 6.99s	remaining: 16.2s
# 302:	learn: 0.4899101	total: 7.01s	remaining: 16.1s
# 303:	learn: 0.4898898	total: 7.03s	remaining: 16.1s
# 304:	learn: 0.4898744	total: 7.06s	remaining: 16.1s
# 305:	learn: 0.4898644	total: 7.08s	remaining: 16.1s
# 306:	learn: 0.4898575	total: 7.1s	remaining: 16s
# 307:	learn: 0.4898446	total: 7.12s	remaining: 16s
# 308:	learn: 0.4898364	total: 7.15s	remaining: 16s
# 309:	learn: 0.4898202	total: 7.17s	remaining: 16s
# 310:	learn: 0.4898075	total: 7.19s	remaining: 15.9s
# 311:	learn: 0.4897873	total: 7.21s	remaining: 15.9s
# 312:	learn: 0.4897733	total: 7.24s	remaining: 15.9s
# 313:	learn: 0.4897645	total: 7.26s	remaining: 15.9s
# 314:	learn: 0.4897581	total: 7.29s	remaining: 15.8s
# 315:	learn: 0.4897484	total: 7.31s	remaining: 15.8s
# 316:	learn: 0.4897296	total: 7.33s	remaining: 15.8s
# 317:	learn: 0.4897205	total: 7.35s	remaining: 15.8s
# 318:	learn: 0.4897059	total: 7.38s	remaining: 15.7s
# 319:	learn: 0.4896896	total: 7.4s	remaining: 15.7s
# 320:	learn: 0.4896780	total: 7.42s	remaining: 15.7s
# 321:	learn: 0.4896671	total: 7.45s	remaining: 15.7s
# 322:	learn: 0.4896438	total: 7.47s	remaining: 15.7s
# 323:	learn: 0.4896202	total: 7.5s	remaining: 15.6s
# 324:	learn: 0.4896125	total: 7.52s	remaining: 15.6s
# 325:	learn: 0.4896029	total: 7.54s	remaining: 15.6s
# 326:	learn: 0.4895903	total: 7.57s	remaining: 15.6s
# 327:	learn: 0.4895737	total: 7.59s	remaining: 15.5s
# 328:	learn: 0.4895652	total: 7.61s	remaining: 15.5s
# 329:	learn: 0.4895419	total: 7.63s	remaining: 15.5s
# 330:	learn: 0.4895339	total: 7.66s	remaining: 15.5s
# 331:	learn: 0.4895194	total: 7.68s	remaining: 15.4s
# 332:	learn: 0.4895008	total: 7.7s	remaining: 15.4s
# 333:	learn: 0.4894785	total: 7.72s	remaining: 15.4s
# 334:	learn: 0.4894655	total: 7.74s	remaining: 15.4s
# 335:	learn: 0.4894470	total: 7.77s	remaining: 15.4s
# 336:	learn: 0.4894356	total: 7.79s	remaining: 15.3s
# 337:	learn: 0.4894183	total: 7.82s	remaining: 15.3s
# 338:	learn: 0.4893799	total: 7.84s	remaining: 15.3s
# 339:	learn: 0.4893650	total: 7.87s	remaining: 15.3s
# 340:	learn: 0.4893568	total: 7.89s	remaining: 15.2s
# 341:	learn: 0.4893447	total: 7.91s	remaining: 15.2s
# 342:	learn: 0.4893343	total: 7.93s	remaining: 15.2s
# 343:	learn: 0.4893149	total: 7.96s	remaining: 15.2s
# 344:	learn: 0.4892923	total: 7.98s	remaining: 15.2s
# 345:	learn: 0.4892765	total: 8.01s	remaining: 15.1s
# 346:	learn: 0.4892665	total: 8.03s	remaining: 15.1s
# 347:	learn: 0.4892509	total: 8.05s	remaining: 15.1s
# 348:	learn: 0.4892399	total: 8.07s	remaining: 15.1s
# 349:	learn: 0.4892256	total: 8.1s	remaining: 15s
# 350:	learn: 0.4892084	total: 8.12s	remaining: 15s
# 351:	learn: 0.4891911	total: 8.14s	remaining: 15s
# 352:	learn: 0.4891758	total: 8.16s	remaining: 15s
# 353:	learn: 0.4891683	total: 8.18s	remaining: 14.9s
# 354:	learn: 0.4891490	total: 8.21s	remaining: 14.9s
# 355:	learn: 0.4891311	total: 8.23s	remaining: 14.9s
# 356:	learn: 0.4891192	total: 8.26s	remaining: 14.9s
# 357:	learn: 0.4891079	total: 8.28s	remaining: 14.9s
# 358:	learn: 0.4890884	total: 8.31s	remaining: 14.8s
# 359:	learn: 0.4890742	total: 8.33s	remaining: 14.8s
# 360:	learn: 0.4890594	total: 8.35s	remaining: 14.8s
# 361:	learn: 0.4890461	total: 8.38s	remaining: 14.8s
# 362:	learn: 0.4890338	total: 8.4s	remaining: 14.7s
# 363:	learn: 0.4890229	total: 8.42s	remaining: 14.7s
# 364:	learn: 0.4890109	total: 8.45s	remaining: 14.7s
# 365:	learn: 0.4889902	total: 8.47s	remaining: 14.7s
# 366:	learn: 0.4889699	total: 8.49s	remaining: 14.6s
# 367:	learn: 0.4889600	total: 8.52s	remaining: 14.6s
# 368:	learn: 0.4889504	total: 8.54s	remaining: 14.6s
# 369:	learn: 0.4889343	total: 8.56s	remaining: 14.6s
# 370:	learn: 0.4889185	total: 8.58s	remaining: 14.5s
# 371:	learn: 0.4889019	total: 8.61s	remaining: 14.5s
# 372:	learn: 0.4888931	total: 8.63s	remaining: 14.5s
# 373:	learn: 0.4888810	total: 8.65s	remaining: 14.5s
# 374:	learn: 0.4888708	total: 8.67s	remaining: 14.5s
# 375:	learn: 0.4888541	total: 8.7s	remaining: 14.4s
# 376:	learn: 0.4888403	total: 8.72s	remaining: 14.4s
# 377:	learn: 0.4888313	total: 8.74s	remaining: 14.4s
# 378:	learn: 0.4888147	total: 8.77s	remaining: 14.4s
# 379:	learn: 0.4887979	total: 8.79s	remaining: 14.3s
# 380:	learn: 0.4887825	total: 8.81s	remaining: 14.3s
# 381:	learn: 0.4887694	total: 8.84s	remaining: 14.3s
# 382:	learn: 0.4887569	total: 8.86s	remaining: 14.3s
# 383:	learn: 0.4887385	total: 8.88s	remaining: 14.2s
# 384:	learn: 0.4887188	total: 8.9s	remaining: 14.2s
# 385:	learn: 0.4887047	total: 8.93s	remaining: 14.2s
# 386:	learn: 0.4886846	total: 8.95s	remaining: 14.2s
# 387:	learn: 0.4886705	total: 8.97s	remaining: 14.2s
# 388:	learn: 0.4886529	total: 8.99s	remaining: 14.1s
# 389:	learn: 0.4886431	total: 9.02s	remaining: 14.1s
# 390:	learn: 0.4886248	total: 9.04s	remaining: 14.1s
# 391:	learn: 0.4886096	total: 9.07s	remaining: 14.1s
# 392:	learn: 0.4885896	total: 9.09s	remaining: 14s
# 393:	learn: 0.4885767	total: 9.12s	remaining: 14s
# 394:	learn: 0.4885628	total: 9.14s	remaining: 14s
# 395:	learn: 0.4885534	total: 9.17s	remaining: 14s
# 396:	learn: 0.4885429	total: 9.19s	remaining: 14s
# 397:	learn: 0.4885267	total: 9.21s	remaining: 13.9s
# 398:	learn: 0.4885045	total: 9.23s	remaining: 13.9s
# 399:	learn: 0.4884852	total: 9.26s	remaining: 13.9s
# 400:	learn: 0.4884729	total: 9.28s	remaining: 13.9s
# 401:	learn: 0.4884549	total: 9.31s	remaining: 13.8s
# 402:	learn: 0.4884377	total: 9.33s	remaining: 13.8s
# 403:	learn: 0.4884093	total: 9.36s	remaining: 13.8s
# 404:	learn: 0.4883924	total: 9.38s	remaining: 13.8s
# 405:	learn: 0.4883769	total: 9.4s	remaining: 13.8s
# 406:	learn: 0.4883594	total: 9.43s	remaining: 13.7s
# 407:	learn: 0.4883400	total: 9.45s	remaining: 13.7s
# 408:	learn: 0.4883224	total: 9.48s	remaining: 13.7s
# 409:	learn: 0.4883052	total: 9.5s	remaining: 13.7s
# 410:	learn: 0.4882838	total: 9.53s	remaining: 13.7s
# 411:	learn: 0.4882569	total: 9.55s	remaining: 13.6s
# 412:	learn: 0.4882453	total: 9.57s	remaining: 13.6s
# 413:	learn: 0.4882297	total: 9.6s	remaining: 13.6s
# 414:	learn: 0.4882133	total: 9.62s	remaining: 13.6s
# 415:	learn: 0.4882014	total: 9.65s	remaining: 13.6s
# 416:	learn: 0.4881816	total: 9.68s	remaining: 13.5s
# 417:	learn: 0.4881610	total: 9.71s	remaining: 13.5s
# 418:	learn: 0.4881410	total: 9.73s	remaining: 13.5s
# 419:	learn: 0.4881219	total: 9.76s	remaining: 13.5s
# 420:	learn: 0.4881057	total: 9.78s	remaining: 13.5s
# 421:	learn: 0.4880954	total: 9.81s	remaining: 13.4s
# 422:	learn: 0.4880818	total: 9.83s	remaining: 13.4s
# 423:	learn: 0.4880669	total: 9.86s	remaining: 13.4s
# 424:	learn: 0.4880509	total: 9.89s	remaining: 13.4s
# 425:	learn: 0.4880435	total: 9.91s	remaining: 13.4s
# 426:	learn: 0.4880205	total: 9.94s	remaining: 13.3s
# 427:	learn: 0.4880031	total: 9.96s	remaining: 13.3s
# 428:	learn: 0.4879838	total: 9.99s	remaining: 13.3s
# 429:	learn: 0.4879514	total: 10s	remaining: 13.3s
# 430:	learn: 0.4879314	total: 10s	remaining: 13.2s
# 431:	learn: 0.4879176	total: 10.1s	remaining: 13.2s
# 432:	learn: 0.4879061	total: 10.1s	remaining: 13.2s
# 433:	learn: 0.4878864	total: 10.1s	remaining: 13.2s
# 434:	learn: 0.4878675	total: 10.1s	remaining: 13.2s
# 435:	learn: 0.4878467	total: 10.2s	remaining: 13.1s
# 436:	learn: 0.4878274	total: 10.2s	remaining: 13.1s
# 437:	learn: 0.4878063	total: 10.2s	remaining: 13.1s
# 438:	learn: 0.4877901	total: 10.2s	remaining: 13.1s
# 439:	learn: 0.4877715	total: 10.2s	remaining: 13s
# 440:	learn: 0.4877562	total: 10.3s	remaining: 13s
# 441:	learn: 0.4877397	total: 10.3s	remaining: 13s
# 442:	learn: 0.4877245	total: 10.3s	remaining: 13s
# 443:	learn: 0.4877081	total: 10.3s	remaining: 12.9s
# 444:	learn: 0.4876940	total: 10.4s	remaining: 12.9s
# 445:	learn: 0.4876754	total: 10.4s	remaining: 12.9s
# 446:	learn: 0.4876613	total: 10.4s	remaining: 12.9s
# 447:	learn: 0.4876424	total: 10.4s	remaining: 12.8s
# 448:	learn: 0.4876279	total: 10.5s	remaining: 12.8s
# 449:	learn: 0.4876080	total: 10.5s	remaining: 12.8s
# 450:	learn: 0.4875987	total: 10.5s	remaining: 12.8s
# 451:	learn: 0.4875785	total: 10.5s	remaining: 12.8s
# 452:	learn: 0.4875606	total: 10.5s	remaining: 12.7s
# 453:	learn: 0.4875478	total: 10.6s	remaining: 12.7s
# 454:	learn: 0.4875343	total: 10.6s	remaining: 12.7s
# 455:	learn: 0.4875172	total: 10.6s	remaining: 12.7s
# 456:	learn: 0.4875065	total: 10.6s	remaining: 12.6s
# 457:	learn: 0.4874855	total: 10.7s	remaining: 12.6s
# 458:	learn: 0.4874711	total: 10.7s	remaining: 12.6s
# 459:	learn: 0.4874601	total: 10.7s	remaining: 12.6s
# 460:	learn: 0.4874403	total: 10.7s	remaining: 12.6s
# 461:	learn: 0.4874285	total: 10.8s	remaining: 12.5s
# 462:	learn: 0.4874131	total: 10.8s	remaining: 12.5s
# 463:	learn: 0.4873960	total: 10.8s	remaining: 12.5s
# 464:	learn: 0.4873802	total: 10.8s	remaining: 12.5s
# 465:	learn: 0.4873586	total: 10.9s	remaining: 12.5s
# 466:	learn: 0.4873396	total: 10.9s	remaining: 12.4s
# 467:	learn: 0.4873089	total: 10.9s	remaining: 12.4s
# 468:	learn: 0.4872917	total: 10.9s	remaining: 12.4s
# 469:	learn: 0.4872774	total: 11s	remaining: 12.4s
# 470:	learn: 0.4872625	total: 11s	remaining: 12.3s
# 471:	learn: 0.4872427	total: 11s	remaining: 12.3s
# 472:	learn: 0.4872271	total: 11s	remaining: 12.3s
# 473:	learn: 0.4872077	total: 11.1s	remaining: 12.3s
# 474:	learn: 0.4871907	total: 11.1s	remaining: 12.2s
# 475:	learn: 0.4871708	total: 11.1s	remaining: 12.2s
# 476:	learn: 0.4871601	total: 11.1s	remaining: 12.2s
# 477:	learn: 0.4871489	total: 11.2s	remaining: 12.2s
# 478:	learn: 0.4871311	total: 11.2s	remaining: 12.2s
# 479:	learn: 0.4871215	total: 11.2s	remaining: 12.1s
# 480:	learn: 0.4871041	total: 11.2s	remaining: 12.1s
# 481:	learn: 0.4870854	total: 11.3s	remaining: 12.1s
# 482:	learn: 0.4870721	total: 11.3s	remaining: 12.1s
# 483:	learn: 0.4870620	total: 11.3s	remaining: 12s
# 484:	learn: 0.4870538	total: 11.3s	remaining: 12s
# 485:	learn: 0.4870347	total: 11.4s	remaining: 12s
# 486:	learn: 0.4870201	total: 11.4s	remaining: 12s
# 487:	learn: 0.4870034	total: 11.4s	remaining: 12s
# 488:	learn: 0.4869877	total: 11.4s	remaining: 11.9s
# 489:	learn: 0.4869709	total: 11.4s	remaining: 11.9s
# 490:	learn: 0.4869563	total: 11.5s	remaining: 11.9s
# 491:	learn: 0.4869398	total: 11.5s	remaining: 11.9s
# 492:	learn: 0.4869218	total: 11.5s	remaining: 11.9s
# 493:	learn: 0.4869027	total: 11.6s	remaining: 11.8s
# 494:	learn: 0.4868909	total: 11.6s	remaining: 11.8s
# 495:	learn: 0.4868788	total: 11.6s	remaining: 11.8s
# 496:	learn: 0.4868637	total: 11.6s	remaining: 11.8s
# 497:	learn: 0.4868506	total: 11.6s	remaining: 11.7s
# 498:	learn: 0.4868364	total: 11.7s	remaining: 11.7s
# 499:	learn: 0.4868204	total: 11.7s	remaining: 11.7s
# 500:	learn: 0.4868025	total: 11.7s	remaining: 11.7s
# 501:	learn: 0.4867852	total: 11.7s	remaining: 11.6s
# 502:	learn: 0.4867677	total: 11.8s	remaining: 11.6s
# 503:	learn: 0.4867582	total: 11.8s	remaining: 11.6s
# 504:	learn: 0.4867404	total: 11.8s	remaining: 11.6s
# 505:	learn: 0.4867240	total: 11.8s	remaining: 11.6s
# 506:	learn: 0.4867049	total: 11.9s	remaining: 11.5s
# 507:	learn: 0.4866933	total: 11.9s	remaining: 11.5s
# 508:	learn: 0.4866731	total: 11.9s	remaining: 11.5s
# 509:	learn: 0.4866632	total: 11.9s	remaining: 11.5s
# 510:	learn: 0.4866512	total: 11.9s	remaining: 11.4s
# 511:	learn: 0.4866382	total: 12s	remaining: 11.4s
# 512:	learn: 0.4866212	total: 12s	remaining: 11.4s
# 513:	learn: 0.4866053	total: 12s	remaining: 11.4s
# 514:	learn: 0.4865940	total: 12s	remaining: 11.3s
# 515:	learn: 0.4865749	total: 12.1s	remaining: 11.3s
# 516:	learn: 0.4865603	total: 12.1s	remaining: 11.3s
# 517:	learn: 0.4865339	total: 12.1s	remaining: 11.3s
# 518:	learn: 0.4865163	total: 12.1s	remaining: 11.3s
# 519:	learn: 0.4864992	total: 12.2s	remaining: 11.2s
# 520:	learn: 0.4864831	total: 12.2s	remaining: 11.2s
# 521:	learn: 0.4864684	total: 12.2s	remaining: 11.2s
# 522:	learn: 0.4864540	total: 12.2s	remaining: 11.2s
# 523:	learn: 0.4864415	total: 12.3s	remaining: 11.1s
# 524:	learn: 0.4864232	total: 12.3s	remaining: 11.1s
# 525:	learn: 0.4864087	total: 12.3s	remaining: 11.1s
# 526:	learn: 0.4863910	total: 12.3s	remaining: 11.1s
# 527:	learn: 0.4863744	total: 12.4s	remaining: 11s
# 528:	learn: 0.4863604	total: 12.4s	remaining: 11s
# 529:	learn: 0.4863417	total: 12.4s	remaining: 11s
# 530:	learn: 0.4863271	total: 12.4s	remaining: 11s
# 531:	learn: 0.4863150	total: 12.4s	remaining: 11s
# 532:	learn: 0.4862969	total: 12.5s	remaining: 10.9s
# 533:	learn: 0.4862842	total: 12.5s	remaining: 10.9s
# 534:	learn: 0.4862754	total: 12.5s	remaining: 10.9s
# 535:	learn: 0.4862672	total: 12.5s	remaining: 10.9s
# 536:	learn: 0.4862495	total: 12.6s	remaining: 10.8s
# 537:	learn: 0.4862357	total: 12.6s	remaining: 10.8s
# 538:	learn: 0.4862226	total: 12.6s	remaining: 10.8s
# 539:	learn: 0.4862095	total: 12.6s	remaining: 10.8s
# 540:	learn: 0.4861926	total: 12.7s	remaining: 10.7s
# 541:	learn: 0.4861783	total: 12.7s	remaining: 10.7s
# 542:	learn: 0.4861629	total: 12.7s	remaining: 10.7s
# 543:	learn: 0.4861526	total: 12.7s	remaining: 10.7s
# 544:	learn: 0.4861419	total: 12.8s	remaining: 10.7s
# 545:	learn: 0.4861281	total: 12.8s	remaining: 10.6s
# 546:	learn: 0.4861157	total: 12.8s	remaining: 10.6s
# 547:	learn: 0.4861023	total: 12.8s	remaining: 10.6s
# 548:	learn: 0.4860853	total: 12.9s	remaining: 10.6s
# 549:	learn: 0.4860697	total: 12.9s	remaining: 10.5s
# 550:	learn: 0.4860569	total: 12.9s	remaining: 10.5s
# 551:	learn: 0.4860422	total: 12.9s	remaining: 10.5s
# 552:	learn: 0.4860145	total: 13s	remaining: 10.5s
# 553:	learn: 0.4859998	total: 13s	remaining: 10.5s
# 554:	learn: 0.4859908	total: 13s	remaining: 10.4s
# 555:	learn: 0.4859779	total: 13s	remaining: 10.4s
# 556:	learn: 0.4859631	total: 13.1s	remaining: 10.4s
# 557:	learn: 0.4859448	total: 13.1s	remaining: 10.4s
# 558:	learn: 0.4859302	total: 13.1s	remaining: 10.4s
# 559:	learn: 0.4859095	total: 13.2s	remaining: 10.3s
# 560:	learn: 0.4859011	total: 13.2s	remaining: 10.3s
# 561:	learn: 0.4858897	total: 13.2s	remaining: 10.3s
# 562:	learn: 0.4858693	total: 13.2s	remaining: 10.3s
# 563:	learn: 0.4858530	total: 13.3s	remaining: 10.3s
# 564:	learn: 0.4858355	total: 13.3s	remaining: 10.2s
# 565:	learn: 0.4858226	total: 13.3s	remaining: 10.2s
# 566:	learn: 0.4858119	total: 13.3s	remaining: 10.2s
# 567:	learn: 0.4857973	total: 13.4s	remaining: 10.2s
# 568:	learn: 0.4857789	total: 13.4s	remaining: 10.1s
# 569:	learn: 0.4857656	total: 13.4s	remaining: 10.1s
# 570:	learn: 0.4857518	total: 13.4s	remaining: 10.1s
# 571:	learn: 0.4857360	total: 13.5s	remaining: 10.1s
# 572:	learn: 0.4857207	total: 13.5s	remaining: 10.1s
# 573:	learn: 0.4857091	total: 13.5s	remaining: 10s
# 574:	learn: 0.4856934	total: 13.5s	remaining: 10s
# 575:	learn: 0.4856795	total: 13.6s	remaining: 9.99s
# 576:	learn: 0.4856659	total: 13.6s	remaining: 9.97s
# 577:	learn: 0.4856486	total: 13.6s	remaining: 9.94s
# 578:	learn: 0.4856363	total: 13.6s	remaining: 9.92s
# 579:	learn: 0.4856159	total: 13.7s	remaining: 9.89s
# 580:	learn: 0.4856089	total: 13.7s	remaining: 9.87s
# 581:	learn: 0.4855940	total: 13.7s	remaining: 9.85s
# 582:	learn: 0.4855803	total: 13.7s	remaining: 9.83s
# 583:	learn: 0.4855683	total: 13.8s	remaining: 9.8s
# 584:	learn: 0.4855600	total: 13.8s	remaining: 9.78s
# 585:	learn: 0.4855466	total: 13.8s	remaining: 9.76s
# 586:	learn: 0.4855265	total: 13.8s	remaining: 9.74s
# 587:	learn: 0.4855110	total: 13.9s	remaining: 9.71s
# 588:	learn: 0.4854951	total: 13.9s	remaining: 9.69s
# 589:	learn: 0.4854784	total: 13.9s	remaining: 9.66s
# 590:	learn: 0.4854624	total: 13.9s	remaining: 9.64s
# 591:	learn: 0.4854472	total: 14s	remaining: 9.62s
# 592:	learn: 0.4854375	total: 14s	remaining: 9.6s
# 593:	learn: 0.4854241	total: 14s	remaining: 9.57s
# 594:	learn: 0.4854091	total: 14s	remaining: 9.55s
# 595:	learn: 0.4853955	total: 14.1s	remaining: 9.53s
# 596:	learn: 0.4853854	total: 14.1s	remaining: 9.5s
# 597:	learn: 0.4853744	total: 14.1s	remaining: 9.48s
# 598:	learn: 0.4853621	total: 14.1s	remaining: 9.46s
# 599:	learn: 0.4853510	total: 14.2s	remaining: 9.44s
# 600:	learn: 0.4853320	total: 14.2s	remaining: 9.41s
# 601:	learn: 0.4853179	total: 14.2s	remaining: 9.39s
# 602:	learn: 0.4853073	total: 14.2s	remaining: 9.37s
# 603:	learn: 0.4853028	total: 14.3s	remaining: 9.34s
# 604:	learn: 0.4852870	total: 14.3s	remaining: 9.32s
# 605:	learn: 0.4852731	total: 14.3s	remaining: 9.3s
# 606:	learn: 0.4852574	total: 14.3s	remaining: 9.28s
# 607:	learn: 0.4852433	total: 14.3s	remaining: 9.25s
# 608:	learn: 0.4852298	total: 14.4s	remaining: 9.23s
# 609:	learn: 0.4852182	total: 14.4s	remaining: 9.21s
# 610:	learn: 0.4852079	total: 14.4s	remaining: 9.18s
# 611:	learn: 0.4851923	total: 14.5s	remaining: 9.16s
# 612:	learn: 0.4851817	total: 14.5s	remaining: 9.14s
# 613:	learn: 0.4851670	total: 14.5s	remaining: 9.12s
# 614:	learn: 0.4851521	total: 14.5s	remaining: 9.09s
# 615:	learn: 0.4851322	total: 14.6s	remaining: 9.07s
# 616:	learn: 0.4851219	total: 14.6s	remaining: 9.05s
# 617:	learn: 0.4851092	total: 14.6s	remaining: 9.02s
# 618:	learn: 0.4850960	total: 14.6s	remaining: 9s
# 619:	learn: 0.4850868	total: 14.6s	remaining: 8.98s
# 620:	learn: 0.4850736	total: 14.7s	remaining: 8.95s
# 621:	learn: 0.4850599	total: 14.7s	remaining: 8.93s
# 622:	learn: 0.4850404	total: 14.7s	remaining: 8.91s
# 623:	learn: 0.4850278	total: 14.7s	remaining: 8.88s
# 624:	learn: 0.4850151	total: 14.8s	remaining: 8.86s
# 625:	learn: 0.4849995	total: 14.8s	remaining: 8.84s
# 626:	learn: 0.4849949	total: 14.8s	remaining: 8.81s
# 627:	learn: 0.4849813	total: 14.8s	remaining: 8.79s
# 628:	learn: 0.4849752	total: 14.9s	remaining: 8.77s
# 629:	learn: 0.4849629	total: 14.9s	remaining: 8.75s
# 630:	learn: 0.4849489	total: 14.9s	remaining: 8.72s
# 631:	learn: 0.4849303	total: 14.9s	remaining: 8.7s
# 632:	learn: 0.4849209	total: 15s	remaining: 8.68s
# 633:	learn: 0.4849102	total: 15s	remaining: 8.65s
# 634:	learn: 0.4848973	total: 15s	remaining: 8.63s
# 635:	learn: 0.4848807	total: 15s	remaining: 8.61s
# 636:	learn: 0.4848706	total: 15.1s	remaining: 8.58s
# 637:	learn: 0.4848548	total: 15.1s	remaining: 8.56s
# 638:	learn: 0.4848390	total: 15.1s	remaining: 8.54s
# 639:	learn: 0.4848264	total: 15.1s	remaining: 8.51s
# 640:	learn: 0.4848183	total: 15.2s	remaining: 8.49s
# 641:	learn: 0.4848072	total: 15.2s	remaining: 8.47s
# 642:	learn: 0.4847929	total: 15.2s	remaining: 8.45s
# 643:	learn: 0.4847855	total: 15.2s	remaining: 8.42s
# 644:	learn: 0.4847708	total: 15.3s	remaining: 8.4s
# 645:	learn: 0.4847563	total: 15.3s	remaining: 8.38s
# 646:	learn: 0.4847441	total: 15.3s	remaining: 8.35s
# 647:	learn: 0.4847328	total: 15.3s	remaining: 8.33s
# 648:	learn: 0.4847248	total: 15.4s	remaining: 8.31s
# 649:	learn: 0.4847142	total: 15.4s	remaining: 8.28s
# 650:	learn: 0.4847007	total: 15.4s	remaining: 8.26s
# 651:	learn: 0.4846851	total: 15.4s	remaining: 8.24s
# 652:	learn: 0.4846754	total: 15.5s	remaining: 8.21s
# 653:	learn: 0.4846625	total: 15.5s	remaining: 8.19s
# 654:	learn: 0.4846484	total: 15.5s	remaining: 8.17s
# 655:	learn: 0.4846371	total: 15.5s	remaining: 8.14s
# 656:	learn: 0.4846300	total: 15.6s	remaining: 8.12s
# 657:	learn: 0.4846232	total: 15.6s	remaining: 8.1s
# 658:	learn: 0.4846147	total: 15.6s	remaining: 8.07s
# 659:	learn: 0.4846016	total: 15.6s	remaining: 8.05s
# 660:	learn: 0.4845924	total: 15.7s	remaining: 8.03s
# 661:	learn: 0.4845786	total: 15.7s	remaining: 8.01s
# 662:	learn: 0.4845636	total: 15.7s	remaining: 7.99s
# 663:	learn: 0.4845559	total: 15.7s	remaining: 7.96s
# 664:	learn: 0.4845416	total: 15.8s	remaining: 7.94s
# 665:	learn: 0.4845277	total: 15.8s	remaining: 7.92s
# 666:	learn: 0.4845134	total: 15.8s	remaining: 7.89s
# 667:	learn: 0.4845052	total: 15.8s	remaining: 7.87s
# 668:	learn: 0.4844962	total: 15.9s	remaining: 7.85s
# 669:	learn: 0.4844872	total: 15.9s	remaining: 7.82s
# 670:	learn: 0.4844786	total: 15.9s	remaining: 7.8s
# 671:	learn: 0.4844687	total: 15.9s	remaining: 7.78s
# 672:	learn: 0.4844612	total: 16s	remaining: 7.75s
# 673:	learn: 0.4844535	total: 16s	remaining: 7.73s
# 674:	learn: 0.4844430	total: 16s	remaining: 7.71s
# 675:	learn: 0.4844393	total: 16s	remaining: 7.68s
# 676:	learn: 0.4844236	total: 16.1s	remaining: 7.66s
# 677:	learn: 0.4844106	total: 16.1s	remaining: 7.64s
# 678:	learn: 0.4844059	total: 16.1s	remaining: 7.62s
# 679:	learn: 0.4843993	total: 16.1s	remaining: 7.59s
# 680:	learn: 0.4843906	total: 16.2s	remaining: 7.57s
# 681:	learn: 0.4843759	total: 16.2s	remaining: 7.54s
# 682:	learn: 0.4843619	total: 16.2s	remaining: 7.52s
# 683:	learn: 0.4843488	total: 16.2s	remaining: 7.5s
# 684:	learn: 0.4843346	total: 16.3s	remaining: 7.47s
# 685:	learn: 0.4843231	total: 16.3s	remaining: 7.45s
# 686:	learn: 0.4843167	total: 16.3s	remaining: 7.43s
# 687:	learn: 0.4843053	total: 16.3s	remaining: 7.4s
# 688:	learn: 0.4842959	total: 16.4s	remaining: 7.38s
# 689:	learn: 0.4842783	total: 16.4s	remaining: 7.36s
# 690:	learn: 0.4842696	total: 16.4s	remaining: 7.33s
# 691:	learn: 0.4842555	total: 16.4s	remaining: 7.31s
# 692:	learn: 0.4842488	total: 16.5s	remaining: 7.29s
# 693:	learn: 0.4842342	total: 16.5s	remaining: 7.27s
# 694:	learn: 0.4842259	total: 16.5s	remaining: 7.24s
# 695:	learn: 0.4842109	total: 16.5s	remaining: 7.22s
# 696:	learn: 0.4841963	total: 16.6s	remaining: 7.2s
# 697:	learn: 0.4841845	total: 16.6s	remaining: 7.17s
# 698:	learn: 0.4841752	total: 16.6s	remaining: 7.15s
# 699:	learn: 0.4841662	total: 16.6s	remaining: 7.13s
# 700:	learn: 0.4841545	total: 16.7s	remaining: 7.1s
# 701:	learn: 0.4841369	total: 16.7s	remaining: 7.08s
# 702:	learn: 0.4841248	total: 16.7s	remaining: 7.06s
# 703:	learn: 0.4841100	total: 16.7s	remaining: 7.04s
# 704:	learn: 0.4841013	total: 16.8s	remaining: 7.01s
# 705:	learn: 0.4840816	total: 16.8s	remaining: 6.99s
# 706:	learn: 0.4840722	total: 16.8s	remaining: 6.97s
# 707:	learn: 0.4840577	total: 16.8s	remaining: 6.94s
# 708:	learn: 0.4840506	total: 16.9s	remaining: 6.92s
# 709:	learn: 0.4840398	total: 16.9s	remaining: 6.9s
# 710:	learn: 0.4840305	total: 16.9s	remaining: 6.87s
# 711:	learn: 0.4840242	total: 16.9s	remaining: 6.85s
# 712:	learn: 0.4840113	total: 17s	remaining: 6.83s
# 713:	learn: 0.4839948	total: 17s	remaining: 6.8s
# 714:	learn: 0.4839896	total: 17s	remaining: 6.78s
# 715:	learn: 0.4839775	total: 17s	remaining: 6.75s
# 716:	learn: 0.4839702	total: 17.1s	remaining: 6.73s
# 717:	learn: 0.4839582	total: 17.1s	remaining: 6.71s
# 718:	learn: 0.4839402	total: 17.1s	remaining: 6.68s
# 719:	learn: 0.4839309	total: 17.1s	remaining: 6.66s
# 720:	learn: 0.4839118	total: 17.2s	remaining: 6.64s
# 721:	learn: 0.4838976	total: 17.2s	remaining: 6.61s
# 722:	learn: 0.4838843	total: 17.2s	remaining: 6.59s
# 723:	learn: 0.4838710	total: 17.2s	remaining: 6.57s
# 724:	learn: 0.4838607	total: 17.3s	remaining: 6.54s
# 725:	learn: 0.4838509	total: 17.3s	remaining: 6.52s
# 726:	learn: 0.4838359	total: 17.3s	remaining: 6.5s
# 727:	learn: 0.4838240	total: 17.3s	remaining: 6.47s
# 728:	learn: 0.4838205	total: 17.4s	remaining: 6.45s
# 729:	learn: 0.4838088	total: 17.4s	remaining: 6.43s
# 730:	learn: 0.4837967	total: 17.4s	remaining: 6.4s
# 731:	learn: 0.4837888	total: 17.4s	remaining: 6.38s
# 732:	learn: 0.4837747	total: 17.4s	remaining: 6.35s
# 733:	learn: 0.4837676	total: 17.5s	remaining: 6.33s
# 734:	learn: 0.4837522	total: 17.5s	remaining: 6.31s
# 735:	learn: 0.4837402	total: 17.5s	remaining: 6.28s
# 736:	learn: 0.4837285	total: 17.5s	remaining: 6.26s
# 737:	learn: 0.4837200	total: 17.6s	remaining: 6.24s
# 738:	learn: 0.4837117	total: 17.6s	remaining: 6.21s
# 739:	learn: 0.4836925	total: 17.6s	remaining: 6.19s
# 740:	learn: 0.4836804	total: 17.6s	remaining: 6.16s
# 741:	learn: 0.4836676	total: 17.7s	remaining: 6.14s
# 742:	learn: 0.4836554	total: 17.7s	remaining: 6.12s
# 743:	learn: 0.4836395	total: 17.7s	remaining: 6.09s
# 744:	learn: 0.4836333	total: 17.7s	remaining: 6.07s
# 745:	learn: 0.4836266	total: 17.8s	remaining: 6.04s
# 746:	learn: 0.4836136	total: 17.8s	remaining: 6.02s
# 747:	learn: 0.4836010	total: 17.8s	remaining: 6s
# 748:	learn: 0.4835910	total: 17.8s	remaining: 5.97s
# 749:	learn: 0.4835815	total: 17.9s	remaining: 5.95s
# 750:	learn: 0.4835672	total: 17.9s	remaining: 5.93s
# 751:	learn: 0.4835589	total: 17.9s	remaining: 5.9s
# 752:	learn: 0.4835477	total: 17.9s	remaining: 5.88s
# 753:	learn: 0.4835340	total: 18s	remaining: 5.86s
# 754:	learn: 0.4835260	total: 18s	remaining: 5.83s
# 755:	learn: 0.4835191	total: 18s	remaining: 5.81s
# 756:	learn: 0.4835115	total: 18s	remaining: 5.79s
# 757:	learn: 0.4834997	total: 18.1s	remaining: 5.76s
# 758:	learn: 0.4834901	total: 18.1s	remaining: 5.74s
# 759:	learn: 0.4834805	total: 18.1s	remaining: 5.72s
# 760:	learn: 0.4834755	total: 18.1s	remaining: 5.69s
# 761:	learn: 0.4834608	total: 18.2s	remaining: 5.67s
# 762:	learn: 0.4834548	total: 18.2s	remaining: 5.65s
# 763:	learn: 0.4834383	total: 18.2s	remaining: 5.62s
# 764:	learn: 0.4834324	total: 18.2s	remaining: 5.6s
# 765:	learn: 0.4834182	total: 18.2s	remaining: 5.57s
# 766:	learn: 0.4834135	total: 18.3s	remaining: 5.55s
# 767:	learn: 0.4834014	total: 18.3s	remaining: 5.53s
# 768:	learn: 0.4833916	total: 18.3s	remaining: 5.5s
# 769:	learn: 0.4833778	total: 18.3s	remaining: 5.48s
# 770:	learn: 0.4833667	total: 18.4s	remaining: 5.46s
# 771:	learn: 0.4833606	total: 18.4s	remaining: 5.43s
# 772:	learn: 0.4833485	total: 18.4s	remaining: 5.41s
# 773:	learn: 0.4833362	total: 18.4s	remaining: 5.38s
# 774:	learn: 0.4833273	total: 18.5s	remaining: 5.36s
# 775:	learn: 0.4833158	total: 18.5s	remaining: 5.34s
# 776:	learn: 0.4833061	total: 18.5s	remaining: 5.32s
# 777:	learn: 0.4832974	total: 18.5s	remaining: 5.29s
# 778:	learn: 0.4832829	total: 18.6s	remaining: 5.27s
# 779:	learn: 0.4832715	total: 18.6s	remaining: 5.24s
# 780:	learn: 0.4832558	total: 18.6s	remaining: 5.22s
# 781:	learn: 0.4832434	total: 18.6s	remaining: 5.2s
# 782:	learn: 0.4832290	total: 18.7s	remaining: 5.17s
# 783:	learn: 0.4832197	total: 18.7s	remaining: 5.15s
# 784:	learn: 0.4832082	total: 18.7s	remaining: 5.12s
# 785:	learn: 0.4831949	total: 18.7s	remaining: 5.1s
# 786:	learn: 0.4831842	total: 18.8s	remaining: 5.08s
# 787:	learn: 0.4831769	total: 18.8s	remaining: 5.05s
# 788:	learn: 0.4831696	total: 18.8s	remaining: 5.03s
# 789:	learn: 0.4831571	total: 18.8s	remaining: 5s
# 790:	learn: 0.4831417	total: 18.9s	remaining: 4.98s
# 791:	learn: 0.4831344	total: 18.9s	remaining: 4.96s
# 792:	learn: 0.4831269	total: 18.9s	remaining: 4.93s
# 793:	learn: 0.4831188	total: 18.9s	remaining: 4.91s
# 794:	learn: 0.4831098	total: 19s	remaining: 4.89s
# 795:	learn: 0.4831028	total: 19s	remaining: 4.86s
# 796:	learn: 0.4830868	total: 19s	remaining: 4.84s
# 797:	learn: 0.4830781	total: 19s	remaining: 4.82s
# 798:	learn: 0.4830726	total: 19s	remaining: 4.79s
# 799:	learn: 0.4830586	total: 19.1s	remaining: 4.77s
# 800:	learn: 0.4830422	total: 19.1s	remaining: 4.74s
# 801:	learn: 0.4830341	total: 19.1s	remaining: 4.72s
# 802:	learn: 0.4830209	total: 19.1s	remaining: 4.7s
# 803:	learn: 0.4830060	total: 19.2s	remaining: 4.67s
# 804:	learn: 0.4829989	total: 19.2s	remaining: 4.65s
# 805:	learn: 0.4829852	total: 19.2s	remaining: 4.62s
# 806:	learn: 0.4829749	total: 19.2s	remaining: 4.6s
# 807:	learn: 0.4829667	total: 19.3s	remaining: 4.58s
# 808:	learn: 0.4829559	total: 19.3s	remaining: 4.55s
# 809:	learn: 0.4829435	total: 19.3s	remaining: 4.53s
# 810:	learn: 0.4829318	total: 19.3s	remaining: 4.51s
# 811:	learn: 0.4829224	total: 19.4s	remaining: 4.48s
# 812:	learn: 0.4829128	total: 19.4s	remaining: 4.46s
# 813:	learn: 0.4828968	total: 19.4s	remaining: 4.43s
# 814:	learn: 0.4828836	total: 19.4s	remaining: 4.41s
# 815:	learn: 0.4828712	total: 19.5s	remaining: 4.39s
# 816:	learn: 0.4828588	total: 19.5s	remaining: 4.36s
# 817:	learn: 0.4828477	total: 19.5s	remaining: 4.34s
# 818:	learn: 0.4828364	total: 19.5s	remaining: 4.32s
# 819:	learn: 0.4828247	total: 19.6s	remaining: 4.29s
# 820:	learn: 0.4828153	total: 19.6s	remaining: 4.27s
# 821:	learn: 0.4828066	total: 19.6s	remaining: 4.25s
# 822:	learn: 0.4827935	total: 19.6s	remaining: 4.22s
# 823:	learn: 0.4827765	total: 19.7s	remaining: 4.2s
# 824:	learn: 0.4827632	total: 19.7s	remaining: 4.17s
# 825:	learn: 0.4827484	total: 19.7s	remaining: 4.15s
# 826:	learn: 0.4827339	total: 19.7s	remaining: 4.13s
# 827:	learn: 0.4827323	total: 19.8s	remaining: 4.1s
# 828:	learn: 0.4827202	total: 19.8s	remaining: 4.08s
# 829:	learn: 0.4827119	total: 19.8s	remaining: 4.06s
# 830:	learn: 0.4827002	total: 19.8s	remaining: 4.03s
# 831:	learn: 0.4826912	total: 19.9s	remaining: 4.01s
# 832:	learn: 0.4826857	total: 19.9s	remaining: 3.99s
# 833:	learn: 0.4826694	total: 19.9s	remaining: 3.96s
# 834:	learn: 0.4826517	total: 19.9s	remaining: 3.94s
# 835:	learn: 0.4826416	total: 20s	remaining: 3.92s
# 836:	learn: 0.4826260	total: 20s	remaining: 3.89s
# 837:	learn: 0.4826139	total: 20s	remaining: 3.87s
# 838:	learn: 0.4826025	total: 20s	remaining: 3.85s
# 839:	learn: 0.4825965	total: 20.1s	remaining: 3.82s
# 840:	learn: 0.4825817	total: 20.1s	remaining: 3.8s
# 841:	learn: 0.4825675	total: 20.1s	remaining: 3.78s
# 842:	learn: 0.4825602	total: 20.2s	remaining: 3.75s
# 843:	learn: 0.4825525	total: 20.2s	remaining: 3.73s
# 844:	learn: 0.4825411	total: 20.2s	remaining: 3.71s
# 845:	learn: 0.4825328	total: 20.2s	remaining: 3.68s
# 846:	learn: 0.4825205	total: 20.3s	remaining: 3.66s
# 847:	learn: 0.4825065	total: 20.3s	remaining: 3.63s
# 848:	learn: 0.4824941	total: 20.3s	remaining: 3.61s
# 849:	learn: 0.4824832	total: 20.3s	remaining: 3.59s
# 850:	learn: 0.4824744	total: 20.4s	remaining: 3.56s
# 851:	learn: 0.4824617	total: 20.4s	remaining: 3.54s
# 852:	learn: 0.4824543	total: 20.4s	remaining: 3.52s
# 853:	learn: 0.4824467	total: 20.4s	remaining: 3.49s
# 854:	learn: 0.4824390	total: 20.5s	remaining: 3.47s
# 855:	learn: 0.4824285	total: 20.5s	remaining: 3.44s
# 856:	learn: 0.4824110	total: 20.5s	remaining: 3.42s
# 857:	learn: 0.4824001	total: 20.5s	remaining: 3.4s
# 858:	learn: 0.4823925	total: 20.6s	remaining: 3.37s
# 859:	learn: 0.4823888	total: 20.6s	remaining: 3.35s
# 860:	learn: 0.4823794	total: 20.6s	remaining: 3.33s
# 861:	learn: 0.4823686	total: 20.6s	remaining: 3.3s
# 862:	learn: 0.4823636	total: 20.6s	remaining: 3.28s
# 863:	learn: 0.4823550	total: 20.7s	remaining: 3.25s
# 864:	learn: 0.4823411	total: 20.7s	remaining: 3.23s
# 865:	learn: 0.4823320	total: 20.7s	remaining: 3.21s
# 866:	learn: 0.4823203	total: 20.7s	remaining: 3.18s
# 867:	learn: 0.4823124	total: 20.8s	remaining: 3.16s
# 868:	learn: 0.4823043	total: 20.8s	remaining: 3.13s
# 869:	learn: 0.4822970	total: 20.8s	remaining: 3.11s
# 870:	learn: 0.4822888	total: 20.8s	remaining: 3.09s
# 871:	learn: 0.4822825	total: 20.9s	remaining: 3.06s
# 872:	learn: 0.4822724	total: 20.9s	remaining: 3.04s
# 873:	learn: 0.4822573	total: 20.9s	remaining: 3.02s
# 874:	learn: 0.4822498	total: 20.9s	remaining: 2.99s
# 875:	learn: 0.4822382	total: 21s	remaining: 2.97s
# 876:	learn: 0.4822263	total: 21s	remaining: 2.94s
# 877:	learn: 0.4822164	total: 21s	remaining: 2.92s
# 878:	learn: 0.4822068	total: 21s	remaining: 2.9s
# 879:	learn: 0.4821949	total: 21.1s	remaining: 2.87s
# 880:	learn: 0.4821854	total: 21.1s	remaining: 2.85s
# 881:	learn: 0.4821730	total: 21.1s	remaining: 2.82s
# 882:	learn: 0.4821631	total: 21.1s	remaining: 2.8s
# 883:	learn: 0.4821504	total: 21.2s	remaining: 2.78s
# 884:	learn: 0.4821374	total: 21.2s	remaining: 2.75s
# ...
# 750:	learn: 0.2014487	total: 2.25s	remaining: 748ms
# 751:	learn: 0.2012196	total: 2.26s	remaining: 745ms
# 752:	learn: 0.2011299	total: 2.26s	remaining: 742ms
# 753:	learn: 0.2010249	total: 2.26s	remaining: 739ms
# 754:	learn: 0.2009184	total: 2.27s	remaining: 736ms
# 755:	learn: 0.2007468	total: 2.27s	remaining: 732ms
# 756:	learn: 0.2006586	total: 2.27s	remaining: 729ms
# 757:	learn: 0.2005237	total: 2.27s	remaining: 726ms
# 758:	learn: 0.2004002	total: 2.28s	remaining: 723ms
# 759:	learn: 0.2002353	total: 2.28s	remaining: 720ms
# 760:	learn: 0.2000823	total: 2.28s	remaining: 717ms
# 761:	learn: 0.1999444	total: 2.29s	remaining: 714ms
# 762:	learn: 0.1997662	total: 2.29s	remaining: 711ms
# 763:	learn: 0.1996226	total: 2.29s	remaining: 708ms
# 764:	learn: 0.1995305	total: 2.29s	remaining: 705ms
# 765:	learn: 0.1994076	total: 2.3s	remaining: 702ms
# 766:	learn: 0.1993204	total: 2.3s	remaining: 699ms
# 767:	learn: 0.1992286	total: 2.3s	remaining: 696ms
# 768:	learn: 0.1991604	total: 2.31s	remaining: 693ms
# 769:	learn: 0.1989245	total: 2.31s	remaining: 690ms
# 770:	learn: 0.1987671	total: 2.31s	remaining: 686ms
# 771:	learn: 0.1985553	total: 2.31s	remaining: 683ms
# 772:	learn: 0.1984310	total: 2.32s	remaining: 680ms
# 773:	learn: 0.1982910	total: 2.32s	remaining: 677ms
# 774:	learn: 0.1980960	total: 2.32s	remaining: 674ms
# 775:	learn: 0.1980372	total: 2.33s	remaining: 671ms
# 776:	learn: 0.1978954	total: 2.33s	remaining: 668ms
# 777:	learn: 0.1976949	total: 2.33s	remaining: 665ms
# 778:	learn: 0.1975607	total: 2.33s	remaining: 662ms
# 779:	learn: 0.1973626	total: 2.34s	remaining: 659ms
# 780:	learn: 0.1971604	total: 2.34s	remaining: 656ms
# 781:	learn: 0.1970515	total: 2.34s	remaining: 653ms
# 782:	learn: 0.1968977	total: 2.35s	remaining: 650ms
# 783:	learn: 0.1967622	total: 2.35s	remaining: 647ms
# 784:	learn: 0.1966510	total: 2.35s	remaining: 644ms
# 785:	learn: 0.1964677	total: 2.35s	remaining: 641ms
# 786:	learn: 0.1964040	total: 2.36s	remaining: 638ms
# 787:	learn: 0.1961855	total: 2.36s	remaining: 635ms
# 788:	learn: 0.1959646	total: 2.36s	remaining: 632ms
# 789:	learn: 0.1957970	total: 2.37s	remaining: 629ms
# 790:	learn: 0.1956805	total: 2.37s	remaining: 626ms
# 791:	learn: 0.1955450	total: 2.37s	remaining: 623ms
# 792:	learn: 0.1954270	total: 2.37s	remaining: 620ms
# 793:	learn: 0.1953471	total: 2.38s	remaining: 617ms
# 794:	learn: 0.1951824	total: 2.38s	remaining: 614ms
# 795:	learn: 0.1950599	total: 2.38s	remaining: 611ms
# 796:	learn: 0.1949023	total: 2.39s	remaining: 608ms
# 797:	learn: 0.1948535	total: 2.39s	remaining: 605ms
# 798:	learn: 0.1946758	total: 2.39s	remaining: 602ms
# 799:	learn: 0.1945277	total: 2.4s	remaining: 599ms
# 800:	learn: 0.1943985	total: 2.4s	remaining: 596ms
# 801:	learn: 0.1941961	total: 2.4s	remaining: 593ms
# 802:	learn: 0.1941131	total: 2.4s	remaining: 590ms
# 803:	learn: 0.1939370	total: 2.41s	remaining: 587ms
# 804:	learn: 0.1937308	total: 2.41s	remaining: 584ms
# 805:	learn: 0.1936631	total: 2.41s	remaining: 581ms
# 806:	learn: 0.1935881	total: 2.42s	remaining: 578ms
# 807:	learn: 0.1934771	total: 2.42s	remaining: 575ms
# 808:	learn: 0.1933881	total: 2.42s	remaining: 572ms
# 809:	learn: 0.1932159	total: 2.42s	remaining: 569ms
# 810:	learn: 0.1931135	total: 2.43s	remaining: 566ms
# 811:	learn: 0.1929876	total: 2.43s	remaining: 563ms
# 812:	learn: 0.1928693	total: 2.43s	remaining: 560ms
# 813:	learn: 0.1925460	total: 2.44s	remaining: 557ms
# 814:	learn: 0.1924578	total: 2.44s	remaining: 554ms
# 815:	learn: 0.1922693	total: 2.44s	remaining: 551ms
# 816:	learn: 0.1922076	total: 2.44s	remaining: 548ms
# 817:	learn: 0.1920823	total: 2.45s	remaining: 544ms
# 818:	learn: 0.1919908	total: 2.45s	remaining: 541ms
# 819:	learn: 0.1918572	total: 2.45s	remaining: 538ms
# 820:	learn: 0.1916557	total: 2.46s	remaining: 535ms
# 821:	learn: 0.1914763	total: 2.46s	remaining: 532ms
# 822:	learn: 0.1913308	total: 2.46s	remaining: 529ms
# 823:	learn: 0.1912018	total: 2.46s	remaining: 526ms
# 824:	learn: 0.1910416	total: 2.47s	remaining: 523ms
# 825:	learn: 0.1907784	total: 2.47s	remaining: 520ms
# 826:	learn: 0.1906129	total: 2.47s	remaining: 517ms
# 827:	learn: 0.1904372	total: 2.48s	remaining: 514ms
# 828:	learn: 0.1903609	total: 2.48s	remaining: 511ms
# 829:	learn: 0.1901733	total: 2.48s	remaining: 508ms
# 830:	learn: 0.1900161	total: 2.48s	remaining: 505ms
# 831:	learn: 0.1898953	total: 2.49s	remaining: 502ms
# 832:	learn: 0.1897897	total: 2.49s	remaining: 499ms
# 833:	learn: 0.1895908	total: 2.49s	remaining: 496ms
# 834:	learn: 0.1894416	total: 2.49s	remaining: 493ms
# 835:	learn: 0.1893568	total: 2.5s	remaining: 490ms
# 836:	learn: 0.1891767	total: 2.5s	remaining: 487ms
# 837:	learn: 0.1890254	total: 2.5s	remaining: 484ms
# 838:	learn: 0.1888493	total: 2.51s	remaining: 481ms
# 839:	learn: 0.1886984	total: 2.51s	remaining: 478ms
# 840:	learn: 0.1885798	total: 2.51s	remaining: 475ms
# 841:	learn: 0.1884143	total: 2.51s	remaining: 472ms
# 842:	learn: 0.1882159	total: 2.52s	remaining: 469ms
# 843:	learn: 0.1880419	total: 2.52s	remaining: 466ms
# 844:	learn: 0.1879334	total: 2.52s	remaining: 463ms
# 845:	learn: 0.1878099	total: 2.53s	remaining: 460ms
# 846:	learn: 0.1876785	total: 2.53s	remaining: 457ms
# 847:	learn: 0.1875223	total: 2.53s	remaining: 454ms
# 848:	learn: 0.1874113	total: 2.53s	remaining: 451ms
# 849:	learn: 0.1872993	total: 2.54s	remaining: 448ms
# 850:	learn: 0.1872035	total: 2.54s	remaining: 445ms
# 851:	learn: 0.1870816	total: 2.54s	remaining: 442ms
# 852:	learn: 0.1869729	total: 2.55s	remaining: 439ms
# 853:	learn: 0.1868272	total: 2.55s	remaining: 436ms
# 854:	learn: 0.1865827	total: 2.55s	remaining: 433ms
# 855:	learn: 0.1864091	total: 2.56s	remaining: 430ms
# 856:	learn: 0.1862792	total: 2.56s	remaining: 427ms
# 857:	learn: 0.1861432	total: 2.56s	remaining: 424ms
# 858:	learn: 0.1860228	total: 2.56s	remaining: 421ms
# 859:	learn: 0.1859253	total: 2.57s	remaining: 418ms
# 860:	learn: 0.1858257	total: 2.57s	remaining: 415ms
# 861:	learn: 0.1856827	total: 2.57s	remaining: 412ms
# 862:	learn: 0.1855554	total: 2.58s	remaining: 409ms
# 863:	learn: 0.1854005	total: 2.58s	remaining: 406ms
# 864:	learn: 0.1852478	total: 2.58s	remaining: 403ms
# 865:	learn: 0.1850754	total: 2.58s	remaining: 400ms
# 866:	learn: 0.1849129	total: 2.59s	remaining: 397ms
# 867:	learn: 0.1847775	total: 2.59s	remaining: 394ms
# 868:	learn: 0.1845429	total: 2.59s	remaining: 391ms
# 869:	learn: 0.1844012	total: 2.6s	remaining: 388ms
# 870:	learn: 0.1842380	total: 2.6s	remaining: 385ms
# 871:	learn: 0.1841499	total: 2.6s	remaining: 382ms
# 872:	learn: 0.1841058	total: 2.6s	remaining: 379ms
# 873:	learn: 0.1840192	total: 2.61s	remaining: 376ms
# 874:	learn: 0.1838982	total: 2.61s	remaining: 373ms
# 875:	learn: 0.1837214	total: 2.61s	remaining: 370ms
# 876:	learn: 0.1836515	total: 2.62s	remaining: 367ms
# 877:	learn: 0.1835201	total: 2.62s	remaining: 364ms
# 878:	learn: 0.1833074	total: 2.62s	remaining: 361ms
# 879:	learn: 0.1832121	total: 2.62s	remaining: 358ms
# 880:	learn: 0.1830891	total: 2.63s	remaining: 355ms
# 881:	learn: 0.1827539	total: 2.63s	remaining: 352ms
# 882:	learn: 0.1825763	total: 2.63s	remaining: 349ms
# 883:	learn: 0.1825081	total: 2.63s	remaining: 346ms
# 884:	learn: 0.1824061	total: 2.64s	remaining: 343ms
# 885:	learn: 0.1822715	total: 2.64s	remaining: 340ms
# 886:	learn: 0.1822070	total: 2.64s	remaining: 337ms
# 887:	learn: 0.1821769	total: 2.65s	remaining: 334ms
# 888:	learn: 0.1820701	total: 2.65s	remaining: 331ms
# 889:	learn: 0.1819710	total: 2.65s	remaining: 328ms
# 890:	learn: 0.1818316	total: 2.66s	remaining: 325ms
# 891:	learn: 0.1816548	total: 2.66s	remaining: 322ms
# 892:	learn: 0.1815178	total: 2.66s	remaining: 319ms
# 893:	learn: 0.1814609	total: 2.66s	remaining: 316ms
# 894:	learn: 0.1813573	total: 2.67s	remaining: 313ms
# 895:	learn: 0.1811779	total: 2.67s	remaining: 310ms
# 896:	learn: 0.1810289	total: 2.67s	remaining: 307ms
# 897:	learn: 0.1808603	total: 2.68s	remaining: 304ms
# 898:	learn: 0.1807634	total: 2.68s	remaining: 301ms
# 899:	learn: 0.1806286	total: 2.68s	remaining: 298ms
# 900:	learn: 0.1803881	total: 2.69s	remaining: 295ms
# 901:	learn: 0.1801656	total: 2.69s	remaining: 292ms
# 902:	learn: 0.1800062	total: 2.69s	remaining: 289ms
# 903:	learn: 0.1798498	total: 2.69s	remaining: 286ms
# 904:	learn: 0.1797293	total: 2.7s	remaining: 283ms
# 905:	learn: 0.1796332	total: 2.7s	remaining: 280ms
# 906:	learn: 0.1795520	total: 2.7s	remaining: 277ms
# 907:	learn: 0.1794716	total: 2.71s	remaining: 274ms
# 908:	learn: 0.1794185	total: 2.71s	remaining: 271ms
# 909:	learn: 0.1793317	total: 2.71s	remaining: 268ms
# 910:	learn: 0.1792073	total: 2.71s	remaining: 265ms
# 911:	learn: 0.1791306	total: 2.72s	remaining: 262ms
# 912:	learn: 0.1790411	total: 2.72s	remaining: 259ms
# 913:	learn: 0.1789446	total: 2.72s	remaining: 256ms
# 914:	learn: 0.1788435	total: 2.73s	remaining: 253ms
# 915:	learn: 0.1787470	total: 2.73s	remaining: 250ms
# 916:	learn: 0.1786296	total: 2.73s	remaining: 247ms
# 917:	learn: 0.1784722	total: 2.73s	remaining: 244ms
# 918:	learn: 0.1783447	total: 2.74s	remaining: 241ms
# 919:	learn: 0.1782341	total: 2.74s	remaining: 238ms
# 920:	learn: 0.1781190	total: 2.74s	remaining: 235ms
# 921:	learn: 0.1780145	total: 2.75s	remaining: 232ms
# 922:	learn: 0.1778884	total: 2.75s	remaining: 229ms
# 923:	learn: 0.1777226	total: 2.75s	remaining: 226ms
# 924:	learn: 0.1775914	total: 2.76s	remaining: 224ms
# 925:	learn: 0.1774420	total: 2.76s	remaining: 221ms
# 926:	learn: 0.1772553	total: 2.76s	remaining: 218ms
# 927:	learn: 0.1771541	total: 2.77s	remaining: 215ms
# 928:	learn: 0.1769317	total: 2.77s	remaining: 212ms
# 929:	learn: 0.1768444	total: 2.77s	remaining: 209ms
# 930:	learn: 0.1767502	total: 2.77s	remaining: 206ms
# 931:	learn: 0.1766439	total: 2.78s	remaining: 203ms
# 932:	learn: 0.1764960	total: 2.78s	remaining: 200ms
# 933:	learn: 0.1764148	total: 2.78s	remaining: 197ms
# 934:	learn: 0.1763260	total: 2.79s	remaining: 194ms
# 935:	learn: 0.1762429	total: 2.79s	remaining: 191ms
# 936:	learn: 0.1760336	total: 2.79s	remaining: 188ms
# 937:	learn: 0.1759063	total: 2.79s	remaining: 185ms
# 938:	learn: 0.1757962	total: 2.8s	remaining: 182ms
# 939:	learn: 0.1757067	total: 2.8s	remaining: 179ms
# 940:	learn: 0.1755438	total: 2.8s	remaining: 176ms
# 941:	learn: 0.1754086	total: 2.81s	remaining: 173ms
# 942:	learn: 0.1752996	total: 2.81s	remaining: 170ms
# 943:	learn: 0.1751570	total: 2.81s	remaining: 167ms
# 944:	learn: 0.1750333	total: 2.81s	remaining: 164ms
# 945:	learn: 0.1748761	total: 2.82s	remaining: 161ms
# 946:	learn: 0.1747137	total: 2.82s	remaining: 158ms
# 947:	learn: 0.1746031	total: 2.82s	remaining: 155ms
# 948:	learn: 0.1744012	total: 2.83s	remaining: 152ms
# 949:	learn: 0.1742467	total: 2.83s	remaining: 149ms
# 950:	learn: 0.1741527	total: 2.83s	remaining: 146ms
# 951:	learn: 0.1740154	total: 2.83s	remaining: 143ms
# 952:	learn: 0.1739029	total: 2.84s	remaining: 140ms
# 953:	learn: 0.1737667	total: 2.84s	remaining: 137ms
# 954:	learn: 0.1736521	total: 2.84s	remaining: 134ms
# 955:	learn: 0.1735854	total: 2.85s	remaining: 131ms
# 956:	learn: 0.1735099	total: 2.85s	remaining: 128ms
# 957:	learn: 0.1733848	total: 2.85s	remaining: 125ms
# 958:	learn: 0.1732572	total: 2.85s	remaining: 122ms
# 959:	learn: 0.1731419	total: 2.86s	remaining: 119ms
# 960:	learn: 0.1730275	total: 2.86s	remaining: 116ms
# 961:	learn: 0.1728885	total: 2.86s	remaining: 113ms
# 962:	learn: 0.1727814	total: 2.87s	remaining: 110ms
# 963:	learn: 0.1725687	total: 2.87s	remaining: 107ms
# 964:	learn: 0.1724131	total: 2.87s	remaining: 104ms
# 965:	learn: 0.1723282	total: 2.87s	remaining: 101ms
# 966:	learn: 0.1722196	total: 2.88s	remaining: 98.2ms
# 967:	learn: 0.1720862	total: 2.88s	remaining: 95.2ms
# 968:	learn: 0.1719532	total: 2.88s	remaining: 92.2ms
# 969:	learn: 0.1717724	total: 2.88s	remaining: 89.3ms
# 970:	learn: 0.1716897	total: 2.89s	remaining: 86.3ms
# 971:	learn: 0.1715673	total: 2.89s	remaining: 83.3ms
# 972:	learn: 0.1714535	total: 2.89s	remaining: 80.3ms
# 973:	learn: 0.1713252	total: 2.9s	remaining: 77.3ms
# 974:	learn: 0.1712380	total: 2.9s	remaining: 74.4ms
# 975:	learn: 0.1711479	total: 2.9s	remaining: 71.4ms
# 976:	learn: 0.1710267	total: 2.91s	remaining: 68.4ms
# 977:	learn: 0.1709357	total: 2.91s	remaining: 65.4ms
# 978:	learn: 0.1708399	total: 2.91s	remaining: 62.5ms
# 979:	learn: 0.1706709	total: 2.91s	remaining: 59.5ms
# 980:	learn: 0.1704160	total: 2.92s	remaining: 56.5ms
# 981:	learn: 0.1702841	total: 2.92s	remaining: 53.5ms
# 982:	learn: 0.1701274	total: 2.92s	remaining: 50.6ms
# 983:	learn: 0.1699734	total: 2.93s	remaining: 47.6ms
# 984:	learn: 0.1698945	total: 2.93s	remaining: 44.6ms
# 985:	learn: 0.1697133	total: 2.93s	remaining: 41.6ms
# 986:	learn: 0.1695886	total: 2.94s	remaining: 38.7ms
# 987:	learn: 0.1695174	total: 2.94s	remaining: 35.7ms
# 988:	learn: 0.1694397	total: 2.94s	remaining: 32.7ms
# 989:	learn: 0.1693023	total: 2.94s	remaining: 29.7ms
# 990:	learn: 0.1691877	total: 2.95s	remaining: 26.8ms
# 991:	learn: 0.1690611	total: 2.95s	remaining: 23.8ms
# 992:	learn: 0.1689310	total: 2.95s	remaining: 20.8ms
# 993:	learn: 0.1688807	total: 2.96s	remaining: 17.8ms
# 994:	learn: 0.1687795	total: 2.96s	remaining: 14.9ms
# 995:	learn: 0.1686904	total: 2.96s	remaining: 11.9ms
# 996:	learn: 0.1686129	total: 2.96s	remaining: 8.92ms
# 997:	learn: 0.1685192	total: 2.97s	remaining: 5.95ms
# 998:	learn: 0.1684709	total: 2.97s	remaining: 2.97ms
# 999:	learn: 0.1684159	total: 2.97s	remaining: 0us
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 96
#      94 # 메타 모델 학습 및 예측
#      95 meta_model = LogisticRegression()
# ---> 96 meta_model.fit(np.vstack((IVF_stack_train, DI_stack_train)), np.hstack((IVF_y, DI_y)))
#      98 # IVF 데이터에 대한 메타 모델 예측
#      99 IVF_stack_test = np.vstack((IVF_lgb_pred_proba, IVF_cat_pred_proba, IVF_xgb_pred_proba)).T
#
# File c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1201, in LogisticRegression.fit(self, X, y, sample_weight)
#    1198 else:
#    1199     _dtype = [np.float64, np.float32]
# -> 1201 X, y = self._validate_data(
#    1202     X,
#    1203     y,
#    1204     accept_sparse="csr",
#    1205     dtype=_dtype,
#    1206     order="C",
#    1207     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1208 )
#    1209 check_classification_targets(y)
#    1210 self.classes_ = np.unique(y)
#
# File c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1281, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1263 X = check_array(
#    1264     X,
#    1265     accept_sparse=accept_sparse,
#    (...)
#    1276     input_name="X",
#    1277 )
#    1279 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
# -> 1281 check_consistent_length(X, y)
#    1283 return X, y
#
# File c:\Users\juneh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:457, in check_consistent_length(*arrays)
#     455 uniques = np.unique(lengths)
#     456 if len(uniques) > 1:
# --> 457     raise ValueError(
#     458         "Found input variables with inconsistent numbers of samples: %r"
#     459         % [int(l) for l in lengths]
#     460     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [51269, 205072]

# %% [markdown]
# .
